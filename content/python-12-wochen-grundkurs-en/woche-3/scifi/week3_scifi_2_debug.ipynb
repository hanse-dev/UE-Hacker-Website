# %% [markdown]
# # 🐛 Debug Quest – 🚀 Week 3 – Conditions (if-else): The Paths of Decision
#
# A junior technician tried to program decision protocols, but something went wrong! Find the bugs:
# > 💡 **These bugs were built in on purpose** – so you can practice debugging!

# %% [markdown]
# ### 🐛 Bug #1
#
# What is wrong? Find and fix the bug!

# %%
level = 10
if level >= 10:
print("Access granted!")
print("Welcome Commander!")

# %% [markdown]
# ### 🐛 Bug #2
#
# What is wrong? Find and fix the bug!

# %%
user = "Admin"
if user = "Admin":
    print("Hello Admin!")

# %% [markdown]
# ### 🐛 Bug #3
#
# What is wrong? Find and fix the bug!

# %%
status = 25
if status >= 18:
    print("System active")
elif:
    print("System inactive")
