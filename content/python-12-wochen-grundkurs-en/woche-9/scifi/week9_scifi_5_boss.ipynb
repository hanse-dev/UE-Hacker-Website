# %% [markdown]
# # 🐉 Boss Quests – 🚀 Week 9 – JSON Files and I/O: The Data Pipelines
# > ⚠️ Harder! Combines everything from this week.
#
# **⚠️ ATTENTION:** These quests are significantly harder! They combine everything you have learned.
#
# **Rewards:** 1500 Cyber Credits total + legendary items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 1: The Mission Diary
#
# **Reward:** 500 Cyber Credits + Digital Log Book
#
# Every crew keeps a mission diary – for the history of the galaxy!
#
# **Step 1 – Write an entry:**
# Let the user enter a log entry with `input()` (date, planet, event). Save it in a text file.
#
# **Step 2 – Read the log:**
# Read the file back in and display all entries clearly.
#
# **Step 3 – Collect entries:**
# Let the user enter 3 entries one after another. Append each new entry to the file. At the end, read the complete log.
#
# **Bonus:** Count how many log entries the file contains.

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss Quest 2: The Star Map
#
# **Reward:** 600 Cyber Credits + Holographic Star Map
#
# All explored systems are stored in a JSON file!
#
# **Step 1 – Create a star map:**
# Create a dictionary with 3 star system entries (name, coordinates, status, distance). Save it as a JSON file.
#
# **Step 2 – Load the map:**
# Load the JSON file back in and display all systems clearly.
#
# **Step 3 – Add a system:**
# Load the map, add a new star system and save the updated version. Display the final map.
#
# **Bonus:** Find the most distant system and mark it.

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 3: The Mission Archive
#
# **Reward:** 400 Cyber Credits + Data Chip
#
# The fleet keeps a digital archive of all missions!
#
# **Step 1 – Save missions:**
# Create a list with 3 mission entries (name, planet, result, crew) as dictionaries. Save as JSON.
#
# **Step 2 – Load archive:**
# Load the archive and display all missions clearly.
#
# **Step 3 – Update mission:**
# Load the archive, change the result status of one mission to "Successfully completed" and save the updated version. Display the final archive.
#
# **Bonus:** Write a short mission report as a text file.

# %%
print()
print('🎉 +400 Cyber Credits: Boss Quest complete!')
print('🏆 You defeated the Data Archivist of Infinite Streams!')
print('⭐ Title earned: Master of Data Pipelines')
print()
print('🎊 CONGRATULATIONS! You have mastered Week 9!')
print('📚 Next week: Object-Oriented Programming!')

# %% [markdown]
# ---
#
# 🎊 **Congratulations!** You have completed all boss quests of this week!
#
# **Next:** Week 10 is already waiting!
