# %% [markdown]
# # ⭐ Missions – 🗺️ Week 1 – Introduction and your first program: The journey begins!
#
# The time has come to prove your knowledge in real challenges!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: The Apprentice Wizard
#
# **Reward:** 300 XP + Magic Scroll
#
# Your first mission in Pythonia! Show that you have mastered the basic commands.
#
# **Step 1 – Personal introduction:**
# Output your name with `print()` and output a friendly greeting for the land of Pythonia
#
# **Step 2 – Choose a favourite spell:**
# Create a variable for your favourite spell and output the spell name in a complete sentence
#
# **Bonus:** Output your hero's motto!

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: The Treasure Hunter
#
# **Reward:** 400 XP + Treasure Map
#
# A legendary treasure is hidden somewhere in Pythonia! Document your search.
#
# **Step 1 – Collect treasure data:**
# Create a variable for the treasure name (text) and create a variable for the treasure type (text)
#
# **Step 2 – Output a treasure report:**
# Output a heading `"=== TREASURE REPORT ==="` and output each value with a description on its own line
#
# **Step 3 – Write discovery report:**
# Create a sentence combining all three pieces of information and add a closing line `"=== SEARCH COMPLETE ==="`
#
# **Bonus:** Add the gold value of the treasure!

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Village Hero
#
# **Reward:** 500 XP + Guild Badge
#
# The village is in danger! Create a hero profile to save the day.
#
# **Step 1 – Collect hero data:**
# Create a variable for the hero name and create a variable for the hero class
#
# **Step 2 – Create hero heading:**
# Output a heading `"=== HERO PROFILE ===" ` and add an empty line
#
# **Step 3 – Write battle description:**
# Create 3 complete sentences about the hero and combine different variables in the sentences
#
# **Step 4 – Add motivation:**
# Output `"For the village!"` and output an inspiring battle cry
#
#
# > 💡 **Tip:** You decide how to implement it – there is no single right way!
# **Bonus:** Add the hero's strength stat!

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### 🎯 Learning goals – Have you achieved them?
#
# Check for yourself whether you have mastered these skills:
#
# - ☐ Display text with `print()`
# - ☐ Store information in variables
# - ☐ Combine texts with `+` and `str()`
# - ☐ Add comments with `#`
# - ☐ Find and fix simple errors
# - ☐ Write your own small programs
#
# If you can tick all the boxes – congratulations! You're ready for the final challenges!
