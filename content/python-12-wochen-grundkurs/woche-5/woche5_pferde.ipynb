# %% [markdown]
# # 🐎 Woche 5 – Die Pferde-Freunde: Funktionen für Tierliebe!
# **Huf-Punkte zu verdienen:** 1200 Punkte
# **Herausforderung:** Der Chaos-Stall der vergessenen Tier-Geschichten

# %% [markdown]
# ## 🐴 Die Pferde-Freundschaft beginnt: Dein erstes Pferde-Tagebuch
# **Hintergrundstory:**
# Du bist ein:e junge:r Pferdefreund:in auf dem wunderschönen Pferdehof "Sonnental". Bisher hast du nur einzelne Pferde und ihre Eigenschaften gekannt – die Fellfarbe hier, das Alter da. Aber jetzt steht dir eine große Aufgabe vor: Du musst das **Pferde-Tagebuch** organisieren, in dem alle Pferde-Geschichten und Persönlichkeiten wild durcheinander liegen!
# Dafür brauchst du ein **Pferde-Tagebuch-System** – eine magische Sammlung, die viele Informationen über deine Lieblingstiere aufnehmen kann. In Python nennen wir diese magische Sammlung eine **Funktion**.
# **Deine Mission:** Lerne, wie du Funktionen erstellst, verwalten und meisterst, um die beste Pferdefreund:in zu sein, die es je gab!

# %% [markdown]
# ## 🏇 Was ist ein Pferde-Tagebuch (Funktion)?
# Stell dir dein Pferde-Tagebuch wie eine **herzerwärmende Sammlung mit nummerierten Seiten** vor. Jede Seite hat eine Nummer (beginnend bei 0 – so zählen Programmierer:innen!) und du kannst auf jede Seite eine Geschichte über ein Pferd schreiben.
# **Warum ist das so schön für Pferde?**
# - 🐎 **Viele Pferde kennenlernen**: Statt nur ein Pferd zu kennen, kannst du alle Pferde, ihre Charaktere und Besonderheiten im Herzen tragen!
# - 📍 **Schnelle Erinnerung**: "Erzähl mir die Geschichte von Seite 2!" – Sofort da!
# - ✨ **Wachsende Freundschaft**: Neue Pferde kennenlernen, besondere Momente festhalten, Beziehungen vertiefen
# - 🔄 **Alle durchgehen**: Erinnere dich an alle schönen Pferde-Momente
# **Fun Fact:** Echte Pferdeliebhaber:innen und Reitbeteiligte nutzen genau dieses Konzept – Listen von Pferden, ihre Eigenschaften und gemeinsame Erlebnisse!

# %% [markdown]
# ### 🐎 Tutorial: Deine erste Pferde-Geschichte erstellen
# Die erfahrene Pferdefreundin zeigt dir die Grundformel:
# ```python
# def routine_name():
#     # Deine Anweisungen hier
#     pass
# ```
# Das Stichwort `def` ist das magische Symbol für Funktionen. Die Einrückung zeigt, was zur Geschichte gehört.

# %% [markdown]
# # 🐴 Level 1: Verschiedene Pferde-Geschichten-Typen erstellen
# # Einfache Geschichte (ohne Arbeitsmittel)
# def begruessung():
#     print("🌾 Willkommen auf dem Pferdehof!")
#     print("🐎 Die Pferde freuen sich auf dich!")
# # Geschichte mit Arbeitsmitteln (Parameter)
# def pferd_begruessen(name):
#     print(f"🤗 Hallo {name}! Du bist ein wunderschönes Pferd!")
# # Geschichte mit Rückgabe (Return)
# def zaehle_pferde(anzahl):
#     return f"Wir haben {anzahl} liebe Pferde!"# Leere Geschichte (für später!)
# def zukuenftige_geschichte():
#     pass
# print("🎉 +100 Huf-Punkte: Du hast gelernt, verschiedene Pferde-Geschichten zu erstellen!")

# %%
# 🐴 Level 2: Deine erste Pferde-Geschichte in Aktion!
# DEFINITION der Geschichte (ins Pferde-Tagebuch schreiben)
def sag_hallo():
    print("✨ Hallo! Schön, dass du da bist.")
    print("🪄 Dies ist deine erste Pferde-Geschichte!")
def haupt_geschichte():
    print("🔮 Ich bin die Hauptgeschichte und rufe jetzt eine andere Geschichte auf...")
    sag_hallo()  # Eine Geschichte ruft eine andere!
# AUFRUF der Geschichte (Erzählen durchführen!)
print("📖 Geschichte wird ins Tagebuch geschrieben...")
print("⚡ Jetzt erzählen wir die Geschichte!\n")
haupt_geschichte()
print("\n🎉 +100 Huf-Punkte: Du hast deine erste Geschichte erzählt!")

# %% [markdown]
# ### 🔍 Skill: Geschichten-Arbeitsmittel (Parameter)
# Manchmal braucht eine Geschichte **Arbeitsmittel**, um zu funktionieren! Eine Fütterungs-Geschichte braucht vielleicht den Pferdenamen, eine Pflege-Geschichte braucht die Art der Pflege.
# Diese "Arbeitsmittel" nennen wir **Parameter**:
# - 📝 **Definition**: `def begruesse(name):` – `name` ist ein Parameter (Platzhalter)
# - ⚡ **Aufruf**: `begruesse("Luna")` – `"Luna"` ist das Argument (das echte Arbeitsmittel)
# **Merke:** Parameter = Platzhalter im Rezept, Argument = echtes Arbeitsmittel bei der Ausführung!

# %%
# 🐴 Level 3: Geschichten mit Arbeitsmitteln!
# Definition mit Parameter 'name' (Platzhalter für ein Arbeitsmittel)
def persoenliche_begruessung(name):
    print(f"🌟 Willkommen auf dem Pferdehof, {name}!")
    print(f"✨ Möge deine Zeit mit den Pferden erfolgreich sein, {name}!")
# Aufrufe mit verschiedenen Argumenten (echte Arbeitsmittel)
print("🧙 Die Pferdefreundin begrüßt die neuen Pferdefreunde:\n")
persoenliche_begruessung("Alex")
print()
persoenliche_begruessung("Maria")
print("\n🎉 +150 Huf-Punkte: Du kannst jetzt Geschichten mit Arbeitsmitteln erstellen!")

# %% [markdown]
# ### ⚡ Power-Moves: `return` – Praktische Ergebnisse zurückbekommen
# Stell dir vor, du fragst eine Pferdeexpertin: "Wie viel Futter braucht ein Pferd?"
# Du willst nicht, dass sie das Ergebnis nur **ansagt** (`print`), sondern dass sie es **dir gibt** (`return`), damit du damit weiterarbeiten kannst!
# **Das macht `return`:**
# - 🎁 Gibt ein Ergebnis an die Stelle zurück, wo die Geschichte durchgeführt wurde
# - 🛑 Beendet die Geschichte sofort
# - 💾 Ermöglicht es, das Ergebnis zu speichern und weiterzuverwenden
# **Wann brauchst du `return`?**
# - ✅ Wenn du das Ergebnis speichern willst
# - ✅ Wenn du damit weiterrechnen willst
# - ✅ Wenn du es an eine andere Geschichte übergeben willst
# **Wann reicht `print`?**
# - ✅ Wenn du nur etwas anzeigen willst (wie eine Nachricht)

# %%
# 🐴 Level 4: Geschichten mit praktischen Ergebnissen!
# Diese Geschichte GIBT ein Ergebnis zurück (wie ein Geschenk!)
def addiere(a, b):
    ergebnis = a + b
    return ergebnis  # 🎁 Das Ergebnis wird zurückgegeben
# Das Ergebnis wird in 'summe' gespeichert
print("🧮 Die Futterberechnung für die Pferde wird durchgeführt...")
summe = addiere(10, 5)
print(f"💎 Das praktische Ergebnis: {summe}")
print(f"✨ Wir können damit weiterarbeiten: {summe * 2}")
print(f"🔮 Oder es in neuen Berechnungen nutzen: {summe + 100}")
print("\n🎉 +200 Huf-Punkte: Du beherrschst jetzt return!")

# %% [markdown]
# ### 📚 Meister-Tipps: Wie die Profis arbeiten
# **Die erfahrene Pferdefreundin verrät dir ihre Geheimnisse:**
# **1. 🏷️ Sprechende Namen (Naming Conventions)**
# - ❌ **Schlecht**: `f1()`, `mache_zeug()`, `x()`
# - ✅ **Gut**: `berechne_futter()`, `pflege_pferd()`, `zaehle_hufe()`
# - 📏 **Python-Stil**: Kleinbuchstaben mit Unterstrichen (`snake_case`)
# **2. 🎯 Eine Aufgabe pro Geschichte**
# - Jede Geschichte sollte **eine klare Aufgabe** haben
# - Nicht: `mache_alles()` ❌
# - Besser: `berechne_futter()`, `zeige_futter()`, `pflege_pferd()` ✅
# **3. 📝 Geschichten-Beschreibungen (Docstrings)**
# - Schreibe auf, was deine Geschichte tut!
# - Hilft dir und anderen, den Code zu verstehen
# - Kann mit `help()` angezeigt werden

# %%
# 🐴 Level 5: Professionelle Geschichten-Dokumentation!
def berechne_pferdejahre(menschenjahre):
    """    🐎 Verwandelt Menschenjahre in Pferdejahre.
    
    Eine nützliche Geschichte, die das Alter zwischen Spezies übersetzt!
    
    Parameter:
        menschenjahre (int): Das Alter in Menschenjahren
    
    Returns:
        int: Das Alter in Pferdejahren (x3)
    
    Beispiel:
        >>> berechne_pferdejahre(10)
        30
    """    return menschenjahre * 3
# Teste die Geschichte
alter_mensch = 10
alter_pferd = berechne_pferdejahre(alter_mensch)
print(f"🐎 Ein {alter_mensch}-jähriger Mensch ist wie ein {alter_pferd}-jähriges Pferd!")
# Zeige die Geschichten-Beschreibung
print("\n📖 Geschichten-Beschreibung:")
help(berechne_pferdejahre)
print("\n🎉 +250 Huf-Punkte: Du dokumentierst wie eine Meister:in!")

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Pferde-Probleme!
# **Story:** Eine vergessliche Pferdefreundin hat Fehler in diese Geschichten geschrieben! Kannst du die Probleme finden und beheben?

# %% [markdown]
# ### 🐛 Problem #1: Die stumme Geschichte

# %%
# ⚠️ Warum passiert hier nichts?
def sag_hallo():
    print("Hallo auf dem Pferdehof!")
# 🤔 Frage: Die Geschichte ist definiert, aber nichts passiert. Warum?
# Tipp: Wurde die Geschichte auch AUSGEFÜHRT (aufgerufen)?

# %% [markdown]
# ### 🐛 Problem #2: Das fehlende Arbeitsmittel

# %%
# ⚠️ Was ist hier falsch bei dieser Geschichte?
def vorstellung(name, alter):
    print(f"Ich bin {name} und bin {alter} Jahre alt.")
vorstellung("Leo")
# 🤔 Frage: Was ist das Problem?
# Tipp: Wie viele Parameter hat die Funktion? Wie viele Argumente gibst du?

# %% [markdown]
# ### 🐛 Problem #3: Das verschwundene Ergebnis (Schwierig!)

# %%
# ⚠️ Warum können wir hier nicht auf 'summe' zugreifen?
def berechne_summe():
    summe2 = 50 + 10
    return summe2
berechne_summe()  # Geschichte wird ausgeführt...
print(summe2)
# 🤔 Frage: Was ist das Problem?
# Tipp: Was passiert mit dem return-Wert? Wird er gespeichert?
# Konzept: "Scope" - Variablen in Geschichten sind nur dort sichtbar!

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise deine Pferde-Geschichten-Kraft!
# **Story:** Das vergessene Pferde-Tagebuch wartet auf liebevolle Geschichten! Aber zuerst musst du drei Prüfungen bestehen, um eine echte Pferdefreund:in zu sein...

# %% [markdown]
# ### 🎯 Mission 1: Die Pferde-Fütterungs-Geschichte
# **Schwierigkeit:** ⭐⭐☆☆☆
# **Belohnung:** 200 Huf-Punkte + Futtermeister-Abzeichen
# **Story:** Du bist verantwortlich für die Pferdefütterung! Aber die Pferde fressen nur, wenn du ihnen die richtige Fütterungs-Geschichte erzählst.
# **Deine Aufgaben:**
# 1. **Definiere** eine Geschichte namens `pferde_fuettern`
# 2. In dieser Geschichte soll die Fütterung drei Schritte durchführen (jeweils mit `print`):
#    - "🐎 Pferde zur Futterstelle rufen!"   - "🌾 Futter in die Krippen füllen!"   - "💧 Wasser auffüllen!"3. **Rufe** die Geschichte auf, damit die Fütterung stattfindet
# 4. **Bonus:** Was passiert, wenn du sie dreimal hintereinander aufrufst?
# **Extra-Challenge:** Füge einen Parameter `anzahl_pferde` hinzu!

# %%
# 🎯 Dein Code für Mission 1
# Lass die Pferde fressen!

# %% [markdown]
# ### 🎯 Mission 2: Die Reiter:innen-Begrüßungs-Geschichte
# **Schwierigkeit:** ⭐⭐⭐☆☆
# **Belohnung:** 300 Huf-Punkte + Reitlehrer:innen-Siegel
# **Story:** Du organisierst eine Reitschule! Jedes Mal, wenn eine:r Reiter:in kommt, soll sie:er persönlich begrüßt werden.
# **Deine Aufgaben:**
# 1. **Definiere** eine Geschichte `begruesse_reiter(reiter_name)`
# 2. Sie soll den Namen als Parameter bekommen
# 3. Gib einen herzlichen Begrüßungs-Spruch aus, z.B.:
#    - `f"🏇 Seid gegrüßt, {reiter_name}!"`
#    - `f"🐎 Möge euer Ritt sicher und euer Pferd gesund sein!"`
# 4. **Rufe** die Geschichte für zwei verschiedene Reiter:innen auf (z.B. "Anna" und "Tom")
# **Bonus-Challenge:** Füge einen zweiten Parameter `level` hinzu (z.B. "Anfänger", "Fortgeschritten") und passe die Begrüßung an!

# %%
# 🎯 Dein Code für Mission 2
# Begrüße die Reiter:innen!

# %% [markdown]
# ### 🎯 Mission 3: Die Heu-Boxen-Geschichte
# **Schwierigkeit:** ⭐⭐⭐⭐☆
# **Belohnung:** 400 Huf-Punkte + Handwerker:innen-Meister-Titel
# **Story:** Du bist ein:e Handwerker:in auf dem Pferdehof, der Heu-Boxen für die Pferde herstellt! Pferdebesitzer:innen bestellen Boxen mit unterschiedlichen Maßen. Du brauchst eine Geschichte, die dir schnell das Volumen berechnet.
# **Deine Aufgaben:**
# 1. **Definiere** eine Geschichte `berechne_box_volumen(laenge, breite, hoehe)`
# 2. Berechne das Volumen: `laenge * breite * hoehe`
# 3. **Nutze `return`**, um das Ergebnis zurückzugeben (wichtig!)
# 4. **Rufe** die Geschichte mit den Maßen `10, 20, 5` auf
# 5. Speichere das Ergebnis in einer Variable `heu_volumen`
# 6. Gib einen schönen Satz aus:
#    - `f"🌾 In diese Box passt Heu im Volumen von {heu_volumen} Kubikzentimetern!"`
# **Bonus-Challenge:**
# - Erstelle eine zweite Geschichte `berechne_heu_menge(volumen)`, die berechnet, wie viele Heuballen reinpassen (1 Ballen = 2 cm³)
# - Kombiniere beide Geschichten!

# %%
# 🎯 Dein Code für Mission 3
# Baue die Heu-Boxen-Werkstatt!

# %% [markdown]
# ### 🤔 Weisheiten der erfahrenen Pferdefreundin (Reflexion)
# Beantworte diese Fragen, um dein Wissen zu vertiefen:
# 1. **Die Macht der Wiederverwendung:** Warum sind Geschichten nützlich, auch wenn du den Code nur einmal brauchst? (Tipp: Denk an Lesbarkeit, Organisation, Wartung)
# 2. **Print vs. Return:** Was ist der Unterschied zwischen `print` und `return` in einer Geschichte? Wann nutzt du was?
# 3. **Der magische Scope:** Was passiert, wenn eine Variable innerhalb einer Geschichte den gleichen Namen hat wie eine Variable außerhalb? Welche wird verwendet?
# 4. **Geschichten-Kombination:** Wie können Geschichten sich gegenseitig aufrufen? Nenne ein praktisches Beispiel aus dem Pferdehof!
# **Diskutiere mit deinen Pferdefreund:innen!**

# %% [markdown]
# ### 🎤 Pferde-Geschichten-Treffen (Review)
# **Show & Tell Zeit!**
# - Zeigt eure schönsten Pferde-Geschichten-Programme!
# - Welche kreativen Anwendungen habt ihr gefunden?
# - Welche Geschichten-Operation war euer Favorit und warum?
# - Gab es Überraschungen oder "Aha!"-Momente?
# **Teilt eure Erfolge und lernt voneinander!**

# %% [markdown]
# ### 📖 Pferde-Tagebuch-Lexikon (Schlüsselwörter)
# Merke dir diese nützlichen Begriffe:
# - **Funktion** 🪄: Ein benannter, wiederverwendbarer Code-Block (wie eine Pferde-Geschichte)
# - **`def`** 📝: Das Stichwort zum Definieren einer Geschichte
# - **Aufruf (Call)** ⚡: Das Ausführen/Durchführen einer Geschichte
# - **Parameter** 🧪: Platzhalter für Werte im Geschichtenkopf (Arbeitsmittel-Rezept)
# - **Argument** 💎: Der echte Wert beim Geschichtenaufruf (echtes Arbeitsmittel)
# - **`return`** 🎁: Gibt ein Ergebnis zurück (damit du es weiterverwenden kannst)
# - **Einrückung** 📏: 4 Leerzeichen nach rechts (zeigt, was zur Geschichte gehört)
# - **snake_case** 🐍: Namenskonvention für Geschichten (klein, mit `_`)
# - **Docstring** 📚: Beschreibung der Geschichte (in `"""..."""`)
# - **Scope** 🔒: Sichtbarkeitsbereich von Variablen

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
# Nach dieser Pferde-Geschichten-Quest solltest du:
# - ✅ Eigene Geschichten mit `def` definieren und aufrufen können
# - ✅ Parameter nutzen, um Geschichten flexibel zu machen
# - ✅ Mit `return` Werte zurückgeben und weiterverwenden können
# - ✅ Den Unterschied zwischen Definition und Aufruf verstehen
# - ✅ Code durch Geschichten strukturieren und organisieren können
# - ✅ Professionelle Geschichten-Namen und Docstrings schreiben können
# **Selbstcheck:** Kannst du alle Haupt-Missionen lösen? Dann bist du bereit für den Meisterprüfungs-Kampf!

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Pferde-Geschichten-Reise
# **Glückwunsch, Pferdefreund:in!**
# Du hast heute das **Pferde-Tagebuch-System** gemeistert – eine der schönsten Fähigkeiten für die Pferdefreundschaft!
# Pferde-Geschichten sind überall:
# - 🐎 Pferde-Erinnerungs-Geschichten
# - 📱 Pferde-App-Funktionen
# - 🤖 Pferde-Trainingsgeschichten
# - 📊 Pflege-Analyse
# - 🌐 Pferdehof-Webseiten
# Mit Pferde-Geschichten kannst du Erinnerungen organisieren, Freundschaften verwalten und liebevoll verarbeiten. Du bist jetzt bereit für größere Pferdeabenteuer!
# **Nächster Schritt:** Die Pferde-Hausaufgaben warten auf dich...

# %% [markdown]
# ## 🐉 Vergessene Pferde-Tagebuch-Kampf: Hausaufgaben-Quests
# **ACHTUNG:** Das vergessene Pferde-Tagebuch erwacht! Nur die besten Pferdefreund:innen können diese Herausforderungen meistern.
# **Belohnung für alle 3 Quests:**
# - 🏆 Meister:in der Pferde-Geschichten (Titel)
# - 💎 1500 Huf-Punkte
# - 🎖️ Bereitschaft für Woche 6
# **Tipp:** Nutze alles, was du heute gelernt hast. Kombiniere verschiedene Pferde-Geschichten-Operationen!

# %% [markdown]
# ### 🐴 Meisterprüfung 1: Die Pferde-Sprach-Übersetzerin
# **Schwierigkeit:** ⭐⭐⭐⭐☆
# **Belohnung:** 500 Huf-Punkte + Pferde-Kommunikator-Siegel
# **Story:** Du hast gelernt, mit Pferden zu kommunizieren! Ihre Sprache ist besonders: Sie sagen alle Wörter **rückwärts** und hängen am Ende **"wieh"** an.
# **Beispiel:** "Hallo" → "ollaHwieh"**Deine Aufgaben:**
# 1. Schreibe eine Geschichte `uebersetze_fuer_pferd(wort)`
# 2. Die Geschichte soll:
#    - Das Wort umdrehen (Tipp: `wort[::-1]` dreht einen String um)
#    - "wieh" anhängen
#    - Das Ergebnis mit `return` zurückgeben
# 3. Frage den Benutzer nach einem Wort (`input()`)
# 4. Rufe deine Geschichte auf
# 5. Gib die Übersetzung schön formatiert aus
# **Bonus-Challenge:**
# - Erstelle auch eine Rückübersetzungs-Geschichte `uebersetze_von_pferd(pferd_wort)`
# - Teste beide Geschichten miteinander!
# **Extra-Bonus:** Lass den Benutzer mehrere Wörter übersetzen (Schleife!)

# %%
# 🐴 Dein Code für Meisterprüfung 1
# Kommuniziere mit den Pferden!

# %% [markdown]
# ### 🏇 Meisterprüfung 2: Die Pferde-Name-Generatorin
# **Schwierigkeit:** ⭐⭐⭐☆☆
# **Belohnung:** 400 Huf-Punkte + Pferde-Namens-Lizenz
# **Story:** Der Pferdehof braucht mehr Pferde mit kreativen Namen! Deine Aufgabe: Erschaffe den Generator!
# **Deine Aufgaben:**
# 1. Schreibe eine Geschichte `erstelle_pferd_name(vorname, eigenschaft)`
# 2. Die Geschichte soll einen coolen Namen generieren, z.B.:
#    - `f"Der/Die schnelle {vorname} - {eigenschaft}!"`
#    - Oder: `f"{vorname} - Meister/in der {eigenschaft}en Kraft!"`
# 3. Nutze `return`, um den Namen zurückzugeben
# 4. Frage den Benutzer nach:
#    - Vorname
#    - Eigenschaft (z.B. "schnell", "stark", "elegant")
# 5. Rufe die Geschichte auf und präsentiere den epischen Namen!
# **Bonus-Challenge:**
# - Füge einen dritten Parameter hinzu: `farbe` (z.B. "braun", "schwarz", "falb")
# - Integriere die Farbe in den Namen
# - Erstelle eine zweite Geschichte `erstelle_pferd_motto(name, eigenschaft)`, die ein cooles Motto generiert
# **Extra-Bonus:** Speichere mehrere Pferde in einer Liste!

# %%
# 🏇 Dein Code für Meisterprüfung 2
# Erschaffe Pferde-Namen!

# %% [markdown]
# ### 🗺️ Meisterprüfung 3: Das Pferdehof-Abenteuer-System
# **Schwierigkeit:** ⭐⭐⭐⭐⭐
# **Belohnung:** 600 Huf-Punkte + Pferdehof-Manager-Zertifikat
# **Story:** Du erschaffst ein Pferdehof-Abenteuer! An einer Weggabelung muss der Besucher entscheiden, wohin er geht. Deine Geschichte bestimmt, was passiert.
# **Deine Aufgaben:**
# 1. Schreibe eine Geschichte `waehle_pferdehof_weg(entscheidung)`
# 2. Die Geschichte soll auf die Entscheidung reagieren (nutze `if-elif-else`):
#    - **"stall"** → `return "🐎 Du gehst in den Stall und streichelst ein freundliches Pferd!"`
#    - **"reitplatz"** → `return "🏇 Du betrittst den Reitplatz und siehst Reiter:innen beim Training!"`
#    - **"weide"** → `return "🌾 Du gehst zur Weide und beobachtest Pferde beim Grasen!"`
#    - **Sonst** → `return "🐿️ Du bist unentschlossen. Ein Eichhörnchen klettert auf deine Schulter!"`
# 3. Frage den Benutzer nach seiner Entscheidung
# 4. Rufe die Geschichte auf und zeige das Ergebnis
# **Bonus-Challenge:**
# - Erstelle mehrere Geschichten für verschiedene Orte
# - Lass die Geschichten sich gegenseitig aufrufen (z.B. `stall_szene()` ruft `reitplatz_szene()` auf)
# - Baue ein komplettes Mini-Abenteuer mit 3-5 Entscheidungen!
# **Extra-Bonus:**
# - Füge ein Energie-System hinzu (Parameter `energie`)
# - Manche Entscheidungen kosten Energie, andere geben Energie zurück
# - Gib die verbleibende Energie zurück

# %%
# 🗺️ Dein Code für Meisterprüfung 3
# Erschaffe dein Pferdehof-Abenteuer!
print("\n🎉 Wenn du alle 3 Meisterprüfungen geschafft hast, bist du eine:e wahre:r PFERDEFREUND:IN! 🏆")
