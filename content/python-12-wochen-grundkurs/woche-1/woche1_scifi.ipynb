# %% [markdown]
# # 🚀 Woche 1 – Einführung und erstes Programm: Willkommen auf Nebula-7
#
# **Cyber Credits zu verdienen:** 1000 Punkte
# **Herausforderung:** Der Kommunikations-Ausfall der stummen Systeme

# %% [markdown]
# ## 🌌 Die Geschichte beginnt: Dein erster Tag auf der Raumstation
#
# Willkommen an Bord der Raumstation **"Nebula-7"**! Du beginnst heute deine Arbeit als Junior-Programmierer und bist verantwortlich für die Wartung der Bordcomputer-Systeme. Doch bevor du komplexe Systeme steuern kannst, musst du die **Grundlagen der Programmierung** beherrschen.
#
# In dieser ersten Woche lernst du die beiden fundamentalen Befehle: **Variablen** (um Daten zu speichern) und **print()** (um Informationen auszugeben). Diese einfachen Kommandos sind die Basis für alle Raumfahrt-Systeme!
#
# **Deine Mission:**
# - Lerne, wie du Text mit `print()` ausgibst
# - Verstehe, wie Variablen Daten speichern
# - Kombiniere Texte und Variablen
# - Erstelle deine ersten System-Berichte

# %% [markdown]
# ## 🎯 Was ist Programmieren?
#
# **Programmieren** ist wie das Schreiben von Befehlen für Raumschiff-Computer! Du gibst dem System präzise Anweisungen, und es führt sie aus. Statt mit Knöpfen und Schaltern arbeitest du mit **Code** – geschriebenen Befehlen, die der Computer versteht.
#
# Python ist eine **Programmiersprache** – eine Sprache, die sowohl Menschen als auch Computer verstehen können. Sie wird in der Raumfahrt, Wissenschaft und vielen anderen Bereichen eingesetzt!
#
# **Warum ist Programmieren so mächtig?**
# - 🚀 **Automatisierung:** Steuere komplexe Systeme mit einfachen Befehlen
# - 🤖 **Effizienz:** Lass Computer Millionen Berechnungen pro Sekunde durchführen
# - 🌍 **Kontrolle:** Überwache und steuere Raumstationen, Satelliten, Sonden
# - 💡 **Innovation:** Entwickle neue Technologien und Lösungen
#
# **Fun Fact:** Die Apollo-11-Mission zum Mond wurde mit einem Computer gesteuert, der weniger Rechenleistung hatte als ein modernes Smartphone – aber die Programmierung war perfekt!

# %% [markdown]
# ### 🤖 Tutorial: Deine ersten Schritte
#
# Die Missionsleiterin ARIA erklärt dir die Grundlagen:
#
# **"Der erste Befehl, den jeder Programmierer lernt, ist `print()`:"**
#
# ```python
# # Mit print() kannst du Text ausgeben
# print("System online")
#
# # Variablen speichern Daten
# schiff_name = "Nebula-7"
# crew_anzahl = 42
#
# # Du kannst Variablen ausgeben
# print(schiff_name)
# print(crew_anzahl)
#
# # Oder Texte kombinieren (mit +)
# print("Raumstation: " + schiff_name)
# print("Crew: " + str(crew_anzahl))
# ```
#
# **Wichtige Regeln:**
# - Text steht immer in Anführungszeichen: `"Text"` oder `'Text'`
# - Variablennamen ohne Anführungszeichen: `schiff_name`, `crew_anzahl`
# - Zahlen in Text umwandeln mit `str()`: `str(42)`
# - Kommentare beginnen mit `#` – der Computer ignoriert sie

# %%
# 🌟 Level 1: Dein erster Befehl

# Der klassische erste Befehl jedes Programmierers
print("System initialisiert")
print("Willkommen auf Nebula-7!")

# Du kannst auch mehrere Zeilen ausgeben
print("Dies ist dein erstes Programm.")
print("Du bist jetzt ein Programmierer!")

print()
print("🎉 +100 Cyber Credits: Erstes Kommando erfolgreich!")

# %% [markdown]
# ### 🎯 Power-Move: print() verstehen
#
# Der `print()`-Befehl ist dein wichtigstes Werkzeug:
# - Er gibt Text auf dem Terminal aus
# - Text muss in Anführungszeichen stehen: `"` oder `'`
# - Jeder `print()` macht automatisch eine neue Zeile
# - Du kannst auch leere Zeilen machen: `print()`

# %%
# 📦 Level 2: Variablen - Deine Daten-Speicher

# Variablen speichern Daten
kommandant = "Captain Nova"
rang = "Commander"
dienst_jahre = 15

# Gib die Variablen aus
print("Kommandant:")
print(kommandant)
print("Rang:")
print(rang)
print("Dienstjahre:")
print(dienst_jahre)

print()
print("🎉 +150 Cyber Credits: Variablen gemeistert!")

# %% [markdown]
# ### 📦 Skill-Erklärung: Variablen
#
# **Variablen** sind wie Speicher-Register, die Daten aufbewahren:
#
# - **Name:** Beschreibt, was gespeichert ist (z.B. `schiff_name`, `energie_level`)
# - **Wert:** Die gespeicherten Daten (z.B. `"Nebula-7"`, `100`)
# - **Zuweisung:** Mit `=` speicherst du einen Wert: `name = "ARIA"`
#
# **Wichtig:** Variablennamen sollten aussagekräftig sein und keine Leerzeichen enthalten!

# %%
# ✨ Level 3: Texte kombinieren

# Speichere Daten
schiff = "USS Discovery"
typ = "Forschungsschiff"
crew = 136

# Kombiniere Text mit + (String-Verkettung)
print("Schiff: " + schiff)
print("Typ: " + typ)

# Zahlen müssen mit str() in Text umgewandelt werden
print("Crew: " + str(crew) + " Personen")

# Längere Kombinationen
print(schiff + " ist ein " + typ + " mit " + str(crew) + " Crew-Mitgliedern.")

print()
print("🎉 +200 Cyber Credits: Text-Kombination erlernt!")

# %% [markdown]
# ### 🔗 Power-Move: String-Verkettung
#
# Mit dem `+` Operator kannst du Texte (Strings) verbinden:
#
# ```python
# "System " + "online"  # Ergibt: "System online"
# ```
#
# **Wichtig:** Zahlen müssen erst mit `str()` in Text umgewandelt werden:
#
# ```python
# "Energie: " + str(100)  # Funktioniert!
# "Energie: " + 100       # Fehler!
# ```

# %%
# 🎭 Level 4: Variablen ändern

# Starte mit Anfangswerten
energie = 100
print("Energie-Level: " + str(energie) + "%")

# Energie wird verbraucht
energie = 75
print("Nach Manöver: " + str(energie) + "%")

# Energie wird aufgeladen
energie = 95
print("Nach Aufladung: " + str(energie) + "%")

# Variablen können sich ändern!
status = "Grün"
print("System-Status: " + status)

status = "Gelb"
print("Neuer Status: " + status)

print()
print("🎉 +250 Cyber Credits: Variablen-Änderung verstanden!")

# %% [markdown]
# ### 🔄 Wichtiges Konzept: Variablen überschreiben
#
# Variablen können ihren Wert ändern:
#
# ```python
# treibstoff = 1000
# treibstoff = 800   # Neuer Wert überschreibt den alten
# treibstoff = 600   # Wieder ein neuer Wert
# ```
#
# Der alte Wert ist dann weg – die Variable speichert immer nur den neuesten Wert!

# %%
# 🗺️ Level 5: Dein erster Missions-Bericht

# Erstelle Missions-Daten
mission = "Asteroid-Erkundung"
ziel = "Asteroid Belt Alpha-7"
dauer = 48
status = "In Bearbeitung"

# Erstelle einen Missions-Bericht
print("=== MISSIONS-BERICHT ===")
print()
print("Mission: " + mission)
print("Ziel: " + ziel)
print("Dauer: " + str(dauer) + " Stunden")
print("Status: " + status)
print()
print("Alle Systeme nominal.")
print("Mission wird fortgesetzt...")

print()
print("🎉 +200 Cyber Credits: Erster Bericht erstellt!")

# %% [markdown]
# ### 📖 Power-Move: Berichte erstellen
#
# Mit `print()` und Variablen kannst du professionelle Berichte erstellen:
# - Speichere wichtige Daten in Variablen
# - Kombiniere sie zu lesbaren Sätzen
# - Nutze Trennlinien für Übersichtlichkeit
#
# Das ist die Grundlage für Raumfahrt-Kontrollsysteme!

# %%
# 🎮 Level 6: System-Status erstellen

# Erstelle einen vollständigen System-Status
schiff_name = "Nebula-7"
schiff_klasse = "Forschungsstation"
energie = 87
sauerstoff = 95
treibstoff = 62
schilde = 100

# Zeige den System-Status
print("====== SYSTEM-STATUS ======")
print()
print("Station: " + schiff_name)
print("Klasse: " + schiff_klasse)
print()
print("Energie: " + str(energie) + "%")
print("Sauerstoff: " + str(sauerstoff) + "%")
print("Treibstoff: " + str(treibstoff) + "%")
print("Schilde: " + str(schilde) + "%")
print()
print("===========================")

print()
print("🎉 +300 Cyber Credits: Status-System erstellt!")

# %% [markdown]
# ### 🎯 Skill-Erklärung: Datentypen
#
# Python kennt verschiedene Arten von Daten:
#
# - **String (Text):** `"Nebula-7"`, `'ARIA'` – immer in Anführungszeichen
# - **Integer (Ganzzahl):** `42`, `100`, `-5` – ohne Anführungszeichen
# - **Float (Dezimalzahl):** `3.14`, `99.9` – mit Punkt statt Komma
#
# **Wichtig:** Text und Zahlen können nicht direkt kombiniert werden – nutze `str()` zur Umwandlung!

# %%
# 🏰 Level 7: Crew-Manifest

# Erstelle ein Crew-Manifest
kommandant = "Captain Nova"
pilot = "Lt. Stellar"
ingenieur = "Chief Quantum"
wissenschaftler = "Dr. Cosmos"
crew_gesamt = 42
dienst_schicht = "Alpha"

# Zeige das Manifest
print("====== CREW-MANIFEST ======")
print()
print("Führungscrew:")
print("- Kommandant: " + kommandant)
print("- Pilot: " + pilot)
print("- Chefingenieur: " + ingenieur)
print("- Wissenschaftsoffizier: " + wissenschaftler)
print()
print("Gesamt-Crew: " + str(crew_gesamt) + " Personen")
print("Aktuelle Schicht: " + dienst_schicht)
print()
print("===========================")

print()
print("🎉 +250 Cyber Credits: Crew-System programmiert!")

# %% [markdown]
# ### 🎒 Wichtiges Konzept: Organisation
#
# Gute Programme sind übersichtlich:
# - **Aussagekräftige Namen:** `schiff_name` statt `x`
# - **Leerzeilen:** Trennen verschiedene Abschnitte
# - **Kommentare:** Erklären, was der Code macht
# - **Struktur:** Logischer Aufbau von oben nach unten

# %%
# 🏆 Level 8: Kompletter Stations-Bericht

# Stations-Informationen
station_name = "Nebula-7"
station_sektor = "Gamma Quadrant"
station_orbit = "Jupiter"
crew_anzahl = 42
andock_plaetze = 8

# System-Informationen
energie_level = 87
schild_status = "Aktiv"
lebenserhaltung = "Optimal"

# Missions-Informationen
aktive_missionen = 3
mission1 = "Asteroid-Bergbau"
mission2 = "Planetare Kartierung"
mission3 = "Wissenschaftliche Forschung"

# Zeige den kompletten Bericht
print("="*50)
print("     RAUMSTATION STATUS-BERICHT     ")
print("="*50)
print()
print("STATION:")
print("  Name: " + station_name)
print("  Sektor: " + station_sektor)
print("  Orbit: " + station_orbit)
print("  Crew: " + str(crew_anzahl) + " Personen")
print("  Andock-Plätze: " + str(andock_plaetze))
print()
print("SYSTEME:")
print("  Energie: " + str(energie_level) + "%")
print("  Schilde: " + schild_status)
print("  Lebenserhaltung: " + lebenserhaltung)
print()
print("AKTIVE MISSIONEN (" + str(aktive_missionen) + "):")
print("  1. " + mission1)
print("  2. " + mission2)
print("  3. " + mission3)
print()
print("Alle Systeme nominal. Station bereit für Operationen.")
print()
print("="*50)

print()
print("🎉 +400 Cyber Credits: Meisterwerk erschaffen!")

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein Junior-Programmierer hat versucht, seine ersten Systeme zu programmieren, aber etwas läuft schief! Drei seiner Programme enthalten typische Anfängerfehler. Kannst du sie finden und korrigieren?

# %% [markdown]
# ### 🐛 Bug #1: Die vergessenen Anführungszeichen

# %%
# 🐛 Dieser Code hat einen Fehler!

schiff = Nebula-7
print("Raumstation: " + schiff)

# 🤔 Frage: Was ist das Problem?

# %% [markdown]
# ### 🐛 Bug #2: Die fehlende Umwandlung

# %%
# 🐛 Dieser Code hat einen Fehler!

crew = 42
print("Crew-Anzahl: " + crew)

# 🤔 Frage: Was ist das Problem?

# %% [markdown]
# ### 🐛 Bug #3: Der Tippfehler

# %%
# 🐛 Dieser Code hat einen Fehler!

station_name = "Nebula-7"
print("Station: " + stationname)

# 🤔 Frage: Was ist das Problem?

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen! Die Kommandozentrale hat drei Aufgaben für dich vorbereitet.

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Dein eigenes Raumschiff
#
# **Belohnung:** 300 Cyber Credits + Schiffs-Handbuch
#
# Erstelle ein Profil für dein eigenes Raumschiff!
#
# **Aufgaben:**
# 1. Erstelle Variablen für: Name, Klasse, Typ, Baujahr
# 2. Gib alle Informationen mit `print()` aus
# 3. Nutze String-Verkettung mit `+`
# 4. Vergiss nicht `str()` für Zahlen!
# 5. Mache es übersichtlich mit Leerzeilen
#
# **Bonus-Challenge:** Füge noch mehr Eigenschaften hinzu (Geschwindigkeit, Bewaffnung, Crew-Kapazität)!

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Missions-Plan
#
# **Belohnung:** 400 Cyber Credits + Missions-Logbuch
#
# Erstelle einen detaillierten Missions-Plan!
#
# **Aufgaben:**
# 1. Erstelle Variablen für: Missions-Name, Ziel, Dauer (in Tagen)
# 2. Erstelle Variablen für: Kommandant, Crew-Größe
# 3. Erstelle Variablen für 3 Missions-Ziele
# 4. Gib einen übersichtlichen Missions-Plan aus
# 5. Nutze Trennlinien (z.B. `print("===")`)
# 6. Mache es professionell und strukturiert!
#
# **Bonus-Challenge:** Füge noch Risiko-Level und benötigte Ressourcen hinzu!

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Der Stations-Bericht
#
# **Belohnung:** 500 Cyber Credits + Kommandanten-Abzeichen
#
# Erstelle einen kompletten Stations-Status-Bericht!
#
# **Aufgaben:**
# 1. Erstelle Variablen für: Stations-Name, Sektor, Orbit
# 2. Erstelle Variablen für: Crew-Anzahl, Andock-Plätze, Fracht-Kapazität
# 3. Erstelle Variablen für System-Status: Energie, Schilde, Lebenserhaltung (in %)
# 4. Erstelle Variablen für 3 aktive Missionen
# 5. Gib einen kompletten Bericht aus:
#    - Stations-Informationen
#    - System-Status
#    - Aktive Missionen
#    - Zusammenfassung
# 6. Mache es professionell und übersichtlich!
#
# **Bonus-Challenge:** Füge noch Warnungen hinzu, wenn Systeme unter 50% sind!

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten der Missionsleiterin (Reflexion)
#
# Bevor du weiterziehst, denke über diese Fragen nach:
#
# 1. **Warum sind Variablen so wichtig?** Was wäre der Nachteil, wenn du immer nur feste Werte verwenden würdest?
#
# 2. **Wann brauchst du `str()`?** Kannst du erklären, warum man Zahlen in Text umwandeln muss?
#
# 3. **Was macht ein Programm übersichtlich?** Welche Tricks hast du gelernt, um deinen Code lesbarer zu machen?
#
# 4. **Wo könntest du `print()` und Variablen in der Raumfahrt nutzen?** Fallen dir Beispiele ein?
#
# Diskutiere deine Gedanken mit anderen Crew-Mitgliedern oder der Missionsleiterin!

# %% [markdown]
# ### 🎤 Helden-Präsentation (Review)
#
# Zeit, deine Kreationen zu präsentieren! Wähle eine deiner Lösungen und stelle sie vor:
#
# **Zeige und erkläre:**
# - Welche Variablen hast du erstellt und warum?
# - Wie hast du Text und Variablen kombiniert?
# - Was war am schwierigsten?
# - Was würdest du beim nächsten Mal anders machen?
#
# **Diskussionspunkte:**
# - Wie könnte man das Programm erweitern?
# - Welche anderen Informationen könnte man speichern?
# - Wie würde man das in echten Raumfahrt-Systemen umsetzen?
# - Was sind die Grenzen von `print()` und Variablen?

# %% [markdown]
# ### 📖 Tech-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **print()** 📢: Gibt Text auf dem Terminal aus
# - **Variable** 📦: Speichert einen Wert unter einem Namen
# - **String** 📝: Text in Anführungszeichen (`"Nebula-7"`)
# - **Integer** 🔢: Ganzzahl ohne Anführungszeichen (`42`)
# - **str()** 🔄: Wandelt eine Zahl in Text um
# - **Zuweisung** ➡️: Speichert einen Wert in einer Variable (`name = "ARIA"`)
# - **String-Verkettung** ➕: Verbindet Texte mit `+`
# - **Kommentar** 💭: Notiz im Code, beginnt mit `#`
# - **Anführungszeichen** " ": Markieren Text (`"` oder `'`)
# - **Code** 💻: Geschriebene Befehle für den Computer
# - **Programm** 🎮: Sammlung von Code-Befehlen
# - **Python** 🐍: Die Programmiersprache, die wir lernen

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ✅ Ich kann Text mit `print()` ausgeben
# - ✅ Ich kann Variablen erstellen und Werte speichern
# - ✅ Ich kann Texte mit `+` kombinieren
# - ✅ Ich kann Zahlen mit `str()` in Text umwandeln
# - ✅ Ich verstehe den Unterschied zwischen String und Integer
# - ✅ Ich kann übersichtliche Programme schreiben
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die Boss-Quests!

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Mission beginnt
#
# **Fantastisch!** Du hast die ersten Schritte in der Welt der Programmierung gemeistert!
#
# **Das hast du gelernt:**
# - `print()` gibt Text auf dem Terminal aus
# - Variablen speichern Daten unter einem Namen
# - Mit `+` kannst du Texte kombinieren
# - `str()` wandelt Zahlen in Text um
# - Kommentare mit `#` helfen, Code zu erklären
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🚀 **Raumfahrt:** Kontrollsysteme, Telemetrie, Missions-Berichte
# - 🛰️ **Satelliten:** Datenübertragung, Status-Updates, Kommandos
# - 🤖 **Robotik:** Sensordaten, Steuerungsbefehle, Diagnose
# - 🔬 **Wissenschaft:** Messdaten, Experimente, Analysen
# - 💻 **Software:** Benutzeroberflächen, Logs, Debugging
#
# **Als Nächstes:** In Woche 2 lernst du **Benutzereingaben** – wie dein Programm mit Menschen interagiert!

# %% [markdown]
# ## 🐉 Boss-Kampf: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Quests sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast, und erfordern kreatives Denken.
#
# **Belohnungen:** Insgesamt 1500 Cyber Credits + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Das komplette Schiffs-Profil
#
# **Belohnung:** 500 Cyber Credits + Kapitäns-Logbuch
#
# Erstelle ein umfassendes Raumschiff-Profil wie in einer echten Datenbank!
#
# **Aufgaben:**
# 1. Erstelle mindestens 12 verschiedene Variablen:
#    - Name, Registrierung, Klasse, Typ
#    - Baujahr, Werft, Heimathafen
#    - Länge, Masse, Crew-Kapazität
#    - Maximale Geschwindigkeit (Warp), Reichweite
# 2. Erstelle Variablen für Systeme (Energie, Schilde, Waffen, Sensoren)
# 3. Erstelle Variablen für Kommandant und Führungscrew
# 4. Gib alles in einem schön formatierten Profil aus
# 5. Nutze Trennlinien und Überschriften
# 6. Füge eine kurze Missions-Geschichte hinzu (3-5 Sätze)
#
# **Bonus-Challenge:** Erstelle Profile für zwei verschiedene Schiffe und vergleiche sie!

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Der Wochen-Missions-Plan
#
# **Belohnung:** 600 Cyber Credits + Admirals-Stern
#
# Erstelle einen kompletten Wochen-Missions-Plan für die Raumstation!
#
# **Aufgaben:**
# 1. Für jeden Tag (Mo-So) erstelle Variablen:
#    - Datum, Sternzeit
#    - Haupt-Mission, Sekundär-Missionen
#    - Verantwortlicher Offizier
# 2. Erstelle Variablen für Ressourcen:
#    - Täglicher Energie-Verbrauch
#    - Täglicher Treibstoff-Verbrauch
# 3. Erstelle Variablen für besondere Ereignisse:
#    - Wartungsarbeiten, Crew-Wechsel, Versorgungslieferungen
# 4. Gib einen übersichtlichen Wochenplan aus
# 5. Zeige Zusammenfassungen (Gesamt-Verbrauch, etc.)
# 6. Nutze verschiedene Formatierungen für jeden Tag
#
# **Bonus-Challenge:** Füge Warnungen hinzu, wenn Ressourcen kritisch werden!

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Das Erste-Kontakt-Protokoll
#
# **Belohnung:** 400 Cyber Credits + Diplomatisches Abzeichen
#
# Erstelle ein Protokoll für den ersten Kontakt mit einer außerirdischen Spezies!
#
# **Aufgaben:**
# 1. Erstelle Variablen für die Begegnung:
#    - Datum, Sternzeit, Koordinaten
#    - Entdeckendes Schiff, Kommandant
# 2. Erstelle Variablen für die Spezies:
#    - Name, Heimatplanet, Technologie-Level
#    - Aussehen, Kommunikationsmethode
# 3. Erstelle Variablen für den Kontakt:
#    - Erste Nachricht (übersetzt)
#    - Reaktion, Status (friedlich/neutral/feindlich)
# 4. Gib ein komplettes Protokoll aus:
#    - Begegnungs-Details
#    - Spezies-Informationen
#    - Kontakt-Verlauf
#    - Empfehlungen für weitere Schritte
# 5. Mache es offiziell und detailliert!
#
# **Bonus-Challenge:** Füge noch kulturelle Besonderheiten und Handelsangebote hinzu!

# %%
# 🐉 Deine Lösung hier:

print()
print("🎉 +400 Cyber Credits: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Kommunikations-Ausfall behoben!")
print("⭐ Titel erhalten: Meister der System-Kommunikation")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 1 gemeistert!")
print("📚 Nächste Woche: Benutzereingaben – Interaktive Systeme erstellen!")
