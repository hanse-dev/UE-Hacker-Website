# %% [markdown]
# # ⭐ Missions – 🐴 Week 9 – JSON Files and I/O: The Stable Archives
#
# The time has come to prove your knowledge in real challenges!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: The Horse Logger
#
# **Reward:** 300 Hoof Points + Stable Book
#
# Create your first horse logging system!
#
# **Step 1 – Write a log file:**
# Open a file (e.g. `stable_log.txt`) with `with open("stable_log.txt", "w") as f` and write at least 3 lines (e.g. horse status, feeding times) and use `f.write("...\n")` for each line; print a confirmation
#
# **Step 2 – Add timestamps:**
# Import `datetime` and add date and time to each entry; write more entries with mode `"a"`; print an example entry
#
# **Step 3 – Use log levels:**
# Define entries with levels INFO, WARN, ERROR (e.g. `[INFO] Luna fed`); write 2–3 entries; read the file with `open(..., "r")` and print the content
#
# **Step 4 – Filter function:**
# Write `filter_level(filename, level)` that returns only lines with that level; call it for one level and print the lines
#
# **Bonus:** Simple rotation (new file when too large).

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: The JSON Converter
#
# **Reward:** 400 Hoof Points + Data Chip
#
# Create a JSON conversion system!
#
# 1. **Horse data as a dictionary** (e.g. name, breed, age, owner); print it.
# 2. **JSON export:** Save with `json.dump(..., indent=2)` to `horse.json`; print confirmation.
# 3. **JSON import:** Load with `json.load()`, check e.g. `data["name"]`; print loaded data.
# 4. **Short statistics** (count, average age etc.) from the loaded data.
#
# **Bonus:** Simple validation (check expected keys).

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: The CSV Database
#
# **Reward:** 500 Hoof Points + Database Certificate
#
# Create a complete CSV management system!
#
# 1. **CSV export:** List of horse dictionaries (name, breed, age) with `csv.DictWriter` into `horses.csv` (`newline=""`); print confirmation.
# 2. **CSV import:** Read with `csv.DictReader`, collect rows in list; print count and first row.
# 3. **Search function** — a function returning rows with this breed; call it and print results.
# 4. **Short report:** Statistics (average age, count per breed) from the read data.
#
# **Bonus:** Check if expected columns are present.

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### 🎯 Learning goals – Have you achieved them?
#
# Check yourself whether you have mastered these skills:
#
# - ☐ Read and write files with open()
# - ☐ Import and export JSON data
# - ☐ Process CSV files
# - ☐ Handle errors when accessing files
# - ☐ Validate and transform data
# - ☐ Create complex data pipelines
