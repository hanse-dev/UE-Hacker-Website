# %% [markdown]
# # 🤔 Reflexion & Zusammenfassung – 🚀 Woche 4 – Schleifen (for, while): Der Zyklus der Zeit
# ### 🤔 Weisheiten des Zeit-Meisters (Reflexion)
#
# Bevor du weiterreist, denke über diese Fragen nach:

# %% [markdown]
# ✏️ *Deine Antwort:*

# %% [markdown]
# 1. **Wann würdest du for statt while verwenden (und umgekehrt)?**

# %% [markdown]
# ✏️ *Deine Antwort:*

# %% [markdown]
# 2. **Warum ist range(ende) exklusiv für das Ende?**

# %% [markdown]
# ✏️ *Deine Antwort:*

# %% [markdown]
# 3. **Wie kannst du Endlosschleifen vermeiden?**
#
# Diskutiere deine Gedanken mit anderen Kommandanten!

# %% [markdown]
# ✏️ *Deine Antwort:*

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Exzellent!** Du hast den Zyklus der Zeit gemeistert!
#
# **Das hast du gelernt:**
# - for-Schleifen für kontrollierte Wiederholungen
# - while-Schleifen für flexible Bedingungen
# - range() für präzise Zahlenfolgen
# - break und continue für Schleifen-Kontrolle
# - Verschachtelte Schleifen für komplexe Muster
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🎮 **Spiele:** Game-Loops, Animationen, KI-Züge
# - 📱 **Apps:** Daten-Downloads, Updates, Benachrichtigungen
# - 🌐 **Websites:** Bildergalerien, News-Feeds, Suchen
# - 🤖 **KI-Systeme:** Training, Datenanalyse, Mustererkennung
# - 📊 **Wissenschaft:** Simulationen, Berechnungen, Modelle
#
# **Als Nächstes:** In Woche 5 lernst du **Funktionen**!
