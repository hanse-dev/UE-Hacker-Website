# %% [markdown]
# # 🐴 Woche 12 – Grafische Projekte mit Turtle: Das Turnier-Visualisierungsbrett!
#
# **XP zu verdienen:** 1200 Punkte
# **Boss:** Der Meister der Reitbahn-Visualisierung

# %% [markdown]
# ## 🌟 Die Quest beginnt: Willkommen auf dem Turnierplatz!
#
# Willkommen, junger Reitmeister! Du betrittst das **Turnier-Visualierungsbrett** – eine magische Leinwand, wo Pferde, Hindernisse und Reitbahnen zum Leben erwachen!
#
# In dieser Woche meistert du die Kunst der visuellen Turnierdarstellung:
#
# **Deine Mission:**
# - Turtle für Sport-Visualisierungen nutzen
# - Reitbahnen und Hindernisse zeichnen
# - Pferde-Bewegungen animieren
# - Turnier-Ergebnisse grafisch darstellen
#
# **Leg los!** Dein Weg zum Visualisierungs-Meister beginnt!

# %% [markdown]
# ## 📚 Zauberformel 1: Die Reitbahn gestalten
#
# **Was es ist:** Eine Reitbahn ist ein rechteckiger Bereich mit Markierungen und Linien.
#
# **Warum nützlich:**
# - Strukturierte Grundlage für Animationen
# - Realistische Darstellung von Sportstätten
# - Hilft bei der Positionierung von Elementen
#
# **Wichtig:** Nutze Koordinaten für präzise Platzierung!

# %%
# Beispiel 1: Eine einfache Reitbahn
import turtle

# Erstelle das Turnier-Feld
screen = turtle.Screen()
screen.title("Turnierplatz von Pyralia")
screen.bgcolor("green")

# Erstelle den Bahn-Zeichner
bahn = turtle.Turtle()
bahn.speed(5)
bahn.color("white")
bahn.pensize(3)

# Zeichne die äußere Bahn
bahn.penup()
bahn.goto(-200, -150)
bahn.pendown()
for _ in range(2):
    bahn.forward(400)
    bahn.left(90)
    bahn.forward(300)
    bahn.left(90)

# Mittellinie
bahn.penup()
bahn.goto(0, -150)
bahn.pendown()
bahn.goto(0, 150)

turtle.done()

# %% [markdown]
# ## 📦 Zauberformel 2: Hindernisse und Sprünge
#
# **Was es ist:** Hindernisse sind die Herausforderungen im Turnier.
#
# **Warum nützlich:**
# - Visuelle Darstellung von Aufgaben
# - Dynamische Elemente in der Szene
# - Basis für Kollisionserkennung
#
# **Wichtig:** Nutze Funktionen für wiederholte Hindernisse!

# %%
# Beispiel 1: Hindernisse zeichnen
import turtle

screen = turtle.Screen()
screen.bgcolor("lightgreen")

# Hindernis-Zeichner
hindernis = turtle.Turtle()
hindernis.speed(3)
hindernis.color("brown")

def zeichne_hindernis(x, y, höhe):
    hindernis.penup()
    hindernis.goto(x, y)
    hindernis.pendown()
    hindernis.begin_fill()
    hindernis.fillcolor("saddlebrown")
    for _ in range(2):
        hindernis.forward(40)
        hindernis.left(90)
        hindernis.forward(höhe)
        hindernis.left(90)
    hindernis.end_fill()

# Zeichne mehrere Hindernisse
zeichne_hindernis(-150, -100, 60)
zeichne_hindernis(-50, -100, 80)
zeichne_hindernis(50, -100, 70)
zeichne_hindernis(150, -100, 90)

turtle.done()

# %% [markdown]
# ## ✨ Zauberformel 3: Pferde animieren
#
# **Was es ist:** Pferde als bewegliche Objekte auf der Bahn.
#
# **Warum nützlich:**
# - Lebendige Darstellung des Sports
# - Visualisierung von Bewegungsabläufen
# - Interaktive Elemente möglich
#
# **Wichtig:** Nutze `shape()` für Turtle-Formen!

# %%
# Beispiel 1: Pferd auf der Bahn
import turtle
import time

screen = turtle.Screen()
screen.bgcolor("green")

# Erstelle ein Pferd
pferd = turtle.Turtle()
pferd.shape("turtle")  # Tempär, bis wir eine bessere Form haben
pferd.color("black")
pferd.shapesize(2, 1.5)
pferd.penup()

# Startposition
pferd.goto(-180, 0)

# Pferd bewegen
for _ in range(10):
    pferd.forward(40)
    time.sleep(0.5)

turtle.done()

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein Lehrling hat versucht, ein Turnier zu visualisieren, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1: Hindernis verschwindet

# Warum sieht man das Hindernis nicht?
import turtle

hindernis = turtle.Turtle()
hindernis.color("brown")
hindernis.penup()
hindernis.goto(0, 0)
# Fehlt etwas?

# %%
# 🐛 Bug #2: Pferd bewegt sich nicht

# Warum bleibt das Pferd stehen?
import turtle

pferd = turtle.Turtle()
pferd.shape("turtle")
pferd.penup()
pferd.goto(-100, 0)
pferd.pendown()
pferd.forward(100)
# Was ist falsch?

# %%
# 🐛 Bug #3: Farben werden nicht angezeigt

# Warum ist alles schwarz?
import turtle

screen = turtle.Screen()
screen.bgcolor("white")

bahn = turtle.Turtle()
bahn.speed(0)
bahn.color("red")
bahn.fillcolor("blue")
bahn.begin_fill()
bahn.circle(50)
# Was fehlt am Ende?

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, deine visuellen Fähigkeiten in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Die Dressur-Bahn
#
# **Belohnung:** 350 Huf-Punkte + Dressurpeitsche der Präzision
#
# Erstelle eine perfekte Dressur-Bahn!
#
# **Deine Aufgaben:**
#
# 1. **Reitplatz zeichnen**
#    - Erstelle ein Turtle-Fenster mit grünem Hintergrund (Rasen)
#    - Zeichne ein Rechteck als Umrandung (weiße Linien) – z.B. 20x40 Einheiten skaliert
#    - Nutze `forward()`, `left()`/`right()` oder `goto()` für den Zaun
#
# 2. **Buchstaben und Linien**
#    - Füge mit `turtle.write("A", align="center")` Buchstaben an den Rändern hinzu (mindestens A, B, C, D, E, F)
#    - Zeichne mindestens eine Diagonale oder Mittellinie im Platz
#
# 3. **Farben**
#    - Nutze weiße Linien für den Zaun und grünen Hintergrund (`screen.bgcolor("green")`)
#
# **Beispiel-Code zum Starten:**
# ```python
# import turtle
# screen = turtle.Screen()
# screen.bgcolor("lightgreen")
# t = turtle.Turtle()
# t.color("white")
# t.pensize(2)
# for _ in range(2):
#     t.forward(200)
#     t.left(90)
#     t.forward(400)
#     t.left(90)
# t.penup()
# t.goto(100, -20)
# t.write("A", align="center", font=("Arial", 14, "bold"))
# turtle.done()
# ```
#
# **Bonus-Challenge:** Füge Kreislinien für Zirkelübungen hinzu!
#
# **Erwartete Ausgabe:**
# ```
# Ein Fenster mit Reitplatz-Umrandung, Buchstaben an den Rändern und Linien
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Springparcours
#
# **Belohnung:** 450 Huf-Punkte + Sprungstiefel der Eleganz
#
# Entwirf einen kompletten Springparcours!
#
# **Deine Aufgaben:**
#
# 1. **Funktion für Hindernisse**
#    - Erstelle eine Funktion `zeichne_hindernis(x, y, hoehe, nummer)` die ein Hindernis (z.B. Rechteck oder Stangen) zeichnet
#    - Die Funktion soll die Nummer mit `turtle.write()` daneben schreiben
#
# 2. **Acht Hindernisse platzieren**
#    - Rufe die Funktion 8 Mal mit unterschiedlichen Positionen und Höhen auf
#    - Platziere sie in einer logischen Reihenfolge (z.B. im Kreis oder entlang einer Strecke)
#
# 3. **Wassergraben und Route**
#    - Zeichne mindestens einen blauen Rechteck als Wassergraben (`fillcolor("blue")`, `begin_fill()`, `end_fill()`)
#    - Optional: Gepunktete Linie als ideale Route (kurze Striche in einer Schleife)
#
# **Beispiel-Code zum Starten:**
# ```python
# import turtle
# def zeichne_hindernis(x, y, hoehe, nummer):
#     t.penup()
#     t.goto(x, y)
#     t.pendown()
#     t.forward(40)
#     t.left(90)
#     t.forward(hoehe)
#     t.left(90)
#     t.forward(40)
#     t.left(90)
#     t.forward(hoehe)
#     t.left(90)
#     t.penup()
#     t.goto(x + 20, y - 15)
#     t.write(str(nummer), align="center")
# t = turtle.Turtle()
# # 8 Hindernisse aufrufen...
# turtle.done()
# ```
#
# **Bonus-Challenge:** Füge eine Zeitmessung mit Animation hinzu!
#
# **Erwartete Ausgabe:**
# ```
# Ein Fenster mit 8 Hindernissen, nummeriert, optional Wassergraben und Route
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Das animierte Pferderennen
#
# **Belohnung:** 550 Huf-Punkte + Siegerkranz der Geschwindigkeit
#
# Erstelle ein animiertes Pferderennen!
#
# **Deine Aufgaben:**
#
# 1. **Rennbahn und Pferde**
#    - Zeichne 5 Bahnen (z.B. 5 horizontale Linien oder Streifen)
#    - Erstelle 5 Turtle-Objekte (oder eine Liste) in verschiedenen Farben als „Pferde“
#    - Setze alle am Start (links) ab
#
# 2. **Animation**
#    - In einer Schleife: Bewege jedes Pferd um einen zufälligen Schritt nach rechts (`random.randint(1, 5)` und `forward()`)
#    - Stoppe, wenn ein Pferd die Ziel-Linie (rechts) erreicht
#
# 3. **Ziel-Linie und Sieger**
#    - Zeichne eine vertikale Linie rechts als Ziel
#    - Gib in der Konsole aus, welches Pferd (welche Farbe/Nummer) gewonnen hat
#
# **Beispiel-Code zum Starten:**
# ```python
# import turtle
# import random
# screen = turtle.Screen()
# # Rennbahn zeichnen
# t = turtle.Turtle()
# t.penup()
# t.goto(-300, 0)
# t.pendown()
# t.goto(300, 0)
# # 5 Pferde als Turtles erstellen, Farben setzen, am Start platzieren
# # Schleife: random Schritt, prüfen ob Ziel erreicht
# turtle.done()
# ```
#
# **Bonus-Challenge:** Füge Wetten und Punktestände hinzu!
#
# **Erwartete Ausgabe:**
# ```
# Ein Fenster mit Rennbahn, 5 Pferden, die sich bewegen; Konsole: "Sieger: Pferd 3"
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten des Reitmeisters (Reflexion)
#
# Bevor du weiterziehst, denke über diese Fragen nach:
#
# 1. **Wie hilft Animation beim Verstehen von Bewegungen?**
#
# 2. **Welche Elemente machen eine Sport-Visualisierung realistisch?**
#
# 3. **Wie kannst du komplexe Szenen strukturieren?**
#
# Diskutiere deine Gedanken mit anderen Reitern!

# %% [markdown]
# ### 📖 Zauberspruch-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **Reitbahn** 🏇: Der Bereich für Pferdesport
# - **Hindernis** 🪵: Zu überwindende Barriere
# - **Animation** 🎬: Bewegte Grafiken
# - **Positionierung** 📍: Genaue Platzierung
# - **Farbschema** 🎨: Harmonische Farben
# - **Linienstärke** 📏: Dicke der Linien
# - **Füllung** 🪣: Gefüllte Flächen
# - **Kollision** 💥: Treffer-Erkennung
# - **Timing** ⏱️: Zeitliche Steuerung
# - **Zufall** 🎲: Unvorhersehbare Elemente
# - **Interaktion** 🖱️: Benutzer-Eingaben
# - **Visualisierung** 👁️: Daten sichtbar machen
# - **Simulation** 🎮: Nachbildung der Realität
# - **Grafik-Design** 🎨: Visuelle Gestaltung
# - **Benutzer-Interface** 🖥️: Steuerungselemente

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ✅ Turtle-Modul importieren und einrichten
# - ✅ Formen zeichnen und bewegen
# - ✅ Farben und Füllungen verwenden
# - ✅ Schleifen für Muster nutzen
# - ✅ Interaktive Grafik erstellen
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die Boss-Quests!

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Hervorragend!** Du hast die Kunst der Turnier-Visualisierung gemeistert!
#
# **Das hast du gelernt:**
# - Sportstätten realistisch darstellen
# - Animationen für Bewegungen erstellen
# - Komplexe Szenen strukturieren
# - Interaktive Elemente einbauen
# - Visuelles Storytelling
#
# **In der echten Welt werden diese Techniken verwendet für:**
# - 🏟️ **Sport-Analyse:** Taktik-Visualisierungen
# - 📺 **TV-Übertragungen:** Grafiken und Animationen
# - 🎮 **Sport-Spiele:** Realistische Darstellungen
# - 📊 **Training:** Bewegungsanalysen
# - 🏆 **Events:** Live-Visualisierungen
#
# **Als Nächstes:** Du bist bereit für professionelle Visualisierungen!

# %% [markdown]
# ## 🐉 Boss-Kampf: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Quests sind extrem schwierig! Sie kombinieren alle Turtle-Konzepte.
#
# **Belohnungen:** Insgesamt 1800 XP + epische Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Das komplette Turnier-Zentrum
#
# **Belohnung:** 600 Huf-Punkte + Meister-Reitbahn
#
# Erstelle ein vollständiges Turnier-Zentrum mit allen Disziplinen!
#
# **Deine Aufgaben:**
#
# **1. Erstelle 3 verschiedene Bereiche:**
#    - Dressur-Bahn (20x40m) mit Buchstaben
#    - Springparcours mit 12 Hindernissen
#    - Vielseitigkeits-Bahn mit Gelände-Elementen
#
# **2. Füge Infrastruktur hinzu:**
#    - Tribünen als Rechtecke
#    - Stallgebäude mit Details
#    - Parkplätze für Besucher
#    - Wege und Beschilderung
#
# **3. Implementiere Beschriftungen:**
#    - Bereichsnamen mit turtle.write()
#    - Entfernungsangaben
#    - Schwierigkeitsgrade
#    - Zeitpläne (simuliert)
#
# **4. Füge lebendige Elemente hinzu:**
#    - Bäume und Landschaft
#    - Wasserstellen für Pferde
#    - Dekorative Elemente
#    - Wetter-Effekte (optional)
#
# **5. Interaktive Features:**
#    - Klick auf Bereich zeigt Details
#    - Farbcodes für Schwierigkeit
#    - Legende für Symbole
#
# **Beispiel-Struktur:**
# ```python
# # So könntest du beginnen:
# import turtle
#
# class TurnierZentrum:
#     def __init__(self):
#         self.screen = turtle.Screen()
#         self.setup_fenster()
#
#     def zeichne_dressur_bahn(self):
#         # Dressur-Bahn Code
#         pass
#
#     def zeichne_springparcours(self):
#         # Springparcours Code
#         pass
#
# # Hauptprogramm
# zentrum = TurnierZentrum()
# # ... weiterer Code
# ```
#
# **Bonus-Challenge:** Füge eine Tag/Nacht-Ansicht mit wechselnden Farben hinzu!
#
# **Erwartete Ausgabe:**
# ```
# Ein Fenster mit Dressur-Bahn, Springparcours, Vielseitigkeit, Tribünen, Beschriftungen und optional interaktiven Features
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Die animierte Turnier-Simulation
#
# **Belohnung:** 800 Huf-Punkte + Szepter der Animation
#
# Erstelle eine komplette animierte Simulation eines Springturniers!
#
# **Deine Aufgaben:**
#
# **1. Erstelle eine Pferd-Klasse:**
#    - Attribute: name, geschwindigkeit, sprungkraft
#    - Methoden: springen(), laufen(), anzeigen()
#    - Verschiedene Fähigkeiten pro Pferd
#
# **2. Baue den Parcours:**
#    - 10 Hindernisse mit Höhen
#    - Abstände zwischen Hindernissen
#    - Schwierigkeits-System
#
# **3. Implementiere die Physik:**
#    - Sprungbahn berechnen (Parabel)
#    - Geschwindigkeit beeinflusst Sprung
#    - Fehler bei zu hohen Hindernissen
#
# **4. Animiere den kompletten Ablauf:**
#    - Pferd startet und galoppiert
#    - Springt über jedes Hindernis
#    - Zeigt Fehler oder Erfolg
#    - Zeitmessung und Punktzahl
#
# **5. Füge mehrere Pferde hinzu:**
#    - 3-5 Pferde nacheinander
#    - Jedes hat eigene Strategie
#    - Vergleich der Ergebnisse
#    - Siegerehrung am Ende
#
# **Beispiel-Struktur:**
# ```python
# # So könntest du beginnen:
# import turtle
# import math
# import time
#
# class Pferd:
#     def __init__(self, name, farbe):
#         self.name = name
#         self.farbe = farbe
#         self.turtle = turtle.Turtle()
#         self.turtle.shape("turtle")
#         self.turtle.color(farbe)
#
#     def springe(self, höhe):
#         # Sprung-Animation
#         pass
#
# class TurnierSimulation:
#     def __init__(self):
#         self.pferde = []
#         self.hindernisse = []
#
#     def starte_turnier(self):
#         # Haupt-Simulation
#         pass
#
# # Hauptprogramm
# simulation = TurnierSimulation()
# # ... weiterer Code
# ```
#
# **Bonus-Challenge:** Füge Wind und Wetter als Einflussfaktoren hinzu!
#
# **Erwartete Ausgabe:**
# ```
# Ein Fenster mit Parcours, animierten Pferden, Hindernissen und Siegerehrung
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 3: Das interaktive Trainings-Tool
#
# **Belohnung:** 400 Huf-Punkte + Codex des interaktiven Trainings
#
# Erstelle ein Tool, mit dem man Reitbahnen selbst gestalten kann!
#
# **Deine Aufgaben:**
#
# **1. Erstelle einen Editor-Modus:**
#    - Maus-Klick platziert Hindernisse
#    - Rechts-Klick löscht Hindernisse
#    - Tasten ändern Hindernis-Typ
#    - Drag & Drop für Positionierung
#
# **2. Baue eine Hindernis-Bibliothek:**
#    - Verschiedene Hindernis-Typen
#    - Jeder Typ hat eigene Eigenschaften
#    - Vorschau beim Platzieren
#    - Anpassbare Höhe und Breite
#
# **3. Implementiere Test-Modus:**
#    - Pferd fährt den erstellten Parcours
#    - Zeigt optimale Linie
#    - Berechnet Schwierigkeit
#    - Gibt Tipps zur Verbesserung
#
# **4. Füge Speicher/Laden hinzu:**
#    - Speichere Parcours als Textdatei
#    - Lade vorherige Entwürfe
#    - Exportiere als Bild
#    - Teile mit anderen
#
# **5. Erstelle ein Tutorial:**
#    - Schritt-für-Schritt Anleitung
#    - Interaktive Hilfe
#    - Beispiele und Vorlagen
#    - Tipps von Profis
#
# **Beispiel-Struktur:**
# ```python
# # So könntest du beginnen:
# import turtle
# import json
#
# class BahnEditor:
#     def __init__(self):
#         self.screen = turtle.Screen()
#         self.setup_events()
#         self.hindernisse = []
#         self.modus = "platzieren"
#
#     def setup_events(self):
#         self.screen.onclick(self.platziere_hindernis)
#         self.screen.onkey(self.speichern, "s")
#         self.screen.listen()
#
#     def platziere_hindernis(self, x, y):
#         # Hindernis platzieren
#         pass
#
# # Hauptprogramm
# editor = BahnEditor()
# # ... weiterer Code
# ```
#
# **Bonus-Challenge:** Füge eine KI hinzu, die optimale Parcours vorschlägt!
#
# **Erwartete Ausgabe:**
# ```
# Ein Fenster mit Editor-Modus, Hindernis-Bibliothek, Test-Modus und optional Speicher/Laden
# ```

# %%
# 🐉 Deine Lösung hier:

print()
print("🎉 +400 XP: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Meister der Reitbahn besiegt!")
print("⭐ Titel erhalten: Visualisierungs-Champion")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 12 gemeistert!")
print("📚 Nächste Woche: Deine eigenen Projekte!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen:

# %%
# ✅ Lösung Bug #1: Hindernis verschwindet

# Problem: pendown() fehlt
import turtle

hindernis = turtle.Turtle()
hindernis.color("brown")
hindernis.penup()
hindernis.goto(0, 0)
hindernis.pendown()  # Fehlende Zeile
hindernis.circle(50)
turtle.done()

# %%
# ✅ Lösung Bug #2: Pferd bewegt sich nicht

# Problem: penup() für Bewegung nutzen
import turtle

pferd = turtle.Turtle()
pferd.shape("turtle")
pferd.penup()  # Stift heben für Bewegung
pferd.goto(-100, 0)
pferd.forward(100)  # Jetzt funktioniert es
turtle.done()

# %%
# ✅ Lösung Bug #3: Farben werden nicht angezeigt

# Problem: end_fill() fehlt
import turtle

screen = turtle.Screen()
screen.bgcolor("white")

bahn = turtle.Turtle()
bahn.speed(0)
bahn.color("red")
bahn.fillcolor("blue")
bahn.begin_fill()
bahn.circle(50)
bahn.end_fill()  # Fehlende Zeile hinzugefügt
turtle.done()
