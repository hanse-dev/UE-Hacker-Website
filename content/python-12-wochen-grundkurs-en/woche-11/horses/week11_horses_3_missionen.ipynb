# %% [markdown]
# # ⭐ Missions – 🐴 Week 11 – Advanced OOP: The Magic Evolution!
#
# The time has come to prove your advanced knowledge in real challenges!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: The Horse Hierarchy
#
# **Reward:** 350 Hoof Points + Breeding Certificate
#
# The stud farm needs a clean hierarchy for all horse breeds!
#
# **Step 1 – Create base class Horse:**
# Create `class Horse:` with `__init__(self, name, age, gender)`; assign the attributes and add a method `neigh()` that prints a message
#
# **Step 2 – Create child classes:**
# Create `class RidingHorse(Horse):`, `class Coldblood(Horse):`, `class Pony(Horse):` and use `super().__init__(name, age, gender)` in each constructor *(= special method that runs automatically when an object is created)* and add a special attribute
#
# **Step 3 – Create an object of each class:**
# Create one object each of RidingHorse, Coldblood and Pony and call `neigh()` and the special method for each object
#
# **Bonus:** Add a fourth class that inherits from a child class (e.g. DressageHorse from RidingHorse).

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: The Polymorphic Training
#
# **Reward:** 450 Hoof Points + Training Whip
#
# The riding school needs a system for different training methods!
#
# **Step 1 – Create three training classes:**
# Create `class Dressage:`, `class Jumping:`, `class Western:` each with `__init__(self, name)` and a method `training(self)` and each `training()` outputs a different exercise (e.g. "Practice Piaffe!", "Jump the course!", "Ride the slalom!")
#
# **Step 2 – Polymorphic function:**
# Create a function `train_horse(horse, training)` that calls `training.training()` (or outputs the exercise) and the function should work with all three training types
#
# **Step 3 – Test all trainings:**
# Create one object each of Dressage, Jumping and Western and call the polymorphic function for each training type
#
# **Bonus:** Create a trainer factory function that creates the matching training based on type.

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: The Champion Register
#
# **Reward:** 550 Hoof Points + Winner's Wreath
#
# The tournament office needs a system for champion horses!
#
# **Step 1 – Create class Champion:**
# Create `class Champion:` with `__init__(self, name, breed, points)`; assign the attributes
#
# **Step 2 – Write Magic Methods:**
# `__str__(self)`: Return a readable string, e.g. `"🏆 {name} ({breed}), Points: {points}"` and `__add__(self, other)`: Return the sum of the points of both champions
#
# **Step 3 – Test Magic Methods:**
# Create two Champion objects and use a function, `len(champion)` and `champion1 + champion2`
#
#
# > 💡 **Tip:** You decide how to implement it – there is no single correct way!
# **Bonus:** Add `__eq__(self, other)` and `__lt__(self, other)` for comparisons by points.

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### 🎯 Learning Goals – Have You Achieved Them?
#
# Check for yourself whether you have mastered these skills:
#
# - ☐ Use inheritance for code reuse
# - ☐ Apply polymorphism *(= same method that works differently depending on the class)* for flexible systems
# - ☐ Write Magic Methods
# - ☐ Recognize and use Design Patterns
# - ☐ Distinguish composition vs inheritance
# - ☐ Use super() correctly
#
# If you can check off all points – congratulations! You are ready for the final challenges!
