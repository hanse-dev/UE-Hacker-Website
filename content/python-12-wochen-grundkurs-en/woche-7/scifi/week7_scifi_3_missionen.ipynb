# %% [markdown]
# # ⭐ Missions – 🚀 Week 7 – Modules and Libraries: The Module Banks of the Space Station
#
# The time has come to prove your knowledge in real challenges!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: The Module Importer
#
# **Reward:** 300 Cyber Credits + Data Chip
#
# In the Module Central of Nebula-7 you learn how to load modules and work with aliases.
#
# **Step 1 – Import modules:**
# Load the modules `math`, `random` and `time` with suitable aliases (e.g. `import math as m`) and print a constant or function from each module (e.g. `math.pi`, `random.randint(1, 10)`)
#
# **Step 2 – Wait time simulation:**
# Create a small function or script that generates a random number of seconds (1–3) with `random` and uses `time.sleep()`, and print a short message before and after the wait
#
# **Step 3 – Flight path calculation:**
# Use `math.sin` and `math.pi` to calculate a height or value for an angle (e.g. 90° in radians) and print the result formatted
#
# **Step 4 – Crew generator:**
# Create a name list with 3–5 crew names and pick a random name with `random.choice()` and print the selected name
#
# **Bonus:** Add another function using the `datetime` module (e.g. display the current time).

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: The Calculation Core
#
# **Reward:** 400 Cyber Credits + Navigation Device
#
# You use the math module for circle calculations, angle conversions and square roots.
#
# **Step 1 – Circle calculation:**
# Write a function or script that calculates the circumference and area for a radius using `math.pi` and print radius, circumference and area formatted
#
# **Step 2 – Random numbers and sum:**
# Generate five random numbers with `random.randint(1, 100)` and store them (e.g. in a list) and calculate the sum and print the numbers and the sum
#
# **Step 3 – Angle conversion:**
# Convert 90°, 180° and 270° to radians using `math.radians()` and print degrees and radians for each angle
#
# **Step 4 – Square roots:**
# Calculate the square roots of 4, 9, 16 and 25 using `math.sqrt()` and print the results clearly
#
# **Bonus:** Add trigonometric calculations (e.g. sin, cos for 45°).

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: The Random Simulator
#
# **Reward:** 500 Cyber Credits + Crew Master Certificate
#
# You build a small simulation system with planets, weather and energy consumption.
#
# **Step 1 – Planet selection:**
# Create a list with 5–6 planet names and pick a random target planet with `random.choice()` and print the list and the chosen planet
#
# **Step 2 – Weather simulation:**
# Generate three temperature values (e.g. for different sectors) using `random.uniform(-50, 50)` and round them to one decimal place and print the temperatures with a short description
#
# **Step 3 – Energy consumption:**
# Simulate 3 systems each with a random consumption between 50 and 150 MW (using `random.randint` or `random.uniform`) and print system name and consumption and calculate the total consumption
#
# **Step 4 – Fleet generator:**
# Create 3 ship names with associated random strength (1–10) and store them (e.g. as a list of tuples or dicts) and print all ships with their strength
#
#
# > 💡 **Tip:** You decide how to implement it – there is no single right way!
# **Bonus:** Add a variable with normal distribution (e.g. `random.gauss(100, 20)` for energy values).

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### 🎯 Learning Goals – Have you achieved them?
#
# Check yourself whether you have mastered these skills:
#
# - ☐ Load modules with import
# - ☐ Use aliases for modules
# - ☐ Import specific functions
# - ☐ Use the math module for calculations
# - ☐ Use the random module for random numbers
# - ☐ Use modules in your own programs
#
# If you can check all the boxes – congratulations! You are ready for the Boss Quests!
