# %% [markdown]
# # 🐉 Boss Quests – 🚀 Week 11 – Advanced OOP: The Magic Evolution!
# > ⚠️ More challenging! Combines everything from this week.
#
# **⚠️ WARNING:** These missions are extremely difficult! They combine all advanced concepts.
#
# **Rewards:** 1800 Cyber Credits total + epic items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 1: The Rank Hierarchy
#
# **Reward:** 600 Cyber Credits + Commander Star
#
# The fleet has cadets, officers and captains – each with different authorities!
#
# **Step 1 – Base class:**
# Write a class `CrewMember` with name and rank. Add a method `show_permissions()`.
#
# **Step 2 – Ranks:**
# Derive 3 child classes (Cadet, Officer, Captain). Each overrides `show_permissions()`.
#
# **Step 3 – Briefing:**
# Create one member of each rank. Call `show_permissions()` for all.
#
# **Bonus:** Add `__str__` for a nice output.

# %%
# 🚀 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss Quest 2: The Robot Family
#
# **Reward:** 800 Cyber Credits + AI Chip
#
# All robots can perform tasks – but each type has a specialization!
#
# **Step 1 – Base class:**
# Write a class `Robot` with name and energy. Add a method `task()`.
#
# **Step 2 – Types:**
# Derive 3 child classes (e.g. CombatRobot, HealingRobot, ExplorationRobot). Each overrides `task()`.
#
# **Step 3 – Deployment:**
# Create one robot of each type. Let all perform their tasks and show the introduction with `__str__`.
#
# **Bonus:** Add `__eq__` that compares two robots by energy.

# %%
# 🚀 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 3: The Alien Contact System
#
# **Reward:** 400 Cyber Credits + First Contact Badge
#
# All alien species can communicate – but each in their own way!
#
# **Step 1 – Base class:**
# Write a class `Alien` with name and origin. Add a method `communicate()`.
#
# **Step 2 – Alien peoples:**
# Derive 4 species. Each overrides `communicate()` with its own language or gesture.
#
# **Step 3 – First contact:**
# Create one alien of each species and call `communicate()` for all.
#
# **Bonus:** Add `__str__` and `__len__`.

# %%
# 🚀 Your solution here:

print()
print("🎉 +400 Cyber Credits: Mission complete!")
print("🏆 You have defeated the Construction Master!")
print("⭐ Title earned: Architect of Systems")
print()
print("🎊 CONGRATULATIONS! You have mastered Week 11!")
print("🚀 Next week: Graphic projects with Turtle!")

# %% [markdown]
# ---
#
# 🎊 **Congratulations!** You have mastered all Boss Quests of this week!
#
# **Up next:** Week 12 is already waiting!
