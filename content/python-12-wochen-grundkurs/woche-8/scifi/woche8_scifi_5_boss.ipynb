# %% [markdown]
# # 🐉 Boss-Quests – 🚀 Woche 8 – Dictionaries und Tupel: Die Daten-Archive der Raumstation
# > ⚠️ Schwieriger! Kombiniert alles aus dieser Woche.
#
# **⚠️ ACHTUNG:** Diese Quests sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 Cyber Credits + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Der Crew-Steckbrief
#
# **Belohnung:** 500 Cyber Credits + Crew-Ausweis
#
# Die Nebula-7 braucht digitale Steckbriefe für alle Crew-Mitglieder!
#
# **Schritt 1 – Steckbrief anlegen:**
# Erstelle ein Dictionary für ein Crew-Mitglied mit mindestens 4 Eigenschaften (Name, Rang, Abteilung, Spezialität). Gib ihn übersichtlich aus.
#
# **Schritt 2 – Crew-Liste:**
# Lege 3 verschiedene Crew-Steckbriefe an und speichere sie in einer Liste.
#
# **Schritt 3 – Suche:**
# Finde alle Crew-Mitglieder einer bestimmten Abteilung. Gib die Gesamtzahl der Crew aus.
#
# **Bonus:** Sortiere die Crew nach Rang.

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Der Raumstations-Manager
#
# **Belohnung:** 600 Cyber Credits + Stations-Schlüssel
#
# Die Raumstation hat verschiedene Sektoren – jeder mit eigener Funktion!
#
# **Schritt 1 – Sektoren anlegen:**
# Erstelle ein Dictionary mit 3 Sektoren (z.B. Brücke, Maschinenraum, Medizin). Jeder Sektor ist ein Dictionary mit Leiter, Status und Energie-Level.
#
# **Schritt 2 – Status prüfen:**
# Zeige alle Sektoren mit ihrem Status. Finde den Sektor mit dem niedrigsten Energie-Level.
#
# **Schritt 3 – Alarm:**
# Erstelle einen Kommandanten-Steckbrief und prüfe für jeden Sektor: Braucht er Hilfe (Energie < 50)? Gib einen Alarmplan aus.
#
# **Bonus:** Speichere den Alarmstatus als Tupel und gib ihn aus.

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Das Missions-Archiv
#
# **Belohnung:** 400 Cyber Credits + Missions-Datenbank
#
# Die Flotte führt ein Archiv aller abgeschlossenen Missionen!
#
# **Schritt 1 – Missionen anlegen:**
# Erstelle 4 Missions-Einträge als Dictionaries (Name, Planet, Ergebnis, Dauer) in einer Liste.
#
# **Schritt 2 – Suche:**
# Finde alle erfolgreichen Missionen. Zeige die Gesamtanzahl aller Missionen.
#
# **Schritt 3 – Statistik:**
# Berechne die durchschnittliche Missionsdauer. Gib die längste und kürzeste Mission aus.
#
# **Bonus:** Füge jeder Mission ein Tupel mit den beteiligten Crew-Mitgliedern hinzu.

# %%
print()
print("🎉 +400 Cyber Credits: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Daten-Kurator der unendlichen Schlüssel besiegt!")
print("⭐ Titel erhalten: Meister der Daten-Archive")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 8 gemeistert!")
print("📚 Nächste Woche: JSON-Dateien und I/O!")

# %% [markdown]
# ---
#
# 🎊 **Glückwunsch!** Du hast alle Boss-Quests dieser Woche gemeistert!
#
# **Als Nächstes:** Woche 9 wartet schon!
