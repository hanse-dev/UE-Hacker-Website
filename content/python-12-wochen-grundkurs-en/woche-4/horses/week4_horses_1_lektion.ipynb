# %% [markdown]
# # 🐴 Week 4 – Loops (for, while): The Rhythm of Riding
#
# Welcome, horse friend! You have reached the **Endurance Training Ground** – a place where movements repeat and rhythm leads to perfection. This week you will learn the three **Rhythms of Riding**:
#
# **Your Mission:**
# - Master the **for loop** for controlled repetitions
# - Control the **while loop** for flexible conditions
# - Understand **range()** for precise counting
# - Learn **break** and **continue** for loop control
#
# **Keep going!** The rhythm of repetition awaits...

# %% [markdown]
# ## Lesson 1: Loop – The Dressage Circle
#
# **What it is:** A for loop repeats code for every element in a sequence.
#
# **The structure of a for loop:**
# ```python
# for variable in sequence:
#     # Code that runs for each element
# ```
#
# **Step-by-step explanation:**
# 1. **`for`** – The command that starts the repetition
# 2. **`variable`** – A placeholder that holds the current element on each pass
# 3. **`in`** – Connects the variable to the sequence
# 4. **`sequence`** – The collection we go through (e.g. list, string, range())
# 5. **`:`** – Ends the loop definition
# 6. **Indented code** – Runs on every pass
#
# **The iterator:**
# - The iterator is like an invisible riding master who remembers where we are in the sequence
# - It starts at the first element
# - After each pass it automatically jumps to the next element
# - The loop ends when no element is left
#
# **Why so useful:**
# - 🎯 Automate repeating tasks
# - 🔍 Process each element individually
# - ⚡ Make code more efficient and shorter
# - 🎲 Create patterns and sequences

# %%
# Example 1: Simple for loop with range()
print("=== Example 1: 5 laps riding ===")
# range(5) creates the numbers 0, 1, 2, 3, 4
for i in range(5):
    print(f"Lap {i+1}: The horse trots elegantly")

print("\n=== What happens here? ===")
print("1. range(5) creates: [0, 1, 2, 3, 4]")
print("2. i is set to the next element on each pass")
print("3. We print i+1 to count from 1 to 5")
print("4. The loop ends after the last element")

# %%
# Example 2: For loop with start and end
print("=== Example 2: Hurdles 3 to 7 ===")
# range(3, 8) creates the numbers 3, 4, 5, 6, 7 (8 is exclusive!)
for hurdle in range(3, 8):
    print(f"Hurdle {hurdle}: Jump!")

print("\n=== Important observation ===")
print("range(start, end) includes start, but not end!")
print("Like a riding arena: from 3 up to BEFORE 8")

# %%
# Example 3: For loop with step size
print("=== Example 3: Every second hurdle ===")
# range(0, 11, 2) creates: 0, 2, 4, 6, 8, 10
for hurdle in range(0, 11, 2):
    print(f"Hurdle {hurdle}: Jumped!")

print("\n=== The step size ===")
print("range(start, end, step) skips hurdles")
print("Here: skip every second hurdle")

# %%
# Example 4: For loop over a string
print("=== Example 4: Letters of a horse name ===")
name = "Thunder"
print(f"The horse name is: {name}")
print("Letter by letter:")

for letter in name:
    print(f"  - {letter}")

print("\n=== What happens here? ===")
print("String is treated as a sequence of letters")
print("Each letter is looped through individually")

# %%
# Example 5: For loop over a list
print("=== Example 5: Horses in the stable ===")
horses = ["Thunder", "Storm", "Shadow", "Blaze"]
print("Horses in the stable:")

for horse in horses:
    print(f"  - {horse}")

print("\n=== With stable number and name ===")
# enumerate gives us both index and value
for number, horse in enumerate(horses, start=1):
    print(f"  Stable {number}: {horse}")

# %% [markdown]
# ## 🔍 The Secret of range() – The Number Rider
#
# **range() is your most faithful companion for number sequences!**
#
# ### The three forms of range():
#
# 1. **`range(n)`** – Numbers from 0 to n-1
#    ```python
#    range(5) → 0, 1, 2, 3, 4
#    ```
#
# 2. **`range(start, end)`** – Numbers from start to end-1
#    ```python
#    range(2, 7) → 2, 3, 4, 5, 6
#    ```
#
# 3. **`range(start, end, step)`** – Numbers with gaps
#    ```python
#    range(1, 10, 2) → 1, 3, 5, 7, 9
#    ```
#
# **Important rules:**
# - The **upper bound is always exclusive** (not included in the count)
# - **Negative steps** are possible for counting backwards
# - range() is **very memory-efficient** (generates numbers only when needed)

# %%
# 🔍 Exercises with range()

# Exercise 1: Countdown to the start
print("=== Countdown to tournament start ===")
for i in range(5, 0, -1):
    print(f"{i}...")
print("🏇 GO!")

# Exercise 2: Even lane numbers
print("\n=== Even lane numbers ===")
for lane in range(2, 21, 2):
    print(f"Lane {lane}", end=" ")
print()

# Exercise 3: Training rounds
print("\n=== Training rounds ===")
for round_ in range(1, 6):
    print(f"Round {round_}: Trot - Canter - Trot")

# %% [markdown]
# ## Lesson 2: Loop – The Endurance Test
#
# **What it is:** A while loop repeats code as long as a condition is true.
#
# **The structure of a while loop:**
# ```python
# while condition:
#     # Code that repeats as long as condition is true
#     # IMPORTANT: The condition must eventually become false!
# ```
#
# **⚠️ Warning:** Infinite loops occur when the condition never becomes false!

# %%
# Example 1: Simple while loop
print("=== Example 1: Counting to 10 ===")
counter = 0
while counter <= 10:
    print(f"Hoof beat {counter}")
    counter += 1  # IMPORTANT: count up, otherwise infinite loop!

print("\n=== What happens here? ===")
print("1. counter starts at 0")
print("2. As long as counter <= 10, the code runs")
print("3. counter += 1 increases the value on each pass")
print("4. At counter = 11 the condition becomes false → loop ends")

# %%
# Example 2: Horse training
print("=== Example 2: Training until exhaustion ===")
stamina = 100
round_ = 1

while stamina > 20:
    usage = 15
    stamina -= usage
    print(f"Round {round_}: -{usage} stamina, remaining: {stamina}%")
    round_ += 1

print(f"\n💪 Training finished after {round_-1} rounds!")
print("Time for a break!")

# %%
# Example 3: Feed quiz
print("=== Example 3: Feed quiz ===")
feed = ""
attempts = 0
max_attempts = 3

while feed != "Hay" and attempts < max_attempts:
    feed = input("What do horses love to eat most? ")
    attempts += 1
    
    if feed == "Hay":
        print("✅ Correct!")
    elif attempts >= max_attempts:
        print("❌ Too many attempts! The answer is: Hay")
    else:
        print(f"Wrong! {max_attempts - attempts} attempts remaining")

# %% [markdown]
# ## Lesson 3: The Training Breakers
#
# **break** – Ends the training immediately
# **continue** – Jumps to the next exercise
#
# - ⚡ Save energy

# %%
# Example 1: break when problems arise
print("=== Example 1: Stop training when in pain ===")
exercises = ["Warm-up", "Trotting", "Cantering", "Jumping", "Cool-down"]

for exercise in exercises:
    print(f"Exercise: {exercise}")
    if exercise == "Jumping":
        print("⚠️ Horse is limping! Training stopped.")
        break  # end loop immediately

print("\n=== Without break all exercises would be done ===")

# %%
# Example 2: continue as a filter
print("=== Example 2: Dressage exercises only ===")
exercises = ["Jumping", "Dressage", "Cantering", "Dressage", "Western"]

print("Dressage exercises today:")
for exercise in exercises:
    # Skip if not a dressage exercise
    if exercise != "Dressage":
        continue  # jump to next pass
    print(f"  - {exercise}")

# %%
# Example 3: Complex training
print("=== Example 3: Intensive training ===")
day = 1
max_days = 7

while day <= max_days:
    print(f"\nDay {day}:")
    
    # 3 training sessions per day
    for session in range(3):
        print(f"  Session {session+1}: Training")
        
        # Break on overload
        if day == 4 and session == 1:
            print("  💪 Overload! Extra rest!")
            continue
    
    day += 1
    
    # Stop training on injury risk
    if day > 5:
        print("\n🏥 Injury risk! Training stopped.")
        break
