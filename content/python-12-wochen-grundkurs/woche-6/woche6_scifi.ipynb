# %% [markdown]
# # 🚀 Woche 6 – Listen: Die Daten-Bänke der Raumstation
#
# **Cyber Credits zu verdienen:** 1000 Punkte
# **Boss:** Der Daten-Archivar der unendlichen Arrays

# %% [markdown]
# ## 🌟 Die Mission beginnt: Das Daten-Zentral der Nebula-7
#
# Willkommen an Bord der Raumstation Nebula-7! Du erreichst das **Daten-Zentral** – ein hochmoderner Sektor, in dem unendlich viele Daten gesammelt und organisiert werden können. In dieser Woche lernst du die drei **Arten der Daten-Sammlungen**:
#
# **Deine Mission:**
# - Meistere die **Listen-Erstellung** mit eckigen Klammern
# - Beherrsche **Elemente hinzufügen** mit append() und insert()
# - Lerne **Elemente entfernen** mit remove() und pop()
# - Verstehe **Listen durchsuchen** mit index() und in-Operator
#
# **Einmal gespeichert, für immer verfügbar!** Die Macht der Listen wartet...

# %% [markdown]
# ## 📚 Daten-Sammlung 1: Die Listen-Erstellung - Der erste Datensatz
#
# **Was es ist:** Eine Liste ist eine geordnete Sammlung von Elementen, die du mit eckigen Klammern erstellst.
#
# **Die Anatomie einer Liste:**
# ```python
# # Leere Liste erstellen
# leere_liste = []
#
# # Liste mit Elementen erstellen
# schiffe = ["Nebula-Explorer", "Star-Fighter", "Cargo-Hauler"]
# ```
#
# **Schritt-für-Schritt-Erklärung:**
# 1. **`[]`** - Eckige Klammern definieren eine Liste
# 2. **`,`** - Kommas trennen die Elemente
# 3. **`""`** - Strings werden in Anführungszeichen gesetzt
# 4. **`[]`** - Mit Index greifst du auf Elemente zu (beginnt bei 0)
#
# **Warum so nützlich:**
# - 🎯 Mehrere Werte in einer Variable speichern
# - 🔍 Geordnete Struktur für Daten
# - ⚡ Flexibel erweiterbar und veränderbar
# - 🎲 Verschiedene Datentypen mischbar

# %%
# Beispiel 1: Einfache Listen erstellen
# Leere Liste
leere_liste = []
print(f"Leere Liste: {leere_liste}")

# Liste mit Schiffen
schiffe = ["Nebula-Explorer", "Star-Fighter", "Cargo-Hauler", "Science-Vessel"]
print(f"Schiff-Liste: {schiffe}")

# Liste mit Zahlen
koordinaten = [100, 200, 300, 400, 500]
print(f"Koordinaten: {koordinaten}")

# Gemischte Liste
mixed = ["Phaser", 25, True, "Tricorder"]
print(f"Gemischte Liste: {mixed}")

# %%
# Beispiel 2: Auf Listenelemente zugreifen
ausruestung = ["Phaser", "Tricorder", "Kommunikator", "Medi-Kit", "Werkzeug"]

print("=== Ausrüstungs-Zugriff ===")
print(f"Gesamte Ausrüstung: {ausruestung}")
print(f"Erstes Item: {ausruestung[0]}")
print(f"Zweites Item: {ausruestung[1]}")
print(f"Letztes Item: {ausruestung[-1]}")

# Länge der Liste
print(f"Anzahl Items: {len(ausruestung)}")

# Slicing (Ausschnitte)
print(f"Erste 3 Items: {ausruestung[0:3]}")
print(f"Letzte 2 Items: {ausruestung[-2:]}")

# %%
# Beispiel 3: Listen in Listen (verschachtelte Listen)
crew_mitglieder = [
    ["Captain Alex", "Kommandant", 35, "Alpha-Quadrant"],
    ["Dr. Zara", "Wissenschaftlerin", 28, "Beta-Quadrant"],
    ["Lt. Nova", "Pilotin", 26, "Gamma-Sektor"]
]

print("=== Crew-Mitglieder ===")
print(f"Erster Crew-Mitglied: {crew_mitglieder[0]}")
print(f"Name des ersten: {crew_mitglieder[0][0]}")
print(f"Position des zweiten: {crew_mitglieder[1][1]}")
print(f"Alter des dritten: {crew_mitglieder[2][2]} Jahre")
print(f"Sektor des ersten: {crew_mitglieder[0][3]}")

# %% [markdown]
# ## 📦 Daten-Sammlung 2: Elemente verwalten - Der Daten-Kurator
#
# **Die wichtigsten Listen-Methoden:**
#
# **Elemente hinzufügen:**
# - `append(element)` - Fügt am Ende hinzu
# - `insert(index, element)` - Fügt an bestimmter Position ein
#
# **Elemente entfernen:**
# - `remove(element)` - Entfernt erstes Vorkommen
# - `pop(index)` - Entfernt und gibt Element zurück
# - `clear()` - Leert die gesamte Liste

# %%
# 🔍 Übungen mit append() und insert()

# Beispiel 1: Elemente hinzufügen
missions_log = []
print(f"Leeres Missions-Log: {missions_log}")

# Mit append() am Ende hinzufügen
missions_log.append("Planetenerkundung")
print(f"Nach append: {missions_log}")

missions_log.append("Asteroidenabbau")
missions_log.append("Erste-Kontakt-Mission")
print(f"Voll gefüllt: {missions_log}")

# Mit insert() an bestimmter Position einfügen
missions_log.insert(0, "System-Check")  # Am Anfang
print(f"Nach insert(0): {missions_log}")

missions_log.insert(2, "Wartung")  # An Position 2
print(f"Nach insert(2): {missions_log}")

# %%
# Beispiel 2: Elemente entfernen
system_protokolle = ["Alpha", "Beta", "Gamma", "Delta", "Epsilon", "Gamma"]
print(f"Original-Protokolle: {system_protokolle}")

# Mit remove() erstes Vorkommen entfernen
system_protokolle.remove("Gamma")
print(f"Nach remove('Gamma'): {system_protokolle}")

# Mit pop() letztes Element entfernen und zurückgeben
letztes_protokoll = system_protokolle.pop()
print(f"Nach pop(): {system_protokolle}")
print(f"Entferntes Protokoll: {letztes_protokoll}")

# Mit pop(index) bestimmtes Element entfernen
zweites_protokoll = system_protokolle.pop(1)
print(f"Nach pop(1): {system_protokolle}")
print(f"Entferntes Protokoll: {zweites_protokoll}")

# Mit clear() alles löschen
system_protokolle.clear()
print(f"Nach clear(): {system_protokolle}")

# %%
# Beispiel 3: Listen kombinieren
schiffe = ["Nebula-Explorer", "Star-Fighter"]
crew = ["Captain Alex", "Dr. Zara"]
missionen = ["Forschung", "Verteidigung", "Erforschung"]

print("=== Listen kombinieren ===")
print(f"Schiffe: {schiffe}")
print(f"Crew: {crew}")
print(f"Missionen: {missionen}")

# Mit + Operator kombinieren
alle = schiffe + crew + missionen
print(f"Alles kombiniert: {alle}")

# Mit extend() eine Liste zur anderen hinzufügen
schiffe.extend(crew)
print(f"Schiffe erweitert: {schiffe}")

# %% [markdown]
# ## ✨ Daten-Sammlung 3: Listen durchsuchen und sortieren - Der Such-Algorithmus
#
# **Die mächtigsten Such-Methoden:**
#
# **Suchen und prüfen:**
# - `index(element)` - Gibt Index des Elements zurück
# - `element in liste` - Prüft ob Element vorhanden
# - `count(element)` - Zählt Vorkommen
#
# **Sortieren:**
# - `sort()` - Sortiert die Liste selbst
# - `sorted(liste)` - Gibt sortierte Kopie zurück
# - `reverse()` - Kehrt Reihenfolge um

# %%
# Beispiel 1: In Listen suchen
systeme = ["Waffensystem", "Schildsystem", "Antriebssystem", "Lebenserhaltung", "Waffensystem", "Antriebssystem"]

print("=== In Listen suchen ===")
print(f"System-Liste: {systeme}")

# Mit index() Position finden
position_schild = systeme.index("Schildsystem")
print(f"Schildsystem an Position: {position_schild}")

# Mit in() prüfen ob vorhanden
hat_antrieb = "Antriebssystem" in systeme
hat_teleporter = "Teleporter" in systeme
print(f"Antriebssystem vorhanden: {hat_antrieb}")
print(f"Teleporter vorhanden: {hat_teleporter}")

# Mit count() zählen
anzahl_waffen = systeme.count("Waffensystem")
print(f"Anzahl Waffensysteme: {anzahl_waffen}")

# %%
# Beispiel 2: Listen sortieren
prioritaeten = [5, 2, 8, 1, 9, 3]
sektoren = ["Zeta", "Alpha", "Gamma", "Beta", "Delta"]

print("=== Listen sortieren ===")
print(f"Original-Prioritäten: {prioritaeten}")
print(f"Original-Sektoren: {sektoren}")

# Mit sort() direkt sortieren
prioritaeten.sort()
print(f"Prioritäten nach sort(): {prioritaeten}")

# Mit sorted() Kopie sortieren
sortierte_sektoren = sorted(sektoren)
print(f"Sektoren Original: {sektoren}")
print(f"Sektoren sortiert: {sortierte_sektoren}")

# Umgekehrt sortieren
prioritaeten.sort(reverse=True)
print(f"Prioritäten absteigend: {prioritaeten}")

# Mit reverse() Reihenfolge umkehren
sektoren.reverse()
print(f"Sektoren umgekehrt: {sektoren}")

# %%
# Beispiel 3: Fortgeschrittene Listen-Operationen
mission_typen = ["Forschung", "Verteidigung", "Erforschung", "Forschung", "Verteidigung"]

print("=== Fortgeschrittene Operationen ===")
print(f"Missionstypen-Liste: {mission_typen}")

# Einzigartige Elemente (mit set)
einzigartige_typen = list(set(mission_typen))
print(f"Einzigartige Missionstypen: {einzigartige_typen}")

# Listen mit for-Schleife durchlaufen
print("\nAlle Missionstypen:")
for i, m in enumerate(mission_typen):
    print(f"  Position {i}: {m}")

# List Comprehension (fortgeschritten)
lange_namen = [m for m in mission_typen if len(m) > 8]
print(f"\nMissionstypen mit langen Namen: {lange_namen}")

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein Techniker hat versucht, die Systemdaten zu organisieren, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1

systeme = ["Waffensystem", "Schildsystem", "Antriebssystem"
print(f"Systeme: {systeme}")

# %%
# 🐛 Bug #2

protokolle = ["Alpha", "Beta", "Gamma"]
print(protokolle[3])

# %%
# 🐛 Bug #3

level = [1, 5, 10, 15]
level.sort(reverse)
print(level)

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Datensammler
#
# **Belohnung:** 300 Cyber Credits + Daten-Chip
#
# Im Daten-Zentral der Nebula-7 erstellst du deine erste geordnete Datensammlung für Schiffe.
#
# **Deine Aufgaben:**
#
# 1. **Schiffsliste anlegen**
#    - Erstelle eine Liste `schiffe` mit 5 verschiedenen Schiffstypen (z.B. "Nebula-Explorer", "Star-Fighter")
#    - Gib die Liste mit `print()` aus
#    - Nutze eckige Klammern `[]` und Kommas zwischen den Elementen
#
# 2. **Elemente ergänzen**
#    - Füge mit `append()` drei weitere Schiffe an das Ende der Liste an
#    - Gib die Liste nach jedem Schritt oder am Ende erneut aus
#    - Optional: Nutze `insert(0, "Name")`, um ein Schiff an den Anfang zu setzen
#
# 3. **Element entfernen und Position finden**
#    - Entferne mit `remove("Name")` ein bestimmtes Schiff aus der Liste
#    - Finde mit `index("Name")` die Position eines anderen Schiffes und gib sie aus
#    - Gib die aktuelle Liste und die gefundene Position aus
#
# 4. **Sortieren und Ausgabe**
#    - Sortiere die Schiffe alphabetisch mit `sort()`
#    - Gib die sortierte Liste und die Anzahl der Schiffe mit `len()` aus
#
# **Beispiel-Code zum Starten:**
# ```python
# schiffe = ["Nebula-Explorer", "Star-Fighter", "Cargo-Hauler", "Science-Vessel", "Scout"]
# print(f"Schiffe: {schiffe}")
#
# schiffe.append("Fighter-X")
# print(f"Nach append: {schiffe}")
# ```
#
# **Bonus-Challenge:**
# - Erstelle eine verschachtelte Liste, in der zu jedem Schiff noch Details (z.B. Klasse, Besatzung) stehen.
#
# **Erwartete Ausgabe:**
# ```
# Schiffe: ['Nebula-Explorer', 'Star-Fighter', ...]
# Nach append: [...]
# Position von 'Cargo-Hauler': 2
# Sortierte Schiffe: ['Cargo-Hauler', ...]
# Anzahl: 7
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der System-Manager
#
# **Belohnung:** 400 Cyber Credits + System-Konsole
#
# Du verwaltest die Schiffssysteme der Raumstation mit Listen und kleinen Hilfsfunktionen.
#
# **Deine Aufgaben:**
#
# 1. **Systemliste anlegen**
#    - Erstelle eine Liste `systeme` mit verschiedenen Schiffssystemen (z.B. "Antrieb", "Schild", "Waffen")
#    - Gib die Liste und die Anzahl der Systeme mit `len()` aus
#
# 2. **Systeme hinzufügen**
#    - Schreibe eine Funktion `system_hinzufuegen(liste, name)` oder nutze direkt `append()` und `insert()`, um Systeme hinzuzufügen
#    - Füge mindestens ein System am Ende und eines an einer bestimmten Position (z.B. Index 0) ein
#    - Gib die aktualisierte Liste aus
#
# 3. **Systeme entfernen und suchen**
#    - Entferne ein System mit `remove()` und eines mit `pop()` (z.B. letztes Element)
#    - Finde mit `index()` die Position eines bestimmten Systems
#    - Prüfe mit `in` (z.B. `"Schild" in systeme`), ob ein System vorhanden ist, und gib das Ergebnis aus
#
# 4. **Statistik ausgeben**
#    - Gib Anzahl der Systeme, die aktuelle Liste und optional eine kurze Statuszeile aus
#
# **Beispiel-Code zum Starten:**
# ```python
# systeme = ["Antrieb", "Schild", "Waffen", "Sensoren"]
# print(f"Systeme: {systeme}, Anzahl: {len(systeme)}")
#
# systeme.append("Leben-Support")
# systeme.insert(0, "Kern-Reaktor")
# print(f"Nach Hinzufügen: {systeme}")
# ```
#
# **Bonus-Challenge:**
# - Speichere zu jedem System eine Priorität (z.B. in einer zweiten Liste oder als Zahl) und gib eine sortierte Übersicht nach Priorität aus.
#
# **Erwartete Ausgabe:**
# ```
# Systeme: ['Antrieb', 'Schild', ...], Anzahl: 4
# Nach Hinzufügen: ['Kern-Reaktor', ...]
# Position von 'Schild': 2
# 'Schild' vorhanden: True
# Aktuelle Systeme: 5
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Die Crew-Datenbank
#
# **Belohnung:** 500 Cyber Credits + Crew-Meister-Urkunde
#
# Du baust eine kleine Crew-Datenbank mit verschachtelten Listen und Such- und Sortierfunktionen.
#
# **Deine Aufgaben:**
#
# 1. **Crew-Liste anlegen**
#    - Erstelle eine verschachtelte Liste `crew`, in der jedes Element eine Liste mit Name, Rang und Position ist (z.B. `["Captain Alex", "Kommandant", "Alpha"]`)
#    - Lege mindestens 3 Crew-Mitglieder an und gib die Liste aus
#
# 2. **Crew erweitern**
#    - Füge mit `append()` ein neues Crew-Mitglied (ebenfalls als Liste mit Name, Rang, Position) hinzu
#    - Optional: Nutze eine Funktion `crew_hinzufuegen(crew, name, rang, position)` dafür
#    - Gib die aktualisierte Crew-Liste aus
#
# 3. **Crew durchsuchen und sortieren**
#    - Finde mit einer Schleife oder mit `index()` die Position eines bestimmten Mitglieds (z.B. nach Namen)
#    - Erstelle eine sortierte Kopie der Crew nach Namen mit `sorted(crew, key=...)` oder sortiere eine Liste von Namen
#    - Gib die gefundene Position und eine kurze sortierte Übersicht aus
#
# 4. **Statistik ausgeben**
#    - Zähle die Anzahl der Crew-Mitglieder und gib eine kurze Rang- oder Positionsübersicht aus (z.B. wie viele pro Rang)
#
# **Beispiel-Code zum Starten:**
# ```python
# crew = [
#     ["Captain Alex", "Kommandant", "Alpha"],
#     ["Dr. Zara", "Wissenschaftlerin", "Beta"],
#     ["Lt. Nova", "Pilotin", "Gamma"],
# ]
# print(f"Crew: {crew}")
#
# crew.append(["Lt. Kim", "Techniker", "Delta"])
# print(f"Nach Hinzufügen: {len(crew)} Mitglieder")
# ```
#
# **Bonus-Challenge:**
# - Füge zu jedem Mitglied eine vierte Spalte „Missionen“ (Anzahl) hinzu und sortiere nach Missionen.
#
# **Erwartete Ausgabe:**
# ```
# Crew: [['Captain Alex', 'Kommandant', 'Alpha'], ...]
# Nach Hinzufügen: 4 Mitglieder
# Position von Dr. Zara: 1
# Sortierte Namen: ['Captain Alex', 'Dr. Zara', ...]
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten des Kommandanten (Reflexion)
#
# Bevor du weiterfliegst, denke über diese Fragen nach:
#
# 1. **Warum sind Listen besser als einzelne Variablen?**
#
# 2. **Wann sollte man append() und wann insert() verwenden?**
#
# 3. **Was ist der Unterschied zwischen sort() und sorted()?**
#
# Diskutiere deine Gedanken mit anderen Kommandanten!

# %% [markdown]
# ### 📖 Tech-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **list** 🚀: Datentyp für Listen
# - **[]** 📦: Eckige Klammern für Listen
# - **append()** ➕: Am Ende hinzufügen
# - **insert()** 📍: An Position einfügen
# - **remove()** ❌: Element entfernen
# - **pop()** 🎯: Element entfernen und zurückgeben
# - **index()** 🔍: Position finden
# - **in** ✅: Prüfen ob vorhanden
# - **sort()** 📊: Liste sortieren
# - **nested list** 🎲: Verschachtelte Liste

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ✅ Listen erstellen mit eckigen Klammern
# - ✅ Elemente hinzufügen mit append() und insert()
# - ✅ Elemente entfernen mit remove() und pop()
# - ✅ Listen durchsuchen mit index() und in-Operator
# - ✅ Listen sortieren mit sort() und sorted()
# - ✅ Listen verschachteln für komplexe Datenstrukturen
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die Boss-Quests!

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Exzellent!** Du hast die Daten-Bänke der Raumstation gemeistert!
#
# **Das hast du gelernt:**
# - Listen erstellen und verwalten
# - Elemente hinzufügen und entfernen
# - In Listen suchen und sortieren
# - Verschachtelte Listen erstellen
# - Fortgeschrittene Listen-Operationen
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🚀 **Raumfahrt:** Telemetrie-Daten, Crew-Listen, Missions-Logs
# - 📱 **Apps:** Kontaktlisten, Playlists, Einkaufswagen
# - 🌐 **Websites:** Menüs, Galerien, Daten-Tabellen
# - 🤖 **KI-Systeme:** Datensätze, Feature-Listen, Ergebnisse
# - 📊 **Wissenschaft:** Messwerte, Experiment-Daten, Ergebnisse
#
# **Als Nächstes:** In Woche 7 lernst du **Module und Bibliotheken**!

# %% [markdown]
# ## 🐉 Boss-Kampf: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Quests sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 Cyber Credits + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Der Daten-Generator
#
# **Belohnung:** 500 Cyber Credits + Daten-Kristall
#
# Baue ein System, das automatisch Datensätze erzeugt, filtert und sortiert.
#
# **Deine Aufgaben:**
#
# 1. **Datensatz erzeugen**
#    - Schreibe eine Funktion `generiere_datensatz(datentyp, komplexitaet)`, die eine Liste mit ein paar Einträgen zurückgibt (z.B. Namen oder IDs je nach Typ)
#    - Nutze `datentyp` und `komplexitaet`, um die Anzahl oder Art der Einträge zu steuern
#    - Gib die Liste mit `return` zurück
#
# 2. **Statistik berechnen**
#    - Erstelle eine Funktion `berechne_statistik(datenliste)`, die Länge und optional Min/Max oder Durchschnitt zurückgibt
#    - Gib die Werte als Dictionary oder als ausgedruckte Zeilen zurück
#
# 3. **Mehrere Datensätze anlegen**
#    - Erstelle eine Liste `daten` und füge mit einer Schleife mindestens 10 Datensätze hinzu (z.B. mit `generiere_datensatz("sensor", i)` für verschiedene i)
#    - Nutze `append()`, um jeden Datensatz zur Liste hinzuzufügen
#
# 4. **Daten filtern und sortieren**
#    - Schreibe eine Funktion `filtere_daten(datenliste, suchbegriff)`, die nur Einträge zurückgibt, die den Suchbegriff enthalten (z.B. mit `in` oder String-Vergleich)
#    - Sortiere die gefilterte oder die gesamte Liste mit `sort()` oder `sorted()` und gib das Ergebnis aus
#
# 5. **Generator zusammenbauen**
#    - Rufe im Hauptteil alle Funktionen auf: Datensätze erzeugen, Statistik ausgeben, filtern, sortieren
#    - Gib eine kurze Zusammenfassung (Anzahl, Statistik, gefilterte Anzahl) aus
#
# **Beispiel-Code zum Starten:**
# ```python
# def generiere_datensatz(datentyp, komplexitaet):
#     """Erzeugt einen kleinen Datensatz je nach Typ und Komplexität."""
#     return [f"{datentyp}-{i}" for i in range(komplexitaet)]
#
# daten = []
# for i in range(1, 11):
#     daten.append(generiere_datensatz("sensor", i))
# print(f"Anzahl Datensätze: {len(daten)}")
# ```
#
# **Bonus-Challenge:**
# - Füge zufällige Attribute (z.B. mit `random`) hinzu und prüfe die Daten auf Gültigkeit (Validierung).
#
# **Erwartete Ausgabe:**
# ```
# Anzahl Datensätze: 10
# Statistik: Länge 10, durchschnittliche Größe 5.5
# Gefilterte Einträge: 3
# Sortierte Liste: [...]
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Der Raumstation-Manager
#
# **Belohnung:** 600 Cyber Credits + Kommandanten-Titel
#
# Verwalte die Decks und Systeme einer Raumstation mit Listen und einfachen Funktionen.
#
# **Deine Aufgaben:**
#
# 1. **Sektoren (Decks) anlegen**
#    - Erstelle eine Funktion `erstelle_sektoren(anzahl_decks, systeme_pro_deck)`, die eine verschachtelte Liste zurückgibt: jedes Deck ist eine Liste mit `systeme_pro_deck` Platzhaltern (z.B. leere Strings oder "frei")
#    - Gib die verschachtelte Liste zurück
#
# 2. **Systeme platzieren**
#    - Schreibe eine Funktion `platziere_system(sektoren, deck_index, system_name)`, die an der angegebenen Deck-Position ein System einträgt (z.B. ersetzt einen Platzhalter durch den Namen)
#    - Nutze Indexzugriff `sektoren[deck_index][position]` und aktualisiere die Liste
#
# 3. **Energie verteilen**
#    - Erstelle eine Funktion `verteile_energie(sektoren, totale_energie)`, die die Energie gleichmäßig oder nach Anzahl der Systeme pro Deck auf die Decks verteilt
#    - Gib eine Liste mit Energie pro Deck zurück oder speichere sie in einer zweiten Struktur
#
# 4. **Übersicht ausgeben**
#    - Schreibe eine Funktion `zeige_uebersicht(sektoren)`, die alle Decks und ihre Systeme formatiert ausgibt (z.B. "Deck 1: Antrieb, Schild, Waffen")
#    - Gib am Ende eine kurze Zusammenfassung (Anzahl Decks, Gesamtsysteme) aus
#
# **Beispiel-Code zum Starten:**
# ```python
# def erstelle_sektoren(anzahl_decks, systeme_pro_deck):
#     """Erstellt eine verschachtelte Liste für Decks und Systeme."""
#     return [["frei"] * systeme_pro_deck for _ in range(anzahl_decks)]
#
# station = erstelle_sektoren(3, 4)
# print(f"Station: {station}")
# ```
#
# **Bonus-Challenge:**
# - Simuliere zufällige Systemausfälle (ersetze ein System durch "Ausfall") und eine Reparatur-Funktion, die es wieder auf "OK" setzt.
#
# **Erwartete Ausgabe:**
# ```
# Station: [['frei', 'frei', 'frei', 'frei'], ...]
# Deck 1: Antrieb, Schild, frei, frei
# Deck 2: ...
# Gesamt: 3 Decks, 12 Plätze
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Die Missions-Datenbank
#
# **Belohnung:** 400 Cyber Credits + Missions-Protokoll
#
# Verwalte Missionen in einer Liste: anlegen, suchen, filtern und auswerten.
#
# **Deine Aufgaben:**
#
# 1. **Mission anlegen**
#    - Erstelle eine Funktion `erstelle_mission(name, ziel, prioritaet)`, die ein Dictionary mit den Keys "name", "ziel", "prioritaet" (und optional "status") zurückgibt
#    - Gib das Dictionary mit `return` zurück
#
# 2. **Mission zur Liste hinzufügen**
#    - Erstelle eine Liste `missionen`
#    - Schreibe eine Funktion `fuege_mission_hinzu(mission, missionsliste)`, die die Mission mit `append()` zur Liste hinzufügt und eine kurze Bestätigung zurückgibt oder ausgibt
#
# 3. **Missionen suchen**
#    - Schreibe eine Funktion `suche_missionen(missionsliste, suchbegriff)`, die alle Missionen zurückgibt, in deren Name oder Ziel der Suchbegriff vorkommt (z.B. mit `in`)
#    - Gib die gefundene Liste zurück
#
# 4. **Nach Status filtern**
#    - Erstelle eine Funktion `filtere_nach_status(missionsliste, status)`, die nur Missionen mit dem angegebenen Status zurückgibt (z.B. "aktiv", "abgeschlossen")
#    - Gib die gefilterte Liste zurück
#
# 5. **Statistik ausgeben**
#    - Schreibe eine Funktion `missionen_statistik(missionsliste)`, die die Anzahl der Missionen und optional die Verteilung nach Priorität oder Status berechnet und ausgibt
#    - Rufe im Hauptteil alle Funktionen auf: Missionen anlegen, hinzufügen, suchen, filtern, Statistik ausgeben
#
# **Beispiel-Code zum Starten:**
# ```python
# def erstelle_mission(name, ziel, prioritaet):
#     """Erstellt ein Mission-Dictionary."""
#     return {"name": name, "ziel": ziel, "prioritaet": prioritaet, "status": "aktiv"}
#
# missionen = []
# m = erstelle_mission("Erkundung", "Alpha-3", 1)
# missionen.append(m)
# print(f"Missionen: {len(missionen)}")
# ```
#
# **Bonus-Challenge:**
# - Füge zu jeder Mission ein Feld "ergebnis" oder "erfolg" hinzu und gib eine Erfolgsstatistik aus.
#
# **Erwartete Ausgabe:**
# ```
# Mission hinzugefügt: Erkundung
# Gefundene Missionen: 2
# Nach Status 'aktiv': 3 Missionen
# Statistik: 5 Missionen, 3 aktiv
# ```

# %%
# 🐉 Deine Lösung hier:

print()
print("🎉 +400 Cyber Credits: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Daten-Archivar der unendlichen Arrays besiegt!")
print("⭐ Titel erhalten: Meister der Daten-Sammlungen")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 6 gemeistert!")
print("📚 Nächste Woche: Module und Bibliotheken (math, random)!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen:

# %%
# ✅ Lösung Bug #1: Fehlende schließende Klammer

# Problem: Liste nicht geschlossen
systeme = ["Waffensystem", "Schildsystem", "Antriebssystem"]
print(f"Systeme: {systeme}")

# %%
# ✅ Lösung Bug #2: Index außerhalb des Bereichs

# Problem: Index 3 existiert nicht (nur 0,1,2)
protokolle = ["Alpha", "Beta", "Gamma"]
print(protokolle[2])  # Letztes Element

# %%
# ✅ Lösung Bug #3: Falscher Parameter für sort()

# Problem: reverse ist ein Boolean, keine separate Variable
level = [1, 5, 10, 15]
level.sort(reverse=True)
print(level)
