# %% [markdown]
# # 🐉 Boss-Quests – 🚀 Woche 9 – JSON-Dateien und I/O: Die Daten-Pipelines der Raumstation
# > ⚠️ Schwieriger! Kombiniert alles aus dieser Woche.
#
# **⚠️ ACHTUNG:** Diese Quests sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 Cyber Credits + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Das Missionstagebuch
#
# **Belohnung:** 500 Cyber Credits + Digitales Logbuch
#
# Jede Crew führt ein Missionstagebuch – für die Geschichte der Galaxis!
#
# **Schritt 1 – Eintrag schreiben:**
# Lass den Benutzer mit `input()` einen Log-Eintrag eingeben (Datum, Planet, Ereignis). Speichere ihn in einer Textdatei.
#
# **Schritt 2 – Log lesen:**
# Lies die Datei wieder ein und gib alle Einträge übersichtlich aus.
#
# **Schritt 3 – Einträge sammeln:**
# Lass den Benutzer 3 Einträge nacheinander eingeben. Hänge jeden neuen an die Datei an. Lies am Ende das komplette Log aus.
#
# **Bonus:** Zähle wie viele Log-Einträge die Datei enthält.

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Die Sternenkarte
#
# **Belohnung:** 600 Cyber Credits + Holografische Sternenkarte
#
# Alle erkundeten Systeme werden in einer JSON-Datei gespeichert!
#
# **Schritt 1 – Sternenkarte anlegen:**
# Erstelle ein Dictionary mit 3 Sternsystem-Einträgen (Name, Koordinaten, Status, Entfernung). Speichere es als JSON-Datei.
#
# **Schritt 2 – Karte laden:**
# Lade die JSON-Datei wieder ein und gib alle Systeme übersichtlich aus.
#
# **Schritt 3 – System hinzufügen:**
# Lade die Karte, füge ein neues Sternsystem hinzu und speichere die aktualisierte Version. Gib die endgültige Karte aus.
#
# **Bonus:** Finde das am weitesten entfernte System und markiere es.

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Das Missionsarchiv
#
# **Belohnung:** 400 Cyber Credits + Daten-Chip
#
# Die Flotte führt ein digitales Archiv aller Missionen!
#
# **Schritt 1 – Missionen speichern:**
# Erstelle eine Liste mit 3 Missions-Einträgen (Name, Planet, Ergebnis, Crew) als Dictionaries. Speichere als JSON.
#
# **Schritt 2 – Archiv laden:**
# Lade das Archiv und gib alle Missionen übersichtlich aus.
#
# **Schritt 3 – Mission aktualisieren:**
# Lade das Archiv, ändere den Ergebnis-Status einer Mission auf "Erfolgreich abgeschlossen" und speichere die aktualisierte Version. Gib das finale Archiv aus.
#
# **Bonus:** Schreibe zusätzlich einen kurzen Missionsbericht als Textdatei.

# %%
print()
print('🎉 +400 Cyber Credits: Boss-Quest abgeschlossen!')
print('🏆 Du hast den Daten-Archivar der unendlichen Streams besiegt!')
print('⭐ Titel erhalten: Meister der Daten-Pipelines')
print()
print('🎊 GLÜCKWUNSCH! Du hast Woche 9 gemeistert!')
print('📚 Nächste Woche: Objektorientierung!')

# %% [markdown]
# ---
#
# 🎊 **Glückwunsch!** Du hast alle Boss-Quests dieser Woche gemeistert!
#
# **Als Nächstes:** Woche 10 wartet schon!
