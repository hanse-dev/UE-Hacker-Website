# %% [markdown]
# # 🐛 Debug Quest – 🚀 Week 5 – Functions: The System Protocols
#
# A technician tried to create system protocols, but something went wrong! Find the errors:
# > 💡 **These errors were built in on purpose** – so you can practise debugging!

# %% [markdown]
# ### 🐛 Bug #1
#
# What is wrong? Find and fix the error!

# %%
def system_boot():
print("System starting up...")
return "Ready"

# %% [markdown]
# ### 🐛 Bug #2
#
# What is wrong? Find and fix the error!

# %%
def calculate_warp_speed(warp_factor):
    return warp_factor ** 3

result = calculate_warp_speed
print(f"Warp speed: {result}")

# %% [markdown]
# ### 🐛 Bug #3
#
# What is wrong? Find and fix the error!

# %%
def add_sensor_data(data1, data2):
    total = data1 + data2

total_data = add_sensor_data(100, 250)
print(f"Total sensor data: {total_data}")
