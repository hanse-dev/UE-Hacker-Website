# %% [markdown]
# # 🧙 Woche 5 – Funktionen: Die Zauberformeln der Macht
#
# **XP zu verdienen:** 1000 Punkte
# **Boss:** Der Meister der unendlichen Wiederholungen

# %% [markdown]
# ## 🌟 Die Quest beginnt: Die Bibliothek der Wiederholungen
#
# Willkommen, junger Magier! Du erreichst die **Bibliothek der Wiederholungen** – ein heiliger Ort, an dem Zauber einmal gelernt und ewig wiederverwendet werden können. In dieser Woche lernst du die drei **Arten der Magie-Formeln**:
#
# **Deine Mission:**
# - Meistere die **Funktions-Definition** mit `def`
# - Beherrsche **Parameter** für flexible Zauber
# - Lerne **return-Werte** für magische Ergebnisse
# - Verstehe **Docstrings** für die Magie-Bücher
#
# **Einmal gelernt, für immer genutzt!** Die Macht der Funktionen wartet...

# %% [markdown]
# ## 📚 Zauberformel 1: Die Funktions-Definition - Der magische Vertrag
#
# **Was es ist:** Eine Funktion ist ein wiederverwendbarer Code-Block, den du einmal definierst und immer wieder aufrufen kannst.
#
# **Die Anatomie einer Funktion:**
# ```python
# def funktions_name(parameter1, parameter2):
#     """Kurze Beschreibung des Zaubers"""
#     # Code, der ausgeführt wird
#     return ergebnis  # Optional: Magie-Ergebnis zurückgeben
# ```
#
# **Schritt-für-Schritt-Erklärung:**
# 1. **`def`** - Das magische Wort, das die Funktions-Definition startet
# 2. **`funktions_name`** - Ein eindeutiger Name für deinen Zauber
# 3. **`(parameter)`** - Zutaten, die dein Zauber braucht (optional)
# 4. **`:`** - Beendet die Funktions-Definition
# 5. **`"""Docstring"""`** - Magie-Buch mit Beschreibung (sehr wichtig!)
# 6. **Eingerückter Code** - Der eigentliche Zauber-Code
# 7. **`return`** - Gibt das Ergebnis zurück (optional)
#
# **Warum so nützlich:**
# - 🎯 Code wiederverwenden statt kopieren
# - 🔍 Logik organisieren und strukturieren
# - ⚡ Fehler an einer Stelle beheben
# - 🎲 Komplexe Probleme in kleine Teile zerlegen

# %% [markdown]
# ## 📜 Zauberformel 1b: Funktionen aufrufen - Der Schlüssel zur Magie
#
# Eine Funktion zu *definieren* reicht nicht – sie muss auch *aufgerufen* werden! Das Aufrufen ist ein eigenes Thema mit wichtigen Regeln.
#
# ### Mit und ohne Klammern
#
# **Mit Klammern `funktion()`:** Der Zauber wird ausgeführt! Die Klammern sagen Python: „Führe diese Funktion jetzt aus“.
#
# **Ohne Klammern `funktion`:** Der Zauber wird NICHT ausgeführt! Du referenzierst nur das Funktionsobjekt – nichts passiert.
#
# ### Aufrufen mit Parametern
#
# Beim Aufruf übergibst du **Argumente** in den Klammern: `funktion(argument1, argument2)`. Die Reihenfolge muss stimmen!
#
# ### Vom Argument zur Variable
#
# **Beim Aufruf:** Du übergibst ein **Argument** (z.B. `"Aria"`)
#
# **In der Funktion:** Daraus wird eine **Variable** mit dem Parameternamen (z.B. `name`)
#
# Der Parameter ist ein **Platzhalter**. Beim Aufruf ersetzt Python ihn durch den übergebenen Wert – dieser steht dann als Variable in der Funktion zur Verfügung.

# %%
# Mit vs. ohne Klammern
def gruesse_abenteurer():
    """Begrüßt einen tapferen Abenteurer"""
    print("Willkommen, tapferer Held!")

# MIT Klammern: Funktion wird ausgeführt
print("=== Mit Klammern gruesse_abenteurer() ===")
gruesse_abenteurer()

# OHNE Klammern: Nur Referenz, nichts passiert
print("\n=== Ohne Klammern gruesse_abenteurer ===")
print("Typ:", type(gruesse_abenteurer))
print("(Die Funktion wurde nicht ausgeführt!)")

# %%
# Argument wird zur Variable: Schritt für Schritt
def gruesse_nach_name(name):  # "name" ist der Parameter (Platzhalter)
    """Begrüßt einen Helden mit seinem Namen"""
    # In der Funktion ist "name" jetzt eine Variable mit dem übergebenen Wert!
    print(f"In der Funktion: name = '{name}'")
    print(f"Willkommen, {name}!")

# Beim Aufruf: "Aria" ist das Argument
print("=== Aufruf: gruesse_nach_name('Aria') ===")
gruesse_nach_name("Aria")  # → name wird zu "Aria"

print("\n=== Aufruf: gruesse_nach_name('Thorin') ===")
gruesse_nach_name("Thorin")  # → name wird zu "Thorin"

# %%
# Beispiel 1: Einfache Funktion ohne Parameter
def gruesse_abenteurer():
    """Begrüßt einen tapferen Abenteurer"""
    print("Willkommen, tapferer Held!")
    print("Dein Abenteuer beginnt jetzt!")

# Funktion aufrufen
print("=== Erster Aufruf ===")
gruesse_abenteurer()

print("\n=== Zweiter Aufruf ===")
gruesse_abenteurer()

print("\n=== Was passiert hier? ===")
print("1. def gruesse_abenteurer(): definiert die Funktion")
print("2. gruesse_abenteurer() ruft die Funktion auf")
print("3. Der Code in der Funktion wird jedes Mal ausgeführt")

# %%
# Beispiel 2: Funktion mit einem Parameter
def gruesse_nach_name(name):
    """Begrüßt einen Helden mit seinem Namen"""
    print(f"Willkommen, {name}!")
    print(f"Viel Erfolg auf deiner Reise, {name}!")

# Funktion mit verschiedenen Namen aufrufen
print("=== Verschiedene Helden ===")
gruesse_nach_name("Aria")
gruesse_nach_name("Thorin")
gruesse_nach_name("Luna")

print("\n=== Was passiert hier? ===")
print("1. name ist ein Platzhalter für den übergebenen Wert")
print("2. Jeder Aufruf übergibt einen anderen Namen")
print("3. Die Funktion arbeitet mit dem übergebenen Wert")

# %%
# Beispiel 3: Funktion mit mehreren Parametern
def erstelle_charakter(name, klasse, level):
    """Erstellt einen Charakter mit Name, Klasse und Level"""
    print(f"Charakter erstellt:")
    print(f"  Name: {name}")
    print(f"  Klasse: {klasse}")
    print(f"  Level: {level}")
    print(f"  Status: Bereit für Abenteuer!")

# Verschiedene Charaktere erstellen
print("=== Charakter-Erstellung ===")
erstelle_charakter("Aria", "Magierin", 5)
print()
erstelle_charakter("Thorin", "Krieger", 8)
print()
erstelle_charakter("Luna", "Schurkin", 3)

# %% [markdown]
# ## 🔍 Das Geheimnis von return - Die magische Rückgabe
#
# **return** ist der mächtigste Teil einer Funktion!
#
# **Was return tut:**
# - Beendet die Funktion sofort
# - Gibt einen Wert zurück an den Aufrufer
# - Dieser Wert kann in einer Variable gespeichert werden
#
# **Ohne return:** Funktion macht etwas (Side Effect)
# **Mit return:** Funktion berechnet und gibt Ergebnis zurück

# %%
# 🔍 Übungen mit return

# Beispiel 1: Einfache Berechnung mit return
def berechne_schaden(basis_schaden, multiplikator):
    """Berechnet den Gesamtschaden eines Angriffs"""
    gesamtschaden = basis_schaden * multiplikator
    return gesamtschaden

# Ergebnis in Variable speichern
print("=== Schadensberechnung ===")
schaden1 = berechne_schaden(10, 2)
print(f"Schlag 1: {schaden1} Schaden")

schaden2 = berechne_schaden(15, 3)
print(f"Schlag 2: {schaden2} Schaden")

# Ergebnis direkt verwenden
print(f"Kritischer Treffer: {berechne_schaden(20, 5)} Schaden")

# %%
# Beispiel 2: Funktion mit bedingtem return
def pruefe_level(level):
    """Prüft, ob ein Charakter für eine Quest bereit ist"""
    if level >= 10:
        return "Bereit für die Quest!"
    else:
        return f"Noch {10 - level} Level needed"

print("=== Level-Prüfung ===")
status1 = pruefe_level(5)
print(f"Level 5: {status1}")

status2 = pruefe_level(12)
print(f"Level 12: {status2}")

status3 = pruefe_level(8)
print(f"Level 8: {status3}")

# %%
# Beispiel 3: Funktion ohne expliziten return (None)
def zeige_inventar():
    """Zeigt das Inventar (gibt nichts zurück)"""
    print("Dein Inventar:")
    print("  - Schwert")
    print("  - Schild")
    print("  - Heiltrank")
    # Kein return - gibt automatisch None zurück

print("=== Inventar anzeigen ===")
ergebnis = zeige_inventar()
print(f"Rückgabewert: {ergebnis}")
print("Funktionen ohne return geben immer None zurück!")

# %% [markdown]
# ## 📦 Zauberformel 2: Docstrings - Die Magie-Bücher
#
# **Was es ist:** Docstrings sind Dokumentations-Strings, die erklären, was eine Funktion tut.
#
# **Warum extrem wichtig:**
# - 📖 Andere (und du später) verstehen deine Funktion
# - 🔍 IDEs zeigen dir Hilfe beim Aufruf
# - 🤖 Tools können automatisch Dokumentation erstellen
# - ⭐ Zeichen von professionellem Code
#
# **Die drei Arten von Docstrings:**
# 1. **Einzeilig:** `"""Kurze Beschreibung"""`
# 2. **Mehrzeilig:** `"""Kurze Beschreibung\n\nDetails..."""`
# 3. **Vollständig:** `"""Beschreibung\n\nArgs:\nReturns:\n"""`

# %%
# Beispiel 1: Verschiedene Docstring-Stile
def einfache_funktion():
    """Dies ist ein einzeiliger Docstring."""
    return "Einfach"

def detaillierte_funktion(name, level):
    """Erstellt eine Charakter-Beschreibung.
    
    Args:
        name (str): Der Name des Charakters
        level (int): Das Level des Charakters
    
    Returns:
        str: Eine formatierte Beschreibung
    """
    return f"{name} ist ein Level {level} Charakter."

# Docstring aufrufen (so funktioniert es!)
print("=== Docstring-Beispiele ===")
print(f"Einfacher Docstring: {einfache_funktion.__doc__}")
print()
print(f"Detaillierter Docstring: {detaillierte_funktion.__doc__}")

# %%
# Beispiel 2: Hilfe-Funktion nutzen
print("=== Hilfe für Funktionen ===")
help(detaillierte_funktion)

# %% [markdown]
# ## ✨ Zauberformel 3: Namenskonventionen - Die Regeln der Magie
#
# **Gute Funktionsnamen sind entscheidend!**
#
# **Die Regeln:**
# - **Kleinbuchstaben** mit Unterstrichen: `berechne_schaden`
# - **Beschreibend**: Was die Funktion **tut** (Verb)
# - **Kurz aber klar**: `get_name()` nicht `retrieve_user_data_from_database()`
# - **Keine Verben im Namen**: `name_get()` falsch, `get_name()` richtig
#
# **Beispiele:**
# - ✅ `berechne_schaden()`
# - ✅ `erstelle_charakter()`
# - ✅ `pruefe_level()`
# - ❌ `BerechneSchaden()` (CamelCase)
# - ❌ `berechne_das_schaden()` (zu lang)
# - ❌ `schaden_berechnen()` (Substantiv zuerst)

# %%
# ✨ Beispiele für gute und schlechte Namen

# ✅ Gute Namen (klar und beschreibend)
def berechne_heilung(basis_heilung, multiplikator):
    """Berechnet die Heilungsmenge."""
    return basis_heilung * multiplikator

def finde_max_level(level_liste):
    """Findet das höchste Level in einer Liste."""
    return max(level_liste)

def ist_quest_verfuegbar(level, benoetigt_level):
    """Prüft, ob eine Quest verfügbar ist."""
    return level >= benoetigt_level

# ❌ Schlechte Namen (unklar oder falsche Konvention)
# def berechneHeilung():  # CamelCase
# def bs(b, m):  # Zu kurz, nicht beschreibend
# def healing_calculation():  # Substantiv zuerst

print("=== Gute Funktionsnamen in Aktion ===")
heilung = berechne_heilung(10, 2)
print(f"Heilung: {heilung}")

levels = [5, 8, 12, 3, 15]
max_level = finde_max_level(levels)
print(f"Höchstes Level: {max_level}")

quest_ok = ist_quest_verfuegbar(8, 10)
print(f"Quest verfügbar: {quest_ok}")

# %% [markdown]
# ## 🛡️ Zauberformel 4: try/except – Fehler abfangen
#
# Manchmal kann ein Programm nicht wissen, ob eine Berechnung klappt. `try/except` lässt das Programm **sicher weiterlaufen**, auch wenn etwas schiefgeht.
#
# ```python
# try:
#     # Code, der einen Fehler auslösen könnte
#     ergebnis = int(input("Zahl eingeben: "))
# except ValueError:
#     # Was passiert, wenn der Fehler auftritt
#     print("Das war keine gültige Zahl!")
# ```
#
# **Häufige Fehlertypen:**
# - `ValueError` – falscher Wert (z.B. `int("abc")`)
# - `TypeError` – falscher Typ (z.B. Zahl + Text ohne `str()`)
# - `ZeroDivisionError` – Division durch null
# - `NameError` – Variable existiert nicht

# %%
# try/except in einer Funktion
def teile_sicher(zahl, teiler):
    """Teilt zwei Zahlen – gibt None zurück wenn der Teiler 0 ist."""
    try:
        return zahl / teiler
    except ZeroDivisionError:
        print("Fehler: Kann nicht durch null teilen!")
        return None

print(teile_sicher(10, 2))   # 5.0
print(teile_sicher(10, 0))   # Fehlermeldung + None

# try/except mit Typumwandlung
def text_zu_zahl(text):
    """Wandelt Text in Zahl um – gibt None zurück bei ungültigem Wert."""
    try:
        return int(text)
    except ValueError:
        print(f"\"{text}\" ist keine gültige Zahl.")
        return None

print(text_zu_zahl("42"))    # 42
print(text_zu_zahl("abc"))  # Fehlermeldung + None

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein Lehrling hat versucht, Zauberformeln zu erstellen, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1

def gruesse_held():
print("Willkommen, Held!")
return "Begrüßt"

# %%
# 🐛 Bug #2

def berechne_schaden(staerke):
    return staerke * 2

result = berechne_schaden

# %%
# 🐛 Bug #3

def addiere(a, b):
    ergebnis = a + b

summe = addiere(5, 3)
print(f"Summe: {summe}")

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Zauber-Lehrling
#
# **Belohnung:** 300 XP + Zauberstab
#
# In der Bibliothek der Wiederholungen lernst du deine ersten wiederverwendbaren Zauberformeln.
#
# **Deine Aufgaben:**
#
# 1. **Begrüßungszauber sprechen**
#    - Erstelle eine Funktion `begruesse_magier()`, die zwei Begrüßungszeilen für den Magier ausgibt
#    - Rufe die Funktion mindestens zweimal auf
#    - Schreibe einen kurzen Docstring, der erklärt, was die Funktion macht
#
# 2. **Mana-Berechnung als Zauber**
#    - Erstelle eine Funktion `berechne_mana(level, basis_mana)`, die `level * basis_mana` berechnet
#    - Gib den Wert mit `return` zurück
#    - Rufe die Funktion mit verschiedenen Werten auf und speichere die Ergebnisse in Variablen
#
# 3. **Zauber-Verfügbarkeit prüfen**
#    - Schreibe eine Funktion `ist_zauber_moeglich(mana_kosten, aktuelles_mana)`, die `True` zurückgibt, wenn genug Mana vorhanden ist, sonst `False`
#    - Nutze die Rückgabewerte in if-Bedingungen und gib passende Nachrichten aus
#
# 4. **Formeln kombinieren**
#    - Erstelle einen kleinen Haupt-Block, der:
#      - den Magier begrüßt,
#      - das verfügbare Mana berechnet und
#      - prüft, ob ein Zauber gewirkt werden kann
#    - Gib am Ende eine kurze Zusammenfassung aus
#
# **Beispiel-Code zum Starten:**
# ```python
# def begruesse_magier():
#     """Begrüßt den Magier vor dem Zaubertraining."""
#     print("Willkommen in der Bibliothek der Wiederholungen!")
#     print("Heute lernst du mächtige Zauberformeln.")
#
# begruesse_magier()
# ```
#
# **Bonus-Challenge:**
# - Erstelle eine Funktion `generiere_zauber()`, die zufällig einen Zauber (z.B. "Feuerball", "Heilung", "Schild") zurückgibt.
#
# **Erwartete Ausgabe:**
# ```
# Willkommen in der Bibliothek der Wiederholungen!
# Heute lernst du mächtige Zauberformeln.
# ...
# Berechnetes Mana: 120
# Zauber möglich: True
# ✅ Du kannst den Zauber wirken!
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Charakter-Erschaffer
#
# **Belohnung:** 400 XP + Schöpfungstafel
#
# Du erschaffst Helden für dein Abenteuer und baust ein kleines System zur Charaktergenerierung.
#
# **Deine Aufgaben:**
#
# 1. **Charakter-Grunddaten erzeugen**
#    - Schreibe eine Funktion `erstelle_charakter(name, klasse, level)`, die ein Dictionary mit diesen Informationen zurückgibt
#    - Ergänze einen Docstring, der Parameter und Rückgabewert beschreibt
#    - Erzeuge mindestens zwei verschiedene Charaktere
#
# 2. **Lebenspunkte berechnen**
#    - Erstelle eine Funktion `berechne_leben(level, klasse)`, die anhand von Level und Klasse Lebenspunkte berechnet (z.B. Magier weniger, Krieger mehr)
#    - Gib die Lebenspunkte mit `return` zurück
#
# 3. **Ausrüstung generieren**
#    - Schreibe eine Funktion `generiere_ausruestung(klasse)`, die eine Liste passender Ausrüstungsgegenstände zurückgibt
#    - Nutze verschiedene Sets für unterschiedliche Klassen
#
# 4. **Charakterbogen anzeigen**
#    - Erstelle eine Funktion `zeige_charakterbogen(charakter, leben, ausruestung)`, die einen formatierten Bogen ausgibt
#    - Nutze dafür die Daten aus den anderen Funktionen
#
# **Beispiel-Code zum Starten:**
# ```python
# def erstelle_charakter(name, klasse, level):
#     """Erstellt einen Basis-Charakter als Dictionary."""
#     return {
#         "name": name,
#         "klasse": klasse,
#         "level": level,
#     }
#
# held = erstelle_charakter("Aria", "Magierin", 5)
# print(held)
# ```
#
# **Bonus-Challenge:**
# - Ergänze zufällige Stats wie Stärke oder Intelligenz und füge sie dem Charakter-Dictionary hinzu.
#
# **Erwartete Ausgabe:**
# ```
# Charakter Aria (Magierin), Level 5
# Lebenspunkte: 45
# Ausrüstung: Stab, Robe, Zauberbuch
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Die Quest-Maschine
#
# **Belohnung:** 500 XP + Quest-Buch
#
# Du entwickelst ein kleines System, das dynamische Quests mit Schwierigkeit, Belohnung und Voraussetzungen verwaltet.
#
# **Deine Aufgaben:**
#
# 1. **Quest-Daten erzeugen**
#    - Erstelle eine Funktion `erstelle_quest(name, typ, schwierigkeit)`, die ein Dictionary mit diesen Daten zurückgibt
#    - Erzeuge mehrere Quests mit unterschiedlichen Typen (z.B. "Kampf", "Erkundung", "Lieferung")
#
# 2. **Belohnung berechnen**
#    - Schreibe eine Funktion `berechne_belohnung(quest)`, die abhängig von Schwierigkeit und Typ XP und Gold berechnet
#    - Gib ein Dictionary oder Tuple mit den Belohnungswerten zurück
#
# 3. **Voraussetzungen prüfen**
#    - Erstelle eine Funktion `erfuellt_voraussetzungen(charakter_level, quest_schwierigkeit)`, die `True` oder `False` zurückgibt
#    - Nutze einfache Regeln, z.B. Mindestlevel für höhere Schwierigkeiten
#
# 4. **Quest-Ablauf anzeigen**
#    - Schreibe eine Funktion `zeige_quest_info(quest, belohnung)`, die eine schöne Zusammenfassung ausgibt
#    - Nutze alle wichtigen Daten: Name, Typ, Schwierigkeit, Belohnung
#
# **Beispiel-Code zum Starten:**
# ```python
# def erstelle_quest(name, typ, schwierigkeit):
#     """Erstellt eine Quest mit Name, Typ und Schwierigkeit."""
#     return {
#         "name": name,
#         "typ": typ,
#         "schwierigkeit": schwierigkeit,
#     }
#
# quest = erstelle_quest("Der verlorene Schlüssel", "Erkundung", 2)
# print(quest)
# ```
#
# **Bonus-Challenge:**
# - Ergänze eine kleine Liste von Quests und wähle zufällig eine aus, die gestartet wird.
#
# **Erwartete Ausgabe:**
# ```
# Quest: Der verlorene Schlüssel (Typ: Erkundung, Schwierigkeit: 2)
# Belohnung: 200 XP und 50 Gold
# Voraussetzungen erfüllt: True
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten des Zaubermeisters (Reflexion)
#
# Bevor du weiterzauberst, denke über diese Fragen nach:
#
# 1. **Warum sind Funktionen besser als kopierter Code?**
#
# 2. **Wann sollte man return verwenden und wann nicht?**
#
# 3. **Warum sind gute Funktionsnamen so wichtig?**
#
# Diskutiere deine Gedanken mit anderen Magiern!

# %% [markdown]
# ### 📖 Zauber-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **def** 🧙: Funktions-Definition starten
# - **parameter** 📦: Werte, die an Funktion übergeben werden
# - **return** 🔄: Wert zurückgeben
# - **docstring** 📖: Funktions-Dokumentation
# - **argument** 🎯: Tatsächlich übergebener Wert
# - **call** 📞: Funktion aufrufen
# - **scope** 🌍: Gültigkeitsbereich von Variablen
# - **side effect** ⚡: Veränderungen außerhalb der Funktion
# - **pure function** 🌟: Funktion ohne Seiteneffekte
# - **recursion** 🔄: Funktion ruft sich selbst auf

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Hake ab, was du schon kannst:
#
# - ☐ Funktionen mit `def` und Parametern definieren
# - ☐ `return`-Werte nutzen
# - ☐ Docstrings schreiben
# - ☐ Namenskonventionen beachten (`snake_case`)
# - ☐ Fehler mit `try/except` abfangen

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Magisch!** Du hast die Zauberformeln der Macht gemeistert!
#
# **Das hast du gelernt:**
# - Funktionen definieren und wiederverwenden
# - Parameter für flexible Zauber nutzen
# - return-Werte für magische Ergebnisse
# - Docstrings für verständlichen Code
# - Namenskonventionen für sauberen Code
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🎮 **Spiele:** Charakter-Systeme, Spiel-Logik, UI-Funktionen
# - 📱 **Apps:** Datenverarbeitung, API-Aufrufe, Berechnungen
# - 🌐 **Websites:** Formular-Validierung, Datenbank-Operationen
# - 🤖 **KI-Systeme:** Daten-Preprocessing, Modell-Funktionen
# - 📊 **Wissenschaft:** Berechnungen, Simulationen, Analyse
#
# **Als Nächstes:** In Woche 6 lernst du **Listen**!

# %% [markdown]
# ## 🐉 Boss-Kampf: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Quests sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 XP + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Der Zauber-Generator
#
# **Belohnung:** 500 XP + Meister-Zauber
#
# Baue ein System, das automatisch verschiedene Zauber mit Element, Stufe und Macht erzeugt und in einem Zauberbuch speichert.
#
# **Deine Aufgaben:**
#
# 1. **Zaubernamen erzeugen**
#    - Schreibe eine Funktion `generiere_zauber_name(element_typ, stufe)`, die aus Element und Stufe einen Namen bildet (z.B. "FEUER-L3")
#    - Gib den Namen als String zurück
#
# 2. **Zaubermacht berechnen**
#    - Erstelle eine Funktion `berechne_macht(komplexitaet, element_typ)`, die einen Wert zwischen 0 und 100 zurückgibt
#    - Nutze unterschiedliche Faktoren je nach `element_typ` (z.B. Feuer stärker, Wasser ausgeglichen, Erde defensiv)
#
# 3. **Zauber-Daten erstellen**
#    - Schreibe eine Funktion `erstelle_zauber(element_typ, stufe, komplexitaet)`, die ein Dictionary mit Name, Element, Stufe und Macht zurückgibt
#    - Verwende dafür deine beiden vorherigen Funktionen
#
# 4. **Zauberbuch verwalten**
#    - Erstelle eine Liste `zauberbuch`
#    - Schreibe eine Funktion `speichere_zauber(buch, zauber)`, die den Zauber hinzufügt
#    - Schreibe eine Funktion `finde_zauber(buch, such_element)`, die alle Zauber eines bestimmten Elements zurückgibt
#
# 5. **Generator nutzen**
#    - Erzeuge im Hauptteil mindestens 5 unterschiedliche Zauber
#    - Speichere sie im Zauberbuch und gib eine kleine Statistik (Anzahl, durchschnittliche Macht) aus
#
# **Beispiel-Code zum Starten:**
# ```python
# def generiere_zauber_name(element_typ, stufe):
#     """Erzeugt einen Zaubernamen aus Element und Stufe."""
#     return f"{element_typ.upper()}-L{stufe}"
#
# zauberbuch = []
#
# # Hier fügst du weitere Funktionen hinzu und generierst Zauber
# ```
#
# **Bonus-Challenge:**
# - Füge eine Funktion hinzu, die alle Zauber nach Macht sortiert ausgibt.
#
# **Erwartete Ausgabe:**
# ```
# Erzeugter Zauber: FEUER-L3 (Macht 82)
# ...
# Anzahl Zauber: 5
# Durchschnittliche Macht: 76.4
# Gefundene FEUER-Zauber: 2
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Der Guilden-Manager
#
# **Belohnung:** 600 XP + Gildenmeister-Titel
#
# Verwalte eine Magiergilde mit Abteilungen, Mana und Magiern.
#
# **Deine Aufgaben:**
#
# 1. **Abteilungen erzeugen**
#    - Erstelle eine Funktion `erstelle_abteilung(abteilung_id, groesse)`, die ein Dictionary mit ID, Größe und aktuellem Mana zurückgibt
#    - Lege eine Liste mit mehreren Abteilungen an
#
# 2. **Mana verteilen**
#    - Schreibe eine Funktion `verteile_mana(abteilungen, totales_mana)`, die Mana proportional zur Größe auf die Abteilungen verteilt
#    - Aktualisiere dazu die Mana-Einträge in den Abteilungs-Dictionaries
#
# 3. **Magier-Schichten planen**
#    - Erstelle eine Funktion `plane_magier_schichten(anzahl_magier, schichten)`, die eine gleichmäßige Verteilung auf alle Schichten berechnet
#    - Gib eine Liste mit Magiern pro Schicht zurück
#
# 4. **Gildenbericht erzeugen**
#    - Schreibe eine Funktion `erzeuge_gildenbericht(abteilungen, mana, magier)`, die eine Übersicht als Text zurückgibt
#    - Nutze Informationen aus den Abteilungen und den Parametern
#
# **Beispiel-Code zum Starten:**
# ```python
# gilde = {
#     "abteilungen": [],
#     "mana": 10000,
#     "magier": 500,
# }
#
# # Hier kannst du Abteilungen erzeugen und Funktionen aufrufen
# ```
#
# **Bonus-Challenge:**
# - Ergänze eine einfache Notfall-Funktion, die bei zu wenig Mana in einer Abteilung eine Warnung zurückgibt.
#
# **Erwartete Ausgabe:**
# ```
# Erzeugte Abteilungen: 3
# Verteiltes Mana: [3000, 4000, 3000]
# Schichtplanung: [170, 170, 160]
# Gildenbericht: Alle Abteilungen versorgt, Mana verteilt, Magier eingeteilt.
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Die Kampf-Simulation
#
# **Belohnung:** 400 XP + Kampf-Simulator
#
# Simuliere einen Kampf zwischen zwei Gruppen (Helden und Monster) mit mehreren Runden.
#
# **Deine Aufgaben:**
#
# 1. **Kampf initialisieren**
#    - Erstelle eine Funktion `initialisiere_kampf(gruppe1, gruppe2)`, die einen Startzustand mit beiden Gruppen (Name, Rüstung, Leben) zurückgibt
#
# 2. **Schaden berechnen**
#    - Schreibe eine Funktion `berechne_schaden(basis_schaden, ruestung_staerke)`, die den tatsächlichen Schaden (z.B. `basis_schaden - ruestung_staerke/10`) zurückgibt
#
# 3. **Kampfrunde ausführen**
#    - Erstelle eine Funktion `fuehre_runde_aus(status)`, die:
#      - zufällig eine angreifende Gruppe wählt,
#      - Schaden berechnet und
#      - Rüstung/Leben der verteidigenden Gruppe aktualisiert
#    - Gib den aktualisierten Status zurück
#
# 4. **Kampf steuern**
#    - Schreibe eine Funktion `starte_kampf(gruppe_a, gruppe_b, max_runden)`, die mehrere Runden durchführt, bis eine Gruppe besiegt ist oder `max_runden` erreicht sind
#    - Gib am Ende Sieger, Verlierer und die verbleibenden Lebenspunkte aus
#
# **Beispiel-Code zum Starten:**
# ```python
# gruppe_a = {"name": "Helden", "ruestung": 100, "leben": 100}
# gruppe_b = {"name": "Monster", "ruestung": 100, "leben": 100}
#
# print("=== KAMPF-SIMULATION ===")
# # Hier rufst du deine Funktionen auf
# ```
#
# **Bonus-Challenge:**
# - Ergänze Spezialzauber, die mit einer kleinen Wahrscheinlichkeit doppelten Schaden verursachen.
#
# **Erwartete Ausgabe:**
# ```
# === KAMPF-SIMULATION ===
# Runde 1: Helden greifen Monster an – 15 Schaden.
# Runde 2: Monster greifen Helden an – 8 Schaden.
# ...
# Sieger: Helden mit 23 Leben.
# ```

# %%
# 🐉 Deine Lösung hier:

print()
print("🎉 +400 XP: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Meister der unendlichen Wiederholungen besiegt!")
print("⭐ Titel erhalten: Meister der Zauberformeln")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 5 gemeistert!")
print("📚 Nächste Woche: Listen (Listen erstellen, bearbeiten, durchsuchen)!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen:

# %%
# ✅ Lösung Bug #1: Falsche Einrückung

# Problem: Code nach def nicht eingerückt
def gruesse_held():
    print("Willkommen, Held!")
    return "Begrüßt"  # Das fehlte!

# %%
# ✅ Lösung Bug #2: Falscher Funktionsaufruf

# Problem: Klammern vergessen
def berechne_schaden(staerke):
    return staerke * 2

# Korrekter Aufruf:
result = berechne_schaden(10)  # Klammern hinzugefügt!

# %%
# ✅ Lösung Bug #3: Vergessenes return

# Problem: return vergessen
def addiere(a, b):
    ergebnis = a + b
    return ergebnis  # Das fehlte!

summe = addiere(5, 3)
print(f"Summe: {summe}")  # Jetzt gibt es 8 aus!
