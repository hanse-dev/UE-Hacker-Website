# %% [markdown]
# # 🏰 Week 11 – Advanced OOP: The Magic Evolution!
#
# Welcome, Master of the Arts! You are entering the **Master Guilds of Pyralia** – a place full of ancient knowledge and powerful magical techniques. This week you will master the advanced concepts:
#
# **Your Mission:**
# - Use inheritance for powerful magical bloodlines
# - Polymorphism *(= same method that works differently depending on the class)* for flexible spell effectiveness
# - Magic Methods for supernatural abilities
# - Design Patterns for masterful architecture
#
# **Get started!** Your path to Archmage begins!

# %% [markdown]
# ## Spell Formula 1: Inheritance
#
# **What it is:** Inheritance lets you derive one class from another. The child class gets all the abilities of the parent class and can add its own.
#
# **Important:** Use `super()` to call the parent methods!

# %%
# Example 1: Simple inheritance
class LivingBeing:
    def __init__(self, name):
        self.name = name
    
    def breathe(self):
        print(f"{self.name} breathes")

class Human(LivingBeing):
    def speak(self):
        print(f"{self.name} speaks")

# Example 2: Overriding methods
class Warrior(LivingBeing):
    def breathe(self):
        print(f"{self.name} breathes like a fighter!")
    
    def fight(self):
        print(f"{self.name} draws their sword!")

# Example 3: Using super()
class Mage(LivingBeing):
    def __init__(self, name, mana):
        super().__init__(name)
        self.mana = mana
    
    def cast_spell(self):
        print(f"{self.name} casts a spell with {self.mana} Mana!")

# %% [markdown]
# ## Spell Formula 2
#
# **What it is:** Polymorphism means "many forms". Objects of different classes can respond differently to the same message.
#
# **Important:** Duck Typing - "If it walks like a duck and quacks like a duck, it's a duck!"

# %%
# Example 1: Method polymorphism
class Swordsman:
    def attack(self):
        print("Strike with the sword! ⚔️")

class Mage:
    def attack(self):
        print("Fireball thrown! 🔥")

class Archer:
    def attack(self):
        print("Arrow fired! 🏹")

# Example 2: Polymorphic function
def battle(character):
    character.attack()

# Example 3: Operator polymorphism
class GoldCoin:
    def __init__(self, value):
        self.value = value
    
    def __add__(self, other):
        return GoldCoin(self.value + other.value)
    
    def __str__(self):
        return f"{self.value} Gold Coins"

# %% [markdown]
# ## Spell Formula 3
#
# **What it is:** Magic Methods (dunders) are special methods with __ at the beginning and end. They give your classes supernatural abilities.
#
# **Important:** The most important Magic Methods are __init__, __str__, __add__, __len__!

# %%
# Example 1: __str__ and __repr__
class MagicPotion:
    def __init__(self, name, colour):
        self.name = name
        self.colour = colour
    
    def __str__(self):
        return f"🧪 {self.name} ({self.colour})"
    
    def __repr__(self):
        return f"MagicPotion('{self.name}', '{self.colour}')"

# Example 2: __len__ and __getitem__
class Inventory:
    def __init__(self):
        self.items = []
    
    def __len__(self):
        return len(self.items)
    
    def __getitem__(self, index):
        return self.items[index]
    
    def add(self, item):
        self.items.append(item)

# Example 3: __eq__ and __lt__
class Hero:
    def __init__(self, name, strength):
        self.name = name
        self.strength = strength
    
    def __eq__(self, other):
        return self.strength == other.strength
    
    def __lt__(self, other):
        return self.strength < other.strength
    
    def __str__(self):
        return f"{self.name} (Strength: {self.strength})"
