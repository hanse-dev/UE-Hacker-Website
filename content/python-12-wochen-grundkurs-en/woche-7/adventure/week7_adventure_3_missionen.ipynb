# %% [markdown]
# # ⭐ Missions – ⚔️ Week 7 – Modules and Libraries: The Magical Toolboxes!
#
# The time has come to prove your knowledge in real challenges!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: The Spell Importer
#
# **Reward:** 300 XP + Magic Bag
#
# In the library of Pyralia you learn how to load spell libraries (modules) and work with aliases.
#
# **Step 1 – Import libraries:**
# Load the modules `math`, `random` and `time` with suitable aliases (e.g. `import math as m`) and output one constant or function from each module (e.g. `math.pi`, `random.randint(1, 10)`)
#
# **Step 2 – Wait spell:**
# Create a small function or script that generates a random number of seconds (1–3) with `random` and uses `time.sleep()` and output a short message before and after the wait (e.g. "Spell loading …")
#
# **Step 3 – Flight path spell:**
# Use `math.sin` and `math.pi` to calculate a height or value for an angle (e.g. 90° in radians) and output the result in a formatted way
#
# **Step 4 – Group generator:**
# Create a name list with 3–5 hero names and use `random.choice()` to pick a random name and output the selected name
#
# **Bonus:** Add another spell using the `datetime` module (e.g. show the current time).

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: The Calculation Spell
#
# **Reward:** 400 XP + Crystal Ball
#
# You use the math module for magical circle calculations, angle conversion, and square roots.
#
# **Step 1 – Circle spell:**
# Write a function or script that calculates the circumference and area for a radius (e.g. a magical circle) using `math.pi` and output the radius, circumference, and area in a formatted way
#
# **Step 2 – Random numbers and sum:**
# Generate five random numbers with `random.randint(1, 100)` (e.g. for mana values) and store them in a list and calculate the sum and output the numbers and the sum
#
# **Step 3 – Angle conversion:**
# Convert 90°, 180° and 270° to radians using `math.radians()` and output the degrees and radians for each angle
#
# **Step 4 – Square roots:**
# Calculate the square roots of 4, 9, 16 and 25 with `math.sqrt()` and output the results clearly
#
# **Bonus:** Add trigonometric spells (e.g. sin, cos for 45°).

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: The Random Spell
#
# **Reward:** 500 XP + Guild Master Certificate
#
# You build a small random system with realms, weather and mana consumption.
#
# **Step 1 – Realm selection:**
# Create a list with 5–6 realm names and use `random.choice()` to pick a random realm and output the list and the chosen realm
#
# **Step 2 – Weather simulation:**
# Generate three temperature values with `random.uniform(-50, 50)` (e.g. for different regions) and round them to one decimal place and output the temperatures with a short description
#
# **Step 3 – Magic consumption:**
# Simulate 3 wizards each with a random mana consumption between 50 and 150 (using `random.randint` or `random.uniform`) and output the wizard name and mana and calculate the total consumption
#
# **Step 4 – Hero generator:**
# Create 3 hero names with a corresponding random strength (1–10) and store them (e.g. as a list of tuples) and output all heroes with their strength
#
#
# > 💡 **Tip:** You decide how to implement this – there is no single correct way!
# **Bonus:** Add a variable with a normal distribution (e.g. `random.gauss(100, 20)` for mana).

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### 🎯 Learning Goals – Have you achieved them?
#
# Check for yourself whether you have mastered these skills:
#
# - ☐ Load libraries with import
# - ☐ Use nicknames for libraries
# - ☐ Import specific spells
# - ☐ Use the math library for calculations
# - ☐ Use the random library for random numbers
# - ☐ Use libraries in your own programs
#
# If you can tick all the boxes – congratulations! You are ready for the Boss Quests!
