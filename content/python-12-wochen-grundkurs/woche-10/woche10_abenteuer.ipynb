# %% [markdown]
# # 🏰 Woche 10 – OOP Grundlagen: Die magischen Blaupausen!
#
# **XP zu verdienen:** 1000 Punkte
# **Boss:** Der Meister der Handwerkszünfte

# %% [markdown]
# ## 🌟 Die Quest beginnt: Willkommen in den Handwerkszünften von Pyralia!
#
# Willkommen, junger Handwerker! Du betrittst die **Handwerkszünfte von Pyralia** – ein Ort voller magischer Blaupausen und wundervoller Schöpfungen. In dieser Woche lernst du die drei wichtigsten Grundlagen:
#
# **Deine Mission:**
# - Klassen als magische Blaupausen erstellen
# - Objekte als lebendige Kreaturen erschaffen
# - Methoden als magische Fähigkeiten verleihen
#
# **Leg los!** Deine erste magische Schöpfung wartet schon...

# %% [markdown]
# ## 📚 Zauberformel 1: Klassen erstellen
#
# **Was es ist:** Eine Klasse ist wie eine magische Blaupause für Objekte. Sie beschreibt, welche Eigenschaften und Fähigkeiten etwas haben soll.
#
# **Warum nützlich:**
# - Du kannst viele ähnliche Objekte schnell erstellen
# - Dein Code wird ordentlich und strukturiert
# - Du kannst Logik direkt in den Objekten speichern
#
# **Wichtig:** Klassennamen beginnen immer mit einem Großbuchstaben!

# %%
# Beispiel 1: Erste Klasse erstellen
class Schwert:
    pass

# Beispiel 2: Klasse mit Attributen
class Magier:
    name = "Unbekannt"
    mana = 100

# Beispiel 3: Klasse mit Methode
class Drache:
    def brüllen(self):
        print("ROAR! 🐉")

# %% [markdown]
# ## 📦 Zauberformel 2: Objekte instanziieren
#
# **Was es ist:** Ein Objekt ist eine konkrete Instanz einer Klasse - wie ein einzelnes Schwert, das aus der Blaupause geschmiedet wurde.
#
# **Warum nützlich:**
# - Jedes Objekt hat eigene Werte
# - Du kannst viele unabhängige Objekte erstellen
# - Objekte können miteinander interagieren
#
# **Wichtig:** Jedes Objekt ist einzigartig, auch wenn es von derselben Klasse stammt!

# %%
# Beispiel 1: Objekte erstellen
mein_schwert = Schwert()
dein_schwert = Schwert()

# Beispiel 2: Attribute setzen
gandalf = Magier()
gandalf.name = "Gandalf"
gandalf.mana = 200

# Beispiel 3: Mehrere Objekte
smaug = Drache()
falcor = Drache()
smaug.brüllen()

# %% [markdown]
# ## ✨ Zauberformel 3: Der Konstruktor (__init__)
#
# **Was es ist:** Der Konstruktor ist eine spezielle Methode, die automatisch ausgeführt wird, wenn ein Objekt erstellt wird.
#
# **Warum nützlich:**
# - Objekte werden direkt mit richtigen Werten erstellt
# - Du kannst Startwerte übergeben
# - Initialisierungslogik wird zentralisiert
#
# **Wichtig:** __init__ hat immer `self` als ersten Parameter! (Warum `self` nötig ist, erfährst du in der nächsten Sektion.)

# %%
# Beispiel 1: Einfacher Konstruktor
class Held:
    def __init__(self, name):
        self.name = name

# Beispiel 2: Konstruktor mit mehreren Werten
class Zaubertrank:
    def __init__(self, name, farbe, staerke):
        self.name = name
        self.farbe = farbe
        self.staerke = staerke

# Beispiel 3: Konstruktor mit Standardwerten
class Goblin:
    def __init__(self, name="Grog", hp=10):
        self.name = name
        self.hp = hp

# %% [markdown]
# ## 🪞 Warum `self`? – Der Schlüssel zu deinen Objekten
#
# **Was ist `self`?** `self` ist die Referenz auf **das konkrete Objekt**, das gerade angesprochen wird. Wenn du `smaug.brüllen()` aufrufst, ist `self` in der Methode genau das Objekt `smaug`.
#
# **Warum brauchen wir es überhaupt?** Eine Klasse kann viele Objekte erzeugen. Python muss wissen: *Welches* dieser Objekte ist gemeint? Bei 10 Drachen muss die Methode wissen: „Ich arbeite für DIESEN Drachen hier.“
#
# **Im Konstruktor `__init__`:**
# - `self.name = name` bedeutet: **Speichere** den übergebenen `name` auf DIESEM Objekt.
# - Ohne `self` würde Python nicht wissen, wo die Variable hingehört – sie würde nur lokal existieren und nach dem Aufruf verschwinden.
#
# **In Methoden:**
# - `self.name` bedeutet: **Lese den Namen** von DIESEM Objekt.
# - Ohne `self` könnte die Methode nicht auf die Attribute des Objekts zugreifen – sie würde nicht wissen, ob es Smaug, Falcor oder ein anderer Drache ist.
#
# **So funktioniert der Aufruf im Hintergrund:**
# - `smaug.brüllen()` wird von Python zu `Drache.brüllen(smaug)` übersetzt.
# - Das erste Argument ist immer das Objekt selbst – deshalb heißt der Parameter `self`.

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein junger Magier hat versucht, seine ersten Klassen zu erstellen, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1: Klasse ohne Großbuchstaben

class schwertkämpfer:
    name = "Held"

kämpfer = schwertkämpfer()
print(kämpfer.name)

# %%
# 🐛 Bug #2: Falscher Konstruktor

class Magier:
    def __init(name, mana):
        name = name
        mana = mana

merlin = Magier("Merlin", 150)
print(merlin.name)

# %%
# 🐛 Bug #3: Methode ohne self

class Drache:
    def __init__(self, name):
        self.name = name
    
    def vorstellen():
        print(f"Ich bin {self.name}!")

drache = Drache("Smaug")
drache.vorstellen()

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Erstelle deine erste Waffenklasse
#
# **Belohnung:** 300 XP + Magischer Schmiedehammer
#
# Der Waffenschmied braucht eine Blaupause für alle Schwerter im Königreich!
#
# **Deine Aufgaben:**
#
# 1. **Klasse Schwert anlegen**
#    - Erstelle mit `class Schwert:` eine Klasse
#    - Füge im Konstruktor `__init__(self, name, schaden, material)` die Attribute hinzu (z.B. `self.name = name`)
#
# 2. **Objekt erstellen**
#    - Erstelle ein Objekt: `excalibur = Schwert("Excalibur", 50, "Stahl")`
#    - Gib alle Eigenschaften mit `print()` aus
#
# 3. **Zweites Schwert**
#    - Erstelle ein zweites Schwert mit anderen Werten und gib seine Eigenschaften aus
#
# **Beispiel-Code zum Starten:**
# ```python
# class Schwert:
#     def __init__(self, name, schaden, material):
#         self.name = name
#         self.schaden = schaden
#         self.material = material
#
# excalibur = Schwert("Excalibur", 50, "Stahl")
# print(f"Name: {excalibur.name}, Schaden: {excalibur.schaden}, Material: {excalibur.material}")
# ```
#
# **Bonus-Challenge:** Füge eine Methode `angriff()` hinzu, die eine kurze Kampfmeldung zurückgibt.
#
# **Erwartete Ausgabe:**
# ```
# Name: Excalibur, Schaden: 50, Material: Stahl
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Die Magiergilde
#
# **Belohnung:** 400 XP + Zauberstab der Weisheit
#
# Die Magiergilde braucht eine Organisation für ihre Mitglieder!
#
# **Deine Aufgaben:**
#
# 1. **Klasse Magier anlegen**
#    - Erstelle `class Magier:` mit `__init__(self, name, level=1, zauber="Feuerball")`
#    - Weise name, level und zauber zu
#
# 2. **Drei Magier erstellen**
#    - Erstelle Objekte für Merlin, Gandalf und Dumbledore (mit unterschiedlichen Leveln)
#    - Gib name und level für jeden aus
#
# 3. **Stärksten finden**
#    - Gib aus, welcher Magier den höchsten Level hat
#
# **Beispiel-Code zum Starten:**
# ```python
# class Magier:
#     def __init__(self, name, level=1, zauber="Feuerball"):
#         self.name = name
#         self.level = level
#         self.zauber = zauber
#
# merlin = Magier("Merlin", 10, "Blitz")
# print(f"{merlin.name}: Level {merlin.level}")
# ```
#
# **Bonus-Challenge:** Füge ein Attribut `element` hinzu und gib es aus.
#
# **Erwartete Ausgabe:**
# ```
# Merlin: Level 10
# Gandalf: Level 8
# Dumbledore: Level 9
# Stärkster: Merlin
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Das Drachennest
#
# **Belohnung:** 500 XP + Drachenei
#
# Die Drachen brauchen eine Struktur für ihre Familien!
#
# **Deine Aufgaben:**
#
# 1. **Klasse Drache anlegen**
#    - Erstelle `class Drache:` mit `__init__(self, name, alter, element)`; weise die Attribute zu
#
# 2. **Methode feuer_atmen()**
#    - Definiere `def feuer_atmen(self):` und gib darin `"PUFF! 🔥"` aus
#
# 3. **Zwei Drachen erstellen**
#    - Erstelle einen Feuer- und einen Eisdrachen
#    - Rufe für beide `feuer_atmen()` auf und gib name und Element aus
#
# **Beispiel-Code zum Starten:**
# ```python
# class Drache:
#     def __init__(self, name, alter, element):
#         self.name = name
#         self.alter = alter
#         self.element = element
#     def feuer_atmen(self):
#         print("PUFF! 🔥")
#
# smaug = Drache("Smaug", 200, "Feuer")
# smaug.feuer_atmen()
# ```
#
# **Bonus-Challenge:** Füge eine Methode `fliegen()` hinzu, die eine Meldung ausgibt.
#
# **Erwartete Ausgabe:**
# ```
# Feuer-Drache: Smaug
# PUFF! 🔥
# Eis-Drache: Frost
# PUFF! 🔥
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten des alten Magiers (Reflexion)
#
# Bevor du weiterziehst, denke über diese Fragen nach:
#
# 1. **Was ist der Unterschied zwischen einer Klasse und einem Objekt?**
#
# 2. **Warum braucht jede Methode in einer Klasse den Parameter self?**
#
# 3. **Wann würdest du Klassen anstelle von einfachen Variablen verwenden?**
#
# Diskutiere deine Gedanken mit anderen Abenteurern!

# %% [markdown]
# ### 📖 Zauberspruch-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **Klasse** 🏗️: Eine Blaupause für Objekte
# - **Objekt** 🎭: Eine konkrete Instanz einer Klasse
# - **Instanz** ⚡: Ein anderes Wort für Objekt
# - **Attribut** 💎: Eine Eigenschaft eines Objekts
# - **Methode** 🎯: Eine Funktion innerhalb einer Klasse
# - **Konstruktor** 🔨: Die __init__ Methode zum Erstellen
# - **self** 🪞: Referenz auf das aktuelle Objekt – ermöglicht Methoden und dem Konstruktor, auf die Attribute genau dieses Objekts zuzugreifen
# - **Instantiierung** ✨: Das Erstellen eines Objekts
# - **Blueprint** 📐: Ein anderes Wort für Klasse
# - **Eigenschaft** 🌟: Ein anderes Wort für Attribut
# - **Verhalten** 🎪: Die Aktionen eines Objekts (Methoden)
# - **Zustand** 📊: Die Werte aller Attribute

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ✅ Klassen mit dem class-Schlüsselwort erstellen
# - ✅ Objekte von Klassen instanziieren
# - ✅ Attribute auf Objekten setzen und lesen
# - ✅ Methoden in Klassen definieren
# - ✅ Den Konstruktor __init__ verwenden
# - ✅ Den self-Parameter korrekt nutzen
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die Boss-Quests!

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Fantastisch!** Du hast die OOP Grundlagen gemeistert!
#
# **Das hast du gelernt:**
# - Klassen als Baupläne für Objekte
# - Objekte als lebendige Instanzen
# - Attribute als Eigenschaften
# - Methoden als Fähigkeiten
# - Konstruktoren für die Initialisierung
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🎮 **Spiele:** Charaktere, Gegenstände, Monster
# - 📱 **Apps:** Benutzer, Produkte, Bestellungen
# - 🌐 **Websites:** Artikel, Kommentare, Profile
# - 🤖 **Chatbots:** Konversationen, intents, Entitäten
# - 📊 **Datenanalyse:** Datensätze, Modelle, Ergebnisse
#
# **Als Nächstes:** In Woche 11 lernst du **OOP Fortgeschritten - Vererbung und Polymorphismus**!

# %% [markdown]
# ## 🐉 Boss-Kampf: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Quests sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 XP + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Das Schmiede-System
#
# **Belohnung:** 500 XP + Legende-Schmiedeammer
#
# Der Meister der Handwerkszünfte braucht ein komplettes System für seine Schmiede!
#
# **Deine Aufgaben:**
#
# **1. Erstelle eine Klasse Waffe:**
#    - Mit Attributen: name, typ, schaden, seltenheit
#    - Die Klasse soll die Grundlage für alle Waffen sein
#    - Tipp: Nutze __init__ für alle Eigenschaften
#
# **2. Erstelle eine Klasse Schmied:**
#    - Mit Attributen: name, skill_level, erfahrung
#    - Erstelle eine Methode schmiede_waffe(name, typ)
#    - Die Methode soll ein neues Waffen-Objekt zurückgeben
#
# **3. Erstelle eine Klasse Verzauberung:**
#    - Mit Attributen: name, bonus, kosten
#    - Erstelle eine Methode wende_an(waffe)
#    - Die Methode soll den Schaden der Waffe erhöhen
#
# **4. Erstelle ein Inventar-System:**
#    - Erstelle eine Klasse Inventar als Liste für Waffen
#    - Methoden: hinzufügen(waffe), entfernen(name), anzeigen()
#    - Das Inventar soll maximal 10 Waffen speichern
#
# **5. Erstelle eine Händler-Klasse:**
#    - Mit Attributen: name, gold, inventar
#    - Methoden: kaufen(waffe), verkaufen(waffe, preis)
#    - Der Händler soll Gewinn machen (verkaufspreis > kaufpreis)
#
# **6. Hauptprogramm:**
#    - Erstelle einen Schmied und einen Händler
#    - Lass den Schmied 5 verschiedene Waffen schmieden
#    - Der Händler kauft alle Waffen und verkauft sie mit Gewinn
#    - Zeige den Gewinn des Händlers an
#
# **Beispiel-Struktur:**
# ```python
# # So könntest du beginnen:
# import random
#
# class Waffe:
#     def __init__(self, name, typ, schaden, seltenheit):
#         # Beschreibung was die Funktion tut
#         pass
#
# # ... weitere Klassen hier
#
# # Hauptprogramm
# schmied = Schmied("Erich", 10, 1000)
# # Verarbeite Waffen...
# ```
#
# **Bonus-Challenge:** Füge ein Zufallssystem für seltene Waffen hinzu!
#
# **Erwartete Ausgabe:**
# ```
# Schmied Erich: 5 Waffen geschmiedet
# Händler-Gewinn: [Betrag] Gold
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Die Magier-Akademie
#
# **Belohnung:** 600 XP + Arch-Zauberstab
#
# Die Akademie braucht ein komplettes Verwaltungssystem für ihre Magier!
#
# **Deine Aufgaben:**
#
# **1. Erstelle eine Klasse Magier:**
#    - Mit Attributen: name, haus, jahr, noten (Dictionary)
#    - Prüfe das Alter falls jahr < 1
#    - Gib "Fehlerhaftes Jahr" zurück wenn jahr < 1
#
# **2. Erstelle eine Klasse Zauber:**
#    - Mit Attributen: name, schwierigkeit, element, wirkung
#    - Erstelle eine Methode lerne(magier)
#    - Der Magier muss das richtige Element beherrschen
#
# **3. Erstelle eine Klasse Haus:**
#    - Mit Attributen: name, leiter, punkte, mitglieder
#    - Methoden: mitglied_hinzufügen(magier), punkte_vergeben(anzahl)
#    - Behandle Fehler wenn magier schon in anderem Haus
#
# **4. Erstelle eine Klasse Lehrer:**
#    - Mit Attributen: name, fach, erfahrung
#    - Methoden: unterrichten(students), note_geben(magier, fach, note)
#    - Noten sind von 1 bis 6
#
# **5. Erstelle eine Klasse Akademie:**
#    - Mit Attributen: name, häuser (Liste), lehrer, schüler
#    - Methoden: schüler_einschreiben(magier), haus_zuweisen(magier)
#    - Gruppiere und aggregiere Daten nach Häusern
#
# **6. Hauptprogramm:**
#    - Erstelle 4 Häuser mit je einem Leiter
#    - Erstelle 20 Magier mit zufälligen Eigenschaften
#    - Teile die Magier den Häusern zu
#    - Simuliere ein Schuljahr mit Noten und Punkten
#    - Zeige welches Haus gewonnen hat
#
# **Beispiel-Struktur:**
# ```python
# # So könntest du beginnen:
# import random
#
# class Magier:
#     def __init__(self, name, haus, jahr, noten):
#         # Erkenne gültige Werte
#         pass
#
# def simuliere_schuljahr(akademie):
#     # Simuliere das Jahr mit Noten
#     pass
#
# # ... weitere Klassen hier
#
# # Hauptprogramm
# hogwarts = Akademie("Hogwarts", [], [], [])
# # Verarbeite Magier...
# ```
#
# **Bonus-Challenge:** Füge einen Schulwettbewerb zwischen den Häusern hinzu!
#
# **Erwartete Ausgabe:**
# ```
# Hogwarts: 4 Häuser, 20 Magier
# Haus des Jahres: [Name]
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Das Monster-Bestiarium
#
# **Belohnung:** 400 XP + Monster-Handbuch
#
# Die Monsterjäger-Gilde braucht ein digitales Bestiarium aller Kreaturen!
#
# **Deine Aufgaben:**
#
# **1. Erstelle eine Klasse Monster:**
#    - Mit Attributen: name, typ, hp, angriff, verteidigung, beute
#    - Erstelle eine Methode angreifen(ziel)
#    - Die Methode soll Schaden basierend auf Angriff/Verteidigung berechnen
#
# **2. Erstelle eine Klasse Jäger:**
#    - Mit Attributen: name, level, erfahrung, ausrüstung
#    - Methoden: jagen(monster), level_up(), belohnung_erhalten(beute)
#    - Der Jäger wird stärker mit jedem Monster
#
# **3. Erstelle eine Klasse Bestiarium:**
#    - Mit Attributen: monster (Dictionary), gefangene_monster
#    - Erstelle eine Methode monster_hinzufügen(monster)
#    - Erstelle eine Suchfunktion für den Typ
#
# **4. Erstelle eine Klasse Quest:**
#    - Mit Attributen: name, beschreibung, ziel_monster, belohnung
#    - Methoden: start(jäger), prüfe_abgeschlossen(jäger)
#    - Die Quest ist abgeschlossen wenn das Zielmonster besiegt wurde
#
# **5. Erstelle eine Klasse Gilde:**
#    - Mit Attributen: name, mitglieder, quests, rangliste
#    - Methoden: mitglied_aufnehmen(jäger), quest_vergeben(jäger)
#    - Verwalte die Rangliste der besten Jäger
#
# **6. Hauptprogramm:**
#    - Erstelle 10 verschiedene Monster-Typen
#    - Erstelle 5 Jäger mit unterschiedlichen Fähigkeiten
#    - Die Gilde vergibt 3 Quests
#    - Simuliere die Jagd und aktualisiere die Rangliste
#    - Zeige den besten Jäger am Ende
#
# **Beispiel-Struktur:**
# ```python
# # So könntest du beginnen:
# import random
#
# class Monster:
#     def __init__(self, name, typ, hp, angriff, verteidigung, beute):
#         # Beschreibung was die Klasse tut
#         pass
#
# def kampf_simulieren(jäger, monster):
#     # Simuliere den Kampf
#     pass
#
# # ... weitere Klassen hier
#
# # Hauptprogramm
# gilde = Gilde("Monsterjäger", [], [], [])
# # Verarbeite Monster...
# ```
#
# **Bonus-Challenge:** Füge seltene Legendäre Monster hinzu!
#
# **Erwartete Ausgabe:**
# ```
# Monsterjäger-Gilde: 5 Jäger, 3 Quests
# Bester Jäger: [Name], Level [X]
# ```

# %%
# 🐉 Deine Lösung hier:

print()
print("🎉 +400 XP: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Meister der Handwerkszünfte besiegt!")
print("⭐ Titel erhalten: Meister der Blaupausen")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 10 gemeistert!")
print("📚 Nächste Woche: OOP Fortgeschritten - Vererbung und Polymorphismus!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen:

# %%
# ✅ Lösung Bug #1: Klasse ohne Großbuchstaben

# Problem: Klassen müssen mit einem Großbuchstaben beginnen
class Schwertkämpfer:
    name = "Held"

kämpfer = Schwertkämpfer()
print(kämpfer.name)

# %%
# ✅ Lösung Bug #2: Falscher Konstruktor

# Problem: __init__ braucht self als ersten Parameter – sonst weiß Python nicht,
# auf welchem Objekt die Attribute (name, mana) gespeichert werden sollen.
class Magier:
    def __init__(self, name, mana):
        self.name = name
        self.mana = mana

merlin = Magier("Merlin", 150)
print(merlin.name)

# %%
# ✅ Lösung Bug #3: Methode ohne self

# Problem: Methoden brauchen immer self als ersten Parameter – ohne self kann
# die Methode nicht auf self.name zugreifen (sie weiß nicht, welcher Drache gemeint ist).
class Drache:
    def __init__(self, name):
        self.name = name
    
    def vorstellen(self):
        print(f"Ich bin {self.name}!")

drache = Drache("Smaug")
drache.vorstellen()
