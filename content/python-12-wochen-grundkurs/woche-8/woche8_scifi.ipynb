# %% [markdown]
# # 🚀 Woche 8 – Dictionaries und Tupel: Die Daten-Archive der Raumstation
#
# **Cyber Credits zu verdienen:** 1000 Punkte
# **Boss:** Der Daten-Kurator der unendlichen Schlüssel

# %% [markdown]
# ## 🌟 Die Mission beginnt: Das Daten-Archiv der Nebula-7
#
# Willkommen an Bord der Raumstation Nebula-7! Du erreichst das **Daten-Archiv** – ein hochmoderner Sektor, in dem unendlich viele Daten strukturiert und gespeichert werden. In dieser Woche lernst du die drei **Arten der Daten-Strukturen**:
#
# **Deine Mission:**
# - Meistere die **Dictionary-Erstellung** mit geschweiften Klammern
# - Beherrsche **Zugriff und Änderung** mit Schlüsseln
# - Lerne **Tupel-Erstellung** mit runden Klammern
# - Verstehe **Unveränderlichkeit** von Tupel-Elementen
#
# **Einmal strukturiert, für immer organisiert!** Die Macht der Daten-Archive wartet...

# %% [markdown]
# ## 📚 Daten-Struktur 1: Das Dictionary - Der digitale Schrank
#
# **Was es ist:** Ein Dictionary ist eine Sammlung von Schlüssel-Wert-Paaren, die du mit geschweiften Klammern erstellst.
#
# **Die Anatomie eines Dictionary:**
# ```python
# # Leeres Dictionary erstellen
# leeres_dict = {}
#
# # Dictionary mit Elementen erstellen
# schiff = {"name": "Nebula-Explorer", "typ": "Forschung", "crew": 150}
# ```
#
# **Schritt-für-Schritt-Erklärung:**
# 1. **`{}`** - Geschweifte Klammern definieren ein Dictionary
# 2. **`:`** - Doppelpunkt trennt Schlüssel vom Wert
# 3. **`,`** - Kommas trennen die Paare
# 4. **`[key]`** - Mit Schlüssel greifst du auf Werte zu
#
# **Warum so nützlich:**
# - 🎯 Daten mit Namen statt Index organisieren
# - 🔍 Schneller Zugriff über Schlüssel
# - ⚡ Flexibel erweiterbar und änderbar
# - 🎲 Verschiedene Datentypen mischbar

# %%
# Beispiel 1: Einfache Dictionaries erstellen
# Leeres Dictionary
leeres_dict = {}
print(f"Leeres Dictionary: {leeres_dict}")

# Schiff-Dictionary
schiff = {
    "name": "Nebula-Explorer",
    "typ": "Forschung",
    "crew": 150,
    "geschwindigkeit": 0.8
}
print(f"Schiff-Dictionary: {schiff}")

# Planeten-Dictionary
planet = {
    "name": "Kepler-452b",
    "distanz": 1400,
    "typ": "Gesteinsplanet",
    "bewohnbar": True
}
print(f"Planet-Dictionary: {planet}")

# %%
# Beispiel 2: Auf Dictionary-Elemente zugreifen
schiff = {
    "name": "Nebula-Explorer",
    "typ": "Forschung",
    "crew": 150,
    "geschwindigkeit": 0.8
}

print("=== Schiff-Zugriff ===")
print(f"Schiff-Name: {schiff['name']}")
print(f"Schiff-Typ: {schiff['typ']}")
print(f"Crew-Größe: {schiff['crew']}")
print(f"Geschwindigkeit: {schiff['geschwindigkeit']}c")

# Mit get() Methode (sicherer)
print(f"\nMit get(): {schiff.get('name')}")
print(f"Nicht existierend: {schiff.get('raumschiff', 'Unbekannt')}")

# %%
# Beispiel 3: Dictionaries ändern und erweitern
schiff = {
    "name": "Nebula-Explorer",
    "typ": "Forschung",
    "crew": 150
}

print(f"Original: {schiff}")

# Wert ändern
schiff["crew"] = 200
print(f"Nach Crew-Änderung: {schiff}")

# Neues Element hinzufügen
schiff["kapitaen"] = "Captain Alex"
print(f"Nach Kapitän hinzufügen: {schiff}")

# Element entfernen
entfernt = schiff.pop("typ")
print(f"Entfernt: {entfernt}")
print(f"Nach entfernen: {schiff}")

# %% [markdown]
# ## 📦 Daten-Struktur 2: Das Tupel - Die Datenkapsel
#
# **Die wichtigsten Tupel-Eigenschaften:**
#
# **Erstellung:**
# - `tupel = (1, 2, 3)` - Mit runden Klammern
# - `tupel = 1, 2, 3` - Ohne Klammern
# - `tupel = (1,)` - Ein Element mit Komma
#
# **Unveränderlichkeit:**
# - Einmal erstellt, können Elemente nicht geändert werden
# - Perfekt für konstante Daten
# - Speichereffizienter als Listen

# %%
# 🔍 Übungen mit Tupeln

# Beispiel 1: Tupel erstellen
koordinaten = (100, 200, 300)
print(f"Koordinaten: {koordinaten}")

# Ohne Klammern
position = 10, 20, 30
print(f"Position: {position}")

# Ein Element
einzel = (42,)
print(f"Einzelnes Element: {einzel}")

# Zugriff auf Elemente
print(f"\nX-Koordinate: {koordinaten[0]}")
print(f"Y-Koordinate: {koordinaten[1]}")
print(f"Z-Koordinate: {koordinaten[2]}")

# %%
# Beispiel 2: Tupel sind unveränderlich
system_status = ("Online", "Stabil", "Aktiv")
print(f"System-Status: {system_status}")

# Zugriff funktioniert
print(f"Status: {system_status[0]}")

# Ändern funktioniert NICHT!
try:
    system_status[0] = "Offline"
except TypeError as e:
    print(f"Fehler: {e}")

# Aber Tupel in Listen können geändert werden
systeme = [
    ("Navigation", "Online"),
    ("Antrieb", "Stabil"),
    ("Kommunikation", "Aktiv")
]
systeme[1] = ("Antrieb", "Offline")
print(f"\nSysteme nach Änderung: {systeme}")

# %%
# Beispiel 3: Tupel unpacking und Methoden
schiff_daten = ("Nebula-Explorer", "Forschung", 150, 0.8)

# Tupel unpacking
name, typ, crew, geschwindigkeit = schiff_daten
print("=== Tupel Unpacking ===")
print(f"Name: {name}")
print(f"Typ: {typ}")
print(f"Crew: {crew}")
print(f"Geschwindigkeit: {geschwindigkeit}")

# Tupel-Methoden
print(f"\nAnzahl Elemente: {len(schiff_daten)}")
print(f"Index von 'Forschung': {schiff_daten.index('Forschung')}")
print(f"Anzahl 'Forschung': {schiff_daten.count('Forschung')}")

# %% [markdown]
# ## ✨ Daten-Struktur 3: Verschachtelte Strukturen - Das Daten-Netzwerk
#
# **Die mächtigsten Kombinationen:**
#
# **Dictionary in Dictionary:**
# - `person = {"name": "Alex", "adresse": {"strasse": "X", "stadt": "Y"}}`
#
# **Liste von Dictionaries:**
# - `crew = [{"name": "A", "rolle": "P"}, {"name": "B", "rolle": "K"}]`
#
# **Tupel als Dictionary-Schlüssel:**
# - `koordinaten = {(10, 20): "Punkt A", (30, 40): "Punkt B"}`

# %%
# Beispiel 1: Dictionary in Dictionary
raumstation = {
    "name": "Nebula-7",
    "position": {
        "sektor": "Alpha",
        "koordinaten": (100, 200, 300),
        "system": "Sol"
    },
    "systeme": {
        "antrieb": "Online",
        "lebenserhaltung": "Stabil",
        "kommunikation": "Aktiv"
    }
}

print("=== Verschachteltes Dictionary ===")
print(f"Station: {raumstation['name']}")
print(f"Sektor: {raumstation['position']['sektor']}")
print(f"Koordinaten: {raumstation['position']['koordinaten']}")
print(f"Antrieb: {raumstation['systeme']['antrieb']}")

# %%
# Beispiel 2: Liste von Dictionaries
crew = [
    {
        "name": "Captain Alex",
        "rolle": "Kommandant",
        "alter": 35,
        "erfahrung": 15
    },
    {
        "name": "Dr. Zara",
        "rolle": "Wissenschaftlerin",
        "alter": 28,
        "erfahrung": 8
    },
    {
        "name": "Lt. Nova",
        "rolle": "Pilotin",
        "alter": 26,
        "erfahrung": 6
    }
]

print("=== Crew-Liste ===")
for mitglied in crew:
    print(f"{mitglied['name']} - {mitglied['rolle']} ({mitglied['alter']} Jahre)")

# Nach Erfahrung filtern
erfahrene = [m for m in crew if m['erfahrung'] > 10]
print(f"\nErfahrene Crew: {[m['name'] for m in erfahrene]}")

# %%
# Beispiel 3: Komplexe Datenstrukturen
# Tupel als Dictionary-Schlüssel
galaxie_karte = {
    (100, 200): "Sonne A",
    (300, 400): "Sonne B",
    (500, 600): "Sonne C"
}

print("=== Galaxie-Karte ===")
for koordinate, stern in galaxie_karte.items():
    print(f"{koordinate}: {stern}")

# Komplexes Missionssystem
missionen = {
    "aktive": [
        {
            "id": 1,
            "ziel": (100, 200, 300),
            "crew": ["Alex", "Zara"],
            "status": "In Bearbeitung"
        }
    ],
    "abgeschlossen": [
        {
            "id": 2,
            "ziel": (400, 500, 600),
            "crew": ["Nova"],
            "status": "Erfolg"
        }
    ]
}

print(f"\nAktive Missionen: {len(missionen['aktive'])}")
print(f"Abgeschlossene Missionen: {len(missionen['abgeschlossen'])}")

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein Techniker hat versucht, die Daten zu organisieren, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1

schiff = {
    "name": "Nebula-Explorer",
    "typ": "Forschung"
}
print(f"Schiff: {schiff}")

# %%
# 🐛 Bug #2

koordinaten = (100, 200, 300)
koordinaten[0] = 150

# %%
# 🐛 Bug #3

crew = [
    {"name": "Alex", "rolle": "Kommandant"},
    {"name": "Zara", "rolle": "Wissenschaftlerin"}
]
print(crew[2])

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Daten-Archivar
#
# **Belohnung:** 300 Cyber Credits + Daten-Chip
#
# In den Daten-Archiven der Nebula-7 erstellst du dein erstes Dictionary für Schiffsdaten.
#
# **Deine Aufgaben:**
#
# 1. **Schiff-Dictionary anlegen**
#    - Erstelle ein Dictionary `schiff` mit Schlüsseln z.B. `name`, `typ`, `crew`, `geschwindigkeit` und passenden Werten
#    - Gib das Dictionary mit `print()` aus
#    - Nutze geschweifte Klammern `{}` und Doppelpunkte für Schlüssel: Wert
#
# 2. **Werte ändern und ergänzen**
#    - Ändere den Wert von `crew` (z.B. auf eine neue Zahl)
#    - Füge einen neuen Schlüssel `kapitaen` mit einem Wert hinzu
#    - Gib das aktualisierte Dictionary aus
#
# 3. **Planeten-Liste aus Dictionaries**
#    - Erstelle eine Liste mit 3 Elementen; jedes Element ist ein Dictionary mit z.B. `name` und `entfernung` (oder ähnlichen Schlüsseln)
#    - Gib die Liste und die Werte eines Planeten (z.B. `planeten[0]["name"]`) aus
#
# 4. **Zugriff und Ausgabe**
#    - Greife mit `schiff["name"]` und `schiff.get("typ")` auf Werte zu und gib sie aus
#    - Gib eine kurze übersichtliche Zusammenfassung (z.B. „Schiff X, Typ Y, Crew Z“) aus
#
# **Beispiel-Code zum Starten:**
# ```python
# schiff = {"name": "Nebula-Explorer", "typ": "Forschung", "crew": 50, "geschwindigkeit": 0.8}
# print(f"Schiff: {schiff}")
#
# schiff["crew"] = 55
# schiff["kapitaen"] = "Captain Alex"
# print(f"Aktualisiert: {schiff}")
# ```
#
# **Bonus-Challenge:**
# - Erstelle ein verschachteltes Dictionary (z.B. Schiff mit Unter-Dictionary „systeme“).
#
# **Erwartete Ausgabe:**
# ```
# Schiff: {'name': 'Nebula-Explorer', 'typ': 'Forschung', ...}
# Aktualisiert: {...}
# Planet 0: Erde, 1.0
# Zusammenfassung: Nebula-Explorer, Forschung, 55 Crew
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Koordinaten-Meister
#
# **Belohnung:** 400 Cyber Credits + Navigations-Gerät
#
# Du nutzt Tupel für 3D-Koordinaten und kombinierst sie mit Dictionaries.
#
# **Deine Aufgaben:**
#
# 1. **Koordinaten als Tupel**
#    - Erstelle mindestens zwei 3D-Koordinaten als Tupel (z.B. `pos1 = (100, 200, 50)`)
#    - Gib die Tupel und die Länge mit `len(pos1)` aus
#    - Greife per Index auf x, y, z zu (z.B. `pos1[0]`, `pos1[1]`, `pos1[2]`) und gib sie aus
#
# 2. **Tupel-Unpacking**
#    - Nutze Unpacking: `x, y, z = pos1` und gib x, y, z aus
#    - Erstelle eine zweite Koordinate und unpacke sie ebenfalls
#
# 3. **Positions-Dictionary**
#    - Erstelle ein Dictionary `positionen`, in dem Schlüssel Namen (Strings) und Werte Koordinaten-Tupel sind (z.B. `{"Alpha": (10, 20, 0), "Beta": (30, 40, 5)}`)
#    - Gib das Dictionary aus und greife auf eine Position zu (z.B. `positionen["Alpha"]`)
#
# 4. **Abstand (vereinfacht)**
#    - Schreibe eine einfache Funktion `abstand(koord1, koord2)`, die z.B. die Summe der absoluten Differenzen pro Achse berechnet (oder euklidische Distanz mit `**0.5`)
#    - Rufe sie für zwei deiner Koordinaten auf und gib das Ergebnis aus
#
# **Beispiel-Code zum Starten:**
# ```python
# pos1 = (100, 200, 50)
# pos2 = (150, 250, 60)
# print(f"Pos1: {pos1}, len: {len(pos1)}")
#
# x, y, z = pos1
# print(f"Unpacked: x={x}, y={y}, z={z}")
#
# positionen = {"Alpha": (10, 20, 0), "Beta": (30, 40, 5)}
# print(f"Alpha: {positionen['Alpha']}")
# ```
#
# **Bonus-Challenge:**
# - Füge 4D-Koordinaten (x, y, z, t) als Tupel hinzu und erweitere die Abstandsberechnung.
#
# **Erwartete Ausgabe:**
# ```
# Pos1: (100, 200, 50), len: 3
# Unpacked: x=100, y=200, z=50
# Alpha: (10, 20, 0)
# Abstand: 86.6
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Die Crew-Datenbank
#
# **Belohnung:** 500 Cyber Credits + Crew-Meister-Urkunde
#
# Du baust eine kleine Crew-Datenbank mit Liste von Dictionaries und Suchfunktionen.
#
# **Deine Aufgaben:**
#
# 1. **Crew-Liste aus Dictionaries**
#    - Erstelle eine Liste `crew`, in der jedes Element ein Dictionary ist mit z.B. `name`, `rang`, `alter`, `erfahrung` (Jahre)
#    - Lege mindestens 3 Crew-Mitglieder an und gib die Liste aus
#
# 2. **Mitglieder hinzufügen**
#    - Füge mit `crew.append({...})` ein neues Crew-Mitglied hinzu
#    - Gib die aktualisierte Liste und die Anzahl der Mitglieder mit `len(crew)` aus
#
# 3. **Suchfunktion nach Rolle**
#    - Schreibe eine Funktion `suche_rolle(crew_liste, rang)`, die alle Mitglieder mit diesem Rang zurückgibt (z.B. Liste von Dictionaries)
#    - Rufe die Funktion für einen Rang (z.B. "Pilot") auf und gib die gefundenen Mitglieder aus
#
# 4. **Statistik und Zuweisung**
#    - Berechne das Durchschnittsalter der Crew (Summe der Alter / Anzahl) und gib es aus
#    - Optional: Weise einem oder mehreren Mitgliedern ein neues Schlüssel-Wert-Paar zu (z.B. `"mission": "Alpha-1"`) und gib die aktualisierte Crew aus
#
# **Beispiel-Code zum Starten:**
# ```python
# crew = [
#     {"name": "Captain Alex", "rang": "Kommandant", "alter": 35, "erfahrung": 10},
#     {"name": "Dr. Zara", "rang": "Wissenschaftlerin", "alter": 28, "erfahrung": 5},
#     {"name": "Lt. Nova", "rang": "Pilotin", "alter": 26, "erfahrung": 3},
# ]
# print(f"Crew: {len(crew)} Mitglieder")
#
# def suche_rolle(crew_liste, rang):
#     return [m for m in crew_liste if m.get("rang") == rang]
# ```
#
# **Bonus-Challenge:**
# - Füge zu jedem Mitglied Schlüssel wie `fähigkeiten` (Liste) oder `zertifikate` hinzu und gib eine Übersicht aus.
#
# **Erwartete Ausgabe:**
# ```
# Crew: 3 Mitglieder
# Nach Hinzufügen: 4 Mitglieder
# Piloten: [{'name': 'Lt. Nova', ...}]
# Durchschnittsalter: 29.5
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten des Kommandanten (Reflexion)
#
# Bevor du weiterfliegst, denke über diese Fragen nach:
#
# 1. **Warum sollte man ein Dictionary statt einer Liste verwenden?**
#
# 2. **Wann sind Tupel besser als Listen?**
#
# 3. **Wie helfen verschachtelte Strukturen bei der Datenorganisation?**
#
# Diskutiere deine Gedanken mit anderen Kommandanten!

# %% [markdown]
# ### 📖 Tech-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **dict** 🚀: Datentyp für Dictionaries
# - **{}** 📦: Geschweifte Klammern für Dictionaries
# - **key** 🔑: Schlüssel im Dictionary
# - **value** 💎: Wert im Dictionary
# - **tuple** 📍: Datentyp für Tupel
# - **()** ⭕: Runde Klammern für Tupel
# - **immutable** 🔒: Unveränderlich
# - **nested** 🎲: Verschachtelt
# - **unpacking** 📤: Auspacken von Tupeln
# - **get()** 🔍: Sichere Zugriffsmethode

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ✅ Dictionaries erstellen und verwenden
# - ✅ Auf Werte über Schlüssel zugreifen
# - ✅ Tupel erstellen und verstehen
# - ✅ Unveränderlichkeit von Tupel nutzen
# - ✅ Verschachtelte Datenstrukturen erstellen
# - ✅ Komplexe Daten organisieren

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Exzellent!** Du hast die Daten-Archive der Raumstation gemeistert!
#
# **Das hast du gelernt:**
# - Dictionaries für strukturierte Daten
# - Tupel für unveränderliche Daten
# - Verschachtelte Datenstrukturen
# - Zugriffsmethoden und Operationen
# - Komplexe Datenorganisation
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🚀 **Raumfahrt:** Telemetrie, Konfigurationen, Koordinaten
# - 📱 **Apps:** Benutzerprofile, Einstellungen, API-Daten
# - 🌐 **Websites:** JSON-Daten, Konfigurationen, Metadaten
# - 🤖 **KI-Systeme**: Modelleinstellungen, Parameter, Ergebnisse
# - 📊 **Wissenschaft:** Experiment-Daten, Messwerte, Ergebnisse

# %% [markdown]
# ## 🐉 Boss-Kampf: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Quests sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 Cyber Credits + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Der Daten-Generator
#
# **Belohnung:** 500 Cyber Credits + Daten-Kristall
#
# Du baust einen Daten-Generator für zufällige System-Dictionaries und filterst sie.
#
# **Deine Aufgaben:**
#
# 1. **System-Generator**
#    - Erstelle eine Funktion `generiere_system()` oder `generiere_system(name)`, die ein Dictionary mit z.B. `name`, `typ` (aus einer Liste mit `random.choice`), `crew` (`random.randint(10, 100)`), `koordinaten` (Tupel mit 3 Zufallszahlen) zurückgibt
#    - Gib ein Beispiel-System aus
#
# 2. **Koordinaten und Distanz**
#    - Schreibe eine Funktion `berechne_distanz(koord1, koord2)`, die zwei 3D-Tupel nimmt und die euklidische Distanz berechnet: √((x1-x2)² + (y1-y2)² + (z1-z2)²); nutze `math.sqrt` oder `**0.5`
#    - Behandle den Fall, dass die Tupel nicht genau 3 Elemente haben (z.B. Fehlermeldung oder 0 zurückgeben)
#    - Gib die Distanz für zwei Beispiel-Koordinaten aus
#
# 3. **Datenbank und Suche**
#    - Erstelle eine Liste `systeme` und füge 10–20 generierte Systeme hinzu (mit einer Schleife)
#    - Schreibe eine Funktion `suche_name(systeme, name)`, die das erste System mit passendem Namen zurückgibt (oder None)
#    - Schreibe eine Funktion `filter_typ(systeme, typ)`, die alle Systeme mit diesem Typ zurückgibt
#    - Optional: Funktion `filter_crew(systeme, min_crew)` für Mindest-Crew-Größe
#
# 4. **Statistik und Ausgabe**
#    - Berechne und gib aus: Anzahl Systeme, durchschnittliche Crew-Größe, Anzahl pro Typ (z.B. mit einer Schleife und einem Dictionary für Zählung)
#    - Gib eine kurze übersichtliche Zusammenfassung aus
#
# **Beispiel-Code zum Starten:**
# ```python
# import random
# import math
#
# def generiere_system():
#     typen = ["Forschung", "Militär", "Handel"]
#     return {
#         "name": f"System-{random.randint(1, 1000)}",
#         "typ": random.choice(typen),
#         "crew": random.randint(10, 100),
#         "koordinaten": (random.randint(0, 100), random.randint(0, 100), random.randint(0, 100))
#     }
#
# def berechne_distanz(koord1, koord2):
#     if len(koord1) != 3 or len(koord2) != 3:
#         return 0
#     return math.sqrt((koord1[0]-koord2[0])**2 + (koord1[1]-koord2[1])**2 + (koord1[2]-koord2[2])**2)
# ```
#
# **Bonus-Challenge:**
# - Füge eine einfache Daten-Validierung hinzu (z.B. crew > 0, Koordinaten im erlaubten Bereich).
#
# **Erwartete Ausgabe:**
# ```
# Beispiel-System: {'name': 'System-42', 'typ': 'Forschung', ...}
# Distanz: 86.6
# Gefunden: System-42
# Filter Typ Forschung: 5 Systeme
# Statistik: 20 Systeme, Ø Crew 55, Typen: Forschung 8, Militär 6, Handel 6
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Der Raumstation-Manager
#
# **Belohnung:** 600 Cyber Credits + Kommandanten-Titel
#
# Du verwaltest eine Raumstation als verschachteltes Dictionary mit Sektoren und Crew.
#
# **Deine Aufgaben:**
#
# 1. **Station-Struktur**
#    - Erstelle eine Funktion `erstelle_station(name, sektor)`, die ein Dictionary zurückgibt mit z.B. `name`, `sektor`, `systeme` (ein Dictionary mit Schlüsseln wie "Antrieb", "Schild", jeweils mit einem Wert oder Unter-Dictionary z.B. `{"status": "aktiv"}`) und `crew` (Liste von Dictionaries mit name, rang)
#    - Gib die Station aus
#
# 2. **Sektoren und Crew**
#    - Erstelle eine Funktion `fuege_sektor_hinzu(station, sektor_name)` oder erweitere die Station um einen weiteren „Sektor“ (z.B. neuer Eintrag in `systeme` oder eigene Liste `sektoren`)
#    - Erstelle eine Funktion `weise_crew_zu(station, name, rang)`, die ein Crew-Mitglied zur Liste `station["crew"]` hinzufügt
#    - Gib die aktualisierte Station (z.B. Anzahl Sektoren/Systeme, Anzahl Crew) aus
#
# 3. **Suche und Statistik**
#    - Schreibe eine Funktion `suche_rolle(station, rang)`, die alle Crew-Mitglieder mit diesem Rang aus `station["crew"]` zurückgibt
#    - Berechne eine kurze Sektor- oder System-Statistik (z.B. wie viele Systeme, wie viele mit status "aktiv") und gib sie aus
#
# 4. **Ereignis (simuliert)**
#    - Erstelle eine Funktion `zufalls_ereignis(station)`, die z.B. mit `random.choice` ein „Ereignis“ wählt (z.B. "Wartung", "Alarm") und den Status eines Systems ändert oder eine Meldung ausgibt
#    - Rufe sie einmal auf und gib das Ergebnis aus
#
# **Beispiel-Code zum Starten:**
# ```python
# import random
#
# def erstelle_station(name, sektor):
#     return {
#         "name": name,
#         "sektor": sektor,
#         "systeme": {"Antrieb": {"status": "aktiv"}, "Schild": {"status": "aktiv"}},
#         "crew": []
#     }
#
# def weise_crew_zu(station, name, rang):
#     station["crew"].append({"name": name, "rang": rang})
# ```
#
# **Bonus-Challenge:**
# - Füge ein einfaches „Notfall-Protokoll“ hinzu: Wenn ein System auf "ausfall" gesetzt wird, gib eine Warnung aus und setze ein anderes System auf "reserve".
#
# **Erwartete Ausgabe:**
# ```
# Station: Nebula-7, Sektor Alpha
# Nach Crew-Zuweisung: 3 Crew-Mitglieder
# Piloten: [{'name': 'Nova', 'rang': 'Pilot'}]
# Ereignis: Wartung - Antrieb auf Reserve
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Die Missions-Datenbank
#
# **Belohnung:** 400 Cyber Credits + Missions-Protokoll
#
# Du verwaltest Missionen als Dictionaries mit Tupeln für unveränderliche Daten.
#
# **Deine Aufgaben:**
#
# 1. **Mission-Struktur**
#    - Erstelle eine Funktion `erstelle_mission(mission_id, ziel, prioritaet)`, die ein Dictionary zurückgibt mit z.B. `id`, `ziel`, `prioritaet`, `crew` (Liste von Namen oder leere Liste), `status` ("offen", "aktiv", "abgeschlossen"); nutze für die Mission-ID oder feste Daten ein Tupel (z.B. `(mission_id, ziel)` als „unveränderlicher Kern“ optional)
#    - Lege 3–5 Missionen an und speichere sie in einer Liste `missionen`
#    - Gib die Liste aus
#
# 2. **Crew-Zuweisung und Status**
#    - Schreibe eine Funktion `weise_crew_zu(mission, name)`, die einen Namen zur Liste `mission["crew"]` hinzufügt
#    - Schreibe eine Funktion `setze_status(mission, neuer_status)`, die `mission["status"]` ändert
#    - Rufe beide für je eine Mission auf und gib die aktualisierte Mission aus
#
# 3. **Suche und Filter**
#    - Erstelle eine Funktion `missionen_nach_status(missionen, status)`, die alle Missionen mit diesem Status zurückgibt
#    - Erstelle eine Funktion `mission_mit_id(missionen, mission_id)`, die die erste Mission mit dieser ID zurückgibt (oder None)
#    - Gib die gefilterten Ergebnisse aus
#
# 4. **Statistik und Bericht**
#    - Berechne: Anzahl Missionen gesamt, Anzahl pro Status (z.B. mit Schleife und Dictionary)
#    - Gib eine kurze übersichtliche Zusammenfassung aus (z.B. „5 Missionen, 2 aktiv, 1 abgeschlossen“)
#
# **Beispiel-Code zum Starten:**
# ```python
# def erstelle_mission(mission_id, ziel, prioritaet):
#     return {"id": mission_id, "ziel": ziel, "prioritaet": prioritaet, "crew": [], "status": "offen"}
#
# def weise_crew_zu(mission, name):
#     mission["crew"].append(name)
#
# def missionen_nach_status(missionen, status):
#     return [m for m in missionen if m.get("status") == status]
# ```
#
# **Bonus-Challenge:**
# - Füge zu jeder Mission ein Feld `ergebnis` und `belohnung` (z.B. Cyber Credits) hinzu und gib eine Belohnungs-Übersicht aus.
#
# **Erwartete Ausgabe:**
# ```
# Missionen: 5
# Mission Alpha aktualisiert: crew=['Alex', 'Zara'], status=aktiv
# Aktive Missionen: 2
# Statistik: 5 Missionen, offen: 2, aktiv: 2, abgeschlossen: 1
# ```

# %%
# 🐉 Deine Lösung hier:

print()
print("🎉 +400 Cyber Credits: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Daten-Kurator der unendlichen Schlüssel besiegt!")
print("⭐ Titel erhalten: Meister der Daten-Archive")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 8 gemeistert!")
print("📚 Nächste Woche: JSON-Dateien und I/O!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen:

# %%
# ✅ Lösung Bug #1: Fehlende schließende Klammer

# Problem: Dictionary nicht geschlossen
schiff = {
    "name": "Nebula-Explorer",
    "typ": "Forschung"
}
print(f"Schiff: {schiff}")

# %%
# ✅ Lösung Bug #2: Tupel sind unveränderlich

# Problem: Tupel können nicht geändert werden
koordinaten = [100, 200, 300]  # Liste verwenden
koordinaten[0] = 150
print(f"Koordinaten: {koordinaten}")

# %%
# ✅ Lösung Bug #3: Index außerhalb des Bereichs

# Problem: Index 2 existiert nicht (nur 0,1)
crew = [
    {"name": "Alex", "rolle": "Kommandant"},
    {"name": "Zara", "rolle": "Wissenschaftlerin"}
]
print(crew[1])  # Letztes Element
