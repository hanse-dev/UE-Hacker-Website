# %% [markdown]
# # 🚀 Woche 6 – Das Raumschiff-Management: Listen für Weltraum-Explorer!
# **Cyber Credits zu verdienen:** 1000 Punkte
# **Herausforderung:** Der Chaos-Hangar der unorganisierten Raumschiff-Daten

# %% [markdown]
# ## 🛸 Die Weltraum-Geschichte beginnt: Dein erstes Raumschiff-System
# **Hintergrundstory:**
# Du bist ein:e junge:r Raumschiff-Kommandant:in auf der weltraum-Station "Nebula-7". Bisher hast du nur einzelne Raumschiffe und Ausrüstungsgegenstände verwalten können – ein Laser hier, ein Schildgenerator da. Aber jetzt steht dir eine große Mission bevor: Du musst den **Chaos-Hangar** organisieren, in dem alle Raumschiff-Daten wild durcheinander liegen!
# Dafür brauchst du ein **Raumschiff-Management-System** – eine digitale Hangar-Konsole, die viele Informationen aufnehmen kann. In Python nennen wir diese digitale Hangar-Konsole eine **Liste**.
# **Deine Mission:** Lerne, wie du Listen erstellst, verwalten und meisterst, um für die interstellare Raumfahrt gerüstet zu sein!

# %% [markdown]
# ## 🚀 Was ist eine Hangar-Konsole (Liste)?
# Stell dir deine Hangar-Konsole wie eine **digitale Raumschiff-Liste mit nummerierten Docking-Plätzen** vor. Jeder Docking-Platz hat eine Nummer (beginnend bei 0 – so zählen Programmierer:innen!) und du kannst an jeden Platz eine Information eintragen.
# **Warum ist das so nützlich für Raumschiffe?**
# - 🛸 **Mehrere Raumschiffe verwalten**: Statt nur ein Schiff zu haben, kannst du alle Schiffe, ihre Treibstoffmengen und Missionspläne dabei haben!
# - 📍 **Schneller Zugriff**: "Gib mir die Information von Docking-Platz 2!" – Sofort verfügbar!
# - ✨ **Dynamisch anpassbar**: Neue Schiffe aufnehmen, abgereiste Schiffe ausfliegen, Ausrüstung upgraden
# - 🔄 **Alle durchgehen**: Prüfe schnell alle Schiffe auf deiner Hangar-Konsole
# **Fun Fact:** Echte Raumfahrt-Agenturen wie NASA, SpaceX und ESA nutzen genau dieses Konzept – Listen von Raumschiffen, Astronaut:innen und Missionen!

# %% [markdown]
# ### 🛸 Tutorial: Deine erste Hangar-Konsole erstellen
# Die erfahrene Missionsleiterin zeigt dir die Grundformel:
# ```python
# hangar_konsole = [schiff1, schiff2, schiff3]
# ```
# Die eckigen Klammern `[]` sind das technologische Symbol für Listen. Die Einträge werden mit Kommas getrennt.

# %%
# 🚀 Level 1: Verschiedene Hangar-Konsole-Typen erstellen
# Raumschiff-Liste (Strings)
raumschiffe = ["Enterprise", "Millennium Falcon", "X-Wing", "Star Destroyer"]
print(f"🛸 Deine Raumschiffe: {raumschiffe}")
# Treibstoff-Mengen (Zahlen)
treibstoff_liter = [3500, 4200, 2800, 5200, 3000]
print(f"⛽ Treibstoff in Liter: {treibstoff_liter}")
# Gemischte Hangar-Informationen (selten aber möglich!)
hangar_info = ["Quantum-Drive", 42, True, 3.14]
print(f"✨ Hangar-Infos: {hangar_info}")
# Leere Hangar-Konsole (für neue Schiffe, die noch ankommen!)
neue_schiffe = []
print(f"📦 Leere Raumschiff-Liste: {neue_schiffe}")
print("\n🎉 +100 Cyber Credits: Du hast gelernt, verschiedene Listen zu erstellen!")

# %% [markdown]
# ### 🔍 Skill: Informationen aus der Hangar-Konsole holen (Indexing)
# Jeder Eintrag in deiner Hangar-Konsole hat eine **Docking-Platz-Nummer** (Index).
# **⚠️ Wichtige Programmierer:innen-Regel:** In der digitalen Welt fangen wir bei **0** an zu zählen!
# - `hangar_konsole[0]` → Docking-Platz 1 (erster Eintrag)
# - `hangar_konsole[1]` → Docking-Platz 2 (zweiter Eintrag)
# - `hangar_konsole[-1]` → Letzter Docking-Platz (negative Zahlen zählen von hinten!)
# - `hangar_konsole[-2]` → Vorletzter Docking-Platz
# **Warum bei 0 anfangen?** Das ist eine alte Tradition der Programmierer:innen-Gilde. Es macht viele Berechnungen einfacher!

# %%
# 🚀 Level 2: Informationen aus der Hangar-Konsole nehmen
# Deine Missions-Liste
missions_plan = ["Planet erkunden", "Alien-Kontakt aufnehmen", "Rohstoffe sammeln", "Schiff reparieren", "Wasser auffüllen"]
print("🧭 Dein Missions-Plan:")
print(f"Docking-Platz 0 (Erste Mission): {missions_plan[0]}")
print(f"Docking-Platz 1 (Zweite Mission): {missions_plan[1]}")
print(f"Docking-Platz -1 (Letzte Mission): {missions_plan[-1]}")
print(f"Docking-Platz -2 (Vorletzte Mission): {missions_plan[-2]}")
print("\n💬 Die Missionsleiterin fragt: 'Was steht auf deiner ersten Liste?'")
print(f"Du antwortest: '{missions_plan[0]}!'")
print("\n🎉 +150 Cyber Credits: Du kannst jetzt gezielt auf Informationen zugreifen!")

# %% [markdown]
# ### ⚡ Power-Moves: Hangar-Konsole verändern
# Deine Hangar-Konsole ist **lebendig** – du kannst sie jederzeit anpassen! Das nennt man in der Programmierer:innen-Sprache "mutable" (veränderbar).

# %% [markdown]
# #### 📥 Neue Raumschiffe aufnehmen
# - `hangar_konsole.append(eintrag)` → Fügt den Eintrag in den nächsten freien Docking-Platz
# - `hangar_konsole.insert(platz, eintrag)` → Setzt den Eintrag an eine bestimmte Position

# %%
# 🚀 Level 3: Neue Raumschiffe aufnehmen!
# Du startest deine Raumfahrt-Karriere mit Grundausstattung
ausruestung = ["Laserkanone", "Schildgenerator"]
print(f"⚔️ Start-Ausrüstung: {ausruestung}")
# Du kaufst eine neue Hyperraum-Maschine!
print("\n💥 Neue Technologie installiert!")
ausruestung.append("Hyperraum-Maschine")
print(f"📦 Neue Ausrüstung! Liste: {ausruestung}")
# Ein Techniker verkauft dir einen Photon-Torpedo - den willst du an Position 1
print("\n🛒 Du kaufst einen Photon-Torpedo beim Ausrüster...")
ausruestung.insert(1, "Photon-Torpedo")
print(f"✨ Ausrüstung neu sortiert: {ausruestung}")
print("\n🎉 +200 Cyber Credits: Du kannst jetzt neue Einträge aufnehmen!")

# %% [markdown]
# #### 🗑️ Einträge entfernen
# - `hangar_konsole.remove(eintrag)` → Entfernt einen bestimmten Eintrag (nur das erste Vorkommen!)
# - `hangar_konsole.pop(platz)` → Nimmt Eintrag aus Docking-Platz und gibt ihn dir zurück
# - `del hangar_konsole[platz]` → Löscht Eintrag aus Docking-Platz (ohne Rückgabe)

# %%
# 🚀 Level 4: Hangar-Konsole-Management
# Deine Aufgaben-Liste
aufgaben = ["Wasserstoff tanken", "Schiff scannen", "Alien kommunizieren", "Systeme prüfen", "Alien kommunizieren"]
print(f"📋 Deine Aufgaben: {aufgaben}")
# Du hast die erste Aufgabe erledigt!
print("\n✅ Aufgabe erledigt: 'Alien kommunizieren'")
aufgaben.remove("Alien kommunizieren")  # Entfernt nur das ERSTE Vorkommen
print(f"📋 Verbleibende Aufgaben: {aufgaben}")
# Die letzte Aufgabe ist die wichtigste - du nimmst sie raus um sie zu prüfen
print("\n🔍 Welche Aufgabe ist am wichtigsten?")
wichtigste_aufgabe = aufgaben.pop()  # Nimmt die letzte Aufgabe
print(f"⭐ Wichtigste Aufgabe: {wichtigste_aufgabe}")
print(f"📋 Übrige Aufgaben: {aufgaben}")
# Die erste Aufgabe ist zu einfach - weg damit!
print("\n🗑️ Die erste Aufgabe ist zu einfach...")
del aufgaben[0]
print(f"📋 Finale Aufgaben-Liste: {aufgaben}")
print("\n🎉 +250 Cyber Credits: Du bist ein Hangar-Konsole-Management-Profi!")

# %% [markdown]
# #### 🔄 Einträge aktualisieren
# Manchmal ändert sich ein Schiffname oder eine Treibstoffmenge. Einfach den Docking-Platz überschreiben!

# %%
# 🚀 Level 5: Raumschiff-Daten aktualisieren!
# Deine Treibstoff-Mengen (in Liter)
treibstoff_mengen = [3500, 4200, 2800, 5200, 3000]
print(f"⛽ Original Treibstoff-Mengen: {treibstoff_mengen}")
# Ein Schiff braucht mehr Treibstoff!
print("\n🔨 Schiff an Position 2 braucht mehr Treibstoff!")
treibstoff_mengen[2] = 4500  # Von 2800 auf 4500!
print(f"✨ Aktualisiert! Neue Mengen: {treibstoff_mengen}")
# Das erste Schiff bekommt auch eine Anpassung
print("\n⚡ Das erste Schiff bekommt auch mehr Treibstoff!")
treibstoff_mengen[0] = 4000
print(f"🎯 Finale Treibstoff-Mengen: {treibstoff_mengen}")
print("\n🎉 +200 Cyber Credits: Du kannst jetzt Daten aktualisieren!")

# %% [markdown]
# ### 🛸 Technologische Hangar-Konsole-Zauber (Built-in Funktionen)
# Die erfahrene Missionsleiterin zeigt dir nützliche Funktionen, die auf Listen wirken:

# %%
# 🚀 Level 6: Technologische Hangar-Konsole-Zauber
# Deine gesammelten Energiezellen (durcheinander!)
energiezellen = [50, 200, 10, 500, 75, 150]
print("🔋 Deine Energiezellen-Stapel:")
print(f"Zellen: {energiezellen}")
print(f"📊 Anzahl Zellen: {len(energiezellen)}")
print(f"💎 Gesamt-Energie: {sum(energiezellen)}")
print(f"🔻 Kleinste Zelle: {min(energiezellen)}")
print(f"🔺 Größte Zelle: {max(energiezellen)}")
print(f"📈 Sortiert (Vorschau): {sorted(energiezellen)}")
print("\n🔮 Permanente Sortier-Technologie!")
energiezellen.sort()
print(f"✨ Energiezellen sortiert: {energiezellen}")
print("\n🔄 Umdreh-Technologie!")
energiezellen.reverse()
print(f"🎭 Energiezellen umgedreht: {energiezellen}")
print("\n🎉 +300 Cyber Credits: Du beherrschst die technologischen Listen-Zauber!")

# %% [markdown]
# ### 🔁 Combo-Move: Listen + Schleifen
# Die wahre Macht zeigt sich, wenn du Listen mit Schleifen kombinierst! So kannst du automatisch durch deine ganze Hangar-Konsole gehen.

# %%
# 🚀 Level 7: Hangar-Konsole-Scan durchführen
# Deine Raumschiffe
raumschiffe = ["Enterprise", "Millennium Falcon", "X-Wing", "Star Destroyer"]
print("🛸 Raumschiff-Team-Übersicht:")
for schiff_name in raumschiffe:
    print(f"  ⚡ {schiff_name} ist bereit für die Mission!")
# Mit Nummern (für Hangar-Listen!)
print("\n📋 Raumschiff-Menü:")
for nummer, schiff_name in enumerate(raumschiffe):
    print(f"  [{nummer + 1}] {schiff_name}")
print("\n🎉 +250 Cyber Credits: Du kannst jetzt durch Listen iterieren!")

# %% [markdown]
# ### 🗺️ Advanced: Die Raumstation-Matrix (Verschachtelte Listen)
# Für echte Raumschiff-Profis: Listen können andere Listen enthalten! Perfekt für Raumstation-Pläne, Missionspläne oder organisierte Abläufe.

# %%
# 🚀 Level 8: Die Raumstation-Plan-Matrix
# Ein 3x3 Raumstation-Plan mit verschiedenen Docking-Plätzen
raumstation_plan = [
    ["Dock A1", "Dock A2", "Dock A3"],
    ["Dock B1", "Dock B2", "Dock B3"],
    ["Dock C1", "Dock C2", "Dock C3"]
]
print("🏛️ Deine Raumstation-Plan:")
print(f"Gesamter Plan: {raumstation_plan}")
print(f"Mittlere Reihe: {raumstation_plan[1]}")
print(f"Dock in der Mitte: {raumstation_plan[1][1]}")
# Alle Docks anzeigen (wie ein echte Raumstation!)
print("\n✨ Raumstation-Plan-Ansicht:")
for reihe in raumstation_plan:
    for dock in reihe:
        print(dock, end=" ")
    print()  # Neue Zeile nach jeder Reihe
print("\n🎉 +400 Cyber Credits: Du hast verschachtelte Listen gemeistert!")

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Raumstation-Probleme!
# **Story:** Ein fehlerhafter KI-Assistent hat Fehler in diese Code-Schnipsel gebracht! Kannst du die Probleme finden und beheben?

# %% [markdown]
# ### 🐛 Problem #1: Der Docking-Platz-Index-Fehler

# %%
# ⚠️ Dieser Code hat einen Fehler! Was ist das Problem?
schiff_typen = ["Kreuzer", "Fregatte", "Zerstörer"]
print(schiff_typen[3])
# 🤔 Frage: Warum gibt es hier einen Fehler?

# %% [markdown]
# ### 🐛 Problem #2: Das Phantom-Raumschiff

# %%
# ⚠️ Dieser Code hat einen Fehler! Was ist das Problem?
schiff_klassen = ["Galaxy-Klasse", "Intrepid-Klasse", "Defiant-Klasse"]
schiff_klassen.remove("Sovereign-Klasse")
# 🤔 Frage: Was ist das Problem?

# %% [markdown]
# ### 🐛 Problem #3: Die verschwundene Änderung (Schwierig!)

# %%
# ⚠️ Warum wird die Liste hier nicht geändert?
def fuege_schiff_hinzu(liste, schiff):
    liste = liste + [schiff]  # Erstellt eine NEUE Liste!
    return liste
meine_schiffe = ["Enterprise", "Voyager"]
fuege_schiff_hinzu(meine_schiffe, "Defiant")
print(meine_schiffe)  # Immer noch ["Enterprise", "Voyager"]!
# 🤔 Frage: Warum ist "Defiant" nicht in der Liste?

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise deine Fähigkeiten!
# **Story:** Der Chaos-Hangar wartet auf Organisation! Aber zuerst musst du drei Prüfungen bestehen, um eine gute Raumfahrt-Kommandant:in zu sein...

# %% [markdown]
# ### 🎯 Mission 1: Die Treibstoff-Managerin
# **Schwierigkeit:** ⭐⭐☆☆☆
# **Belohnung:** 300 Cyber Credits + Treibstoffmeister-Abzeichen
# **Story:** Du hilfst einer Treibstoff-Händlerin, ihre Waren zu organisieren. Sie ist völlig überfordert!
# **Deine Aufgaben:**
# 1. Erstelle eine Treibstoffliste mit mindestens 5 Treibstoff-Arten deiner Wahl
# 2. Gib die Liste aus
# 3. Die Händlerin bekommt 2 neue Treibstoff-Arten – füge sie am Ende hinzu
# 4. Ein Kunde kauft die dritte Treibstoff-Art – entferne sie
# 5. Die erste Treibstoff-Art ist jetzt in Quanten-Qualität – ändere sie zu "Quanten-[Treibstoff-Art]"6. Zeige die finale Liste mit der Anzahl der Treibstoff-Arten
# **Bonus-Challenge:** Gib die Liste nummeriert aus (1. Treibstoff-Art, 2. Treibstoff-Art, ...)

# %%
# 🎯 Dein Code für Mission 1
# Starte hier!

# %% [markdown]
# ### 🎯 Mission 2: Die Raumfahrt-Akademie
# **Schwierigkeit:** ⭐⭐⭐☆☆
# **Belohnung:** 400 Cyber Credits + Pilot:innen-Zertifikat
# **Story:** Die Raumfahrt-Akademie braucht deine Hilfe, um die Piloten-Noten auszuwerten!
# **Deine Aufgaben:**
# 1. Erstelle eine Liste mit 5 Piloten-Noten (Zahlen zwischen 1.0 und 6.0)
# 2. Berechne und zeige an:
#    - Durchschnittsnote
#    - Beste Note
#    - Schlechteste Note
# 3. Gib alle Noten sortiert aus (von beste nach schlechteste)
# 4. **Bonus-Challenge:** Zähle, wie viele Noten besser als 4.0 sind (bestanden!)
# **Extra-Bonus:** Vergib Titel basierend auf dem Durchschnitt:
# - < 2.0: "Raumfahrt-Ass"- < 3.0: "Erfahrene:r Pilot:in"- < 4.0: "Fortgeschrittene:r Pilot:in"- >= 4.0: "Kadett:in"

# %%
# 🎯 Dein Code für Mission 2
# Zeige deine Piloten-Künste!

# %% [markdown]
# ### 🎯 Mission 3: Die Champion-Flotte
# **Schwierigkeit:** ⭐⭐⭐⭐☆
# **Belohnung:** 500 Cyber Credits + Flotten-Kommandant:innen-Status
# **Story:** Die Raumfahrt-Flotte braucht ein System, um Top-3-Listen für verschiedene Raumschiff-Kategorien zu erstellen!
# **Deine Aufgaben:**
# 1. Erstelle eine Funktion `erstelle_top_drei(titel, schiff_liste)`
# 2. Die Funktion soll:
#    - Prüfen, ob mindestens 3 Raumschiffe in der Liste sind
#    - Wenn ja: Die ersten 3 als schöne Top-3-Liste ausgeben
#    - Wenn nein: Alle ausgeben + Hinweis "Zu wenige Schiffe für Top 3!"3. Teste mit mindestens 2 verschiedenen Listen:
#    - Eine mit 5+ Schiffen (z.B. "Schnellste Raumschiffe")
#    - Eine mit nur 2 Schiffen (z.B. "Quanten-Schiffe")
# **Bonus-Challenge:** Füge Medaillen-Emojis hinzu: 🥇 🥈 🥉

# %%
# 🎯 Dein Code für Mission 3
# Werde zur Flotten-Kommandant:in!

# %% [markdown]
# ### 🤔 Weisheiten der erfahrenen Missionsleiterin (Reflexion)
# Beantworte diese Fragen, um dein Wissen zu festigen:
# 1. **Treibstoff-Wahl:** Was ist der Unterschied zwischen `append()` und `insert()`? Wann würdest du welche Methode wählen?
# 2. **Die Null-Regel:** Warum fängt Python bei 0 zu zählen an? Welche Vorteile hat das? (Tipp: Denk an Mathematik und Speicher-Adressen)
# 3. **Hangar-Konsole vs. Einzelne Terminals:** Wann würdest du eine Liste statt einzelner Variablen verwenden? Nenne 3 praktische Beispiele aus der Raumfahrt!
# 4. **Der verbotene Index:** Was passiert, wenn du auf einen Index zugreifst, der nicht existiert? Wie kannst du das vermeiden?
# **Diskutiere mit deinen Raumfahrt-Kolleg:innen!**

# %% [markdown]
# ### 🎤 Raumfahrt-Präsentation (Review)
# **Show & Tell Zeit!**
# - Zeigt eure coolsten Raumschiff-Management-Programme!
# - Welche kreativen Anwendungen habt ihr gefunden?
# - Welche Listen-Operation war euer Favorit und warum?
# - Gab es Überraschungen oder "Aha!"-Momente?
# **Teilt eure Erfolge und lernt voneinander!**

# %% [markdown]
# ### 📖 Hangar-Konsole-Lexikon (Schlüsselwörter)
# Merke dir diese nützlichen Begriffe:
# - **Liste** 📜: Eine geordnete, veränderbare Sammlung von Werten (wie eine digitale Hangar-Konsole)
# - **Index** 🔢: Die Position eines Elements (beginnt bei 0!)
# - **Element** 💎: Ein einzelner Wert in der Liste
# - **`append()`** ➕: Fügt Element am Ende hinzu
# - **`insert()`** 📌: Fügt Element an bestimmter Position ein
# - **`remove()`** ❌: Entfernt bestimmtes Element
# - **`pop()`** 🎯: Entfernt und gibt Element zurück
# - **`len()`** 📏: Gibt Anzahl der Elemente zurück
# - **`sort()`** 📊: Sortiert die Liste permanent
# - **`sorted()`** 👀: Gibt sortierte Kopie zurück (Original bleibt)
# - **Verschachtelte Liste** 🗂️: Liste in einer Liste (Matrix/Tabelle)

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
# Nach dieser Raumfahrt-Quest solltest du:
# - ✅ Listen erstellen und mit Werten füllen können
# - ✅ Über Indizes auf Listenelemente zugreifen können
# - ✅ Listen mit `append()`, `remove()`, `pop()`, `insert()` verändern können
# - ✅ Nützliche Funktionen wie `len()`, `sum()`, `min()`, `max()` anwenden können
# - ✅ Listen mit Schleifen kombinieren und alle Elemente verarbeiten können
# - ✅ Verschachtelte Listen verstehen und nutzen können
# **Selbstcheck:** Kannst du alle Haupt-Missionen lösen? Dann bist du bereit für den Chaos-Hangar-Kampf!

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Raumfahrt-Reise
# **Glückwunsch, Raumfahrt-Kommandant:in!**
# Du hast heute das **Raumschiff-Management-System** gemeistert – eine der nützlichsten Fähigkeiten für die interstellare Raumfahrt!
# Listen sind überall:
# - 🛸 Raumschiff-Listen
# - 📱 Raumfahrt-App-Daten
# - 🤖 Raumschiff-Trainingsdaten
# - 📊 Treibstoff-Analyse
# - 🌐 Raumfahrt-Webseiten
# Mit Listen kannst du Daten organisieren, verwalten und effizient verarbeiten. Du bist jetzt bereit für größere Raumfahrt-Abenteuer!
# **Nächster Schritt:** Die Raumfahrt-Hausaufgaben warten auf dich...

# %% [markdown]
# ## 🐉 Chaos-Hangar-Kampf: Hausaufgaben-Quests
# **ACHTUNG:** Der Chaos-Hangar erwacht! Nur die besten Raumfahrt-Kommandant:innen können diese Herausforderungen meistern.
# **Belohnung für alle 3 Quests:**
# - 🏆 Meister:in der Listen (Titel)
# - 💎 1500 Cyber Credits
# - 🎖️ Bereitschaft für Woche 7
# **Tipp:** Nutze alles, was du heute gelernt hast. Kombiniere verschiedene Listen-Operationen!

# %% [markdown]
# ### 🎬 Raumfahrt-Quest 1: Das Missionen-System
# **Schwierigkeit:** ⭐⭐⭐⭐☆
# **Belohnung:** 500 Cyber Credits + Missionen-Kommandant:innen-Abzeichen
# **Story:** Du organisierst dein eigenes Missionen-System und musst die Astronaut:innen und Raumschiffe verwalten! Die Zeitpläne sind knallhart...
# **Deine Aufgaben:**
# 1. Erstelle zwei Listen:
#    - `astronauten`: Speichere mindestens 5 Astronaut:innen-Namen
#    - `raumschiffe`: Speichere die dazugehörigen Raumschiffe für jede:n Astronaut:in
#
# 2. Schreibe folgende Funktionen:
#    - `neue_astronautin(name, schiff)`: Fügt eine:n Astronaut:in mit Raumschiff hinzu
#    - `zeige_alle_astronauten()`: Zeigt alle Astronaut:innen mit ihren Raumschiffen schön formatiert
#    - `durchschnitt_berechnen()`: Berechnet die durchschnittliche Anzahl an Missionen pro Woche
#    - `beste_schiffe()`: Findet und zeigt alle Raumschiffe mit 5 Sterne-Bewertung
# 3. Teste alle Funktionen!
# **Bonus-Challenge:**
# - Füge eine Funktion `astronautin_entfernen(name)` hinzu, die eine:n Astronaut:in UND ihr Raumschiff entfernt
# - Sortiere die Astronaut:innen nach Erfahrung (meist zuerst)

# %%
# 🎬 Dein Code für Raumfahrt-Quest 1
# Erschaffe dein Missionen-System!

# %% [markdown]
# ### 🏫 Raumfahrt-Quest 2: Die Piloten-Akademie
# **Schwierigkeit:** ⭐⭐⭐⭐⭐
# **Belohnung:** 600 Cyber Credits + Pilotenlehrer:innen-Zepter
# **Story:** Du bist jetzt Direktor:in der Piloten-Akademie! Organisiere den Simulator-Platz mit einem intelligenten Sitzplan-System.
# **Deine Aufgaben:**
# 1. Erstelle eine 3x3 verschachtelte Liste für den Simulator-Platz-Plan
#    - Leere Plätze als `"Leer"` markieren
#    - Mindestens 5 Pilot:innen einsetzen (Namen deiner Wahl)
# 2. Schreibe folgende Funktionen:
#    - `platziere_pilot(reihe, platz, name)`: Setzt eine:n Pilot:in an Position
#    - `zeige_simulatorplan()`: Zeigt den Simulatorplan schön formatiert (wie eine echte Tabelle!)
#    - `finde_pilot(name)`: Prüft, ob eine:r Pilot:in auf dem Platz sitzt und wo
#    - `entferne_pilot(name)`: Entfernt eine:n Pilot:in (Platz wird "Leer")
# 3. Teste alle Funktionen mit verschiedenen Pilot:innen!
# **Bonus-Challenge:**
# - Füge eine Funktion `freie_plaetze()` hinzu, die alle leeren Plätze zählt
# - Zeige den Simulatorplan mit Koordinaten (A1, A2, A3, B1, B2, ...)

# %%
# 🏫 Dein Code für Raumfahrt-Quest 2
# Werde zur Pilotenlehrer:in!

# %% [markdown]
# ### 🔢 Raumfahrt-Quest 3: Die Treibstoff-Analyst:in
# **Schwierigkeit:** ⭐⭐⭐⭐☆
# **Belohnung:** 400 Cyber Credits + Treibstoff-Analyst:innen-Medaille
# **Story:** Als Treibstoff-Analyst:in musst du magische Treibstoff-Elixiere analysieren und transformieren!
# **Deine Aufgaben:**
# 1. Schreibe eine Funktion `analysiere_treibstoff(treibstoff_liste)`, die:
#    - Die größte und kleinste Treibstoffmenge findet und ausgibt
#    - Den Durchschnitt berechnet und ausgibt
#    - Zählt, wie viele Mengen über und unter 4000l liegen
#    - Eine neue Liste zurückgibt, die NUR die Mengen über 4000l enthält
# 2. Teste deine Funktion mit mindestens 3 verschiedenen Treibstofflisten:
#    - Eine mit nur großen Mengen
#    - Eine mit nur kleinen Mengen
#    - Eine gemischte Liste
# 3. Gib alle Ergebnisse schön formatiert aus (mit Emojis und Beschreibungen!)
# **Bonus-Challenge:**
# - Finde alle Mengen, die genau 3500l sind
# - Erstelle eine Funktion, die die Liste in große und kleine Mengen aufteilt
# - Berechne die Summe aller großen vs. kleinen Mengen

# %%
# 🔢 Dein Code für Raumfahrt-Quest 3
# Entfessle die Analyse der Treibstoff!
print("\n🎉 Wenn du alle 3 Raumfahrt-Quests geschafft hast, bist du eine:e wahre:r RAUMFAHRT-MANAGER:IN! 🏆")
