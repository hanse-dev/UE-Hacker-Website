# %% [markdown]
# # 🤔 Reflexion & Zusammenfassung – 🐴 Woche 2 – Datentypen und Variablen: Die vier Hufschlag-Typen
# ### 🤔 Weisheiten der erfahrenen Reitlehrerin (Reflexion)
#
# Bevor du weiterreitest, denke über diese Fragen nach:

# %% [markdown]
# ✏️ *Deine Antwort:*

# %% [markdown]
# 1. **Warum ist es wichtig zu wissen, welchen Datentyp eine Variable hat?**

# %% [markdown]
# ✏️ *Deine Antwort:*

# %% [markdown]
# 2. **Was passiert, wenn du versuchst, Text und Zahlen zu multiplizieren?**

# %% [markdown]
# ✏️ *Deine Antwort:*

# %% [markdown]
# 3. **Wann würdest du Boolean-Werte im Stallalltag verwenden?**
#
# Diskutiere deine Gedanken mit anderen Pferdefreunden!

# %% [markdown]
# ✏️ *Deine Antwort:*

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Wunderbar!** Du hast die vier Hufschlag-Typen gemeistert!
#
# **Das hast du gelernt:**
# - f-Strings für moderne Textformatierung
# - Die vier fundamentalen Datentypen von Python
# - Mathematische und textliche Operationen
# - Die Kunst der Typumwandlung
# - Die Verarbeitung von Informationen
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🎮 **Pferdespiele:** Pferdestatistiken, Turniere, Zucht
# - 📱 **Reit-Apps:** Trainingspläne, Pferdeprofile, Termine
# - 🌐 **Reitställe:** Buchungssysteme, Abrechnungen, Planung
# - 🤖 **Pferde-Chatbots:** Beratung, Tipps, Informationen
# - 📊 **Pferdezucht:** Statistiken, Stammbäume, Werte
#
# **Als Nächstes:** In Woche 3 lernst du **Bedingungen (if-else)**!
