# %% [markdown]
# # 🐉 Boss Quests – 🏰 Week 10 – OOP Basics: The Magic Blueprints!
# > ⚠️ Harder! Combines everything from this week.
#
# **⚠️ WARNING:** These quests are significantly harder! They combine everything you have learned.
#
# **Rewards:** 1500 XP total + legendary items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 1: The Weapon Forge
#
# **Reward:** 500 XP + Master Smith's Hammer
#
# The blacksmith needs a digital catalogue for his storage!
#
# **Step 1 – Create a class:**
# Write a class for a weapon. You decide what properties a weapon should have (e.g. name, type, damage).
#
# **Step 2 – Add methods:**
# Add at least 2 methods – e.g. one to display the weapon and one to "use" it.
#
# **Step 3 – Weapon storage:**
# Create 3 different weapon objects. Print all weapons clearly and find the strongest one.
#
# **Bonus:** Add a method that upgrades the weapon (e.g. damage +5).

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss Quest 2: The Zookeeper
#
# **Reward:** 600 XP + Zoo Director's Certificate
#
# The magic zoo of Pythonia needs a digital management system!
#
# **Step 1 – Animal class:**
# Write a class for an animal. Every animal has at least a name, a species and a favourite food.
#
# **Step 2 – Methods:**
# Add a method that introduces the animal, and one that shows what it eats.
#
# **Step 3 – Fill the zoo:**
# Create 4 different animals and add them to a list. Have all animals introduce themselves and show which animal eats the most.
#
# **Bonus:** Add a method `feed(amount)` that updates a hunger display.

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 3: The Monster Bestiary
#
# **Reward:** 400 XP + Monster Handbook
#
# The Monster Hunters' Guild keeps a digital bestiary!
#
# **Step 1 – Monster class:**
# Write a class for a monster. You decide what properties a monster has (e.g. name, type, hit points).
#
# **Step 2 – Combat method:**
# Add a method that attacks the monster. The damage should depend on the properties.
#
# **Step 3 – Bestiary:**
# Create 3 different monsters, let them fight each other and show who wins.
#
# **Bonus:** Add a `heal()` method that restores hit points.

# %%
print()
print("🎉 +400 XP: Boss Quest completed!")
print("🏆 You have defeated the Master of the Guilds!")
print("⭐ Title earned: Master of Blueprints")
print()
print("🎊 CONGRATULATIONS! You have mastered Week 10!")
print("📚 Next week: Advanced OOP – Inheritance and Polymorphism!")

# %% [markdown]
# ---
#
# 🎊 **Congratulations!** You have mastered all boss quests of this week!
#
# **Next up:** Week 11 is already waiting!
