# %% [markdown]
# # ⭐ Missionen – 🚀 Woche 7 – Module und Bibliotheken: Die Modul-Banken der Raumstation
#
# > 📖 Vorher: `…_1_lektion` und `…_2_debug`

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Modul-Importer
#
# **Belohnung:** 300 Cyber Credits + Daten-Chip
#
# Im Modul-Zentral der Nebula-7 lernst du, wie du Module lädst und mit Aliasen arbeitest.
#
# **Schritt 1 – Module importieren:**
# Lade die Module `math`, `random` und `time` mit passenden Aliasen (z.B. `import math as m`) und gib jeweils eine Konstante oder Funktion aus jedem Modul aus (z.B. `math.pi`, `random.randint(1, 10)`)
#
# **Schritt 2 – Wartezeit-Simulation:**
# Erstelle eine kleine Funktion oder ein Skript, das eine zufällige Sekundenzahl (1–3) mit `random` erzeugt und `time.sleep()` nutzt und gib vor und nach der Wartezeit eine kurze Meldung aus
#
# **Schritt 3 – Flugbahn-Berechnung:**
# Nutze `math.sin` und `math.pi`, um für einen Winkel (z.B. 90° in Bogenmaß) eine Höhe oder einen Wert zu berechnen und gib das Ergebnis formatiert aus
#
# **Schritt 4 – Crew-Generator:**
# Erstelle eine Namensliste mit 3–5 Crew-Namen und wähle mit `random.choice()` einen zufälligen Namen aus und gib den ausgewählten Namen aus
#
# **Bonus:** Füge eine weitere Funktion mit dem `datetime`-Modul hinzu (z.B. aktuelle Uhrzeit anzeigen).

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Berechnungs-Kern
#
# **Belohnung:** 400 Cyber Credits + Navigations-Gerät
#
# Du nutzt das math-Modul für Kreisberechnungen, Winkelumrechnung und Wurzeln.
#
# **Schritt 1 – Kreis-Berechnung:**
# Schreibe eine Funktion oder ein Skript, das für einen Radius Umfang und Fläche mit `math.pi` berechnet und gib Radius, Umfang und Fläche formatiert aus
#
# **Schritt 2 – Zufalls-Zahlen und Summe:**
# Erzeuge mit `random.randint(1, 100)` fünf Zufallszahlen und speichere sie (z.B. in einer Liste) und berechne die Summe und gib die Zahlen sowie die Summe aus
#
# **Schritt 3 – Winkel-Umrechnung:**
# Wandle 90°, 180° und 270° mit `math.radians()` in Bogenmaß um und gib Grad und Bogenmaß für jeden Winkel aus
#
# **Schritt 4 – Wurzel-Ziehen:**
# Berechne mit `math.sqrt()` die Wurzeln von 4, 9, 16 und 25 und gib die Ergebnisse übersichtlich aus
#
# **Bonus:** Füge trigonometrische Berechnungen hinzu (z.B. sin, cos für 45°).

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Der Zufalls-Simulator
#
# **Belohnung:** 500 Cyber Credits + Crew-Meister-Urkunde
#
# Du baust ein kleines Simulationssystem mit Planeten, Wetter und Energieverbrauch.
#
# **Schritt 1 – Planetenauswahl:**
# Erstelle eine Liste mit 5–6 Planeten-Namen und wähle mit `random.choice()` einen zufälligen Zielplaneten aus und gib die Liste und den gewählten Planeten aus
#
# **Schritt 2 – Wetter-Simulation:**
# Erzeuge mit `random.uniform(-50, 50)` drei Temperaturwerte (z.B. für verschiedene Sektoren) und runde sie auf eine Dezimalstelle und gib die Temperaturen mit kurzer Beschreibung aus
#
# **Schritt 3 – Energie-Verbrauch:**
# Simuliere 3 Systeme mit je einem zufälligen Verbrauch zwischen 50 und 150 MW (mit `random.randint` oder `random.uniform`) und gib Systemname und Verbrauch aus und berechne den Gesamtverbrauch
#
# **Schritt 4 – Flotten-Generator:**
# Erstelle 3 Schiffsnamen mit zugehöriger zufälliger Stärke (1–10) und speichere sie (z.B. als Liste von Tupeln oder Dicts) und gib alle Schiffe mit ihrer Stärke aus
#
#
# > 💡 **Tipp:** Du entscheidest selbst, wie du das umsetzt – es gibt keinen einzig richtigen Weg!
# **Bonus:** Füge eine Variable mit Normalverteilung hinzu (z.B. `random.gauss(100, 20)` für Energiewerte).

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ☐ Module mit import laden
# - ☐ Aliase für Module verwenden
# - ☐ Spezielle Funktionen importieren
# - ☐ math-Modul für Berechnungen nutzen
# - ☐ random-Modul für Zufallszahlen verwenden
# - ☐ Module in eigenen Programmen einsetzen
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die Boss-Quests!
