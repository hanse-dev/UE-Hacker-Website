# %% [markdown]
# # ⭐ Missions – 🐴 Week 12 – Turtle Graphics: The Tournament Visualisation Board!
#
# The time has come to prove your visual skills in real challenges!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: The Dressage Arena
#
# **Reward:** 350 Hoof Points + Dressage Whip of Precision
#
# Create a perfect dressage arena!
#
# **Step 1 – Draw the riding area:**
# Create a Turtle window with a green background (lawn) and draw a rectangle as border (white lines)
#
# **Step 2 – Letters and lines:**
# Add letters at the edges using `turtle.write("A", align="center")` (at least A, B, C, D, E, F) and draw at least one diagonal or centre line in the arena
#
# **Step 3 – Colours:**
# Use white lines for the fence and green background (`screen.bgcolor("green")`)
#
# **Bonus:** Add circle lines for circle exercises!

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: The Show Jumping Course
#
# **Reward:** 450 Hoof Points + Jump Boots of Elegance
#
# Design a complete show jumping course!
#
# **Step 1 – Function for obstacles:**
# Create a function `draw_obstacle(x, y, height, number)` that draws an obstacle (e.g. rectangle or poles) and the function should write the number next to it using `turtle.write()`
#
# **Step 2 – Place eight obstacles:**
# Call the function 8 times with different positions and heights and place them in a logical order (e.g. in a circle or along a route)
#
# **Step 3 – Water jump and route:**
# Draw at least one blue rectangle as a water jump (`fillcolor("blue")`, `begin_fill()`, `end_fill()`) and optionally: a dotted line as the ideal route (short dashes in a loop)
#
# **Bonus:** Add a timing animation!

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: The Animated Horse Race
#
# **Reward:** 550 Hoof Points + Victory Wreath of Speed
#
# Create an animated horse race!
#
# **Step 1 – Racetrack and horses:**
# Draw 5 lanes (e.g. 5 horizontal lines or stripes) and create 5 Turtle objects (or a list) in different colours as "horses"
#
# **Step 2 – Animation:**
# In a loop: move each horse a random number of steps to the right (`random.randint(1, 5)` and `forward()`) and stop when a horse reaches the finish line (on the right)
#
# **Step 3 – Finish line and winner:**
# Draw a vertical line on the right as the finish and print in the console which horse (which colour/number) won
#
# > 💡 **Tip:** You decide how to implement it – there is no single right way!
#
# **Bonus:** Add bets and scoreboards!

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### 🎯 Learning Goals – Have You Reached Them?
#
# Check for yourself whether you have mastered these skills:
#
# - ☐ Import and set up the Turtle module
# - ☐ Draw and move shapes
# - ☐ Use colours and fills
# - ☐ Use loops for patterns
# - ☐ Create interactive graphics
#
# If you can tick all the boxes – congratulations! You are ready for the boss quests!
