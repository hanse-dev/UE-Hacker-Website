# %% [markdown]
# # ⭐ Missions – 🚀 Week 10 – OOP Basics: The Magic Blueprints!
#
# The time has come to prove your knowledge in real challenges!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Create Your First Robot Class
#
# **Reward:** 300 Cyber Credits + Wrench
#
# The technician needs a blueprint for all service robots on board!
#
# **Step 1 – Create class Robot:**
# Create a class with `class Robot:` and add the attributes `__init__(self, id, model, energy, function)` in the constructor *(= special method that runs automatically when an object is created)* (e.g. `self.id = id`)
#
# **Step 2 – Create an object:**
# Create an object: `r2 = Robot(2, "Astromech", 100, "Repair")` and print all properties with `print()`
#
# **Step 3 – Second object:**
# Create a second robot with different values and print its properties
#
# **Bonus:** Add a method `status()` that returns a short status line.

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: The Space Marines
#
# **Reward:** 400 Cyber Credits + Laser Pistol
#
# The Space Marines need an organisation for their soldiers!
#
# **Step 1 – Create class Soldier:**
# Create `class Soldier:` with `__init__(self, name, rank="Recruit", unit="Standard")`; assign name, rank and unit
#
# **Step 2 – Create three soldiers:**
# Create objects for Shepard, Vasquez and Hicks (with different ranks); print name and rank for each
#
# **Step 3 – Compare ranks:**
# Print which soldier has the "highest" rank (e.g. fixed order or comparison)
#
# **Bonus:** Add an attribute `special_ability` and print it.

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: The Spaceship System
#
# **Reward:** 500 Cyber Credits + Space Suit
#
# The fleet needs a structure for all ships!
#
# **Step 1 – Create class Spaceship:**
# Create `class Spaceship:` with `__init__(self, name, ship_class, crew)`; assign the attributes
#
# **Step 2 – Method hyperjump():**
# Define `def hyperjump(self):` and print e.g. `"Hyperjump initiated! ⚡"` inside it
#
# **Step 3 – Create two ships:**
# Create a cruiser and a fighter object; call `hyperjump()` for both and print name and class
#
# > 💡 **Tip:** You decide how to implement it – there is no single right way!
#
# **Bonus:** Add a method `activate_shields()` that prints a message.

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### 🎯 Learning Goals – Have You Reached Them?
#
# Check for yourself whether you have mastered these skills:
#
# - ☐ Create classes with the class keyword
# - ☐ Create objects from classes
# - ☐ Set and read attributes on objects
# - ☐ Define methods in classes
# - ☐ Use the `__init__` constructor
# - ☐ Use the `self` parameter correctly
#
# If you can tick all the boxes – congratulations! You are ready for the final challenges!
