# %% [markdown]
# # 🏰 Week 12 – Turtle Graphics: The Magic Canvas!
#
# Welcome, young master of the visual arts! You are entering the **Workshop of the Magic Drawing Scrolls of Pyralia** – a place where code comes to life and colorful graphics are born!
#
# This week you will master the magical art of turtle graphics:
#
# **Your Mission:**
# - Use the turtle module for visual magic
# - Draw shapes and patterns
# - Use colors for enchanting effects
# - Create animations and interactive art
#
# **Get started!** Your journey to becoming a visual master begins!

# %% [markdown]
# ## Magic Spell 1
#
# **What it is:** The turtle module is Python's magical drawing scroll that lets you draw with code.
#
# **Important:** Always import `turtle` and call `turtle.done()` at the end!

# %%
# %pip install Tinker
from turtle import *

# %%
# Example 1: Setting up Turtle
import turtle

# Create a magic drawing scroll
screen = turtle.Screen()
screen.title("Magic Drawing Scroll of Pyralia")
screen.bgcolor("black")

# Create a magic pen (Turtle)
pen = turtle.Turtle()
pen.speed(1)  # Slow for magical effects
pen.color("cyan")

# Draw a magic shape
pen.forward(100)
pen.left(90)
pen.forward(100)

# Close the magic drawing scroll
turtle.done()

# %% [markdown]
# ## Magic Spell 2
#
# **What it is:** With turtle commands you can draw different shapes and move the pen.
#
# **Important:** The turtle always turns at its current position!

# %%
# Example 1: Basic movements
import turtle

screen = turtle.Screen()
screen.bgcolor("navy")
pen = turtle.Turtle()
pen.speed(5)
pen.color("gold")

# A magic square
for _ in range(4):
    pen.forward(100)
    pen.left(90)

# A magic triangle
pen.penup()
pen.goto(-150, 0)
pen.pendown()
for _ in range(3):
    pen.forward(100)
    pen.left(120)

turtle.done()

# %% [markdown]
# ## Magic Spell 3
#
# **What it is:** Colors bring your graphics to life and fills give them body.
#
# **Important:** Use `begin_fill()` and `end_fill()` for filled shapes!

# %%
# Example 1: Magic colors and fills
import turtle

screen = turtle.Screen()
screen.bgcolor("darkblue")
pen = turtle.Turtle()
pen.speed(3)

# Magic star
pen.color("yellow", "orange")
pen.begin_fill()
for _ in range(5):
    pen.forward(100)
    pen.right(144)
pen.end_fill()

# Magic circle
pen.penup()
pen.goto(150, 0)
pen.pendown()
pen.color("cyan", "lightblue")
pen.begin_fill()
pen.circle(50)
pen.end_fill()

turtle.done()
