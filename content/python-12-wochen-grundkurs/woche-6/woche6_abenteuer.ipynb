# %% [markdown]
# # 🗡️ Woche 6 – Listen: Die Schatzkammer der Sammlungen
#
# **XP zu verdienen:** 1000 Punkte
# **Boss:** Der Wächter der unendlichen Sammlungen

# %% [markdown]
# ## 🌟 Die Quest beginnt: Die Schatzkammer des Königs
#
# Willkommen, tapferer Held! Du erreichst die **Schatzkammer des Königs** – ein magischer Ort, an dem unendlich viele Schätze gesammelt und organisiert werden können. In dieser Woche lernst du die drei **Arten der Sammlungs-Zauber**:
#
# **Deine Mission:**
# - Meistere die **Listen-Erstellung** mit eckigen Klammern
# - Beherrsche **Elemente hinzufügen** mit append() und insert()
# - Lerne **Elemente entfernen** mit remove() und pop()
# - Verstehe **Listen durchsuchen** mit index() und in-Operator
#
# **Einmal gesammelt, für immer organisiert!** Die Macht der Listen wartet...

# %% [markdown]
# ## 📚 Sammlungs-Zauber 1: Die Listen-Erstellung - Der erste Schatz
#
# **Was es ist:** Eine Liste ist eine geordnete Sammlung von Elementen, die du mit eckigen Klammern erstellst.
#
# **Die Anatomie einer Liste:**
# ```python
# # Leere Liste erstellen
# leere_liste = []
#
# # Liste mit Elementen erstellen
# schatzliste = ["Gold", "Edelsteine", "Zaubertränke"]
# ```
#
# **Schritt-für-Schritt-Erklärung:**
# 1. **`[]`** - Eckige Klammern definieren eine Liste
# 2. **`,`** - Kommas trennen die Elemente
# 3. **`""`** - Strings werden in Anführungszeichen gesetzt
# 4. **`[]`** - Mit Index greifst du auf Elemente zu (beginnt bei 0)
#
# **Warum so nützlich:**
# - 🎯 Mehrere Werte in einer Variable speichern
# - 🔍 Geordnete Struktur für Daten
# - ⚡ Flexibel erweiterbar und veränderbar
# - 🎲 Verschiedene Datentypen mischbar

# %%
# Beispiel 1: Einfache Listen erstellen
# Leere Liste
leere_liste = []
print(f"Leere Liste: {leere_liste}")

# Liste mit Schätzen
schaetze = ["Goldmünzen", "Silberbarren", "Edelsteine"]
print(f"Schatzliste: {schaetze}")

# Liste mit Zahlen
level = [1, 5, 10, 15, 20]
print(f"Level-Liste: {level}")

# Gemischte Liste
mixed = ["Schwert", 25, True, "Schild"]
print(f"Gemischte Liste: {mixed}")

# %%
# Beispiel 2: Auf Listenelemente zugreifen
inventar = ["Schwert", "Schild", "Trank", "Bogen", "Pfeile"]

print("=== Inventar-Zugriff ===")
print(f"Gesamtes Inventar: {inventar}")
print(f"Erstes Item: {inventar[0]}")
print(f"Zweites Item: {inventar[1]}")
print(f"Letztes Item: {inventar[-1]}")

# Länge der Liste
print(f"Anzahl Items: {len(inventar)}")

# Slicing (Ausschnitte)
print(f"Erste 3 Items: {inventar[0:3]}")
print(f"Letzte 2 Items: {inventar[-2:]}")

# %%
# Beispiel 3: Listen in Listen (verschachtelte Listen)
helden_party = [
    ["Aria", "Magierin", 15],
    ["Thorin", "Krieger", 12],
    ["Luna", "Schurkin", 8]
]

print("=== Helden-Party ===")
print(f"Erster Held: {helden_party[0]}")
print(f"Name des ersten Helden: {helden_party[0][0]}")
print(f"Klasse des zweiten Helden: {helden_party[1][1]}")
print(f"Level des dritten Helden: {helden_party[2][2]}")

# %% [markdown]
# ## 📦 Sammlungs-Zauber 2: Elemente verwalten - Der Schatzmeister
#
# **Die wichtigsten Listen-Methoden:**
#
# **Elemente hinzufügen:**
# - `append(element)` - Fügt am Ende hinzu
# - `insert(index, element)` - Fügt an bestimmter Position ein
#
# **Elemente entfernen:**
# - `remove(element)` - Entfernt erstes Vorkommen
# - `pop(index)` - Entfernt und gibt Element zurück
# - `clear()` - Leert die gesamte Liste

# %%
# 🔍 Übungen mit append() und insert()

# Beispiel 1: Elemente hinzufügen
beutesack = []
print(f"Leerer Beutesack: {beutesack}")

# Mit append() am Ende hinzufügen
beutesack.append("Goldring")
print(f"Nach append: {beutesack}")

beutesack.append("Zauberstab")
beutesack.append("Heiltrank")
print(f"Voll gefüllt: {beutesack}")

# Mit insert() an bestimmter Position einfügen
beutesack.insert(0, "Schlüssel")  # Am Anfang
print(f"Nach insert(0): {beutesack}")

beutesack.insert(2, "Amulett")  # An Position 2
print(f"Nach insert(2): {beutesack}")

# %%
# Beispiel 2: Elemente entfernen
inventar = ["Schwert", "Schild", "Trank", "Bogen", "Pfeile", "Trank"]
print(f"Original-Inventar: {inventar}")

# Mit remove() erstes Vorkommen entfernen
inventar.remove("Trank")
print(f"Nach remove('Trank'): {inventar}")

# Mit pop() letztes Element entfernen und zurückgeben
letztes_item = inventar.pop()
print(f"Nach pop(): {inventar}")
print(f"Entferntes Item: {letztes_item}")

# Mit pop(index) bestimmtes Element entfernen
zweites_item = inventar.pop(1)
print(f"Nach pop(1): {inventar}")
print(f"Entferntes Item: {zweites_item}")

# Mit clear() alles löschen
inventar.clear()
print(f"Nach clear(): {inventar}")

# %%
# Beispiel 3: Listen kombinieren
schaetze = ["Gold", "Silber", "Edelsteine"]
waffen = ["Schwert", "Bogen", "Axt"]
tränke = ["Heilung", "Mana", "Stärke"]

print("=== Listen kombinieren ===")
print(f"Schätze: {schaetze}")
print(f"Waffen: {waffen}")
print(f"Tränke: {tränke}")

# Mit + Operator kombinieren
alles = schaetze + waffen + tränke
print(f"Alles kombiniert: {alles}")

# Mit extend() eine Liste zur anderen hinzufügen
schaetze.extend(waffen)
print(f"Schätze erweitert: {schaetze}")

# %% [markdown]
# ## ✨ Sammlungs-Zauber 3: Listen durchsuchen und sortieren
#
# **Suchen und prüfen:**
# - `index(element)` – gibt die Position des Elements zurück
# - `element in liste` – prüft ob Element vorhanden (`True`/`False`)
# - `count(element)` – zählt wie oft ein Element vorkommt
# - `len(liste)` – gibt die Anzahl der Elemente zurück
#
# **Sortieren:**
# - `sort()` – sortiert die Liste (verändert sie direkt)
# - `sorted(liste)` – gibt eine sortierte Kopie zurück
# - `reverse()` – dreht die Reihenfolge um
#
# **Mit Index und Wert gleichzeitig:**
# - `enumerate(liste)` – liefert in einer `for`-Schleife immer **Index und Wert** als Paar:
#
# ```python
# for index, element in enumerate(liste):
#     print(f"Position {index}: {element}")
# ```

# %%
# Beispiel 1: In Listen suchen
inventar = ["Schwert", "Schild", "Trank", "Bogen", "Schwert", "Pfeile"]

print("=== In Listen suchen ===")
print(f"Inventar: {inventar}")

# Mit index() Position finden
position_schild = inventar.index("Schild")
print(f"Schild an Position: {position_schild}")

# Mit in() prüfen ob vorhanden
hat_bogen = "Bogen" in inventar
hat_zauberstab = "Zauberstab" in inventar
print(f"Bogen vorhanden: {hat_bogen}")
print(f"Zauberstab vorhanden: {hat_zauberstab}")

# Mit count() zählen
anzahl_schwerter = inventar.count("Schwert")
print(f"Anzahl Schwerter: {anzahl_schwerter}")

# %%
# Beispiel 2: Listen sortieren
zahlen = [5, 2, 8, 1, 9, 3]
namen = ["Zara", "Anna", "Max", "Berta", "Klaus"]

print("=== Listen sortieren ===")
print(f"Original-Zahlen: {zahlen}")
print(f"Original-Namen: {namen}")

# Mit sort() direkt sortieren
zahlen.sort()
print(f"Zahlen nach sort(): {zahlen}")

# Mit sorted() Kopie sortieren
sortierte_namen = sorted(namen)
print(f"Namen Original: {namen}")
print(f"Namen sortiert: {sortierte_namen}")

# Umgekehrt sortieren
zahlen.sort(reverse=True)
print(f"Zahlen absteigend: {zahlen}")

# Mit reverse() Reihenfolge umkehren
namen.reverse()
print(f"Namen umgekehrt: {namen}")

# %%
# Beispiel 3: Nützliche Listen-Operationen
monster = ["Goblin", "Ork", "Troll", "Drache", "Goblin", "Ork"]

print("=== Listen-Operationen ===")
print(f"Monster-Liste: {monster}")
print(f"Anzahl Monster: {len(monster)}")

# Einzigartige Elemente: set() entfernt Duplikate
# set ist eine Sammlung ohne Reihenfolge und ohne Duplikate
einzigartige_monster = list(set(monster))
print(f"Einzigartige Monster: {einzigartige_monster}")

# Mit enumerate() Index und Wert gleichzeitig
print("\nAlle Monster mit Position:")
for index, m in enumerate(monster):
    print(f"  Position {index}: {m}")

# %% [markdown]
# ## 🛑 Sammlungs-Zauber 4: break und continue – Schleifen steuern
#
# Wenn du eine Liste durchläufst, kannst du die Schleife gezielt steuern:
#
# - **`break`** – Schleife sofort beenden (z.B. wenn du gefunden hast was du suchst)
# - **`continue`** – aktuellen Durchlauf überspringen und mit dem nächsten weitermachen
#
# ```python
# for item in liste:
#     if item == "Gesuchtes":
#         break       # gefunden – aufhören
#     if item == "Überspringen":
#         continue    # dieses Element ignorieren
#     print(item)
# ```

# %%
inventar = ["Trank", "Schwert", "Schlüssel", "Schatz", "Karte"]

# break: Suche beenden sobald Schatz gefunden
print("=== Schatzsuche ===")
for gegenstand in inventar:
    print(f"Prüfe: {gegenstand}")
    if gegenstand == "Schatz":
        print("🎉 Schatz gefunden! Suche beendet.")
        break

# continue: Tränke beim Ausgeben überspringen
print("\n=== Inventar ohne Tränke ===")
for gegenstand in inventar:
    if gegenstand == "Trank":
        continue
    print(f"  - {gegenstand}")

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein Schatzsammler hat versucht, seine Schätze zu organisieren, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1

schaetze = ["Gold", "Silber", "Edelsteine"
print(f"Schätze: {schaetze}")

# %%
# 🐛 Bug #2

inventar = ["Schwert", "Schild", "Trank"]
print(inventar[3])

# %%
# 🐛 Bug #3

level = [1, 5, 10, 15]
level.sort(reverse)
print(level)

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Schatzsammler
#
# **Belohnung:** 300 XP + Magischer Beutel
#
# In der Schatzkammer erstellst du deine erste geordnete Schatzliste.
#
# **Deine Aufgaben:**
#
# 1. **Schatzliste anlegen**
#    - Erstelle eine Liste `schaetze` mit 5 verschiedenen Schätzen (z.B. "Gold", "Kristall", "Amulett")
#    - Gib die Liste mit `print()` aus und nutze eckige Klammern `[]`
#
# 2. **Schätze ergänzen**
#    - Füge mit `append()` drei weitere Schätze an und gib die Liste danach aus
#    - Optional: Nutze `insert(0, "Name")`, um einen Schatz an den Anfang zu setzen
#
# 3. **Schatz entfernen und Position finden**
#    - Entferne mit `remove("Name")` einen Schatz und finde mit `index("Name")` die Position eines anderen
#    - Gib die aktuelle Liste und die gefundene Position aus
#
# 4. **Sortieren und Ausgabe**
#    - Sortiere die Schätze mit `sort()` und gib die Liste sowie `len(schaetze)` aus
#
# **Beispiel-Code zum Starten:**
# ```python
# schaetze = ["Gold", "Kristall", "Amulett", "Schwert", "Trank"]
# print(f"Schätze: {schaetze}")
# schaetze.append("Rune")
# print(f"Nach append: {schaetze}")
# ```
#
# **Bonus-Challenge:** Erstelle eine verschachtelte Liste mit Schatz-Details (Name, Wert, Seltenheit).
#
# **Erwartete Ausgabe:**
# ```
# Schätze: ['Gold', 'Kristall', ...]
# Position von 'Amulett': 2
# Sortierte Schätze: ['Amulett', ...]
# Anzahl: 7
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Inventar-Manager
#
# **Belohnung:** 400 XP + Rucksack der Unendlichkeit
#
# Du verwaltest dein Inventar mit Listen und kleinen Hilfsfunktionen.
#
# **Deine Aufgaben:**
#
# 1. **Inventarliste anlegen**
#    - Erstelle eine Liste `inventar` mit Waffen und Rüstungen (z.B. "Schwert", "Schild", "Trank")
#    - Gib die Liste und `len(inventar)` aus
#
# 2. **Items hinzufügen**
#    - Nutze `append()` und `insert()`, um Items am Ende und an einer Position (z.B. 0) einzufügen
#    - Gib die aktualisierte Liste aus
#
# 3. **Items entfernen und suchen**
#    - Entferne mit `remove()` und `pop()`, finde mit `index()` eine Position und prüfe mit `in`
#    - Gib die Liste und die gefundene Position aus
#
# 4. **Statistik ausgeben**
#    - Gib Anzahl der Items, die aktuelle Liste und optional eine kurze Statuszeile aus
#
# **Beispiel-Code zum Starten:**
# ```python
# inventar = ["Schwert", "Schild", "Trank", "Rüstung"]
# print(f"Inventar: {inventar}, Anzahl: {len(inventar)}")
# inventar.append("Zauberstab")
# inventar.insert(0, "Fackel")
# print(f"Nach Hinzufügen: {inventar}")
# ```
#
# **Bonus-Challenge:** Speichere zu jedem Item einen Wert (z.B. in einer zweiten Liste) und gib eine sortierte Übersicht nach Wert aus.
#
# **Erwartete Ausgabe:**
# ```
# Inventar: ['Schwert', 'Schild', ...], Anzahl: 4
# Position von 'Trank': 2
# Aktuelle Items: 6
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Die Helden-Gilde
#
# **Belohnung:** 500 XP + Gilde-Meister-Urkunde
#
# Du baust eine kleine Helden-Gilde mit verschachtelten Listen und Such- und Sortierfunktionen.
#
# **Deine Aufgaben:**
#
# 1. **Gilden-Liste anlegen**
#    - Erstelle eine verschachtelte Liste `gilde`, in der jedes Element [Name, Klasse, Level] ist
#    - Lege mindestens 3 Helden an und gib die Liste aus
#
# 2. **Helden erweitern**
#    - Füge mit `append()` ein neues Mitglied [Name, Klasse, Level] hinzu und gib die Liste aus
#
# 3. **Helden durchsuchen und sortieren**
#    - Finde die Position eines bestimmten Helden (z.B. nach Namen) und sortiere eine Kopie mit `sorted(..., key=...)` oder eine Namensliste
#    - Gib die gefundene Position und eine kurze sortierte Übersicht aus
#
# 4. **Statistik ausgeben**
#    - Zähle die Mitglieder und gib eine kurze Level- oder Klassenübersicht aus
#
# **Beispiel-Code zum Starten:**
# ```python
# gilde = [
#     ["Aria", "Magierin", 5],
#     ["Thorin", "Krieger", 8],
#     ["Luna", "Schurkin", 3],
# ]
# print(f"Gilde: {gilde}")
# gilde.append(["Nova", "Heiler", 4])
# print(f"Nach Hinzufügen: {len(gilde)} Mitglieder")
# ```
#
# **Bonus-Challenge:** Füge zu jedem Helden eine vierte Spalte „Missionen“ hinzu und sortiere nach Missionen.
#
# **Erwartete Ausgabe:**
# ```
# Gilde: [['Aria', 'Magierin', 5], ...]
# Position von Thorin: 1
# Sortierte Namen: ['Aria', 'Luna', ...]
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten des Schatzmeisters (Reflexion)
#
# Bevor du weiterziehst, denke über diese Fragen nach:
#
# 1. **Warum sind Listen besser als einzelne Variablen?**
#
# 2. **Wann sollte man append() und wann insert() verwenden?**
#
# 3. **Was ist der Unterschied zwischen sort() und sorted()?**
#
# Diskutiere deine Gedanken mit anderen Abenteurern!

# %% [markdown]
# ### 📖 Schatz-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **list** 🗡️: Datentyp für Listen
# - **[]** 📦: Eckige Klammern für Listen
# - **append()** ➕: Am Ende hinzufügen
# - **insert()** 📍: An Position einfügen
# - **remove()** ❌: Element entfernen
# - **pop()** 🎯: Element entfernen und zurückgeben
# - **index()** 🔍: Position finden
# - **in** ✅: Prüfen ob vorhanden
# - **sort()** 📊: Liste sortieren
# - **nested list** 🎲: Verschachtelte Liste

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Hake ab, was du schon kannst:
#
# - ☐ Listen erstellen und Elemente hinzufügen/entfernen
# - ☐ Auf Elemente per Index zugreifen
# - ☐ `len()` für die Listenlänge benutzen
# - ☐ Listen durchsuchen (`in`, `index()`)
# - ☐ Listen sortieren (`sort()`, `sorted()`)
# - ☐ `enumerate()` in einer Schleife benutzen

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Legendär!** Du hast die Schatzkammer der Sammlungen gemeistert!
#
# **Das hast du gelernt:**
# - Listen erstellen und verwalten
# - Elemente hinzufügen und entfernen
# - In Listen suchen und sortieren
# - Verschachtelte Listen erstellen
# - Fortgeschrittene Listen-Operationen
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🎮 **Spiele:** Inventar-Systeme, Highscores, Spiel-Objekte
# - 📱 **Apps:** Kontaktlisten, Playlists, Einkaufswagen
# - 🌐 **Websites:** Menüs, Galerien, Daten-Tabellen
# - 🤖 **KI-Systeme:** Datensätze, Feature-Listen, Ergebnisse
# - 📊 **Wissenschaft:** Messwerte, Experiment-Daten, Ergebnisse
#
# **Als Nächstes:** In Woche 7 lernst du **Module und Bibliotheken**!

# %% [markdown]
# ## 🐉 Boss-Kampf: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Quests sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 XP + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Der Zauber-Generator
#
# **Belohnung:** 500 XP + Zauber-Kristall
#
# Baue ein System, das automatisch Zauber erzeugt, filtert und sortiert.
#
# **Deine Aufgaben:**
#
# 1. **Zauber erzeugen**
#    - Schreibe `generiere_zauber(element, stufe)`, die eine Liste mit Einträgen zurückgibt (z.B. Zaubernamen je nach Element/Stufe)
#    - Gib die Liste mit `return` zurück
#
# 2. **Statistik berechnen**
#    - Erstelle `berechne_zauber_statistik(zauberliste)`, die Länge und optional Durchschnitt zurückgibt
#    - Gib die Werte als Dictionary oder ausgedruckt zurück
#
# 3. **Mehrere Zauber anlegen**
#    - Erstelle eine Liste `zauber` und füge mit einer Schleife mindestens 10 Zauber hinzu (z.B. mit `generiere_zauber("Feuer", i)`)
#    - Nutze `append()` für jeden Eintrag
#
# 4. **Zauber filtern und sortieren**
#    - Schreibe `filtere_zauber(zauberliste, suchbegriff)`, die nur Einträge zurückgibt, die den Suchbegriff enthalten
#    - Sortiere die Liste mit `sort()` oder `sorted()` und gib das Ergebnis aus
#
# 5. **Generator zusammenbauen**
#    - Rufe im Hauptteil alle Funktionen auf und gib eine kurze Zusammenfassung (Anzahl, Statistik, gefilterte Anzahl) aus
#
# **Beispiel-Code zum Starten:**
# ```python
# def generiere_zauber(element, stufe):
#     """Erzeugt einen kleinen Zauber je nach Element und Stufe."""
#     return [f"{element}-{i}" for i in range(stufe)]
#
# zauber = []
# for i in range(1, 11):
#     zauber.append(generiere_zauber("Feuer", i))
# print(f"Anzahl Zauber: {len(zauber)}")
# ```
#
# **Bonus-Challenge:** Füge zufällige Attribute (z.B. Mana-Kosten, Reichweite) hinzu und prüfe die Daten auf Gültigkeit.
#
# **Erwartete Ausgabe:**
# ```
# Anzahl Zauber: 10
# Statistik: Länge 10, durchschnittliche Größe 5.5
# Gefilterte Einträge: 3
# Sortierte Liste: [...]
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Der Guilden-Manager
#
# **Belohnung:** 600 XP + Gildenmeister-Titel
#
# Verwalte Abteilungen und Mitglieder einer Magier-Gilde mit Listen und einfachen Funktionen.
#
# **Deine Aufgaben:**
#
# 1. **Abteilungen anlegen**
#    - Erstelle `erstelle_abteilungen(anzahl_abteilungen, mitglieder_pro_abteilung)`, die eine verschachtelte Liste zurückgibt (jede Abteilung eine Liste mit Platzhaltern wie "frei")
#    - Gib die verschachtelte Liste zurück
#
# 2. **Mitglieder platzieren**
#    - Schreibe `platziere_mitglied(abteilungen, abteil_index, name)`, die an der angegebenen Abteilungs-Position ein Mitglied einträgt
#    - Nutze Indexzugriff und aktualisiere die Liste
#
# 3. **Mana verteilen**
#    - Erstelle `verteile_mana(abteilungen, totales_mana)`, die Mana gleichmäßig oder nach Belegung auf die Abteilungen verteilt
#    - Gib eine Liste mit Mana pro Abteilung zurück
#
# 4. **Übersicht ausgeben**
#    - Schreibe `zeige_uebersicht(abteilungen)`, die alle Abteilungen und ihre Mitglieder formatiert ausgibt
#    - Gib am Ende eine kurze Zusammenfassung (Anzahl Abteilungen, Gesamtplätze) aus
#
# **Beispiel-Code zum Starten:**
# ```python
# def erstelle_abteilungen(anzahl_abteilungen, mitglieder_pro_abteilung):
#     """Erstellt eine verschachtelte Liste für Abteilungen."""
#     return [["frei"] * mitglieder_pro_abteilung for _ in range(anzahl_abteilungen)]
#
# gilde = erstelle_abteilungen(3, 4)
# print(f"Gilde: {gilde}")
# ```
#
# **Bonus-Challenge:** Simuliere zufällige Quests (z.B. "Drache besiegen") und eine Funktion, die sie als erledigt markiert.
#
# **Erwartete Ausgabe:**
# ```
# Gilde: [['frei', 'frei', 'frei', 'frei'], ...]
# Abteilung 1: Aria, Thorin, frei, frei
# Gesamt: 3 Abteilungen, 12 Plätze
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Die Quest-Datenbank
#
# **Belohnung:** 400 XP + Quest-Buch
#
# Verwalte Quests in einer Liste: anlegen, suchen, filtern und auswerten.
#
# **Deine Aufgaben:**
#
# 1. **Quest anlegen**
#    - Erstelle `erstelle_quest(name, ziel, schwierigkeit)`, die ein Dictionary mit "name", "ziel", "schwierigkeit" (und optional "status") zurückgibt
#    - Gib das Dictionary mit `return` zurück
#
# 2. **Quest zur Liste hinzufügen**
#    - Erstelle eine Liste `quests` und schreibe `fuege_quest_hinzu(quest, questliste)`, die mit `append()` hinzufügt und eine Bestätigung ausgibt
#
# 3. **Quests suchen**
#    - Schreibe `suche_quests(questliste, suchbegriff)`, die alle Quests zurückgibt, in deren Name oder Ziel der Suchbegriff vorkommt
#
# 4. **Nach Status filtern**
#    - Erstelle `filtere_nach_status(questliste, status)` und gib die gefilterte Liste zurück
#
# 5. **Statistik ausgeben**
#    - Schreibe `quest_statistik(questliste)`, die Anzahl und optional Verteilung nach Schwierigkeit ausgibt; rufe im Hauptteil alle Funktionen auf
#
# **Beispiel-Code zum Starten:**
# ```python
# def erstelle_quest(name, ziel, schwierigkeit):
#     """Erstellt ein Quest-Dictionary."""
#     return {"name": name, "ziel": ziel, "schwierigkeit": schwierigkeit, "status": "offen"}
#
# quests = []
# q = erstelle_quest("Der verlorene Schlüssel", "Turm", 2)
# quests.append(q)
# print(f"Quests: {len(quests)}")
# ```
#
# **Bonus-Challenge:** Füge zu jeder Quest ein Feld "belohnung" oder "erfolg" hinzu und gib eine Erfolgsstatistik aus.
#
# **Erwartete Ausgabe:**
# ```
# Quest hinzugefügt: Der verlorene Schlüssel
# Gefundene Quests: 2
# Nach Status 'offen': 3 Quests
# Statistik: 5 Quests, 3 offen
# ```

# %%
# 🐉 Deine Lösung hier:

print()
print("🎉 +400 XP: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Wächter der unendlichen Sammlungen besiegt!")
print("⭐ Titel erhalten: Meister der Schatzsammlungen")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 6 gemeistert!")
print("📚 Nächste Woche: Module und Bibliotheken (math, random)!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen:

# %%
# ✅ Lösung Bug #1: Fehlende schließende Klammer

# Problem: Liste nicht geschlossen
schaetze = ["Gold", "Silber", "Edelsteine"]
print(f"Schätze: {schaetze}")

# %%
# ✅ Lösung Bug #2: Index außerhalb des Bereichs

# Problem: Index 3 existiert nicht (nur 0,1,2)
inventar = ["Schwert", "Schild", "Trank"]
print(inventar[2])  # Letztes Element

# %%
# ✅ Lösung Bug #3: Falscher Parameter für sort()

# Problem: reverse ist ein Boolean, keine separate Variable
level = [1, 5, 10, 15]
level.sort(reverse=True)
print(level)
