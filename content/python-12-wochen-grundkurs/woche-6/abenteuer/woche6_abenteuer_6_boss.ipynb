# %% [markdown]
# # 🐉 Boss-Quests – 🗡️ Woche 6 – Listen: Die Schatzkammer der Sammlungen
#
# > ⚠️ Schwieriger! Kombiniert alles aus dieser Woche.

# %% [markdown]
# ## 🐉 Boss-Kampf: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Quests sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 XP + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Der Zauber-Generator
#
# **Belohnung:** 500 XP + Zauber-Kristall
#
# Baue ein System, das automatisch Zauber erzeugt, filtert und sortiert.
#
# **Schritt 1 – Zauber erzeugen:**
# Schreibe `generiere_zauber(element, stufe)`, die eine Liste mit Einträgen zurückgibt (z.B. Zaubernamen je nach Element/Stufe) und gib die Liste mit `return` zurück
#
# **Schritt 2 – Statistik berechnen:**
# Erstelle `berechne_zauber_statistik(zauberliste)`, die Länge und optional Durchschnitt zurückgibt und gib die Werte als Dictionary oder ausgedruckt zurück
#
# **Schritt 3 – Mehrere Zauber anlegen:**
# Erstelle eine Liste `zauber` und füge mit einer Schleife mindestens 10 Zauber hinzu (z.B. mit `generiere_zauber("Feuer", i)`) und nutze `append()` für jeden Eintrag
#
# **Schritt 4 – Zauber filtern und sortieren:**
# Schreibe `filtere_zauber(zauberliste, suchbegriff)`, die nur Einträge zurückgibt, die den Suchbegriff enthalten und sortiere die Liste mit `sort()` oder `sorted()` und gib das Ergebnis aus
#
# **Schritt 5 – Generator zusammenbauen:**
# Rufe im Hauptteil alle Funktionen auf und gib eine kurze Zusammenfassung (Anzahl, Statistik, gefilterte Anzahl) aus
#
# **Bonus:** Füge zufällige Attribute (z.B. Mana-Kosten, Reichweite) hinzu und prüfe die Daten auf Gültigkeit.

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Der Guilden-Manager
#
# **Belohnung:** 600 XP + Gildenmeister-Titel
#
# Verwalte Abteilungen und Mitglieder einer Magier-Gilde mit Listen und einfachen Funktionen.
#
# **Schritt 1 – Abteilungen anlegen:**
# Erstelle `erstelle_abteilungen(anzahl_abteilungen, mitglieder_pro_abteilung)`, die eine verschachtelte Liste zurückgibt (jede Abteilung eine Liste mit Platzhaltern wie "frei") und gib die verschachtelte Liste zurück
#
# **Schritt 2 – Mitglieder platzieren:**
# Schreibe `platziere_mitglied(abteilungen, abteil_index, name)`, die an der angegebenen Abteilungs-Position ein Mitglied einträgt und nutze Indexzugriff und aktualisiere die Liste
#
# **Schritt 3 – Mana verteilen:**
# Erstelle `verteile_mana(abteilungen, totales_mana)`, die Mana gleichmäßig oder nach Belegung auf die Abteilungen verteilt und gib eine Liste mit Mana pro Abteilung zurück
#
# **Schritt 4 – Übersicht ausgeben:**
# Schreibe `zeige_uebersicht(abteilungen)`, die alle Abteilungen und ihre Mitglieder formatiert ausgibt und gib am Ende eine kurze Zusammenfassung (Anzahl Abteilungen, Gesamtplätze) aus
#
# **Bonus:** Simuliere zufällige Quests (z.B. "Drache besiegen") und eine Funktion, die sie als erledigt markiert.

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Die Quest-Datenbank
#
# **Belohnung:** 400 XP + Quest-Buch
#
# Verwalte Quests in einer Liste: anlegen, suchen, filtern und auswerten.
#
# **Schritt 1 – Quest anlegen:**
# Erstelle `erstelle_quest(name, ziel, schwierigkeit)`, die ein Dictionary mit "name", "ziel", "schwierigkeit" (und optional "status") zurückgibt und gib das Dictionary mit `return` zurück
#
# **Schritt 2 – Quest zur Liste hinzufügen:**
# Erstelle eine Liste `quests` und schreibe `fuege_quest_hinzu(quest, questliste)`, die mit `append()` hinzufügt und eine Bestätigung ausgibt
#
# **Schritt 3 – Quests suchen:**
# Schreibe `suche_quests(questliste, suchbegriff)`, die alle Quests zurückgibt, in deren Name oder Ziel der Suchbegriff vorkommt
#
# **Schritt 4 – Nach Status filtern:**
# Erstelle `filtere_nach_status(questliste, status)` und gib die gefilterte Liste zurück
#
# **Schritt 5 – Statistik ausgeben:**
# Schreibe `quest_statistik(questliste)`, die Anzahl und optional Verteilung nach Schwierigkeit ausgibt; rufe im Hauptteil alle Funktionen auf
#
# **Bonus:** Füge zu jeder Quest ein Feld "belohnung" oder "erfolg" hinzu und gib eine Erfolgsstatistik aus.

# %%
# 🐉 Deine Lösung hier:

print()
print("🎉 +400 XP: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Wächter der unendlichen Sammlungen besiegt!")
print("⭐ Titel erhalten: Meister der Schatzsammlungen")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 6 gemeistert!")
print("📚 Nächste Woche: Module und Bibliotheken (math, random)!")

# %% [markdown]
# ---
#
# 🎊 **Glückwunsch!** Du hast alle Boss-Quests dieser Woche gemeistert!
#
# **Als Nächstes:** Woche 7 wartet schon!
