# %% [markdown]
# # 🚀 Woche 7 – Module und Bibliotheken: Die Modul-Banken der Raumstation
#
# **Cyber Credits zu verdienen:** 1000 Punkte
# **Boss:** Der Code-Archivar der unendlichen Funktionen

# %% [markdown]
# ## 🌟 Die Mission beginnt: Das Modul-Zentral der Nebula-7
#
# Willkommen an Bord der Raumstation Nebula-7! Du erreichst das **Modul-Zentral** – ein hochmoderner Sektor, in dem unendlich viele Code-Funktionen gespeichert und organisiert werden. In dieser Woche lernst du die drei **Arten der Modul-Nutzung**:
#
# **Deine Mission:**
# - Meistere den **Modul-Import** mit import und from
# - Beherrsche die **math-Funktionen** für Berechnungen
# - Lerne die **random-Funktionen** für Zufallsereignisse
#
# **Einmal importiert, für immer verfügbar!** Die Macht der Module wartet...

# %% [markdown]
# ## 📚 Modul-Sammlung 1: Der Import-Protokoll - Das erste Modul
#
# **Was es ist:** Ein Modul ist eine Sammlung von vordefinierten Funktionen, die du in dein Programm laden kannst.
#
# **Die Anatomie eines Imports:**
# ```python
# # Ganzes Modul importieren
# import math
#
# # Mit Alias importieren
# import math as m
#
# # Nur bestimmte Funktionen importieren
# from math import pi, sqrt
# ```
#
# **Schritt-für-Schritt-Erklärung:**
# 1. **`import`** - Schlüsselwort zum Laden
# 2. **`math`** - Name des Moduls
# 3. **`as`** - Optionaler Alias/Spitzname
# 4. **`from`** - Importiert spezifische Funktionen
#
# **Warum so nützlich:**
# - 🎯 Code nicht neu erfinden müssen
# - 🔍 Professionelle, optimierte Funktionen
# - ⚡ Dein Code bleibt übersichtlich
# - 🎲 Zugriff auf spezialisierte Werkzeuge

# %%
# Beispiel 1: Module importieren
# Ganzes Modul importieren
import math
print(f"Pi aus math: {math.pi}")

# Mit Alias importieren
import random as r
print(f"Zufallszahl: {r.randint(1, 10)}")

# Nur bestimmte Funktionen importieren
from math import sqrt, sin, cos
print(f"Wurzel aus 16: {sqrt(16)}")
print(f"Sinus 90°: {sin(1.57)}")
print(f"Kosinus 0°: {cos(0)}")

# %%
# Beispiel 2: Verschiedene Import-Methoden vergleichen
# Methode 1: import math
import math
print("Methode 1 - import math:")
print(f"  math.pi: {math.pi}")
print(f"  math.sqrt(25): {math.sqrt(25)}")

# Methode 2: import math as m
import math as m
print("\nMethode 2 - import math as m:")
print(f"  m.pi: {m.pi}")
print(f"  m.sqrt(25): {m.sqrt(25)}")

# Methode 3: from math import pi, sqrt
from math import pi, sqrt
print("\nMethode 3 - from math import pi, sqrt:")
print(f"  pi: {pi}")
print(f"  sqrt(25): {sqrt(25)}")

# %%
# Beispiel 3: Mehrere Module importieren
import math
import random
import time

# Berechne eine zufällige Flugdauer
distanz = 1000  # Lichtjahre
geschwindigkeit = random.uniform(0.1, 0.9)  # Bruchteil der Lichtgeschwindigkeit
flugzeit = distanz / geschwindigkeit

print("=== Raumflug-Simulation ===")
print(f"Distanz: {distanz} Lichtjahre")
print(f"Geschwindigkeit: {geschwindigkeit:.2f}c")
print(f"Flugzeit: {flugzeit:.1f} Jahre")
print(f"Warte 2 Sekunden...")
time.sleep(2)
print(f"Ankunft im Zielsystem!")

# %% [markdown]
# ## 📦 Modul-Sammlung 2: Das math-Modul - Der Berechnungs-Kern
#
# **Die wichtigsten math-Funktionen:**
#
# **Konstanten:**
# - `math.pi` - Die Zahl Pi (3.14159...)
# - `math.e` - Eulersche Zahl (2.71828...)
# - `math.inf` - Unendlich
#
# **Grundfunktionen:**
# - `math.sqrt(x)` - Quadratwurzel
# - `math.pow(x, y)` - x hoch y
# - `math.ceil(x)` - Aufrunden
# - `math.floor(x)` - Abrunden
# - `math.fabs(x)` - Absolutwert

# %%
# 🔍 Übungen mit math-Konstanten
import math

print("=== Mathematische Konstanten ===")
print(f"Pi (π): {math.pi}")
print(f"Eulersche Zahl (e): {math.e}")
print(f"Unendlich: {math.inf}")
print(f"Tau (2π): {math.tau}")

# Praktische Anwendung: Kreisberechnungen
radius = 10
umfang = 2 * math.pi * radius
flaeche = math.pi * radius ** 2
print(f"\nKreis mit r={radius}:")
print(f"  Umfang: {umfang:.2f}")
print(f"  Fläche: {flaeche:.2f}")

# %%
# Beispiel 2: Mathematische Grundfunktionen
import math

print("=== Mathematische Funktionen ===")

# Wurzel und Potenzen
print(f"sqrt(16): {math.sqrt(16)}")
print(f"pow(2, 3): {math.pow(2, 3)}")
print(f"2**3: {2**3}")

# Runden
zahl = 3.7
print(f"\nZahl: {zahl}")
print(f"round({zahl}): {round(zahl)}")
print(f"math.ceil({zahl}): {math.ceil(zahl)}")
print(f"math.floor({zahl}): {math.floor(zahl)}")

# Absolutwert
print(f"\nmath.fabs(-5.5): {math.fabs(-5.5)}")
print(f"abs(-5.5): {abs(-5.5)}")

# %%
# Beispiel 3: Fortgeschrittene math-Funktionen
import math

print("=== Fortgeschrittene Funktionen ===")

# Winkelfunktionen (in Bogenmaß!)
winkel_grad = 45
winkel_rad = math.radians(winkel_grad)
print(f"{winkel_grad}° = {winkel_rad:.3f} rad")
print(f"sin({winkel_grad}°): {math.sin(winkel_rad):.3f}")
print(f"cos({winkel_grad}°): {math.cos(winkel_rad):.3f}")
print(f"tan({winkel_grad}°): {math.tan(winkel_rad):.3f}")

# Logarithmen
print(f"\nlog(10): {math.log(10):.3f}")
print(f"log10(100): {math.log10(100)}")
print(f"log2(8): {math.log2(8)}")

# Spezielle Funktionen
print(f"\nfactorial(5): {math.factorial(5)}")
print(f"gcd(24, 36): {math.gcd(24, 36)}")
print(f"lcm(12, 15): {math.lcm(12, 15)}")

# %% [markdown]
# ## ✨ Modul-Sammlung 3: Das random-Modul - Der Zufalls-Generator
#
# **Die mächtigsten Zufalls-Funktionen:**
#
# **Zahlen erzeugen:**
# - `random.randint(a, b)` - Zufällige Ganzzahl von a bis b
# - `random.uniform(a, b)` - Zufällige Kommazahl von a bis b
# - `random.random()` - Zufallszahl zwischen 0 und 1
#
# **Aus Listen wählen:**
# - `random.choice(liste)` - Ein zufälliges Element
# - `random.choices(liste, k=n)` - n zufällige Elemente
# - `random.shuffle(liste)` - Liste mischen
#
# **Verteilungen:**
# - `random.gauss(mu, sigma)` - Normalverteilung
# - `random.expovariate(lambda)` - Exponentialverteilung

# %%
# Beispiel 1: Zufallszahlen erzeugen
import random

print("=== Zufallszahlen ===")

# Ganzzahlen
print(f"Zufällige Zahl 1-6: {random.randint(1, 6)}")
print(f"Zufällige Zahl 0-100: {random.randint(0, 100)}")

# Kommazahlen
print(f"Zufallszahl 0-1: {random.random():.3f}")
print(f"Zufallszahl 10-20: {random.uniform(10, 20):.2f}")

# Mit Seeds reproduzierbar
random.seed(42)
print(f"Mit Seed 42: {random.randint(1, 100)}")
random.seed(42)
print(f"Mit Seed 42: {random.randint(1, 100)} (gleiches Ergebnis!)")

# %%
# Beispiel 2: Aus Listen wählen
import random

print("=== Zufallsauswahl aus Listen ===")

# Planeten im System
planeten = ["Merkur", "Venus", "Erde", "Mars", "Jupiter", "Saturn"]
print(f"Alle Planeten: {planeten}")

# Ein zufälliger Planet
ziel = random.choice(planeten)
print(f"Zielplanet: {ziel}")

# Drei zufällige Planeten
flotte = random.choices(planeten, k=3)
print(f"Flottenziele: {flotte}")

# Liste mischen
reihenfolge = planeten.copy()
random.shuffle(reihenfolge)
print(f"Gemischte Reihenfolge: {reihenfolge}")

# %%
# Beispiel 3: Fortgeschrittene Zufallsfunktionen
import random
import math

print("=== Fortgeschrittene Zufallsfunktionen ===")

# Normalverteilung für Energiewerte
print("Energieverbrauch (Normalverteilung):")
for i in range(5):
    energie = random.gauss(100, 20)  # Mittelwert 100, Stdabw 20
    print(f"  System {i+1}: {max(0, energie):.1f} MW")

# Exponentialverteilung für Wartezeiten
print("\nWartezeiten (Exponentialverteilung):")
for i in range(5):
    warten = random.expovariate(0.1)  # Lambda = 0.1
    print(f"  Wartezeit {i+1}: {warten:.1f} Minuten")

# Zufälliger Punkt im Kreis
def zufalls_punkt_kreis(radius):
    winkel = random.uniform(0, 2 * math.pi)
    r = radius * math.sqrt(random.random())
    x = r * math.cos(winkel)
    y = r * math.sin(winkel)
    return x, y

x, y = zufalls_punkt_kreis(10)
print(f"\nZufälliger Punkt im Kreis r=10: ({x:.2f}, {y:.2f})")

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein Techniker hat versucht, die Module zu verwenden, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1

result = math.sqrt(9)
print(f"Ergebnis: {result}")

# %%
# 🐛 Bug #2

import random
zahl = random.zahl(1, 10)
print(f"Zufallszahl: {zahl}")

# %%
# 🐛 Bug #3

import math
winkel = 90
sinus = sin(math.radians(winkel))
print(f"Sinus von {winkel}°: {sinus}")

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Modul-Importer
#
# **Belohnung:** 300 Cyber Credits + Daten-Chip
#
# Im Modul-Zentral der Nebula-7 lernst du, wie du Module lädst und mit Aliasen arbeitest.
#
# **Deine Aufgaben:**
#
# 1. **Module importieren**
#    - Lade die Module `math`, `random` und `time` mit passenden Aliasen (z.B. `import math as m`)
#    - Gib jeweils eine Konstante oder Funktion aus jedem Modul aus (z.B. `math.pi`, `random.randint(1, 10)`)
#
# 2. **Wartezeit-Simulation**
#    - Erstelle eine kleine Funktion oder ein Skript, das eine zufällige Sekundenzahl (1–3) mit `random` erzeugt und `time.sleep()` nutzt
#    - Gib vor und nach der Wartezeit eine kurze Meldung aus
#
# 3. **Flugbahn-Berechnung**
#    - Nutze `math.sin` und `math.pi`, um für einen Winkel (z.B. 90° in Bogenmaß) eine Höhe oder einen Wert zu berechnen
#    - Gib das Ergebnis formatiert aus
#
# 4. **Crew-Generator**
#    - Erstelle eine Namensliste mit 3–5 Crew-Namen und wähle mit `random.choice()` einen zufälligen Namen aus
#    - Gib den ausgewählten Namen aus
#
# **Beispiel-Code zum Starten:**
# ```python
# import math as m
# import random as r
# import time as t
#
# print(f"Pi: {m.pi}")
# print(f"Zufall 1-10: {r.randint(1, 10)}")
# sekunden = r.randint(1, 3)
# print(f"Warte {sekunden} Sekunden...")
# t.sleep(sekunden)
# print("Bereit!")
# ```
#
# **Bonus-Challenge:**
# - Füge eine weitere Funktion mit dem `datetime`-Modul hinzu (z.B. aktuelle Uhrzeit anzeigen).
#
# **Erwartete Ausgabe:**
# ```
# Pi: 3.141592653589793
# Zufall 1-10: 7
# Warte 2 Sekunden...
# Bereit!
# Crew-Mitglied: Captain Alex
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Berechnungs-Kern
#
# **Belohnung:** 400 Cyber Credits + Navigations-Gerät
#
# Du nutzt das math-Modul für Kreisberechnungen, Winkelumrechnung und Wurzeln.
#
# **Deine Aufgaben:**
#
# 1. **Kreis-Berechnung**
#    - Schreibe eine Funktion oder ein Skript, das für einen Radius Umfang und Fläche mit `math.pi` berechnet
#    - Gib Radius, Umfang und Fläche formatiert aus
#
# 2. **Zufalls-Zahlen und Summe**
#    - Erzeuge mit `random.randint(1, 100)` fünf Zufallszahlen und speichere sie (z.B. in einer Liste)
#    - Berechne die Summe und gib die Zahlen sowie die Summe aus
#
# 3. **Winkel-Umrechnung**
#    - Wandle 90°, 180° und 270° mit `math.radians()` in Bogenmaß um
#    - Gib Grad und Bogenmaß für jeden Winkel aus
#
# 4. **Wurzel-Ziehen**
#    - Berechne mit `math.sqrt()` die Wurzeln von 4, 9, 16 und 25
#    - Gib die Ergebnisse übersichtlich aus
#
# **Beispiel-Code zum Starten:**
# ```python
# import math
# import random
#
# radius = 10
# umfang = 2 * math.pi * radius
# flaeche = math.pi * radius ** 2
# print(f"Radius {radius}: Umfang {umfang:.2f}, Fläche {flaeche:.2f}")
#
# zahlen = [random.randint(1, 100) for _ in range(5)]
# print(f"Zufallszahlen: {zahlen}, Summe: {sum(zahlen)}")
# ```
#
# **Bonus-Challenge:**
# - Füge trigonometrische Berechnungen hinzu (z.B. sin, cos für 45°).
#
# **Erwartete Ausgabe:**
# ```
# Radius 10: Umfang 62.83, Fläche 314.16
# Zufallszahlen: [23, 67, 12, 89, 34], Summe: 225
# 90° = 1.57 rad | 180° = 3.14 rad | 270° = 4.71 rad
# sqrt(4)=2.0, sqrt(9)=3.0, ...
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Der Zufalls-Simulator
#
# **Belohnung:** 500 Cyber Credits + Crew-Meister-Urkunde
#
# Du baust ein kleines Simulationssystem mit Planeten, Wetter und Energieverbrauch.
#
# **Deine Aufgaben:**
#
# 1. **Planetenauswahl**
#    - Erstelle eine Liste mit 5–6 Planeten-Namen und wähle mit `random.choice()` einen zufälligen Zielplaneten aus
#    - Gib die Liste und den gewählten Planeten aus
#
# 2. **Wetter-Simulation**
#    - Erzeuge mit `random.uniform(-50, 50)` drei Temperaturwerte (z.B. für verschiedene Sektoren) und runde sie auf eine Dezimalstelle
#    - Gib die Temperaturen mit kurzer Beschreibung aus
#
# 3. **Energie-Verbrauch**
#    - Simuliere 3 Systeme mit je einem zufälligen Verbrauch zwischen 50 und 150 MW (mit `random.randint` oder `random.uniform`)
#    - Gib Systemname und Verbrauch aus und berechne den Gesamtverbrauch
#
# 4. **Flotten-Generator**
#    - Erstelle 3 Schiffsnamen mit zugehöriger zufälliger Stärke (1–10) und speichere sie (z.B. als Liste von Tupeln oder Dicts)
#    - Gib alle Schiffe mit ihrer Stärke aus
#
# **Beispiel-Code zum Starten:**
# ```python
# import random
#
# planeten = ["Merkur", "Venus", "Erde", "Mars", "Jupiter"]
# ziel = random.choice(planeten)
# print(f"Zielplanet: {ziel}")
#
# temp1 = round(random.uniform(-50, 50), 1)
# print(f"Sektor Alpha: {temp1}°C")
# ```
#
# **Bonus-Challenge:**
# - Füge eine Variable mit Normalverteilung hinzu (z.B. `random.gauss(100, 20)` für Energiewerte).
#
# **Erwartete Ausgabe:**
# ```
# Zielplanet: Mars
# Temperaturen: -12.3°C, 22.1°C, 45.0°C
# System 1: 87 MW, System 2: 120 MW, System 3: 65 MW — Gesamt: 272 MW
# Schiffe: [('Nebula-1', 7), ('Star-2', 3), ('Cargo-3', 9)]
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten des Kommandanten (Reflexion)
#
# Bevor du weiterfliegst, denke über diese Fragen nach:
#
# 1. **Warum sollte man Module verwenden statt alles selbst zu programmieren?**
#
# 2. **Was ist der Unterschied zwischen `import math` und `from math import sqrt`?**
#
# 3. **Wann verwendet man `random.choice()` und wann `random.randint()`?**
#
# Diskutiere deine Gedanken mit anderen Kommandanten!

# %% [markdown]
# ### 📖 Tech-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **import** 📦: Modul laden
# - **from** 🎯: Selektiver Import
# - **as** 🏷️: Alias/Spitzname
# - **math** 🔢: Mathematik-Modul
# - **random** 🎲: Zufalls-Modul
# - **pi** ⭕: Kreiszahl
# - **sqrt()** √: Wurzelziehen
# - **randint()** 🎯: Zufällige Ganzzahl
# - **choice()** 🎲: Zufällige Auswahl
# - **seed()** 🌱: Zufalls-Seed

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ✅ Module mit import laden
# - ✅ Aliase für Module verwenden
# - ✅ Spezielle Funktionen importieren
# - ✅ math-Modul für Berechnungen nutzen
# - ✅ random-Modul für Zufallszahlen verwenden
# - ✅ Module in eigenen Programmen einsetzen
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die Boss-Quests!

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Exzellent!** Du hast die Modul-Banken der Raumstation gemeistert!
#
# **Das hast du gelernt:**
# - Module importieren und verwenden
# - Mathematische Berechnungen durchführen
# - Zufallsereignisse simulieren
# - Verschiedene Import-Methoden kennen
# - Professionelle Code-Bibliotheken nutzen
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🚀 **Raumfahrt:** Flugbahnen, Energieberechnungen, Simulationen
# - 📱 **Apps:** Spiele, Zufallsgeneratoren, Berechnungen
# - 🌐 **Websites:** Statistiken, Visualisierungen, Algorithmen
# - 🤖 **KI-Systeme:** Mathematische Modelle, Zufallsprozesse
# - 📊 **Wissenschaft:** Datenanalyse, Simulationen, Berechnungen
#
# **Als Nächstes:** In Woche 8 lernst du **Dictionaries und Tupel**!

# %% [markdown]
# ## 🐉 Boss-Kampf: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Quests sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 Cyber Credits + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Der Universum-Simulator
#
# **Belohnung:** 500 Cyber Credits + Simulations-Kern
#
# Du baust einen kleinen Universum-Simulator mit Sternsystemen, Gravitation und bewohnbaren Planeten.
#
# **Deine Aufgaben:**
#
# 1. **Sternsystem-Generator**
#    - Erstelle eine Funktion `erstelle_sternsystem(anzahl_planeten, zentralstern_typ)`, die eine Liste mit Planeten-Namen (z.B. mit `random.choice` aus einer Vorlage) zurückgibt
#    - Gib die Liste der Planeten und den Zentralstern-Typ aus
#
# 2. **Gravitations-Berechnung**
#    - Schreibe eine Funktion `berechne_gravitation(masse1, masse2, distanz)` mit der Formel F = G * m1 * m2 / r² (G z.B. 6.67e-11); nutze `math` für Potenzen
#    - Gib die Gravitationskraft für ein Beispiel (z.B. zwei Massen, eine Distanz) aus
#
# 3. **Lebenswahrscheinlichkeit und bewohnbare Planeten**
#    - Erstelle eine Funktion, die aus Temperatur, Wasser und Atmosphäre eine Wahrscheinlichkeit (0–1) berechnet (z.B. mit `random.uniform` oder einfacher Formel)
#    - Erstelle eine Funktion, die aus einer Planetenliste die „bewohnbaren“ filtert (z.B. Wahrscheinlichkeit > Schwellwert)
#    - Gib die gefilterte Liste aus
#
# 4. **Hauptprogramm**
#    - Simuliere 5–10 Sternsysteme mit deinen Funktionen, berechne für ein Beispiel die Gravitation und zeige eine kurze Statistik (z.B. wie viele Planeten pro System, wie viele „bewohnbar“)
#
# **Beispiel-Code zum Starten:**
# ```python
# import math
# import random
#
# def erstelle_sternsystem(anzahl_planeten, zentralstern_typ):
#     namen = ["Alpha", "Beta", "Gamma", "Delta", "Epsilon"]
#     return [random.choice(namen) + f"-{i}" for i in range(anzahl_planeten)]
#
# def berechne_gravitation(masse1, masse2, distanz):
#     G = 6.67e-11
#     return G * masse1 * masse2 / (distanz ** 2)
# ```
#
# **Bonus-Challenge:**
# - Füge zufällige „Lebensformen“ mit Eigenschaften (z.B. Name, Typ) zu bewohnbaren Planeten hinzu.
#
# **Erwartete Ausgabe:**
# ```
# Sternsystem: ['Alpha-0', 'Beta-1', 'Gamma-2'] (Typ: Gelb)
# Gravitation: 1.23e-10 N
# Bewohnbare Planeten: 2 von 5
# Statistik: 10 Systeme, 3 bewohnbar gefunden
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Der Quantencomputer
#
# **Belohnung:** 600 Cyber Credits + Quanten-Prozessor
#
# Du simulierst vereinfacht „Quantenzustände“ und Zufalls-Messungen mit dem random-Modul.
#
# **Deine Aufgaben:**
#
# 1. **Quantenzustand (simuliert)**
#    - Erstelle eine Funktion `erstelle_quantenzustand(anzahl_qubits)`, die eine Liste von Zufallswerten (0 oder 1) mit `random.randint(0, 1)` für jedes Qubit zurückgibt
#    - Gib den Zustand aus
#
# 2. **Quantenmessung (simuliert)**
#    - Erstelle eine Funktion `messung(quantenzustand, qubit_index)`, die den Wert des Qubits an der Stelle `qubit_index` zurückgibt (oder zufällig 0/1, wenn du „Kollaps“ simulieren willst)
#    - Gib das Messergebnis für ein Beispiel aus
#
# 3. **Verschränkung (simuliert)**
#    - Erstelle eine Funktion `verschraenke(q1, q2)`, die zwei „Qubits“ (z.B. zwei 0/1-Werte) nimmt und einen gemeinsamen Zustand zurückgibt (z.B. Liste [q1, q2] oder ein Tupel); optional: bei Messung beide auf gleichen Wert setzen mit `random.randint(0, 1)`
#    - Gib den verschränkten Zustand aus
#
# 4. **Demo**
#    - Erzeuge einen Quantenzustand mit 3–5 Qubits, führe „Messungen“ durch und zeige eine kurze Erklärung (z.B. print) zu jedem Schritt
#
# **Beispiel-Code zum Starten:**
# ```python
# import random
#
# def erstelle_quantenzustand(anzahl_qubits):
#     return [random.randint(0, 1) for _ in range(anzahl_qubits)]
#
# def messung(quantenzustand, qubit_index):
#     return quantenzustand[qubit_index]
# ```
#
# **Bonus-Challenge:**
# - Simuliere einen einfachen „Quantenalgorithmus“: z.B. mehrfach Zufallsbits erzeugen und eine „Parität“ (Summe mod 2) ausgeben.
#
# **Erwartete Ausgabe:**
# ```
# Quantenzustand: [1, 0, 1, 0, 1]
# Messung Qubit 2: 1
# Verschränkter Zustand: (0, 1)
# Demo: 5 Qubits erzeugt, Messungen an 0 und 2 durchgeführt.
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Die KI-Matrix
#
# **Belohnung:** 400 Cyber Credits + KI-Kern
#
# Du baust eine vereinfachte „KI“-Simulation mit Gewichten (Zufallszahlen) und einfacher Vorhersage.
#
# **Deine Aufgaben:**
#
# 1. **Netzwerk-Struktur**
#    - Erstelle eine Funktion `erstelle_netz(input_size, hidden_size, output_size)`, die ein „Netz“ als verschachtelte Listen zurückgibt: z.B. [[random.uniform(-1,1) for _ in range(hidden_size)] for _ in range(input_size)] für eine Gewichtsmatrix
#    - Gib die Struktur (z.B. Form/Länge) aus
#
# 2. **Training (simuliert)**
#    - Schreibe eine Funktion `trainiere(netzwerk, epochen)`, die in einer Schleife `epochen`-mal Zufallszahlen mit `random.uniform` ändert (z.B. ein Gewicht zufällig anpassen), um „Training“ zu simulieren
#    - Gib nach dem Training eine kurze Meldung aus (z.B. „Training abgeschlossen, 100 Epochen“)
#
# 3. **Vorhersage (simuliert)**
#    - Erstelle eine Funktion `vorhersage(netzwerk, input_daten)`, die aus input_daten (Liste von Zahlen) und den Gewichten einen einfachen Wert berechnet (z.B. Summe der Produkte oder ein einziger Zufallswert mit `random.choice([0, 1])`)
#    - Gib die Vorhersage für ein Beispiel-Input aus
#
# 4. **Genauigkeit und Demo**
#    - Berechne für 5–10 Testfälle (z.B. vorhersage(netz, [1,0,1])) eine „Genauigkeit“ (z.B. wie oft die Ausgabe in einem gewünschten Bereich liegt) und gib sie in Prozent aus
#
# **Beispiel-Code zum Starten:**
# ```python
# import random
#
# def erstelle_netz(input_size, hidden_size, output_size):
#     return [[random.uniform(-1, 1) for _ in range(hidden_size)] for _ in range(input_size)]
#
# def vorhersage(netzwerk, input_daten):
#     # Einfach: gewichtete Summe des ersten versteckten Neurons
#     return sum(input_daten[i] * netzwerk[i][0] for i in range(len(input_daten)))
# ```
#
# **Bonus-Challenge:**
# - Füge eine zweite „Schicht“ (weitere Gewichtsliste) hinzu und berechne die Vorhersage über beide Schichten.
#
# **Erwartete Ausgabe:**
# ```
# Netzwerk: 2 Eingänge, 3 versteckt, 1 Ausgang
# Training abgeschlossen, 50 Epochen
# Vorhersage für [1, 0]: 0.42
# Genauigkeit (Test): 70.0%
# ```

# %%
# 🐉 Deine Lösung hier:

print()
print("🎉 +400 Cyber Credits: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Code-Archivar der unendlichen Funktionen besiegt!")
print("⭐ Titel erhalten: Meister der Module")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 7 gemeistert!")
print("📚 Nächste Woche: Dictionaries und Tupel!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen:

# %%
# ✅ Lösung Bug #1: Modul nicht importiert

# Problem: math wurde nicht importiert
import math
result = math.sqrt(9)
print(f"Ergebnis: {result}")

# %%
# ✅ Lösung Bug #2: Falscher Funktionsname

# Problem: random.zahl existiert nicht
import random
zahl = random.randint(1, 10)
print(f"Zufallszahl: {zahl}")

# %%
# ✅ Lösung Bug #3: Funktion nicht gefunden

# Problem: sin existiert nicht ohne math.
import math
winkel = 90
sinus = math.sin(math.radians(winkel))
print(f"Sinus von {winkel}°: {sinus}")
