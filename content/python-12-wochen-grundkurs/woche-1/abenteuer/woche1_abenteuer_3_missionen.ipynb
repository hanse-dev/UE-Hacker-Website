# %% [markdown]
# # ⭐ Woche 1 – Missionen: Beweise dein Können!
#
# > 📖 Vorher: `woche1_abenteuer_lektion.ipynb` und `…_debug.ipynb`

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Zauberlehrling
#
# **Belohnung:** 300 XP + Magischer Grimoire
#
# Dein erster Tag als Zauberlehrling! Zeig, dass du die Grundbefehle kennst.
#
# **Schritt 1 – Vorstellung:**
# Gib deinen Namen mit `print()` aus und begrüße die Welt von Pythonia.
#
# **Schritt 2 – Alter speichern:**
# Speichere dein Alter in einer Variable und gib es in einem Satz aus. Denk an `str()`!
#
# **Bonus:** Gib deinen Lieblingsspruch aus.

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Schatzjäger
#
# **Belohnung:** 400 XP + Schatzkarte
#
# Du hast einen Schatz entdeckt! Dokumentiere deinen Fund für die Gilde.
#
# **Schritt 1 – Schatzdaten anlegen:**
# Erstelle Variablen für Schatzname, Goldwert (Zahl) und Fundort.
#
# **Schritt 2 – Schatzbericht ausgeben:**
# Gib eine Überschrift und alle drei Werte aus. Denk an `str()` für den Goldwert.
#
# **Schritt 3 – Zusammenfassung:**
# Fasse alles in einem Satz zusammen: Was wurde wo für wie viel Gold gefunden?
#
# **Bonus:** Füge eine Seltenheitsstufe von 1–5 Sternen hinzu.

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Der Held des Dorfes
#
# **Belohnung:** 500 XP + Heldenschwert
#
# Das Dorf wird von einem Ungeheuer bedroht! Erstelle ein Heldenprofil für den Retter.
#
# **Schritt 1 – Helden-Variablen anlegen:**
# Erstelle Variablen für Name, Waffe, Level, Stärke und Klasse (z.B. Krieger, Magier).
#
# **Schritt 2 – Heldenprofil ausgeben:**
# Gib eine Überschrift `=== HELDENPROFIL ===` aus, dann alle fünf Werte – Zahlen bitte mit `str()` umwandeln.
#
# **Schritt 3 – Heldengeschichte:**
# Schreibe 2 Sätze über deinen Helden (aus Variablen zusammengesetzt) und füge am Ende einen Schlachtruf hinzu.
#
#
# > 💡 **Tipp:** Du entscheidest selbst, wie du das umsetzt – es gibt keinen einzig richtigen Weg!
# **Bonus:** Füge eine magische Fähigkeit als zusätzliche Variable hinzu!
#
# **Starter-Code:**
# ```python
# heldenname = "Thorin"
# waffe = "Kriegshammer"
# level = 10
# staerke = 85
# klasse = "Krieger"
#
# print("=== HELDENPROFIL ===")
# print("Name: " + heldenname)
# # ... weiter geht's!
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Hake ab, was du schon kannst:
#
# - ☐ Text mit `print()` ausgeben
# - ☐ Informationen in Variablen speichern
# - ☐ Texte mit `+` und `str()` kombinieren
# - ☐ Kommentare mit `#` hinzufügen
# - ☐ Einfache Fehler finden und beheben
# - ☐ Eigene kleine Programme schreiben
