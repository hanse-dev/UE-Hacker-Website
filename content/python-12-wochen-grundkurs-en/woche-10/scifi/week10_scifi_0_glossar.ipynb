# %% [markdown]
# # 📖 Glossary – 🚀 Week 10 – OOP Basics: The Magic Blueprints!
# > You can keep this notebook open all week.
#
# | Term | Meaning | Example |
# |------|---------|--------|
# | `class` | Define your own class (blueprint for objects) | `class Hero:` |
# | **Object** | A concrete instance of a class | `ship = Spaceship("Enterprise")` |
# | **Instance** | A single created object of a class | `ship = Spaceship()` |
# | `__init__` | Constructor *(= special method that runs automatically when an object is created)* – called when an object is created | `def __init__(self, name):` |
# | `self` | Reference to the object itself inside the class | `self.name = name` |
# | **Attribute** | Property / variable of an object | `ship.name` |
# | **Method** | Function of an object (uses `self`) | `ship.launch()` |
# | **Constructor** | `__init__` – method that runs automatically when an object is created | `def __init__(self, name):` |

# %% [markdown]
# ## Quick Examples

# %% [markdown]
# ## Review – Terms from Previous Weeks
#
# ### From Week 5
#
# | Term | Meaning | Example |
# |------|---------|--------|
# | `def` | Create a function – methods are functions inside classes | `def calculate(x):` |
#
#
# ### From Week 8
#
# | Term | Meaning | Example |
# |------|---------|--------|
# | **Dictionary** `{}` | Precursor to a class – same idea, more possibilities | `{"name": "Aria", "level": 5}` |

# %%
class Spaceship:
    def __init__(self, name, ship_type="Standard"):
        self.name = name
        self.ship_type = ship_type

    def introduce(self):
        print(f"I am {self.name}, type: {self.ship_type}!")

    def launch(self):
        print(f"{self.name} is launching!")

# Create objects
ship1 = Spaceship("Enterprise")
ship2 = Spaceship("Voyager", ship_type="Intrepid")

ship1.introduce()   # I am Enterprise, type: Standard!
ship1.launch()      # Enterprise is launching!
print(ship2.ship_type)  # Intrepid
