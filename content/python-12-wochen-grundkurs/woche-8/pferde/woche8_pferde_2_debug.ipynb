# %% [markdown]
# # 🐛 Debug-Quest – 🐴 Woche 8 – Dictionaries und Tupel: Die Stall-Archive des Reiterhofs
#
# Ein Stallhelfer hat versucht, die Daten zu organisieren, aber etwas läuft schief! Finde die Fehler:
# > 💡 **Diese Fehler wurden absichtlich eingebaut** – damit du das Debuggen üben kannst!

# %% [markdown]
# ### 🐛 Bug #1
#
# Was ist falsch? Finde und behebe den Fehler!

# %%
pferd = {
    "name": "Thunder",
    "rasse": "Hannoveraner"
}
print(f"Pferd: {pferd}")

# %% [markdown]
# ### 🐛 Bug #2
#
# Was ist falsch? Finde und behebe den Fehler!

# %%
koordinaten = (100, 200)
koordinaten[0] = 150

# %% [markdown]
# ### 🐛 Bug #3
#
# Was ist falsch? Finde und behebe den Fehler!

# %%
pferde = [
    {"name": "Thunder", "rasse": "Hannoveraner"},
    {"name": "Luna", "rasse": "Isländer"}
]
print(pferde[2])
