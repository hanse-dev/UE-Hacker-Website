# %% [markdown]
# # 🐉 Boss Quests – 🚀 Week 8 – Dictionaries and Tuples: The Data Archives of the Space Station
# > ⚠️ Harder! Combines everything from this week.
#
# **⚠️ WARNING:** These quests are significantly harder! They combine everything you have learned.
#
# **Rewards:** A total of 1500 Cyber Credits + legendary items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 1: The Crew Profile
#
# **Reward:** 500 Cyber Credits + Crew ID Card
#
# Nebula-7 needs digital profiles for all crew members!
#
# **Step 1 – Create a profile:**
# Create a dictionary for a crew member with at least 4 attributes (name, rank, department, speciality). Print it in a clear format.
#
# **Step 2 – Crew list:**
# Create 3 different crew profiles and store them in a list.
#
# **Step 3 – Search:**
# Find all crew members in a specific department. Print the total number of crew members.
#
# **Bonus:** Sort the crew by rank.

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss Quest 2: The Sensor Matrix
#
# **Reward:** 600 Cyber Credits + Sensor Calibrator
#
# The space station watches the void with several sensor arrays – each with its own state!
#
# **Step 1 – Create sensor arrays:**
# Create a dictionary with 3 sensor arrays (e.g. Long-Range Radar, Short-Range Scanner, Spectral Analyzer). Each array is a dictionary with a technician, status and range.
#
# **Step 2 – Check status:**
# Show all sensor arrays with their status. Find the array with the lowest range.
#
# **Step 3 – Maintenance plan:**
# Check for each array: does it need maintenance (range < 80)? Print a maintenance plan.
#
# **Bonus:** Calculate the average range across all arrays.

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 3: The Mission Archive
#
# **Reward:** 400 Cyber Credits + Mission Database
#
# The fleet keeps an archive of all completed missions!
#
# **Step 1 – Create missions:**
# Create 4 mission entries as dictionaries (name, planet, result, duration) in a list.
#
# **Step 2 – Search:**
# Find all successful missions. Show the total number of all missions.
#
# **Step 3 – Statistics:**
# Calculate the average mission duration. Print the longest and shortest mission.
#
# **Bonus:** Add a tuple of involved crew members to each mission.

# %%
print()
print("🎉 +400 Cyber Credits: Boss Quest completed!")
print("🏆 You have defeated the Data Curator of the Infinite Keys!")
print("⭐ Title earned: Master of the Data Archives")
print()
print("🎊 CONGRATULATIONS! You have mastered Week 8!")
print("📚 Next week: JSON files and I/O!")

# %% [markdown]
# ---
#
# 🎊 **Congratulations!** You have completed all Boss Quests of this week!
#
# **Next up:** Week 9 is already waiting!
