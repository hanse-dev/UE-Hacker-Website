# %% [markdown]
# # ⭐ Missionen – 🐴 Woche 8 – Dictionaries und Tupel: Die Stall-Archive des Reiterhofs
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Stallarchivar
#
# **Belohnung:** 300 Huf-Punkte + Stall-Schlüssel
#
# Auf dem Reiterhof Sonnentals erstellst du deine erste Stallkarte (Dictionary) für Pferdedaten.
#
# **Schritt 1 – Pferde-Stallkarte anlegen:**
# Erstelle ein Dictionary `pferd` mit Schlüsseln z.B. `name`, `rasse`, `alter`, `groesse` und passenden Werten und gib das Dictionary mit `print()` aus
#
# **Schritt 2 – Werte ändern und ergänzen:**
# Ändere den Wert von `alter` (z.B. auf eine neue Zahl) und füge einen neuen Schlüssel `besitzer` mit einem Wert hinzu
#
# **Schritt 3 – Pferde-Liste aus Dictionaries:**
# Erstelle eine Liste mit 3 Elementen; jedes Element ist ein Dictionary mit z.B. `name`, `rasse`, `alter` und gib die Liste und die Werte eines Pferdes (z.B. `pferde[0]["name"]`) aus
#
# **Schritt 4 – Zugriff und Ausgabe:**
# Greife mit `pferd["name"]` und `pferd.get("rasse")` auf Werte zu und gib sie aus und gib eine kurze übersichtliche Zusammenfassung (z.B. „Pferd X, Rasse Y, Alter Z“) aus
#
# **Bonus:** Erstelle ein verschachteltes Dictionary (z.B. Pferd mit Unter-Dictionary „gesundheit“).

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Koordinaten-Reiter
#
# **Belohnung:** 400 Huf-Punkte + GPS-Halsband
#
# Du nutzt Tupel für 2D-Koordinaten (Reitwege) und kombinierst sie mit Dictionaries.
#
# **Schritt 1 – Koordinaten als Tupel:**
# Erstelle mindestens zwei 2D-Koordinaten als Tupel (z.B. `pos1 = (100, 200)` für Wegpunkte) und gib die Tupel und die Länge mit `len(pos1)` aus
#
# **Schritt 2 – Tupel-Unpacking:**
# Nutze Unpacking: `x, y = pos1` und gib x, y aus und erstelle eine zweite Koordinate und unpacke sie ebenfalls
#
# **Schritt 3 – Positions-Dictionary:**
# Erstelle ein Dictionary `positionen`, in dem Schlüssel Namen (Strings, z.B. „Stall“, „Reitplatz“) und Werte Koordinaten-Tupel sind (z.B. `{"Stall": (0, 0), "Reitplatz": (50, 30)}`) und gib das Dictionary aus und greife auf eine Position zu (z.B. `positionen["Stall"]`)
#
# **Schritt 4 – Abstand (vereinfacht):**
# Schreibe eine einfache Funktion `abstand(koord1, koord2)`, die z.B. die euklidische Distanz für 2D berechnet: √((x1-x2)² + (y1-y2)²) und rufe sie für zwei deiner Koordinaten auf und gib das Ergebnis aus
#
# **Bonus:** Füge 3D-Koordinaten (x, y, z) als Tupel hinzu und erweitere die Abstandsberechnung.

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Die Reiter-Gilde
#
# **Belohnung:** 500 Huf-Punkte + Reitmeister-Urkunde
#
# Du baust eine kleine Reiter-Gilde mit Liste von Dictionaries und Suchfunktionen.
#
# **Schritt 1 – Reiter-Liste aus Dictionaries:**
# Erstelle eine Liste `reiter`, in der jedes Element ein Dictionary ist mit z.B. `name`, `level`, `alter`, `erfahrung` (Jahre) und lege mindestens 3 Reiter an und gib die Liste aus
#
# **Schritt 2 – Mitglieder hinzufügen:**
# Füge mit `reiter.append({...})` ein neues Reiter-Mitglied hinzu und gib die aktualisierte Liste und die Anzahl der Mitglieder mit `len(reiter)` aus
#
# **Schritt 3 – Suchfunktion nach Level:**
# Schreibe eine Funktion eine Funktion, die alle Reiter mit diesem Level zurückgibt (z.B. Liste von Dictionaries) und rufe die Funktion für ein Level (z.B. 2) auf und gib die gefundenen Reiter aus
#
# **Schritt 4 – Statistik und Zuweisung:**
# Berechne das Durchschnittsalter der Reiter (Summe der Alter / Anzahl) und gib es aus und optional: Weise einem oder mehreren Reitern ein neues Schlüssel-Wert-Paar zu (z.B. `"pferd": "Luna"`) und gib die aktualisierte Liste aus
#
#
# > 💡 **Tipp:** Du entscheidest selbst, wie du das umsetzt – es gibt keinen einzig richtigen Weg!
# **Bonus:** Füge zu jedem Reiter Schlüssel wie `turniere` (Liste) oder `erfolge` hinzu und gib eine Übersicht aus.

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ☐ Stallkarten erstellen und verwenden
# - ☐ Auf Werte über Schlüssel zugreifen
# - ☐ Kapseln erstellen und verstehen
# - ☐ Unveränderlichkeit von Kapseln nutzen
# - ☐ Verschachtelte Datenstrukturen erstellen
# - ☐ Komplexe Daten organisieren
