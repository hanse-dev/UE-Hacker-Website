# %% [markdown]
# # ⭐ Missionen – 🐴 Woche 5 – Funktionen: Die Trainingsroutinen
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Trainings-Anfänger
#
# **Belohnung:** 300 Huf-Punkte + Trainingsplan
#
# In der Trainingshalle der Perfektion erstellst du deine ersten wiederverwendbaren Trainingsroutinen für Pferde.
#
# **Schritt 1 – Begrüßungs-Training erstellen:**
# Erstelle eine Funktion `begruesse_pferd()`, die zwei Begrüßungszeilen für das Pferd ausgibt und rufe die Funktion mindestens zweimal auf
#
# **Schritt 2 – Trainings-Intensität berechnen:**
# Erstelle eine Funktion `berechne_intensitaet(level, dauer)`, die `level * dauer * 5` berechnet und gib das Ergebnis mit `return` zurück
#
# **Schritt 3 – Trainings-Möglichkeit prüfen:**
# Erstelle eine Funktion `ist_training_moeglich(energie)`, die `True` zurückgibt, wenn `energie >= 50` ist, sonst `False` und nutze die Ergebnisse in if-Bedingungen und gib passende Nachrichten aus (z.B. "Training möglich" / "Pferd braucht Pause")
#
# **Schritt 4 – Routinen kombinieren:**
# Erstelle einen kleinen Haupt-Block, der: und das Pferd begrüßt,
#
# **Bonus:** Erstelle eine Funktion `generiere_training()`, die zufällig eine Trainingsart (z.B. "Dressur", "Springen", "Gelände") zurückgibt.

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Pferde-Trainer
#
# **Belohnung:** 400 Huf-Punkte + Trainer-Zertifikat
#
# Du entwickelst ein kleines Trainingssystem, das Pferdeprofile, Energie und einzelne Trainingseinheiten verwaltet.
#
# **Schritt 1 – Trainingsplan für ein Pferd erstellen:**
# Schreibe eine Funktion `erstelle_trainingsplan(pferd_name, rasse, level)`, die ein Dictionary mit diesen Informationen zurückgibt und füge einen Docstring hinzu, der Parameter und Ergebnis beschreibt
#
# **Schritt 2 – Energiebedarf berechnen:**
# Erstelle eine Funktion `berechne_energie(intensitaet, dauer)`, die den Energieverbrauch (z.B. `intensitaet * dauer`) berechnet und gib den Wert mit `return` zurück und nutze ihn später im System
#
# **Schritt 3 – Trainingseinheit erstellen:**
# Schreibe eine Funktion `generiere_trainingseinheit(name, energie)`, die eine kurze Beschreibung des Trainings als String zurückgibt und nutze sowohl den Pferdenamen als auch den Energiebedarf im Text
#
# **Schritt 4 – Fortschritt anzeigen:**
# Erstelle eine Funktion `zeige_fortschritt(pferd, absolvierte_einheiten)`, die eine zusammenfassende Ausgabe macht und nutze Daten aus dem Trainingsplan und der Anzahl der Einheiten
#
# **Bonus:** Ergänze eine Funktion, die zufälliges Wetter (z.B. "Sonne", "Regen", "Wind") und Bodenbedingungen einbezieht und den Energiebedarf beeinflusst.

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Die Turnier-Maschine
#
# **Belohnung:** 500 Huf-Punkte + Turnier-Planer
#
# Du entwickelst ein kleines System, das Teilnehmer, Disziplinen und Punkte eines Turniers verwaltet.
#
# **Schritt 1 – Turnierplan erstellen:**
# Erstelle eine Funktion eine Funktion, die ein Dictionary mit Namen, Disziplin und Startpunkten zurückgibt und erzeuge damit mehrere Turnier-Einträge
#
# **Schritt 2 – Punkte berechnen:**
# Schreibe eine Funktion eine Funktion, die den Durchschnitt der Noten berechnet und mit der Schwierigkeit multipliziert und gib die endgültigen Punkte mit `return` zurück
#
# **Schritt 3 – Voraussetzungen prüfen:**
# Erstelle eine Funktion eine Funktion, die `True` oder `False` zurückgibt und nutze einfache Regeln (z.B. Mindestlevel, bestimmte Ausrüstung nötig)
#
# **Schritt 4 – Turnier-Ergebnis zusammenfassen:**
# Schreibe eine Funktion eine Funktion, die am Ende Sieger und Gesamtübersicht ausgibt und nutze Daten aus den vorherigen Funktionen
#
#
# > 💡 **Tipp:** Du entscheidest selbst, wie du das umsetzt – es gibt keinen einzig richtigen Weg!
# **Bonus:** Füge ein einfaches Ranking hinzu, das alle Teilnehmer nach Punkten sortiert ausgibt.

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ☐ Funktionen mit def und Parameter definieren
# - ☐ return-Werte und Funktionsaufrufe nutzen
# - ☐ Docstrings zur Dokumentation schreiben
# - ☐ Schreibregeln beachten
# - ☐ Funktionen mit und ohne Ergebnisse erstellen
# - ☐ Parameter übergeben und Standardwerte verwenden
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die Boss-Quests!
