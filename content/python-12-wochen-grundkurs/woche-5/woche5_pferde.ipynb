# %% [markdown]
# # 🐴 Woche 5 – Funktionen: Die Trainingsroutinen
#
# **Huf-Punkte zu verdienen:** 1000 Punkte
# **Boss:** Der Meister der unendlichen Runden

# %% [markdown]
# ## 🌟 Die Quest beginnt: Die Trainingshalle der Perfektion
#
# Willkommen auf dem Reiterhof! Du erreichst die **Trainingshalle der Perfektion** – ein Ort, an dem Trainingsroutinen einmal entwickelt und für alle Pferde wiederverwendet werden können. In dieser Woche lernst du die drei **Arten der Trainings-Methoden**:
#
# **Deine Mission:**
# - Meistere die **Funktions-Definition** mit `def`
# - Beherrsche **Parameter** für flexible Trainings
# - Lerne **return-Werte** für Trainingsergebnisse
# - Verstehe **Docstrings** für die Trainingshandbücher
#
# **Einmal entwickelt, immer angewendet!** Die Macht der Funktionen wartet...

# %% [markdown]
# ## 📚 Trainings-Methode 1: Die Funktions-Definition - Der Trainingsplan
#
# **Was es ist:** Eine Funktion ist ein wiederverwendbarer Trainings-Block, den du einmal definierst und immer wieder aufrufen kannst.
#
# **Die Anatomie einer Funktion:**
# ```python
# def trainings_name(parameter1, parameter2):
#     """Beschreibung des Trainings"""
#     # Trainings-Code
#     return ergebnis  # Optional: Ergebnis zurückgeben
# ```
#
# **Schritt-für-Schritt-Erklärung:**
# 1. **`def`** - Das Kommando, das die Trainings-Definition startet
# 2. **`trainings_name`** - Ein eindeutiger Name für dein Training
# 3. **`(parameter)`** - Trainings-Variablen (optional)
# 4. **`:`** - Beendet die Trainings-Definition
# 5. **`"""Docstring"""`** - Trainingshandbuch (sehr wichtig!)
# 6. **Eingerückter Code** - Der eigentliche Trainings-Code
# 7. **`return`** - Gibt das Ergebnis zurück (optional)
#
# **Warum so nützlich:**
# - 🎯 Trainings wiederverwenden statt neu schreiben
# - 🔍 Training organisieren und strukturieren
# - ⚡ Fehler an einer Stelle beheben
# - 🎲 Komplexe Trainings in kleine Teile zerlegen

# %%
# Beispiel 1: Einfache Funktion ohne Parameter
def begruessung_reiterhof():
    """Begrüßt Besucher auf dem Reiterhof"""
    print("Willkommen auf dem Reiterhof Sonnental!")
    print("Dein Training beginnt jetzt!")

# Funktion aufrufen
print("=== Erster Besucher ===")
begruessung_reiterhof()

print("\n=== Zweiter Besucher ===")
begruessung_reiterhof()

print("\n=== Was passiert hier? ===")
print("1. def begruessung_reiterhof(): definiert die Funktion")
print("2. begruessung_reiterhof() ruft die Funktion auf")
print("3. Der Code in der Funktion wird jedes Mal ausgeführt")

# %%
# Beispiel 2: Funktion mit einem Parameter
def begruesse_reiter(name):
    """Begrüßt einen Reiter mit seinem Namen"""
    print(f"Hallo {name}!")
    print(f"Viel Erfolg beim Training, {name}!")

# Funktion mit verschiedenen Namen aufrufen
print("=== Verschiedene Reiter ===")
begruesse_reiter("Anna")
begruesse_reiter("Max")
begruesse_reiter("Lena")

print("\n=== Was passiert hier? ===")
print("1. name ist ein Platzhalter für den übergebenen Wert")
print("2. Jeder Aufruf übergibt einen anderen Namen")
print("3. Die Funktion arbeitet mit dem übergebenen Wert")

# %%
# Beispiel 3: Funktion mit mehreren Parametern
def erstelle_pferd_profil(name, rasse, alter):
    """Erstellt ein Pferd-Profil mit Name, Rasse und Alter"""
    print(f"Pferd-Profil:")
    print(f"  Name: {name}")
    print(f"  Rasse: {rasse}")
    print(f"  Alter: {alter} Jahre")
    print(f"  Status: Bereit für das Training!")

# Verschiedene Pferde-Profile erstellen
print("=== Pferd-Profile ===")
erstelle_pferd_profil("Thunder", "Hannoveraner", 8)
print()
erstelle_pferd_profil("Luna", "Isländer", 5)
print()
erstelle_pferd_profil("Storm", "Quarter Horse", 6)

# %% [markdown]
# ## 🔍 Das Geheimnis von return - Das Trainingsergebnis
#
# **return** ist der mächtigste Teil einer Funktion!
#
# **Was return tut:**
# - Beendet die Funktion sofort
# - Gibt einen Wert zurück an den Aufrufer
# - Dieser Wert kann in einer Variable gespeichert werden
#
# **Ohne return:** Funktion macht etwas (Side Effect)
# **Mit return:** Funktion berechnet und gibt Ergebnis zurück

# %%
# 🔍 Übungen mit return

# Beispiel 1: Einfache Berechnung mit return
def berechne_trainingszeit(einheiten, dauer_pro_einheit):
    """Berechnet die gesamte Trainingszeit"""
    gesamtzeit = einheiten * dauer_pro_einheit
    return gesamtzeit

# Ergebnis in Variable speichern
print("=== Trainingszeit-Berechnung ===")
zeit1 = berechne_trainingszeit(5, 15)
print(f"Training 1: {zeit1} Minuten")

zeit2 = berechne_trainingszeit(3, 20)
print(f"Training 2: {zeit2} Minuten")

# Ergebnis direkt verwenden
print(f"Intensivtraining: {berechne_trainingszeit(10, 30} Minuten")

# %%
# Beispiel 2: Funktion mit bedingtem return
def pruefe_training_level(erfahrung):
    """Prüft, ob ein Pferd für fortgeschrittenes Training bereit ist"""
    if erfahrung >= 50:
        return "Bereit für fortgeschrittenes Training!"
    else:
        return f"Noch {50 - erfahrung} Trainingseinheiten needed"

print("=== Training-Level-Prüfung ===")
status1 = pruefe_training_level(25)
print(f"Erfahrung 25: {status1}")

status2 = pruefe_training_level(75)
print(f"Erfahrung 75: {status2}")

status3 = pruefe_training_level(40)
print(f"Erfahrung 40: {status3}")

# %%
# Beispiel 3: Funktion ohne expliziten return (None)
def zeige_ausruestung():
    """Zeigt die Standard-Ausrüstung (gibt nichts zurück)"""
    print("Deine Ausrüstung:")
    print("  - Sattel")
    print("  - Zaumzeug")
    print("  - Gerte")
    # Kein return - gibt automatisch None zurück

print("=== Ausrüstung anzeigen ===")
ergebnis = zeige_ausruestung()
print(f"Rückgabewert: {ergebnis}")
print("Funktionen ohne return geben immer None zurück!")

# %% [markdown]
# ## 📦 Trainings-Methode 2: Docstrings - Die Trainingshandbücher
#
# **Was es ist:** Docstrings sind Dokumentations-Strings, die erklären, was eine Funktion tut.
#
# **Warum extrem wichtig:**
# - 📖 Andere (und du später) verstehen deine Funktion
# - 🔍 IDEs zeigen dir Hilfe beim Aufruf
# - 🤖 Tools können automatisch Dokumentation erstellen
# - ⭐ Zeichen von professionellem Code
#
# **Die drei Arten von Docstrings:**
# 1. **Einzeilig:** `"""Kurze Beschreibung"""`
# 2. **Mehrzeilig:** `"""Kurze Beschreibung\n\nDetails..."""`
# 3. **Vollständig:** `"""Beschreibung\n\nArgs:\nReturns:\n"""`

# %%
# Beispiel 1: Verschiedene Docstring-Stile
def einfache_funktion():
    """Dies ist ein einzeiliger Docstring."""
    return "Einfach"

def detaillierte_funktion(pferd_name, training_level):
    """Erstellt eine Trainings-Beschreibung.
    
    Args:
        pferd_name (str): Der Name des Pferdes
        training_level (int): Das Trainings-Level des Pferdes
    
    Returns:
        str: Eine formatierte Beschreibung
    """
    return f"{pferd_name} hat Trainings-Level {training_level}."

# Docstring aufrufen (so funktioniert es!)
print("=== Docstring-Beispiele ===")
print(f"Einfacher Docstring: {einfache_funktion.__doc__}")
print()
print(f"Detaillierter Docstring: {detaillierte_funktion.__doc__}")

# %%
# Beispiel 2: Hilfe-Funktion nutzen
print("=== Hilfe für Funktionen ===")
help(detaillierte_funktion)

# %% [markdown]
# ## ✨ Trainings-Methode 3: Namenskonventionen - Die Regeln des Reitstalls
#
# **Gute Funktionsnamen sind entscheidend!**
#
# **Die Regeln:**
# - **Kleinbuchstaben** mit Unterstrichen: `berechne_trainingszeit`
# - **Beschreibend**: Was die Funktion **tut** (Verb)
# - **Kurz aber klar**: `get_name()` nicht `retrieve_horse_data_from_stable()`
# - **Keine Verben im Namen**: `name_get()` falsch, `get_name()` richtig
#
# **Beispiele:**
# - ✅ `berechne_trainingszeit()`
# - ✅ `erstelle_pferd_profil()`
# - ✅ `pruefe_training_level()`
# - ❌ `BerechneTrainingszeit()` (CamelCase)
# - ❌ `berechne_das_training()` (zu lang)
# - ❌ `training_berechnen()` (Substantiv zuerst)

# %%
# ✨ Beispiele für gute und schlechte Namen

# ✅ Gute Namen (klar und beschreibend)
def berechne_futter_menge(gewicht, aktivitaet):
    """Berechnet die tägliche Futtermenge."""
    return gewicht * aktivitaet * 0.02

def finde_bestes_training(pferde_liste):
    """Findet das beste Training für eine Pferdeliste."""
    return max(pferde_liste)

def ist_pferd_verfuegbar(pferd_id, zeitpunkt):
    """Prüft, ob ein Pferd verfügbar ist."""
    return pferd_id not in belegte_pferde[zeitpunkt]

# ❌ Schlechte Namen (unklar oder falsche Konvention)
# def berechneFutterMenge():  # CamelCase
# def fm(g, a):  # Zu kurz, nicht beschreibend
# def feeding_calculation():  # Substantiv zuerst

print("=== Gute Funktionsnamen in Aktion ===")
futter = berechne_futter_menge(500, 1.5)
print(f"Futtermenge: {futter} kg")

trainings = ["Dressur", "Springen", "Western"]
bestes_training = finde_bestes_training(trainings)
print(f"Bestes Training: {bestes_training}")

# Beispiel-Daten für Verfügbarkeitsprüfung
belegte_pferde = {"morgen": ["Thunder", "Luna"], "mittag": []}
verfuegbar = ist_pferd_verfuegbar("Storm", "morgen")
print(f"Pferd verfügbar: {verfuegbar}")

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein Anfänger hat versucht, Trainingsroutinen zu erstellen, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1

def begruessung():
print("Willkommen im Stall!")
return "Begrüßt"

# %%
# 🐛 Bug #2

def berechne_trainingszeit(dauer):
    return dauer * 60

result = berechne_trainingszeit

# %%
# 🐛 Bug #3

def addiere_trainingseinheiten(einheiten1, einheiten2):
    gesamt = einheiten1 + einheiten2

gesamt_training = addiere_trainingseinheiten(5, 3)
print(f"Gesamt-Training: {gesamt_training}")

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Trainings-Anfänger
#
# **Belohnung:** 300 Huf-Punkte + Trainingsplan
#
# Erstelle deine ersten Trainingsroutinen!
#
# **Was du tun sollst:**
# 1. **Begrüßungsfunktion:** Erstelle eine Funktion für die Pferde-Begrüßung
# 2. **Intensität berechnen:** Erstelle eine Funktion mit level und dauer als Parameter
# 3. **Möglichkeit prüfen:** Erstelle eine Funktion, die True/False zurückgibt
# 4. **System kombinieren:** Rufe alle Funktionen nacheinander auf
# 5. **Dokumentation:** Füge Docstrings zu allen Funktionen hinzu
#
# **Tipp:** Nutze `def` für die Definition und `return` für Rückgabewerte!
#
# **Bonus-Challenge:** Erstelle eine Funktion, die zufällige Trainings generiert.

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Pferde-Trainer
#
# **Belohnung:** 400 Huf-Punkte + Trainer-Zertifikat
#
# Erstelle ein System zum Trainieren von Pferden!
#
# **Was du tun sollst:**
# 1. **Trainingsplan erstellen:** Funktion mit pferd_name, rasse und level als Parameter
# 2. **Energie berechnen:** Funktion, die intensität und dauer nutzt
# 3. **Trainingseinheit generieren:** Funktion, die eine Trainingseinheit zurückgibt
# 4. **Fortschritt zeigen:** Funktion, die Pferde-Daten ausgibt
# 5. **System integrieren:** Verbinde alle Funktionen zu einem Trainings-Tool
#
# **Tipp:** Nutze return-Werte, um Daten zwischen Funktionen zu übergeben!
#
# **Bonus-Challenge:** Füge Zufalls-Elemente für Wetter und Bedingungen hinzu.

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Die Turnier-Maschine
#
# **Belohnung:** 500 Huf-Punkte + Turnier-Planer
#
# Erstelle ein System für Turnier-Planung!
#
# **Was du tun sollst:**
# 1. **Turnierplan generieren:** Funktion für teilnehmer- und disziplinbasierte Pläne
# 2. **Punkte berechnen:** Funktion, die richter_noten und schwierigkeit nutzt
# 3. **Voraussetzungen prüfen:** Funktion, die level und ausrüstung prüft
# 4. **Wettkampf starten:** Funktion, die pferd und turnier als Parameter nimmt
# 5. **Turnier beenden:** Funktion, die ergebnisse und sieger verarbeitet
#
# **Tipp:** Nutze mehrere Parameter und kombiniere verschiedene Datentypen!
#
# **Bonus-Challenge:** Erstelle ein komplettes Turnier-System mit Speicherung.

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten des Stallmeisters (Reflexion)
#
# Bevor du weiter trainierst, denke über diese Fragen nach:
#
# 1. **Warum sind Funktionen besser als kopierter Code?**
#
# 2. **Wann sollte man return verwenden und wann nicht?**
#
# 3. **Warum sind gute Funktionsnamen so wichtig?**
#
# Diskutiere deine Gedanken mit anderen Reitern!

# %% [markdown]
# ### 📖 Pferde-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **def** 🐴: Funktions-Definition starten
# - **parameter** 📦: Werte, die an Funktion übergeben werden
# - **return** 🔄: Wert zurückgeben
# - **docstring** 📖: Funktions-Dokumentation
# - **argument** 🎯: Tatsächlich übergebener Wert
# - **call** 📞: Funktion aufrufen
# - **scope** 🌍: Gültigkeitsbereich von Variablen
# - **side effect** ⚡: Veränderungen außerhalb der Funktion
# - **pure function** 🌟: Funktion ohne Seiteneffekte
# - **recursion** 🔄: Funktion ruft sich selbst auf

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ✅ Funktionen mit def und Parameter definieren
# - ✅ return-Werte und Funktionsaufrufe nutzen
# - ✅ Docstrings zur Dokumentation schreiben
# - ✅ Namenskonventionen beachten
# - ✅ Funktionen mit und ohne Rückgabewerte erstellen
# - ✅ Parameter übergeben und Standardwerte verwenden
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die Boss-Quests!

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Hervorragend!** Du hast die Trainingsroutinen gemeistert!
#
# **Das hast du gelernt:**
# - Funktionen definieren und wiederverwenden
# - Parameter für flexible Trainings nutzen
# - return-Werte für Trainingsergebnisse
# - Docstrings für verständlichen Code
# - Namenskonventionen für sauberen Code
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🐴 **Pferdesport:** Trainingspläne, Leistungsanalyse, Turnier-Software
# - 📱 **Apps:** Datenverarbeitung, Berechnungen, Benutzeroberflächen
# - 🌐 **Websites:** Formulare, Datenbanken, Benutzer-Systeme
# - 🤖 **KI-Systeme:** Datenanalyse, Mustererkennung, Vorhersagen
# - 📊 **Wissenschaft:** Simulationen, Berechnungen, Forschung
#
# **Als Nächstes:** In Woche 6 lernst du **Listen**!

# %% [markdown]
# ## 🐉 Boss-Kampf: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Quests sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 Huf-Punkte + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Der Trainings-Generator
#
# **Belohnung:** 500 Huf-Punkte + Meister-Training
#
# Erstelle ein System, das automatisch Trainings generiert!
#
# **Was du tun sollst:**
#
# **1. Namen generieren:**
#    - Erstelle eine Funktion für pferdetyp- und schwierigkeitsbasierte Namen
#    - Die Funktion soll pferde_typ und schwierigkeit als Parameter nehmen
#    - Nutze f-Strings für die Namensgenerierung
#
# **2. Intensität berechnen:**
#    - Schreibe eine Funktion, die dauer und pferdetyp bewertet
#    - Die Funktion soll eine Intensitäts-Zahl zurückgeben (0-100)
#    - Berücksichtige verschiedene Pferde-Typen
#
# **3. Beschreibung erstellen:**
#    - Erstelle eine Funktion, die Trainings-Details generiert
#    - Die Funktion soll name, typ und intensitaet nutzen
#    - Gib einen formatierten Beschreibungs-Text zurück
#
# **4. Training speichern:**
#    - Schreibe eine Funktion zum Speichern in einem Trainingsplan
#    - Die Funktion soll ein Training-Dictionary entgegennehmen
#    - Füge das Training zur Liste hinzu und gib Bestätigung zurück
#
# **5. Training finden:**
#    - Erstelle eine Funktion zur Suche nach bestimmten Kriterien
#    - Die Funktion soll eine Liste und suchbegriff entgegennehmen
#    - Gib eine Liste mit gefundenen Trainings zurück
#
# **6. System integrieren:**
#    - Verbinde alle Funktionen zu einem Generator
#    - Erstelle mindestens 5 verschiedene Trainings
#    - Zeige eine Statistik der generierten Trainings
#
# **Beispiel-Struktur:**
# ```python
# # So könntest du beginnen:
# def generiere_training_name(pferde_typ, schwierigkeit):
#     # Generiert Training-Namen basierend auf Typ und Schwierigkeit
#     pass
#
# def berechne_intensitaet(dauer, pferde_typ):
#     # Berechnet Intensitäts-Wert
#     pass
#
# # ... weitere Funktionen hier
#
# # Hauptprogramm
# trainings = []
# # Generiere Trainings...
# ```
#
# **Bonus-Challenge:** Füge Training-Kombinationen und Progression hinzu.

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Der Stall-Manager
#
# **Belohnung:** 600 Huf-Punkte + Stallmeister-Titel
#
# Erstelle ein System, das automatisch Ställe verwaltet!
#
# **Was du tun sollst:**
#
# **1. Boxen generieren:**
#    - Erstelle eine Funktion für ID- und größenbasierte Boxen
#    - Die Funktion soll box_id und groesse als Parameter nehmen
#    - Gib ein Dictionary mit Boxen-Daten zurück
#
# **2. Futter planen:**
#    - Schreibe eine Funktion zur Verteilung von Futter auf Boxen
#    - Die Funktion soll eine Liste von Boxen und totales_futter nehmen
#    - Verteile Futter basierend auf Boxengröße und Pferdetyp
#
# **3. Schichten organisieren:**
#    - Erstelle eine Funktion für Reiter- und Schichtplanung
#    - Die Funktion soll anzahl_reiter und schichten als Parameter nehmen
#    - Erstelle eine optimale Verteilung auf alle Schichten
#
# **4. Pflege planen:**
#    - Schreibe eine Funktion für pferde- und prioritätenbasierte Pflege
#    - Die Funktion soll eine Pferdeliste und dringlichkeit nutzen
#    - Sortiere Pferde nach Pflegepriorität
#
# **5. Übersicht zeigen:**
#    - Erstelle eine Funktion für den Stall-Zusammenfassung
#    - Die Funktion soll alle Stall-Daten entgegennehmen
#    - Gib eine formatierte Übersicht zurück
#
# **6. Notfälle verwalten:**
#    - Schreibe eine Funktion für ereignisbasierte Notfallreaktion
#    - Die Funktion soll notfall_typ und stall_status nutzen
#    - Implementiere verschiedene Notfall-Protokolle
#
# **Beispiel-Struktur:**
# ```python
# # So könntest du beginnen:
# def erstelle_box(box_id, groesse):
#     # Erstellt Boxen-Dictionary
#     pass
#
# def verteile_futter(boxen, totales_futter):
#     # Verteilt Futter auf Boxen
#     pass
#
# # ... weitere Funktionen hier
#
# # Hauptprogramm
# stall = {
#     "boxen": [],
#     "futter": 10000,
#     "reiter": 50
# }
# # Verwalte Stall...
# ```
#
# **Bonus-Challenge:** Füge zufällige Krankheiten und Tierarzt-Besuche hinzu.

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Das Turnier-Simulation
#
# **Belohnung:** 400 Huf-Punkte + Turnier-Simulator
#
# Erstelle ein komplettes Turnier-Simulationssystem!
#
# **Was du tun sollst:**
#
# **1. Turnier initialisieren:**
#    - Erstelle eine Funktion zum Starten mit zwei Teilnehmern
#    - Die Funktion soll teilnehmer1 und teilnehmer2 als Dictionaries nehmen
#    - Gib einen initialen Turnier-Status zurück
#
# **2. Runde ausführen:**
#    - Schreibe eine Funktion für Punkte- und Fehlerberechnungen
#    - Die Funktion soll reiter und pferd entgegennehmen
#    - Berechne Punkte basierend auf Leistung und Stil
#
# **3. Ergebnis berechnen:**
#    - Erstelle eine Funktion für Fehler- und Stilberechnung
#    - Die Funktion soll basis_punkte und fehler_anzahl nutzen
#    - Gib die tatsächlichen Punkte zurück
#
# **4. Status aktualisieren:**
#    - Schreibe eine Funktion zur Aktualisierung der Teilnehmer-Daten
#    - Die Funktion soll teilnehmer and neue_punkte nehmen
#    - Aktualisiere Punkte und Platzierung des Teilnehmers
#
# **5. Turnier beenden:**
#    - Erstelle eine Funktion für Sieger-, Verlierer- und Preisberechnung
#    - Die Funktion soll endstatus und ursprüngliche teilnehmer nutzen
#    - Gib eine Zusammenfassung des Turniers zurück
#
# **6. Simulation starten:**
#    - Schreibe eine Funktion, die das komplette Turnier steuert
#    - Die Funktion soll zwei Teilnehmer und max_disziplinen nehmen
#    - Führt Disziplinen durch bis ein Sieger feststeht
#
# **Beispiel-Struktur:**
# ```python
# # So könntest du beginnen:
# def initialisiere_turnier(teilnehmer1, teilnehmer2):
#     # Startet das Turnier mit zwei Teilnehmern
#     pass
#
# def fuehre_disziplin_aus(reiter, pferd):
#     # Führt eine Turnierdisziplin aus
#     pass
#
# # ... weitere Funktionen hier
#
# # Hauptprogramm
# teilnehmer_a = {"name": "Anna", "pferd": "Thunder", "punkte": 0}
# teilnehmer_b = {"name": "Ben", "pferd": "Storm", "punkte": 0}
# # Starte Simulation...
# ```
#
# **Bonus-Challenge:** Füge verschiedene Disziplinen und Schwierigkeitsgrade hinzu.

# %%
# 🐉 Deine Lösung hier:

print()
print("🎉 +400 Huf-Punkte: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Meister der unendlichen Runden besiegt!")
print("⭐ Titel erhalten: Meister der Trainingsroutinen")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 5 gemeistert!")
print("📚 Nächste Woche: Listen (Listen erstellen, bearbeiten, durchsuchen)!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen:

# %%
# ✅ Lösung Bug #1: Falsche Einrückung

# Problem: Code nach def nicht eingerückt
def begruessung():
    print("Willkommen im Stall!")
    return "Begrüßt"  # Das fehlte!

# %%
# ✅ Lösung Bug #2: Falscher Funktionsaufruf

# Problem: Klammern vergessen
def berechne_trainingszeit(dauer):
    return dauer * 60

# Korrekter Aufruf:
result = berechne_trainingszeit(30)  # Klammern hinzugefügt!

# %%
# ✅ Lösung Bug #3: Vergessenes return

# Problem: return vergessen
def addiere_trainingseinheiten(einheiten1, einheiten2):
    gesamt = einheiten1 + einheiten2
    return gesamt  # Das fehlte!

gesamt_training = addiere_trainingseinheiten(5, 3)
print(f"Gesamt-Training: {gesamt_training}")  # Jetzt gibt es 8 aus!
