# %% [markdown]
# # 🚀 Woche 1 – Dein erstes Programm: Die Mission beginnt
#
# **Cyber Credits zu verdienen:** 1000 Punkte
# **Herausforderung:** Der stille Protokoll-Droid

# %% [markdown]
# ## 🌟 Die Mission beginnt: Willkommen an Bord der Nebula-7
#
# Willkommen, Kommandant:in! Du betrittstest die hochmoderne **Raumstation Nebula-7** – ein Zentrum für technologische Innovationen und interstellare Abenteuer. In dieser Woche lernst du die vier wichtigsten **Systemprotokolle**:
#
# **Deine Mission:**
# - Lerne, wie du Text mit `print()` ausgibst
# - Speichere Informationen in **Datenspeichern**
# - Kombiniere Texte und Daten zu Nachrichten
# - Füge Kommentare hinzu, um deinen Code zu dokumentieren
#
# **Leg los!** Dein erster Befehl wartet schon...

# %% [markdown]
# ## 🔬 Was ist ein Systemprotokoll?
#
# Ein **Systemprotokoll** ist wie ein Befehlssatz für die Raumstation - eine festgelegte Anweisung, die der Computer verstehen und ausführen kann.
#
# **Stell dir vor:**
# - 📡 Die Kommandobrücke sendet Protokolle an die Schiffs-Systeme
# - 🤖 Jedes Protokoll hat eine spezifische Funktion und Syntax
# - ⚡ Die Systeme führen die Befehle präzise aus
# - 📊 Ohne Protokolle würde die Kommunikation zusammenbrechen
#
# **In der Programmierung lernen wir:**
# - Die grundlegenden Protokolle (Befehle) von Python
# - Wie man diese Protokolle kombiniert
# - Wie man eigene Protokolle erstellt (später)
#
# **Jedes Systemprotokoll, das du lernst, ist wie ein neues Werkzeug für dein Raumschiff!**

# %% [markdown]
# ## 📚 Systemprotokoll 1: Der `print()`-Befehl
#
# **Was es ist:** `print()` ist dein erster Kommunikations-Befehl. Er gibt Text auf dem Bildschirm aus.
#
# **Warum nützlich:**
# - 📡 Übermittelt Statusmeldungen an die Kommandobrücke
# - 🖥️ Zeigt Ergebnisse von Scans und Analysen an
# - 🔧 Hilft bei der Diagnose von Systemfehlern
# - 📊 Protokolliert Missionsdaten für die Zukunft
#
# **Wichtig:** Text muss immer in Anführungszeichen `"` oder `'` stehen!

# %%
# Beispiel 1: Einfache Textausgabe
print("Hallo Welt!")
print("Willkommen an Bord der Nebula-7!")

# Beispiel 2: Mehrere Zeilen
print("Dies ist dein erstes Programm.")
print("Du bist jetzt ein Programmierer!")

# Beispiel 3: Leere Zeile für bessere Übersicht
print()
print("=== Dein Programm läuft erfolgreich! ===")

# %% [markdown]
# ## 📦 Systemprotokoll 2: Datenspeicher - Digitale Container
#
# **Was es ist:** Ein Datenspeicher (Variable) ist wie ein Speicherchip mit Namen. Du kannst Informationen darin speichern und später wieder abrufen.
#
# **Warum nützlich:**
# - 💾 Speichert Lebenszeichen der Crew-Mitglieder
# - 🎯 Verfolgt Kurskoordinaten und Zieldaten
# - ⚡ Misst Energielevel der Schilde und Waffen
# - 🔄 Kann jederzeit aktualisiert werden bei neuen Messungen
#
# **Wichtig:**
# - Text: in Anführungszeichen (`"Zephyr"`)
# - Zahlen: ohne Anführungszeichen (`42`)

# %%
# Beispiel 1: Verschiedene Datentypen
pilot_name = "Zephyr"      # Text (String)
pilot_level = 1            # Zahl (Integer)
pilot_credits = 50         # Zahl (Integer)
pilot_aktiv = True         # Wahrheitswert (Boolean)

# Beispiel 2: Datenspeicher ausgeben
print("Pilot-Name:")
print(pilot_name)
print("Level:")
print(pilot_level)
print("Credits:")
print(pilot_credits)

# Beispiel 3: Datenspeicher können sich ändern
print("\nCredits vor der Mission: " + str(pilot_credits))
pilot_credits = 150  # Neuer Wert
print("Credits nach dem Erfolg: " + str(pilot_credits))

# %% [markdown]
# ## ✨ Systemprotokoll 3: Daten kombinieren
#
# **Was es ist:** Mit `+` kannst du Texte und Datenspeicher zu einer Nachricht verbinden.
#
# **Warum nützlich:**
# - 📡 Erstellt vollständige Missionsberichte
# - 🛸 Kombiniert Sensordaten mit festen Texten
# - 🎯 Generiert personalisierte Befehle für die Crew
# - 📊 Macht Ausgaben informativer und verständlicher
#
# **Wichtig:** Zahlen müssen mit `str()` in Text umgewandelt werden!

# %%
# Beispiel 1: Einfache Kombination
name = "Nova"
schiff = "Rächer"
print("Pilot: " + name)
print("Schiff: " + schiff)

# Beispiel 2: Mit Zahlen (str() nötig!)
torpedos = 20
print("Torpedos: " + str(torpedos))

# Beispiel 3: Komplexe Sätze
print(name + " kommandiert die " + schiff + " mit " + str(torpedos) + " Torpedos.")

# Beispiel 4: Mehrere Informationen
print("\n=== SCHIFFSDATEN ===")
print("Pilot: " + name)
print("Schiff: " + schiff)
print("Bewaffnung: " + str(torpedos) + " Torpedos")
print("=====================")

# %% [markdown]
# ## 💭 Systemprotokoll 4: Kommentare - Digitale Notizen
#
# **Was es ist:** Kommentare sind Notizen im Code, die mit `#` beginnen. Der Computer ignoriert sie.
#
# **Warum nützlich:**
# - 📝 Dokumentiert komplexe Algorithmen für die Wissenschaft
# - 🤖 Erklärt KI-Entscheidungen für menschliche Analysten
# - 👥 Macht Code für andere Ingenieure verständlich
# - 🔭 Hilft bei der zukünftigen Wartung der Systeme
#
# **Wichtig:** Kommentare stehen immer in einer eigenen Zeile oder nach dem Code!

# %%
# Beispiel 1: Einfache Kommentare
# Dies ist ein Kommentar
print("Hallo!")  # Dies ist ein Kommentar nach dem Code

# Beispiel 2: Mehrzeilige Erklärungen
# Erstelle einen Piloten mit folgenden Eigenschaften:
# - Name: Orion
# - Level: 42
# - Spezialität: Navigation
pilot_name = "Orion"
pilot_level = 42

# Beispiel 3: Kommentare zur Erklärung von Berechnungen
energie = 75         # Energie des Schilds
verbrauch = 25       # Energieverbrauch
rest_energie = energie - verbrauch  # Berechne verbleibende Energie
print("Verbleibende Schild-Energie: " + str(rest_energie))
