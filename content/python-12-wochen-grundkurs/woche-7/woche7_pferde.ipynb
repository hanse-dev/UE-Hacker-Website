# %% [markdown]
# # 🐴 Woche 7 – Module und Bibliotheken: Die Werkzeugkisten des Reiterhofs!
#
# **Huf-Punkte zu verdienen:** 1000 Punkte
# **Boss:** Der Schmied der unendlichen Werkzeuge

# %% [markdown]
# ## 🌟 Die Freundschaft beginnt: Die Werkstatt vom Sonnentals-Hof
#
# Willkommen auf dem Reiterhof Sonnentals! Du erreichst die **große Werkstatt** – ein gut organisierter Ort, an dem unendlich viele Werkzeuge und Ausrüstungsgegenstände aufbewahrt werden. In dieser Woche lernst du die drei **Arten der Werkzeugnutzung**:
#
# **Deine Mission:**
# - Meistere den **Werkzeug-Import** mit import und from
# - Beherrsche die **math-Werkzeuge** für Berechnungen
# - Lerne die **Zufalls-Werkzeuge** für unvorhersehbare Ereignisse
#
# **Einmal importiert, für immer verfügbar!** Die Macht der Werkzeuge wartet...

# %% [markdown]
# ## 📚 Werkzeug-Sammlung 1: Der Import-Kasten - Das erste Modul
#
# **Was es ist:** Ein Modul ist eine Sammlung von vordefinierten Werkzeugen, die du in dein Programm laden kannst.
#
# **Die Anatomie eines Imports:**
# ```python
# # Ganzes Modul importieren
# import math
#
# # Mit Alias importieren
# import math as m
#
# # Nur bestimmte Werkzeuge importieren
# from math import pi, sqrt
# ```
#
# **Schritt-für-Schritt-Erklärung:**
# 1. **`import`** - Schlüsselwort zum Laden
# 2. **`math`** - Name der Werkzeugkiste
# 3. **`as`** - Optionaler Spitzname
# 4. **`from`** - Importiert spezifische Werkzeuge
#
# **Warum so nützlich:**
# - 🎯 Werkzeuge nicht neu bauen müssen
# - 🔍 Professionelle, optimierte Ausrüstung
# - ⚡ Dein Stall bleibt übersichtlich
# - 🎲 Zugriff auf spezialisierte Werkzeuge

# %%
# Beispiel 1: Module importieren
# Ganzes Modul importieren
import math
print(f"Pi aus math: {math.pi}")

# Mit Alias importieren
import random as r
print(f"Zufallszahl: {r.randint(1, 10)}")

# Nur bestimmte Werkzeuge importieren
from math import sqrt, sin, cos
print(f"Wurzel aus 16: {sqrt(16)}")
print(f"Sinus 90°: {sin(1.57)}")
print(f"Kosinus 0°: {cos(0)}")

# %%
# Beispiel 2: Verschiedene Import-Methoden vergleichen
# Methode 1: import math
import math
print("Methode 1 - import math:")
print(f"  math.pi: {math.pi}")
print(f"  math.sqrt(25): {math.sqrt(25)}")

# Methode 2: import math as m
import math as m
print("\nMethode 2 - import math as m:")
print(f"  m.pi: {m.pi}")
print(f"  m.sqrt(25): {m.sqrt(25)}")

# Methode 3: from math import pi, sqrt
from math import pi, sqrt
print("\nMethode 3 - from math import pi, sqrt:")
print(f"  pi: {pi}")
print(f"  sqrt(25): {sqrt(25)}")

# %%
# Beispiel 3: Mehrere Module importieren
import math
import random
import time

# Berechne eine zufällige Reitdauer
distanz = 1000  # Meter
geschwindigkeit = random.uniform(0.1, 0.9)  # Bruchteil der Maximalgeschwindigkeit
reitzeit = distanz / geschwindigkeit

print("=== Reit-Simulation ===")
print(f"Distanz: {distanz} Meter")
print(f"Geschwindigkeit: {geschwindigkeit:.2f} m/s")
print(f"Reitzeit: {reitzeit:.1f} Minuten")
print(f"Warte 2 Sekunden...")
time.sleep(2)
print(f"Ankunft am Ziel!")

# %% [markdown]
# ## 📦 Werkzeug-Sammlung 2: Das math-Modul - Der Rechen-Bock
#
# **Die wichtigsten math-Werkzeuge:**
#
# **Konstanten:**
# - `math.pi` - Die Zahl Pi (3.14159...)
# - `math.e` - Eulersche Zahl (2.71828...)
# - `math.inf` - Unendlich
#
# **Grundwerkzeuge:**
# - `math.sqrt(x)` - Quadratwurzel
# - `math.pow(x, y)` - x hoch y
# - `math.ceil(x)` - Aufrunden
# - `math.floor(x)` - Abrunden
# - `math.fabs(x)` - Absolutwert

# %%
# 🔍 Übungen mit math-Konstanten
import math

print("=== Mathematische Konstanten ===")
print(f"Pi (π): {math.pi}")
print(f"Eulersche Zahl (e): {math.e}")
print(f"Unendlich: {math.inf}")
print(f"Tau (2π): {math.tau}")

# Praktische Anwendung: Kreisberechnungen
radius = 10
umfang = 2 * math.pi * radius
flaeche = math.pi * radius ** 2
print(f"\nKreis mit r={radius}:")
print(f"  Umfang: {umfang:.2f}")
print(f"  Fläche: {flaeche:.2f}")

# %%
# Beispiel 2: Mathematische Grundwerkzeuge
import math

print("=== Mathematische Werkzeuge ===")

# Wurzel und Potenzen
print(f"sqrt(16): {math.sqrt(16)}")
print(f"pow(2, 3): {math.pow(2, 3)}")
print(f"2**3: {2**3}")

# Runden
zahl = 3.7
print(f"\nZahl: {zahl}")
print(f"round({zahl}): {round(zahl)}")
print(f"math.ceil({zahl}): {math.ceil(zahl)}")
print(f"math.floor({zahl}): {math.floor(zahl)}")

# Absolutwert
print(f"\nmath.fabs(-5.5): {math.fabs(-5.5)}")
print(f"abs(-5.5): {abs(-5.5)}")

# %%
# Beispiel 3: Fortgeschrittene Werkzeuge
import math

print("=== Fortgeschrittene Werkzeuge ===")

# Winkelfunktionen (in Bogenmaß!)
winkel_grad = 45
winkel_rad = math.radians(winkel_grad)
print(f"{winkel_grad}° = {winkel_rad:.3f} rad")
print(f"sin({winkel_grad}°): {math.sin(winkel_rad):.3f}")
print(f"cos({winkel_grad}°): {math.cos(winkel_rad):.3f}")
print(f"tan({winkel_grad}°): {math.tan(winkel_rad):.3f}")

# Logarithmen
print(f"\nlog(10): {math.log(10):.3f}")
print(f"log10(100): {math.log10(100)}")
print(f"log2(8): {math.log2(8)}")

# Spezielle Werkzeuge
print(f"\nfactorial(5): {math.factorial(5)}")
print(f"gcd(24, 36): {math.gcd(24, 36)}")
print(f"lcm(12, 15): {math.lcm(12, 15)}")

# %% [markdown]
# ## ✨ Werkzeug-Sammlung 3: Das random-Modul - Das Zufalls-Pferd
#
# **Die mächtigsten Zufalls-Werkzeuge:**
#
# **Zahlen erzeugen:**
# - `random.randint(a, b)` - Zufällige Ganzzahl von a bis b
# - `random.uniform(a, b)` - Zufällige Kommazahl von a bis b
# - `random.random()` - Zufallszahl zwischen 0 und 1
#
# **Aus Listen wählen:**
# - `random.choice(liste)` - Ein zufälliges Element
# - `random.choices(liste, k=n)` - n zufällige Elemente
# - `random.shuffle(liste)` - Liste mischen
#
# **Verteilungen:**
# - `random.gauss(mu, sigma)` - Normalverteilung
# - `random.expovariate(lambda)` - Exponentialverteilung

# %%
# Beispiel 1: Zufallszahlen erzeugen
import random

print("=== Zufallszahlen ===")

# Ganzzahlen
print(f"Zufällige Zahl 1-6: {random.randint(1, 6)}")
print(f"Zufällige Zahl 0-100: {random.randint(0, 100)}")

# Kommazahlen
print(f"Zufallszahl 0-1: {random.random():.3f}")
print(f"Zufallszahl 10-20: {random.uniform(10, 20):.2f}")

# Mit Seeds reproduzierbar
random.seed(42)
print(f"Mit Seed 42: {random.randint(1, 100)}")
random.seed(42)
print(f"Mit Seed 42: {random.randint(1, 100)} (gleiches Ergebnis!)")

# %%
# Beispiel 2: Aus Listen wählen
import random

print("=== Zufallsauswahl aus Listen ===")

# Pferde auf dem Hof
pferde = ["Thunder", "Stormy", "Sunny", "Shadow", "Blaze", "Misty"]
print(f"Alle Pferde: {pferde}")

# Ein zufälliges Pferd
ziel = random.choice(pferde)
print(f"Zielpferd: {ziel}")

# Drei zufällige Pferde
gruppe = random.choices(pferde, k=3)
print(f"Reitgruppe: {gruppe}")

# Liste mischen
reihenfolge = pferde.copy()
random.shuffle(reihenfolge)
print(f"Gemischte Reihenfolge: {reihenfolge}")

# %%
# Beispiel 3: Fortgeschrittene Zufallswerkzeuge
import random
import math

print("=== Fortgeschrittene Zufallswerkzeuge ===")

# Normalverteilung für Futterwerte
print("Futterverbrauch (Normalverteilung):")
for i in range(5):
    futter = random.gauss(100, 20)  # Mittelwert 100, Stdabw 20
    print(f"  Pferd {i+1}: {max(0, futter):.1f} kg")

# Exponentialverteilung für Wartezeiten
print("\nWartezeiten (Exponentialverteilung):")
for i in range(5):
    warten = random.expovariate(0.1)  # Lambda = 0.1
    print(f"  Wartezeit {i+1}: {warten:.1f} Minuten")

# Zufälliger Punkt im Kreis
def zufalls_punkt_kreis(radius):
    winkel = random.uniform(0, 2 * math.pi)
    r = radius * math.sqrt(random.random())
    x = r * math.cos(winkel)
    y = r * math.sin(winkel)
    return x, y

x, y = zufalls_punkt_kreis(10)
print(f"\nZufälliger Punkt im Kreis r=10: ({x:.2f}, {y:.2f})")

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein Stallhelfer hat versucht, die Werkzeuge zu verwenden, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1

result = math.sqrt(9)
print(f"Ergebnis: {result}")

# %%
# 🐛 Bug #2

import random
zahl = random.zahl(1, 10)
print(f"Zufallszahl: {zahl}")

# %%
# 🐛 Bug #3

import math
winkel = 90
sinus = sin(math.radians(winkel))
print(f"Sinus von {winkel}°: {sinus}")

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Werkzeug-Importer
#
# **Belohnung:** 300 Huf-Punkte + Stall-Schlüssel
#
# In der Werkstatt vom Sonnentals-Hof lernst du, wie du Werkzeugkisten (Module) lädst und mit Aliasen arbeitest.
#
# **Deine Aufgaben:**
#
# 1. **Werkzeugkisten importieren**
#    - Lade die Module `math`, `random` und `time` mit passenden Aliasen (z.B. `import math as m`)
#    - Gib jeweils eine Konstante oder Funktion aus jedem Modul aus (z.B. `math.pi`, `random.randint(1, 10)`)
#
# 2. **Wartezeit-Simulation**
#    - Erstelle eine kleine Funktion oder ein Skript, das eine zufällige Sekundenzahl (1–3) mit `random` erzeugt und `time.sleep()` nutzt
#    - Gib vor und nach der Wartezeit eine kurze Meldung aus (z.B. „Warte auf Pferd …“)
#
# 3. **Sprung-Berechnung**
#    - Nutze `math.sin` und `math.pi`, um für einen Winkel (z.B. 90° in Bogenmaß) eine Sprunghöhe oder einen Wert zu berechnen
#    - Gib das Ergebnis formatiert aus
#
# 4. **Reiter-Generator**
#    - Erstelle eine Namensliste mit 3–5 Reiter-Namen und wähle mit `random.choice()` einen zufälligen Namen aus
#    - Gib den ausgewählten Namen aus
#
# **Beispiel-Code zum Starten:**
# ```python
# import math as m
# import random as r
# import time as t
#
# print(f"Pi: {m.pi}")
# print(f"Zufall 1-10: {r.randint(1, 10)}")
# sekunden = r.randint(1, 3)
# print(f"Warte {sekunden} Sekunden...")
# t.sleep(sekunden)
# print("Bereit!")
# ```
#
# **Bonus-Challenge:**
# - Füge eine weitere Funktion mit dem `datetime`-Modul hinzu (z.B. aktuelle Uhrzeit anzeigen).
#
# **Erwartete Ausgabe:**
# ```
# Pi: 3.141592653589793
# Zufall 1-10: 7
# Warte 2 Sekunden...
# Bereit!
# Reiter: Luna
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Rechen-Bock
#
# **Belohnung:** 400 Huf-Punkte + GPS-Halsband
#
# Du nutzt das math-Modul für Reitplatz-Berechnungen, Winkelumrechnung und Wurzeln.
#
# **Deine Aufgaben:**
#
# 1. **Reitplatz-Berechnung**
#    - Schreibe eine Funktion oder ein Skript, das für einen Radius (Reitplatz) Umfang und Fläche mit `math.pi` berechnet
#    - Gib Radius, Umfang und Fläche formatiert aus
#
# 2. **Zufalls-Zahlen und Summe**
#    - Erzeuge mit `random.randint(1, 100)` fünf Zufallszahlen (z.B. für Futterrationen) und speichere sie in einer Liste
#    - Berechne die Summe und gib die Zahlen sowie die Summe aus
#
# 3. **Winkel-Umrechnung**
#    - Wandle 90°, 180° und 270° mit `math.radians()` in Bogenmaß um
#    - Gib Grad und Bogenmaß für jeden Winkel aus
#
# 4. **Wurzel-Ziehen**
#    - Berechne mit `math.sqrt()` die Wurzeln von 4, 9, 16 und 25
#    - Gib die Ergebnisse übersichtlich aus
#
# **Beispiel-Code zum Starten:**
# ```python
# import math
# import random
#
# radius = 10
# umfang = 2 * math.pi * radius
# flaeche = math.pi * radius ** 2
# print(f"Reitplatz r={radius}: Umfang {umfang:.2f}, Fläche {flaeche:.2f}")
#
# zahlen = [random.randint(1, 100) for _ in range(5)]
# print(f"Zufallszahlen: {zahlen}, Summe: {sum(zahlen)}")
# ```
#
# **Bonus-Challenge:**
# - Füge trigonometrische Berechnungen hinzu (z.B. sin, cos für 45°).
#
# **Erwartete Ausgabe:**
# ```
# Reitplatz r=10: Umfang 62.83, Fläche 314.16
# Zufallszahlen: [23, 67, 12, 89, 34], Summe: 225
# 90° = 1.57 rad | 180° = 3.14 rad | 270° = 4.71 rad
# sqrt(4)=2.0, sqrt(9)=3.0, ...
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Der Zufalls-Hengst
#
# **Belohnung:** 500 Huf-Punkte + Reitmeister-Urkunde
#
# Du baust ein kleines Zufallssystem mit Pferdeauswahl, Wetter und Futterverbrauch.
#
# **Deine Aufgaben:**
#
# 1. **Pferdeauswahl**
#    - Erstelle eine Liste mit 5–6 Pferde-Namen und wähle mit `random.choice()` ein zufälliges Pferd aus
#    - Gib die Liste und das gewählte Pferd aus
#
# 2. **Wetter-Simulation**
#    - Erzeuge mit `random.uniform(-10, 30)` drei Temperaturwerte (z.B. für verschiedene Tage) und runde sie auf eine Dezimalstelle
#    - Gib die Temperaturen mit kurzer Beschreibung aus
#
# 3. **Futter-Verbrauch**
#    - Simuliere 3 Pferde mit je einem zufälligen Futterverbrauch zwischen 5 und 15 kg (mit `random.randint` oder `random.uniform`)
#    - Gib Pferdename und Futtermenge aus und berechne den Gesamtverbrauch
#
# 4. **Pferde-Generator**
#    - Erstelle 3 Pferdenamen mit zugehöriger zufälliger „Geschwindigkeit“ (1–10) und speichere sie (z.B. als Liste von Tupeln)
#    - Gib alle Pferde mit ihrer Geschwindigkeit aus
#
# **Beispiel-Code zum Starten:**
# ```python
# import random
#
# pferde = ["Luna", "Storm", "Blitz", "Stern", "Mond"]
# auswahl = random.choice(pferde)
# print(f"Gewähltes Pferd: {auswahl}")
#
# temp1 = round(random.uniform(-10, 30), 1)
# print(f"Tag 1: {temp1}°C")
# ```
#
# **Bonus-Challenge:**
# - Füge eine Variable mit Normalverteilung hinzu (z.B. `random.gauss(10, 2)` für Futtermenge).
#
# **Erwartete Ausgabe:**
# ```
# Gewähltes Pferd: Storm
# Temperaturen: 12.3°C, 22.1°C, 8.0°C
# Pferd 1: 12 kg, Pferd 2: 8 kg, Pferd 3: 14 kg — Gesamt: 34 kg
# Pferde: [('Luna', 7), ('Storm', 3), ('Blitz', 9)]
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten des Reitmeisters (Reflexion)
#
# Bevor du weiterreitest, denke über diese Fragen nach:
#
# 1. **Warum sollte man Werkzeuge (Module) verwenden statt alles selbst zu bauen?**
#
# 2. **Was ist der Unterschied zwischen `import math` und `from math import sqrt`?**
#
# 3. **Wann verwendet man `random.choice()` und wann `random.randint()`?**
#
# Diskutiere deine Gedanken mit anderen Reitern!

# %% [markdown]
# ### 📖 Werkzeug-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **import** 📦: Werkzeugkiste laden
# - **from** 🎯: Selektiver Import
# - **as** 🏷️: Spitzname
# - **math** 🔢: Mathe-Werkzeugkiste
# - **random** 🎲: Zufalls-Werkzeugkiste
# - **pi** ⭕: Kreiszahl
# - **sqrt()** √: Wurzelziehen
# - **randint()** 🎯: Zufällige Ganzzahl
# - **choice()** 🎲: Zufällige Auswahl
# - **seed()** 🌱: Zufalls-Seed

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ✅ Werkzeugkisten mit import laden
# - ✅ Spitznamen für Werkzeugkisten verwenden
# - ✅ Spezielle Werkzeuge importieren
# - ✅ math-Werkzeugkiste für Berechnungen nutzen
# - ✅ random-Werkzeugkiste für Zufallszahlen verwenden
# - ✅ Werkzeugkisten in eigenen Programmen einsetzen
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die Boss-Quests!

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Exzellent!** Du hast die Werkstatt vom Sonnentals-Hof gemeistert!
#
# **Das hast du gelernt:**
# - Werkzeugkisten importieren und verwenden
# - Mathematische Berechnungen durchführen
# - Zufallsereignisse simulieren
# - Verschiedene Import-Methoden kennen
# - Professionelle Werkzeugbibliotheken nutzen
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🏇 **Reitsport:** Statistiken, Training, Wettkämpfe
# - 🐎 **Pflege:** Futterberechnung, Medikamentendosierung
# - 📊 **Betrieb:** Buchhaltung, Planung, Analyse
# - 🎮 **Spiele:** Pferdesimulationen, Zuchtprogramme
# - 🔬 **Wissenschaft:** Bewegungsanalyse, Forschung
#
# **Als Nächstes:** In Woche 8 lernst du **Dictionaries und Tupel**!

# %% [markdown]
# ## 🐉 Boss-Kampf: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Quests sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 Huf-Punkte + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Der Hof-Simulator
#
# **Belohnung:** 500 Huf-Punkte + Simulations-Sattel
#
# Du baust einen kleinen Hof-Simulator mit Ställen, Futterberechnung und „gesunden“ Pferden.
#
# **Deine Aufgaben:**
#
# 1. **Hof-Generator**
#    - Erstelle eine Funktion `erstelle_hof(anzahl_staelle, hof_typ)`, die eine Liste mit Stall-Namen (z.B. mit `random.choice` aus einer Vorlage) zurückgibt
#    - Gib die Liste der Ställe und den Hof-Typ aus
#
# 2. **Futter-Berechnung**
#    - Schreibe eine Funktion `futter_berechnung(pferde_anzahl, kg_pro_pferd, tage)`, die den Gesamtfutterbedarf in kg berechnet; nutze `math.ceil` zum Aufrunden
#    - Gib den Futterbedarf für ein Beispiel aus
#
# 3. **Pferde-Gesundheit (simuliert) und gesunde Pferde**
#    - Erstelle eine Funktion, die für ein Pferd (z.B. Name und „Gesundheitswert“ 0–1 mit `random.uniform`) einen Gesundheitswert zurückgibt
#    - Erstelle eine Funktion, die aus einer Pferdeliste die „gesunden“ filtert (z.B. Gesundheitswert > 0.5)
#    - Gib die gefilterte Liste aus
#
# 4. **Hauptprogramm**
#    - Simuliere 5 Höfe mit deinen Funktionen, berechne für ein Beispiel den Futterbedarf und zeige eine kurze Statistik (z.B. wie viele Ställe pro Hof, wie viele „gesunde“ Pferde)
#
# **Beispiel-Code zum Starten:**
# ```python
# import math
# import random
#
# def erstelle_hof(anzahl_staelle, hof_typ):
#     namen = ["Nord", "Süd", "Ost", "West", "Mitte"]
#     return [random.choice(namen) + f"-Stall-{i}" for i in range(anzahl_staelle)]
#
# def futter_berechnung(pferde_anzahl, kg_pro_pferd, tage):
#     return math.ceil(pferde_anzahl * kg_pro_pferd * tage)
# ```
#
# **Bonus-Challenge:**
# - Füge zufällige „Turniere“ mit Ergebnissen (z.B. Name, Platz) hinzu.
#
# **Erwartete Ausgabe:**
# ```
# Hof: ['Nord-Stall-0', 'Süd-Stall-1', ...] (Typ: Reitschule)
# Futterbedarf: 150 kg
# Gesunde Pferde: 3 von 5
# Statistik: 5 Höfe, 12 gesunde Pferde
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Der Champion-Trainer
#
# **Belohnung:** 600 Huf-Punkte + Meister-Peitsche
#
# Du simulierst ein Trainingssystem mit „Trainingszuständen“ und Zufalls-Messungen.
#
# **Deine Aufgaben:**
#
# 1. **Trainings-Zustand**
#    - Erstelle eine Funktion `erstelle_trainingszustand(pferd_name, anzahl_runden)`, die eine Liste von Zufallswerten (z.B. „Punkte“ 1–10 mit `random.randint`) für jede Runde zurückgibt
#    - Gib den Zustand aus
#
# 2. **Trainings-Messung**
#    - Erstelle eine Funktion `messung(trainingszustand, runde_index)`, die den Wert der Runde an der Stelle `runde_index` zurückgibt
#    - Gib das Messergebnis für ein Beispiel aus
#
# 3. **Trainings-Plan (simuliert)**
#    - Erstelle eine Funktion `trainings_plan(pferd, ziel_runden)`, die einen „Plan“ zurückgibt (z.B. Liste mit zufälligen Zielwerten mit `random.choices` oder `random.randint`)
#    - Gib den Plan aus
#
# 4. **Demo**
#    - Erzeuge einen Trainingszustand mit 5 Runden, führe „Messungen“ durch und vergleiche mit dem Plan; gib eine kurze Zusammenfassung aus
#
# **Beispiel-Code zum Starten:**
# ```python
# import random
#
# def erstelle_trainingszustand(pferd_name, anzahl_runden):
#     return [random.randint(1, 10) for _ in range(anzahl_runden)]
#
# def messung(trainingszustand, runde_index):
#     return trainingszustand[runde_index]
# ```
#
# **Bonus-Challenge:**
# - Simuliere ein „Meister-Training“ mit mehreren Phasen (z.B. mehrere Listen) und gib den Gesamtfortschritt aus.
#
# **Erwartete Ausgabe:**
# ```
# Trainingszustand Luna: [7, 8, 6, 9, 8]
# Messung Runde 2: 8
# Plan: [8, 9, 8, 9, 10]
# Demo: 5 Runden, Durchschnitt 7.6, Ziel erreicht in 3 Runden
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Die Ausrüstungs-Schmiede
#
# **Belohnung:** 400 Huf-Punkte + Schmiedehammer
#
# Du baust eine vereinfachte „Schmiede“-Simulation mit Materialien und Qualitätswerten.
#
# **Deine Aufgaben:**
#
# 1. **Ausrüstungs-Struktur**
#    - Erstelle eine Funktion `erstelle_ausruestung(material, anzahl_teile)`, die eine „Ausrüstung“ als Liste zurückgibt: z.B. für jedes Teil einen Qualitätswert mit `random.uniform(0, 1)`
#    - Gib die Struktur (z.B. Liste der Qualitätswerte) aus
#
# 2. **Herstellung (simuliert)**
#    - Schreibe eine Funktion `herstellen(teile_liste, runden)`, die in einer Schleife `runden`-mal zufällig ein Teil „verbessert“ (z.B. einen Qualitätswert mit `random.uniform` anhebt)
#    - Gib nach der Herstellung eine kurze Meldung aus (z.B. „Herstellung abgeschlossen, 10 Runden“)
#
# 3. **Qualitäts-Vorhersage (simuliert)**
#    - Erstelle eine Funktion `qualitaet_vorhersage(ausruestung)`, die aus den Qualitätswerten einen Durchschnitt oder eine „Gesamtqualität“ berechnet (z.B. mit `math` oder `sum`/`len`)
#    - Gib die Qualität für ein Beispiel aus
#
# 4. **Analyse und Demo**
#    - Berechne für eine Ausrüstung die Qualität und gib die Einzelteile sowie die Gesamtqualität in Prozent aus
#
# **Beispiel-Code zum Starten:**
# ```python
# import random
#
# def erstelle_ausruestung(material, anzahl_teile):
#     return [random.uniform(0, 1) for _ in range(anzahl_teile)]
#
# def qualitaet_vorhersage(ausruestung):
#     return sum(ausruestung) / len(ausruestung) * 100
# ```
#
# **Bonus-Challenge:**
# - Füge „Meister-Qualitäten“ mit mehreren Schichten hinzu (z.B. zweite Liste mit Verfeinerungsstufen).
#
# **Erwartete Ausgabe:**
# ```
# Ausrüstung: [0.7, 0.8, 0.6, 0.9]
# Herstellung abgeschlossen, 5 Runden
# Qualität: 75.0%
# Demo: 4 Teile, Gesamtqualität 75.0%
# ```

# %%
# 🐉 Deine Lösung hier:

print()
print("🎉 +400 Huf-Punkte: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Schmied der unendlichen Werkzeuge besiegt!")
print("⭐ Titel erhalten: Meister der Werkzeugkisten")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 7 gemeistert!")
print("📚 Nächste Woche: Dictionaries und Tupel!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen:

# %%
# ✅ Lösung Bug #1: Werkzeugkiste nicht importiert

# Problem: math wurde nicht importiert
import math
result = math.sqrt(9)
print(f"Ergebnis: {result}")

# %%
# ✅ Lösung Bug #2: Falscher Werkzeugname

# Problem: random.zahl existiert nicht
import random
zahl = random.randint(1, 10)
print(f"Zufallszahl: {zahl}")

# %%
# ✅ Lösung Bug #3: Werkzeug nicht gefunden

# Problem: sin existiert nicht ohne math.
import math
winkel = 90
sinus = math.sin(math.radians(winkel))
print(f"Sinus von {winkel}°: {sinus}")
