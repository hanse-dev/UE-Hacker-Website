# %% [markdown]
# # 🐛 Woche 1 – Debug-Quest: Finde die Fehler!
#
# > 📖 Vorher: `woche1_abenteuer_lektion.ipynb` durcharbeiten

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein junger Magier hat versucht, seine ersten Zauber zu wirken, aber etwas läuft schief! Finde die Fehler:

# %% [markdown]
# ### 🐛 Bug #1
#
# **Was passiert:** Python liest `Hallo` und `Welt` als Variablennamen – aber diese Variablen gibt es nicht. Text muss immer in Anführungszeichen stehen, damit Python weiß: das ist Text, keine Variable.

# %%
# 🐛 Bug #1: Fehlende Anführungszeichen

print(Hallo Welt)

# %% [markdown]
# ### 🐛 Bug #2
#
# **Was passiert:** `alter` ist eine Zahl (Integer), der Text davor und danach ist ein String. Python kann diese zwei Typen nicht direkt mit `+` verbinden – das ist wie versuchen, einen Stein an einen Faden zu knoten. `str()` löst das: es verwandelt die Zahl in Text.

# %%
# 🐛 Bug #2: Zahl ohne str()

alter = 25
print("Ich bin " + alter + " Jahre alt.")

# %% [markdown]
# ### 🐛 Bug #3
#
# **Was passiert:** Die Variable heißt `name`, aber im `print()` steht `nam` – ein Buchstabe fehlt. Python sucht exakt nach dem Namen `nam` und findet ihn nicht. Tippfehler in Variablennamen sind einer der häufigsten Anfängerfehler!

# %%
# 🐛 Bug #3: Falsche Variable

name = "Gandalf"
print("Willkommen, " + nam)
