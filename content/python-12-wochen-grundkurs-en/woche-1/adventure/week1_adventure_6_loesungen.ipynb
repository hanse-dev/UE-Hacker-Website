# %% [markdown]
# # 🔧 Solutions – 🗺️ Week 1 – Introduction and your first program: The journey begins!
# > Tried it yourself first? Then check here!

# %% [markdown]
# ## 🐛 Debug Solution Suggestions

# %% [markdown]
# **Explanation:** Python reads `Hello` and `World` as variable names – but these variables don't exist. Text must always be in quotation marks so Python knows: this is text, not a variable.

# %%
# Problem: text without quotation marks
print("Hello World")

# %% [markdown]
# **Explanation:** `age` is a number (Integer), the text before it is a String. Python cannot directly connect these two types with `+` – it's like trying to tie a stone to a thread. `str()` solves this: it converts the number to text.

# %%
# Problem: number cannot be directly connected with text
age = 25
print("The hero is " + str(age) + " years old.")

# %% [markdown]
# **Explanation:** The variable is called `name`, but in `print()` it says `nam` – one letter missing. Python searches exactly for the name `nam` and cannot find it. Typos in variable names are one of the most common beginner errors!

# %%
# Problem: variable 'nam' does not exist
name = "Aria"
print("Welcome, " + name)

# %% [markdown]
# ## ⭐ Mission Solution Suggestions

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: The Apprentice Wizard

# %%
# Step 1 – Personal introduction
print("Apprentice: Aria")
print("Welcome to the magical land of Pythonia!")
print()

# Step 2 – Choose a favourite spell
favourite_spell = "Fireball"
print("My favourite spell is " + favourite_spell + ".")

# Bonus
print("Never give up – magic is within everyone!")

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: The Treasure Hunter

# %%
# Step 1 – Collect treasure data
treasure_name = "Crystal of Eternity"
treasure_type = "Magic artefact"
gold_value = 500

# Step 2 – Output treasure report
print("=== TREASURE REPORT ===")
print("Treasure: " + treasure_name)
print("Type: " + treasure_type)
print("Gold value: " + str(gold_value) + " gold")

# Step 3 – Discovery report
print()
print("Found: " + treasure_name + " (" + treasure_type + ") worth " + str(gold_value) + " gold!")
print("=== SEARCH COMPLETE ===")

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Village Hero

# %%
# Step 1 – Collect hero data
hero_name = "Aria"
hero_class = "Mage"
strength = 85

# Step 2 – Hero heading
print("=== HERO PROFILE ===")
print()

# Step 3 – Battle description
print(hero_name + " is a brave " + hero_class + ".")
print("With strength " + str(strength) + ", " + hero_name + " defends the village.")
print("The villagers are safe thanks to " + hero_class + " " + hero_name + "!")

# Step 4 – Motivation
print()
print("For the village!")
print("Heroes never give up – we stand strong until the end!")

# %% [markdown]
# ## 🐉 Boss Quest Solution Suggestions

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 1: The Tower of Knowledge

# %%
# Step 1 – Write a hero poem
line1 = "Through dark forests and stormy seas"
line2 = "The brave hero fights with skill and ease"
line3 = "Each challenge faced with courage true"
line4 = "A legend born from me and you"

# Step 2 – Book entry
title = "The Hero's Journey"
author = "Aria of Pythonia"
stars = 5

# Step 3 – Output formatted
print("=== " + title + " ===")
print("---")
print(line1)
print(line2)
print(line3)
print(line4)
print()

# Step 4 – Metadata
print("Author: " + author)
print("Rating: " + str(stars) + " stars")

# Bonus: secret message as comment
# SECRET: The hidden treasure of Pythonia lies beneath the old oak tree

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss Quest 2: The Curse of the Silent Dragon

# %%
# Step 1 – Curse-breaking plan
step1 = "Gather the three magic ingredients at midnight"
step2 = "Speak the ancient words of unbinding in reverse"
step3 = "Place the dragon amulet on the curse stone"

# Step 2 – Document the steps
print("=== CURSE-BREAKING PLAN ===")
print("Step 1: " + step1)
print("Step 2: " + step2)
print("Step 3: " + step3)
print()

# Step 3 – Magic ingredients
ingredient = "Dragon Tear, Moon Blossom, Shadow Crystal"
print("Magic ingredients: " + ingredient)
print()

# Step 4 – Warning and success
print("WARNING: Do not speak the words out loud – write them only!")
print("Spell is being cast...")
print("Success! The curse is broken!")

# Bonus: dragon's reaction
# Dragon roars, shakes head, smoke dissolves – then bows in gratitude

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 3: The Portal of Possibilities

# %%
# Step 1 – Describe the portal
color = "Deep violet"
shape = "Spiral"

# Step 2 – Record measurements
size = 3
stability = 68

print("Colour: " + color)
print("Shape: " + shape)
print("Size: " + str(size) + " metres")
print("Stability: " + str(stability) + " percent")
print()

# Step 3 – Warning and navigation
print("=== PORTAL WARNING ===")
print("CAUTION: All travellers keep a minimum safe distance of 50 metres!")
print()

# Step 4 – Scientific question
question = "Does this portal lead to another time, another world, or another dimension?"
print("Open research question: " + question)

print()
print("🎉 +400 XP: Challenge complete!")
print("🏆 You broke the curse of the Silent Dragon!")
print("⭐ Title earned: Guild Master")
print()
print("🎊 CONGRATULATIONS! You have mastered Week 1!")
print("🗺️ Next week: Data types and variables!")
