# %% [markdown]
# # 🐴 Woche 1 – Einführung und erstes Programm: Der Reitbeginn
#
# **Huf-Punkte zu verdienen:** 1000 Punkte
# **Herausforderung:** Das scheue Pferd gewinnen

# %% [markdown]
# ## 🌟 Die Freundschaft beginnt: Willkommen im Reiterhof Sonnental
#
# Willkommen, junge Pferdefreund:in! Du betrittst den idyllischen **Reiterhof Sonnental** – ein Ort voller Natur, Freundschaft und Abenteuer mit Pferden. In dieser Woche lernst du die vier wichtigsten Lektion:
#
# **Deine Mission:**
# - Lerne, wie du Text mit `print()` ausgibst
# - Speichere Informationen in **Variablen**
# - Kombiniere Texte und Variablen zu Nachrichten
# - Füge Kommentare hinzu, um deinen Code zu erklären
#
# **Leg los!** Dein Pferdefreund wartet schon auf dich...

# %% [markdown]
# ## 🐎 Was ist eine Lektion?
#
# Eine **Lektion** ist wie eine Trainingseinheit für dich und dein Pferd - eine festgelegte Übung, die ihr gemeinsam lernt und beherrscht.
#
# **Stell dir vor:**
# - 🐴 Pferde brauchen klare Anweisungen und Training
# - 👥 Jede Lektion baut auf der vorherigen auf
# - 🌿 Mit jeder Lektion werdet ihr besser zusammen
# - 🏆 Am Ende könntet ihr ganze Parcours reiten
#
# **In der Programmierung lernen wir:**
# - Die grundlegenden Lektionen (Befehle) von Python
# - Wie man diese Lektionen kombiniert
# - Wie man eigene Lektionen erstellt (später)
#
# **Jede Lektion, die du lernst, macht dich zu einem besseren Reiter/Programmierer!**

# %% [markdown]
# ## 📚 Lektion 1: Der `print()`-Ruf
#
# **Was es ist:** `print()` ist dein erster Befehl. Er gibt Text auf dem Bildschirm aus.
#
# **Warum nützlich:**
# - 🐴 Ruft Pferde beim Namen
# - 📝 Schreibt Notizen für die Reitstunde
# - 🗺️ Erstellt Reitweg-Beschreibungen
# - 📖 Hält Trainingserfolge fest
#
# **Wichtig:** Text muss immer in Anführungszeichen `"` oder `'` stehen!

# %%
# Beispiel 1: Einfache Textausgabe
print("Hallo auf dem Reiterhof!")
print("Willkommen im Sonnental!")

# Beispiel 2: Mehrere Zeilen
print("Dies ist dein erster Tag.")
print("Du bist jetzt eine Pferdefreund:in!")

# Beispiel 3: Leere Zeile für bessere Übersicht
print()
print("=== Dein Reitbeginn ===")

# %% [markdown]
# ## 🐎 Lektion 2: Variablen - Futtertröge
#
# **Was es ist:** Eine Variable ist wie ein Futtertrogt mit Namen. Du kannst Informationen darin speichern und später wieder abrufen.
#
# **Warum nützlich:**
# - 🥕 Bewahrt Futter und Leckerlis auf
# - 🏇 Merkt sich die Namen der Pferde
# - 🧺 Speichert Ausrüstung und ihre Funktion
# - 🔄 Kann jederzeit neu befüllt werden
#
# **Wichtig:**
# - Text: in Anführungszeichen (`"Bobby"`)
# - Zahlen: ohne Anführungszeichen (`42`)

# %%
# Beispiel 1: Verschiedene Variablentypen
pferd_name = "Bobby"       # Text (String)
pferd_alter = 5            # Zahl (Integer)
pferd_groesse = 150        # Zahl (Integer)
pferd_freundlich = True    # Wahrheitswert (Boolean)

# Beispiel 2: Variablen ausgeben
print("Pferdename:")
print(pferd_name)
print("Alter:")
print(pferd_alter)
print("Größe in cm:")
print(pferd_groesse)

# Beispiel 3: Variablen können sich ändern
print("Futter vor dem Training: " + str(2) + " kg")
futter_menge = 3  # Nach Training mehr Futter
print("Futter nach dem Training: " + str(futter_menge) + " kg")

# %% [markdown]
# ## 🍃 Lektion 3: Texte kombinieren
#
# **Was es ist:** Mit `+` kannst du Texte und Variablen zu einer Nachricht verbinden.
#
# **Warum nützlich:**
# - 📜 Schreibt Pferdebeschreibungen
# - 🏰 Erstellt Stallpläne
# - ⚔️ Kombiniert Ausrüstung mit ihrer Funktion
# - 📊 Macht Ausgaben informativer
#
# **Wichtig:** Zahlen müssen mit `str()` in Text umgewandelt werden!

# %%
# Beispiel 1: Einfache Kombination
name = "Stormy"
rasse = "Haflinger"
print("Pferd: " + name)
print("Rasse: " + rasse)

# Beispiel 2: Mit Zahlen (str() nötig!)
alter = 8
print("Alter: " + str(alter) + " Jahre")

# Beispiel 3: Komplexe Sätze
print(name + " ist ein " + rasse + " und " + str(alter) + " Jahre alt.")

# Beispiel 4: Mehrere Informationen
print()
print("=== PFERDEPROFIL ===")
print("Name: " + name)
print("Rasse: " + rasse)
print("Alter: " + str(alter) + " Jahre")
print("==================")

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein junger Reiter hat versucht, die ersten Befehle zu geben, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1: Fehlende Anführungszeichen

print(Hallo Pferd)

# %%
# 🐛 Bug #2: Zahl ohne str()

stallnummer = 12
print("Mein Stall ist Nummer " + stallnummer)

# %%
# 🐛 Bug #3: Falsche Variable

pferd = "Lucky"
print("Willkommen, " + pferde)

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Stallhelfer
#
# **Belohnung:** 300 Huf-Punkte + Stallkarte
#
# Deine erste Aufgabe im Stall! Zeige, dass du die Grundbefehle für den Reiterhof beherrschst.
#
# **Deine Aufgaben:**
#
# 1. **Persönliche Vorstellung**
#    - Gib deinen Namen mit `print()` aus
#    - Gib eine freundliche Begrüßung für den Reiterhof aus
#    - Füge eine leere Zeile für bessere Übersicht ein
#
# 2. **Lieblingspferd wählen**
#    - Erstelle eine Variable für den Namen deines Lieblingspferdes
#    - Gib den Pferdenamen in einem vollständigen Satz aus
#    - Nutze `str()` falls du Zahlen verwendest
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Vorstellung
# print("Stallhelfer: [Dein Name]")
#
# # 2. Lieblingspferd
# lieblingspferd = "Blitz"
# print("Mein Lieblingspferd: " + lieblingspferd)
# ```
#
# **Bonus-Challenge:**
# - Gib deinen Lieblingsreitspruch aus!
#
# **Erwartete Ausgabe:**
# ```
# Stallhelfer: Anna
# Willkommen auf dem Reiterhof Sonnental!
#
# Mein Lieblingspferd: Blitz
# Ich freue mich auf die Arbeit!
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Pferdeflüsterer
#
# **Belohnung:** 400 Huf-Punkte + Futtereimer
#
# Du musst alle Pferde füttern! Dokumentiere deine Arbeit sorgfältig.
#
# **Deine Aufgaben:**
#
# 1. **Futterdaten erfassen**
#    - Erstelle eine Variable für den Pferdenamen (Text)
#    - Erstelle eine Variable für die Futterart (Text)
#    - Erstelle eine Variable für die Futtermenge in kg (Zahl)
#
# 2. **Fütterplan ausgeben**
#    - Gib eine Überschrift "=== FÜTTERPLAN ===" aus
#    - Gib jeden Wert mit Beschreibung in einer eigenen Zeile aus
#    - Nutze `str()` für die Futtermenge
#
# 3. **Fütterungsbericht erstellen**
#    - Erstelle einen Satz, der alle drei Informationen kombiniert
#    - Füge eine Abschlusszeile "=== FÜTTERUNG ABGESCHLOSSEN ===" hinzu
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Futterdaten erfassen
# pferdename = "Moritz"
# futterart = "Hafer"
# futtermenge = 3
#
# # 2. Fütterplan ausgeben
# print("=== FÜTTERPLAN ===")
# print("Pferd: " + pferdename)
# ```
#
# **Bonus-Challenge:**
# - Füge die Fütterungszeit hinzu!
#
# **Erwartete Ausgabe:**
# ```
# === FÜTTERPLAN ===
# Pferd: Moritz
# Futterart: Hafer
# Menge: 3 kg
#
# Moritz bekommt 3 kg Hafer.
# === FÜTTERUNG ABGESCHLOSSEN ===
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Das Reitturnier
#
# **Belohnung:** 500 Huf-Punkte + Turnierbande
#
# Das große Turnier beginnt! Erstelle ein Teilnehmerprofil.
#
# **Deine Aufgaben:**
#
# 1. **Turnierdaten sammeln**
#    - Erstelle eine Variable für den Reiternamen
#    - Erstelle eine Variable für den Pferdenamen
#    - Erstelle eine Variable für die Startnummer
#    - Erstelle eine Variable für die Disziplin
#    - Erstelle eine Variable für die Erfahrung (in Jahren)
#
# 2. **Turnierüberschrift erstellen**
#    - Gib eine Überschrift "=== TURNIERPROFIL ===" aus
#    - Füge eine leere Zeile ein
#    - Gib alle Turnierdaten strukturiert aus
#
# 3. **Wettkampfbeschreibung formulieren**
#    - Erstelle 3 vollständige Sätze über den Wettkampf
#    - Kombiniere verschiedene Variablen in den Sätzen
#    - Nutze `str()` für alle Zahlen
#
# 4. **Motivation hinzufügen**
#    - Gib "Viel Erfolg!" aus
#    - Gib einen inspirierenden Motivationsspruch aus
#    - Beende mit "Auf zum Sieg!"
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Turnierdaten sammeln
# reitername = "Lisa"
# pferdename = "Donnerwetter"
# startnummer = 42
# disziplin = "Springreiten"
# erfahrung = 5
#
# # 2. Turnierüberschrift
# print("=== TURNIERPROFIL ===")
# print()
# print("Reiter: " + reitername)
# ```
#
# **Bonus-Challenge:**
# - Füge die Hindernishöhe hinzu!
#
# **Erwartete Ausgabe:**
# ```
# === TURNIERPROFIL ===
#
# Reiter: Lisa
# Pferd: Donnerwetter
# Startnummer: 42
# Disziplin: Springreiten
# Erfahrung: 5 Jahre
#
# Lisa reitet auf Donnerwetter im Springreiten.
# Sie trägt die Startnummer 42.
# Mit 5 Jahren Erfahrung ist sie gut vorbereitet.
#
# Viel Erfolg!
# Gib dein Bestes und hab Vertrauen!
# Auf zum Sieg!
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten der erfahrenen Reitlehrerin (Reflexion)
#
# Bevor du weiterreitest, denke über diese Fragen nach:
#
# 1. **Warum müssen Texte immer in Anführungszeichen?**
#
# 2. **Was passiert, wenn du versuchst, eine Zahl direkt mit Text zu verbinden?**
#
# 3. **Wie können Variablen dir beim Umgang mit Pferden helfen?**
#
# Diskutiere deine Gedanken mit anderen Pferdefreunden!

# %% [markdown]
# ### 📖 Reiterhof-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **print()** 🐴: Befehl zur Textausgabe
# - **Variable** 🥕: Behälter zum Speichern von Informationen
# - **String** 📝: Text in Anführungszeichen
# - **Integer** 🔢: Ganze Zahl ohne Komma
# - **Boolean** ✅: Wahrheitswert (True/False)
# - **Verkettung** ⛓️: Verbinden von Texten mit `+`
# - **str()** 🔄: Wandelt Zahlen in Text um
# - **Kommentar** 📋: Erklärung im Code mit `#`
# - **Syntax** 📐: Regeln für korrekten Code
# - **Fehler** 🐛: Wenn der Code nicht funktioniert
# - **Debugging** 🔧: Fehler finden und beheben
# - **Ausgabe** 📺: Was auf dem Bildschirm erscheint

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ✅ Text mit `print()` ausgeben
# - ✅ Informationen in Variablen speichern
# - ✅ Texte mit `+` und `str()` kombinieren
# - ✅ Kommentare mit `#` hinzufügen
# - ✅ Einfache Fehler finden und beheben
# - ✅ Eigene kleine Programme schreiben
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die finalen Herausforderungen!

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Wunderbar!** Du hast die Grundlagen der Programmierung gemeistert!
#
# **Das hast du gelernt:**
# - Wie du dem Computer mit `print()` Befehle gibst
# - Wie du Informationen in Variablen speicherst
# - Wie du Texte und Zahlen kombinierst
# - Wie du deinen Code mit Kommentaren erklärst
# - Wie du einfache Fehler selbst findest
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🐴 **Pferdesport:** Anzeigen von Turnierergebnissen
# - 🌾 **Landwirtschaft:** Protokolle für Futterrationen
# - 🏇 **Reitställe:** Verwaltung von Pferdedaten
# - 🦄 **Tierpflege:** Dokumentation von Pflegeplänen
# - 📊 **Pferdezucht:** Stammbäume und Zuchtdaten
#
# **Als Nächstes:** In Woche 2 lernst du **Datentypen und Variablen**!

# %% [markdown]
# ## 🏆 Abschluss-Challenge: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Herausforderungen sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 Huf-Punkte + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Das Futterbuch
#
# **Belohnung:** 500 Huf-Punkte + Futterbuch
#
# Das Futterbuch des Reiterhofs muss vervollständigt werden!
#
# **Deine Aufgaben:**
#
# 1. **Futtergedicht verfassen**
#    - Schreibe 4 Zeilen über die Bedeutung guten Futters
#    - Lege für jede Zeile eine eigene Variable an
#    - Die Zeilen sollten zusammen ein Gedicht ergeben
#
# 2. **Bucheintrag erstellen**
#    - Erstelle eine Variable für den Titel des Gedichts
#    - Erstelle eine Variable für deinen Namen als Verfasser
#    - Erstelle eine Variable für die Bewertung (1-5 Karotten)
#
# 3. **Gedicht formatiert ausgeben**
#    - Gib den Titel als Überschrift aus
#    - Gib eine Trennlinie aus
#    - Gib alle vier Zeilen untereinander aus
#    - Füge eine leere Zeile ein
#
# 4. **Metadaten hinzufügen**
#    - Gib "Verfasser: [Name]" aus
#    - Gib "Bewertung: [Anzahl] Karotten" aus
#    - Gib einen Satz aus, warum gutes Futter wichtig ist
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Gedicht erstellen
# zeile1 = "Gutes Futter macht Pferde stark"
# zeile2 = "Hafer, Heu und frisches Gras"
# zeile3 = "Gesunde Pferde, voller Kraft"
# zeile4 = "Das ist es, was sie brauchen"
#
# # 2. Bucheintrag
# titel = "Ode ans Futter"
# verfasser = "Dein Name"
# bewertung = 5
#
# # 3. Ausgabe
# print("=== " + titel + " ===")
# print("---")
# ```
#
# **Bonus-Challenge:**
# - Füge ein geheimes Futterrezept als Kommentar hinzu!
#
# **Erwartete Ausgabe:**
# ```
# === Ode ans Futter ===
# ---
# Gutes Futter macht Pferde stark
# Hafer, Heu und frisches Gras
# Gesunde Pferde, voller Kraft
# Das ist es, was sie brauchen
#
# Verfasser: Anna Pferdefreund
# Bewertung: 5 Karotten
# Gutes Futter ist die Grundlage für gesunde und glückliche Pferde.
# ```

# %%
# 🐴 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Das scheue Pferd
#
# **Belohnung:** 600 Huf-Punkte + Vertrauensbande
#
# Ein scheues Pferd muss gewonnen werden! Nur der perfekte Umgang hilft.
#
# **Deine Aufgaben:**
#
# 1. **Annäherungsplan entwickeln**
#    - Erstelle Variablen für 3 Annäherungsschritte
#    - Jeder Schritt sollte eine klare Beschreibung haben
#    - Nummeriere die Schritte (Schritt 1, 2, 3)
#
# 2. **Schritte dokumentieren**
#    - Gib eine Überschrift "=== TRAININGSPLAN ===" aus
#    - Gib jeden Schritt mit seiner Nummer und Beschreibung aus
#    - Füge zwischen den Schritten leere Zeilen ein
#
# 3. **Positive Wirkung beschreiben**
#    - Erstelle eine Variable für die erwartete Wirkung
#    - Gib "Erwartete Wirkung: [Wirkung]" aus
#    - Die Wirkung sollte positiv und ermutigend sein
#
# 4. **Vorsicht und Erfolg**
#    - Gib eine Warnung vor schnellen Bewegungen aus
#    - Gib "Training wird durchgeführt..." aus
#    - Gib "Erfolg! Das Pferd vertraut dir!" aus
#    - Beende mit "Vertrauensbande geknüpft!"
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Annäherungsschritte erstellen
# schritt1 = "Langsam und ruhig nähern"
# schritt2 = "Sanft sprechen und Hand ausstrecken"
# schritt3 = "Leckerli anbieten und streicheln"
#
# # 2. Trainingsplan ausgeben
# print("=== TRAININGSPLAN ===")
# print()
# print("Schritt 1: " + schritt1)
# ```
#
# **Bonus-Challenge:**
# - Beschreibe die Körpersprache des Pferdes (Ohren, Schwanz, etc.)!
#
# **Erwartete Ausgabe:**
# ```
# === TRAININGSPLAN ===
#
# Schritt 1: Langsam und ruhig nähern
# Schritt 2: Sanft sprechen und Hand ausstrecken
# Schritt 3: Leckerli anbieten und streicheln
#
# Erwartete Wirkung: Das Pferd wird ruhiger und vertraut dir mehr.
#
# WARNUNG: Vermeide schnelle Bewegungen und laute Geräusche!
#
# Training wird durchgeführt...
# Erfolg! Das Pferd vertraut dir!
# Vertrauensbande geknüpft!
# ```

# %%
# 🐴 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Das Springturnier
#
# **Belohnung:** 400 Huf-Punkte + Turnier-Urkunde
#
# Das große Springturnier beginnt! Erstelle einen kompletten Bericht.
#
# **Deine Aufgaben:**
#
# 1. **Parcours beschreiben**
#    - Erstelle eine Variable für die Anzahl der Hindernisse
#    - Erstelle eine Variable für die maximale Höhe (in cm)
#    - Erstelle eine Variable für die Parcourslänge (in Metern)
#    - Gib alle drei Eigenschaften strukturiert aus
#
# 2. **Schwierigkeit bewerten**
#    - Erstelle eine Variable für die Schwierigkeitsstufe (1-5 Sterne)
#    - Gib "Schwierigkeit: [Anzahl] Sterne" aus
#    - Erstelle eine Einschätzung für Reiter und Pferd
#
# 3. **Startliste erstellen**
#    - Gib eine Überschrift "=== STARTLISTE ===" aus
#    - Liste 3 Teilnehmer mit Startnummern auf
#    - Gib die Startzeiten an
#
# 4. **Siegerehrung und Dank**
#    - Beschreibe die geplante Siegerehrung
#    - Gib einen Dank an alle Helfer aus
#    - Beende mit "Viel Erfolg allen Teilnehmern!"
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Parcours beschreiben
# hindernisse = 12
# max_hoehe = 120
# laenge = 450
#
# # 2. Schwierigkeit
# schwierigkeit = 4
#
# # 3. Ausgabe
# print("=== SPRINGTURNIER-BERICHT ===")
# print()
# print("Hindernisse: " + str(hindernisse))
# ```
#
# **Bonus-Challenge:**
# - Füge die Wetterbedingungen hinzu!
#
# **Erwartete Ausgabe:**
# ```
# === SPRINGTURNIER-BERICHT ===
#
# Hindernisse: 12
# Maximale Höhe: 120 cm
# Parcourslänge: 450 m
#
# Schwierigkeit: 4 Sterne
# Dieser Parcours erfordert Erfahrung und ein gut trainiertes Pferd.
#
# === STARTLISTE ===
# Startnummer 1: 10:00 Uhr
# Startnummer 2: 10:15 Uhr
# Startnummer 3: 10:30 Uhr
#
# Siegerehrung: Nach allen Ritten auf dem Hauptplatz
# Vielen Dank an alle Helfer und Organisatoren!
# Viel Erfolg allen Teilnehmern!
# ```

# %%
# 🐴 Deine Lösung hier:

print()
print("🎉 +400 Huf-Punkte: Herausforderung abgeschlossen!")
print("🏆 Du hast das scheue Pferd gewonnen!")
print("⭐ Titel erhalten: Pferdeflüsterer")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 1 gemeistert!")
print("🐴 Nächste Woche: Datentypen und Variablen!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen:

# %%
# ✅ Lösung Bug #1: Fehlende Anführungszeichen

# Problem: Text ohne Anführungszeichen
print("Hallo Pferd")

# %%
# ✅ Lösung Bug #2: Zahl ohne str()

# Problem: Zahl kann nicht direkt mit Text verbunden werden
stallnummer = 12
print("Mein Stall ist Nummer " + str(stallnummer))

# %%
# ✅ Lösung Bug #3: Falsche Variable

# Problem: Variable 'pferde' existiert nicht
pferd = "Lucky"
print("Willkommen, " + pferd)
