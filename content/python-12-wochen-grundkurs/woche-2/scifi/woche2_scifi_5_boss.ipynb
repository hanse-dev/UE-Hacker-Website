# %% [markdown]
# # 🐉 Boss-Quests – 🚀 Woche 2 – Datentypen und Variablen: Die vier Quanten-Typen
# > ⚠️ Schwieriger! Kombiniert alles aus dieser Woche.
#
# **⚠️ ACHTUNG:** Diese Missionen sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 Cyber Credits + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Das Raumschiff-Dock
#
# **Belohnung:** 500 Cyber Credits + Dock-Zugang
#
# Das Dock hat 8 Andockstellen. Jede braucht Überwachung!
#
# **Schritt 1 – Flotte erfassen:**
# Erstelle Variablen für 8 Schiffe mit Namen (String) und Energielevel (Integer/Float) und gib jedem Schiff eine eindeutige Bezeichnung
#
# **Schritt 2 – Statusprotokoll erstellen:**
# Gib eine Überschrift "=== DOCK-PROTOKOLL ===" aus und erstelle eine Statusmeldung für jedes Schiff mit f-Strings
#
# **Schritt 3 – Durchschnitt berechnen:**
# Addiere alle Energiewerte und teile die Summe durch 8
#
# **Schritt 4 – Bestes Schiff finden:**
# Vergleiche alle Energielevel und bestimme das Schiff mit der höchsten Energie
#
# **Schritt 5 – Energiebedarf ermitteln:**
# Berechne den Gesamtenergiebedarf (100 Einheiten pro Schiff) und multipliziere die Schiffanzahl mit 100
#
# **Bonus:** Zähle und gib aus, wie viele Schiffe unter dem Durchschnitt liegen!

# %%
# 🚀 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Das KI-Labor
#
# **Belohnung:** 600 Cyber Credits + KI-Entwickler-Titel
#
# Im KI-Labor experimentierst du mit neuronalen Netzen!
#
# **Schritt 1 – KI-Modelle erstellen:**
# Erstelle 5 Modelle mit Name, Genauigkeit (Float 0-1), Parameterzahl, Trainingszeit und nutze passende Datentypen für jede Eigenschaft
#
# **Schritt 2 – Modellbeschreibungen ausgeben:**
# Gib eine Überschrift "=== KI-LABOR-PROTOKOLL ===" aus und erstelle eine Beschreibung für jede KI mit f-Strings
#
# **Schritt 3 – Parameter summieren:**
# Addiere alle Parameterzahlen der Modelle und speichere die Gesamtzahl in einer Variable
#
# **Schritt 4 – Beste Modelle finden:**
# Finde das genaueste Modell (höchste Genauigkeit) und finde das größte Modell (meiste Parameter)
#
# **Schritt 5 – Durchschnittsgenauigkeit berechnen:**
# Addiere alle Genauigkeiten und teile durch 5 und speichere den Durchschnitt
#
# **Schritt 6 – Leistungsstarke filtern:**
# Bestimme, welche Modelle über dem Durchschnitt liegen und nutze Boolean-Variablen zur Markierung
#
# **Bonus:** Berechne die Effizienz (Genauigkeit / Parameterzahl × 1000000) für jedes Modell!

# %%
# 🚀 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Die Raummission
#
# **Belohnung:** 400 Cyber Credits + Missionsabzeichen
#
# Plane die nächste große Raummission!
#
# **Schritt 1 – Missionen definieren:**
# Erstelle Mission 1: Ziel, Dauer (Tage), Kosten, Crewgröße, Erfolgswahrscheinlichkeit (0-1) und erstelle Mission 2: Ziel, Dauer (Tage), Kosten, Crewgröße, Erfolgswahrscheinlichkeit (0-1)
#
# **Schritt 2 – Missionsprotokoll erstellen:**
# Gib eine Überschrift "=== MISSIONS-PROTOKOLL ===" aus und stelle beide Missionen mit allen Daten vor
#
# **Schritt 3 – Gesamtwerte berechnen:**
# Addiere die Gesamtkosten beider Missionen und addiere die Gesamt-Crewbelegung
#
# **Schritt 4 – Erfolg prognostizieren:**
# Berechne erwarteten Erfolg: Kosten × Erfolgswahrscheinlichkeit und berechne für beide Missionen
#
# **Schritt 5 – Missionen vergleichen:**
# Vergleiche Kosten, Dauer und Erfolgswahrscheinlichkeit und zeige Unterschiede deutlich an
#
# **Schritt 6 – Profitabilität bestimmen:**
# Finde heraus, welche Mission profitabler ist und nutze Boolean-Variable zur Markierung
#
# **Bonus:** Berechne die Kosten pro Crewmitglied für jede Mission!

# %%
# 🚀 Deine Lösung hier:

print()
print("🎉 +400 Cyber Credits: Finale Herausforderung abgeschlossen!")
print("🏆 Du hast den Shapeshifter der instabilen Daten besiegt!")
print("⭐ Titel erhalten: Meister der Quanten-Typen")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 2 gemeistert!")
print("🚀 Nächste Woche: Bedingungen (if-else)!")

# %% [markdown]
# ---
#
# 🎊 **Glückwunsch!** Du hast alle Boss-Quests dieser Woche gemeistert!
#
# **Als Nächstes:** Woche 3 wartet schon!
