# %% [markdown]
# # ⭐ Missions – 🚀 Week 3 – Conditions (if-else): The Paths of Decision
#
# The time has come to prove your knowledge in real challenges!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: The Security Scanner
#
# **Reward:** 300 Cyber Credits + Scanner License
#
# The security scanner checks who is allowed to enter the bridge!
#
# **Step 1 – Capture access data:**
# Create a variable for rank (integer 1–10) and create a variable for ID card possession (Boolean True/False)
#
# **Step 2 – Write access rule:**
# Check with if whether rank >= 5 OR ID card present OR emergency and use the `or` operator for the connection
#
# **Step 3 – Add rejection message:**
# Use else for the case where no condition is met and print "Access denied"
#
# **Bonus:** Only require an ID card when rank is below 8!

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: The Terminal Access
#
# **Reward:** 400 Cyber Credits + Terminal Access
#
# The terminal only grants access when the correct password is entered!
#
# **Step 1 – Set passwords:**
# Create a variable for the admin password and create a variable for the guest password
#
# **Step 2 – Simulate input:**
# Create a variable for the entered password and store a test password as a string
#
# **Step 3 – Write access check:**
# Check with if whether input == admin password and check with elif whether input == guest password
#
# **Step 4 – Output different messages:**
# For admin: print "Full access granted" and for guest: print "Read access granted"
#
# **Bonus:** Give different hints for wrong passwords!

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: The Mission Rating
#
# **Reward:** 500 Cyber Credits + Mission Badge
#
# The mission is rated based on its performance!
#
# **Step 1 – Capture mission data:**
# Create a variable for the level (1–10) and create a variable for success points (0–100)
#
# **Step 2 – Calculate overall score:**
# Calculate: score = success_points - (losses × 10) - (time / 5) and store the result in a variable
#
# **Step 3 – Check legendary status:**
# Check: level >= 10 AND score >= 85 AND losses == 0 and use `and` for the connection
#
# **Step 4 – Further rating levels:**
# Check with elif: level >= 8 AND score >= 70 AND losses <= 2 and print "⭐ EXCELLENT!"
#
# **Step 5 – Check speed bonus:**
# Check separately with if whether time < 30 and print "+50 Bonus for lightning mission!"
#
#
# > 💡 **Tip:** You decide how to implement this – there is no single right way!
# **Bonus:** Also take the mission difficulty into account!

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### 🎯 Learning Goals – Have you reached them?
#
# Check for yourself whether you have mastered these skills:
#
# - ☐ if-conditions for simple decisions
# - ☐ if-else for two paths of decision
# - ☐ if-elif-else for multiple paths
# - ☐ Correctly applying comparison operators
# - ☐ Using logical operators (and, or, not)
# - ☐ Nested conditions with indentation
#
# If you can check off all points – congratulations! You are ready for the final challenges!
