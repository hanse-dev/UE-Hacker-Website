# %% [markdown]
# # 🤔 Reflexion & Zusammenfassung – 🐴 Woche 4 – Schleifen (for, while): Der Rhythmus des Reitens

# %% [markdown]
# ### 🤔 Weisheiten des erfahrenen Reiters (Reflexion)
#
# Bevor du weiterreitest, denke über diese Fragen nach:

# %% [markdown]
# ✏️ *Deine Antwort:*

# %% [markdown]
# 1. **Wann würdest du for statt while verwenden (und umgekehrt)?**

# %% [markdown]
# ✏️ *Deine Antwort:*

# %% [markdown]
# 2. **Warum ist range(ende) exklusiv für das Ende?**

# %% [markdown]
# ✏️ *Deine Antwort:*

# %% [markdown]
# 3. **Wie kannst du Endlosschleifen vermeiden?**
#
# Diskutiere deine Gedanken mit anderen Pferdefreunden!

# %% [markdown]
# ✏️ *Deine Antwort:*

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Wunderbar!** Du hast den Rhythmus des Reitens gemeistert!
#
# **Das hast du gelernt:**
# - for-Schleifen für kontrollierte Wiederholungen
# - while-Schleifen für flexible Bedingungen
# - range() für präzise Zahlenfolgen
# - break und continue für Schleifen-Kontrolle
# - Verschachtelte Schleifen für komplexe Muster
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🎮 **Pferdespiele:** Trainings-Loops, Ausdauer-Systeme
# - 📱 **Reit-Apps:** Trainings-Planung, Fortschritt-Tracking
# - 🌐 **Reitställe:** Buchungs-Systeme, Stall-Management
# - 🤖 **Pferde-Tracker:** Bewegungsanalyse, Gesundheits-Überwachung
# - 📊 **Pferdezucht:** Zucht-Programme, Stammbaum-Analyse
#
# **Als Nächstes:** In Woche 5 lernst du **Funktionen**!
