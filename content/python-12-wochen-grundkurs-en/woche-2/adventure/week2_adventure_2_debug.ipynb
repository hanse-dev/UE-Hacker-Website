# %% [markdown]
# # 🐛 Debug Quest – 💎 Week 2 – Data Types and Variables: The Four Magic Elements
#
# A young wizard tried to cast his first spells, but something went wrong! Find the errors:
# > 💡 **These errors were built in on purpose** – so you can practise debugging!

# %% [markdown]
# ### 🐛 Bug #1
#
# What is wrong? Find and fix the error!

# %%
name = "Gandalf"
level = 99
print("Hello name! You are Level level!")

# %% [markdown]
# ### 🐛 Bug #2
#
# What is wrong? Find and fix the error!

# %%
spell_power = "100"
bonus = 50
print(f"Total power: {spell_power + bonus}")

# %% [markdown]
# ### 🐛 Bug #3
#
# What is wrong? Find and fix the error!

# %%
gold = 250
print(f"Your gold: gold + 50")
