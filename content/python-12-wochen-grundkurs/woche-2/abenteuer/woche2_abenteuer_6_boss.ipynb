# %% [markdown]
# # 🐉 Boss-Quests – 💎 Woche 2 – Datentypen und Variablen: Die vier magischen Elemente
#
# > ⚠️ Schwieriger! Kombiniert alles aus dieser Woche.

# %% [markdown]
# ## 🐉 Boss-Kampf: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Quests sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 XP + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Der Schatzraum
#
# **Belohnung:** 500 XP + Schatzschlüssel
#
# Der Schatzraum hat 8 Truhen. Jede muss katalogisiert werden!
#
# **Schritt 1 – Schätze erfassen:**
# Erstelle Variablen für 8 Truhen mit Namen (String) und Goldwert (Integer) und gib jeder Truhe eine eindeutige Bezeichnung
#
# **Schritt 2 – Schatzprotokoll erstellen:**
# Gib eine Überschrift "=== SCHATZRAUM-PROTOKOLL ===" aus und erstelle eine Beschreibung für jede Truhe mit f-Strings
#
# **Schritt 3 – Durchschnitt berechnen:**
# Addiere alle Goldwerte und teile die Summe durch 8
#
# **Schritt 4 – Reichste Truhe finden:**
# Vergleiche alle Goldwerte und bestimme die Truhe mit dem höchsten Wert
#
# **Schritt 5 – Gesamtwert ermitteln:**
# Berechne den Gesamtwert aller Truhen und addiere alle Goldwerte
#
# **Bonus:** Zähle und gib aus, wie viele Truhen unter dem Durchschnitt liegen!

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Die Zauberwerkstatt
#
# **Belohnung:** 600 XP + Zaubermeister-Titel
#
# In der Zauberwerkstatt experimentierst du mit magischen Formeln!
#
# **Schritt 1 – Zauber erstellen:**
# Erstelle 5 Zauber mit Name, Stärke (Float 0-100), Komplexität (1-5), Zauberdauer (Sekunden) und nutze passende Datentypen für jede Eigenschaft
#
# **Schritt 2 – Zauberbeschreibungen ausgeben:**
# Gib eine Überschrift "=== ZAUBERWERKSTATT-PROTOKOLL ===" aus und erstelle eine Beschreibung für jeden Zauber mit f-Strings
#
# **Schritt 3 – Komplexität summieren:**
# Addiere alle Komplexitätswerte der Zauber und speichere die Gesamtzahl in einer Variable
#
# **Schritt 4 – Stärkste Zauber finden:**
# Finde den stärksten Zauber (höchste Stärke) und finde den komplexesten Zauber (höchste Komplexität)
#
# **Schritt 5 – Durchschnittsstärke berechnen:**
# Addiere alle Stärken und teile durch 5 und speichere den Durchschnitt
#
# **Schritt 6 – Mächtige filtern:**
# Bestimme, welche Zauber über dem Durchschnitt liegen und nutze Boolean-Variablen zur Markierung
#
# **Bonus:** Berechne die Effizienz (Stärke / Komplexität) für jeden Zauber!

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Die Quest-Planung
#
# **Belohnung:** 400 XP + Quest-Buch
#
# Plane die nächste große Quest!
#
# **Schritt 1 – Quests definieren:**
# Erstelle Quest 1: Ziel, Dauer (Tage), Belohnung, Gruppengröße, Erfolgswahrscheinlichkeit (0-1) und erstelle Quest 2: Ziel, Dauer (Tage), Belohnung, Gruppengröße, Erfolgswahrscheinlichkeit (0-1)
#
# **Schritt 2 – Questprotokoll erstellen:**
# Gib eine Überschrift "=== QUEST-PROTOKOLL ===" aus und stelle beide Quests mit allen Daten vor
#
# **Schritt 3 – Gesamtwerte berechnen:**
# Addiere die Gesamtbelohnung beider Quests und addiere die Gesamt-Gruppengröße
#
# **Schritt 4 – Erfolg prognostizieren:**
# Berechne erwartete Belohnung: Belohnung × Erfolgswahrscheinlichkeit und berechne für beide Quests
#
# **Schritt 5 – Quests vergleichen:**
# Vergleiche Belohnung, Dauer und Erfolgswahrscheinlichkeit und zeige Unterschiede deutlich an
#
# **Schritt 6 – Rentabilität bestimmen:**
# Finde heraus, welche Quest rentabler ist und nutze Boolean-Variable zur Markierung
#
# **Bonus:** Berechne die Belohnung pro Gruppenmitglied für jede Quest!

# %%
# 🐉 Deine Lösung hier:

print()
print("🎉 +400 XP: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Golem der verwirrten Formen besiegt!")
print("⭐ Titel erhalten: Meister der Elemente")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 2 gemeistert!")
print("📚 Nächste Woche: Bedingungen (if-else)!")

# %% [markdown]
# ---
#
# 🎊 **Glückwunsch!** Du hast alle Boss-Quests dieser Woche gemeistert!
#
# **Als Nächstes:** Woche 3 wartet schon!
