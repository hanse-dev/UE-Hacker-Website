# %% [markdown]
# # 🔧 Lösungen – ⚔️ Woche 7 – Module und Bibliotheken: Die magischen Werkzeugkästen!
# > Erst selber versucht? Dann check hier nach!

# %% [markdown]
# ## 🐛 Debug-Lösungsvorschläge

# %% [markdown]
# **Erklärung:** `math` wurde noch nicht importiert. Vor dem Benutzen muss das Modul mit `import math` geladen werden.

# %%
# Problem: math wurde nicht importiert
import math
result = math.sqrt(9)
print(f"Ergebnis: {result}")

# %% [markdown]
# **Erklärung:** Diese Methode oder Eigenschaft gibt es nicht. Vielleicht ist der Name falsch geschrieben?

# %%
# Problem: random.zahl existiert nicht
import random
zahl = random.randint(1, 10)
print(f"Zufallszahl: {zahl}")

# %% [markdown]
# **Erklärung:** Python kennt `sin` nicht. Entweder ist der Name falsch geschrieben, oder die Variable wurde noch nicht angelegt.

# %%
# Problem: sin existiert nicht ohne math.
import math
winkel = 90
sinus = math.sin(math.radians(winkel))
print(f"Sinus von {winkel}°: {sinus}")

# %% [markdown]
# ## ⭐ Missions-Lösungsvorschläge

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Zauber-Importer

# %%
import math as m
import random as r
import time as t

# Schritt 1: Konstanten und Funktionen ausgeben
print("=== Bibliotheks-Zauber ===")
print(f"math.pi: {m.pi}")
print(f"Zufallszahl (1-10): {r.randint(1, 10)}")

# Schritt 2: Wartezeit-Zauber
wartezeit = r.randint(1, 3)
print(f"\nZauber lädt ... ({wartezeit} Sekunden)")
t.sleep(wartezeit)
print("Zauber bereit!")

# Schritt 3: Flugbahn-Zauber
winkel_grad = 90
winkel_bogenmass = m.radians(winkel_grad)
hoehe = m.sin(winkel_bogenmass)
print(f"\nFlugbahn bei {winkel_grad}°: Höhe = {hoehe:.2f}")

# Schritt 4: Gruppen-Generator
helden = ["Merlin", "Thorin", "Aria", "Lyra", "Dragan"]
ausgewaehlter_held = r.choice(helden)
print(f"\nAusgewählter Held: {ausgewaehlter_held}")

# Bonus: datetime
from datetime import datetime
jetzt = datetime.now()
print(f"Aktuelle Zeit: {jetzt.strftime('%H:%M:%S')}")

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Berechnungs-Zauber

# %%
import math
import random

# Schritt 1: Kreis-Zauber
radius = 7
umfang = 2 * math.pi * radius
flaeche = math.pi * radius ** 2
print("=== Magischer Kreis ===")
print(f"Radius:  {radius} m")
print(f"Umfang:  {umfang:.2f} m")
print(f"Fläche:  {flaeche:.2f} m²")

# Schritt 2: Zufalls-Zahlen und Summe
mana_werte = [random.randint(1, 100) for _ in range(5)]
mana_summe = sum(mana_werte)
print(f"\nMana-Werte: {mana_werte}")
print(f"Summe:      {mana_summe}")

# Schritt 3: Winkel-Umrechnung
print("\nWinkel-Umrechnung:")
for grad in [90, 180, 270]:
    bogenmass = math.radians(grad)
    print(f"  {grad}° = {bogenmass:.4f} rad")

# Schritt 4: Wurzeln
print("\nWurzel-Ziehen:")
for zahl in [4, 9, 16, 25]:
    print(f"  √{zahl} = {math.sqrt(zahl):.1f}")

# Bonus: Trigonometrie
winkel = math.radians(45)
print(f"\nBonus: sin(45°) = {math.sin(winkel):.4f}, cos(45°) = {math.cos(winkel):.4f}")

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Der Zufalls-Zauber

# %%
import random
import math

# Schritt 1: Reichsauswahl
reiche = ["Pyralia", "Frostmark", "Sonnenstein", "Schattental", "Kristallküste", "Eisenfeste"]
gewaehltes_reich = random.choice(reiche)
print("=== Abenteuer-Welt ===")
print(f"Alle Reiche: {reiche}")
print(f"Gewähltes Reich: {gewaehltes_reich}")

# Schritt 2: Wetter-Simulation
print("\nWetter-Bericht:")
regionen = ["Nordregion", "Zentralregion", "Südregion"]
for region in regionen:
    temperatur = round(random.uniform(-50, 50), 1)
    print(f"  {region}: {temperatur}°C")

# Schritt 3: Magie-Verbrauch
print("\nMana-Verbrauch der Zauberer:")
zauberer_namen = ["Merlin", "Gandara", "Pyrokles"]
gesamt_mana = 0
for name in zauberer_namen:
    mana = random.randint(50, 150)
    gesamt_mana += mana
    print(f"  {name}: {mana} Mana")
print(f"  Gesamt: {gesamt_mana} Mana")

# Schritt 4: Helden-Generator
print("\nHelden-Rangliste:")
helden = [(name, random.randint(1, 10)) for name in ["Thorin", "Aria", "Drake"]]
for name, staerke in helden:
    print(f"  {name}: Stärke {staerke}/10")

# Bonus: Normalverteilung
mana_gauss = round(random.gauss(100, 20), 1)
print(f"\nBonus – Magischer Mana-Wert (Gauss): {mana_gauss}")

# %% [markdown]
# ## 🐉 Boss-Quest Lösungsvorschläge

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Der Würfelturm

# %%
import random

spieler = ["Merlin", "Aria", "Dragan"]
siege = {name: 0 for name in spieler}

print("=== WÜRFELTURNIER ===")

for runde in range(1, 6):
    print(f"\nRunde {runde}:")
    wuerfe = {}
    for name in spieler:
        wurf = random.randint(1, 6)
        wuerfe[name] = wurf
        print(f"  {name} würfelt: {wurf}")

    bester = max(wuerfe, key=wuerfe.get)
    siege[bester] += 1
    print(f"  -> Gewinner: {bester}!")

print("\n=== TURNIER-ERGEBNIS ===")
for name, anzahl in siege.items():
    print(f"  {name}: {anzahl} Runden gewonnen")
champion = max(siege, key=siege.get)
print(f"\nGesamtsieger: {champion}!")

# Bonus: Magiewürfel
print("\n=== BONUS: Magiewürfel-Runde (1-20) ===")
for name in spieler:
    magie_wurf = random.randint(1, 20)
    print(f"  {name}: {magie_wurf}")

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Das Magie-Orakel

# %%
import math
import random

# Schritt 1: Glückszahl aus Namen berechnen
name = input("Dein Name: ")
glueckszahl = math.floor(math.sqrt(len(name) * 100))
print(f"\nDeine magische Glückszahl: {glueckszahl}")

# Schritt 2: Prophezeiung
prophezeiungen = [
    "Ein unerwartetes Abenteuer erwartet dich.",
    "Die Weisheit der Alten wird dich führen.",
    "Ein neuer Freund erscheint auf deinem Weg.",
    "Große Stärke liegt verborgen in dir.",
    "Das Schicksal lächelt dir heute.",
    "Mut wird dir Türen öffnen, die verschlossen schienen.",
]
prophezeiung = random.choice(prophezeiungen)

# Schritt 3: Horoskop
print("\n=== DEIN MAGISCHES HOROSKOP ===")
print(f"Name:        {name}")
print(f"Glückszahl:  {glueckszahl}")
print(f"Prophezeiung: {prophezeiung}")

# Bonus: Wahrscheinlichkeit
wahrscheinlichkeit = round(100 / len(prophezeiungen), 1)
print(f"\nWahrscheinlichkeit dieser Prophezeiung: {wahrscheinlichkeit}%")

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Der Zufalls-Dungeon

# %%
import random
import math

raum_typen = ["Schatzkammer", "Falle", "Leerer Raum", "Wachposten", "Altar"]
monster_liste = ["Goblin", "Skelett", "Troll", None, None]  # None = kein Monster

print("=== ZUFALLS-DUNGEON ===")
monster_count = 0

for i in range(1, 6):
    raum_typ = random.choice(raum_typen)
    monster = random.choice(monster_liste)
    if monster:
        monster_count += 1
        inhalt = f"Monster: {monster}"
    else:
        inhalt = "Sicher – kein Monster"
    print(f"Raum {i}: {raum_typ} | {inhalt}")

benoetigte_leben = math.ceil(monster_count / 2)
print(f"\nMonster gesamt: {monster_count}")
print(f"Benötigte Leben: {benoetigte_leben}")

print()
print("🎉 +400 XP: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Bibliothekar der unendlichen Zauber besiegt!")
print("⭐ Titel erhalten: Meister der Bibliotheken")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 7 gemeistert!")
print("📚 Nächste Woche: Dictionaries und Tupel!")
