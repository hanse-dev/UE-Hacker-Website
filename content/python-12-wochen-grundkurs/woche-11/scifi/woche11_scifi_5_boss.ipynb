# %% [markdown]
# # 🐉 Boss-Quests – 🚀 Woche 11 – OOP Fortgeschritten: Die magische Evolution!
# > ⚠️ Schwieriger! Kombiniert alles aus dieser Woche.
#
# **⚠️ ACHTUNG:** Diese Missionen sind extrem schwierig! Sie kombinieren alle fortgeschrittenen Konzepte.
#
# **Belohnungen:** Insgesamt 1800 Cyber Credits + epische Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Die Rang-Hierarchie
#
# **Belohnung:** 600 Cyber Credits + Kommandanten-Stern
#
# Die Flotte hat Kadetten, Offiziere und Kapitäne – jeder hat andere Befugnisse!
#
# **Schritt 1 – Basis-Klasse:**
# Schreibe eine Klasse `Besatzungsmitglied` mit Name und Rang. Füge eine Methode `befugnisse_anzeigen()` hinzu.
#
# **Schritt 2 – Ränge:**
# Leite 3 Kind-Klassen ab (Kadett, Offizier, Kapitän). Jede überschreibt `befugnisse_anzeigen()`.
#
# **Schritt 3 – Briefing:**
# Erstelle je ein Mitglied jedes Ranges. Rufe `befugnisse_anzeigen()` für alle auf.
#
# **Bonus:** Füge `__str__` hinzu für eine schöne Ausgabe.

# %%
# 🚀 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Die Roboter-Familie
#
# **Belohnung:** 800 Cyber Credits + KI-Chip
#
# Alle Roboter können Aufgaben ausführen – aber jeder Typ ist auf etwas spezialisiert!
#
# **Schritt 1 – Basis-Klasse:**
# Schreibe eine Klasse `Roboter` mit Name und Energie. Füge eine Methode `aufgabe()` hinzu.
#
# **Schritt 2 – Typen:**
# Leite 3 Kind-Klassen ab (z.B. Kampfroboter, Heilroboter, Erkundungsroboter). Jede überschreibt `aufgabe()`.
#
# **Schritt 3 – Einsatz:**
# Erstelle je einen Roboter jedes Typs. Lass alle ihre Aufgaben ausführen und zeige mit `__str__` die Vorstellung.
#
# **Bonus:** Füge `__eq__` hinzu, der zwei Roboter nach Energie vergleicht.

# %%
# 🚀 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Das Alien-Kontakt-System
#
# **Belohnung:** 400 Cyber Credits + Erstkontakt-Abzeichen
#
# Alle Alienarten können kommunizieren – aber jede auf ihre eigene Weise!
#
# **Schritt 1 – Basis-Klasse:**
# Schreibe eine Klasse `Alien` mit Name und Herkunft. Füge eine Methode `kommunizieren()` hinzu.
#
# **Schritt 2 – Alien-Völker:**
# Leite 4 Völker ab. Jedes überschreibt `kommunizieren()` mit seiner eigenen Sprache oder Geste.
#
# **Schritt 3 – Erstkontakt:**
# Erstelle je ein Alien jedes Volkes und rufe für alle `kommunizieren()` auf.
#
# **Bonus:** Füge `__str__` und `__len__` hinzu.

# %%
# 🚀 Deine Lösung hier:

print()
print("🎉 +400 Cyber Credits: Mission abgeschlossen!")
print("🏆 Du hast den Konstruktions-Meister besiegt!")
print("⭐ Titel erhalten: Architekt der Systeme")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 11 gemeistert!")
print("🚀 Nächste Woche: Grafische Projekte mit Turtle!")

# %% [markdown]
# ---
#
# 🎊 **Glückwunsch!** Du hast alle Boss-Quests dieser Woche gemeistert!
#
# **Als Nächstes:** Woche 12 wartet schon!
