# %% [markdown]
# # ⭐ Missionen – ⚔️ Woche 9 – JSON-Dateien und I/O: Die Schriftrollen der Daten
#
# > 📖 Vorher: `…_1_lektion` und `…_2_debug`

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Quest-Logger
#
# **Belohnung:** 300 XP + Magisches Tagebuch
#
# Erstelle dein erstes Quest-Logging-System!
#
# **Schritt 1 – Quest-Log schreiben:**
# Datei (z.B. `quest_log.txt`) mit `with open(..., "w")` öffnen, 3+ Zeilen (Quest-Status) schreiben; Bestätigung ausgeben.
# **Schritt 2 – Zeitstempel:**
# `datetime` nutzen, Einträge mit Modus `"a"` anhängen; Beispiel-Eintrag ausgeben.
# **Schritt 3 – Log-Level:**
# Einträge mit [INFO], [WARN], [ERROR]; Datei lesen und Inhalt ausgeben.
# 4. **Filter-Funktion** `filter_level(dateiname, level)` – nur Zeilen mit diesem Level zurückgeben; aufrufen und ausgeben.
#
# **Beispiel-Code:** with open("quest_log.txt", "w") as f: f.write(...); datetime.now() für Zeitstempel.
#
# **Bonus:** Einfache Rotation (neue Datei bei Größenlimit).

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der JSON-Zauberer
#
# **Belohnung:** 400 XP + Zauberstab
#
# Erstelle ein JSON-Zaubersystem!
#
# 1. **Helden-Daten als Dictionary** (name, klasse, level, lebenspunkte); ausgeben.
# **Schritt 2 – JSON-Export:**
# mit json.dump(..., indent=2) in held.json speichern; Bestätigung ausgeben.
# **Schritt 3 – JSON-Import:**
# mit json.load() laden, z.B. daten["name"] prüfen; geladene Daten ausgeben.
# 4. **Kurze Statistik** (Level, LP o.ä.) aus den geladenen Daten ausgeben.
#
# **Beispiel-Code:** held = {...}; json.dump(held, f, indent=2); json.load(f).
#
# **Bonus:** Einfache Validierung (erwartete Schlüssel prüfen).

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Die CSV-Datenbank
#
# **Belohnung:** 500 XP + Datenbank-Urkunde
#
# Erstelle ein komplettes CSV-Verwaltungssystem!
#
# **Schritt 1 – CSV-Export:**
# Liste von Helden-Dictionaries (name, klasse, level) mit csv.DictWriter in helden.csv schreiben (newline=""); Bestätigung ausgeben.
# **Schritt 2 – CSV-Import:**
# mit csv.DictReader lesen, Zeilen in Liste sammeln; Anzahl und erste Zeile ausgeben.
# 3. **Suchfunktion** eine Funktion – Zeilen mit dieser Klasse zurückgeben; aufrufen und ausgeben.
# **Schritt 4 – Kurzer Bericht:**
# Statistik (Durchschnittslevel, Anzahl pro Klasse) aus den gelesenen Daten ausgeben.
#
# **Beispiel-Code:** csv.DictWriter/DictReader; fieldnames=["name", "klasse", "level"].
#
# **Bonus:** Prüfung erwarteter Spalten.

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ☐ Schriftrollen mit open() lesen und schreiben
# - ☐ JSON-Daten importieren und exportieren
# - ☐ CSV-Schriftrollen verarbeiten
# - ☐ Fehler bei Schriftrollen-Zugriffen behandeln
# - ☐ Daten validieren und transformieren
# - ☐ Komplexe Daten-Pipelines erstellen
