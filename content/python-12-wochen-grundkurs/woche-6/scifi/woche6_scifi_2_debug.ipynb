# %% [markdown]
# # 🐛 Debug-Quest – 🚀 Woche 6 – Listen: Die Daten-Bänke der Raumstation
#
# > 📖 Vorher: `…_1_lektion` durcharbeiten

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein Techniker hat versucht, die Systemdaten zu organisieren, aber etwas läuft schief! Finde die Fehler:

# %% [markdown]
# ### 🐛 Bug #1
#
# **Was passiert:** Python kann diese Zeile nicht lesen – schau genau hin. Oft fehlt ein `:`, eine Klammer oder ein Anführungszeichen.

# %%
# 🐛 Bug #1

systeme = ["Waffensystem", "Schildsystem", "Antriebssystem"
print(f"Systeme: {systeme}")

# %% [markdown]
# ### 🐛 Bug #2
#
# **Was passiert:** Dieser Code enthält einen Fehler – findest du ihn?

# %%
# 🐛 Bug #2

protokolle = ["Alpha", "Beta", "Gamma"]
print(protokolle[3])

# %% [markdown]
# ### 🐛 Bug #3
#
# **Was passiert:** Python kennt `reverse` nicht. Entweder ist der Name falsch geschrieben, oder die Variable wurde noch nicht angelegt.

# %%
# 🐛 Bug #3

level = [1, 5, 10, 15]
level.sort(reverse)
print(level)
