# %% [markdown]
# # 🐛 Debug-Quest – 🚀 Woche 6 – Listen: Die Daten-Bänke der Raumstation
#
# Ein Techniker hat versucht, die Systemdaten zu organisieren, aber etwas läuft schief! Finde die Fehler:
# > 💡 **Diese Fehler wurden absichtlich eingebaut** – damit du das Debuggen üben kannst!

# %% [markdown]
# ### 🐛 Bug #1
#
# Was ist falsch? Finde und behebe den Fehler!
#
# **Ziel:** Das Programm soll die Liste der drei Systeme ausgeben.

# %%
systeme = ["Waffensystem", "Schildsystem", "Antriebssystem"
print(f"Systeme: {systeme}")

# %% [markdown]
# ### 🐛 Bug #2
#
# Was ist falsch? Finde und behebe den Fehler!
#
# **Ziel:** Das Programm soll den letzten Eintrag der Liste ausgeben, also `Gamma`.

# %%
protokolle = ["Alpha", "Beta", "Gamma"]
print(protokolle[3])

# %% [markdown]
# ### 🐛 Bug #3
#
# Was ist falsch? Finde und behebe den Fehler!
#
# **Ziel:** Die Liste soll absteigend sortiert werden, also `[15, 10, 5, 1]`.

# %%
level = [1, 5, 10, 15]
level.sort(reverse)
print(level)
