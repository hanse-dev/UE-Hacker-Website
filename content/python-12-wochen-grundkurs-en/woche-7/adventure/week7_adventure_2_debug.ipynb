# %% [markdown]
# # 🐛 Debug Quest – ⚔️ Week 7 – Modules and Libraries: The Library of Borrowed Magic
#
# An apprentice tried to cast the Archivist's guardian spells, but something went wrong! Find the bugs:
# > 💡 **These bugs were planted on purpose** – so you can practise debugging!

# %% [markdown]
# ### 🐛 Bug #1
#
# What's wrong? Find and fix the error!

# %%
number = random.randint(1, 6)
print(f"Dice roll: {number}")

# %% [markdown]
# ### 🐛 Bug #2
#
# What's wrong? Find and fix the error!

# %%
import random
key = random.randomnumber(1, 100)
print(f"Rune key number: {key}")

# %% [markdown]
# ### 🐛 Bug #3
#
# What's wrong? Find and fix the error!

# %%
import random
import string
rune = random.choice(string.ascii_letter)
print(f"Drawn rune: {rune}")
