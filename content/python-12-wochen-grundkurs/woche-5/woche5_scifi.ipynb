# %% [markdown]
# # 🚀 Woche 5 – Funktionen: Die Systemprotokolle
#
# **Cyber Credits zu verdienen:** 1000 Punkte
# **Boss:** Der Architekt der unendlichen Rekursion

# %% [markdown]
# ## 🌟 Die Mission beginnt: Das Hauptquartier der Wiederverwendbarkeit
#
# Willkommen an Bord der Raumstation Nebula-7! Du erreichst das **Hauptquartier der Wiederverwendbarkeit** – ein hochmoderner Sektor, in dem Systemprotokolle einmal entwickelt und für alle Missionen wiederverwendet werden können. In dieser Woche lernst du die drei **Arten der Systemprotokolle**:
#
# **Deine Mission:**
# - Meistere die **Funktions-Definition** mit `def`
# - Beherrsche **Parameter** für flexible Protokolle
# - Lerne **return-Werte** für Systemergebnisse
# - Verstehe **Docstrings** für die Systemhandbücher
#
# **Einmal programmiert, immer eingesetzt!** Die Macht der Funktionen wartet...

# %% [markdown]
# ## 📚 Systemprotokoll 1: Die Funktions-Definition - Der Befehlscode
#
# **Was es ist:** Eine Funktion ist ein wiederverwendbarer Protokoll-Block, den du einmal definierst und immer wieder aufrufen kannst.
#
# **Die Anatomie einer Funktion:**
# ```python
# def protokoll_name(parameter1, parameter2):
#     """Beschreibung des Protokolls"""
#     # Protokoll-Code
#     return ergebnis  # Optional: Ergebnis zurückgeben
# ```
#
# **Schritt-für-Schritt-Erklärung:**
# 1. **`def`** - Das Kommando, das die Protokoll-Definition startet
# 2. **`protokoll_name`** - Ein eindeutiger Name für dein Protokoll
# 3. **`(parameter)`** - System-Variablen (optional)
# 4. **`:`** - Beendet die Protokoll-Definition
# 5. **`"""Docstring"""`** - Systemhandbuch (sehr wichtig!)
# 6. **Eingerückter Code** - Der eigentliche Protokoll-Code
# 7. **`return`** - Gibt das Ergebnis zurück (optional)
#
# **Warum so nützlich:**
# - 🎯 Protokolle wiederverwenden statt neu programmieren
# - 🔍 System organisieren und strukturieren
# - ⚡ Fehler an einer Stelle beheben
# - 🎲 Komplexe Systeme in kleine Teile zerlegen

# %%
# Beispiel 1: Einfache Funktion ohne Parameter
def system_begruessung():
    """Begrüßt Besitzer auf der Raumstation"""
    print("Willkommen an Bord der Nebula-7!")
    print("Deine Mission beginnt jetzt!")

# Funktion aufrufen
print("=== Erster Besucher ===")
system_begruessung()

print("\n=== Zweiter Besucher ===")
system_begruessung()

print("\n=== Was passiert hier? ===")
print("1. def system_begruessung(): definiert die Funktion")
print("2. system_begruessung() ruft die Funktion auf")
print("3. Der Code in der Funktion wird jedes Mal ausgeführt")

# %%
# Beispiel 2: Funktion mit einem Parameter
def begruesse_piloten(name):
    """Begrüßt einen Piloten mit seinem Namen"""
    print(f"Hallo {name}!")
    print(f"Viel Erfolg bei deiner Mission, {name}!")

# Funktion mit verschiedenen Namen aufrufen
print("=== Verschiedene Piloten ===")
begruesse_piloten("Alex")
begruesse_piloten("Zara")
begruesse_piloten("Nova")

print("\n=== Was passiert hier? ===")
print("1. name ist ein Platzhalter für den übergebenen Wert")
print("2. Jeder Aufruf übergibt einen anderen Namen")
print("3. Die Funktion arbeitet mit dem übergebenen Wert")

# %%
# Beispiel 3: Funktion mit mehreren Parametern
def erstelle_schiff_profil(name, klasse, besatzung):
    """Erstellt ein Schiff-Profil mit Name, Klasse und Besatzung"""
    print(f"Schiff-Profil:")
    print(f"  Name: {name}")
    print(f"  Klasse: {klasse}")
    print(f"  Besatzung: {besatzung} Personen")
    print(f"  Status: Bereit für den Einsatz!")

# Verschiedene Schiff-Profile erstellen
print("=== Schiff-Profile ===")
erstelle_schiff_profil("Nebula-Explorer", "Forschungsschiff", 150)
print()
erstelle_schiff_profil("Star-Fighter", "Jäger", 2)
print()
erstelle_schiff_profil("Cargo-Hauler", "Frachter", 25)

# %% [markdown]
# ## 🔍 Das Geheimnis von return - Das Systemergebnis
#
# **return** ist der mächtigste Teil einer Funktion!
#
# **Was return tut:**
# - Beendet die Funktion sofort
# - Gibt einen Wert zurück an den Aufrufer
# - Dieser Wert kann in einer Variable gespeichert werden
#
# **Ohne return:** Funktion macht etwas (Side Effect)
# **Mit return:** Funktion berechnet und gibt Ergebnis zurück

# %%
# 🔍 Übungen mit return

# Beispiel 1: Einfache Berechnung mit return
def berechne_warp_distanz(warp_faktor, zeit):
    """Berechnet die zurückgelegte Distanz im Warp"""
    distanz = warp_faktor * zeit * 1000
    return distanz

# Ergebnis in Variable speichern
print("=== Warp-Distanz-Berechnung ===")
distanz1 = berechne_warp_distanz(5, 10)
print(f"Sprung 1: {distanz1} Lichtjahre")

distanz2 = berechne_warp_distanz(8, 15)
print(f"Sprung 2: {distanz2} Lichtjahre")

# Ergebnis direkt verwenden
print(f"Notfall-Sprung: {berechne_warp_distanz(10, 5)} Lichtjahre")

# %%
# Beispiel 2: Funktion mit bedingtem return
def pruefe_system_status(energie_level):
    """Prüft, ob das System für eine Mission bereit ist"""
    if energie_level >= 75:
        return "System bereit für Mission!"
    else:
        return f"Noch {75 - energie_level}% Energie needed"

print("=== System-Status-Prüfung ===")
status1 = pruefe_system_status(60)
print(f"Energie 60%: {status1}")

status2 = pruefe_system_status(90)
print(f"Energie 90%: {status2}")

status3 = pruefe_system_status(70)
print(f"Energie 70%: {status3}")

# %%
# Beispiel 3: Funktion ohne expliziten return (None)
def zeige_ausruestung():
    """Zeigt die Standard-Ausrüstung (gibt nichts zurück)"""
    print("Deine Ausrüstung:")
    print("  - Phaser")
    print("  - Tricorder")
    print("  - Kommunikator")
    # Kein return - gibt automatisch None zurück

print("=== Ausrüstung anzeigen ===")
ergebnis = zeige_ausruestung()
print(f"Rückgabewert: {ergebnis}")
print("Funktionen ohne return geben immer None zurück!")

# %% [markdown]
# ## 📦 Systemprotokoll 2: Docstrings - Die Systemhandbücher
#
# **Was es ist:** Docstrings sind Dokumentations-Strings, die erklären, was eine Funktion tut.
#
# **Warum extrem wichtig:**
# - 📖 Andere (und du später) verstehen deine Funktion
# - 🔍 IDEs zeigen dir Hilfe beim Aufruf
# - 🤖 Tools können automatisch Dokumentation erstellen
# - ⭐ Zeichen von professionellem Code
#
# **Die drei Arten von Docstrings:**
# 1. **Einzeilig:** `"""Kurze Beschreibung"""`
# 2. **Mehrzeilig:** `"""Kurze Beschreibung\n\nDetails..."""`
# 3. **Vollständig:** `"""Beschreibung\n\nArgs:\nReturns:\n"""`

# %%
# Beispiel 1: Verschiedene Docstring-Stile
def einfache_funktion():
    """Dies ist ein einzeiliger Docstring."""
    return "Einfach"

def detaillierte_funktion(schiff_name, flotten_id):
    """Erstellt eine Missions-Beschreibung.
    
    Args:
        schiff_name (str): Der Name des Schiffs
        flotten_id (int): Die ID der Flotte
    
    Returns:
        str: Eine formatierte Beschreibung
    """
    return f"{schiff_name} gehört zur Flotte {flotten_id}."

# Docstring aufrufen (so funktioniert es!)
print("=== Docstring-Beispiele ===")
print(f"Einfacher Docstring: {einfache_funktion.__doc__}")
print()
print(f"Detaillierter Docstring: {detaillierte_funktion.__doc__}")

# %%
# Beispiel 2: Hilfe-Funktion nutzen
print("=== Hilfe für Funktionen ===")
help(detaillierte_funktion)

# %% [markdown]
# ## ✨ Systemprotokoll 3: Namenskonventionen - Die Regeln des Codes
#
# **Gute Funktionsnamen sind entscheidend!**
#
# **Die Regeln:**
# - **Kleinbuchstaben** mit Unterstrichen: `berechne_warp_distanz`
# - **Beschreibend**: Was die Funktion **tut** (Verb)
# - **Kurz aber klar**: `get_name()` nicht `retrieve_starship_data_from_database()`
# - **Keine Verben im Namen**: `name_get()` falsch, `get_name()` richtig
#
# **Beispiele:**
# - ✅ `berechne_warp_distanz()`
# - ✅ `erstelle_schiff_profil()`
# - ✅ `pruefe_system_status()`
# - ❌ `BerechneWarpDistanz()` (CamelCase)
# - ❌ `berechne_das_warp()` (zu lang)
# - ❌ `warp_berechnen()` (Substantiv zuerst)

# %%
# ✨ Beispiele für gute und schlechte Namen

# ✅ Gute Namen (klar und beschreibend)
def berechne_schild_effizienz(energie, flaeche):
    """Berechnet die Effizienz der Schilde."""
    return (energie / flaeche) * 100

def finde_naechsten_hafen(schiff_position, hafen_liste):
    """Findet den nächsten Hafen zur aktuellen Position."""
    return min(hafen_liste, key=lambda h: abs(h - schiff_position))

def ist_kommunikation_moeglich(reichweite, distanz):
    """Prüft, ob Kommunikation möglich ist."""
    return distanz <= reichweite

# ❌ Schlechte Namen (unklar oder falsche Konvention)
# def berechneSchildEffizienz():  # CamelCase
# def se(e, f):  # Zu kurz, nicht beschreibend
# def shield_calculation():  # Substantiv zuerst

print("=== Gute Funktionsnamen in Aktion ===")
effizienz = berechne_schild_effizienz(1000, 50)
print(f"Schild-Effizienz: {effizienz}%")

position = 100
haefen = [50, 200, 350, 500]
naechster_hafen = finde_naechsten_hafen(position, haefen)
print(f"Nächster Hafen: {naechster_hafen}")

komm_ok = ist_kommunikation_moeglich(1000, 750)
print(f"Kommunikation möglich: {komm_ok}")

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein Techniker hat versucht, Systemprotokolle zu erstellen, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1

def system_boot():
print("System wird gestartet...")
return "Bereit"

# %%
# 🐛 Bug #2

def berechne_warp_geschwindigkeit(warp_faktor):
    return warp_faktor ** 3

result = berechne_warp_geschwindigkeit

# %%
# 🐛 Bug #3

def addiere_sensordaten(daten1, daten2):
    gesamt = daten1 + daten2

summe = addiere_sensordaten(100, 250)
print(f"Gesamt-Sensordaten: {summe}")

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der System-Techniker
#
# **Belohnung:** 300 Cyber Credits + System-Zugang
#
# Im Hauptquartier der Wiederverwendbarkeit erstellst du deine ersten Systemprotokolle für die Raumstation Nebula-7.
#
# **Deine Aufgaben:**
#
# 1. **Begrüßungsfunktion programmieren**
#    - Erstelle eine Funktion `begruesse_besatzung()`, die zwei Begrüßungszeilen ausgibt
#    - Rufe die Funktion mindestens zweimal auf
#    - Achte auf einen passenden Docstring, der erklärt, was die Funktion tut
#
# 2. **Energie-Berechnung als Funktion**
#    - Erstelle eine Funktion `berechne_energie(level, dauer)`, die `level * dauer * 10` berechnet
#    - Gib das Ergebnis mit `return` zurück
#    - Rufe die Funktion mit verschiedenen Werten auf und speichere die Ergebnisse in Variablen
#
# 3. **System-Status prüfen**
#    - Erstelle eine Funktion `ist_system_bereit(energie)`, die `True` zurückgibt, wenn `energie >= 100` ist, sonst `False`
#    - Nutze die Rückgabewerte in if-Bedingungen und gib passende Statusmeldungen aus
#
# 4. **Protokolle kombinieren**
#    - Rufe in einem kleinen "Hauptprogramm" alle drei Funktionen nacheinander auf
#    - Nutze die berechnete Energie, um den System-Status zu prüfen
#    - Gib eine Abschlussmeldung aus, ob das System einsatzbereit ist
#
# **Beispiel-Code zum Starten:**
# ```python
# def begruesse_besatzung():
#     """Begrüßt die Besatzung der Raumstation."""
#     print("Willkommen an Bord der Nebula-7!")
#     print("Bereite dich auf deine Mission vor!")
#
# # Aufruf der Funktion
# begruesse_besatzung()
# ```
#
# **Bonus-Challenge:**
# - Erstelle eine Funktion `generiere_systemereignis()`, die zufällig ein Systemereignis wie "Sonnensturm", "Sensorfehler" oder "Alles stabil" zurückgibt.
#
# **Erwartete Ausgabe:**
# ```
# Willkommen an Bord der Nebula-7!
# Bereite dich auf deine Mission vor!
# ...
# Berechnete Energie: 150
# System bereit: True
# ✅ System ist bereit für die nächste Mission!
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Missions-Planer
#
# **Belohnung:** 400 Cyber Credits + Missions-Kontrolle
#
# Du planst Missionen im Kontrollzentrum der Nebula-7 und kombinierst mehrere Funktionen zu einem Planungstool.
#
# **Deine Aufgaben:**
#
# 1. **Missions-Profil erstellen**
#    - Schreibe eine Funktion `erstelle_missions_profil(name, ziel, prioritaet)`, die ein Dictionary mit diesen Informationen zurückgibt
#    - Achte auf einen klaren Docstring, der Parameter und Rückgabewert beschreibt
#    - Erstelle mindestens zwei verschiedene Missionsprofile
#
# 2. **Reisezeit berechnen**
#    - Erstelle eine Funktion `berechne_reisezeit(distanz, geschwindigkeit)`, die `distanz / geschwindigkeit` berechnet
#    - Gib das Ergebnis als Zahl (z.B. Stunden) mit `return` zurück
#    - Nutze die Funktion mit unterschiedlichen Missionsdaten
#
# 3. **Missionsbericht generieren**
#    - Schreibe eine Funktion `generiere_bericht(profil, reisezeit)`, die einen formatierten Text zurückgibt
#    - Nutze Informationen aus dem Profil (Name, Ziel, Priorität) und der berechneten Reisezeit
#    - Gib den Bericht mit `print()` aus
#
# 4. **Planungs-System zusammenbauen**
#    - Erstelle eine kleine Steuer-Funktion oder einen Haupt-Block, der:
#      - ein Missionsprofil erstellt,
#      - die Reisezeit berechnet und
#      - den Missionsbericht ausgibt
#    - Wiederhole das für mindestens zwei Missionen
#
# **Beispiel-Code zum Starten:**
# ```python
# def erstelle_missions_profil(name, ziel, prioritaet):
#     """Erstellt ein Missionsprofil als Dictionary."""
#     return {
#         "name": name,
#         "ziel": ziel,
#         "prioritaet": prioritaet,
#     }
#
# profil = erstelle_missions_profil("Versorgung", "Außenposten X-3", "hoch")
# print(profil)
# ```
#
# **Bonus-Challenge:**
# - Füge Zufalls-Elemente wie Raumwetter ("ruhig", "Meteorsturm", "Sonnenwind") und Hindernisse ("Asteroidenfeld", "Raumpiraten") hinzu und baue sie in den Bericht ein.
#
# **Erwartete Ausgabe:**
# ```
# Missionsprofil: Versorgung nach Außenposten X-3 (Priorität: hoch)
# Geschätzte Reisezeit: 12.5 Stunden
# Status: Mission geplant, alle Systeme bereit.
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Die Flotten-Koordination
#
# **Belohnung:** 500 Cyber Credits + Flotten-Kommando
#
# Du koordinierst eine ganze Flotte von Raumschiffen und nutzt mehrere Funktionen, um Effizienz und Kommunikation zu steuern.
#
# **Deine Aufgaben:**
#
# 1. **Flotten-Daten vorbereiten**
#    - Erstelle eine Liste von Schiffen (z.B. Dictionaries mit Name und Klasse)
#    - Schreibe eine Funktion `koordiniere_flotte(flotte, ziel)`, die kurz beschreibt, welches Schiff zu welchem Ziel fliegt
#    - Gib für jedes Schiff eine Statuszeile aus
#
# 2. **Effizienz-Funktion erstellen**
#    - Erstelle eine Funktion `berechne_effizienz(anzahl_schiffe, formation)`, die einen Effizienzwert (0–100) zurückgibt
#    - Nutze unterschiedliche Formationen (z.B. "Keil", "Linie", "Verteidigung") mit verschiedenen Effizienzfaktoren
#    - Gib den Effizienzwert in einer formatierten Ausgabe aus
#
# 3. **Kommunikationsnetz prüfen**
#    - Schreibe eine Funktion `ist_kommunikation_stabil(reichweite, distanz)`, die `True` oder `False` zurückgibt
#    - Nutze die Funktion, um für verschiedene Entfernungen die Stabilität zu prüfen
#    - Gib passende Meldungen aus (z.B. "Signal stabil" / "Signal zu schwach")
#
# 4. **Kurzer Flottenbericht**
#    - Erstelle eine Funktion `erstelle_flottenbericht(flotte, effizienz)`, die einen Textbericht über Flotte und Effizienz zurückgibt
#    - Gib den Bericht am Ende der Mission aus
#
# **Beispiel-Code zum Starten:**
# ```python
# flotte = [
#     {"name": "Nova-1", "klasse": "Jäger"},
#     {"name": "Orion", "klasse": "Kreuzer"},
# ]
#
# for schiff in flotte:
#     print(f"Schiff {schiff['name']} der Klasse {schiff['klasse']} bereit.")
# ```
#
# **Bonus-Challenge:**
# - Erweitere das System so, dass du mehrere Flotten vergleichen kannst (z.B. welche Flotte die höhere Gesamteffizienz hat).
#
# **Erwartete Ausgabe:**
# ```
# Schiff Nova-1 der Klasse Jäger bereit.
# Schiff Orion der Klasse Kreuzer bereit.
# ...
# Flotteneffizienz in Formation "Keil": 85%
# Kommunikationsstatus: Signal stabil
# Flottenbericht: 2 Schiffe im Einsatz, Effizienz 85% – Einsatzbereit.
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten des Kommandanten (Reflexion)
#
# Bevor du weiterfliegst, denke über diese Fragen nach:
#
# 1. **Warum sind Funktionen besser als kopierter Code?**
#
# 2. **Wann sollte man return verwenden und wann nicht?**
#
# 3. **Warum sind gute Funktionsnamen so wichtig?**
#
# Diskutiere deine Gedanken mit anderen Kommandanten!

# %% [markdown]
# ### 📖 Tech-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **def** 🚀: Funktions-Definition starten
# - **parameter** 📦: Werte, die an Funktion übergeben werden
# - **return** 🔄: Wert zurückgeben
# - **docstring** 📖: Funktions-Dokumentation
# - **argument** 🎯: Tatsächlich übergebener Wert
# - **call** 📞: Funktion aufrufen
# - **scope** 🌍: Gültigkeitsbereich von Variablen
# - **side effect** ⚡: Veränderungen außerhalb der Funktion
# - **pure function** 🌟: Funktion ohne Seiteneffekte
# - **recursion** 🔄: Funktion ruft sich selbst auf

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ✅ Funktionen mit def und Parameter definieren
# - ✅ return-Werte und Funktionsaufrufe nutzen
# - ✅ Docstrings zur Dokumentation schreiben
# - ✅ Namenskonventionen beachten
# - ✅ Funktionen mit und ohne Rückgabewerte erstellen
# - ✅ Parameter übergeben und Standardwerte verwenden
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die Boss-Quests!

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Exzellent!** Du hast die Systemprotokolle gemeistert!
#
# **Das hast du gelernt:**
# - Funktionen definieren und wiederverwenden
# - Parameter für flexible Protokolle nutzen
# - return-Werte für Systemergebnisse
# - Docstrings für verständlichen Code
# - Namenskonventionen für sauberen Code
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🚀 **Raumfahrt:** Flugsteuerung, Telemetrie, Missionsplanung
# - 📱 **Apps:** Datenverarbeitung, Berechnungen, Benutzeroberflächen
# - 🌐 **Websites:** Formulare, Datenbanken, Benutzer-Systeme
# - 🤖 **KI-Systeme:** Datenanalyse, Mustererkennung, Vorhersagen
# - 📊 **Wissenschaft:** Simulationen, Berechnungen, Forschung
#
# **Als Nächstes:** In Woche 6 lernst du **Listen**!

# %% [markdown]
# ## 🐉 Boss-Kampf: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Quests sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 Cyber Credits + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Der Protokoll-Generator
#
# **Belohnung:** 500 Cyber Credits + Master-Protokoll
#
# Erstelle ein System, das automatisch Systemprotokolle erzeugt, bewertet und in einer kleinen "Datenbank" verwaltet.
#
# **Deine Aufgaben:**
#
# 1. **Protokoll-Namen generieren**
#    - Schreibe eine Funktion `generiere_protokoll_name(system_typ, sicherheits_level)`, die aus Typ und Level einen Namen baut (z.B. `"SEC-ALARM-L3"`)
#    - Gib den Namen als String zurück
#    - Nutze f-Strings und einen kurzen Docstring
#
# 2. **Effizienz berechnen**
#    - Erstelle eine Funktion `berechne_effizienz(komplexitaet, system_typ)`, die einen Wert zwischen 0 und 100 zurückgibt
#    - Nutze unterschiedliche Faktoren je nach `system_typ` (z.B. "Alarm", "Scan", "Log")
#    - Gib die Effizienz als Zahl zurück
#
# 3. **Protokoll-Daten erstellen**
#    - Schreibe eine Funktion `erstelle_protokoll(system_typ, sicherheits_level, komplexitaet)`, die ein Dictionary mit Name, Typ, Level und Effizienz zurückgibt
#    - Nutze dafür deine beiden vorherigen Funktionen
#
# 4. **Protokolle speichern und finden**
#    - Erstelle eine Liste `protokolle`
#    - Schreibe eine Funktion `speichere_protokoll(liste, protokoll)`, die das Protokoll hinzufügt
#    - Schreibe eine Funktion `finde_protokolle(liste, such_typ)`, die alle Protokolle eines bestimmten Typs zurückgibt
#
# 5. **Generator-System aufbauen**
#    - Erzeuge im Hauptteil mindestens 5 verschiedene Protokolle
#    - Speichere sie in der Liste und gib eine kleine Statistik aus (Anzahl, Durchschnittseffizienz)
#
# **Beispiel-Code zum Starten:**
# ```python
# def generiere_protokoll_name(system_typ, sicherheits_level):
#     """Erzeugt einen Protokoll-Namen aus Typ und Sicherheitslevel."""
#     return f"{system_typ.upper()}-L{sicherheits_level}"
#
# protokolle = []
#
# # Hier kannst du weitere Funktionen definieren und Protokolle erzeugen
# ```
#
# **Bonus-Challenge:**
# - Füge eine Funktion hinzu, die Protokolle nach Effizienz sortiert ausgibt.
#
# **Erwartete Ausgabe:**
# ```
# Erzeugtes Protokoll: ALARM-L3 (Effizienz 82)
# ...
# Anzahl Protokolle: 5
# Durchschnittliche Effizienz: 76.4
# Gefundene ALARM-Protokolle: 2
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Der Raumstation-Manager
#
# **Belohnung:** 600 Cyber Credits + Kommandanten-Titel
#
# Baue ein System, das die wichtigsten Bereiche einer Raumstation verwaltet: Sektoren, Energie und Personal.
#
# **Deine Aufgaben:**
#
# 1. **Sektoren erzeugen**
#    - Erstelle eine Funktion `erstelle_sektor(sektor_id, groesse)`, die ein Dictionary mit ID, Größe und Anfangsenergie zurückgibt
#    - Lege eine Liste mit mehreren Sektoren an
#
# 2. **Energie verteilen**
#    - Schreibe eine Funktion `verteile_energie(sektoren, gesamt_energie)`, die die Energie proportional zur Größe auf die Sektoren verteilt
#    - Aktualisiere dafür die Einträge in den Sektor-Dictionaries
#
# 3. **Schichtplanung vereinfachen**
#    - Erstelle eine Funktion `plane_schichten(anzahl_personal, schichten)`, die eine einfache Verteilung (z.B. gleichmäßig) berechnet
#    - Gib eine Liste mit Personalzahlen pro Schicht zurück
#
# 4. **Stations-Übersicht erzeugen**
#    - Schreibe eine Funktion `erzeuge_stationsbericht(sektoren, energie, personal)`, die eine Übersicht als Text zurückgibt
#    - Nutze Informationen aus den Sektoren, der Gesamtenergie und der Personalzahl
#
# **Beispiel-Code zum Starten:**
# ```python
# station = {
#     "sektoren": [],
#     "energie": 10000,
#     "personal": 500,
# }
#
# # Hier kannst du Sektoren erzeugen und Funktionen aufrufen
# ```
#
# **Bonus-Challenge:**
# - Füge eine einfache Notfall-Funktion hinzu, die bei zu wenig Energie in einem Sektor eine Warnung zurückgibt.
#
# **Erwartete Ausgabe:**
# ```
# Erzeugte Sektoren: 3
# Verteilte Energie: [3000, 4000, 3000]
# Schichtplanung: [170, 170, 160]
# Stationsbericht: Alle Sektoren versorgt, Personal verteilt, Station betriebsbereit.
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Die Kampf-Simulation
#
# **Belohnung:** 400 Cyber Credits + Kampf-Simulator
#
# Baue ein vereinfachtes Kampfsimulationssystem für zwei Flotten mit klar getrennten Funktionen.
#
# **Deine Aufgaben:**
#
# 1. **Kampf initialisieren**
#    - Erstelle eine Funktion `initialisiere_kampf(flotte1, flotte2)`, die einen Startzustand (z.B. Dictionary) zurückgibt
#    - Speichere Namen, Schilde und Hülle beider Flotten darin
#
# 2. **Schaden berechnen**
#    - Schreibe eine Funktion `berechne_schaden(basis_schaden, schild_staerke)`, die den tatsächlichen Schaden (z.B. `basis_schaden - schild_staerke/10`) zurückgibt
#    - Nutze diese Funktion später in den Kampfrunden
#
# 3. **Kampfrunde ausführen**
#    - Erstelle eine Funktion `fuehre_runde_aus(status)`, die:
#      - zufällig eine angreifende Flotte wählt,
#      - Schaden berechnet und
#      - Schilde/Hülle der verteidigenden Flotte aktualisiert
#    - Gib den aktualisierten Status zurück
#
# 4. **Kampf steuern**
#    - Schreibe eine Funktion `starte_simulation(flotte1, flotte2, max_runden)`, die mehrere Runden durchführt, bis eine Flotte besiegt ist oder `max_runden` erreicht sind
#    - Gib am Ende eine Zusammenfassung mit Sieger, Verlierer und verbleibender Hülle aus
#
# **Beispiel-Code zum Starten:**
# ```python
# flotte_a = {"name": "Alpha", "schilde": 100, "huelle": 100}
# flotte_b = {"name": "Beta", "schilde": 100, "huelle": 100}
#
# print("=== KAMPF-SIMULATION ===")
# # Hier rufst du deine Funktionen auf
# ```
#
# **Bonus-Challenge:**
# - Füge Spezialwaffen hinzu, die mit einer kleinen Wahrscheinlichkeit doppelten Schaden verursachen.
#
# **Erwartete Ausgabe:**
# ```
# === KAMPF-SIMULATION ===
# Runde 1: Alpha greift Beta an – 15 Schaden.
# Runde 2: Beta greift Alpha an – 8 Schaden.
# ...
# Sieger: Flotte Alpha, Hülle 23.
# ```

# %%
# 🐉 Deine Lösung hier:

print()
print("🎉 +400 Cyber Credits: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Architekten der unendlichen Rekursion besiegt!")
print("⭐ Titel erhalten: Meister der Systemprotokolle")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 5 gemeistert!")
print("📚 Nächste Woche: Listen (Listen erstellen, bearbeiten, durchsuchen)!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen:

# %%
# ✅ Lösung Bug #1: Falsche Einrückung

# Problem: Code nach def nicht eingerückt
def system_boot():
    print("System wird gestartet...")
    return "Bereit"  # Das fehlte!

# %%
# ✅ Lösung Bug #2: Falscher Funktionsaufruf

# Problem: Klammern vergessen
def berechne_warp_geschwindigkeit(warp_faktor):
    return warp_faktor ** 3

# Korrekter Aufruf:
result = berechne_warp_geschwindigkeit(5)  # Klammern hinzugefügt!

# %%
# ✅ Lösung Bug #3: Vergessenes return

# Problem: return vergessen
def addiere_sensordaten(daten1, daten2):
    gesamt = daten1 + daten2
    return gesamt  # Das fehlte!

summe = addiere_sensordaten(100, 250)
print(f"Gesamt-Sensordaten: {summe}")  # Jetzt gibt es 350 aus!
