# %% [markdown]
# # ⚔️ Woche 7 – Module und Bibliotheken: Die magischen Werkzeugkästen!
#
# **XP zu verdienen:** 1000 Punkte
# **Boss:** Der Bibliothekar der unendlichen Zauber

# %% [markdown]
# ## 🌟 Die Quest beginnt: Die Bibliothek von Pyralia
#
# Willkommen in der magischen Bibliothek von Pyralia! Du erreichst die **große Bibliothek** – ein mystischer Ort, an dem unendlich viele Zauberformeln und magische Werkzeuge aufbewahrt werden. In dieser Woche lernst du die drei **Arten der Magie-Bibliotheken**:
#
# **Deine Mission:**
# - Meistere den **Zauber-Import** mit import und from
# - Beherrsche die **math-Magie** für Berechnungen
# - Lerne die **Zufalls-Zauber** für unvorhersehbare Ereignisse
#
# **Einmal importiert, für immer verfügbar!** Die Macht der Bibliotheken wartet...

# %% [markdown]
# ## 📚 Magie-Sammlung 1: Der Zauber-Import - Das erste Modul
#
# **Was es ist:** Ein Modul ist eine Sammlung von vordefinierten Zaubern, die du in dein Programm laden kannst.
#
# **Die Anatomie eines Imports:**
# ```python
# # Ganzes Modul importieren
# import math
#
# # Mit Alias importieren
# import math as m
#
# # Nur bestimmte Zauber importieren
# from math import pi, sqrt
# ```
#
# **Schritt-für-Schritt-Erklärung:**
# 1. **`import`** - Zauberwort zum Laden
# 2. **`math`** - Name der Bibliothek
# 3. **`as`** - Optionaler Spitzname
# 4. **`from`** - Importiert spezifische Zauber
#
# **Warum so nützlich:**
# - 🎯 Zauber nicht neu erfinden müssen
# - 🔍 Professionelle, optimierte Sprüche
# - ⚡ Dein Code bleibt übersichtlich
# - 🎲 Zugriff auf spezialisierte Magie

# %%
# Beispiel 1: Module importieren
# Ganzes Modul importieren
import math
print(f"Pi aus math: {math.pi}")

# Mit Alias importieren
import random as r
print(f"Zufallszahl: {r.randint(1, 10)}")

# Nur bestimmte Zauber importieren
from math import sqrt, sin, cos
print(f"Wurzel aus 16: {sqrt(16)}")
print(f"Sinus 90°: {sin(1.57)}")
print(f"Kosinus 0°: {cos(0)}")

# %%
# Beispiel 2: Verschiedene Import-Methoden vergleichen
# Methode 1: import math
import math
print("Methode 1 - import math:")
print(f"  math.pi: {math.pi}")
print(f"  math.sqrt(25): {math.sqrt(25)}")

# Methode 2: import math as m
import math as m
print("\nMethode 2 - import math as m:")
print(f"  m.pi: {m.pi}")
print(f"  m.sqrt(25): {m.sqrt(25)}")

# Methode 3: from math import pi, sqrt
from math import pi, sqrt
print("\nMethode 3 - from math import pi, sqrt:")
print(f"  pi: {pi}")
print(f"  sqrt(25): {sqrt(25)}")

# %%
# Beispiel 3: Mehrere Module importieren
import math
import random
import time

# Berechne eine zufällige Flugdauer
distanz = 1000  # Meilen
geschwindigkeit = random.uniform(0.1, 0.9)  # Bruchteil der Lichtgeschwindigkeit
flugzeit = distanz / geschwindigkeit

print("=== Magische Reise-Simulation ===")
print(f"Distanz: {distanz} Meilen")
print(f"Geschwindigkeit: {geschwindigkeit:.2f}c")
print(f"Reisezeit: {flugzeit:.1f} Stunden")
print(f"Warte 2 Sekunden...")
time.sleep(2)
print(f"Ankunft am Ziel!")

# %% [markdown]
# ## 📦 Magie-Sammlung 2: Das math-Modul - Der Berechnungs-Zauber
#
# **Die wichtigsten math-Zauber:**
#
# **Konstanten:**
# - `math.pi` - Die Zahl Pi (3.14159...)
# - `math.e` - Eulersche Zahl (2.71828...)
# - `math.inf` - Unendlich
#
# **Grundzauber:**
# - `math.sqrt(x)` - Quadratwurzel
# - `math.pow(x, y)` - x hoch y
# - `math.ceil(x)` - Aufrunden
# - `math.floor(x)` - Abrunden
# - `math.fabs(x)` - Absolutwert

# %%
# 🔍 Übungen mit math-Konstanten
import math

print("=== Magische Konstanten ===")
print(f"Pi (π): {math.pi}")
print(f"Eulersche Zahl (e): {math.e}")
print(f"Unendlich: {math.inf}")
print(f"Tau (2π): {math.tau}")

# Praktische Anwendung: Kreisberechnungen
radius = 10
umfang = 2 * math.pi * radius
flaeche = math.pi * radius ** 2
print(f"\nKreis mit r={radius}:")
print(f"  Umfang: {umfang:.2f}")
print(f"  Fläche: {flaeche:.2f}")

# %%
# Beispiel 2: Mathematische Grundzauber
import math

print("=== Mathematische Zauber ===")

# Wurzel und Potenzen
print(f"sqrt(16): {math.sqrt(16)}")
print(f"pow(2, 3): {math.pow(2, 3)}")
print(f"2**3: {2**3}")

# Runden
zahl = 3.7
print(f"\nZahl: {zahl}")
print(f"round({zahl}): {round(zahl)}")
print(f"math.ceil({zahl}): {math.ceil(zahl)}")
print(f"math.floor({zahl}): {math.floor(zahl)}")

# Absolutwert
print(f"\nmath.fabs(-5.5): {math.fabs(-5.5)}")
print(f"abs(-5.5): {abs(-5.5)}")

# %%
# Beispiel 3: Fortgeschrittene Zauber
import math

print("=== Fortgeschrittene Zauber ===")

# Winkelfunktionen (in Bogenmaß!)
winkel_grad = 45
winkel_rad = math.radians(winkel_grad)
print(f"{winkel_grad}° = {winkel_rad:.3f} rad")
print(f"sin({winkel_grad}°): {math.sin(winkel_rad):.3f}")
print(f"cos({winkel_grad}°): {math.cos(winkel_rad):.3f}")
print(f"tan({winkel_grad}°): {math.tan(winkel_rad):.3f}")

# Logarithmen
print(f"\nlog(10): {math.log(10):.3f}")
print(f"log10(100): {math.log10(100)}")
print(f"log2(8): {math.log2(8)}")

# Spezielle Zauber
print(f"\nfactorial(5): {math.factorial(5)}")
print(f"gcd(24, 36): {math.gcd(24, 36)}")
print(f"lcm(12, 15): {math.lcm(12, 15)}")

# %% [markdown]
# ## ✨ Magie-Sammlung 3: Das random-Modul - Der Zufalls-Zauber
#
# **Die mächtigsten Zufalls-Zauber:**
#
# **Zahlen erzeugen:**
# - `random.randint(a, b)` - Zufällige Ganzzahl von a bis b
# - `random.uniform(a, b)` - Zufällige Kommazahl von a bis b
# - `random.random()` - Zufallszahl zwischen 0 und 1
#
# **Aus Listen wählen:**
# - `random.choice(liste)` - Ein zufälliges Element
# - `random.choices(liste, k=n)` - n zufällige Elemente
# - `random.shuffle(liste)` - Liste mischen
#
# **Verteilungen:**
# - `random.gauss(mu, sigma)` - Normalverteilung
# - `random.expovariate(lambda)` - Exponentialverteilung

# %%
# Beispiel 1: Zufallszahlen erzeugen
import random

print("=== Zufallszahlen ===")

# Ganzzahlen
print(f"Zufällige Zahl 1-6: {random.randint(1, 6)}")
print(f"Zufällige Zahl 0-100: {random.randint(0, 100)}")

# Kommazahlen
print(f"Zufallszahl 0-1: {random.random():.3f}")
print(f"Zufallszahl 10-20: {random.uniform(10, 20):.2f}")

# Mit Seeds reproduzierbar
random.seed(42)
print(f"Mit Seed 42: {random.randint(1, 100)}")
random.seed(42)
print(f"Mit Seed 42: {random.randint(1, 100)} (gleiches Ergebnis!)")

# %%
# Beispiel 2: Aus Listen wählen
import random

print("=== Zufallsauswahl aus Listen ===")

# Reiche im Königreich
reiche = ["Pyralia", "Aquaria", "Terrania", "Aeris", "Ignis", "Natura"]
print(f"Alle Reiche: {reiche}")

# Ein zufälliges Reich
ziel = random.choice(reiche)
print(f"Zielreich: {ziel}")

# Drei zufällige Reiche
flotte = random.choices(reiche, k=3)
print(f"Reiseziele: {flotte}")

# Liste mischen
reihenfolge = reiche.copy()
random.shuffle(reihenfolge)
print(f"Gemischte Reihenfolge: {reihenfolge}")

# %%
# Beispiel 3: Fortgeschrittene Zufallszauber
import random
import math

print("=== Fortgeschrittene Zufallszauber ===")

# Normalverteilung für Energiewerte
print("Magische Energie (Normalverteilung):")
for i in range(5):
    energie = random.gauss(100, 20)  # Mittelwert 100, Stdabw 20
    print(f"  Magier {i+1}: {max(0, energie):.1f} Mana")

# Exponentialverteilung für Wartezeiten
print("\nWartezeiten (Exponentialverteilung):")
for i in range(5):
    warten = random.expovariate(0.1)  # Lambda = 0.1
    print(f"  Wartezeit {i+1}: {warten:.1f} Minuten")

# Zufälliger Punkt im Kreis
def zufalls_punkt_kreis(radius):
    winkel = random.uniform(0, 2 * math.pi)
    r = radius * math.sqrt(random.random())
    x = r * math.cos(winkel)
    y = r * math.sin(winkel)
    return x, y

x, y = zufalls_punkt_kreis(10)
print(f"\nZufälliger Punkt im Kreis r=10: ({x:.2f}, {y:.2f})")

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein Lehrling hat versucht, die Zauber zu verwenden, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1

result = math.sqrt(9)
print(f"Ergebnis: {result}")

# %%
# 🐛 Bug #2

import random
zahl = random.zahl(1, 10)
print(f"Zufallszahl: {zahl}")

# %%
# 🐛 Bug #3

import math
winkel = 90
sinus = sin(math.radians(winkel))
print(f"Sinus von {winkel}°: {sinus}")

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Zauber-Importer
#
# **Belohnung:** 300 XP + Magischer Beutel
#
# In der Bibliothek von Pyralia lernst du, wie du Zauber-Bibliotheken (Module) lädst und mit Aliasen arbeitest.
#
# **Deine Aufgaben:**
#
# 1. **Bibliotheken importieren**
#    - Lade die Module `math`, `random` und `time` mit passenden Aliasen (z.B. `import math as m`)
#    - Gib jeweils eine Konstante oder Funktion aus jedem Modul aus (z.B. `math.pi`, `random.randint(1, 10)`)
#
# 2. **Wartezeit-Zauber**
#    - Erstelle eine kleine Funktion oder ein Skript, das eine zufällige Sekundenzahl (1–3) mit `random` erzeugt und `time.sleep()` nutzt
#    - Gib vor und nach der Wartezeit eine kurze Meldung aus (z.B. „Zauber lädt …“)
#
# 3. **Flugbahn-Zauber**
#    - Nutze `math.sin` und `math.pi`, um für einen Winkel (z.B. 90° in Bogenmaß) eine Höhe oder einen Wert zu berechnen
#    - Gib das Ergebnis formatiert aus
#
# 4. **Gruppen-Generator**
#    - Erstelle eine Namensliste mit 3–5 Helden-Namen und wähle mit `random.choice()` einen zufälligen Namen aus
#    - Gib den ausgewählten Namen aus
#
# **Beispiel-Code zum Starten:**
# ```python
# import math as m
# import random as r
# import time as t
#
# print(f"Pi: {m.pi}")
# print(f"Zufall 1-10: {r.randint(1, 10)}")
# sekunden = r.randint(1, 3)
# print(f"Zauber lädt {sekunden} Sekunden...")
# t.sleep(sekunden)
# print("Bereit!")
# ```
#
# **Bonus-Challenge:**
# - Füge einen weiteren Zauber mit dem `datetime`-Modul hinzu (z.B. aktuelle Uhrzeit anzeigen).
#
# **Erwartete Ausgabe:**
# ```
# Pi: 3.141592653589793
# Zufall 1-10: 7
# Zauber lädt 2 Sekunden...
# Bereit!
# Held: Elara
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Berechnungs-Zauber
#
# **Belohnung:** 400 XP + Kristallkugel
#
# Du nutzt das math-Modul für magische Kreisberechnungen, Winkelumrechnung und Wurzeln.
#
# **Deine Aufgaben:**
#
# 1. **Kreis-Zauber**
#    - Schreibe eine Funktion oder ein Skript, das für einen Radius (z.B. magischer Kreis) Umfang und Fläche mit `math.pi` berechnet
#    - Gib Radius, Umfang und Fläche formatiert aus
#
# 2. **Zufalls-Zahlen und Summe**
#    - Erzeuge mit `random.randint(1, 100)` fünf Zufallszahlen (z.B. für Mana-Werte) und speichere sie in einer Liste
#    - Berechne die Summe und gib die Zahlen sowie die Summe aus
#
# 3. **Winkel-Umrechnung**
#    - Wandle 90°, 180° und 270° mit `math.radians()` in Bogenmaß um
#    - Gib Grad und Bogenmaß für jeden Winkel aus
#
# 4. **Wurzel-Ziehen**
#    - Berechne mit `math.sqrt()` die Wurzeln von 4, 9, 16 und 25
#    - Gib die Ergebnisse übersichtlich aus
#
# **Beispiel-Code zum Starten:**
# ```python
# import math
# import random
#
# radius = 10
# umfang = 2 * math.pi * radius
# flaeche = math.pi * radius ** 2
# print(f"Magischer Kreis r={radius}: Umfang {umfang:.2f}, Fläche {flaeche:.2f}")
#
# zahlen = [random.randint(1, 100) for _ in range(5)]
# print(f"Zufallszahlen: {zahlen}, Summe: {sum(zahlen)}")
# ```
#
# **Bonus-Challenge:**
# - Füge trigonometrische Zauber hinzu (z.B. sin, cos für 45°).
#
# **Erwartete Ausgabe:**
# ```
# Magischer Kreis r=10: Umfang 62.83, Fläche 314.16
# Zufallszahlen: [23, 67, 12, 89, 34], Summe: 225
# 90° = 1.57 rad | 180° = 3.14 rad | 270° = 4.71 rad
# sqrt(4)=2.0, sqrt(9)=3.0, ...
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Der Zufalls-Zauber
#
# **Belohnung:** 500 XP + Gilde-Meister-Urkunde
#
# Du baust ein kleines Zufallssystem mit Reichen, Wetter und Mana-Verbrauch.
#
# **Deine Aufgaben:**
#
# 1. **Reichsauswahl**
#    - Erstelle eine Liste mit 5–6 Reiche-Namen und wähle mit `random.choice()` ein zufälliges Reich aus
#    - Gib die Liste und das gewählte Reich aus
#
# 2. **Wetter-Simulation**
#    - Erzeuge mit `random.uniform(-50, 50)` drei Temperaturwerte (z.B. für verschiedene Regionen) und runde sie auf eine Dezimalstelle
#    - Gib die Temperaturen mit kurzer Beschreibung aus
#
# 3. **Magie-Verbrauch**
#    - Simuliere 3 Zauberer mit je einem zufälligen Mana-Verbrauch zwischen 50 und 150 (mit `random.randint` oder `random.uniform`)
#    - Gib Zauberer-Name und Mana aus und berechne den Gesamtverbrauch
#
# 4. **Helden-Generator**
#    - Erstelle 3 Helden-Namen mit zugehöriger zufälliger Stärke (1–10) und speichere sie (z.B. als Liste von Tupeln)
#    - Gib alle Helden mit ihrer Stärke aus
#
# **Beispiel-Code zum Starten:**
# ```python
# import random
#
# reiche = ["Nordreich", "Südland", "Ostmark", "Westküste", "Mittelreich"]
# auswahl = random.choice(reiche)
# print(f"Gewähltes Reich: {auswahl}")
#
# temp1 = round(random.uniform(-50, 50), 1)
# print(f"Region Alpha: {temp1}°C")
# ```
#
# **Bonus-Challenge:**
# - Füge eine Variable mit Normalverteilung hinzu (z.B. `random.gauss(100, 20)` für Mana).
#
# **Erwartete Ausgabe:**
# ```
# Gewähltes Reich: Südland
# Temperaturen: -12.3°C, 22.1°C, 45.0°C
# Zauberer 1: 87 Mana, Zauberer 2: 120 Mana, Zauberer 3: 65 Mana — Gesamt: 272
# Helden: [('Elara', 7), ('Thor', 3), ('Luna', 9)]
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten des Bibliothekars (Reflexion)
#
# Bevor du weitergehst, denke über diese Fragen nach:
#
# 1. **Warum sollte man Zauber (Module) verwenden statt alles selbst zu erfinden?**
#
# 2. **Was ist der Unterschied zwischen `import math` und `from math import sqrt`?**
#
# 3. **Wann verwendet man `random.choice()` und wann `random.randint()`?**
#
# Diskutiere deine Gedanken mit anderen Magiern!

# %% [markdown]
# ### 📖 Zauberbuch-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **import** 📦: Bibliothek laden
# - **from** 🎯: Selektiver Import
# - **as** 🏷️: Spitzname
# - **math** 🔢: Mathe-Bibliothek
# - **random** 🎲: Zufalls-Bibliothek
# - **pi** ⭕: Kreiszahl
# - **sqrt()** √: Wurzelziehen
# - **randint()** 🎯: Zufällige Ganzzahl
# - **choice()** 🎲: Zufällige Auswahl
# - **seed()** 🌱: Zufalls-Seed

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ✅ Bibliotheken mit import laden
# - ✅ Spitznamen für Bibliotheken verwenden
# - ✅ Spezielle Zauber importieren
# - ✅ math-Bibliothek für Berechnungen nutzen
# - ✅ random-Bibliothek für Zufallszahlen verwenden
# - ✅ Bibliotheken in eigenen Programmen einsetzen
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die Boss-Quests!

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Exzellent!** Du hast die Bibliothek von Pyralia gemeistert!
#
# **Das hast du gelernt:**
# - Bibliotheken importieren und verwenden
# - Mathematische Berechnungen durchführen
# - Zufallsereignisse simulieren
# - Verschiedene Import-Methoden kennen
# - Professionelle Zauberbibliotheken nutzen
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🎮 **Spiele:** Statistiken, Zufall, Physik
# - 📱 **Apps:** Berechnungen, Simulationen
# - 🌐 **Websites:** Datenanalyse, Visualisierungen
# - 🔬 **Wissenschaft:** Modelle, Simulationen
# - 🎨 **Kreativität:** Generative Kunst, Musik
#
# **Als Nächstes:** In Woche 8 lernst du **Dictionaries und Tupel**!

# %% [markdown]
# ## 🐉 Boss-Kampf: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Quests sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 XP + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Der Welten-Simulator
#
# **Belohnung:** 500 XP + Simulations-Kristall
#
# Du baust einen kleinen Welten-Simulator mit Regionen, Magie-Berechnung und „bewohnbaren“ Orten.
#
# **Deine Aufgaben:**
#
# 1. **Welt-Generator**
#    - Erstelle eine Funktion `erstelle_welt(anzahl_regionen, welt_typ)`, die eine Liste mit Region-Namen (z.B. mit `random.choice` aus einer Vorlage) zurückgibt
#    - Gib die Liste der Regionen und den Welt-Typ aus
#
# 2. **Magie-Berechnung**
#    - Schreibe eine Funktion `magie_berechnung(mana1, mana2, distanz)`, die eine „Magie-Kraft“ berechnet (z.B. mana1 * mana2 / distanz mit `math`); nutze sinnvolle Werte
#    - Gib die Magie-Kraft für ein Beispiel aus
#
# 3. **Lebenskraft und bewohnbare Regionen**
#    - Erstelle eine Funktion, die für eine Region (z.B. Name und „Lebenskraft“ 0–1 mit `random.uniform`) einen Wert zurückgibt
#    - Erstelle eine Funktion, die aus einer Regionenliste die „bewohnbaren“ filtert (z.B. Lebenskraft > Schwellwert)
#    - Gib die gefilterte Liste aus
#
# 4. **Hauptprogramm**
#    - Simuliere 5 Welten mit deinen Funktionen, berechne für ein Beispiel die Magie-Kraft und zeige eine kurze Statistik (z.B. wie viele Regionen pro Welt, wie viele „bewohnbar“)
#
# **Beispiel-Code zum Starten:**
# ```python
# import math
# import random
#
# def erstelle_welt(anzahl_regionen, welt_typ):
#     namen = ["Nord", "Süd", "Ost", "West", "Mitte"]
#     return [random.choice(namen) + f"-{i}" for i in range(anzahl_regionen)]
#
# def magie_berechnung(mana1, mana2, distanz):
#     return mana1 * mana2 / max(distanz, 1)
# ```
#
# **Bonus-Challenge:**
# - Füge zufällige „Kreaturen“ mit Eigenschaften (z.B. Name, Typ) zu bewohnbaren Regionen hinzu.
#
# **Erwartete Ausgabe:**
# ```
# Welt: ['Nord-0', 'Süd-1', 'West-2'] (Typ: Fantasy)
# Magie-Kraft: 42.5
# Bewohnbare Regionen: 2 von 5
# Statistik: 5 Welten, 3 bewohnbare Regionen
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Der Elementar-Zauberer
#
# **Belohnung:** 600 XP + Elementarstab
#
# Du simulierst ein Elementar-Zaubersystem mit „Elementarzuständen“ und Zufalls-Messungen.
#
# **Deine Aufgaben:**
#
# 1. **Elementar-Zustand**
#    - Erstelle eine Funktion `erstelle_elementarzustand(element, anzahl_zauber)`, die eine Liste von Zufallswerten (0 oder 1) mit `random.randint(0, 1)` für jeden Zauber zurückgibt
#    - Gib den Zustand aus
#
# 2. **Elementar-Messung**
#    - Erstelle eine Funktion `messung(elementarzustand, zauber_index)`, die den Wert des Zaubers an der Stelle `zauber_index` zurückgibt
#    - Gib das Messergebnis für ein Beispiel aus
#
# 3. **Elementar-Verbindung (simuliert)**
#    - Erstelle eine Funktion `verbinde(e1, e2)`, die zwei „Elemente“ (z.B. zwei 0/1-Werte) nimmt und einen gemeinsamen Zustand zurückgibt (z.B. Liste [e1, e2] oder Tupel)
#    - Gib den verbundenen Zustand aus
#
# 4. **Demo**
#    - Erzeuge einen Elementarzustand mit 3–5 Zaubern, führe „Messungen“ durch und zeige eine kurze Erklärung zu jedem Schritt
#
# **Beispiel-Code zum Starten:**
# ```python
# import random
#
# def erstelle_elementarzustand(element, anzahl_zauber):
#     return [random.randint(0, 1) for _ in range(anzahl_zauber)]
#
# def messung(elementarzustand, zauber_index):
#     return elementarzustand[zauber_index]
# ```
#
# **Bonus-Challenge:**
# - Simuliere einen „Meister-Zauber“: z.B. mehrfach Zufallsbits erzeugen und eine „Parität“ (Summe mod 2) ausgeben.
#
# **Erwartete Ausgabe:**
# ```
# Elementarzustand Feuer: [1, 0, 1, 0, 1]
# Messung Zauber 2: 1
# Verbundener Zustand: (0, 1)
# Demo: 5 Zauber erzeugt, Messungen an 0 und 2 durchgeführt.
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Die Artefakt-Schmiede
#
# **Belohnung:** 400 XP + Gilde-Meister-Urkunde (Artefakt)
#
# Du baust eine vereinfachte „Artefakt-Schmiede“-Simulation mit Runen und Verzauberungsstärke.
#
# **Deine Aufgaben:**
#
# 1. **Artefakt-Struktur**
#    - Erstelle eine Funktion `erstelle_artefakt(magie_typ, anzahl_runen)`, die ein „Artefakt“ als Liste zurückgibt: z.B. für jede Rune einen Stärke-Wert mit `random.uniform(0, 1)`
#    - Gib die Struktur (z.B. Liste der Stärkewerte) aus
#
# 2. **Verzauberung (simuliert)**
#    - Schreibe eine Funktion `verzaubere(artefakt, runden)`, die in einer Schleife `runden`-mal zufällig eine Rune „verstärkt“ (z.B. einen Wert mit `random.uniform` anhebt)
#    - Gib nach der Verzauberung eine kurze Meldung aus (z.B. „Verzauberung abgeschlossen, 10 Runden“)
#
# 3. **Vorhersage (simuliert)**
#    - Erstelle eine Funktion `artefakt_staerke(artefakt)`, die aus den Runen-Werten eine „Gesamtstärke“ berechnet (z.B. Durchschnitt mit `sum`/`len` oder `math`)
#    - Gib die Stärke für ein Beispiel aus
#
# 4. **Analyse und Demo**
#    - Berechne für ein Artefakt die Gesamtstärke und gib die Einzelrunen sowie die Verzauberungsstärke in Prozent aus
#
# **Beispiel-Code zum Starten:**
# ```python
# import random
#
# def erstelle_artefakt(magie_typ, anzahl_runen):
#     return [random.uniform(0, 1) for _ in range(anzahl_runen)]
#
# def artefakt_staerke(artefakt):
#     return sum(artefakt) / len(artefakt) * 100
# ```
#
# **Bonus-Challenge:**
# - Füge „Meister-Verzauberungen“ mit mehreren Schichten hinzu (z.B. zweite Liste mit Verfeinerungsstufen).
#
# **Erwartete Ausgabe:**
# ```
# Artefakt: [0.7, 0.8, 0.6, 0.9]
# Verzauberung abgeschlossen, 5 Runden
# Stärke: 75.0%
# Demo: 4 Runen, Verzauberungsstärke 75.0%
# ```

# %%
# 🐉 Deine Lösung hier:

print()
print("🎉 +400 XP: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Bibliothekar der unendlichen Zauber besiegt!")
print("⭐ Titel erhalten: Meister der Bibliotheken")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 7 gemeistert!")
print("📚 Nächste Woche: Dictionaries und Tupel!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen:

# %%
# ✅ Lösung Bug #1: Bibliothek nicht importiert

# Problem: math wurde nicht importiert
import math
result = math.sqrt(9)
print(f"Ergebnis: {result}")

# %%
# ✅ Lösung Bug #2: Falscher Zaubername

# Problem: random.zahl existiert nicht
import random
zahl = random.randint(1, 10)
print(f"Zufallszahl: {zahl}")

# %%
# ✅ Lösung Bug #3: Zauber nicht gefunden

# Problem: sin existiert nicht ohne math.
import math
winkel = 90
sinus = math.sin(math.radians(winkel))
print(f"Sinus von {winkel}°: {sinus}")
