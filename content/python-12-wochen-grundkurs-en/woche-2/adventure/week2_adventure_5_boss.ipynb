# %% [markdown]
# # 🐉 Boss Quests – 💎 Week 2 – Data Types and Variables: The Four Magic Elements
# > ⚠️ Harder! Combines everything from this week.
#
# **⚠️ WARNING:** These quests are significantly harder! They combine everything you have learned.
#
# **Rewards:** 1500 XP total + legendary items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 1: The Treasure Room
#
# **Reward:** 500 XP + Treasure Key
#
# The treasure room has 8 chests. Each one must be catalogued!
#
# **Step 1 – Record the treasures:**
# Create variables for 8 chests with name (String) and gold value (Integer) and give each chest a unique label
#
# **Step 2 – Create the treasure protocol:**
# Output a heading `"=== TREASURE ROOM PROTOCOL ==="` and create a description for each chest using f-Strings
#
# **Step 3 – Calculate average:**
# Add all gold values and divide the sum by 8
#
# **Step 4 – Find the richest chest:**
# Compare all gold values and determine the chest with the highest value
#
# **Step 5 – Determine total value:**
# Calculate the total value of all chests by adding all gold values
#
# **Bonus:** Count and output how many chests are below the average!

# %%
# 🗺️ Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss Quest 2: The Magic Workshop
#
# **Reward:** 600 XP + Spell Master Title
#
# In the magic workshop you experiment with magical formulas!
#
# **Step 1 – Create spells:**
# Create 5 spells with name, power (Float 0–100), complexity (1–5), casting time (seconds) and use appropriate data types for each property
#
# **Step 2 – Output spell descriptions:**
# Output a heading `"=== MAGIC WORKSHOP PROTOCOL ==="` and create a description for each spell using f-Strings
#
# **Step 3 – Sum complexity:**
# Add all complexity values of the spells and store the total in a variable
#
# **Step 4 – Find the most powerful spells:**
# Find the most powerful spell (highest power) and find the most complex spell (highest complexity)
#
# **Step 5 – Calculate average power:**
# Add all powers and divide by 5 and store the average
#
# **Step 6 – Filter the mighty:**
# Determine which spells are above average and use Boolean variables for marking
#
# **Bonus:** Calculate the efficiency (power / complexity) for each spell!

# %%
# 🗺️ Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 3: The Quest Planning
#
# **Reward:** 400 XP + Quest Book
#
# Plan the next great quest!
#
# **Step 1 – Define quests:**
# Create Quest 1: goal, duration (days), reward, group size, success probability (0–1) and create Quest 2: goal, duration (days), reward, group size, success probability (0–1)
#
# **Step 2 – Create quest protocol:**
# Output a heading `"=== QUEST PROTOCOL ==="` and present both quests with all data
#
# **Step 3 – Calculate totals:**
# Add the total reward of both quests and add the total group size
#
# **Step 4 – Forecast success:**
# Calculate expected reward: reward × success probability and calculate for both quests
#
# **Step 5 – Compare quests:**
# Compare reward, duration and success probability and clearly show the differences
#
# **Step 6 – Determine profitability:**
# Find out which quest is more profitable and use a Boolean variable for marking
#
# **Bonus:** Calculate the reward per group member for each quest!

# %%
print()
print("🎉 +400 XP: Boss Quest complete!")
print("🏆 You defeated the Golem of Confused Forms!")
print("⭐ Title earned: Master of Elements")
print()
print("🎊 CONGRATULATIONS! You have mastered Week 2!")
print("📚 Next week: Conditions (if-else)!")

# %% [markdown]
# ---
#
# 🎊 **Congratulations!** You have completed all boss quests of this week!
#
# **Next:** Week 3 is already waiting!
