# %% [markdown]
# # 🐉 Boss Quests – 🏰 Week 11 – Advanced OOP: The Magic Evolution!
# > ⚠️ Harder! Combines everything from this week.
#
# **⚠️ ATTENTION:** These quests are extremely difficult! They combine all the advanced concepts.
#
# **Rewards:** 1800 XP total + epic items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 1: The Guild System
#
# **Reward:** 600 XP + Master Guild Ring
#
# The Guild has different membership ranks – each with different rights!
#
# **Step 1 – Base class:**
# Write a class `Member` with name and rank. Add a method that describes the member's rights.
#
# **Step 2 – Specialisations:**
# Derive 3 child classes (e.g. Apprentice, Journeyman, Master). Each overrides the rights method with its own content.
#
# **Step 3 – Guild:**
# Create one object of each rank. Call the rights method for all and show polymorphism in action.
#
# **Bonus:** Add `__str__` so that `print(member)` produces a nice output.

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss Quest 2: The Mage Family
#
# **Reward:** 800 XP + Sceptre of Magic
#
# Every mage has a basic education – but each school has its own strength!
#
# **Step 1 – Base class:**
# Write a class `Mage` with name and mana. Add a method `cast_spell()`.
#
# **Step 2 – Schools:**
# Derive 3 child classes (e.g. FireMage, IceMage, LightningMage). Each overrides `cast_spell()` with its own spell style.
#
# **Step 3 – Duel:**
# Create one representative of each school. Let all three cast their spell and show a nice introduction with `__str__`.
#
# **Bonus:** Add `__eq__` that compares two mages by mana.

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 3: The Polymorphic Animal System
#
# **Reward:** 400 XP + Animal Whisperer Badge
#
# All animals can speak – but each says something different!
#
# **Step 1 – Base class:**
# Write a class `Animal` with name. Add a method `make_sound()` that prints a general message.
#
# **Step 2 – Animal types:**
# Derive 4 animals (e.g. Dog, Cat, Dragon, Owl). Each overrides `make_sound()` with its typical sound.
#
# **Step 3 – Animal Parade:**
# Create one of each animal and call `make_sound()` for all – show that Python automatically picks the right version.
#
# **Bonus:** Add `__str__` and `__len__` (`__len__` returns the length of the name).

# %%
print()
print("🎉 +400 XP: Boss Quest completed!")
print("🏆 You have defeated the Archmage!")
print("⭐ Title earned: Master of the OOP Arts")
print()
print("🎊 CONGRATULATIONS! You have mastered Week 11!")
print("📚 Next week: Graphical projects with Turtle!")

# %% [markdown]
# ---
#
# 🎊 **Congratulations!** You have mastered all the Boss Quests this week!
#
# **Up next:** Week 12 is already waiting!
