# %% [markdown]
# # 🏰 Woche 12 – Grafische Projekte mit Turtle: Die magische Leinwand!
#
# Willkommen, junger Magier der visuellen Künste! Du betrittst die **Werkstatt der magischen Zeichenrollen von Pyralia** – ein Ort, wo Code zu Leben erwacht und farbenfrohe Grafiken entstehen!
#
# In dieser Woche meistert du die magische Kunst der Turtle-Grafik:
#
# **Deine Mission:**
# - Turtle-Modul für visuelle Magie nutzen
# - Formen und Muster zeichnen
# - Farben für zauberhafte Effekte einsetzen
# - Animationen und interaktive Kunst erschaffen
#
# **Leg los!** Deine Reise zum visuellen Meister beginnt!

# %% [markdown]
# ## Zauberformel 1
#
# **Was es ist:** Das Turtle-Modul ist Pythons magische Zeichenrolle, die es dir ermöglicht, mit Code zu zeichnen.
#
# **Wichtig:** Importiere immer `turtle` und rufe `turtle.done()` am Ende auf!

# %%
# %pip install Tinker
from turtle import *
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 get_ipython().run_line_magic('pip', 'install Tinker')
# ----> 2 from turtle import *
#
# File /opt/homebrew/Cellar/python@3.14/3.14.3_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/turtle.py:101
#       1 #
#       2 # turtle.py: a Tkinter based turtle graphics module for Python
#       3 # Version 1.1b - 4. 5. 2009
#    (...)     21 #    misrepresented as being the original software.
#      22 # 3. This notice may not be removed or altered from any source distribution.
#      24 """
#      25 Turtle graphics is a popular way for introducing programming to
# ...

# %%
# Beispiel 1: Turtle einrichten
import turtle

# Erstelle eine magische Zeichenrolle
screen = turtle.Screen()
screen.title("Magische Zeichenrolle von Pyralia")
screen.bgcolor("black")

# Erstelle einen magischen Stift (Turtle)
pen = turtle.Turtle()
pen.speed(1)  # Langsam für magische Effekte
pen.color("cyan")

# Zeichne eine magische Form
pen.forward(100)
pen.left(90)
pen.forward(100)

# Schließe die magische Zeichenrolle
turtle.done()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Beispiel 1: Turtle einrichten
# ----> 2 import turtle
#       3
#       4 # Erstelle eine magische Zeichenrolle
#       5 screen = turtle.Screen()
#
# File /opt/homebrew/Cellar/python@3.14/3.14.3_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/turtle.py:101
#       1 #
#       2 # turtle.py: a Tkinter based turtle graphics module for Python
#       3 # Version 1.1b - 4. 5. 2009
#    (...)     21 #    misrepresented as being the original software.
#      22 # 3. This notice may not be removed or altered from any source distribution.
#      24 """
#      25 Turtle graphics is a popular way for introducing programming to
#      26 kids. It was part of the original Logo programming language developed
#    (...)     98 extensions in mind. These will be commented and documented elsewhere.
# ...

# %% [markdown]
# ## Zauberformel 2
#
# **Was es ist:** Mit Turtle-Befehlen kannst du verschiedene Formen zeichnen und den Stift bewegen.
#
# **Wichtig:** Die Turtle dreht sich immer an ihrer aktuellen Position!

# %%
# Beispiel 1: Grundlegende Bewegungen
import turtle

screen = turtle.Screen()
screen.bgcolor("navy")
pen = turtle.Turtle()
pen.speed(5)
pen.color("gold")

# Ein magisches Quadrat
for _ in range(4):
    pen.forward(100)
    pen.left(90)

# Ein magisches Dreieck
pen.penup()
pen.goto(-150, 0)
pen.pendown()
for _ in range(3):
    pen.forward(100)
    pen.left(120)

turtle.done()

# %% [markdown]
# ## Zauberformel 3
#
# **Was es ist:** Farben machen deine Grafiken lebendig und Füllungen geben ihnen Körper.
#
# **Wichtig:** Nutze `begin_fill()` und `end_fill()` für gefüllte Formen!

# %%
# Beispiel 1: Magische Farben und Füllungen
import turtle

screen = turtle.Screen()
screen.bgcolor("darkblue")
pen = turtle.Turtle()
pen.speed(3)

# Magischer Stern
pen.color("yellow", "orange")
pen.begin_fill()
for _ in range(5):
    pen.forward(100)
    pen.right(144)
pen.end_fill()

# Magischer Kreis
pen.penup()
pen.goto(150, 0)
pen.pendown()
pen.color("cyan", "lightblue")
pen.begin_fill()
pen.circle(50)
pen.end_fill()

turtle.done()
