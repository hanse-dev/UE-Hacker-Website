# %% [markdown]
# # ⭐ Missions – 💎 Week 2 – Data Types and Variables: The Four Magic Elements
#
# The time has come to prove your knowledge in real challenges!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: The Wizard's Treasure
#
# **Reward:** 300 XP + Crystal Ball
#
# An old wizard has hidden his treasure. Find it by decoding the clues!
#
# **Step 1 – Define hero name:**
# Create a variable for your hero name and create a variable for your hero ID (whole number)
#
# **Step 2 – Record treasure chests:**
# Store the number of chests as a whole number and store the gold per chest as a decimal number (e.g. 125.5)
#
# **Step 3 – Calculate total gold:**
# Multiply the chests by the gold per chest and store the result in a variable
#
# **Bonus:** Add a variable for magic dust per chest and calculate the total amount!

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: The Spell Book
#
# **Reward:** 400 XP + Magic Ink Pot
#
# You need to create a spell book with information about various spells!
#
# **Step 1 – Name the spells:**
# Create three variables for spell names as text and create three variables for damage values as whole numbers
#
# **Step 2 – Output spell protocol:**
# Output a heading `"=== SPELL BOOK ==="` and output each spell with name, damage and mana cost
#
# **Step 3 – Calculate total damage:**
# Add all damage values and store the sum in a variable
#
# **Step 4 – Determine average damage:**
# Add all damage values and divide by 3 and store the average in a variable
#
# **Bonus:** Calculate the average mana cost!

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: The Champion's Arena
#
# **Reward:** 500 XP + Champion Medal
#
# In the arena the best heroes compete. Calculate their statistics!
#
# **Step 1 – Create heroes:**
# Create for Hero 1: name, level, strength, intelligence and create for Hero 2: name, level, strength, intelligence
#
# **Step 2 – Calculate total stats:**
# Calculate for Hero 1: strength + intelligence and calculate for Hero 2: strength + intelligence
#
# **Step 3 – Determine the stronger hero:**
# Output both heroes with their total stats and compare the values and determine the stronger one
#
# **Step 4 – Output battle announcement:**
# Output a message about who is stronger and calculate the average strength of both heroes
#
#
# > 💡 **Tip:** You decide how to implement it – there is no single right way!
# **Bonus:** Calculate how much stronger the winner is!

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### 🎯 Learning goals – Have you achieved them?
#
# Tick what you can already do:
#
# - ☐ Use f-Strings for text formatting
# - ☐ Know and apply the four basic data types
# - ☐ Use `type()` and `len()`
# - ☐ Perform type conversions (`int()`, `float()`, `str()`)
# - ☐ Read input with `input()`
