# %% [markdown]
# # 🐛 Debug-Quest – 🚀 Woche 12 – Grafische Projekte mit Turtle: Die Hologramm-Projektoren der Nebula-7!
#
# Ein Techniker hat versucht, ein Hologramm zu erstellen, aber etwas läuft schief! Finde die Fehler:
# > 💡 **Diese Fehler wurden absichtlich eingebaut** – damit du das Debuggen üben kannst!

# %% [markdown]
# ### 🐛 Bug #1
#
# Was ist falsch? Finde und behebe den Fehler!

# %%
# Warum sieht man die Sterne nicht?
import turtle

screen = turtle.Screen()
screen.bgcolor("white")

stern = turtle.Turtle()
stern.color("white")  # Bug: weiß auf weißem Hintergrund!
stern.begin_fill()
stern.circle(5)
stern.end_fill()
turtle.done()

# %% [markdown]
# ### 🐛 Bug #2
#
# Was ist falsch? Finde und behebe den Fehler!

# %%
# Warum bewegt sich das Schiff nicht?
import turtle

schiff = turtle.Turtle()
schiff.shape("turtle")
schiff.color("red")
schiff.goto(-100, 0)
schiff.forward(200)
# Fehlt etwas?

# %% [markdown]
# ### 🐛 Bug #3
#
# Was ist falsch? Finde und behebe den Fehler!

# %%
# Warum ist der Ring unsichtbar?
import turtle

planet = turtle.Turtle()
planet.color("blue")
planet.penup()
planet.goto(0, -30)
planet.pendown()
planet.circle(30)
# Jetzt der Ring:
planet.penup()
planet.goto(0, -55)
planet.color("white")  # Bug: Ring ist weiß auf weißem Hintergrund!
planet.width(8)
planet.pendown()
planet.circle(55)
turtle.done()
