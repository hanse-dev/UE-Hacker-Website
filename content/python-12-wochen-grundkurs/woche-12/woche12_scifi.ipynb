# %% [markdown]
# # 🚀 Woche 12 – Grafische Projekte mit Turtle: Die Hologramm-Projektoren der Nebula-7!
#
# **XP zu verdienen:** 1200 Punkte
# **Boss:** Der Kommandant der Raumstation

# %% [markdown]
# ## 🌟 Die Quest beginnt: Willkommen an Bord der Nebula-7!
#
# Willkommen, Techniker der holografischen Künste! Du betrittst die **Hologramm-Projektoren der Nebula-7** – eine hochmoderne Raumstation, wo visuelle Daten und Weltraum-Szenen zum Leben erwachen!
#
# In dieser Woche meistert du die Kunst der sci-fi Visualisierung:
#
# **Deine Mission:**
# - Turtle für Weltraum-Szenen nutzen
# - Raumschiffe und Planeten zeichnen
# - Hologramm-Effekte erstellen
# - Interaktive Sternkarten bauen
#
# **Leg los!** Deine Reise zum Hologramm-Meister beginnt!

# %% [markdown]
# ## 📚 Zauberformel 1: Der Weltraum-Hintergrund
#
# **Was es ist:** Ein realistischer Weltraum-Hintergrund mit Sternen.
#
# **Warum nützlich:**
# - Atmosphärische Grundlage für Sci-Fi-Szenen
# - Tiefe und Dimension erzeugen
# - Perfekte Leinwand für andere Elemente
#
# **Wichtig:** Nutze Zufall für natürliche Sternenverteilung!

# %%
# Beispiel 1: Weltraum mit Sternen
import turtle
import random

# Erstelle das Hologramm-Fenster
screen = turtle.Screen()
screen.title("Hologramm-Projektor Nebula-7")
screen.bgcolor("black")
screen.setup(800, 600)

# Erstelle Sternen-Zeichner
stern = turtle.Turtle()
stern.speed(0)
stern.hideturtle()

# Zeichne zufällige Sterne
def zeichne_stern(x, y, größe):
    stern.penup()
    stern.goto(x, y)
    stern.pendown()
    stern.color("white")
    stern.begin_fill()
    for _ in range(5):
        stern.forward(größe)
        stern.right(144)
    stern.end_fill()

# Erstelle 100 zufällige Sterne
for _ in range(100):
    x = random.randint(-380, 380)
    y = random.randint(-280, 280)
    größe = random.randint(1, 5)
    zeichne_stern(x, y, größe)

turtle.done()

# %% [markdown]
# ## 📦 Zauberformel 2: Raumschiffe und Raumstationen
#
# **Was es ist:** Geometrische Formen, die wie Raumschiffe aussehen.
#
# **Warum nützlich:**
# - Zentrale Elemente in Sci-Fi-Szenen
# - Kombinierbar zu Flotten
# - Animierbar für Bewegungen
#
# **Wichtig:** Nutze Dreiecke und Trapeze für futuristische Looks!

# %%
# Beispiel 1: Ein einfaches Raumschiff
import turtle

screen = turtle.Screen()
screen.bgcolor("black")

# Raumschiff-Zeichner
schiff = turtle.Turtle()
schiff.speed(3)
schiff.color("silver")
schiff.pensize(2)

def zeichne_raumschiff(x, y):
    schiff.penup()
    schiff.goto(x, y)
    schiff.pendown()
    schiff.fillcolor("gray")
    schiff.begin_fill()
    
    # Hauptkörper
    schiff.forward(60)
    schiff.right(120)
    schiff.forward(40)
    schiff.right(60)
    schiff.forward(40)
    schiff.right(120)
    schiff.forward(60)
    
    schiff.end_fill()

# Zeichne das Raumschiff
zeichne_raumschiff(0, 0)

# Füge Fenster hinzu
schiff.penup()
schiff.goto(20, -10)
schiff.pendown()
schiff.color("cyan")
schiff.begin_fill()
schiff.circle(10)
schiff.end_fill()

turtle.done()

# %% [markdown]
# ## ✨ Zauberformel 3: Planeten und Monde
#
# **Was es ist:** Kreise mit Farben und Mustern als Himmelskörper.
#
# **Warum nützlich:**
# - Schöne visuelle Elemente
# - Zeigt Größenverhältnisse
# - Kann umkreist werden
#
# **Wichtig:** Nutze `circle()` für perfekte Planeten!

# %%
# Beispiel 1: Planetensystem
import turtle

screen = turtle.Screen()
screen.bgcolor("black")

# Planeten-Zeichner
planet = turtle.Turtle()
planet.speed(5)
planet.hideturtle()

# Sonne
planet.penup()
planet.goto(0, 0)
planet.pendown()
planet.color("yellow")
planet.begin_fill()
planet.fillcolor("orange")
planet.circle(50)
planet.end_fill()

# Planet 1
planet.penup()
planet.goto(150, 0)
planet.pendown()
planet.color("blue")
planet.begin_fill()
planet.fillcolor("lightblue")
planet.circle(20)
planet.end_fill()

# Planet 2 mit Ring
planet.penup()
planet.goto(-150, 0)
planet.pendown()
planet.color("brown")
planet.begin_fill()
planet.fillcolor("tan")
planet.circle(30)
planet.end_fill()

# Ring um Planet 2
planet.penup()
planet.goto(-150, -30)
planet.pendown()
planet.color("gray")
planet.width(3)
planet.circle(30, 360)

turtle.done()

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein Techniker hat versucht, ein Hologramm zu erstellen, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1: Sterne sind unsichtbar

# Warum sieht man die Sterne nicht?
import turtle

screen = turtle.Screen()
screen.bgcolor("white")

stern = turtle.Turtle()
stern.color("white")
stern.begin_fill()
stern.circle(5)
# Was ist falsch?

# %%
# 🐛 Bug #2: Raumschiff fliegt nicht

# Warum bewegt sich das Schiff nicht?
import turtle

schiff = turtle.Turtle()
schiff.shape("turtle")
schiff.color("red")
schiff.goto(-100, 0)
schiff.forward(200)
# Fehlt etwas?

# %%
# 🐛 Bug #3: Planet hat keinen Ring

# Warum wird der Ring nicht gezeichnet?
import turtle

planet = turtle.Turtle()
planet.penup()
planet.goto(0, 0)
planet.pendown()
planet.circle(50)
planet.penup()
planet.goto(0, -50)
planet.width(5)
planet.circle(50)
# Was fehlt?

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, deine holografischen Fähigkeiten in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Die Raumstation Nebula-7
#
# **Belohnung:** 350 Cyber Credits + Hologramm-Projektor
#
# Zeichne die beeindruckende Raumstation Nebula-7!
#
# **Deine Aufgaben:**
#
# 1. **Ringförmiges Modul zeichnen**
#    - Erstelle ein Turtle-Fenster mit dunklem Hintergrund (z.B. schwarz oder dunkelblau)
#    - Zeichne einen oder mehrere Kreise als Hauptstruktur der Station
#    - Nutze `circle()` und `penup()`/`pendown()` für die Position
#
# 2. **Solarpaneele und Andockstellen**
#    - Füge Rechtecke oder Linien als Solarpaneele an den Seiten hinzu
#    - Zeichne kleine Rechtecke oder Kreise als Andockstellen
#    - Platziere kurze Linien als Antennen
#
# 3. **Sci-Fi-Farben nutzen**
#    - Setze Farben mit `color()` und `fillcolor()`: z.B. Silber, Blau, Cyan
#    - Fülle mindestens eine Form mit `begin_fill()` und `end_fill()`
#
# **Beispiel-Code zum Starten:**
# ```python
# import turtle
# screen = turtle.Screen()
# screen.bgcolor("black")
# t = turtle.Turtle()
# t.speed(3)
# t.color("silver")
# t.circle(80)
# t.penup()
# t.goto(100, 0)
# t.pendown()
# t.color("cyan")
# t.circle(20)
# turtle.done()
# ```
#
# **Bonus-Challenge:** Füge blinkende Lichter mit Animation hinzu!
#
# **Erwartete Ausgabe:**
# ```
# Ein Fenster mit Raumstation: Ring-Modul, Solarpaneele, Andockstellen in Sci-Fi-Farben
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Die Flottenformation
#
# **Belohnung:** 450 Cyber Credits + Kommandanten-Abzeichen
#
# Erstelle eine komplette Raumflotte in Formation!
#
# **Deine Aufgaben:**
#
# 1. **Funktion für ein Raumschiff**
#    - Erstelle eine Funktion `zeichne_schiff(x, y, groesse)` die ein einfaches Schiff zeichnet (z.B. Dreieck oder Trapez)
#    - Das Schiff soll an der Position (x, y) mit der angegebenen Größe erscheinen
#
# 2. **Fünf Schiffe in V-Formation**
#    - Rufe die Funktion 5 Mal mit unterschiedlichen Positionen auf, sodass die Schiffe in V-Form angeordnet sind
#    - Nutze unterschiedliche Größen (z.B. das mittlere Schiff größer)
#
# 3. **Farbschema und Verbindungen**
#    - Setze ein einheitliches Farbschema (z.B. Silber/Cyan)
#    - Zeichne optional gepunktete Linien zwischen den Schiffen (mit `penup()`, kurze Striche in Schleife)
#
# **Beispiel-Code zum Starten:**
# ```python
# import turtle
# def zeichne_schiff(x, y, groesse):
#     t.penup()
#     t.goto(x, y)
#     t.pendown()
#     t.setheading(0)
#     for _ in range(3):
#         t.forward(groesse)
#         t.left(120)
# # V-Formation: 5 Positionen aufrufen
# turtle.done()
# ```
#
# **Bonus-Challenge:** Mache die Formation animiert mit `turtle.ontimer()` oder Schleifen!
#
# **Erwartete Ausgabe:**
# ```
# Ein Fenster mit 5 Raumschiffen in V-Formation, unterschiedliche Größen, einheitliches Farbschema
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Das interaktive Sonnensystem
#
# **Belohnung:** 550 Cyber Credits + Sternenkartographen-Zertifikat
#
# Baue ein komplettes, interaktives Sonnensystem!
#
# **Deine Aufgaben:**
#
# 1. **Sonne im Zentrum**
#    - Zeichne einen großen gefüllten Kreis als Sonne (z.B. gelb oder orange) in der Mitte
#    - Optional: Strahlen als kurze Linien rundherum
#
# 2. **Acht Planeten mit Umlaufbahnen**
#    - Zeichne für jeden Planeten einen Kreis als Umlaufbahn (ohne zu füllen, nur Linie)
#    - Platziere auf jeder Bahn einen gefüllten Kreis als Planet mit unterschiedlichen Größen und Farben
#
# 3. **Monde und Beschriftung**
#    - Füge bei mindestens einem Planeten einen kleinen Mond (kleiner Kreis) hinzu
#    - Beschrifte Sonne und mindestens 2 Planeten mit `turtle.write("Name", align="center")`
#
# **Beispiel-Code zum Starten:**
# ```python
# import turtle
# t = turtle.Turtle()
# t.speed(0)
# t.penup()
# t.goto(0, 0)
# t.pendown()
# t.fillcolor("orange")
# t.begin_fill()
# t.circle(40)
# t.end_fill()
# # Planeten: Kreis-Bahnen, dann Planeten-Kreise an verschiedenen Positionen
# turtle.done()
# ```
#
# **Bonus-Challenge:** Mache die Planeten umlaufbar mit Animation!
#
# **Erwartete Ausgabe:**
# ```
# Ein Fenster mit Sonne, 8 Planeten auf Umlaufbahnen, mindestens ein Mond, Beschriftungen
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten des Kommandanten (Reflexion)
#
# Bevor du weiterziehst, denke über diese Fragen nach:
#
# 1. **Wie macht man einfache Formen futuristisch?**
#
# 2. **Welche Farben erzeugen eine Sci-Fi-Atmosphäre?**
#
# 3. **Wie kann man Tiefe in 2D-Grafiken erzeugen?**
#
# Diskutiere deine Gedanken mit anderen Techniker!

# %% [markdown]
# ### 📖 Zauberspruch-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **Hologramm** 🌐: 3D-Projektion
# - **Raumstation** 🛸: Orbitale Basis
# - **Flotte** 🚀: Gruppe von Raumschiffen
# - **Planetensystem** 🪐: Sonne mit Planeten
# - **Umlaufbahn** ⭕: Planetenbahn
# - **Formation** 📐: Anordnung von Schiffen
# - **Sci-Fi** 🛰️: Science-Fiction
# - **Hintergrund** 🌌: Szene-Grundlage
# - **Vordergrund** 🔭: Nahe Elemente
# - **Perspektive** 👁️: Tiefenwahrnehmung
# - **Animation** ▶️: Bewegte Grafiken
# - **Interaktiv** 🖱️: Benutzer-Steuerung
# - **Farbschema** 🎨: Farb-Thema
# - **Geometrie** 📐: Formenlehre
# - **Komposition** 🖼️: Bildaufbau

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ✅ Turtle-Modul importieren und einrichten
# - ✅ Formen zeichnen und bewegen
# - ✅ Farben und Füllungen verwenden
# - ✅ Schleifen für Muster nutzen
# - ✅ Interaktive Grafik erstellen
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die Boss-Quests!

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Hervorragend!** Du hast die holografische Kunst gemeistert!
#
# **Das hast du gelernt:**
# - Sci-Fi-Szenen gestalten
# - Raumschiffe und Stationen bauen
# - Planetensysteme erstellen
# - Interaktive Sternkarten
# - Futuristische Designs
#
# **In der echten Welt werden diese Techniken verwendet für:**
# - 🎮 **Spiele:** Sci-Fi-UI und Weltraum-Szenen
# - 📺 **Filme:** Konzept-Kunst und Storyboards
# - 📊 **Daten-Vis:** Zukunfts-Visualisierungen
# - 🎓 **Bildung:** Astronomie-Unterricht
# - 🚀 **NASA:** Mission-Visualisierungen
#
# **Als Nächstes:** Du bist bereit für deine eigenen Sci-Fi-Projekte!

# %% [markdown]
# ## 🐉 Boss-Kampf: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Quests sind extrem schwierig! Sie kombinieren alle Turtle-Konzepte.
#
# **Belohnungen:** Insgesamt 1800 XP + epische Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Die komplette Galaxie-Karte
#
# **Belohnung:** 600 Cyber Credits + Galaktische Karte
#
# Erstelle eine detaillierte Karte der gesamten Galaxie!
#
# **Deine Aufgaben:**
#
# **1. Erstelle den Galaxie-Hintergrund:**
#    - Spiralarme mit Kurven
#    - Tausende von Sternen
#    - Nebel-Wolken mit Farben
#    - Zentrales schwarzes Loch
#
# **2. Platziere Sternensysteme:**
#    - 50 verschiedene Systeme
#    - Jedes mit eigener Farbe
#    - Verschiedene Größen
#    - Namen für wichtige Systeme
#
# **3. Füge Handelsrouten hinzu:**
#    - Linien zwischen Systemen
#    - Verschiedene Routen-Typen
#    - Farbcodierung nach Sicherheit
#    - Animierter Verkehr (optional)
#
# **4. Implementiere eine Legende:**
#    - Symbole für System-Typen
#    - Farbcodes für Fraktionen
#    - Skala für Entfernungen
#    - Kompass-Rose
#
# **5. Interaktive Features:**
#    - Klick zeigt System-Details
#    - Zoom-Funktion
#    - Suchfunktion für Namen
#
# **Beispiel-Struktur:**
# ```python
# # So könntest du beginnen:
# import turtle
# import random
#
# class GalaxieKarte:
#     def __init__(self):
#         self.screen = turtle.Screen()
#         self.setup_galaxie()
#         self.systeme = []
#
#     def erstelle_spiralarm(self):
#         # Spiralarm zeichnen
#         pass
#
#     def platziere_system(self, x, y, typ):
#         # Sternensystem platzieren
#         pass
#
# # Hauptprogramm
# karte = GalaxieKarte()
# # ... weiterer Code
# ```
#
# **Bonus-Challenge:** Füge rotierende Galaxie-Arme mit Animation hinzu!
#
# **Erwartete Ausgabe:**
# ```
# Ein Fenster mit Galaxie-Hintergrund, Sternensystemen, Handelsrouten, Legende und optional interaktiven Features
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Die epische Raum-Schlacht
#
# **Belohnung:** 800 Cyber Credits + Szepter der Flotten-Kommandanten
#
# Erstelle eine animierte Raum-Schlacht mit zwei Flotten!
#
# **Deine Aufgaben:**
#
# **1. Erstelle zwei Flotten-Klassen:**
#    - Föderation (blau/silber)
#    - Klingonen (rot/schwarz)
#    - Jede mit 10 Schiffen
#    - Verschiedene Schiffstypen
#
# **2. Implementiere Bewegungssysteme:**
#    - Jedes Schiff bewegt sich unabhängig
#    - Formationsflug
#    - Angriffsmuster
#    - Ausweichmanöver
#
# **3. Füge Kampf-Effekte hinzu:**
#    - Laserstrahlen als Linien
#    - Explosionen als gelbe Kreise
#    - Rauchwolken als graue Flecken
#    - Schild-Effekte als Blasen
#
# **4. Baue ein Kampfsystem:**
#    - Treffer-Erkennung
#    - Schadensberechnung
#    - Schiff-Zerstörung
#    - Sieger-Bestimmung
#
# **5. Erstelle HUD-Elemente:**
#    - Lebensbalken für Flotten
#    - Punktestand
#    - Timer
#    - Kampfstatistiken
#
# **Beispiel-Struktur:**
# ```python
# # So könntest du beginnen:
# import turtle
# import random
# import time
#
# class Raumschiff:
#     def __init__(self, x, y, team):
#         self.turtle = turtle.Turtle()
#         self.team = team
#         self.leben = 100
#         self.x = x
#         self.y = y
#
#     def bewege(self):
#         # Bewegungslogik
#         pass
#
#     def schieße(self, ziel):
#         # Schuss-Animation
#         pass
#
# class RaumSchlacht:
#     def __init__(self):
#         self.föderation = []
#         self.klingonen = []
#
#     def starte_schlacht(self):
#         # Haupt-Schlacht-Loop
#         pass
#
# # Hauptprogramm
# schlacht = RaumSchlacht()
# # ... weiterer Code
# ```
#
# **Bonus-Challenge:** Füge Power-ups und Spezial-Waffen hinzu!
#
# **Erwartete Ausgabe:**
# ```
# Ein Fenster mit zwei Flotten, animierter Schlacht, Schüssen und optional Power-ups
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 3: Der interaktive Hologramm-Editor
#
# **Belohnung:** 400 Cyber Credits + Codex des Hologramm-Meisters
#
# Erstelle einen Editor für eigene Hologramm-Szenen!
#
# **Deine Aufgaben:**
#
# **1. Baue einen Werkzeugkasten:**
#    - Buttons für verschiedene Objekte
#    - Farbauswahl-Palette
#    - Größen-Einstellungen
#    - Rotations-Steuerung
#
# **2. Implementiere Zeichen-Modi:**
#    - Platzieren-Modus für Objekte
#    - Verschieben-Modus
#    - Löschen-Modus
#    - Verbinden-Modus
#
# **3. Erstelle eine Objekt-Bibliothek:**
#    - Raumschiffe (5 Typen)
#    - Planeten (mit Ringen)
#    - Raumstationen
#    - Asteroiden
#    - Nebel-Effekte
#
# **4. Füge Animationen hinzu:**
#    - Umlauf-Animation für Planeten
#    - Blink-Lichter für Stationen
#    - Flug-Animationen für Schiffe
#    - Partikel-Effekte
#
# **5. Speicher/Lade-System:**
#    - Speichere Szenen als JSON
#    - Lade vorherige Szenen
#    - Export als Bild
#    - Teilen mit anderen
#
# **Beispiel-Struktur:**
# ```python
# # So könntest du beginnen:
# import turtle
# import json
#
# class HologrammEditor:
#     def __init__(self):
#         self.screen = turtle.Screen()
#         self.setup_ui()
#         self.objekte = []
#         self.modus = "platzieren"
#         self.aktuelles_objekt = "schiff"
#
#     def setup_ui(self):
#         # UI-Elemente erstellen
#         self.screen.onclick(self.klick_handler)
#         self.screen.onkey(self.speichern, "s")
#         self.screen.listen()
#
#     def klick_handler(self, x, y):
#         # Maus-Klick verarbeiten
#         pass
#
#     def zeichne_ui(self):
#         # Benutzeroberfläche zeichnen
#         pass
#
# # Hauptprogramm
# editor = HologrammEditor()
# # ... weiterer Code
# ```
#
# **Bonus-Challenge:** Füge 3D-Effekte mit Perspektive hinzu!
#
# **Erwartete Ausgabe:**
# ```
# Ein Fenster mit Werkzeugkasten, Zeichen-Modi, Objekt-Bibliothek, Animationen und optional Speicher/Lade
# ```

# %%
# 🐉 Deine Lösung hier:

print()
print("🎉 +400 XP: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Kommandanten besiegt!")
print("⭐ Titel erhalten: Hologramm-Meister der Nebula-7")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 12 gemeistert!")
print("📚 Nächste Woche: Deine eigenen Projekte!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen:

# %%
# ✅ Lösung Bug #1: Sterne sind unsichtbar

# Problem: Schwarze Sterne auf weißem Grund
import turtle

screen = turtle.Screen()
screen.bgcolor("black")  # Schwarzer Hintergrund

stern = turtle.Turtle()
stern.color("yellow")  # Gelbe Sterne
stern.begin_fill()
stern.fillcolor("white")  # Weiße Füllung
stern.circle(5)
stern.end_fill()
turtle.done()

# %%
# ✅ Lösung Bug #2: Raumschiff fliegt nicht

# Problem: turtle.done() fehlt
import turtle

schiff = turtle.Turtle()
schiff.shape("turtle")
schiff.color("red")
schiff.penup()  # Stift heben
schiff.goto(-100, 0)
schiff.forward(200)
turtle.done()  # Fehlende Zeile

# %%
# ✅ Lösung Bug #3: Planet hat keinen Ring

# Problem: pendown() fehlt für den Ring
import turtle

planet = turtle.Turtle()
planet.penup()
planet.goto(0, 0)
planet.pendown()
planet.circle(50)
planet.penup()
planet.goto(0, -50)
planet.pendown()  # Fehlende Zeile
planet.width(5)
planet.circle(50)
turtle.done()
