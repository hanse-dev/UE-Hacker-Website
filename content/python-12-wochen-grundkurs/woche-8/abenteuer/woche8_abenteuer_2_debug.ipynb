# %% [markdown]
# # 🐛 Debug-Quest – ⚔️ Woche 8 – Dictionaries und Tupel: Steckbriefe und Artefakte
#
# Ein Archivarius hat versucht, die Steckbriefe zu pflegen, aber etwas läuft schief! Finde die Fehler:
# > 💡 **Diese Fehler wurden absichtlich eingebaut** – damit du das Debuggen üben kannst!

# %% [markdown]
# ### 🐛 Bug #1
#
# Was ist falsch? Finde und behebe den Fehler!

# %%
held = {
    "name": "Aria",
    "klasse": "Magierin"
}
print(f"Held: {held}")

# %% [markdown]
# ### 🐛 Bug #2
#
# Was ist falsch? Finde und behebe den Fehler!

# %%
koordinaten = (100, 200)
koordinaten[0] = 150

# %% [markdown]
# ### 🐛 Bug #3
#
# Was ist falsch? Finde und behebe den Fehler!

# %%
helden = [
    {"name": "Aria", "klasse": "Magierin"},
    {"name": "Thorin", "klasse": "Krieger"}
]
print(helden[2])
