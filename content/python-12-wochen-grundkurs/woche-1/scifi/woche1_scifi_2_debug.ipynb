# %% [markdown]
# # 🐛 Debug-Quest – 🚀 Woche 1 – Einführung und erstes Programm: Startsequenz
#
# > 📖 Vorher: `…_1_lektion` durcharbeiten

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein junger Techniker hat versucht, die ersten Befehle auszuführen, aber etwas läuft schief! Finde die Fehler:

# %% [markdown]
# ### 🐛 Bug #1
#
# **Was passiert:** Python liest `System` und `online` als Variablennamen – aber diese Variablen gibt es nicht. Text muss immer in Anführungszeichen stehen, damit Python weiß: das ist Text, keine Variable.

# %%
# 🐛 Bug #1: Fehlende Anführungszeichen

print(System online)

# %% [markdown]
# ### 🐛 Bug #2
#
# **Was passiert:** `level` ist eine Zahl (Integer), der Text davor ist ein String. Python kann diese zwei Typen nicht direkt mit `+` verbinden – das ist wie versuchen, einen Stein an einen Faden zu knoten. `str()` löst das: es verwandelt die Zahl in Text.

# %%
# 🐛 Bug #2: Zahl ohne str()

level = 3
print("Sicherheitsstufe: " + level)

# %% [markdown]
# ### 🐛 Bug #3
#
# **Was passiert:** Die Variable heißt `status`, aber im `print()` steht `statu` – ein Buchstabe fehlt. Python sucht exakt nach dem Namen `statu` und findet ihn nicht. Tippfehler in Variablennamen sind einer der häufigsten Anfängerfehler!

# %%
# 🐛 Bug #3: Falsche Variable

status = "Aktiv"
print("Systemstatus: " + statu)
