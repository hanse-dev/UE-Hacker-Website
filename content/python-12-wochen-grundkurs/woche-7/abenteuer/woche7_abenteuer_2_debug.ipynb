# %% [markdown]
# # 🐛 Debug-Quest – ⚔️ Woche 7 – Module und Bibliotheken: Die magischen Werkzeugkästen!
#
# > 📖 Vorher: `…_1_lektion` durcharbeiten

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein Lehrling hat versucht, die Zauber zu verwenden, aber etwas läuft schief! Finde die Fehler:

# %% [markdown]
# ### 🐛 Bug #1
#
# **Was passiert:** `math` wurde noch nicht importiert. Vor dem Benutzen muss das Modul mit `import math` geladen werden.

# %%
# 🐛 Bug #1

result = math.sqrt(9)
print(f"Ergebnis: {result}")

# %% [markdown]
# ### 🐛 Bug #2
#
# **Was passiert:** Diese Methode oder Eigenschaft gibt es nicht. Vielleicht ist der Name falsch geschrieben?

# %%
# 🐛 Bug #2

import random
zahl = random.zahl(1, 10)
print(f"Zufallszahl: {zahl}")

# %% [markdown]
# ### 🐛 Bug #3
#
# **Was passiert:** Python kennt `sin` nicht. Entweder ist der Name falsch geschrieben, oder die Variable wurde noch nicht angelegt.

# %%
# 🐛 Bug #3

import math
winkel = 90
sinus = sin(math.radians(winkel))
print(f"Sinus von {winkel}°: {sinus}")
