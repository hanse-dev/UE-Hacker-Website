# %% [markdown]
# # 🚀 Woche 1 – Einführung und erstes Programm: Startsequenz
#
# **Cyber Credits zu verdienen:** 1000 Punkte
# **Herausforderung:** Der KI-Virus der stummen Terminals

# %% [markdown]
# ## 🌟 Die Mission beginnt: Willkommen an Bord der Nebula-7
#
# Willkommen, Kommandant:in! Du betrittstest die hochmoderne **Raumstation Nebula-7** – ein Zentrum für technologische Innovationen und interstellare Abenteuer. In dieser Woche lernst du die vier wichtigsten Systemprotokolle:
#
# **Deine Mission:**
# - Lerne, wie du Text mit `print()` ausgibst
# - Speichere Informationen in **Variablen**
# - Kombiniere Texte und Variablen zu Nachrichten
# - Füge Kommentare hinzu, um deinen Code zu erklären
#
# **Leg los!** Dein nächster Befehl wartet schon...

# %% [markdown]
# ## 🔬 Was ist ein Systemprotokoll?
#
# Ein **Systemprotokoll** ist wie ein Befehlssatz für die Raumstation - eine festgelegte Anweisung, die der Computer verstehen und ausführen kann.
#
# **Stell dir vor:**
# - 📡 Die Kommandobrücke sendet Protokolle an die Schiffs-Systeme
# - 🤖 Jedes Protokoll hat eine spezifische Funktion und Syntax
# - ⚡ Die Systeme führen die Befehle präzise aus
# - 📊 Ohne Protokolle würde die Kommunikation zusammenbrechen
#
# **In der Programmierung lernen wir:**
# - Die grundlegenden Protokolle (Befehle) von Python
# - Wie man diese Protokolle kombiniert
# - Wie man eigene Protokolle erstellt (später)
#
# **Jedes Systemprotokoll, das du lernst, ist wie ein neues Werkzeug für dein Raumschiff!**

# %% [markdown]
# ## 📚 Systemprotokoll 1: Der `print()`-Befehl
#
# **Was es ist:** `print()` ist dein erster Befehl. Er gibt Text auf dem Bildschirm aus.
#
# **Warum nützlich:**
# - 🖥️ Sendet Nachrichten an das Terminal
# - 📡 Überträgt Statusmeldungen
# - 🗺️ Erstellt Navigationsanzeigen
# - 📖 Protokolliert Missionen
#
# **Wichtig:** Text muss immer in Anführungszeichen `"` oder `'` stehen!

# %%
# Beispiel 1: Einfache Textausgabe
print("Hallo Welt!")
print("Willkommen an Bord der Nebula-7!")

# Beispiel 2: Mehrere Zeilen
print("Dies ist dein erster Einsatz.")
print("Du bist jetzt Kommandant:in!")

# Beispiel 3: Leere Zeile für bessere Übersicht
print()
print("=== SYSTEM STARTET ===")

# %% [markdown]
# ## 🤖 Systemprotokoll 2: Variablen - Datenspeicher
#
# **Was es ist:** Eine Variable ist wie ein Datenspeicher mit Namen. Du kannst Informationen darin speichern und später wieder abrufen.
#
# **Warum nützlich:**
# - 💾 Speichert Schiffsdaten
# - 🚀 Merkt sich Koordinaten
# - 🔧 Bewahrt Konfigurationen
# - 🔄 Kann jederzeit aktualisiert werden
#
# **Wichtig:**
# - Text: in Anführungszeichen (`"Alpha"`)
# - Zahlen: ohne Anführungszeichen (`42`)

# %%
# Beispiel 1: Verschiedene Variablentypen
schiff_name = "Enterprise"    # Text (String)
besatzung = 150              # Zahl (Integer)
geschwindigkeit = 5          # Zahl (Integer)
system_online = True         # Wahrheitswert (Boolean)

# Beispiel 2: Variablen ausgeben
print("Schiffsname:")
print(schiff_name)
print("Besatzung:")
print(besatzung)
print("Lichtgeschwindigkeit:")
print(geschwindigkeit)

# Beispiel 3: Variablen können sich ändern
print("Energie vor dem Sprung: " + str(80) + "%")
energie = 45  # Nach Sprung
print("Energie nach dem Sprung: " + str(energie) + "%")

# %% [markdown]
# ## 🛸 Systemprotokoll 3: Texte kombinieren
#
# **Was es ist:** Mit `+` kannst du Texte und Variablen zu einer Nachricht verbinden.
#
# **Warum nützlich:**
# - 📡 Erstellt Statusberichte
# - 🗺️ Kombiniert Koordinaten mit Beschreibungen
# - ⚔️ Verbindet Waffennamen mit ihrer Stärke
# - 📊 Macht Ausgaben informativer
#
# **Wichtig:** Zahlen müssen mit `str()` in Text umgewandelt werden!

# %%
# Beispiel 1: Einfache Kombination
pilot = "Kirk"
rang = "Captain"
print("Name: " + pilot)
print("Rang: " + rang)

# Beispiel 2: Mit Zahlen (str() nötig!)
mission = 5
print("Mission Nummer: " + str(mission))

# Beispiel 3: Komplexe Sätze
print(pilot + " ist " + rang + " der Mission " + str(mission))

# Beispiel 4: Mehrere Informationen
print()
print("=== MISSIONSPROFIL ===")
print("Captain: " + pilot)
print("Mission: " + str(mission))
print("Status: Aktiv")
print("=======================")

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein junger Techniker hat versucht, die ersten Befehle auszuführen, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1: Fehlende Anführungszeichen

print(System online)

# %%
# 🐛 Bug #2: Zahl ohne str()

level = 3
print("Sicherheitsstufe: " + level)

# %%
# 🐛 Bug #3: Falsche Variable

status = "Aktiv"
print("Systemstatus: " + statu)

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Kadett
#
# **Belohnung:** 300 Cyber Credits + Datenpad
#
# Deine erste Mission! Zeige, dass du die Grundbefehle der Raumstation beherrschst.
#
# **Deine Aufgaben:**
#
# 1. **Persönliche Daten ausgeben**
#    - Gib deinen Namen mit `print()` aus
#    - Gib eine Begrüßung für die Raumstation aus
#    - Füge eine leere Zeile für bessere Übersicht ein
#
# 2. **Dienstnummer speichern**
#    - Erstelle eine Variable für deine Dienstnummer
#    - Gib die Dienstnummer in einem vollständigen Satz aus
#    - Nutze `str()` um die Zahl in Text umzuwandeln
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Name ausgeben
# print("Kommandant: [Dein Name]")
#
# # 2. Dienstnummer speichern
# dienstnummer = 1001
# print("Dienstnummer: " + str(dienstnummer))
# ```
#
# **Bonus-Challenge:**
# - Gib dein Lieblingszitat aus der Raumfahrt aus!
#
# **Erwartete Ausgabe:**
# ```
# Kommandant: Alex
# Willkommen an Bord der Nebula-7!
#
# Dienstnummer: 1001
# Bereit für den Einsatz!
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Datentechniker
#
# **Belohnung:** 400 Cyber Credits + Scanner
#
# Du musst wichtige Schiffsdaten protokollieren. Sei präzise und folge dem Format!
#
# **Deine Aufgaben:**
#
# 1. **Schiffsdaten erstellen**
#    - Erstelle eine Variable für den Schiffstyp (Text)
#    - Erstelle eine Variable für die Registrierungsnummer (Text)
#    - Erstelle eine Variable für die Crew-Größe (Zahl)
#
# 2. **Daten strukturiert ausgeben**
#    - Gib eine Überschrift "=== SCHIFFSPROTOKOLL ===" aus
#    - Gib jeden Wert mit Beschreibung in einer eigenen Zeile aus
#    - Nutze `str()` für die Crew-Größe
#
# 3. **Vollständigen Bericht erstellen**
#    - Erstelle einen Satz, der alle drei Informationen kombiniert
#    - Füge eine Abschlusszeile "=== ENDE PROTOKOLL ===" hinzu
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Schiffsdaten erstellen
# schiffstyp = "Fregatte"
# registrierung = "NX-2401"
# crew_groesse = 85
#
# # 2. Protokoll ausgeben
# print("=== SCHIFFSPROTOKOLL ===")
# print("Typ: " + schiffstyp)
# ```
#
# **Bonus-Challenge:**
# - Füge das Baujahr des Schiffes hinzu!
#
# **Erwartete Ausgabe:**
# ```
# === SCHIFFSPROTOKOLL ===
# Typ: Fregatte
# Registrierung: NX-2401
# Crew: 85
#
# Die Fregatte NX-2401 hat eine Crew von 85 Personen.
# === ENDE PROTOKOLL ===
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Der Shuttle-Pilot
#
# **Belohnung:** 500 Cyber Credits + Pilotenabzeichen
#
# Ein wichtiger Transporteinsatz wartet! Erstelle ein komplettes Flugprotokoll.
#
# **Deine Aufgaben:**
#
# 1. **Flugdaten sammeln**
#    - Erstelle eine Variable für die Shuttle-Nummer
#    - Erstelle eine Variable für das Ziel
#    - Erstelle eine Variable für die Flugdauer (in Stunden)
#    - Erstelle eine Variable für die Passagieranzahl
#    - Erstelle eine Variable für den Pilot-Namen
#
# 2. **Protokoll-Kopf erstellen**
#    - Gib eine Überschrift "=== FLUGPROTOKOLL ===" aus
#    - Füge eine leere Zeile ein
#    - Gib alle Flugdaten strukturiert aus
#
# 3. **Missionsbeschreibung formulieren**
#    - Erstelle 3 vollständige Sätze über den Flug
#    - Kombiniere verschiedene Variablen in den Sätzen
#    - Nutze `str()` für alle Zahlen
#
# 4. **Countdown zum Start**
#    - Gib "Start in:" aus
#    - Gib "3... 2... 1... Start!" aus
#    - Beende mit "Guten Flug!"
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Flugdaten sammeln
# shuttle_nummer = 7
# ziel = "Mars-Station Alpha"
# flugdauer = 4
# passagiere = 12
# pilot = "Commander Silva"
#
# # 2. Protokoll ausgeben
# print("=== FLUGPROTOKOLL ===")
# print()
# print("Shuttle: " + str(shuttle_nummer))
# ```
#
# **Bonus-Challenge:**
# - Füge die Zielkoordinaten (X, Y, Z) hinzu!
#
# **Erwartete Ausgabe:**
# ```
# === FLUGPROTOKOLL ===
#
# Shuttle: 7
# Ziel: Mars-Station Alpha
# Flugdauer: 4 Stunden
# Passagiere: 12
# Pilot: Commander Silva
#
# Shuttle 7 fliegt zur Mars-Station Alpha.
# Die Flugdauer beträgt 4 Stunden.
# Commander Silva transportiert 12 Passagiere.
#
# Start in:
# 3... 2... 1... Start!
# Guten Flug!
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten der Missionsleiterin (Reflexion)
#
# Bevor du weiterfliegst, denke über diese Fragen nach:
#
# 1. **Warum müssen Texte immer in Anführungszeichen?**
#
# 2. **Was passiert, wenn du versuchst, eine Zahl direkt mit Text zu verbinden?**
#
# 3. **Wie können Variablen dir bei Weltraummissionen helfen?**
#
# Diskutiere deine Gedanken mit anderen Kommandant:innen!

# %% [markdown]
# ### 📖 Tech-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **print()** 🖥️: Befehl zur Textausgabe
# - **Variable** 💾: Datenspeicher für Informationen
# - **String** 📝: Text in Anführungszeichen
# - **Integer** 🔢: Ganze Zahl ohne Komma
# - **Boolean** ✅: Wahrheitswert (True/False)
# - **Verkettung** ⛓️: Verbinden von Texten mit `+`
# - **str()** 🔄: Wandelt Zahlen in Text um
# - **Kommentar** 📋: Erklärung im Code mit `#`
# - **Syntax** 📐: Regeln für korrekten Code
# - **Fehler** 🐛: Wenn der Code nicht funktioniert
# - **Debugging** 🔧: Fehler finden und beheben
# - **Ausgabe** 📺: Was auf dem Bildschirm erscheint

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ✅ Text mit `print()` ausgeben
# - ✅ Informationen in Variablen speichern
# - ✅ Texte mit `+` und `str()` kombinieren
# - ✅ Kommentare mit `#` hinzufügen
# - ✅ Einfache Fehler finden und beheben
# - ✅ Eigene kleine Programme schreiben
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die finalen Herausforderungen!

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Mission
#
# **Exzellent!** Du hast die Grundlagen der Programmierung gemeistert!
#
# **Das hast du gelernt:**
# - Wie du dem Computer mit `print()` Befehle gibst
# - Wie du Informationen in Variablen speicherst
# - Wie du Texte und Zahlen kombinierst
# - Wie du deinen Code mit Kommentaren erklärst
# - Wie du einfache Fehler selbst findest
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🚀 **Raumfahrt:** Anzeigen von Telemetriedaten
# - 🤖 **Robotik:** Steuerungsbefehle und Statusmeldungen
# - 💻 **KI-Entwicklung:** Trainingsergebnisse und Logs
# - 🛰️ **Satellitentechnik:** Übertragungsprotokolle
# - 🌌 **Astrophysik:** Simulationsergebnisse
#
# **Als Nächstes:** In Woche 2 lernst du **Datentypen und Variablen**!

# %% [markdown]
# ## 🐉 Finale Herausforderung: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Missionen sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 Cyber Credits + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Das Schiffslogbuch
#
# **Belohnung:** 500 Cyber Credits + Quantenschreiber
#
# Erstelle ein offizielles Schiffslogbuch für die Sternenflotte-Archive!
#
# **Deine Aufgaben:**
#
# 1. **Gedicht verfassen**
#    - Schreibe 4 Zeilen über die Raumfahrt
#    - Lege für jede Zeile eine eigene Variable an
#    - Die Zeilen sollten zusammen ein Gedicht ergeben
#
# 2. **Metadaten erstellen**
#    - Erstelle eine Variable für den Titel des Gedichts
#    - Erstelle eine Variable für deinen Namen als Autor
#    - Erstelle eine Variable für die Bewertung (1-5 Sterne)
#
# 3. **Gedicht formatiert ausgeben**
#    - Gib den Titel als Überschrift aus
#    - Gib eine Trennlinie aus
#    - Gib alle vier Zeilen untereinander aus
#    - Füge eine leere Zeile ein
#
# 4. **Metadaten hinzufügen**
#    - Gib "Autor: [Name]" aus
#    - Gib "Bewertung: [Sterne] Sterne" aus
#    - Gib einen Satz aus, warum Raumfahrt wichtig ist
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Gedicht erstellen
# zeile1 = "Durch die Sterne fliegen wir"
# zeile2 = "Unendliche Weiten vor uns"
# zeile3 = "Neue Welten zu entdecken"
# zeile4 = "Das ist unser Auftrag"
#
# # 2. Metadaten
# titel = "Die Reise"
# autor = "Dein Name"
# bewertung = 5
#
# # 3. Ausgabe
# print("=== " + titel + " ===")
# print("---")
# ```
#
# **Bonus-Challenge:**
# - Füge eine geheime Botschaft als Kommentar hinzu!
#
# **Erwartete Ausgabe:**
# ```
# === Die Reise ===
# ---
# Durch die Sterne fliegen wir
# Unendliche Weiten vor uns
# Neue Welten zu entdecken
# Das ist unser Auftrag
#
# Autor: Alex Raumfahrer
# Bewertung: 5 Sterne
# Raumfahrt verbindet die Menschheit und erweitert unseren Horizont.
# ```

# %%
# 🚀 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Der KI-Virus
#
# **Belohnung:** 600 Cyber Credits + Antivirus-Protokoll
#
# Ein KI-Virus hat die Terminals lahmgelegt! Nur perfekter Code kann das System retten.
#
# **Deine Aufgaben:**
#
# 1. **Antivirus-Programm entwickeln**
#    - Erstelle Variablen für 3 Bereinigungsschritte
#    - Jeder Schritt sollte eine klare Beschreibung haben
#    - Nummeriere die Schritte (Schritt 1, 2, 3)
#
# 2. **Schritte dokumentieren**
#    - Gib eine Überschrift "=== ANTIVIRUS-PROTOKOLL ===" aus
#    - Gib jeden Schritt mit seiner Nummer und Beschreibung aus
#    - Füge zwischen den Schritten leere Zeilen ein
#
# 3. **Bereinigungscode ausgeben**
#    - Erstelle eine Variable für den Bereinigungscode
#    - Gib "Bereinigungscode: [Code]" aus
#    - Der Code sollte eine Kombination aus Buchstaben und Zahlen sein
#
# 4. **Warnung und Erfolgsmeldung**
#    - Gib eine Warnung vor zukünftigen Infektionen aus
#    - Gib "System wird bereinigt..." aus
#    - Gib "Bereinigung erfolgreich!" aus
#    - Gib "Alle Systeme wieder online!" aus
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Bereinigungsschritte erstellen
# schritt1 = "Virus-Signatur identifizieren"
# schritt2 = "Infizierte Dateien isolieren"
# schritt3 = "System-Integrität wiederherstellen"
#
# # 2. Protokoll ausgeben
# print("=== ANTIVIRUS-PROTOKOLL ===")
# print()
# print("Schritt 1: " + schritt1)
# ```
#
# **Bonus-Challenge:**
# - Füge eine Statusanzeige als Fortschrittsbalken hinzu (z.B. [####------] 40%)!
#
# **Erwartete Ausgabe:**
# ```
# === ANTIVIRUS-PROTOKOLL ===
#
# Schritt 1: Virus-Signatur identifizieren
# Schritt 2: Infizierte Dateien isolieren
# Schritt 3: System-Integrität wiederherstellen
#
# Bereinigungscode: AV-7X9K2
#
# WARNUNG: Installieren Sie regelmäßige Sicherheitsupdates!
#
# System wird bereinigt...
# Bereinigung erfolgreich!
# Alle Systeme wieder online!
# ```

# %%
# 🚀 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Das Wurmloch
#
# **Belohnung:** 400 Cyber Credits + Wurmloch-Koordinaten
#
# Ein mysteriöses Wurmloch ist aufgetaucht! Erstelle ein wissenschaftliches Protokoll.
#
# **Deine Aufgaben:**
#
# 1. **Wurmloch beschreiben**
#    - Erstelle eine Variable für die Farbe des Wurmlochs
#    - Erstelle eine Variable für die Form
#    - Erstelle eine Variable für die Größe (in Kilometern)
#    - Gib alle drei Eigenschaften strukturiert aus
#
# 2. **Messdaten protokollieren**
#    - Erstelle eine Variable für die Energiesignatur
#    - Erstelle eine Variable für die Stabilität (in Prozent)
#    - Erstelle eine Variable für die Entfernung (in Lichtjahren)
#    - Gib alle Messwerte mit Einheiten aus
#
# 3. **Warnung und Navigation**
#    - Gib eine Überschrift "=== NAVIGATIONSWARNUNG ===" aus
#    - Erstelle eine Warnung für vorbeifliegende Schiffe
#    - Liste 3 mögliche Reiseziele durch das Wurmloch auf
#    - Gib eine Anweisung für die sichere Rückkehr
#
# 4. **Wissenschaftliche Frage**
#    - Formuliere eine theoretische Frage über Wurmlöcher
#    - Gib die Frage am Ende aus
#    - Beende mit "Weitere Forschung erforderlich."
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Wurmloch-Eigenschaften
# farbe = "Violett"
# form = "Spiralförmig"
# groesse = 500
#
# # 2. Messdaten
# energiesignatur = "Hoch"
# stabilitaet = 78
# entfernung = 2.5
#
# # 3. Ausgabe
# print("=== WURMLOCH-PROTOKOLL ===")
# print()
# print("Farbe: " + farbe)
# ```
#
# **Bonus-Challenge:**
# - Kodiere eine Botschaft für andere Zivilisationen in Binärcode!
#
# **Erwartete Ausgabe:**
# ```
# === WURMLOCH-PROTOKOLL ===
#
# Farbe: Violett
# Form: Spiralförmig
# Größe: 500 km
#
# Energiesignatur: Hoch
# Stabilität: 78%
# Entfernung: 2.5 Lichtjahre
#
# === NAVIGATIONSWARNUNG ===
# ACHTUNG: Wurmloch mit hoher Energiesignatur detektiert!
#
# Mögliche Ziele:
# - Andromeda-Sektor
# - Gamma-Quadrant
# - Unbekannte Region 47
#
# Rückkehr-Anweisung: Koordinaten speichern und Rückkehr-Beacon aktivieren!
#
# Frage: Können Wurmlöcher als stabile Transportwege genutzt werden?
# Weitere Forschung erforderlich.
# ```

# %%
# 🚀 Deine Lösung hier:

print()
print("🎉 +400 Cyber Credits: Mission abgeschlossen!")
print("🏆 Du hast den KI-Virus besiegt!")
print("⭐ Titel erhalten: System-Administrator")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 1 gemeistert!")
print("🚀 Nächste Woche: Datentypen und Variablen!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen:

# %%
# ✅ Lösung Bug #1: Fehlende Anführungszeichen

# Problem: Text ohne Anführungszeichen
print("System online")

# %%
# ✅ Lösung Bug #2: Zahl ohne str()

# Problem: Zahl kann nicht direkt mit Text verbunden werden
level = 3
print("Sicherheitsstufe: " + str(level))

# %%
# ✅ Lösung Bug #3: Falsche Variable

# Problem: Variable 'statu' existiert nicht
status = "Aktiv"
print("Systemstatus: " + status)
