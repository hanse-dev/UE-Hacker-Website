# %% [markdown]
# # 🐛 Debug-Quest – 🚀 Woche 7 – Module und Bibliotheken: Die Modul-Banken der Raumstation
#
# Ein Techniker hat versucht, die Module zu verwenden, aber etwas läuft schief! Finde die Fehler:
# > 💡 **Diese Fehler wurden absichtlich eingebaut** – damit du das Debuggen üben kannst!

# %% [markdown]
# ### 🐛 Bug #1
#
# Was ist falsch? Finde und behebe den Fehler!
#
# **Ziel:** Das Programm soll die Quadratwurzel von 9 berechnen und ausgeben.

# %%
result = math.sqrt(9)
print(f"Ergebnis: {result}")

# %% [markdown]
# ### 🐛 Bug #2
#
# Was ist falsch? Finde und behebe den Fehler!
#
# **Ziel:** Das Programm soll eine Zufallszahl zwischen 1 und 10 erzeugen und ausgeben.

# %%
import random
zahl = random.zahl(1, 10)
print(f"Zufallszahl: {zahl}")

# %% [markdown]
# ### 🐛 Bug #3
#
# Was ist falsch? Finde und behebe den Fehler!
#
# **Ziel:** Das Programm soll den Sinus von 90° berechnen und ausgeben.

# %%
import math
winkel = 90
sinus = sin(math.radians(winkel))
print(f"Sinus von {winkel}°: {sinus}")
