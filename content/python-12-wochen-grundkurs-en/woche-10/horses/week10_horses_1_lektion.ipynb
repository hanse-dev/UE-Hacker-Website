# %% [markdown]
# # 🐴 Week 10 – OOP Basics: The Magic Blueprints!
#
# Welcome, young horse lover! You are entering the idyllic **Sonnental Riding School** – a place full of nature, friendship and adventures with horses. This week you will learn the three most important lessons:
#
# **Your mission:**
# - Create classes as stable plans for horses
# - Bring objects to life as individual horses
# - Grant methods as abilities of the horses
#
# **Let's go!** Your horse friend is already waiting for you...

# %% [markdown]
# ## Lesson 1
#
# **What it is:** A class is like a stable plan for horses. It describes what properties and abilities each horse should have.
#
# **Important:** Class names always start with a capital letter!

# %%
# Example 1: Create first class
class Horse:
    pass

# Example 2: Class with attributes
class Rider:
    name = "Unknown"
    experience = 0

# Example 3: Class with method
class Pony:
    def neigh(self):
        print("Neigh! 🐴")

# %% [markdown]
# ## Lesson 2
#
# **What it is:** An object is a concrete horse born from the stable plan.
#
# **Important:** Every object is unique, even if it comes from the same class!

# %%
# Example 1: Create objects
my_horse = Horse()
your_horse = Horse()

# Example 2: Set attributes
anna = Rider()
anna.name = "Anna"
anna.experience = 5

# Example 3: Multiple objects
lucky = Pony()
spirit = Pony()
lucky.neigh()

# %% [markdown]
# ## Lesson 3: __init__
#
# **What it is:** The constructor *(= special method that runs automatically when an object is created)* is a special method that is automatically executed when a horse is born.
#
# **Important:** `__init__` always has `self` as its first parameter! (Why `self` is needed is explained in the next section.)

# %%
# Example 1: Simple constructor
class Horse:
    def __init__(self, name):
        self.name = name

# Example 2: Constructor with multiple values
class Foal:
    def __init__(self, name, age, gender):
        self.name = name
        self.age = age
        self.gender = gender

# Example 3: Constructor with default values
class Horse:
    def __init__(self, name="Stormy", breed="Pony"):
        self.name = name
        self.breed = breed

# %% [markdown]
# ## 🪞 Why `self`? – The Key to Your Horses
#
# **What is `self`?** `self` is the reference to **the concrete horse** that is currently being addressed. When you call `lucky.neigh()`, `self` inside the method is exactly the object `lucky`.
#
# **Why do we need it at all?** A class can create many horses. Python needs to know: *which* of these horses is meant? With 10 horses the method needs to know: "I am working for THIS horse here."
#
# **In the constructor `__init__`:**
# - `self.name = name` means: **Save** the passed `name` on THIS horse.
# - Without `self` Python would not know where the variable belongs – it would only exist locally and disappear after the call.
#
# **In methods:**
# - `self.name` means: **Read the name** from THIS horse.
# - Without `self` the method could not access the object's attributes – it would not know whether it's Lucky, Spirit or another horse.
#
# **How the call works in the background:**
# - `lucky.neigh()` is translated by Python to `Pony.neigh(lucky)`.
# - The first argument is always the object itself – that's why the parameter is called `self`.
