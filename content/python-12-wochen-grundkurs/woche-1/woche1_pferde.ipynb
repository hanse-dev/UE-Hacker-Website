# %% [markdown]
# # 🐴 Woche 1 – Einführung und erstes Programm: Willkommen auf dem Reiterhof
#
# **Huf-Punkte zu verdienen:** 1000 Punkte
# **Herausforderung:** Das große Chaos der namenlosen Pferde

# %% [markdown]
# ## 🌟 Die Freundschaft beginnt: Dein erster Tag im Sonnental
#
# Willkommen auf dem Reiterhof **"Sonnental"**! Du beginnst heute deine Arbeit als Stallhelfer:in und bist verantwortlich für die Pflege und Organisation der Pferde. Doch bevor du reiten oder trainieren kannst, musst du die **Grundlagen der Hof-Verwaltung** lernen.
#
# In dieser ersten Woche lernst du die beiden wichtigsten Werkzeuge: **Variablen** (um Informationen über Pferde zu speichern) und **print()** (um Listen und Berichte auszugeben). Diese einfachen Grundlagen sind die Basis für alles, was noch kommt!
#
# **Deine Mission:**
# - Lerne, wie du Text mit `print()` ausgibst
# - Verstehe, wie Variablen Informationen speichern
# - Kombiniere Texte und Variablen
# - Erstelle deine ersten Pferde-Profile

# %% [markdown]
# ## 🎯 Was ist Programmieren?
#
# **Programmieren** ist wie das Führen eines Hof-Tagebuchs – nur viel mächtiger! Du gibst dem Computer präzise Anweisungen, und er hilft dir bei der Organisation. Statt alles von Hand aufzuschreiben, nutzt du **Code** – geschriebene Befehle, die der Computer versteht.
#
# Python ist eine **Programmiersprache** – eine Sprache, die sowohl Menschen als auch Computer verstehen können. Sie ist besonders freundlich für Anfänger!
#
# **Warum ist Programmieren so praktisch?**
# - 📋 **Organisation:** Verwalte Pferde, Futter, Termine automatisch
# - ⏰ **Zeitersparnis:** Lass den Computer wiederkehrende Aufgaben erledigen
# - 📊 **Übersicht:** Behalte den Überblick über große Datenmengen
# - 🎯 **Präzision:** Keine vergessenen Informationen mehr
#
# **Fun Fact:** Viele moderne Reiterhöfe nutzen Software für Stallmanagement, Futterplanung und Trainingsplanung – alles basiert auf Programmierung!

# %% [markdown]
# ### 🐴 Tutorial: Deine ersten Schritte
#
# Die erfahrene Reitlehrerin Anna erklärt dir die Grundlagen:
#
# **"Der erste Befehl, den jeder Programmierer lernt, ist `print()`:"**
#
# ```python
# # Mit print() kannst du Text ausgeben
# print("Hallo Sonnental!")
#
# # Variablen speichern Informationen
# pferd_name = "Bella"
# pferd_alter = 8
#
# # Du kannst Variablen ausgeben
# print(pferd_name)
# print(pferd_alter)
#
# # Oder Texte kombinieren (mit +)
# print("Pferd: " + pferd_name)
# print("Alter: " + str(pferd_alter))
# ```
#
# **Wichtige Regeln:**
# - Text steht immer in Anführungszeichen: `"Text"` oder `'Text'`
# - Variablennamen ohne Anführungszeichen: `pferd_name`, `alter`
# - Zahlen in Text umwandeln mit `str()`: `str(8)`
# - Kommentare beginnen mit `#` – der Computer ignoriert sie

# %%
# 🌟 Level 1: Dein erster Befehl

# Der klassische erste Befehl
print("Hallo Sonnental!")
print("Willkommen auf dem Reiterhof!")

# Du kannst auch mehrere Zeilen ausgeben
print("Dies ist dein erstes Programm.")
print("Du bist jetzt ein Programmierer!")

print()
print("🎉 +100 Huf-Punkte: Erster Befehl erfolgreich!")

# %% [markdown]
# ### 🎯 Power-Move: print() verstehen
#
# Der `print()`-Befehl ist dein wichtigstes Werkzeug:
# - Er gibt Text auf dem Bildschirm aus
# - Text muss in Anführungszeichen stehen: `"` oder `'`
# - Jeder `print()` macht automatisch eine neue Zeile
# - Du kannst auch leere Zeilen machen: `print()`

# %%
# 📦 Level 2: Variablen - Deine Informations-Speicher

# Variablen speichern Informationen
pferd_name = "Luna"
pferd_alter = 6
pferd_farbe = "Schimmel"

# Gib die Variablen aus
print("Pferdename:")
print(pferd_name)
print("Alter:")
print(pferd_alter)
print("Farbe:")
print(pferd_farbe)

print()
print("🎉 +150 Huf-Punkte: Variablen gemeistert!")

# %% [markdown]
# ### 📦 Skill-Erklärung: Variablen
#
# **Variablen** sind wie Boxen mit Etiketten, die Informationen speichern:
#
# - **Name:** Beschreibt, was drin ist (z.B. `pferd_name`, `futter_menge`)
# - **Wert:** Die gespeicherte Information (z.B. `"Luna"`, `25`)
# - **Zuweisung:** Mit `=` speicherst du einen Wert: `name = "Bella"`
#
# **Wichtig:** Variablennamen sollten aussagekräftig sein und keine Leerzeichen enthalten!

# %%
# ✨ Level 3: Texte kombinieren

# Speichere Informationen
name = "Stella"
rasse = "Haflinger"
groesse = 148

# Kombiniere Text mit + (String-Verkettung)
print("Name: " + name)
print("Rasse: " + rasse)

# Zahlen müssen mit str() in Text umgewandelt werden
print("Größe: " + str(groesse) + " cm")

# Längere Kombinationen
print(name + " ist ein " + rasse + " mit " + str(groesse) + " cm Stockmaß.")

print()
print("🎉 +200 Huf-Punkte: Text-Kombination erlernt!")

# %% [markdown]
# ### 🔗 Power-Move: String-Verkettung
#
# Mit dem `+` Operator kannst du Texte (Strings) verbinden:
#
# ```python
# "Hallo " + "Welt"  # Ergibt: "Hallo Welt"
# ```
#
# **Wichtig:** Zahlen müssen erst mit `str()` in Text umgewandelt werden:
#
# ```python
# "Alter: " + str(6)  # Funktioniert!
# "Alter: " + 6       # Fehler!
# ```

# %%
# 🎭 Level 4: Variablen ändern

# Starte mit Anfangswerten
futter_kg = 50
print("Futter im Lager: " + str(futter_kg) + " kg")

# Neue Lieferung!
futter_kg = 100
print("Nach der Lieferung: " + str(futter_kg) + " kg")

# Pferde gefüttert
futter_kg = 75
print("Nach dem Füttern: " + str(futter_kg) + " kg")

# Variablen können sich ändern!
wetter = "sonnig"
print("Wetter: " + wetter)

wetter = "regnerisch"
print("Neues Wetter: " + wetter)

print()
print("🎉 +250 Huf-Punkte: Variablen-Änderung verstanden!")

# %% [markdown]
# ### 🔄 Wichtiges Konzept: Variablen überschreiben
#
# Variablen können ihren Wert ändern:
#
# ```python
# pferde = 5
# pferde = 6   # Neuer Wert überschreibt den alten
# pferde = 7   # Wieder ein neuer Wert
# ```
#
# Der alte Wert ist dann weg – die Variable speichert immer nur den neuesten Wert!

# %%
# 🗺️ Level 5: Dein erster Tagesplan

# Erstelle Informationen
pferd = "Thunder"
aktivitaet = "Ausritt"
dauer = 60
ort = "Waldweg"

# Erstelle einen Tagesplan
print("=== TAGESPLAN ===")
print()
print("Pferd: " + pferd)
print("Aktivität: " + aktivitaet)
print("Dauer: " + str(dauer) + " Minuten")
print("Ort: " + ort)
print()
print("Viel Spaß beim " + aktivitaet + " mit " + pferd + "!")

print()
print("🎉 +200 Huf-Punkte: Erster Tagesplan erstellt!")

# %% [markdown]
# ### 📖 Power-Move: Organisation
#
# Mit `print()` und Variablen kannst du übersichtliche Pläne erstellen:
# - Speichere wichtige Informationen in Variablen
# - Kombiniere sie zu lesbaren Sätzen
# - Nutze Trennlinien für Übersichtlichkeit
#
# Das ist die Grundlage für Stallmanagement-Software!

# %%
# 🎮 Level 6: Pferde-Steckbrief erstellen

# Erstelle einen vollständigen Steckbrief
name = "Moonlight"
rasse = "Araber"
farbe = "Rappe"
alter = 7
stockmass = 155
charakter = "lebhaft"

# Zeige den Steckbrief
print("====== PFERDE-STECKBRIEF ======")
print()
print("Name: " + name)
print("Rasse: " + rasse)
print("Farbe: " + farbe)
print()
print("Alter: " + str(alter) + " Jahre")
print("Stockmaß: " + str(stockmass) + " cm")
print("Charakter: " + charakter)
print()
print("===============================")

print()
print("🎉 +300 Huf-Punkte: Steckbrief-System erstellt!")

# %% [markdown]
# ### 🎯 Skill-Erklärung: Datentypen
#
# Python kennt verschiedene Arten von Daten:
#
# - **String (Text):** `"Bella"`, `'Thunder'` – immer in Anführungszeichen
# - **Integer (Ganzzahl):** `7`, `148`, `-5` – ohne Anführungszeichen
# - **Float (Dezimalzahl):** `1.55`, `62.5` – mit Punkt statt Komma
#
# **Wichtig:** Text und Zahlen können nicht direkt kombiniert werden – nutze `str()` zur Umwandlung!

# %%
# 🏰 Level 7: Futter-Planung

# Erstelle eine Futter-Liste
pferd_name = "Blitz"
heu_kg = 8
kraftfutter_kg = 2
karotten = 3
aepfel = 2
wasser_liter = 40

# Zeige den Futterplan
print("====== FUTTERPLAN ======")
print()
print("Pferd: " + pferd_name)
print()
print("Tägliche Ration:")
print("- Heu: " + str(heu_kg) + " kg")
print("- Kraftfutter: " + str(kraftfutter_kg) + " kg")
print("- Karotten: " + str(karotten) + " Stück")
print("- Äpfel: " + str(aepfel) + " Stück")
print("- Wasser: " + str(wasser_liter) + " Liter")
print()
print("========================")

print()
print("🎉 +250 Huf-Punkte: Futterplan programmiert!")

# %% [markdown]
# ### 🎒 Wichtiges Konzept: Organisation
#
# Gute Programme sind übersichtlich:
# - **Aussagekräftige Namen:** `pferd_name` statt `x`
# - **Leerzeilen:** Trennen verschiedene Abschnitte
# - **Kommentare:** Erklären, was der Code macht
# - **Struktur:** Logischer Aufbau von oben nach unten

# %%
# 🏆 Level 8: Kompletter Stall-Bericht

# Stall-Informationen
stall_name = "Sonnental"
stall_ort = "Grüne Wiesen"
anzahl_pferde = 12
anzahl_boxen = 15

# Pferd-Informationen
pferd1 = "Bella"
pferd2 = "Thunder"
pferd3 = "Moonlight"

# Tages-Informationen
datum = "Montag"
wetter = "sonnig"
temperatur = 22

# Zeige den kompletten Bericht
print("="*50)
print("     REITERHOF TAGESBERICHT     ")
print("="*50)
print()
print("STALL-INFO:")
print("  Name: " + stall_name)
print("  Ort: " + stall_ort)
print("  Pferde: " + str(anzahl_pferde))
print("  Freie Boxen: " + str(anzahl_boxen - anzahl_pferde))
print()
print("HEUTIGE PFERDE:")
print("  1. " + pferd1)
print("  2. " + pferd2)
print("  3. " + pferd3)
print()
print("WETTER:")
print("  Tag: " + datum)
print("  Bedingungen: " + wetter)
print("  Temperatur: " + str(temperatur) + "°C")
print()
print("Perfektes Wetter für einen Ausritt!")
print()
print("="*50)

print()
print("🎉 +400 Huf-Punkte: Meisterwerk erschaffen!")

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein neuer Stallhelfer hat versucht, seine ersten Programme zu schreiben, aber etwas läuft schief! Drei seiner Programme enthalten typische Anfängerfehler. Kannst du sie finden und korrigieren?

# %% [markdown]
# ### 🐛 Bug #1: Die vergessenen Anführungszeichen

# %%
# 🐛 Dieser Code hat einen Fehler!

pferd = Bella
print("Pferd: " + pferd)

# 🤔 Frage: Was ist das Problem?

# %% [markdown]
# ### 🐛 Bug #2: Die fehlende Umwandlung

# %%
# 🐛 Dieser Code hat einen Fehler!

alter = 7
print("Alter: " + alter + " Jahre")

# 🤔 Frage: Was ist das Problem?

# %% [markdown]
# ### 🐛 Bug #3: Der Tippfehler

# %%
# 🐛 Dieser Code hat einen Fehler!

pferd_name = "Thunder"
print("Name: " + pferdname)

# 🤔 Frage: Was ist das Problem?

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen! Die Hofleitung hat drei Aufgaben für dich vorbereitet.

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Dein eigenes Pferd
#
# **Belohnung:** 300 Huf-Punkte + Pflegehandbuch
#
# Erstelle ein Profil für dein Lieblingspferd!
#
# **Aufgaben:**
# 1. Erstelle Variablen für: Name, Rasse, Farbe, Alter
# 2. Gib alle Informationen mit `print()` aus
# 3. Nutze String-Verkettung mit `+`
# 4. Vergiss nicht `str()` für Zahlen!
# 5. Mache es übersichtlich mit Leerzeilen
#
# **Bonus-Challenge:** Füge noch mehr Eigenschaften hinzu (Stockmaß, Charakter, Lieblingsfutter)!

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Trainingsplan
#
# **Belohnung:** 400 Huf-Punkte + Trainings-Tagebuch
#
# Erstelle einen Trainingsplan für eine Woche!
#
# **Aufgaben:**
# 1. Erstelle Variablen für: Pferd-Name, Wochentag
# 2. Erstelle Variablen für 3 verschiedene Aktivitäten (z.B. Dressur, Springen, Ausritt)
# 3. Erstelle Variablen für die Dauer jeder Aktivität (in Minuten)
# 4. Gib einen übersichtlichen Wochenplan aus
# 5. Nutze Trennlinien (z.B. `print("===")`)
# 6. Mache es übersichtlich und strukturiert!
#
# **Bonus-Challenge:** Füge noch Informationen hinzu (Ort, Trainer, benötigte Ausrüstung)!

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Der Stall-Bericht
#
# **Belohnung:** 500 Huf-Punkte + Stallmeister-Abzeichen
#
# Erstelle einen kompletten Tagesbericht für den Stall!
#
# **Aufgaben:**
# 1. Erstelle Variablen für: Datum, Wetter, Temperatur
# 2. Erstelle Variablen für: Anzahl Pferde, gefütterte Pferde, trainierte Pferde
# 3. Erstelle Variablen für: Verbrauchtes Heu (kg), Kraftfutter (kg)
# 4. Erstelle Variablen für 3 besondere Ereignisse des Tages
# 5. Gib einen kompletten Bericht aus:
#    - Datum und Wetter
#    - Pferde-Statistik
#    - Futter-Verbrauch
#    - Besondere Ereignisse
# 6. Mache es professionell und übersichtlich!
#
# **Bonus-Challenge:** Füge noch eine Zusammenfassung und Ausblick für morgen hinzu!

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten der Reitlehrerin (Reflexion)
#
# Bevor du weiterziehst, denke über diese Fragen nach:
#
# 1. **Warum sind Variablen so wichtig?** Was wäre der Nachteil, wenn du immer nur feste Werte verwenden würdest?
#
# 2. **Wann brauchst du `str()`?** Kannst du erklären, warum man Zahlen in Text umwandeln muss?
#
# 3. **Was macht ein Programm übersichtlich?** Welche Tricks hast du gelernt, um deinen Code lesbarer zu machen?
#
# 4. **Wo könntest du `print()` und Variablen auf einem echten Reiterhof nutzen?** Fallen dir Beispiele ein?
#
# Diskutiere deine Gedanken mit anderen Reitschülern oder deiner Reitlehrerin!

# %% [markdown]
# ### 🎤 Helden-Präsentation (Review)
#
# Zeit, deine Kreationen zu präsentieren! Wähle eine deiner Lösungen und stelle sie vor:
#
# **Zeige und erkläre:**
# - Welche Variablen hast du erstellt und warum?
# - Wie hast du Text und Variablen kombiniert?
# - Was war am schwierigsten?
# - Was würdest du beim nächsten Mal anders machen?
#
# **Diskussionspunkte:**
# - Wie könnte man das Programm erweitern?
# - Welche anderen Informationen könnte man speichern?
# - Wie würde man das in echter Stallmanagement-Software umsetzen?
# - Was sind die Grenzen von `print()` und Variablen?

# %% [markdown]
# ### 📖 Reit-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **print()** 📢: Gibt Text auf dem Bildschirm aus
# - **Variable** 📦: Speichert einen Wert unter einem Namen
# - **String** 📝: Text in Anführungszeichen (`"Bella"`)
# - **Integer** 🔢: Ganzzahl ohne Anführungszeichen (`7`)
# - **str()** 🔄: Wandelt eine Zahl in Text um
# - **Zuweisung** ➡️: Speichert einen Wert in einer Variable (`name = "Luna"`)
# - **String-Verkettung** ➕: Verbindet Texte mit `+`
# - **Kommentar** 💭: Notiz im Code, beginnt mit `#`
# - **Anführungszeichen** " ": Markieren Text (`"` oder `'`)
# - **Code** 💻: Geschriebene Befehle für den Computer
# - **Programm** 🎮: Sammlung von Code-Befehlen
# - **Python** 🐍: Die Programmiersprache, die wir lernen

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ✅ Ich kann Text mit `print()` ausgeben
# - ✅ Ich kann Variablen erstellen und Werte speichern
# - ✅ Ich kann Texte mit `+` kombinieren
# - ✅ Ich kann Zahlen mit `str()` in Text umwandeln
# - ✅ Ich verstehe den Unterschied zwischen String und Integer
# - ✅ Ich kann übersichtliche Programme schreiben
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die Boss-Quests!

# %% [markdown]
# ### 🏆 Zusammenfassung: Dein Start im Sonnental
#
# **Fantastisch!** Du hast die ersten Schritte in der Welt der Programmierung gemeistert!
#
# **Das hast du gelernt:**
# - `print()` gibt Text auf dem Bildschirm aus
# - Variablen speichern Informationen unter einem Namen
# - Mit `+` kannst du Texte kombinieren
# - `str()` wandelt Zahlen in Text um
# - Kommentare mit `#` helfen, Code zu erklären
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🐴 **Stallmanagement:** Pferde-Datenbanken, Futterpläne, Trainingsplanung
# - 📱 **Apps:** Reiterhof-Verwaltung, Turnier-Organisation
# - 📊 **Berichte:** Tagesberichte, Statistiken, Dokumentation
# - 🏥 **Tiermedizin:** Gesundheitsakten, Impfpläne, Behandlungsverläufe
# - 📅 **Planung:** Belegungspläne, Reitstunden, Veranstaltungen
#
# **Als Nächstes:** In Woche 2 lernst du **Benutzereingaben** – wie dein Programm mit Menschen interagiert!

# %% [markdown]
# ## 🏆 Boss-Kampf: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Quests sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast, und erfordern kreatives Denken.
#
# **Belohnungen:** Insgesamt 1500 Huf-Punkte + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Das komplette Pferdeprofil
#
# **Belohnung:** 500 Huf-Punkte + Goldenes Halfter
#
# Erstelle ein umfassendes Pferdeprofil wie in einer echten Datenbank!
#
# **Aufgaben:**
# 1. Erstelle mindestens 12 verschiedene Variablen:
#    - Name, Rufname, Rasse, Farbe
#    - Alter, Geburtsdatum, Geschlecht
#    - Stockmaß, Gewicht
#    - Charakter, Temperament
#    - Besitzer, Standort
# 2. Erstelle Variablen für Gesundheit (Impfungen, letzter Tierarzt-Besuch)
# 3. Erstelle Variablen für Training (Ausbildungsstand, Disziplinen)
# 4. Gib alles in einem schön formatierten Profil aus
# 5. Nutze Trennlinien und Überschriften
# 6. Füge eine kurze Beschreibung des Pferdes hinzu (3-5 Sätze)
#
# **Bonus-Challenge:** Erstelle Profile für zwei verschiedene Pferde und vergleiche sie!

# %%
# 🏆 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Der Wochen-Stallplan
#
# **Belohnung:** 600 Huf-Punkte + Stallmeister-Urkunde
#
# Erstelle einen kompletten Wochenplan für den gesamten Stall!
#
# **Aufgaben:**
# 1. Für jeden Tag (Mo-So) erstelle Variablen:
#    - Datum, Wetter
#    - Anzahl Reitstunden, Ausritte, Trainings
#    - Besondere Ereignisse (Tierarzt, Hufschmied, etc.)
# 2. Erstelle Variablen für Ressourcen:
#    - Täglicher Heu-Verbrauch
#    - Täglicher Kraftfutter-Verbrauch
# 3. Erstelle Variablen für Personal:
#    - Anzahl Mitarbeiter pro Tag
#    - Arbeitszeiten
# 4. Gib einen übersichtlichen Wochenplan aus
# 5. Zeige Zusammenfassungen (Gesamt-Verbrauch, etc.)
# 6. Nutze verschiedene Formatierungen für jeden Tag
#
# **Bonus-Challenge:** Füge eine Wettervorhersage und Empfehlungen hinzu (z.B. "Bei Regen: Halle nutzen")!

# %%
# 🏆 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Die Turnier-Anmeldung
#
# **Belohnung:** 400 Huf-Punkte + Turnier-Schleife
#
# Erstelle eine Turnier-Anmeldung mit allen wichtigen Informationen!
#
# **Aufgaben:**
# 1. Erstelle Variablen für das Turnier:
#    - Name, Ort, Datum
#    - Veranstalter, Richter
# 2. Erstelle Variablen für 3 verschiedene Prüfungen:
#    - Prüfungs-Name, Klasse, Startzeit
#    - Nenngeld, Preisgelder
# 3. Erstelle Variablen für den Teilnehmer:
#    - Reiter-Name, Pferd-Name
#    - Startnummer
# 4. Gib eine komplette Turnier-Anmeldung aus:
#    - Turnier-Informationen
#    - Alle Prüfungen mit Details
#    - Teilnehmer-Informationen
#    - Gesamtkosten (Nenngelder)
# 5. Mache es professionell und übersichtlich!
#
# **Bonus-Challenge:** Füge noch Informationen zu Stallungen, Verpflegung und Zeitplan hinzu!

# %%
# 🏆 Deine Lösung hier:

print()
print("🎉 +400 Huf-Punkte: Boss-Quest abgeschlossen!")
print("🏆 Du hast das Chaos der namenlosen Pferde besiegt!")
print("⭐ Titel erhalten: Meister der Hof-Organisation")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 1 gemeistert!")
print("📚 Nächste Woche: Benutzereingaben – Interaktive Programme erstellen!")
