# %% [markdown]
# # 📖 Glossary – 🐴 Week 3 – Conditions (if-else): The Crossroads of the Riding Path
# > You can keep this notebook open all week.
#
# | Term | Meaning | Example |
# |------|---------|--------|
# | `if` | If-condition – run code only when condition is true | `if x > 5:` |
# | `elif` | Else-if – check another condition | `elif x == 5:` |
# | `else` | Otherwise – code when all conditions are false | `else:` |
# | `==` | Is equal (comparison, not assignment!) | `x == 5` |
# | `!=` | Is not equal | `x != 5` |
# | `<` / `>` | Less than / Greater than | `x < 10` |
# | `<=` / `>=` | Less than or equal / Greater than or equal | `x <= 10` |
# | `and` | Both conditions must be true | `x > 0 and x < 10` |
# | `or` | At least one condition must be true | `x < 0 or x > 10` |
# | `not` | Reverses a truth value | `not True` → `False` |

# %% [markdown]
# ## Quick Examples

# %% [markdown]
# ## Review – Terms from previous weeks
#
# ### From Week 1
#
# | Term | Meaning | Example |
# |------|---------|--------|
# | **Variable** | Container with a name | `name = "Aria"` |
# | **Boolean** | Yes/No value | `ready = True` |
# | `input()` | Reads user input | `name = input("Name? ")` |
#
#
# ### From Week 2
#
# | Term | Meaning | Example |
# |------|---------|--------|
# | `f-String` | Variables directly in text | `f"Hello {name}"` |
# | `int()` | Convert to number – needed for input | `int(input("Number? "))` |

# %%
age = 15

# if / elif / else
if age >= 18:
    print("Adult")
elif age >= 13:
    print("Teenager")
else:
    print("Child")

# Comparison operators
print(age == 15)   # True
print(age != 10)   # True
print(age > 10)    # True

# Logical operators
print(age > 10 and age < 20)  # True
print(age < 10 or age > 12)   # True
