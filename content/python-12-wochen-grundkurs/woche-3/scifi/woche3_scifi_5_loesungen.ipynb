# %% [markdown]
# # 🔧 Lösungen – 🚀 Woche 3 – Bedingungen (if-else): Die Pfade der Entscheidung
#
# > Erst selber versucht? Dann check hier nach!

# %% [markdown]
# ## 🐛 Debug-Quest Lösungen

# %%
# ✅ Lösung Bug #1: Falsche Einrückung

# Problem: Code nach if nicht eingerückt
level = 10
if level >= 10:
    print("Zugriff gewährt!")
    print("Willkommen Kommandant!")

# %%
# ✅ Lösung Bug #2: Falscher Vergleich

# Problem: = statt == für Vergleich verwendet
user = "Admin"
if user == "Admin":
    print("Hallo Admin!")

# %%
# ✅ Lösung Bug #3: Vergessene Bedingung

# Problem: elif braucht immer eine Bedingung
status = 25
if status >= 18:
    print("System aktiv")
else:
    print("System inaktiv")

# %% [markdown]
# ## ⭐ Missions-Lösungsvorschläge
#
# > Lösungsvorschläge werden noch ergänzt.

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Sicherheits-Scanner

# %%
# ✏️ Lösungsvorschlag Mission 1 – Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Terminal-Zugang

# %%
# ✏️ Lösungsvorschlag Mission 2 – Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Die Missionsbewertung

# %%
# ✏️ Lösungsvorschlag Mission 3 – Deine Lösung hier:
