# %% [markdown]
# # 🐛 Debug Quest – 🚀 Week 6 – Lists: The Data Banks of the Space Station
#
# A technician tried to organize the system data, but something went wrong! Find the bugs:
# > 💡 **These bugs were put in on purpose** – so you can practice debugging!

# %% [markdown]
# ### 🐛 Bug #1
#
# What's wrong? Find and fix the bug!
#
# **Goal:** The program should print the list of the three systems.

# %%
systems = ["Weapon System", "Shield System", "Propulsion System"
print(f"Systems: {systems}")

# %% [markdown]
# ### 🐛 Bug #2
#
# What's wrong? Find and fix the bug!
#
# **Goal:** The program should print the last entry of the list, i.e. `Gamma`.

# %%
protocols = ["Alpha", "Beta", "Gamma"]
print(protocols[3])

# %% [markdown]
# ### 🐛 Bug #3
#
# What's wrong? Find and fix the bug!
#
# **Goal:** The list should be sorted in descending order, i.e. `[15, 10, 5, 1]`.

# %%
level = [1, 5, 10, 15]
level.sort(reverse)
print(level)
