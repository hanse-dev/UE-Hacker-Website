# %% [markdown]
# # 🏰 Woche 12 – Grafische Projekte mit Turtle: Die magische Leinwand!
#
# **XP zu verdienen:** 1200 Punkte
# **Boss:** Der Meister der magischen Zeichenrollen

# %% [markdown]
# ## 🌟 Die Quest beginnt: Willkommen in der Welt der magischen Zeichenrollen!
#
# Willkommen, junger Magier der visuellen Künste! Du betrittst die **Werkstatt der magischen Zeichenrollen von Pyralia** – ein Ort, wo Code zu Leben erwacht und farbenfrohe Grafiken entstehen!
#
# In dieser Woche meistert du die magische Kunst der Turtle-Grafik:
#
# **Deine Mission:**
# - Turtle-Modul für visuelle Magie nutzen
# - Formen und Muster zeichnen
# - Farben für zauberhafte Effekte einsetzen
# - Animationen und interaktive Kunst erschaffen
#
# **Leg los!** Deine Reise zum visuellen Meister beginnt!

# %% [markdown]
# ## 📚 Zauberformel 1: Turtle importieren und einrichten
#
# **Was es ist:** Das Turtle-Modul ist Pythons magische Zeichenrolle, die es dir ermöglicht, mit Code zu zeichnen.
#
# **Warum nützlich:**
# - Macht Code sichtbar und greifbar
# - Perfekt für kreative Projekte
# - Lernen durch visuelles Feedback
#
# **Wichtig:** Importiere immer `turtle` und rufe `turtle.done()` am Ende auf!

# %%
# %pip install Tinker
from turtle import *
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 get_ipython().run_line_magic('pip', 'install Tinker')
# ----> 2 from turtle import *
#
# File /opt/homebrew/Cellar/python@3.14/3.14.3_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/turtle.py:101
#       1 #
#       2 # turtle.py: a Tkinter based turtle graphics module for Python
#       3 # Version 1.1b - 4. 5. 2009
#    (...)     21 #    misrepresented as being the original software.
#      22 # 3. This notice may not be removed or altered from any source distribution.
#      24 """
#      25 Turtle graphics is a popular way for introducing programming to
# ...

# %%
# Beispiel 1: Turtle einrichten
import turtle

# Erstelle eine magische Zeichenrolle
screen = turtle.Screen()
screen.title("Magische Zeichenrolle von Pyralia")
screen.bgcolor("black")

# Erstelle einen magischen Stift (Turtle)
pen = turtle.Turtle()
pen.speed(1)  # Langsam für magische Effekte
pen.color("cyan")

# Zeichne eine magische Form
pen.forward(100)
pen.left(90)
pen.forward(100)

# Schließe die magische Zeichenrolle
turtle.done()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Beispiel 1: Turtle einrichten
# ----> 2 import turtle
#       3
#       4 # Erstelle eine magische Zeichenrolle
#       5 screen = turtle.Screen()
#
# File /opt/homebrew/Cellar/python@3.14/3.14.3_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/turtle.py:101
#       1 #
#       2 # turtle.py: a Tkinter based turtle graphics module for Python
#       3 # Version 1.1b - 4. 5. 2009
#    (...)     21 #    misrepresented as being the original software.
#      22 # 3. This notice may not be removed or altered from any source distribution.
#      24 """
#      25 Turtle graphics is a popular way for introducing programming to
#      26 kids. It was part of the original Logo programming language developed
#    (...)     98 extensions in mind. These will be commented and documented elsewhere.
# ...

# %% [markdown]
# ## 📦 Zauberformel 2: Formen zeichnen und bewegen
#
# **Was es ist:** Mit Turtle-Befehlen kannst du verschiedene Formen zeichnen und den Stift bewegen.
#
# **Warum nützlich:**
# - Bausteine für komplexe Grafiken
# - Verständlich durch einfache Befehle
# - Kombinierbar zu Mustern
#
# **Wichtig:** Die Turtle dreht sich immer an ihrer aktuellen Position!

# %%
# Beispiel 1: Grundlegende Bewegungen
import turtle

screen = turtle.Screen()
screen.bgcolor("navy")
pen = turtle.Turtle()
pen.speed(5)
pen.color("gold")

# Ein magisches Quadrat
for _ in range(4):
    pen.forward(100)
    pen.left(90)

# Ein magisches Dreieck
pen.penup()
pen.goto(-150, 0)
pen.pendown()
for _ in range(3):
    pen.forward(100)
    pen.left(120)

turtle.done()

# %% [markdown]
# ## ✨ Zauberformel 3: Farben und Füllungen
#
# **Was es ist:** Farben machen deine Grafiken lebendig und Füllungen geben ihnen Körper.
#
# **Warum nützlich:**
# - Visuelle Attraktivität
# - Unterscheidung von Elementen
# - Professionelles Aussehen
#
# **Wichtig:** Nutze `begin_fill()` und `end_fill()` für gefüllte Formen!

# %%
# Beispiel 1: Magische Farben und Füllungen
import turtle

screen = turtle.Screen()
screen.bgcolor("darkblue")
pen = turtle.Turtle()
pen.speed(3)

# Magischer Stern
pen.color("yellow", "orange")
pen.begin_fill()
for _ in range(5):
    pen.forward(100)
    pen.right(144)
pen.end_fill()

# Magischer Kreis
pen.penup()
pen.goto(150, 0)
pen.pendown()
pen.color("cyan", "lightblue")
pen.begin_fill()
pen.circle(50)
pen.end_fill()

turtle.done()

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein Lehrling hat versucht, magische Zeichenrollen zu erstellen, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1: Falscher Import

# Der Code funktioniert nicht - warum?
import Turtle

pen = Turtle()
pen.forward(100)
pen.done()

# %%
# 🐛 Bug #2: Fehlende Füllung

# Warum ist der Stern nicht gefüllt?
import turtle

pen = turtle.Turtle()
pen.color("red")
pen.begin_fill()
for _ in range(5):
    pen.forward(100)
    pen.right(144)
# Fehlt etwas?

# %%
# 🐛 Bug #3: Turtle bewegt sich nicht

# Warum sieht man nichts?
import turtle

pen = turtle.Turtle()
pen.speed(0)
pen.color("white")
pen.forward(100)
# Was fehlt am Ende?

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, deine magischen Zeichenkünste in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Die magische Rune zeichnen
#
# **Belohnung:** 350 XP + Magischer Zeichenstift
#
# Zeichne eine uralte magische Rune mit Turtle!
#
# **Deine Aufgaben:**
#
# 1. **Turtle-Fenster und Pentagramm**
#    - Erstelle ein Turtle-Fenster mit schwarzem Hintergrund (`screen.bgcolor("black")`)
#    - Zeichne ein Pentagramm (fünfzackiger Stern): 5 Linien, nach jeder Linie 144 Grad drehen (`right(144)` oder `left(144)`)
#
# 2. **Kreis und Füllung**
#    - Zeichne einen Kreis um den Stern herum mit `circle(radius)` (vorher mit `penup()` und `goto()` positionieren)
#    - Nutze magische Farben (z.B. Gold oder Silber) mit `color()` und `fillcolor()`
#    - Fülle mindestens eine Form mit `begin_fill()` und `end_fill()`
#
# 3. **Formen verbinden**
#    - Pentagramm und Kreis sollen sichtbar und ansprechend aussehen
#
# **Beispiel-Code zum Starten:**
# ```python
# import turtle
# screen = turtle.Screen()
# screen.bgcolor("black")
# t = turtle.Turtle()
# t.color("gold")
# t.speed(3)
# for _ in range(5):
#     t.forward(100)
#     t.right(144)
# t.penup()
# t.goto(0, -50)
# t.pendown()
# t.circle(50)
# turtle.done()
# ```
#
# **Bonus-Challenge:** Füge Runenzeichen um das Pentagramm herum hinzu!
#
# **Erwartete Ausgabe:**
# ```
# Ein Fenster mit schwarzem Hintergrund, Pentagramm und Kreis in Gold/Silber
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Zauberhut des Magiers
#
# **Belohnung:** 450 XP + Hut der Visualisierung
#
# Zeichne den ikonischen Zauberhut eines Pyralia-Magiers!
#
# **Deine Aufgaben:**
#
# 1. **Zylinder zeichnen**
#    - Zeichne ein Rechteck oder Oval als Hauptteil des Hutes (z.B. mit `forward()`, `left()`, oder `circle()`)
#    - Nutze `penup()` und `goto()` um den Stift zu positionieren
#
# 2. **Krempe und Verzierungen**
#    - Füge eine breite Krempe am unteren Rand hinzu (z.B. ein breiteres Rechteck oder Ellipse)
#    - Platziere mindestens einen Stern oder Mond als Verzierung (kleine Formen mit `circle()` oder Linien)
#
# 3. **Magische Farben**
#    - Nutze lila und blau (`color("purple")`, `color("blue")`) für Hut und Krempe
#    - Optional: Verschiedene Blautöne für Schatten
#
# **Beispiel-Code zum Starten:**
# ```python
# import turtle
# t = turtle.Turtle()
# t.speed(3)
# t.color("purple")
# t.begin_fill()
# t.forward(60)
# t.left(90)
# t.forward(80)
# t.left(90)
# t.forward(60)
# t.left(90)
# t.forward(80)
# t.left(90)
# t.end_fill()
# t.penup()
# t.goto(30, -20)
# t.pendown()
# t.color("blue")
# t.circle(80)  # Krempe
# turtle.done()
# ```
#
# **Bonus-Challenge:** Füge glitzernde Effekte mit kleinen Punkten hinzu!
#
# **Erwartete Ausgabe:**
# ```
# Ein Fenster mit Zauberhut (Zylinder, Krempe), Verzierungen in Lila/Blau
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Das magische Mandala
#
# **Belohnung:** 550 XP + Amulett der Symmetrie
#
# Erstelle ein komplexes, symmetrisches Mandala!
#
# **Deine Aufgaben:**
#
# 1. **Symmetrische Teile mit Schleife**
#    - Zeichne 8 gleiche Teile um ein Zentrum: In einer `for`-Schleife von 0 bis 8, bei jedem Durchlauf um 360/8 = 45 Grad drehen
#    - Jeder „Teil“ kann ein Kreis, Dreieck oder Quadrat sein (z.B. `circle(30)` oder Linien für Dreieck/Quadrat)
#
# 2. **Verschiedene Formen und Farben**
#    - Nutze mindestens zwei verschiedene Formen (z.B. Kreise und Linien)
#    - Setze verschiedene Farben (z.B. Liste von Farben und wechsle in der Schleife) für einen Farbverlauf
#
# 3. **Zentrieren**
#    - Starte in der Mitte (0, 0) oder positioniere das Mandala so, dass es mittig erscheint
#
# **Beispiel-Code zum Starten:**
# ```python
# import turtle
# t = turtle.Turtle()
# t.speed(0)
# farben = ["red", "orange", "yellow", "green", "blue", "purple", "pink", "cyan"]
# for i in range(8):
#     t.color(farben[i])
#     t.circle(50)
#     t.left(45)
# turtle.done()
# ```
#
# **Bonus-Challenge:** Mache das Mandala animiert mit langsamen Drehungen!
#
# **Erwartete Ausgabe:**
# ```
# Ein Fenster mit 8 symmetrischen Teilen, Farbverlauf, zentriert
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten des Zeichenmeisters (Reflexion)
#
# Bevor du weiterziehst, denke über diese Fragen nach:
#
# 1. **Wie hilft visuelle Programmierung beim Lernen?**
#
# 2. **Welche Muster kannst du mit Schleifen erstellen?**
#
# 3. **Wie kannst du Farben effektiv einsetzen?**
#
# Diskutiere deine Gedanken mit anderen Magiern!

# %% [markdown]
# ### 📖 Zauberspruch-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **Turtle** 🐢: Das Zeichenmodul von Python
# - **Screen** 🖥️: Das Zeichenfenster
# - **Pen** ✏️: Der Zeichenstift (Turtle-Objekt)
# - **forward()** ⬆️: Vorwärts bewegen
# - **backward()** ⬇️: Rückwärts bewegen
# - **left()** ↰: Links drehen
# - **right()** ↱: Rechts drehen
# - **penup()** ⬆️: Stift anheben
# - **pendown()** ⬇️: Stift senken
# - **color()** 🎨: Farbe setzen
# - **begin_fill()** 🪣: Füllung beginnen
# - **end_fill()** ✅: Füllung beenden
# - **circle()** ⭕: Kreis zeichnen
# - **goto()** 📍: Zu Position bewegen
# - **speed()** ⚡: Geschwindigkeit setzen
# - **done()** 🏁: Programm beenden

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ✅ Turtle-Modul importieren und einrichten
# - ✅ Formen zeichnen und bewegen
# - ✅ Farben und Füllungen verwenden
# - ✅ Schleifen für Muster nutzen
# - ✅ Interaktive Grafik erstellen
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die Boss-Quests!

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Hervorragend!** Du hast die magische Kunst der Turtle-Grafik gemeistert!
#
# **Das hast du gelernt:**
# - Turtle für visuelle Programmierung
# - Formen und Muster erstellen
# - Farben für lebendige Grafiken
# - Animationen und Effekte
# - Kreative Projekte umsetzen
#
# **In der echten Welt werden diese Techniken verwendet für:**
# - 🎮 **Spiele:** Einfache 2D-Grafiken und Animationen
# - 📊 **Datenvisualisierung:** Diagramme und Schaubilder
# - 🎨 **Kunst:** Generative Kunst und Designs
# - 📚 **Bildung:** Visuelles Lernen und Demonstrationen
# - 🔬 **Simulation:** Visualisierung von Prozessen
#
# **Als Nächstes:** Du bist bereit für deine eigenen kreativen Projekte!

# %% [markdown]
# ## 🐉 Boss-Kampf: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Quests sind extrem schwierig! Sie kombinieren alle Turtle-Konzepte.
#
# **Belohnungen:** Insgesamt 1800 XP + epische Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Die magische Landkarte von Pyralia
#
# **Belohnung:** 600 XP + Meisterkarte der Magier
#
# Erstelle eine detaillierte Landkarte des magischen Reichs Pyralia!
#
# **Deine Aufgaben:**
#
# **1. Erstelle das Karten-Layout:**
#    - Schwarzer Hintergrund als Nachthimmel
#    - Ränder als Kartenrahmen
#    - Kompass-Rose in der Ecke
#
# **2. Zeichne magische Orte:**
#    - 5 Städte als gefüllte Kreise
#    - Verbinde Städte mit Pfaden (Linien)
#    - Jede Stadt hat eigene Farbe
#
# **3. Füge geografische Features hinzu:**
#    - Berge als Dreiecke
#    - Flüsse als geschwungene Linien
#    - Wälder als kleine Kreise
#
# **4. Beschrifte alles:**
#    - Stadtnamen mit turtle.write()
#    - Legende für Symbole
#    - Titel "Königreich Pyralia"
#
# **5. Magische Effekte:**
#    - Sterne am Himmel
#    - Glitzer-Effekte an Orten
#    - Farbübergänge für Flüsse
#
# **Beispiel-Struktur:**
# ```python
# # So könntest du beginnen:
# import turtle
#
# # Setup für die Karte
# screen = turtle.Screen()
# screen.title("Karte von Pyralia")
# screen.bgcolor("black")
#
# # Erstelle verschiedene Turtle für verschiedene Elemente
# map_pen = turtle.Turtle()
# text_pen = turtle.Turtle()
# # ... weiterer Code
# ```
#
# **Bonus-Challenge:** Mache die Karte interaktiv mit Maus-Klicks auf Städte!
#
# **Erwartete Ausgabe:**
# ```
# Ein Fenster mit Karten-Layout, magischen Orten, geografischen Features, Beschriftungen und optional magischen Effekten
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Das animierte Zaubersiegel
#
# **Belohnung:** 800 XP + Szepter der Animation
#
# Erstelle ein komplexes, animiertes Zaubersiegel!
#
# **Deine Aufgaben:**
#
# **1. Erstelle Funktionen für Formen:**
#    - zeichne_stern(x, y, größe, farbe)
#    - zeichne_kreis(x, y, radius, farbe)
#    - zeichne_rune(x, y, text)
#
# **2. Baue das Siegel-Design:**
#    - Äußerer Kreis mit Runen
#    - Mittlerer Stern als Hauptelement
#    - Innere Symbole und Muster
#    - Symmetrische Anordnung
#
# **3. Implementiere Animation:**
#    - Langsame Drehung des gesamten Siegels
#    - Pulsierende Farben (Farbwechsel)
#    - Nacheinander erscheinende Elemente
#    - Nutze time.sleep() für Timing
#
# **4. Farb- und Lichteffekte:**
#    - Farbverläufe mit mehreren Farben
#    - Glüheffekte durch Linienstärke
#    - Regenbogenfarben für Magie
#    - Schatten für Tiefe
#
# **5. Interaktive Elemente:**
#    - Mausklick startet/stoppt Animation
#    - Tasten ändern Farben
#    - Geschwindigkeit regulierbar
#
# **Beispiel-Struktur:**
# ```python
# # So könntest du beginnen:
# import turtle
# import time
#
# def zeichne_stern(x, y, größe):
#     pen.penup()
#     pen.goto(x, y)
#     pen.pendown()
#     # Zeichne Stern hier
#
# def animiere_siegel():
#     for winkel in range(0, 360, 5):
#         # Rotationslogik hier
#         pass
#
# # Hauptprogramm
# # ... weiterer Code
# ```
#
# **Bonus-Challenge:** Füge Sound-Effekte mit winsound oder os.system hinzu!
#
# **Erwartete Ausgabe:**
# ```
# Ein Fenster mit Siegel-Design, Animation (Drehung, Farbwechsel), Lichteffekte und optional interaktiven Elementen
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 3: Die magische Zeichenrolle des Schöpfers
#
# **Belohnung:** 400 XP + Codex der unendlichen Kreativität
#
# Erstelle ein Turtle-Programm, das selbstständig Kunst erschafft!
#
# **Deine Aufgaben:**
#
# **1. Erstelle eine Zeichen-Klasse:**
#    - Klasse MagischerZeichner mit Turtle
#    - Methoden für verschiedene Muster
#    - Zufällige Farbauswahl
#    - Positionstracking
#
# **2. Implementiere Zufallskunst:**
#    - Zufällige Formen an zufälligen Orten
#    - Zufällige Größen und Farben
#    - Nutze random module
#    - Harmonische Farbpaletten
#
# **3. Erstelle Muster-Generatoren:**
#    - Spiralen-Muster
#    - Fraktale Strukturen
#    - Mandala-Generator
#    - Abstrakte Kompositionen
#
# **4. Benutzer-Interaktion:**
#    - Eingabe: Thema der Kunst (z.B. "Natur", "Space")
#    - Eingabe: Farbschema
#    - Eingabe: Komplexität
#    - Speichern als Bild (optional)
#
# **5. Galerie-Modus:**
#    - Erstelle 5 verschiedene Kunstwerke
#    - Zeige sie nacheinander
#    - Jedes mit 3 Sekunden Pause
#    - Automatische Farbübergänge
#
# **Beispiel-Struktur:**
# ```python
# # So könntest du beginnen:
# import turtle
# import random
# import time
#
# class MagischerZeichner:
#     def __init__(self):
#         self.pen = turtle.Turtle()
#         self.screen = turtle.Screen()
#         self.farben = ["red", "blue", "green", "yellow", "purple"]
#
#     def zeichne_zufälliges_muster(self):
#         # Zufällige Muster-Logik
#         pass
#
# # Hauptprogramm
# zeichner = MagischerZeichner()
# # ... weiterer Code
# ```
#
# **Bonus-Challenge:** Implementiere einen Genetischen Algorithmus zur Kunst-Evolution!
#
# **Erwartete Ausgabe:**
# ```
# Ein Fenster mit Zufallskunst, Muster-Generatoren, optional Benutzer-Interaktion und Galerie-Modus
# ```

# %%
# 🐉 Deine Lösung hier:

print()
print("🎉 +400 XP: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Meister der Zeichenrollen besiegt!")
print("⭐ Titel erhalten: Magier der visuellen Künste")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 12 gemeistert!")
print("📚 Nächste Woche: Deine eigenen Projekte!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen:

# %%
# ✅ Lösung Bug #1: Falscher Import

# Problem: Modulname muss kleingeschrieben werden
import turtle

pen = turtle.Turtle()
pen.forward(100)
turtle.done()

# %%
# ✅ Lösung Bug #2: Fehlende Füllung

# Problem: end_fill() fehlt
import turtle

pen = turtle.Turtle()
pen.color("red", "darkred")  # Füllfarbe hinzufügen
pen.begin_fill()
for _ in range(5):
    pen.forward(100)
    pen.right(144)
pen.end_fill()  # Fehlende Zeile hinzugefügt
turtle.done()

# %%
# ✅ Lösung Bug #3: Turtle bewegt sich nicht

# Problem: turtle.done() fehlt am Ende
import turtle

pen = turtle.Turtle()
pen.speed(1)  # Langsam genug zum Sehen
pen.color("white")
pen.forward(100)
turtle.done()  # Fehlende Zeile hinzugefügt
