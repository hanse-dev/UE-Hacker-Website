# %% [markdown]
# # 💎 Woche 2 – Datentypen und Variablen: Die vier magischen Elemente
#
# **XP zu verdienen:** 1000 Punkte
# **Boss:** Der Golem der verwirrten Formen

# %% [markdown]
# ## 🌟 Die Quest beginnt: Die Elemente der Macht
#
# Willkommen zurück, Abenteurer! In der Alchimistenwerkstatt vertiefst du, was du über Variablen weißt – und lernst die vier **magischen Elementtypen** richtig kennen.
#
# **Deine Mission:**
# - Lerne mit **f-Strings** Texte elegant zusammenzusetzen
# - Kenne die vier Typen: `String`, `Integer`, `Float`, `Boolean`
# - Benutze `type()` und `len()` um Variablen zu untersuchen
# - Lese Eingaben vom Benutzer mit `input()` ein
#
# > 💡 **Woche 1 Rückblick:** Du kennst schon Variablen und einfache Typen. Diese Woche gehen wir tiefer.

# %% [markdown]
# ## 📚 Zauberformel 1: f-Strings – die moderne Textformatierung
#
# Ein f-String ist die **modernere und lesbarere** Art, Variablen in Text einzubauen. Das `f` vor den Anführungszeichen sagt Python: *"Schau in die geschweiften Klammern!"*
#
# **f-String vs. `+`-Verkettung – was soll ich benutzen?**
#
# | Methode | Beispiel | Empfehlung |
# |---------|---------|------------|
# | `+`-Verkettung | `"Hallo " + name` | funktioniert, braucht `str()` für Zahlen |
# | f-String | `f"Hallo {name}"` | moderner, kürzer, Zahlen funktionieren direkt |
#
# > ✅ Benutze f-Strings – sie sind klarer zu lesen und weniger fehleranfällig.
# > Die `+`-Methode aus Woche 1 funktioniert aber weiterhin.

# %%
# Beispiel 1: Einfache f-Strings
name = "Aria"
level = 5
print(f"Hallo {name}!")
print(f"Du bist Level {level}!")

# Beispiel 2: Mit Berechnungen
gold = 100
bonus = 25
print(f"Dein Gold: {gold + bonus}")

# Beispiel 3: Mehrere Variablen
held = "Thorin"
klasse = "Krieger"
waffe = "Axt"
print(f"{held} der {klasse} schwingt seine {waffe}!")

# %% [markdown]
# ## 📦 Zauberformel 2: Die vier Elementtypen
#
# Jede Variable in Python hat einen **Typ** – er bestimmt, was man damit tun kann.
#
# | Typ | Fachbegriff | Beispiel | Wofür |
# |-----|------------|---------|-------|
# | Text | `str` | `"Hallo"` | Namen, Texte, Zaubersprüche |
# | Ganze Zahl | `int` | `42` | Level, Gold, Punkte |
# | Kommazahl | `float` | `3.14` | Prozente, Schadenswerte |
# | Ja/Nein | `bool` | `True` / `False` | Schalter, Zustände |
#
# **Zwei nützliche Hilfsbefehle:**
# - `type(x)` – zeigt dir den Typ einer Variable an
# - `len(x)` – zeigt dir die Länge eines Textes (oder später einer Liste)
#
# ```python
# name = "Aria"
# print(type(name))   # <class 'str'>
# print(len(name))    # 4
# ```

# %%
# Beispiel 1: Strings - Textelemente
zauber = "Feuerball"
beschreibung = "Ein mächtiger Feuerzauber"
print(f"Zauber: {zauber}")
print(f"Typ: {type(zauber)}")

# Beispiel 2: Integers - Ganze Zahlen
level = 12
lebenspunkte = 150
print(f"Level: {level}, LP: {lebenspunkte}")
print(f"Typ: {type(level)}")

# Beispiel 3: Floats - Kommazahlen
schaden = 23.5
prozent = 87.25
print(f"Schaden: {schaden}, Trefferchance: {prozent}%")
print(f"Typ: {type(schaden)}")

# Beispiel 4: Booleans - Wahrheitswerte
magie_aktiv = True
vergiftet = False
print(f"Magie aktiv: {magie_aktiv}")
print(f"Vergiftet: {vergiftet}")
print(f"Typ: {type(magie_aktiv)}")

# %% [markdown]
# ## ✨ Zauberformel 3: Element-Operationen und Umwandlungen
#
# **Was es ist:** Wie du Elemente kombinierst, veränderst und von einer Form in eine andere wandelst.
#
# **Warum nützlich:**
# - ⚔️ Mathematische Operationen für Berechnungen
# - 🔤 Textoperationen für Nachrichten
# - 🔄 Typumwandlung für flexible Nutzung
# - 📊 Eingaben verarbeiten und nutzen
#
# **Wichtig:** Nicht alle Elemente können direkt kombiniert werden!

# %%
# Beispiel 1: Mathematische Operationen
gold_a = 150
gold_b = 75
print(f"Gesamtgold: {gold_a + gold_b}")
print(f"Differenz: {gold_a - gold_b}")
print(f"Doppeltes Gold: {gold_a * 2}")
print(f"Geteilt: {gold_a / 3}")

# Beispiel 2: String-Operationen
vorname = "Luna"
nachname = "Silbermond"
titel = "die Weise"
voller_name = vorname + " " + nachname + " " + titel
print(f"Voller Name: {voller_name}")
print(f"Name mal 3: {vorname * 3}")

# Beispiel 3: Typumwandlung
alter_str = "25"
alter_int = int(alter_str)
print(f"Alter als Text: {alter_str} (Typ: {type(alter_str)})")
print(f"Alter als Zahl: {alter_int} (Typ: {type(alter_int)})")

# Beispiel 4: Eingaben verarbeiten
# Eingabe simuliert (später mit input())
eingabe = "42"
zahl = int(eingabe)
print(f"Die Zahl {zahl} verdoppelt ist {zahl * 2}")

# %% [markdown]
# ## 🔮 Zauberformel 4: input() – Das Orakel befragt
#
# `input()` liest eine Eingabe vom Benutzer ein. Das Ergebnis ist immer ein **String** – auch wenn jemand eine Zahl tippt. Für Zahlen muss man den Wert also noch umwandeln:
#
# ```python
# name = input("Wie heißt du? ")       # ergibt einen String
# alter = int(input("Wie alt bist du? ")) # String → Integer
# ```
#
# > ⚠️ In diesen Notebooks läuft `input()` nur, wenn du das Notebook lokal ausführst oder in einer interaktiven Umgebung bist.

# %%
# Beispiel: Eingabe einlesen und verarbeiten
# (lokal ausführen – in statischen Umgebungen ggf. kommentieren)

name = input("Wie heißt dein Held? ")
level_str = input("Welches Level hat er? ")
level = int(level_str)   # String → Integer

print(f"Willkommen, {name}!")
print(f"{name} ist auf Level {level}.")
print(f"In 5 Levels erreichst du Level {level + 5}.")

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein junger Magier hat versucht, seine ersten Zauber zu wirken, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1

name = "Gandalf"
level = 99
print("Hallo name! Du bist Level level!")

# %%
# 🐛 Bug #2

zauberkraft = "100"
bonus = 50
print(f"Gesamtkraft: {zauberkraft + bonus}")

# %%
# 🐛 Bug #3

gold = 250
print(f"Dein Gold: gold + 50")

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Schatz des Magiers
#
# **Belohnung:** 300 XP + Kristallkugel
#
# Ein alter Magier hat seinen Schatz versteckt. Finde ihn, indem du die Hinweise entschlüsselst!
#
# **Deine Aufgaben:**
#
# 1. **Heldenname festlegen**
#    - Erstelle eine Variable für deinen Heldennamen
#    - Erstelle eine Variable für deine Helden-ID (Ganzzahl)
#    - Gib beide Werte mit f-Strings aus
#
# 2. **Schatztruhen erfassen**
#    - Speichere die Anzahl der Truhen als Ganzzahl
#    - Speichere das Gold pro Truhe als Kommazahl (z.B. 125.5)
#    - Gib beide Werte formatiert aus
#
# 3. **Gesamtgold berechnen**
#    - Multipliziere die Truhen mit dem Gold pro Truhe
#    - Speichere das Ergebnis in einer Variable
#    - Gib das Gesamtgold mit f-String aus
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Heldenname festlegen
# held_name = "Thorin"
# held_id = 777
#
# # 2. Schatztruhen erfassen
# anzahl_truhen = 5
# gold_pro_truhe = 125.5
#
# # 3. Berechnung
# gesamtgold = anzahl_truhen * gold_pro_truhe
# print(f"Gesamtgold: {gesamtgold} Münzen")
# ```
#
# **Bonus-Challenge:**
# - Füge eine Variable für magischen Staub pro Truhe hinzu und berechne die Gesamtmenge!
#
# **Erwartete Ausgabe:**
# ```
# Held: Thorin
# ID: 777
# Schatztruhen: 5
# Gold pro Truhe: 125.5 Münzen
# Gesamtgold: 627.5 Münzen
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Das Zauberbuch
#
# **Belohnung:** 400 XP + Magisches Tintenfass
#
# Du musst ein Zauberbuch mit Informationen über verschiedene Sprüche erstellen!
#
# **Deine Aufgaben:**
#
# 1. **Zauber benennen**
#    - Erstelle drei Variablen für Zaubernamen als Text
#    - Erstelle drei Variablen für Schadenswerte als Ganzzahlen
#    - Erstelle drei Variablen für Mana-Kosten als Ganzzahlen
#
# 2. **Zauberprotokoll ausgeben**
#    - Gib eine Überschrift "=== ZAUBERBUCH ===" aus
#    - Gib jeden Zauber mit Name, Schaden und Mana-Kosten aus
#    - Nutze f-Strings für formatierte Ausgaben
#
# 3. **Gesamtschaden berechnen**
#    - Addiere alle Schadenswerte
#    - Speichere die Summe in einer Variable
#    - Gib den Gesamtschaden formatiert aus
#
# 4. **Durchschnittsschaden ermitteln**
#    - Addiere alle Schadenswerte und teile durch 3
#    - Speichere den Durchschnitt in einer Variable
#    - Gib das Ergebnis aus
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Zauber benennen
# zauber1_name = "Feuerball"
# zauber1_schaden = 50
# zauber1_mana = 30
#
# zauber2_name = "Eisblitz"
# zauber2_schaden = 45
# zauber2_mana = 25
#
# # 2. Ausgabe
# print("=== ZAUBERBUCH ===")
# print(f"Zauber 1: {zauber1_name}, Schaden: {zauber1_schaden}, Mana: {zauber1_mana}")
# ```
#
# **Bonus-Challenge:**
# - Berechne die durchschnittlichen Mana-Kosten!
#
# **Erwartete Ausgabe:**
# ```
# === ZAUBERBUCH ===
# Zauber 1: Feuerball, Schaden: 50, Mana: 30
# Zauber 2: Eisblitz, Schaden: 45, Mana: 25
# Zauber 3: Blitzschlag, Schaden: 60, Mana: 35
#
# Gesamtschaden: 155
# Durchschnittsschaden: 51.67
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Die Arena des Champions
#
# **Belohnung:** 500 XP + Championmedaille
#
# In der Arena kämpfen die besten Helden. Berechne ihre Statistiken!
#
# **Deine Aufgaben:**
#
# 1. **Helden erstellen**
#    - Erstelle für Held 1: Name, Level, Stärke, Intelligenz
#    - Erstelle für Held 2: Name, Level, Stärke, Intelligenz
#    - Nutze passende Datentypen (String für Namen, Integer für Zahlen)
#
# 2. **Gesamtstatistik berechnen**
#    - Berechne für Held 1: Stärke + Intelligenz
#    - Berechne für Held 2: Stärke + Intelligenz
#    - Speichere beide Ergebnisse in Variablen
#
# 3. **Stärkeren Helden bestimmen**
#    - Gib beide Helden mit ihren Gesamtstatistiken aus
#    - Vergleiche die Werte und bestimme den Stärkeren
#    - Nutze einen Boolean um zu markieren, welcher Held stärker ist
#
# 4. **Kampfansage ausgeben**
#    - Gib eine Nachricht aus, wer stärker ist
#    - Berechne die durchschnittliche Stärke beider Helden
#    - Gib die Differenz zwischen den Gesamtstatistiken aus
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Helden erstellen
# held1_name = "Thorin"
# held1_level = 15
# held1_staerke = 85
# held1_intelligenz = 60
#
# held2_name = "Aria"
# held2_level = 14
# held2_staerke = 70
# held2_intelligenz = 90
#
# # 2. Gesamtstatistik berechnen
# gesamt1 = held1_staerke + held1_intelligenz
# gesamt2 = held2_staerke + held2_intelligenz
#
# print(f"{held1_name}: {gesamt1} Punkte")
# ```
#
# **Bonus-Challenge:**
# - Berechne, wie viel stärker der Sieger ist!
#
# **Erwartete Ausgabe:**
# ```
# === ARENA-KAMPF ===
# Thorin: 145 Punkte
# Aria: 160 Punkte
#
# Aria ist stärker!
# Durchschnittsstärke: 77.5
# Differenz: 15 Punkte
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten des alten Magiers (Reflexion)
#
# Bevor du weiterziehst, denke über diese Fragen nach:
#
# 1. **Warum ist es wichtig zu wissen, welchen Datentyp eine Variable hat?**
#
# 2. **Was passiert, wenn du versuchst, Text und Zahlen zu addieren?**
#
# 3. **Wann würdest du Boolean-Werte in einem Spiel verwenden?**
#
# Diskutiere deine Gedanken mit anderen Abenteurern!

# %% [markdown]
# ### 📖 Zauberspruch-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **f-string** ✨: Moderne Textformatierung mit f"...{variable}..."
# - **String** 🔤: Textdatentyp, immer in Anführungszeichen
# - **Integer** 🔢: Ganzzahliger Datentyp ohne Komma
# - **Float** 💧: Kommazahl-Datentyp für Dezimalwerte
# - **Boolean** ✅: Wahrheitswert, nur True oder False
# - **type()** 🔍: Funktion zum Überprüfen des Datentyps
# - **int()** 🔄: Wandelt in Integer um
# - **float()** 💧: Wandelt in Float um
# - **str()** 🔤: Wandelt in String um
# - **bool()** ✅: Wandelt in Boolean um
# - **Variable** 📦: Behälter für Daten mit Namen
# - **Operation** ⚡: Berechnung oder Aktion mit Daten

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Hake ab, was du schon kannst:
#
# - ☐ f-Strings für die Textformatierung verwenden
# - ☐ Die vier Grunddatentypen kennen und anwenden
# - ☐ `type()` und `len()` benutzen
# - ☐ Typumwandlungen durchführen (`int()`, `float()`, `str()`)
# - ☐ Eingaben mit `input()` einlesen

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Fantastisch!** Du hast die vier magischen Elemente gemeistert!
#
# **Das hast du gelernt:**
# - f-Strings für moderne Textformatierung
# - Die vier fundamentalen Datentypen von Python
# - Mathematische und textliche Operationen
# - Die Kunst der Typumwandlung
# - Die Verarbeitung von Benutzereingaben
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🎮 **Spiele:** Charakterstatistiken, Punktestände, Inventar
# - 📱 **Apps:** Benutzerprofile, Einstellungen, Nachrichten
# - 🌐 **Websites:** Formulardaten, Berechnungen, Inhalte
# - 🤖 **Chatbots:** Konversationen, Entscheidungen, Antworten
# - 📊 **Datenanalyse:** Zahlen, Texte, Statistiken
#
# **Als Nächstes:** In Woche 3 lernst du **Bedingungen (if-else)**!

# %% [markdown]
# ## 🐉 Boss-Kampf: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Quests sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 XP + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Der Schatzraum
#
# **Belohnung:** 500 XP + Schatzschlüssel
#
# Der Schatzraum hat 8 Truhen. Jede muss katalogisiert werden!
#
# **Deine Aufgaben:**
#
# 1. **Schätze erfassen**
#    - Erstelle Variablen für 8 Truhen mit Namen (String) und Goldwert (Integer)
#    - Gib jeder Truhe eine eindeutige Bezeichnung
#    - Nutze passende Datentypen für jede Eigenschaft
#
# 2. **Schatzprotokoll erstellen**
#    - Gib eine Überschrift "=== SCHATZRAUM-PROTOKOLL ===" aus
#    - Erstelle eine Beschreibung für jede Truhe mit f-Strings
#    - Zeige Name und Goldwert übersichtlich an
#
# 3. **Durchschnitt berechnen**
#    - Addiere alle Goldwerte
#    - Teile die Summe durch 8
#    - Speichere und gib den Durchschnitt aus
#
# 4. **Reichste Truhe finden**
#    - Vergleiche alle Goldwerte
#    - Bestimme die Truhe mit dem höchsten Wert
#    - Gib den Namen der reichsten Truhe aus
#
# 5. **Gesamtwert ermitteln**
#    - Berechne den Gesamtwert aller Truhen
#    - Addiere alle Goldwerte
#    - Zeige das Ergebnis formatiert an
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Schätze erfassen
# print("=== SCHATZRAUM-PROTOKOLL ===")
# print()
#
# truhe1_name = "Drachen-Truhe"
# truhe1_gold = 1000
#
# truhe2_name = "Königs-Truhe"
# truhe2_gold = 850
#
# # ... weitere Truhen
#
# # 2. Schatzprotokoll
# print(f"Truhe 1: {truhe1_name} - {truhe1_gold} Gold")
# print(f"Truhe 2: {truhe2_name} - {truhe2_gold} Gold")
#
# # 3. Berechnungen
# durchschnitt = (truhe1_gold + truhe2_gold + ...) / 8
# ```
#
# **Bonus-Challenge:**
# - Zähle und gib aus, wie viele Truhen unter dem Durchschnitt liegen!
#
# **Erwartete Ausgabe:**
# ```
# === SCHATZRAUM-PROTOKOLL ===
#
# Truhe 1: Drachen-Truhe - 1000 Gold
# Truhe 2: Königs-Truhe - 850 Gold
# ...
#
# Durchschnittswert: 750 Gold
# Reichste Truhe: Drachen-Truhe (1000 Gold)
# Gesamtwert: 6000 Gold
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Die Zauberwerkstatt
#
# **Belohnung:** 600 XP + Zaubermeister-Titel
#
# In der Zauberwerkstatt experimentierst du mit magischen Formeln!
#
# **Deine Aufgaben:**
#
# 1. **Zauber erstellen**
#    - Erstelle 5 Zauber mit Name, Stärke (Float 0-100), Komplexität (1-5), Zauberdauer (Sekunden)
#    - Nutze passende Datentypen für jede Eigenschaft
#    - Gib jedem Zauber einen eindeutigen Namen
#
# 2. **Zauberbeschreibungen ausgeben**
#    - Gib eine Überschrift "=== ZAUBERWERKSTATT-PROTOKOLL ===" aus
#    - Erstelle eine Beschreibung für jeden Zauber mit f-Strings
#    - Zeige alle Eigenschaften formatiert an
#
# 3. **Komplexität summieren**
#    - Addiere alle Komplexitätswerte der Zauber
#    - Speichere die Gesamtzahl in einer Variable
#    - Gib die Summe formatiert aus
#
# 4. **Stärkste Zauber finden**
#    - Finde den stärksten Zauber (höchste Stärke)
#    - Finde den komplexesten Zauber (höchste Komplexität)
#    - Gib beide Namen aus
#
# 5. **Durchschnittsstärke berechnen**
#    - Addiere alle Stärken und teile durch 5
#    - Speichere den Durchschnitt
#    - Gib das Ergebnis auf 2 Nachkommastellen aus
#
# 6. **Mächtige filtern**
#    - Bestimme, welche Zauber über dem Durchschnitt liegen
#    - Nutze Boolean-Variablen zur Markierung
#    - Gib die mächtigen Zauber aus
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Zauber erstellen
# print("=== ZAUBERWERKSTATT-PROTOKOLL ===")
# print()
#
# zauber1_name = "Feuerball"
# zauber1_staerke = 85.5
# zauber1_komplexitaet = 3
# zauber1_dauer = 2
#
# zauber2_name = "Eisblitz"
# zauber2_staerke = 72.0
# zauber2_komplexitaet = 2
# zauber2_dauer = 1
#
# # ... weitere Zauber
#
# # 2. Ausgabe
# print(f"Zauber 1: {zauber1_name}")
# print(f"  Stärke: {zauber1_staerke}")
# print(f"  Komplexität: {zauber1_komplexitaet}")
# print(f"  Dauer: {zauber1_dauer}s")
# ```
#
# **Bonus-Challenge:**
# - Berechne die Effizienz (Stärke / Komplexität) für jeden Zauber!
#
# **Erwartete Ausgabe:**
# ```
# === ZAUBERWERKSTATT-PROTOKOLL ===
#
# Zauber 1: Feuerball
#   Stärke: 85.5
#   Komplexität: 3
#   Dauer: 2s
# ...
#
# Gesamtkomplexität: 15
# Stärkster Zauber: Feuerball (85.5)
# Komplexester Zauber: Feuerball (3)
# Durchschnittsstärke: 78.50
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Die Quest-Planung
#
# **Belohnung:** 400 XP + Quest-Buch
#
# Plane die nächste große Quest!
#
# **Deine Aufgaben:**
#
# 1. **Quests definieren**
#    - Erstelle Quest 1: Ziel, Dauer (Tage), Belohnung, Gruppengröße, Erfolgswahrscheinlichkeit (0-1)
#    - Erstelle Quest 2: Ziel, Dauer (Tage), Belohnung, Gruppengröße, Erfolgswahrscheinlichkeit (0-1)
#    - Nutze passende Datentypen (String für Ziel, Integer/Float für Zahlen)
#
# 2. **Questprotokoll erstellen**
#    - Gib eine Überschrift "=== QUEST-PROTOKOLL ===" aus
#    - Stelle beide Quests mit allen Daten vor
#    - Nutze f-Strings für formatierte Ausgaben
#
# 3. **Gesamtwerte berechnen**
#    - Addiere die Gesamtbelohnung beider Quests
#    - Addiere die Gesamt-Gruppengröße
#    - Gib beide Summen formatiert aus
#
# 4. **Erfolg prognostizieren**
#    - Berechne erwartete Belohnung: Belohnung × Erfolgswahrscheinlichkeit
#    - Berechne für beide Quests
#    - Gib die Prognosen aus
#
# 5. **Quests vergleichen**
#    - Vergleiche Belohnung, Dauer und Erfolgswahrscheinlichkeit
#    - Zeige Unterschiede deutlich an
#    - Nutze Berechnungen für den Vergleich
#
# 6. **Rentabilität bestimmen**
#    - Finde heraus, welche Quest rentabler ist
#    - Nutze Boolean-Variable zur Markierung
#    - Gib die Entscheidung klar aus
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Quests definieren
# print("=== QUEST-PROTOKOLL ===")
# print()
#
# quest1_ziel = "Drachenhort"
# quest1_dauer = 5
# quest1_belohnung = 1000
# quest1_gruppe = 4
# quest1_erfolg = 0.85
#
# quest2_ziel = "Verlorene Stadt"
# quest2_dauer = 8
# quest2_belohnung = 1500
# quest2_gruppe = 6
# quest2_erfolg = 0.70
#
# # 2. Ausgabe
# print(f"Quest 1: {quest1_ziel}")
# print(f"  Dauer: {quest1_dauer} Tage")
# print(f"  Belohnung: {quest1_belohnung} Gold")
# ```
#
# **Bonus-Challenge:**
# - Berechne die Belohnung pro Gruppenmitglied für jede Quest!
#
# **Erwartete Ausgabe:**
# ```
# === QUEST-PROTOKOLL ===
#
# Quest 1: Drachenhort
#   Dauer: 5 Tage
#   Belohnung: 1000 Gold
#   Gruppengröße: 4
#   Erfolgswahrscheinlichkeit: 0.85
#
# Quest 2: Verlorene Stadt
#   Dauer: 8 Tage
#   Belohnung: 1500 Gold
#   Gruppengröße: 6
#   Erfolgswahrscheinlichkeit: 0.70
#
# Gesamtbelohnung: 2500 Gold
# Gesamtgruppengröße: 10
# Erwartete Belohnung Quest 1: 850.0 Gold
# Erwartete Belohnung Quest 2: 1050.0 Gold
# Quest 2 ist rentabler!
# ```

# %%
# 🐉 Deine Lösung hier:

print()
print("🎉 +400 XP: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Golem der verwirrten Formen besiegt!")
print("⭐ Titel erhalten: Meister der Elemente")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 2 gemeistert!")
print("📚 Nächste Woche: Bedingungen (if-else)!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen:

# %%
# ✅ Lösung Bug #1: Falscher Zauber

# Problem: Kein f-String verwendet
name = "Gandalf"
level = 99
print(f"Hallo {name}! Du bist Level {level}!")

# %%
# ✅ Lösung Bug #2: Elementenkollision

# Problem: String und Integer können nicht addiert werden
zauberkraft = "100"
bonus = 50
print(f"Gesamtkraft: {int(zauberkraft) + bonus}")

# %%
# ✅ Lösung Bug #3: Falsche Formel

# Problem: Variable in f-String nicht in geschweifte Klammern
gold = 250
print(f"Dein Gold: {gold + 50}")
