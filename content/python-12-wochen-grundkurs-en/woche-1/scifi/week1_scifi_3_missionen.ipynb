# %% [markdown]
# # ⭐ Missions – 🚀 Week 1 – Introduction and your first program: Launch sequence!
#
# The time has come to prove your knowledge in real challenges!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: The Cadet
#
# **Reward:** 300 Cyber Credits + Data Pad
#
# Your first mission! Show that you have mastered the basic commands of the space station.
#
# **Step 1 – Output personal data:**
# Output your name with `print()` and output a greeting for the space station
#
# **Step 2 – Store service number:**
# Create a variable for your service number and output the service number in a complete sentence
#
# **Bonus:** Output your favourite space exploration quote!

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: The Data Technician
#
# **Reward:** 400 Cyber Credits + Scanner
#
# You need to log important ship data. Be precise and follow the format!
#
# **Step 1 – Create ship data:**
# Create a variable for the ship type (text) and create a variable for the registration number (text)
#
# **Step 2 – Output structured data:**
# Output a heading `"=== SHIP PROTOCOL ==="` and output each value with a description on its own line
#
# **Step 3 – Create complete report:**
# Create a sentence combining all three pieces of information and add a closing line `"=== END PROTOCOL ==="`
#
# **Bonus:** Add the ship's year of construction!

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: The Shuttle Pilot
#
# **Reward:** 500 Cyber Credits + Pilot Badge
#
# An important transport mission is waiting! Create a complete flight protocol.
#
# **Step 1 – Collect flight data:**
# Create a variable for the shuttle number and create a variable for the destination
#
# **Step 2 – Create protocol header:**
# Output a heading `"=== FLIGHT PROTOCOL ==="` and add an empty line
#
# **Step 3 – Write mission description:**
# Create 3 complete sentences about the flight and combine different variables in the sentences
#
# **Step 4 – Countdown to launch:**
# Output `"Launch in:"` and output `"3... 2... 1... Launch!"`
#
#
# > 💡 **Tip:** You decide how to implement it – there is no single right way!
# **Bonus:** Add the target coordinates (X, Y, Z)!

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### 🎯 Learning goals – Have you achieved them?
#
# Check for yourself whether you have mastered these skills:
#
# - ☐ Display text with `print()`
# - ☐ Store information in variables
# - ☐ Combine texts with `+` and `str()`
# - ☐ Add comments with `#`
# - ☐ Find and fix simple errors
# - ☐ Write your own small programs
#
# If you can tick all the boxes – congratulations! You're ready for the final challenges!
