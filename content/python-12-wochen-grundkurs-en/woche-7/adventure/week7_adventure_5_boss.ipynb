# %% [markdown]
# # 🐉 Boss Quests – ⚔️ Week 7 – Modules and Libraries: The Magical Toolboxes!
# > ⚠️ Harder! Combines everything from this week.
#
# **⚠️ ATTENTION:** These quests are significantly harder! They combine everything you have learned.
#
# **Rewards:** 1500 XP total + legendary items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 1: The Dice Tower
#
# **Reward:** 500 XP + Magic Dice
#
# The old wizard has built a dice tower – whoever rolls the highest number wins the treasure hunt!
#
# **Step 1 – Roll the dice:**
# Generate one dice roll (1–6) for 3 players using `random.randint()` and output the results.
#
# **Step 2 – Winner:**
# Find out who rolled the highest number and announce the winner.
#
# **Step 3 – Tournament:**
# Run 5 rounds and count who wins most often. Output the overall statistics at the end.
#
# **Bonus:** Add a "magic dice" (1–20) as a joker round.

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss Quest 2: The Magic Oracle
#
# **Reward:** 600 XP + Crystal Ball
#
# The oracle foretells the future – but only with mathematics and randomness!
#
# **Step 1 – Lucky number:**
# Let the user enter their name. Calculate a "magical lucky number" from the length of the name using `math` functions (e.g. `math.sqrt`, `math.floor`).
#
# **Step 2 – Prophecy:**
# Create a list with 6 prophecies and use `random.choice()` to pick a suitable one.
#
# **Step 3 – Horoscope:**
# Combine the lucky number and prophecy into a personal horoscope text and output it.
#
# **Bonus:** Show how likely this prophecy was (in %).

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 3: The Random Dungeon
#
# **Reward:** 400 XP + Dungeon Map
#
# No adventure is like another – a new dungeon every time!
#
# **Step 1 – Create rooms:**
# Create lists with possible room types (e.g. "Treasure Chamber", "Trap", "Empty Room") and monsters. Randomly select 5 rooms.
#
# **Step 2 – Distribute monsters:**
# Assign a random monster to each room (or none – some rooms are safe).
#
# **Step 3 – Output the dungeon:**
# Output the dungeon room by room: number, type and contents. At the end, calculate with `math.ceil()` how many lives the hero would need (1 life per 2 monsters, rounded up).
#
# **Bonus:** Let the player decide with `input()` whether to enter a dangerous room.

# %%
print()
print("🎉 +400 XP: Boss Quest completed!")
print("🏆 You defeated the Librarian of Infinite Spells!")
print("⭐ Title earned: Master of Libraries")
print()
print("🎊 CONGRATULATIONS! You have mastered Week 7!")
print("📚 Next week: Dictionaries and Tuples!")

# %% [markdown]
# ---
#
# 🎊 **Congratulations!** You have mastered all Boss Quests of this week!
#
# **Next up:** Week 8 is already waiting!
