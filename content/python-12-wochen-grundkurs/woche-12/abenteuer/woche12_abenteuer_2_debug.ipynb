# %% [markdown]
# # 🐛 Debug-Quest – 🏰 Woche 12 – Grafische Projekte mit Turtle: Die magische Leinwand!
#
# > 📖 Vorher: `…_1_lektion` durcharbeiten

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein Lehrling hat versucht, magische Zeichenrollen zu erstellen, aber etwas läuft schief! Finde die Fehler:

# %% [markdown]
# ### 🐛 Bug #1
#
# **Was passiert:** Dieser Code enthält einen Fehler – findest du ihn?

# %%
# 🐛 Bug #1: Falscher Import

# Der Code funktioniert nicht - warum?
import Turtle

pen = Turtle()
pen.forward(100)
pen.done()

# %% [markdown]
# ### 🐛 Bug #2
#
# **Was passiert:** Dieser Code enthält einen Fehler – findest du ihn?

# %%
# 🐛 Bug #2: Fehlende Füllung

# Warum ist der Stern nicht gefüllt?
import turtle

pen = turtle.Turtle()
pen.color("red")
pen.begin_fill()
for _ in range(5):
    pen.forward(100)
    pen.right(144)
# Fehlt etwas?

# %% [markdown]
# ### 🐛 Bug #3
#
# **Was passiert:** Dieser Code enthält einen Fehler – findest du ihn?

# %%
# 🐛 Bug #3: Turtle bewegt sich nicht

# Warum sieht man nichts?
import turtle

pen = turtle.Turtle()
pen.speed(0)
pen.color("white")
pen.forward(100)
# Was fehlt am Ende?
