# %% [markdown]
# # 🐛 Debug-Quest – 🚀 Woche 2 – Datentypen und Variablen: Die vier Quanten-Typen
#
# > 📖 Vorher: `…_1_lektion` durcharbeiten

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein junger Techniker hat versucht, die ersten Systembefehle auszuführen, aber etwas läuft schief! Finde die Fehler:

# %% [markdown]
# ### 🐛 Bug #1
#
# **Was passiert:** Dieser Code enthält einen Fehler – findest du ihn?

# %%
# 🐛 Bug #1

roboter = "R2D2"
status = 3
print("Hallo roboter! Dein Status ist status.")

# %% [markdown]
# ### 🐛 Bug #2
#
# **Was passiert:** Python kann Text und Zahlen nicht direkt zusammenfügen. Verwende `str()` um die Zahl zuerst in Text umzuwandeln.

# %%
# 🐛 Bug #2

energie = "80"
verbrauch = 30
print(f"Restenergie: {energie - verbrauch}")

# %% [markdown]
# ### 🐛 Bug #3
#
# **Was passiert:** Dieser Code enthält einen Fehler – findest du ihn?

# %%
# 🐛 Bug #3

schildstaerke = 95
print(f"Schildstärke: schildstaerke Prozent")
