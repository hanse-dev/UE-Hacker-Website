# %% [markdown]
# # ⭐ Missions – ⚔️ Week 9 – JSON Files and I/O: The Scrolls of Data
#
# The time has come to prove your knowledge in real challenges!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: The Quest Logger
#
# **Reward:** 300 XP + Magical Diary
#
# Create your first quest logging system!
#
# **Step 1 – Write quest log:**
# Open a file (e.g. `quest_log.txt`) with `with open(..., "w")`, write 3+ lines (quest status); print a confirmation.
# **Step 2 – Timestamp:**
# Use `datetime`, append entries with mode `"a"`; print a sample entry.
# **Step 3 – Log level:**
# Entries with [INFO], [WARN], [ERROR]; read the file and print its contents.
# 4. **Filter function** `filter_level(filename, level)` – return only lines with that level; call it and print the results.
#
# **Example code:** `with open("quest_log.txt", "w") as f: f.write(...)`; `datetime.now()` for the timestamp.
#
# **Bonus:** Simple rotation (new file when a size limit is reached).

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: The JSON Wizard
#
# **Reward:** 400 XP + Magic Wand
#
# Create a JSON magic system!
#
# 1. **Hero data as a dictionary** (name, class, level, hit_points); print it.
# **Step 2 – JSON export:**
# Save with `json.dump(..., indent=2)` to `hero.json`; print a confirmation.
# **Step 3 – JSON import:**
# Load with `json.load()`, check e.g. `data["name"]`; print the loaded data.
# 4. **Short statistics** (level, HP, etc.) from the loaded data.
#
# **Example code:** `hero = {...}`; `json.dump(hero, f, indent=2)`; `json.load(f)`.
#
# **Bonus:** Simple validation (check for expected keys).

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: The CSV Database
#
# **Reward:** 500 XP + Database Certificate
#
# Create a complete CSV management system!
#
# **Step 1 – CSV export:**
# Write a list of hero dictionaries (name, class, level) with `csv.DictWriter` to `heroes.csv` (`newline=""`); print a confirmation.
# **Step 2 – CSV import:**
# Read with `csv.DictReader`, collect rows into a list; print count and first row.
# 3. **Search function** – a function that returns rows matching a given class; call it and print results.
# **Step 4 – Short report:**
# Statistics (average level, count per class) from the read data.
#
# **Example code:** `csv.DictWriter`/`DictReader`; `fieldnames=["name", "class", "level"]`.
#
# **Bonus:** Check for expected columns.

# %%
# 🎯 Your solution here:

# %% [markdown]
# ### 🎯 Learning Goals – Have You Achieved Them?
#
# Check for yourself whether you have mastered these skills:
#
# - ☐ Read and write scrolls with open()
# - ☐ Import and export JSON data
# - ☐ Process CSV scrolls
# - ☐ Handle errors when accessing scrolls
# - ☐ Validate and transform data
# - ☐ Create complex data pipelines
