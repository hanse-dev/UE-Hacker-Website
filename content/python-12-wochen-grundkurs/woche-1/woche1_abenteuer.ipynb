# %% [markdown]
# # 🗺️ Woche 1 – Einführung und erstes Programm: Die Reise beginnt
#
# **XP zu verdienen:** 1000 Punkte
# **Boss:** Der Schweige-Drache der stummen Befehle

# %% [markdown]
# ## 🌟 Die Quest beginnt: Willkommen in Pythonia
#
# Willkommen, junger Abenteurer! Du betrittst die magische Welt von **Pythonia** – ein Land voller Geheimnisse, Abenteuer und mächtiger Zaubersprüche. Doch bevor du gegen Drachen kämpfen oder Schätze finden kannst, musst du die **Grundlagen der Programmier-Magie** erlernen.
#
# In dieser ersten Woche lernst du die beiden wichtigsten Zauber eines jeden Programmierers: **Variablen** (um Informationen zu speichern) und **print()** (um Nachrichten auszugeben). Diese einfachen Zauber sind die Grundlage für alles, was noch kommt!
#
# **Deine Mission:**
# - Lerne, wie du Text mit `print()` ausgibst
# - Verstehe, wie Variablen Informationen speichern
# - Kombiniere Texte und Variablen
# - Erstelle dein erstes interaktives Programm

# %% [markdown]
# ## 🎯 Was ist Programmieren?
#
# **Programmieren** ist wie Zaubersprüche schreiben! Du gibst dem Computer präzise Anweisungen, und er führt sie aus. Statt mit einem Zauberstab arbeitest du mit **Code** – geschriebenen Befehlen, die der Computer versteht.
#
# Python ist eine **Programmiersprache** – eine Sprache, die sowohl Menschen als auch Computer verstehen können. Sie ist besonders freundlich für Anfänger!
#
# **Warum ist Programmieren so mächtig?**
# - 🎮 **Spiele erschaffen:** Von einfachen Text-Abenteuern bis zu 3D-Welten
# - 🤖 **Aufgaben automatisieren:** Lass den Computer langweilige Arbeit erledigen
# - 🌍 **Probleme lösen:** Finde kreative Lösungen für echte Herausforderungen
# - 🚀 **Ideen verwirklichen:** Baue alles, was du dir vorstellen kannst
#
# **Fun Fact:** Python wurde nach der Comedy-Gruppe "Monty Python" benannt, nicht nach der Schlange! Der Erfinder Guido van Rossum wollte eine Sprache schaffen, die Spaß macht.

# %% [markdown]
# ### 🧙 Tutorial: Deine ersten Schritte
#
# Der alte Magier Pythonicus erklärt dir die Grundlagen:
#
# **"Der erste Zauber, den jeder Programmierer lernt, ist `print()`:"**

# %%
# Mit print() kannst du Text ausgeben
print("Hallo Welt!")

# Variablen speichern Informationen
name = "Gandalf"
level = 42

# Du kannst Variablen ausgeben
print(name)
print(level)

# Oder Texte kombinieren (mit +)
print("Hallo, " + name + "!")
print("Dein Level: " + str(level))

# %% [markdown]
# **Wichtige Regeln:**
# - Text steht immer in Anführungszeichen: `"Text"` oder `'Text'`
# - Variablennamen ohne Anführungszeichen: `name`, `level`
# - Zahlen in Text umwandeln mit `str()`: `str(42)`
# - Kommentare beginnen mit `#` – der Computer ignoriert sie

# %%
# 🌟 Level 1: Dein erster Zauber

# Der klassische erste Befehl jedes Programmierers
print("Hallo Welt!")
print("Willkommen in Pythonia!")

# Du kannst auch mehrere Zeilen ausgeben
print("Dies ist dein erstes Programm.")
print("Du bist jetzt ein Programmierer!")

print()
print("🎉 +100 XP: Erster Zauber erfolgreich gewirkt!")

# %% [markdown]
# ### 🎯 Power-Move: print() verstehen
#
# Der `print()`-Befehl ist dein wichtigstes Werkzeug:
# - Er gibt Text auf dem Bildschirm aus
# - Text muss in Anführungszeichen stehen: `"` oder `'`
# - Jeder `print()` macht automatisch eine neue Zeile
# - Du kannst auch leere Zeilen machen: `print()`

# %%
# 📦 Level 2: Variablen - Deine magischen Container

# Variablen speichern Informationen
held_name = "Aragorn"
held_level = 1
held_gold = 50

# Gib die Variablen aus
print("Dein Held:")
print(held_name)
print("Level:")
print(held_level)
print("Gold:")
print(held_gold)

print()
print("🎉 +150 XP: Variablen gemeistert!")

# %% [markdown]
# ### 📦 Skill-Erklärung: Variablen
#
# **Variablen** sind wie magische Container, die Informationen speichern:
#
# - **Name:** Beschreibt, was drin ist (z.B. `held_name`, `gold`)
# - **Wert:** Die gespeicherte Information (z.B. `"Aragorn"`, `50`)
# - **Zuweisung:** Mit `=` speicherst du einen Wert: `name = "Gandalf"`
#
# **Wichtig:** Variablennamen sollten aussagekräftig sein und keine Leerzeichen enthalten!

# %%
# ✨ Level 3: Texte kombinieren

# Speichere Informationen
name = "Legolas"
waffe = "Bogen"
pfeile = 20

# Kombiniere Text mit + (String-Verkettung)
print("Held: " + name)
print("Waffe: " + waffe)

# Zahlen müssen mit str() in Text umgewandelt werden
print("Pfeile: " + str(pfeile))

# Längere Kombinationen
print(name + " hat einen " + waffe + " mit " + str(pfeile) + " Pfeilen.")

print()
print("🎉 +200 XP: Text-Kombination erlernt!")

# %% [markdown]
# ### 🔗 Power-Move: String-Verkettung
#
# Mit dem `+` Operator kannst du Texte (Strings) verbinden:
#
# ```python
# "Hallo " + "Welt"  # Ergibt: "Hallo Welt"
# ```
#
# **Wichtig:** Zahlen müssen erst mit `str()` in Text umgewandelt werden:
#
# ```python
# "Level: " + str(5)  # Funktioniert!
# "Level: " + 5       # Fehler!
# ```

# %%
# 🎭 Level 4: Variablen ändern

# Starte mit Anfangswerten
gold = 100
print("Start-Gold: " + str(gold))

# Finde einen Schatz!
gold = 150
print("Nach dem Schatz: " + str(gold))

# Kaufe eine Waffe
gold = 50
print("Nach dem Kauf: " + str(gold))

# Variablen können sich ändern!
status = "gesund"
print("Status: " + status)

status = "verletzt"
print("Neuer Status: " + status)

print()
print("🎉 +250 XP: Variablen-Änderung verstanden!")

# %% [markdown]
# ### 🔄 Wichtiges Konzept: Variablen überschreiben
#
# Variablen können ihren Wert ändern:
#
# ```python
# leben = 100
# leben = 80   # Neuer Wert überschreibt den alten
# leben = 60   # Wieder ein neuer Wert
# ```
#
# Der alte Wert ist dann weg – die Variable speichert immer nur den neuesten Wert!

# %%
# 🗺️ Level 5: Deine erste Geschichte

# Erstelle Charaktere
held = "Frodo"
begleiter = "Sam"
ziel = "Mordor"

# Erzähle eine Geschichte
print("=== Die Quest beginnt ===")
print()
print(held + " und " + begleiter + " stehen am Anfang ihrer Reise.")
print("Ihr Ziel: " + ziel)
print()
print("Die Gefahr ist groß, aber ihr Mut ist größer!")
print("Das Abenteuer beginnt...")

print()
print("🎉 +200 XP: Erste Geschichte programmiert!")

# %% [markdown]
# ### 📖 Power-Move: Geschichten erzählen
#
# Mit `print()` und Variablen kannst du interaktive Geschichten erstellen:
# - Speichere Namen, Orte und Gegenstände in Variablen
# - Kombiniere sie zu Sätzen
# - Ändere die Variablen, um die Geschichte anzupassen
#
# Das ist die Grundlage für Text-Adventures und Spiele!

# %%
# 🎮 Level 6: Charakterbogen erstellen

# Erstelle einen vollständigen Charakter
name = "Gimli"
klasse = "Zwerg"
waffe = "Axt"
level = 5
leben = 120
mana = 30

# Zeige den Charakterbogen
print("====== CHARAKTERBOGEN ======")
print()
print("Name: " + name)
print("Klasse: " + klasse)
print("Waffe: " + waffe)
print()
print("Level: " + str(level))
print("Leben: " + str(leben))
print("Mana: " + str(mana))
print()
print("============================")

print()
print("🎉 +300 XP: Charaktersystem erstellt!")

# %% [markdown]
# ### 🎯 Skill-Erklärung: Datentypen
#
# Python kennt verschiedene Arten von Daten:
#
# - **String (Text):** `"Hallo"`, `'Welt'` – immer in Anführungszeichen
# - **Integer (Ganzzahl):** `42`, `100`, `-5` – ohne Anführungszeichen
# - **Float (Dezimalzahl):** `3.14`, `99.9` – mit Punkt statt Komma
#
# **Wichtig:** Text und Zahlen können nicht direkt kombiniert werden – nutze `str()` zur Umwandlung!

# %%
# 🏰 Level 7: Inventar-System

# Erstelle ein Inventar
spieler = "Boromir"
gegenstand1 = "Schwert"
gegenstand2 = "Schild"
gegenstand3 = "Heiltrank"
anzahl_traenke = 3
gold = 75

# Zeige das Inventar
print("====== INVENTAR ======")
print()
print("Spieler: " + spieler)
print()
print("Ausrüstung:")
print("- " + gegenstand1)
print("- " + gegenstand2)
print("- " + gegenstand3 + " (" + str(anzahl_traenke) + "x)")
print()
print("Gold: " + str(gold) + " Münzen")
print()
print("=====================")

print()
print("🎉 +250 XP: Inventar-System programmiert!")

# %% [markdown]
# ### 🎒 Wichtiges Konzept: Organisation
#
# Gute Programme sind übersichtlich:
# - **Aussagekräftige Namen:** `held_name` statt `x`
# - **Leerzeilen:** Trennen verschiedene Abschnitte
# - **Kommentare:** Erklären, was der Code macht
# - **Struktur:** Logischer Aufbau von oben nach unten

# %%
# 🏆 Level 8: Komplettes Abenteuer-Intro

# Charakter-Informationen
held_name = "Eowyn"
held_titel = "Schildmaid von Rohan"
held_level = 10
held_leben = 150
held_staerke = 85

# Quest-Informationen
quest_name = "Die Schlacht um Helms Klamm"
quest_ort = "Helms Klamm"
quest_gegner = "Uruk-hai"
quest_belohnung = 500

# Zeige das komplette Intro
print("="*50)
print("     WILLKOMMEN IN PYTHONIA     ")
print("="*50)
print()
print("HELD:")
print("  Name: " + held_name)
print("  Titel: " + held_titel)
print("  Level: " + str(held_level))
print("  Leben: " + str(held_leben) + " HP")
print("  Stärke: " + str(held_staerke))
print()
print("QUEST:")
print("  " + quest_name)
print("  Ort: " + quest_ort)
print("  Gegner: " + quest_gegner)
print("  Belohnung: " + str(quest_belohnung) + " XP")
print()
print("Die Dunkelheit naht...")
print(held_name + ", bist du bereit für den Kampf?")
print()
print("="*50)

print()
print("🎉 +400 XP: Meisterwerk erschaffen!")

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein junger Magier hat versucht, seine ersten Zauber zu wirken, aber etwas läuft schief! Drei seiner Programme enthalten typische Anfängerfehler. Kannst du sie finden und korrigieren?

# %% [markdown]
# ### 🐛 Bug #1: Die vergessenen Anführungszeichen

# %%
# 🐛 Dieser Code hat einen Fehler!

name = Gandalf
print("Willkommen, " + name)

# 🤔 Frage: Was ist das Problem?

# %% [markdown]
# ### 🐛 Bug #2: Die fehlende Umwandlung

# %%
# 🐛 Dieser Code hat einen Fehler!

level = 42
print("Dein Level: " + level)

# 🤔 Frage: Was ist das Problem?

# %% [markdown]
# ### 🐛 Bug #3: Der Tippfehler

# %%
# 🐛 Dieser Code hat einen Fehler!

held_name = "Aragorn"
print("Held: " + heldname)

# 🤔 Frage: Was ist das Problem?

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen! Der Rat der Magier hat drei Aufgaben für dich vorbereitet.

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Dein eigener Held
#
# **Belohnung:** 300 XP + Magisches Notizbuch
#
# Erstelle deinen eigenen Charakter!
#
# **Aufgaben:**
# 1. Erstelle Variablen für: Name, Klasse, Waffe, Level
# 2. Gib alle Informationen mit `print()` aus
# 3. Nutze String-Verkettung mit `+`
# 4. Vergiss nicht `str()` für Zahlen!
# 5. Mache es übersichtlich mit Leerzeilen
#
# **Bonus-Challenge:** Füge noch mehr Eigenschaften hinzu (Stärke, Geschicklichkeit, Intelligenz)!

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Die Quest-Beschreibung
#
# **Belohnung:** 400 XP + Questbuch der Abenteuer
#
# Erstelle eine Quest-Beschreibung wie in einem echten Spiel!
#
# **Aufgaben:**
# 1. Erstelle Variablen für: Quest-Name, Ort, Ziel, Belohnung (in Gold)
# 2. Erstelle eine Variable für den Auftraggeber
# 3. Gib eine schöne Quest-Beschreibung aus
# 4. Nutze Trennlinien (z.B. `print("===")`)
# 5. Mache es spannend und übersichtlich!
#
# **Bonus-Challenge:** Füge eine kurze Geschichte hinzu (3-4 Sätze), die die Quest erklärt!

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Der Kampf-Bericht
#
# **Belohnung:** 500 XP + Chronik der Schlachten
#
# Erstelle einen Kampf-Bericht wie nach einem Spiel!
#
# **Aufgaben:**
# 1. Erstelle Variablen für: Held-Name, Gegner-Name
# 2. Erstelle Variablen für: Held-Schaden, Gegner-Schaden
# 3. Erstelle Variablen für: Held-Leben (vorher/nachher), Gegner-Leben (vorher/nachher)
# 4. Gib einen kompletten Kampf-Bericht aus:
#    - Wer gegen wen gekämpft hat
#    - Wie viel Schaden verursacht wurde
#    - Wie viel Leben übrig ist
#    - Wer gewonnen hat
# 5. Mache es übersichtlich und spannend!
#
# **Bonus-Challenge:** Füge noch mehr Details hinzu (kritische Treffer, ausgewichene Angriffe, etc.)!

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten des alten Magiers (Reflexion)
#
# Bevor du weiterziehst, denke über diese Fragen nach:
#
# 1. **Warum sind Variablen so wichtig?** Was wäre der Nachteil, wenn du immer nur feste Werte verwenden würdest?
#
# 2. **Wann brauchst du `str()`?** Kannst du erklären, warum man Zahlen in Text umwandeln muss?
#
# 3. **Was macht ein Programm übersichtlich?** Welche Tricks hast du gelernt, um deinen Code lesbarer zu machen?
#
# 4. **Wo könntest du `print()` und Variablen im echten Leben nutzen?** Fallen dir Beispiele ein?
#
# Diskutiere deine Gedanken mit anderen Abenteurern oder deinem Mentor!

# %% [markdown]
# ### 🎤 Helden-Präsentation (Review)
#
# Zeit, deine Kreationen zu präsentieren! Wähle eine deiner Lösungen und stelle sie vor:
#
# **Zeige und erkläre:**
# - Welche Variablen hast du erstellt und warum?
# - Wie hast du Text und Variablen kombiniert?
# - Was war am schwierigsten?
# - Was würdest du beim nächsten Mal anders machen?
#
# **Diskussionspunkte:**
# - Wie könnte man das Programm erweitern?
# - Welche anderen Informationen könnte man speichern?
# - Wie würde man das in einem echten Spiel umsetzen?
# - Was sind die Grenzen von `print()` und Variablen?

# %% [markdown]
# ### 📖 Zauberspruch-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **print()** 📢: Gibt Text auf dem Bildschirm aus
# - **Variable** 📦: Speichert einen Wert unter einem Namen
# - **String** 📝: Text in Anführungszeichen (`"Hallo"`)
# - **Integer** 🔢: Ganzzahl ohne Anführungszeichen (`42`)
# - **str()** 🔄: Wandelt eine Zahl in Text um
# - **Zuweisung** ➡️: Speichert einen Wert in einer Variable (`name = "Gandalf"`)
# - **String-Verkettung** ➕: Verbindet Texte mit `+`
# - **Kommentar** 💭: Notiz im Code, beginnt mit `#`
# - **Anführungszeichen** " ": Markieren Text (`"` oder `'`)
# - **Code** 💻: Geschriebene Befehle für den Computer
# - **Programm** 🎮: Sammlung von Code-Befehlen
# - **Python** 🐍: Die Programmiersprache, die wir lernen

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ✅ Ich kann Text mit `print()` ausgeben
# - ✅ Ich kann Variablen erstellen und Werte speichern
# - ✅ Ich kann Texte mit `+` kombinieren
# - ✅ Ich kann Zahlen mit `str()` in Text umwandeln
# - ✅ Ich verstehe den Unterschied zwischen String und Integer
# - ✅ Ich kann übersichtliche Programme schreiben
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die Boss-Quests!

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise beginnt
#
# **Fantastisch!** Du hast die ersten Schritte in der Welt der Programmierung gemeistert!
#
# **Das hast du gelernt:**
# - `print()` gibt Text auf dem Bildschirm aus
# - Variablen speichern Informationen unter einem Namen
# - Mit `+` kannst du Texte kombinieren
# - `str()` wandelt Zahlen in Text um
# - Kommentare mit `#` helfen, Code zu erklären
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🎮 **Spiele:** Charaktere, Dialoge, Inventare
# - 📱 **Apps:** Benutzernamen, Nachrichten, Benachrichtigungen
# - 🌐 **Websites:** Texte, Überschriften, Inhalte
# - 🤖 **Chatbots:** Antworten, Begrüßungen, Informationen
# - 📊 **Datenanalyse:** Berichte, Zusammenfassungen, Ergebnisse
#
# **Als Nächstes:** In Woche 2 lernst du **Benutzereingaben** – wie dein Programm mit Menschen interagiert!

# %% [markdown]
# ## 🐉 Boss-Kampf: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Quests sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast, und erfordern kreatives Denken.
#
# **Belohnungen:** Insgesamt 1500 XP + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Das komplette Charakterprofil
#
# **Belohnung:** 500 XP + Buch der Helden
#
# Erstelle ein umfassendes Charakterprofil wie in einem echten RPG!
#
# **Aufgaben:**
# 1. Erstelle mindestens 10 verschiedene Variablen:
#    - Name, Titel, Klasse, Rasse
#    - Level, Erfahrungspunkte
#    - Leben, Mana, Ausdauer
#    - Stärke, Geschicklichkeit, Intelligenz
# 2. Erstelle Variablen für Ausrüstung (Waffe, Rüstung, Accessoire)
# 3. Erstelle Variablen für Ressourcen (Gold, Edelsteine)
# 4. Gib alles in einem schön formatierten Charakterbogen aus
# 5. Nutze Trennlinien und Überschriften
# 6. Füge eine kurze Hintergrundgeschichte hinzu (3-5 Sätze)
#
# **Bonus-Challenge:** Erstelle zwei verschiedene Charaktere und zeige beide Profile!

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Die epische Quest-Kette
#
# **Belohnung:** 600 XP + Chronik der großen Taten
#
# Erstelle eine Kette von 3 aufeinanderfolgenden Quests!
#
# **Aufgaben:**
# 1. Für jede Quest erstelle Variablen:
#    - Quest-Nummer, Name, Beschreibung
#    - Ort, Auftraggeber
#    - Ziel (was muss getan werden)
#    - Belohnung (Gold und XP)
# 2. Die Quests sollen eine zusammenhängende Geschichte erzählen
# 3. Gib alle 3 Quests übersichtlich aus
# 4. Nutze verschiedene Formatierungen für jede Quest
# 5. Füge eine Einleitung und einen Abschluss hinzu
# 6. Zeige den Fortschritt (Quest 1/3, Quest 2/3, Quest 3/3)
#
# **Bonus-Challenge:** Füge für jede Quest noch "Optionale Ziele" hinzu mit Extra-Belohnungen!

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Der Taverne-Simulator
#
# **Belohnung:** 400 XP + Schlüssel zur Goldenen Taverne
#
# Erstelle eine Simulation einer Taverne mit mehreren Charakteren!
#
# **Aufgaben:**
# 1. Erstelle Variablen für die Taverne:
#    - Name der Taverne, Ort, Wirt-Name
#    - Anzahl Gäste, Stimmung
# 2. Erstelle 3 verschiedene Gäste mit jeweils:
#    - Name, Beruf, Getränk
#    - Was sie sagen (ein Zitat)
# 3. Erstelle ein Menü mit 5 Gerichten und Preisen
# 4. Gib eine lebendige Taverne-Szene aus:
#    - Beschreibung der Taverne
#    - Vorstellung der Gäste und ihre Gespräche
#    - Das Menü
# 5. Nutze viele Details, um die Szene lebendig zu machen!
#
# **Bonus-Challenge:** Füge noch einen Barden hinzu, der ein Lied singt (3-4 Zeilen)!

# %%
# 🐉 Deine Lösung hier:

print()
print("🎉 +400 XP: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Schweige-Drachen besiegt!")
print("⭐ Titel erhalten: Meister der ersten Zauber")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 1 gemeistert!")
print("📚 Nächste Woche: Benutzereingaben – Lass dein Programm sprechen!")
