# %% [markdown]
# # ⭐ Missionen – ⚔️ Woche 7 – Module und Bibliotheken: Die magischen Werkzeugkästen!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Zauber-Importer
#
# **Belohnung:** 300 XP + Magischer Beutel
#
# In der Bibliothek von Pyralia lernst du, wie du Zauber-Bibliotheken (Module) lädst und mit Aliasen arbeitest.
#
# **Schritt 1 – Bibliotheken importieren:**
# Lade die Module `math`, `random` und `time` mit passenden Aliasen (z.B. `import math as m`) und gib jeweils eine Konstante oder Funktion aus jedem Modul aus (z.B. `math.pi`, `random.randint(1, 10)`)
#
# **Schritt 2 – Wartezeit-Zauber:**
# Erstelle eine kleine Funktion oder ein Skript, das eine zufällige Sekundenzahl (1–3) mit `random` erzeugt und `time.sleep()` nutzt und gib vor und nach der Wartezeit eine kurze Meldung aus (z.B. „Zauber lädt …“)
#
# **Schritt 3 – Flugbahn-Zauber:**
# Nutze `math.sin` und `math.pi`, um für einen Winkel (z.B. 90° in Bogenmaß) eine Höhe oder einen Wert zu berechnen und gib das Ergebnis formatiert aus
#
# **Schritt 4 – Gruppen-Generator:**
# Erstelle eine Namensliste mit 3–5 Helden-Namen und wähle mit `random.choice()` einen zufälligen Namen aus und gib den ausgewählten Namen aus
#
# **Bonus:** Füge einen weiteren Zauber mit dem `datetime`-Modul hinzu (z.B. aktuelle Uhrzeit anzeigen).

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Berechnungs-Zauber
#
# **Belohnung:** 400 XP + Kristallkugel
#
# Du nutzt das math-Modul für magische Kreisberechnungen, Winkelumrechnung und Wurzeln.
#
# **Schritt 1 – Kreis-Zauber:**
# Schreibe eine Funktion oder ein Skript, das für einen Radius (z.B. magischer Kreis) Umfang und Fläche mit `math.pi` berechnet und gib Radius, Umfang und Fläche formatiert aus
#
# **Schritt 2 – Zufalls-Zahlen und Summe:**
# Erzeuge mit `random.randint(1, 100)` fünf Zufallszahlen (z.B. für Mana-Werte) und speichere sie in einer Liste und berechne die Summe und gib die Zahlen sowie die Summe aus
#
# **Schritt 3 – Winkel-Umrechnung:**
# Wandle 90°, 180° und 270° mit `math.radians()` in Bogenmaß um und gib Grad und Bogenmaß für jeden Winkel aus
#
# **Schritt 4 – Wurzel-Ziehen:**
# Berechne mit `math.sqrt()` die Wurzeln von 4, 9, 16 und 25 und gib die Ergebnisse übersichtlich aus
#
# **Bonus:** Füge trigonometrische Zauber hinzu (z.B. sin, cos für 45°).

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Der Zufalls-Zauber
#
# **Belohnung:** 500 XP + Gilde-Meister-Urkunde
#
# Du baust ein kleines Zufallssystem mit Reichen, Wetter und Mana-Verbrauch.
#
# **Schritt 1 – Reichsauswahl:**
# Erstelle eine Liste mit 5–6 Reiche-Namen und wähle mit `random.choice()` ein zufälliges Reich aus und gib die Liste und das gewählte Reich aus
#
# **Schritt 2 – Wetter-Simulation:**
# Erzeuge mit `random.uniform(-50, 50)` drei Temperaturwerte (z.B. für verschiedene Regionen) und runde sie auf eine Dezimalstelle und gib die Temperaturen mit kurzer Beschreibung aus
#
# **Schritt 3 – Magie-Verbrauch:**
# Simuliere 3 Zauberer mit je einem zufälligen Mana-Verbrauch zwischen 50 und 150 (mit `random.randint` oder `random.uniform`) und gib Zauberer-Name und Mana aus und berechne den Gesamtverbrauch
#
# **Schritt 4 – Helden-Generator:**
# Erstelle 3 Helden-Namen mit zugehöriger zufälliger Stärke (1–10) und speichere sie (z.B. als Liste von Tupeln) und gib alle Helden mit ihrer Stärke aus
#
#
# > 💡 **Tipp:** Du entscheidest selbst, wie du das umsetzt – es gibt keinen einzig richtigen Weg!
# **Bonus:** Füge eine Variable mit Normalverteilung hinzu (z.B. `random.gauss(100, 20)` für Mana).

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ☐ Bibliotheken mit import laden
# - ☐ Spitznamen für Bibliotheken verwenden
# - ☐ Spezielle Zauber importieren
# - ☐ math-Bibliothek für Berechnungen nutzen
# - ☐ random-Bibliothek für Zufallszahlen verwenden
# - ☐ Bibliotheken in eigenen Programmen einsetzen
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die Boss-Quests!
