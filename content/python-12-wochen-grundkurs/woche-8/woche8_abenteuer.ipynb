# %% [markdown]
# # ⚔️ Woche 8 – Dictionaries und Tupel: Steckbriefe und Artefakte
#
# **XP zu verdienen:** 1000 Punkte
# **Boss:** Der Archivar des Gildenarchivs

# %% [markdown]
# ## 🌟 Die Quest beginnt: Das Gildenarchiv von Pyralia
#
# Willkommen im **Gildenarchiv von Pyralia** – hier werden alle Helden, Monster und Orte in **Steckbriefen** geführt. In dieser Woche lernst du die **zwei zentralen Datenstrukturen**:
#
# **Deine Mission:**
# - Meistere den **Steckbrief (Dictionary)** – Eigenschaften mit Namen statt Nummern
# - Beherrsche **Zugriff und Änderung** über Schlüssel
# - Lerne die **Artefakt-Kapsel (Tupel)** mit runden Klammern
# - Verstehe **Unveränderlichkeit** von Artefakten
#
# **Jeder Held hat seinen Steckbrief – jeder Eintrag seinen Schlüssel!** Das Archiv wartet auf dich...

# %% [markdown]
# ## 📚 Datenstruktur 1: Der Steckbrief – Eigenschaften mit Namen
#
# **Was es ist:** Ein Dictionary ist wie ein **Steckbrief**: Zu jeder **Eigenschaft** (Schlüssel) gehört ein **Wert**. Du erstellst ihn mit geschweiften Klammern.
#
# **Die Anatomie eines Steckbriefs:**
# ```python
# # Leeren Steckbrief anlegen
# leerer_steckbrief = {}
#
# # Steckbrief mit Eigenschaften füllen
# held = {"name": "Aria", "klasse": "Magierin", "level": 15}
# ```
#
# **Schritt-für-Schritt-Erklärung:**
# 1. **`{}`** – Geschweifte Klammern definieren einen Steckbrief
# 2. **`:`** – Doppelpunkt trennt Eigenschaftsname (Schlüssel) vom Wert
# 3. **`,`** – Kommas trennen die Einträge
# 4. **`[key]`** – Mit dem Schlüssel greifst du auf den Wert zu
#
# **Warum so nützlich:**
# - 🎯 Eigenschaften mit Namen statt Position (wie bei Listen)
# - 🔍 Schneller Zugriff über den Schlüssel
# - ⚡ Flexibel erweiterbar und änderbar
# - 🎲 Verschiedene Werttypen pro Eigenschaft möglich

# %%
# Beispiel 1: Einfache Steckbriefe erstellen
# Leerer Steckbrief
leerer_steckbrief = {}
print(f"Leerer Steckbrief: {leerer_steckbrief}")

# Helden-Steckbrief
held = {
    "name": "Aria",
    "klasse": "Magierin",
    "level": 15,
    "lebenspunkte": 120
}
print(f"Helden-Steckbrief: {held}")

# Monster-Steckbrief
monster = {
    "name": "Drache",
    "typ": "Feuer",
    "staerke": 50,
    "beute": True
}
print(f"Monster-Steckbrief: {monster}")

# %%
# Beispiel 2: Auf Steckbriefe zugreifen
held = {
    "name": "Aria",
    "klasse": "Magierin",
    "level": 15,
    "lebenspunkte": 120
}

print("=== Helden-Steckbrief auslesen ===")
print(f"Helden-Name: {held['name']}")
print(f"Klasse: {held['klasse']}")
print(f"Level: {held['level']}")
print(f"Lebenspunkte: {held['lebenspunkte']}")

# Mit get() Methode (sicherer)
print(f"\nMit get(): {held.get('name')}")
print(f"Nicht existierend: {held.get('mana', 'Unbekannt')}")

# %%
# Beispiel 3: Steckbriefe ändern und erweitern
held = {
    "name": "Aria",
    "klasse": "Magierin",
    "level": 15
}

print(f"Original: {held}")

# Wert ändern
held["level"] = 16
print(f"Nach Level-Up: {held}")

# Neue Eigenschaft hinzufügen
held["mana"] = 80
print(f"Nach Mana hinzufügen: {held}")

# Eintrag entfernen
entfernt = held.pop("klasse")
print(f"Entfernt: {entfernt}")
print(f"Nach entfernen: {held}")

# %% [markdown]
# ## 🔑 Datenstruktur 1b: Steckbriefe durchlaufen
#
# Um alle Einträge eines Dictionaries zu verarbeiten, gibt es drei Methoden:
#
# | Methode | Liefert | Beispiel |
# |---------|---------|----------|
# | `.keys()` | alle Schlüssel | `for k in held.keys()` |
# | `.values()` | alle Werte | `for v in held.values()` |
# | `.items()` | Schlüssel + Wert als Paar | `for k, v in held.items()` |
#
# `.items()` ist am nützlichsten – du bekommst beides auf einmal.

# %%
held = {
    "name": "Aria",
    "klasse": "Magierin",
    "level": 15,
    "lebenspunkte": 120
}

# .keys() – nur Schlüssel
print("Eigenschaften:", list(held.keys()))

# .values() – nur Werte
print("Werte:", list(held.values()))

# .items() – Schlüssel + Wert
print("\n=== Helden-Steckbrief ===")
for eigenschaft, wert in held.items():
    print(f"  {eigenschaft}: {wert}")

# %% [markdown]
# ## 📦 Datenstruktur 2: Das Artefakt – Die magische Kapsel
#
# **Die wichtigsten Artefakt-Eigenschaften:**
#
# **Erstellung:**
# - `artefakt = (1, 2, 3)` - Mit runden Klammern
# - `artefakt = 1, 2, 3` - Ohne Klammern
# - `artefakt = (1,)` - Ein Element mit Komma
#
# **Unveränderlichkeit:**
# - Einmal erstellt, können Artefakte nicht geändert werden
# - Perfekt für ewige Schätze
# - Magisch geschützt vor Veränderung

# %%
# 🔍 Übungen mit Artefakten

# Beispiel 1: Artefakte erstellen
koordinaten = (100, 200)
print(f"Koordinaten: {koordinaten}")

# Ohne Klammern
position = 10, 20
print(f"Position: {position}")

# Ein Element
einzel = (42,)
print(f"Einzelnes Artefakt: {einzel}")

# Zugriff auf Elemente
print(f"\nX-Koordinate: {koordinaten[0]}")
print(f"Y-Koordinate: {koordinaten[1]}")

# %%
# Beispiel 2: Artefakte sind unveränderlich
zauber_status = ("Aktiv", "Stabil", "Mächtig")
print(f"Zauber-Status: {zauber_status}")

# Zugriff funktioniert
print(f"Status: {zauber_status[0]}")

# Ändern funktioniert NICHT!
try:
    zauber_status[0] = "Inaktiv"
except TypeError as e:
    print(f"Fehler: {e}")

# Aber Artefakte in Listen können geändert werden
zauber = [
    ("Feuerball", "Aktiv"),
    ("Heilung", "Stabil"),
    ("Schild", "Mächtig")
]
zauber[1] = ("Heilung", "Inaktiv")
print(f"\nZauber nach Änderung: {zauber}")

# %%
# Beispiel 3: Artefakt unpacking und Methoden
held_daten = ("Aria", "Magierin", 15, 120)

# Artefakt unpacking
name, klasse, level, lebenspunkte = held_daten
print("=== Artefakt Unpacking ===")
print(f"Name: {name}")
print(f"Klasse: {klasse}")
print(f"Level: {level}")
print(f"Lebenspunkte: {lebenspunkte}")

# Artefakt-Methoden
print(f"\nAnzahl Elemente: {len(held_daten)}")
print(f"Index von 'Magierin': {held_daten.index('Magierin')}")
print(f"Anzahl 'Magierin': {held_daten.count('Magierin')}")

# %% [markdown]
# ## ✨ Verschachtelte Strukturen – Steckbriefe im Steckbrief
#
# **Die mächtigsten Kombinationen:**
#
# **Steckbrief in Steckbrief:**
# - `person = {"name": "Alex", "ausruestung": {"waffe": "X", "ruestung": "Y"}}`
#
# **Liste von Steckbriefen:**
# - `helden = [{"name": "A", "klasse": "M"}, {"name": "B", "klasse": "K"}]`
#
# **Artefakt (Tupel) als Steckbrief-Schlüssel:**
# - `positionen = {(10, 20): "Punkt A", (30, 40): "Punkt B"}`

# %%
# Beispiel 1: Steckbrief in Steckbrief
dungeon = {
    "name": "Verdammnis-Festung",
    "location": {
        "region": "Schattenlande",
        "koordinaten": (100, 200),
        "reich": "Pyralia"
    },
    "gefaehrten": {
        "boss": "Lich-König",
        "monster": "Skelette",
        "fallen": "Magisch"
    }
}

print("=== Verschachtelter Steckbrief ===")
print(f"Dungeon: {dungeon['name']}")
print(f"Region: {dungeon['location']['region']}")
print(f"Koordinaten: {dungeon['location']['koordinaten']}")
print(f"Boss: {dungeon['gefaehrten']['boss']}")

# %%
# Beispiel 2: Liste von Steckbriefen
helden = [
    {
        "name": "Aria",
        "klasse": "Magierin",
        "level": 15,
        "erfahrung": 2500
    },
    {
        "name": "Thorin",
        "klasse": "Krieger",
        "level": 18,
        "erfahrung": 3200
    },
    {
        "name": "Luna",
        "klasse": "Schurkin",
        "level": 12,
        "erfahrung": 1800
    }
]

print("=== Helden-Liste ===")
for held in helden:
    print(f"{held['name']} - {held['klasse']} (Level {held['level']})")

# Nach Level filtern
starke = [h for h in helden if h['level'] > 14]
print(f"\nStarke Helden: {[h['name'] for h in starke]}")

# %%
# Beispiel 3: Komplexe Strukturen
# Artefakt (Tupel) als Steckbrief-Schlüssel
schatz_karte = {
    (100, 200): "Goldtruhe",
    (300, 400): "Magie-Truhe",
    (500, 600): "Artefakt-Truhe"
}

print("=== Schatz-Karte (Tupel als Schlüssel) ===")
for position, schatz in schatz_karte.items():
    print(f"{position}: {schatz}")

# Komplexes Questsystem
quests = {
    "aktiv": [
        {
            "id": 1,
            "ziel": "Drache besiegen",
            "belohnung": ("Gold", 1000, "XP", 500),
            "status": "In Bearbeitung"
        }
    ],
    "abgeschlossen": [
        {
            "id": 2,
            "ziel": "Schatz finden",
            "belohnung": ("Silber", 500, "XP", 250),
            "status": "Erfolg"
        }
    ]
}

print(f"\nAktive Quests: {len(quests['aktiv'])}")
print(f"Abgeschlossene Quests: {len(quests['abgeschlossen'])}")

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein Archivarius hat versucht, die Steckbriefe zu pflegen, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1

held = {
    "name": "Aria",
    "klasse": "Magierin"
}
print(f"Held: {held}")

# %%
# 🐛 Bug #2

koordinaten = (100, 200)
koordinaten[0] = 150

# %%
# 🐛 Bug #3

helden = [
    {"name": "Aria", "klasse": "Magierin"},
    {"name": "Thorin", "klasse": "Krieger"}
]
print(helden[2])

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Steckbrief-Meister
#
# **Belohnung:** 300 XP + Magischer Beutel
#
# Im Gildenarchiv von Pyralia legst du deinen ersten **Steckbrief** (Dictionary) für Heldendaten an.
#
# **Deine Aufgaben:**
#
# 1. **Helden-Steckbrief anlegen**
#    - Erstelle ein Dictionary `held` mit Eigenschaften z.B. `name`, `klasse`, `level`, `lebenspunkte` und passenden Werten
#    - Gib das Dictionary mit `print()` aus
#    - Nutze geschweifte Klammern `{}` und Doppelpunkte für Schlüssel: Wert
#
# 2. **Werte ändern und ergänzen**
#    - Ändere den Wert von `level` (z.B. auf eine neue Zahl)
#    - Füge eine neue Eigenschaft `mana` mit einem Wert hinzu
#    - Gib das aktualisierte Dictionary aus
#
# 3. **Monster-Liste aus Steckbriefen**
#    - Erstelle eine Liste mit 3 Elementen; jedes Element ist ein Dictionary (Steckbrief) mit z.B. `name`, `typ`, `stärke`
#    - Gib die Liste und die Werte eines Monsters (z.B. `monster[0]["name"]`) aus
#
# 4. **Zugriff und Ausgabe**
#    - Greife mit `held["name"]` und `held.get("klasse")` auf Werte zu und gib sie aus
#    - Gib eine kurze übersichtliche Zusammenfassung (z.B. „Held X, Klasse Y, Level Z“) aus
#
# **Beispiel-Code zum Starten:**
# ```python
# held = {"name": "Elara", "klasse": "Magierin", "level": 5, "lebenspunkte": 80}
# print(f"Held: {held}")
#
# held["level"] = 6
# held["mana"] = 50
# print(f"Aktualisiert: {held}")
# ```
#
# **Bonus-Challenge:**
# - Erstelle ein verschachteltes Dictionary (z.B. Held mit Unter-Steckbrief „ausrüstung“).
#
# **Erwartete Ausgabe:**
# ```
# Held: {'name': 'Elara', 'klasse': 'Magierin', ...}
# Aktualisiert: {...}
# Monster 0: Ork, Stärke 10
# Zusammenfassung: Elara, Magierin, Level 6
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Artefakt-Meister
#
# **Belohnung:** 400 XP + Kristallkugel
#
# Du nutzt Tupel für Artefakte (unveränderliche magische Gegenstände) und kombinierst sie mit Dictionaries.
#
# **Deine Aufgaben:**
#
# 1. **Artefakte als Tupel**
#    - Erstelle mindestens zwei „Artefakte“ als Tupel (z.B. `artefakt1 = ("Schwert", 10, "Feuer")` für Name, Stärke, Element)
#    - Gib die Tupel und die Länge mit `len(artefakt1)` aus
#    - Greife per Index auf die Werte zu (z.B. `artefakt1[0]`, `artefakt1[1]`) und gib sie aus
#
# 2. **Tupel-Unpacking**
#    - Nutze Unpacking: `name, staerke, element = artefakt1` und gib name, staerke, element aus
#    - Erstelle ein zweites Artefakt-Tupel und unpacke es ebenfalls
#
# 3. **Artefakt-Dictionary**
#    - Erstelle ein Dictionary `artefakte`, in dem Schlüssel Namen (Strings) und Werte Tupel sind (z.B. `{"Feuerstab": ("Stab", 15, "Feuer"), "Eisring": ("Ring", 5, "Eis")}`)
#    - Gib das Dictionary aus und greife auf ein Artefakt zu (z.B. `artefakte["Feuerstab"]`)
#
# 4. **Abstand (vereinfacht)**
#    - Wenn deine Tupel Zahlen enthalten (z.B. Stärke, Level), schreibe eine einfache Funktion, die zwei solche Tupel vergleicht (z.B. Differenz der Stärken) oder die „Distanz“ zwischen zwei Koordinaten-Tupeln berechnet
#    - Gib das Ergebnis aus
#
# **Beispiel-Code zum Starten:**
# ```python
# artefakt1 = ("Schwert", 10, "Feuer")
# artefakt2 = ("Bogen", 8, "Wind")
# print(f"Artefakt1: {artefakt1}, len: {len(artefakt1)}")
#
# name, staerke, element = artefakt1
# print(f"Unpacked: {name}, {staerke}, {element}")
#
# artefakte = {"Feuerstab": ("Stab", 15, "Feuer"), "Eisring": ("Ring", 5, "Eis")}
# print(f"Feuerstab: {artefakte['Feuerstab']}")
# ```
#
# **Bonus-Challenge:**
# - Füge „4D-Artefakte“ hinzu (Tupel mit 4 Werten) und erweitere die Vergleichs- oder Abstandsberechnung.
#
# **Erwartete Ausgabe:**
# ```
# Artefakt1: ('Schwert', 10, 'Feuer'), len: 3
# Unpacked: Schwert, 10, Feuer
# Feuerstab: ('Stab', 15, 'Feuer')
# Differenz Stärke: 2
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Die Helden-Gilde
#
# **Belohnung:** 500 XP + Gilde-Meister-Urkunde
#
# Du baust eine kleine Helden-Gilde mit Liste von Dictionaries und Suchfunktionen.
#
# **Deine Aufgaben:**
#
# 1. **Helden-Liste aus Dictionaries**
#    - Erstelle eine Liste `helden`, in der jedes Element ein Dictionary ist mit z.B. `name`, `klasse`, `level`, `erfahrung` (XP)
#    - Lege mindestens 3 Helden an und gib die Liste aus
#
# 2. **Mitglieder hinzufügen**
#    - Füge mit `helden.append({...})` einen neuen Helden hinzu
#    - Gib die aktualisierte Liste und die Anzahl der Helden mit `len(helden)` aus
#
# 3. **Suchfunktion nach Klasse**
#    - Schreibe eine Funktion `suche_klasse(helden_liste, klasse)`, die alle Helden mit dieser Klasse zurückgibt (z.B. Liste von Dictionaries)
#    - Rufe die Funktion für eine Klasse (z.B. "Magier") auf und gib die gefundenen Helden aus
#
# 4. **Statistik und Zuweisung**
#    - Berechne das Durchschnittslevel der Helden (Summe der Level / Anzahl) und gib es aus
#    - Optional: Weise einem oder mehreren Helden ein neues Schlüssel-Wert-Paar zu (z.B. `"quest": "Drache besiegen"`) und gib die aktualisierte Liste aus
#
# **Beispiel-Code zum Starten:**
# ```python
# helden = [
#     {"name": "Elara", "klasse": "Magierin", "level": 5, "erfahrung": 120},
#     {"name": "Thor", "klasse": "Krieger", "level": 7, "erfahrung": 250},
#     {"name": "Luna", "klasse": "Magierin", "level": 4, "erfahrung": 80},
# ]
# print(f"Helden: {len(helden)} Mitglieder")
#
# def suche_klasse(helden_liste, klasse):
#     return [h for h in helden_liste if h.get("klasse") == klasse]
# ```
#
# **Bonus-Challenge:**
# - Füge zu jedem Helden Schlüssel wie `fähigkeiten` (Liste) oder `ausrüstung` hinzu und gib eine Übersicht aus.
#
# **Erwartete Ausgabe:**
# ```
# Helden: 3 Mitglieder
# Nach Hinzufügen: 4 Mitglieder
# Magier: [{'name': 'Elara', ...}, {'name': 'Luna', ...}]
# Durchschnittslevel: 5.3
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten des Archivars (Reflexion)
#
# Bevor du weitergehst, denke über diese Fragen nach:
#
# 1. **Warum sollte man einen Steckbrief (Dictionary) statt einer Liste verwenden?**
#
# 2. **Wann sind Artefakte (Tupel) besser als Listen?**
#
# 3. **Wie helfen verschachtelte Steckbriefe bei der Datenorganisation?**
#
# Diskutiere deine Gedanken mit anderen Abenteurern!

# %% [markdown]
# ### 📖 Archiv-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **dict** ⚔️: Datentyp für Steckbriefe (Dictionaries)
# - **{}** 📦: Geschweifte Klammern für Steckbriefe
# - **key** 🔑: Schlüssel (Eigenschaftsname) im Steckbrief
# - **value** 💎: Wert zur Eigenschaft
# - **tuple** 📍: Datentyp für Artefakte
# - **()** ⭕: Runde Klammern für Artefakte
# - **immutable** 🔒: Unveränderlich
# - **nested** 🎲: Verschachtelt
# - **unpacking** 📤: Auspacken von Artefakten
# - **get()** 🔍: Sichere Zugriffsmethode

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Hake ab, was du schon kannst:
#
# - ☐ Dictionaries erstellen und Werte abrufen
# - ☐ Werte ändern und neue Einträge hinzufügen
# - ☐ `.keys()`, `.values()`, `.items()` benutzen
# - ☐ `.get()` für sicheren Zugriff verwenden
# - ☐ Tupel erstellen und auspacken (Unpacking)
# - ☐ Verschachtelte Dictionaries lesen

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Legendär!** Du hast Steckbriefe und Artefakte gemeistert!
#
# **Das hast du gelernt:**
# - Steckbriefe (Dictionaries) für strukturierte Daten mit Namen
# - Artefakte (Tupel) für unveränderliche Daten
# - Verschachtelte Datenstrukturen
# - Zugriffsmethoden und Operationen
# - Komplexe Datenorganisation
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🎮 **Spiele:** Charaktere, Inventar, Spiel-Status
# - 📱 **Apps:** Benutzerprofile, Einstellungen, Konfigurationen
# - 🌐 **Websites:** JSON-Daten, Metadaten, Inhalte
# - 🤖 **KI-Systeme**: Modelleinstellungen, Parameter, Ergebnisse
# - 📊 **Wissenschaft:** Experiment-Daten, Messwerte, Ergebnisse

# %% [markdown]
# ## 🐉 Boss-Kampf: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Quests sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 XP + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Der Schatz-Steckbrief-Generator
#
# **Belohnung:** 500 XP + Schatzkarte
#
# Du baust einen Generator für zufällige **Schatz-Steckbriefe** (Dictionaries) und filterst sie im Archiv.
#
# **Deine Aufgaben:**
#
# 1. **Schatz-Steckbrief-Generator**
#    - Erstelle eine Funktion `generiere_schatz()` oder `generiere_schatz(name)`, die ein Dictionary (Steckbrief) mit z.B. `name`, `typ` (aus einer Liste mit `random.choice`), `wert` (`random.randint(10, 500)`), `seltenheit` (z.B. "normal", "selten", "legendär" mit `random.choice`) zurückgibt
#    - Gib einen Beispiel-Steckbrief aus
#
# 2. **Koordinaten und Entfernung**
#    - Schreibe eine Funktion `berechne_entfernung(koord1, koord2)`, die zwei 2D-Tupel nimmt und die euklidische Distanz berechnet: √((x1-x2)² + (y1-y2)²); nutze `math.sqrt` oder `**0.5`
#    - Behandle den Fall, dass die Tupel nicht genau 2 Elemente haben (z.B. Fehlermeldung oder 0 zurückgeben)
#    - Gib die Entfernung für zwei Beispiel-Koordinaten aus
#
# 3. **Archiv und Suche**
#    - Erstelle eine Liste `schaetze` und füge 10–20 generierte Schatz-Steckbriefe hinzu (mit einer Schleife)
#    - Schreibe eine Funktion `suche_name(schaetze, name)`, die den ersten Steckbrief mit passendem Namen zurückgibt (oder None)
#    - Schreibe eine Funktion `filter_typ(schaetze, typ)`, die alle Schätze mit diesem Typ zurückgibt
#    - Optional: Funktion `filter_seltenheit(schaetze, seltenheit)` für Seltenheitsfilter
#
# 4. **Statistik und Ausgabe**
#    - Berechne und gib aus: Anzahl Schätze, durchschnittlicher Wert, Anzahl pro Typ (z.B. mit Schleife und Dictionary für Zählung)
#    - Gib eine kurze übersichtliche Zusammenfassung aus
#
# **Beispiel-Code zum Starten:**
# ```python
# import random
# import math
#
# def generiere_schatz():
#     typen = ["Gold", "Artefakt", "Juwel"]
#     seltenheiten = ["normal", "selten", "legendär"]
#     return {
#         "name": f"Schatz-{random.randint(1, 1000)}",
#         "typ": random.choice(typen),
#         "wert": random.randint(10, 500),
#         "seltenheit": random.choice(seltenheiten)
#     }
#
# def berechne_entfernung(koord1, koord2):
#     if len(koord1) != 2 or len(koord2) != 2:
#         return 0
#     return math.sqrt((koord1[0]-koord2[0])**2 + (koord1[1]-koord2[1])**2)
# ```
#
# **Bonus-Challenge:**
# - Füge eine einfache Schatz-Validierung hinzu (z.B. wert > 0, seltenheit in erlaubter Liste).
#
# **Erwartete Ausgabe:**
# ```
# Beispiel-Schatz: {'name': 'Schatz-42', 'typ': 'Artefakt', ...}
# Entfernung: 50.0
# Gefunden: Schatz-42
# Filter Typ Artefakt: 7 Schätze
# Statistik: 20 Schätze, Ø Wert 255, Typen: Gold 8, Artefakt 6, Juwel 6
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Der Dungeon-Manager
#
# **Belohnung:** 600 XP + Dungeon-Meister-Titel
#
# Du verwaltest einen Dungeon als verschachteltes Dictionary mit Ebenen und Monstern.
#
# **Deine Aufgaben:**
#
# 1. **Dungeon-Struktur**
#    - Erstelle eine Funktion `erstelle_dungeon(name, ebenen_anzahl)`, die ein Dictionary zurückgibt mit z.B. `name`, `ebenen` (ein Dictionary mit Schlüsseln wie "1", "2" oder "Ebene-1", Wert z.B. `{"monster": [], "fallen": 0}`) und `schaetze` (Liste von Strings oder Dictionaries)
#    - Gib den Dungeon aus
#
# 2. **Ebenen und Monster-Zuweisung**
#    - Erstelle eine Funktion `platziere_monster(dungeon, ebene_nummer, monster_name)`, die in `dungeon["ebenen"][ebene_nummer]["monster"]` ein Monster einträgt (z.B. als String oder Dictionary mit name, typ)
#    - Gib die aktualisierte Dungeon-Struktur (z.B. welche Ebenen Monster haben) aus
#
# 3. **Suche und Statistik**
#    - Schreibe eine Funktion `suche_monster(dungeon, monster_name)`, die die Ebene zurückgibt, in der das Monster steht (oder None)
#    - Berechne eine kurze Statistik (z.B. wie viele Ebenen, wie viele Monster gesamt) und gib sie aus
#
# 4. **Ereignis (simuliert)**
#    - Erstelle eine Funktion `zufalls_ereignis(dungeon)`, die z.B. mit `random.choice` ein „Ereignis“ wählt (z.B. "Falle ausgelöst", "Schatz gefunden") und eine Meldung ausgibt oder einen Eintrag ändert
#    - Rufe sie einmal auf und gib das Ergebnis aus
#
# **Beispiel-Code zum Starten:**
# ```python
# import random
#
# def erstelle_dungeon(name, ebenen_anzahl):
#     ebenen = {str(i): {"monster": [], "fallen": 0} for i in range(1, ebenen_anzahl + 1)}
#     return {"name": name, "ebenen": ebenen, "schaetze": []}
#
# def platziere_monster(dungeon, ebene_nummer, monster_name):
#     dungeon["ebenen"][str(ebene_nummer)]["monster"].append(monster_name)
# ```
#
# **Bonus-Challenge:**
# - Füge einen „Boss“ pro Dungeon hinzu (z.B. Schlüssel `boss` im Dictionary) und gib den Boss der aktuellen Ebene aus.
#
# **Erwartete Ausgabe:**
# ```
# Dungeon: Verdammnis-Festung, 5 Ebenen
# Nach Monster: Ebene 1 = [Ork, Goblin], Ebene 2 = [Drache]
# Ork steht in Ebene 1
# Statistik: 5 Ebenen, 3 Monster
# Ereignis: Schatz gefunden
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Die Quest-Datenbank
#
# **Belohnung:** 400 XP + Quest-Buch
#
# Du verwaltest Quests als **Steckbriefe** (Dictionaries) mit Tupeln für unveränderliche Daten.
#
# **Deine Aufgaben:**
#
# 1. **Quest-Struktur**
#    - Erstelle eine Funktion `erstelle_quest(quest_id, ziel, belohnung)`, die ein Dictionary zurückgibt mit z.B. `id`, `ziel`, `belohnung`, `helden` (Liste von Namen oder leere Liste), `status` ("offen", "aktiv", "abgeschlossen"); nutze für feste Daten optional ein Tupel (z.B. `(quest_id, ziel)`)
#    - Lege 3–5 Quests an und speichere sie in einer Liste `quests`
#    - Gib die Liste aus
#
# 2. **Helden-Zuweisung und Status**
#    - Schreibe eine Funktion `weise_held_zu(quest, name)`, die einen Namen zur Liste `quest["helden"]` hinzufügt
#    - Schreibe eine Funktion `setze_status(quest, neuer_status)`, die `quest["status"]` ändert
#    - Rufe beide für je eine Quest auf und gib die aktualisierte Quest aus
#
# 3. **Suche und Filter**
#    - Erstelle eine Funktion `quests_nach_status(quests, status)`, die alle Quests mit diesem Status zurückgibt
#    - Erstelle eine Funktion `quest_mit_id(quests, quest_id)`, die die erste Quest mit dieser ID zurückgibt (oder None)
#    - Gib die gefilterten Ergebnisse aus
#
# 4. **Statistik und Bericht**
#    - Berechne: Anzahl Quests gesamt, Anzahl pro Status (z.B. mit Schleife und Dictionary)
#    - Gib eine kurze übersichtliche Zusammenfassung aus (z.B. „5 Quests, 2 aktiv, 1 abgeschlossen“)
#
# **Beispiel-Code zum Starten:**
# ```python
# def erstelle_quest(quest_id, ziel, belohnung):
#     return {"id": quest_id, "ziel": ziel, "belohnung": belohnung, "helden": [], "status": "offen"}
#
# def weise_held_zu(quest, name):
#     quest["helden"].append(name)
#
# def quests_nach_status(quests, status):
#     return [q for q in quests if q.get("status") == status]
# ```
#
# **Bonus-Challenge:**
# - Füge zu jeder Quest ein Feld `ergebnis` und `belohnung_verteilt` hinzu und gib eine Belohnungs-Übersicht aus.
#
# **Erwartete Ausgabe:**
# ```
# Quests: 5
# Quest Drachenjagd aktualisiert: helden=['Elara', 'Thor'], status=aktiv
# Aktive Quests: 2
# Statistik: 5 Quests, offen: 2, aktiv: 2, abgeschlossen: 1

# %%
# 🐉 Deine Lösung hier:

print()
print("🎉 +400 XP: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Archivar des Gildenarchivs besiegt!")
print("⭐ Titel erhalten: Meister der Steckbriefe")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 8 gemeistert!")
print("📚 Nächste Woche: JSON-Dateien und I/O!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen (Steckbrief = Dictionary):

# %%
# ✅ Lösung Bug #1: Fehlende schließende Klammer

# Problem: Steckbrief (Dictionary) nicht geschlossen
held = {
    "name": "Aria",
    "klasse": "Magierin"
}
print(f"Held: {held}")

# %%
# ✅ Lösung Bug #2: Artefakte sind unveränderlich

# Problem: Artefakte können nicht geändert werden
koordinaten = [100, 200]  # Liste verwenden
koordinaten[0] = 150
print(f"Koordinaten: {koordinaten}")

# %%
# ✅ Lösung Bug #3: Index außerhalb des Bereichs

# Problem: Index 2 existiert nicht (nur 0,1)
helden = [
    {"name": "Aria", "klasse": "Magierin"},
    {"name": "Thorin", "klasse": "Krieger"}
]
print(helden[1])  # Letztes Element
