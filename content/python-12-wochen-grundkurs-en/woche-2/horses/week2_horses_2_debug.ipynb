# %% [markdown]
# # 🐛 Debug Quest – 🐴 Week 2 – Data Types and Variables: The Four Hoof-Beat Types
#
# A young rider tried to give the first stable commands, but something went wrong! Find the errors:
# > 💡 **These errors were built in on purpose** – so you can practise debugging!

# %% [markdown]
# ### 🐛 Bug #1
#
# What is wrong? Find and fix the error!

# %%
horse = "Comet"
age = 6
print("Hello horse! You are age years old.")

# %% [markdown]
# ### 🐛 Bug #2
#
# What is wrong? Find and fix the error!

# %%
feed_kg = "10"
days = 5
print(f"Total feed: {feed_kg * days} kg")

# %% [markdown]
# ### 🐛 Bug #3
#
# What is wrong? Find and fix the error!

# %%
hours = 3
print(f"Training takes hours hours.")
