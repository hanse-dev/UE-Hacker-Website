# %% [markdown]
# # 🐉 Woche 1 – Boss-Quests: Hausaufgaben
# > ⚠️ Schwieriger! Kombiniert alles aus dieser Woche.
#
# **⚠️ ACHTUNG:** Diese Quests sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 XP + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Der Turm des Wissens
#
# **Belohnung:** 500 XP + Kristallkugel
#
# Der alte Turm enthält ein verschlüsseltes Gedicht über die Macht des Programmierens. Entschlüssele es!
#
# **Schritt 1 – Gedicht verfassen:**
# Lege 4 Variablen an (`zeile1` bis `zeile4`) – jede mit einem Satz über das Programmieren.
#
# **Schritt 2 – Formatiert ausgeben:**
# Gib einen Titel, eine Trennlinie und alle vier Zeilen untereinander aus.
#
# **Schritt 3 – Signatur:**
# Gib deinen Namen als Autor und eine Bewertung (1–5 Sterne) aus.
#
# **Bonus:** Füge einen Kommentar mit einer versteckten Botschaft ein.

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Der Fluch des Schweige-Drachen
#
# **Belohnung:** 600 XP + Drachenamulett
#
# Der Schweige-Drache hat den Dorfältesten verstummen lassen! Nur ein perfektes Heilungsritual kann ihn retten.
#
# **Schritt 1 – Zutaten:**
# Lege 3 Variablen für magische Zutaten an und gib jede mit einer kurzen Wirkung aus.
#
# **Schritt 2 – Zauberspruch:**
# Erstelle eine Variable für den Zauberspruch und gib ihn aus.
#
# **Schritt 3 – Ritual abschließen:**
# Gib `"Zauber wird gewirkt..."` und am Ende `"Erfolg! Der Fluch ist gebrochen!"` aus.
#
# **Bonus:** Schreibe den Zauberspruch rückwärts in einer zweiten Variable.

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Das Portal der Möglichkeiten
#
# **Belohnung:** 400 XP + Portalschlüssel
#
# Ein magisches Portal erscheint! Erstelle ein Portalprotokoll für die Abenteurer-Gilde.
#
# **Schritt 1 – Portal beschreiben:**
# Lege Variablen für Farbe, Form und Größe an und gib sie strukturiert aus.
#
# **Schritt 2 – Koordinaten:**
# Lege X-, Y- und Z-Koordinate als Zahlen an und gib alle drei aus.
#
# **Schritt 3 – Reisewarnung:**
# Schreibe eine Warnung für Portalreisende und liste 3 mögliche Reiseziele auf.
#
# **Bonus:** Formuliere ein Rätsel über das Portal.

# %%
print()
print("🎉 +400 XP: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Schweige-Drachen besiegt!")
print("⭐ Titel erhalten: Portal-Meister")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 1 gemeistert!")
print("📚 Nächste Woche: Datentypen und Variablen!")

# %% [markdown]
# ---
#
# 🎊 **GLÜCKWUNSCH!** Du hast alle Boss-Quests von Woche 1 gemeistert!
#
# **Gesammelte XP:** 1500 Punkte
# **Titel erhalten:** Portal-Meister
# **Als Nächstes:** Woche 2 – Datentypen und Variablen!
