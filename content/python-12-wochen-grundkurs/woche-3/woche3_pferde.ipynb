# %% [markdown]
# # 🐴 Woche 3 – Bedingungen (if-else): Die Weichen des Reitwegs
#
# **Huf-Punkte zu verdienen:** 1000 Punkte
# **Herausforderung:** Das Pferd der unentschlossenen Wege

# %% [markdown]
# ## 🌟 Die Freundschaft beginnt: Am Scheideweg der Weide
#
# Willkommen, Pferdefreund! Du erreichst den **Scheideweg der Weide** – ein Ort, an dem jede Entscheidung über den richtigen Reitweg entscheidet. In dieser Woche lernst du die drei **Wege der Weisheit**:
#
# **Deine Mission:**
# - Lerne, wie du mit **if-else** Entscheidungen triffst
# - Meistere **Vergleichs-Operatoren** für präzise Urteile
# - Beherrsche **logische Verknüpfungen** für komplexe Bedingungen
# - Verstehe die **Macht der Einrückung** für verschachtelte Pfade
#
# **Reite weise!** Dein Pferd vertraut auf dich...

# %% [markdown]
# ## 📚 Lektion 1: Der einfache Reitweg (if)
#
# **Was es ist:** `if` prüft eine Bedingung und führt Code nur aus, wenn die Bedingung wahr ist.
#
# **Warum nützlich:**
# - 🎯 Treffe Entscheidungen basierend auf Bedingungen
# - 🔍 Prüfe, ob etwas wahr oder falsch ist
# - ⚔️ Aktiviere Fähigkeiten nur bei Bedarf
# - 🎲 Reagiere auf zufällige Ereignisse
#
# **Wichtig:** Der Code nach `if` muss eingerückt werden!

# %%
# Beispiel 1: Einfache if-Bedingung
alter_pferd = 5
if alter_pferd >= 5:
    print("🎉 Das Pferd ist reif für das Training!")

# Beispiel 2: Prüfen auf True/False
hat_sattel = True
if hat_sattel:
    print("🔑 Du kannst aufsteigen!")

# Beispiel 3: Gangart prüfen
gangart = "Galopp"
if gangart == "Galopp":
    print("🐎 Volles Tempo!")

# %% [markdown]
# ## 🔍 Die Hufschläge des Vergleichs: Wichtige Operatoren
#
# ### Zuweisung vs Vergleich: = vs ==
#
# **Das ist ein entscheidender Unterschied!**
#
# - **`=` (ein Gleichheitszeichen)**: Weist einer Variable einen Wert zu
#
# ```python
# alter = 10  # Weise alter den Wert 10 zu
# ```
#
# - **`==` (zwei Gleichheitszeichen)**: Vergleicht zwei Werte auf Gleichheit
#
# ```python
# if alter == 10:  # Prüfe OB alter 10 ist
#     print("Das Pferd ist 10 Jahre alt!")
# ```
#
# ### Die vier Vergleichsoperatoren
#
# - **`<` (kleiner als)**: Prüft, ob der linke Wert kleiner ist
#
# ```python
# if alter < 5:
#     print("Noch ein Fohlen!")
# ```
#
# - **`<=` (kleiner oder gleich)**: Prüft, ob der linke Wert kleiner oder gleich ist
#
# ```python
# if alter <= 5:
#     print("Junges Pferd oder Fohlen!")
# ```
#
# - **`>` (größer als)**: Prüft, ob der linke Wert größer ist
#
# ```python
# if alter > 15:
#     print("Ein erfahrenes Pferd!")
# ```
#
# - **`>=` (größer oder gleich)**: Prüft, ob der linke Wert größer oder gleich ist
#
# ```python
# if alter >= 3:
#     print("Alt genug zum Reiten!")
# ```
#
# **Merke:** In Bedingungen immer `==` für Vergleiche verwenden, nie `=`!

# %%
# 🔍 Übungen zu Vergleichsoperatoren

# Beispiel 1: = vs == im Vergleich
alter = 8  # Zuweisung mit =
if alter == 8:  # Vergleich mit ==
    print("✅ Richtig: Das Pferd ist 8 Jahre alt")

# Beispiel 2: Alle vier Vergleichsoperatoren
groesse = 160  # cm Stockmaß
print(f"Stockmaß: {groesse} cm")
print(f"{groesse} < 165: {groesse < 165}")
print(f"{groesse} <= 160: {groesse <= 160}")
print(f"{groesse} > 150: {groesse > 150}")
print(f"{groesse} >= 160: {groesse >= 160}")

# Beispiel 3: Praktische Anwendung
futter = 25
bedarf = 20
if futter > bedarf:
    print(f"🌾 Genug Futter! Übrig: {futter - bedarf} kg")
elif futter == bedarf:
    print("⚖️ Perfekte Menge!")
else:
    print(f"❌ Zu wenig Futter! Fehlen: {bedarf - futter} kg")

# %% [markdown]
# ## 📦 Lektion 2: Der zweigeteilte Reitweg (if-else)
#
# **Was es ist:** `if-else` bietet zwei Pfade - einen für wahre und einen für falsche Bedingungen.
#
# **Warum nützlich:**
# - ✅ Handle unterschiedlich bei Erfolg/Misserfolg
# - 🔄 Gib alternative Antworten
# - 🎮 Erstelle Win/Lose-Szenarien
# - ⚖️ Balance gute und schlechte Ergebnisse
#
# **Wichtig:** `else` braucht keine Bedingung und wird bei allem anderen ausgeführt!

# %%
# Beispiel 1: Hürdensprung
hoehe = 120
if hoehe <= 100:
    print("⚔️ Leichte Hürde gemeistert!")
else:
    print("💨 Anspruchsvolle Hürde!")

# Beispiel 2: Wetterprüfung
regnet = False
if regnet:
    print("🌧️ Wir reiten in der Halle.")
else:
    print("☀️ Perfekt für die Weide!")

# Beispiel 3: Futter-Check
heu_vorrat = 45
bedarf = 50
if heu_vorrat >= bedarf:
    print(f"💰 Genug Heu! Rest: {heu_vorrat - bedarf} kg")
else:
    print(f"❌ Zu wenig Heu! Fehlt: {bedarf - heu_vorrat} kg")

# %% [markdown]
# ## ✨ Lektion 3: Der multiple Reitweg (if-elif-else)
#
# **Was es ist:** `if-elif-else` prüft mehrere Bedingungen nacheinander.
#
# **Warum nützlich:**
# - 🎭 Handle unterschiedlich bei verschiedenen Situationen
# - 🌟 Erstelle Stufen- und Level-Systeme
# - 🎨 Gib personalisierte Antworten
# - 🏆 Bewerte Leistungen mit Noten
#
# **Wichtig:** `elif` braucht immer eine Bedingung! Nur der erste wahre Pfad wird ausgeführt.

# %%
# Beispiel 1: Reitfertigkeit
erfahrung = 750
if erfahrung >= 1000:
    print("🏆 Meisterreiter!")
elif erfahrung >= 500:
    print("⭐ Fortgeschrittener Reiter!")
elif erfahrung >= 100:
    print("🌟 Anfänger!")
else:
    print("📚 Noch viel zu üben...")

# Beispiel 2: Pferdedisziplin
disziplin = "Springen"
if disziplin == "Dressur":
    print("🎆 Elegante Dressur!")
elif disziplin == "Springen":
    print("🏇 Sprungkurs!")
elif disziplin == "Western":
    print("🤠 Western-Style!")
elif disziplin == "Voltigieren":
    print("🤸 Voltigier-Akrobatik!")
else:
    print("❓ Unbekannte Disziplin!")

# Beispiel 3: Pferde-Typ
groesse = 168
temperament = 8
if groesse > 170 and temperament > 7:
    print("⚔️🧠 Warmblut für Sport!")
elif groesse > 170:
    print("💪 Kaltblut für Arbeit!")
elif temperament > 7:
    print("🐎 Vollblut für Rennen!")
else:
    print("👤 Pony für Freizeit!")

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein junger Reiter hat versucht, Entscheidungsregeln zu erstellen, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1

level = 10
if level >= 10:
print("Reitfertigkeit erreicht!")
print("Glückwunsch!")

# %%
# 🐛 Bug #2

name = "Thunder"
if name = "Thunder":
    print("Hallo Thunder!")

# %%
# 🐛 Bug #3

alter = 8
if alter >= 5:
    print("Ausgebildet")
elif:
    print("In Ausbildung")

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Stallwart
#
# **Belohnung:** 300 Huf-Punkte + Stallschlüssel
#
# Der Stallwart prüft, wer den Stall betreten darf!
#
# **Deine Aufgaben:**
#
# 1. **Zugangsdaten erfassen**
#    - Erstelle eine Variable für das Alter (Ganzzahl)
#    - Erstelle eine Variable für Helmbesitz (Boolean True/False)
#    - Erstelle eine Variable für Erlaubnis (Boolean True/False)
#
# 2. **Zugangsregel implementieren**
#    - Prüfe mit if, ob Alter >= 12 ODER Helm vorhanden ODER Erlaubnis
#    - Nutze den `or`-Operator für die Verknüpfung
#    - Gib "Zugang gewährt" bei Erfolg aus
#
# 3. **Ablehnungsmeldung hinzufügen**
#    - Nutze else für den Fall, dass keine Bedingung zutrifft
#    - Gib "Zugang verweigert" aus
#    - Füge eine Begründung hinzu
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Zugangsdaten erfassen
# alter = 10
# hat_helm = True
# hat_erlaubnis = False
#
# # 2. Zugangsregel
# if alter >= 12 or hat_helm or hat_erlaubnis:
#     print("✅ Zugang gewährt!")
# else:
#     print("❌ Zugang verweigert!")
# ```
#
# **Bonus-Challenge:**
# - Fordere nur bei Reitern unter 16 einen Helm!
#
# **Erwartete Ausgabe:**
# ```
# ✅ Zugang gewährt!
# Grund: Helm vorhanden
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Futterautomat
#
# **Belohnung:** 400 Huf-Punkte + Futterschip
#
# Der Futterautomat gibt nur Futter, wenn das richtige Passwort eingegeben wird!
#
# **Deine Aufgaben:**
#
# 1. **Passwörter festlegen**
#    - Erstelle eine Variable für das Stallmeister-Passwort
#    - Erstelle eine Variable für das Pfleger-Passwort
#    - Erstelle eine Variable für das Notfall-Passwort
#
# 2. **Eingabe simulieren**
#    - Erstelle eine Variable für die eingegebene Passwort-Eingabe
#    - Speichere ein Testpasswort als String
#
# 3. **Zugriffsprüfung implementieren**
#    - Prüfe mit if, ob Eingabe == Stallmeister-Passwort
#    - Prüfe mit elif, ob Eingabe == Pfleger-Passwort
#    - Prüfe mit elif, ob Eingabe == Notfall-Passwort
#    - Nutze else für falsche Passwörter
#
# 4. **Unterschiedliche Meldungen ausgeben**
#    - Gib bei Stallmeister: "Vollzugriff gewährt"
#    - Gib bei Pfleger: "Futterzugriff gewährt"
#    - Gib bei Notfall: "Notfallzugriff aktiviert"
#    - Gib bei Fehler: "Zugriff verweigert"
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Passwörter festlegen
# stallmeister_pw = "HAFER123"
# pfleger_pw = "HEU456"
# notfall_pw = "KAROTTE999"
#
# # 2. Eingabe simulieren
# eingabe = "HAFER123"
#
# # 3. Zugriffsprüfung
# if eingabe == stallmeister_pw:
#     print("🔓 Vollzugriff gewährt!")
# elif eingabe == pfleger_pw:
#     print("🌾 Futterzugriff gewährt!")
# ```
#
# **Bonus-Challenge:**
# - Gib verschiedene Hinweise bei falschen Passwörtern!
#
# **Erwartete Ausgabe:**
# ```
# 🔓 Vollzugriff gewährt!
# Willkommen, Stallmeister!
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Das Turnier
#
# **Belohnung:** 500 Huf-Punkte + Turnierbande
#
# Beim Turnier werden Reiter nach ihrer Leistung bewertet!
#
# **Deine Aufgaben:**
#
# 1. **Turnierdaten erfassen**
#    - Erstelle eine Variable für Punkte (0-100)
#    - Erstelle eine Variable für Zeit in Sekunden
#    - Erstelle eine Variable für Fehler (Anzahl)
#
# 2. **Gesamtnote berechnen**
#    - Berechne: note = Punkte - (Fehler × 5) - (Zeit / 10)
#    - Speichere das Ergebnis in einer Variable
#    - Gib die Note aus
#
# 3. **Gold-Medaille prüfen**
#    - Prüfe: note >= 85 UND Fehler == 0
#    - Nutze `and` für die Verknüpfung
#    - Gib "🥇 GOLD!" bei Erfolg aus
#
# 4. **Weitere Medaillenstufen**
#    - Prüfe mit elif: note >= 70 UND Fehler <= 2
#    - Gib "🥈 SILBER!" aus
#    - Prüfe mit elif: note >= 50 UND Fehler <= 5
#    - Gib "🥉 BRONZE!" aus
#    - Nutze else für "📚 TEILGENOMMEN"
#
# 5. **Perfekte-Zeit-Bonus prüfen**
#    - Prüfe separat mit if, ob Zeit < 60
#    - Gib "+10 Bonus für perfekte Zeit!" aus
#    - Addiere den Bonus zur Note
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Turnierdaten erfassen
# punkte = 90
# zeit = 55
# fehler = 0
#
# # 2. Gesamtnote berechnen
# note = punkte - (fehler * 5) - (zeit / 10)
# print(f"Note: {note}")
#
# # 3. Gold-Medaille prüfen
# if note >= 85 and fehler == 0:
#     print("🥇 GOLD!")
# ```
#
# **Bonus-Challenge:**
# - Berücksichtige auch die Schwierigkeit der Prüfung!
#
# **Erwartete Ausgabe:**
# ```
# Note: 84.5
# 🥇 GOLD!
# +10 Bonus für perfekte Zeit!
# Finale Note: 94.5
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten der erfahrenen Reitlehrerin (Reflexion)
#
# Bevor du weiterreitest, denke über diese Fragen nach:
#
# 1. **Warum ist die richtige Einrückung bei Bedingungen so wichtig?**
#
# 2. **Was ist der Unterschied zwischen `==` und `=`?**
#
# 3. **Wann würdest du `elif` anstelle von mehreren `if`-Statements verwenden?**
#
# Diskutiere deine Gedanken mit anderen Pferdefreunden!

# %% [markdown]
# ### 📖 Reiterhof-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **if** 🎯: Prüft eine Bedingung und führt Code aus bei Wahr
# - **else** 🔄: Alternativcode bei falscher Bedingung
# - **elif** 🎭: Prüft zusätzliche Bedingungen
# - **==** ⚖️: Vergleichsoperator für Gleichheit
# - **!=** ❌: Vergleichsoperator für Ungleichheit
# - **>** 📈: Größer als
# - **<** 📉: Kleiner als
# - **>=** 📊: Größer oder gleich
# - **<=** 📉: Kleiner oder gleich
# - **and** 🔗: Logisches UND
# - **or** ⚡: Logisches ODER
# - **not** 🚫: Logische Verneinung

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ✅ if-Bedingungen für einfache Entscheidungen
# - ✅ if-else für zwei Wege der Entscheidung
# - ✅ if-elif-else für multiple Pfade
# - ✅ Vergleichsoperatoren richtig anwenden
# - ✅ Logische Operatoren (and, or, not) nutzen
# - ✅ Verschachtelte Bedingungen mit Einrückung
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die finalen Herausforderungen!

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Wunderbar!** Du hast die Weichen des Reitwegs gemeistert!
#
# **Das hast du gelernt:**
# - Entscheidungen mit if-else treffen
# - Vergleichsoperatoren für präzise Prüfungen
# - Logische Verknüpfungen für komplexe Regeln
# - Die Macht der Einrückung verstehen
# - Verschachtelte Bedingungen meistern
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🎮 **Pferdespiele:** Trainings-Entscheidungen, Pferde-Management
# - 📱 **Reit-Apps:** Termin-Planung, Trainings-Empfehlungen
# - 🌐 **Reitställe:** Buchungs-Systeme, Stall-Regeln
# - 🤖 **Pferde-Chatbots:** Pflege-Tipps, Trainings-Ratschläge
# - 📊 **Pferdezucht:** Bewertungs-Systeme, Zucht-Entscheidungen
#
# **Als Nächstes:** In Woche 4 lernst du **Schleifen (for, while)**!

# %% [markdown]
# ## 🐴 Abschluss-Challenge: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Missionen sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 Huf-Punkte + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Das Reiter-Quiz
#
# **Belohnung:** 500 Huf-Punkte + Reiter-Zertifikat
#
# Teste dein Wissen über Reitkunst!
#
# **Deine Aufgaben:**
#
# 1. **Quiz-Antworten erstellen**
#    - Erstelle 5 Boolean-Variablen für Antworten (True = richtig, False = falsch)
#    - Gib jeder Frage eine eindeutige Nummer
#    - Simuliere verschiedene Antworten
#
# 2. **Antworten einzeln prüfen**
#    - Nutze if-else für jede Antwort
#    - Gib "✅ Richtig!" oder "❌ Falsch!" aus
#    - Zeige die richtige Antwort bei Fehlern
#
# 3. **Punkte zählen**
#    - Erstelle eine Variable `punkte = 0`
#    - Addiere 100 Punkte pro richtige Antwort mit `punkte += 100`
#    - Gib die Gesamtpunktzahl aus
#
# 4. **Abschlussbewertung erstellen**
#    - Prüfe mit if: punkte >= 400 → Note "A"
#    - Prüfe mit elif: punkte >= 300 → Note "B"
#    - Prüfe mit elif: punkte >= 200 → Note "C"
#    - Prüfe mit elif: punkte >= 100 → Note "D"
#    - Nutze else für Note "F"
#
# 5. **Zertifikat ausgeben**
#    - Prüfe mit if, ob punkte >= 300 (bestanden)
#    - Gib ein Reiter-Zertifikat aus
#    - Nutze verschachtelte if für Zertifikatsstufe (Gold/Silber/Bronze)
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Quiz-Antworten erstellen
# print("=== REITER-QUIZ ===")
# print()
#
# frage1_richtig = True   # Frage 1: Ist Schritt die langsamste Gangart?
# frage2_richtig = False  # Frage 2: Hat ein Pferd 6 Beine?
# frage3_richtig = True   # Frage 3: Braucht man einen Sattel?
# frage4_richtig = True   # Frage 4: Ist Dressur eine Disziplin?
# frage5_richtig = False  # Frage 5: Können Pferde fliegen?
#
# # 2. Antworten prüfen
# punkte = 0
#
# if frage1_richtig:
#     print("Frage 1: ✅ Richtig!")
#     punkte += 100
# else:
#     print("Frage 1: ❌ Falsch! Richtig ist: True")
#
# # ... weitere Fragen prüfen
# ```
#
# **Bonus-Challenge:**
# - Füge verschiedene Schwierigkeitsgrade hinzu!
#
# **Erwartete Ausgabe:**
# ```
# === REITER-QUIZ ===
#
# Frage 1: ✅ Richtig!
# Frage 2: ❌ Falsch! Richtig ist: False
# ...
#
# Gesamtpunktzahl: 300
# Note: B
# 🎓 Zertifikat: Silber
# ```

# %%
# 🐴 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Der Hindernis-Simulator
#
# **Belohnung:** 600 Huf-Punkte + Reitmeister-Lizenz
#
# Der Simulator hat 5 Level mit steigenden Anforderungen!
#
# **Deine Aufgaben:**
#
# 1. **Level 1: Aufsitzen**
#    - Erstelle Variablen für pferd_groesse (in Metern) und reiter_gewicht (in kg)
#    - Prüfe mit if: pferd_groesse >= 1.60 UND reiter_gewicht <= 80
#    - Gib "✅ Aufsitzen erfolgreich!" aus
#    - Nutze else für Fehlermeldung
#
# 2. **Level 2: Gangwahl**
#    - Erstelle eine Variable gangart mit Wert "Schritt" oder "Trab"
#    - Nutze if-else für die Gangwahl
#    - Gib "Schritt gewählt" oder "Trab gewählt" aus
#    - Bestätige die Gangart
#
# 3. **Level 3: Geschwindigkeit**
#    - Erstelle eine Variable tempo (0-100)
#    - Nutze if-elif-else für 5 Stufen:
#      - < 20: "Schritt"
#      - < 40: "Trab"
#      - < 60: "Leichter Galopp"
#      - < 80: "Galopp"
#      - >= 80: "Renngalopp"
#    - Gib Hinweise zur Geschwindigkeit aus
#
# 4. **Level 4: Hindernisprüfung**
#    - Erstelle Variablen für hoehe, breite, schwierigkeit (jeweils 0-100)
#    - Nutze verschachtelte if-Bedingungen
#    - Prüfe: hoehe <= 120 UND breite <= 150 UND schwierigkeit <= 70
#    - Gib "Hindernis schaffbar" oder spezifische Fehler aus
#
# 5. **Level 5: Abmeldung**
#    - Erstelle Variablen für zeit, fehler, stil (0-100)
#    - Baue komplexe Logik: zeit <= 60 ODER (fehler == 0 UND stil >= 80)
#    - Gib verschiedene Ergebnisse aus
#    - Prüfe alle Kombinationen
#
# 6. **Punktesystem**
#    - Zähle erfolgreiche Level mit Variable erfolge = 0
#    - Addiere 1 pro bestandenem Level
#    - Gib Reiter-Rang aus (5=Meister, 4=Experte, 3=Fortgeschritten, 2=Anfänger, 1=Neuling)
#
# **Beispiel-Code zum Starten:**
# ```python
# # So könntest du beginnen:
# print("=== HINDERNIS-SIMULATOR ===")
# print()
#
# erfolge = 0
#
# # Level 1: Aufsitzen
# pferd_groesse = 1.70
# reiter_gewicht = 70
# if pferd_groesse >= 1.60 and reiter_gewicht <= 80:
#     print("Level 1: ✅ Aufsitzen erfolgreich!")
#     erfolge += 1
# else:
#     print("Level 1: ❌ Aufsitzen nicht möglich!")
#
# # Level 2: Gangwahl
# gangart = "Schritt"
# if gangart == "Schritt":
#     print("Level 2: ✅ Schritt gewählt!")
#     erfolge += 1
# else:
#     print("Level 2: ✅ Trab gewählt!")
#     erfolge += 1
#
# # ... weitere Level
# ```
#
# **Bonus-Challenge:**
# - Füge Zeitlimits für jedes Level hinzu!
#
# **Erwartete Ausgabe:**
# ```
# === HINDERNIS-SIMULATOR ===
#
# Level 1: ✅ Aufsitzen erfolgreich!
# Level 2: ✅ Schritt gewählt!
# Level 3: 🐎 Galopp!
# Level 4: ✅ Hindernis schaffbar!
# Level 5: ✅ Abmeldung erfolgreich!
#
# Erfolgreiche Level: 5/5
# Reiter-Rang: Meister
# ```

# %%
# 🐴 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Das Turnier
#
# **Belohnung:** 400 Huf-Punkte + Turnier-Abzeichen
#
# Führe das wichtigste Turnier durch!
#
# **Deine Aufgaben:**
#
# 1. **Turnierphasen erstellen**
#    - Erstelle 5 Boolean-Variablen für Phasen (phase1_ok, phase2_ok, etc.)
#    - Simuliere verschiedene Erfolge und Misserfolge
#    - Gib jeder Phase einen Namen
#
# 2. **Schwierigkeitsstufe implementieren**
#    - Erstelle eine Variable schwierigkeit (1-5)
#    - Nutze if-elif-else für 5 Stufen:
#      - 5: "MEISTERKLASSE"
#      - 4: "FORTGESCHRITTEN"
#      - 3: "MITTEL"
#      - 2: "ANFÄNGER"
#      - 1: "EINSTEIGER"
#    - Gib entsprechende Hinweise aus
#
# 3. **Zufallsereignisse simulieren**
#    - Erstelle Boolean-Variablen für: hindernis_umgeworfen, pferd_scheut, sattel_verrutscht
#    - Prüfe jedes Ereignis mit if
#    - Gib spezifische Meldungen aus
#    - Reduziere Erfolgschance bei Ereignissen
#
# 4. **Erfolgsbedingungen prüfen**
#    - Zähle erfolgreiche Phasen
#    - Prüfe: erfolgreiche_phasen >= 4 UND schwierigkeit <= 3
#    - Nutze kombinierte Bedingungen mit and/or
#    - Gib "Turnier gewonnen" oder "Turnier verloren" aus
#
# 5. **Sonderaktionen**
#    - Prüfe mit verschachtelten if: schwierigkeit >= 4 UND erfolgreiche_phasen < 3
#    - Gib "Zusatztraining erforderlich!" aus
#    - Biete Trainingsoptionen an
#    - Implementiere Verbesserungsvorschläge
#
# 6. **Turnier-Auswertung**
#    - Berechne Gesamtpunkte: erfolgreiche_phasen × 100 - schwierigkeit × 20
#    - Berechne Platzierung: (erfolgreiche_phasen / 5) × 100
#    - Gib Bewertung aus (>80%: Gold, >60%: Silber, >40%: Bronze, sonst: Teilnahme)
#    - Erstelle Abschlussmeldung mit Empfehlung
#
# **Beispiel-Code zum Starten:**
# ```python
# # So könntest du beginnen:
# print("=== TURNIER ===")
# print()
#
# # 1. Turnierphasen
# phase1_ok = True
# phase2_ok = True
# phase3_ok = False
# phase4_ok = True
# phase5_ok = True
#
# # 2. Schwierigkeitsstufe
# schwierigkeit = 3
# if schwierigkeit >= 4:
#     print("⚠️ MEISTERKLASSE!")
# elif schwierigkeit >= 3:
#     print("⚡ Fortgeschritten!")
# else:
#     print("✅ Anfängerklasse.")
#
# # 3. Zufallsereignisse
# hindernis_umgeworfen = False
# pferd_scheut = True
# sattel_verrutscht = False
#
# if hindernis_umgeworfen:
#     print("💥 Hindernis umgeworfen!")
# if pferd_scheut:
#     print("🐴 Pferd scheut!")
#
# # ... weitere Logik
# ```
#
# **Bonus-Challenge:**
# - Füge ein Team-Score für Mannschaftsturniere hinzu!
#
# **Erwartete Ausgabe:**
# ```
# === TURNIER ===
#
# ⚡ Fortgeschritten!
# 🐴 Pferd scheut!
#
# Phase 1: ✅ Erfolgreich
# Phase 2: ✅ Erfolgreich
# Phase 3: ❌ Fehlgeschlagen
# Phase 4: ✅ Erfolgreich
# Phase 5: ✅ Erfolgreich
#
# Erfolgreiche Phasen: 4/5
# Gesamtpunkte: 340
# Platzierung: 80%
# Bewertung: Gold
# Empfehlung: Weiter so!
# ```

# %%
# 🐴 Deine Lösung hier:

print()
print("🎉 +400 Huf-Punkte: Abschluss-Challenge abgeschlossen!")
print("🏆 Du hast das Pferd der unentschlossenen Wege gemeistert!")
print("⭐ Titel erhalten: Meister der Weichen")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 3 gemeistert!")
print("🐴 Nächste Woche: Schleifen (for, while)!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen:

# %%
# ✅ Lösung Bug #1: Falsche Einrückung

# Problem: Code nach if nicht eingerückt
level = 10
if level >= 10:
    print("Reitfertigkeit erreicht!")
    print("Glückwunsch!")

# %%
# ✅ Lösung Bug #2: Falscher Vergleich

# Problem: = statt == für Vergleich verwendet
name = "Thunder"
if name == "Thunder":
    print("Hallo Thunder!")

# %%
# ✅ Lösung Bug #3: Vergessene Bedingung

# Problem: elif braucht immer eine Bedingung
alter = 8
if alter >= 5:
    print("Ausgebildet")
else:
    print("In Ausbildung")
