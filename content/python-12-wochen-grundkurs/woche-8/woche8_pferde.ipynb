# %% [markdown]
# # 🐴 Woche 8 – Dictionaries und Tupel: Die Stall-Archive des Reiterhofs
#
# **Huf-Punkte zu verdienen:** 1000 Punkte
# **Boss:** Der Stallmeister der unendlichen Archive

# %% [markdown]
# ## 🌟 Die Freundschaft beginnt: Das Archiv vom Sonnentals-Hof
#
# Willkommen auf dem Reiterhof Sonnentals! Du erreichst das **große Archiv** – ein gut organisierter Ort, an dem unendlich viele Pferdedaten und Ausrüstungsgegenstände gespeichert werden. In dieser Woche lernst du die drei **Arten der Archiv-Strukturen**:
#
# **Deine Mission:**
# - Meistere die **Stallkarte (Dictionary)** mit geschweiften Klammern
# - Beherrsche **Zugriff und Änderung** mit Namen als Schlüssel
# - Lerne die **Daten-Kapsel (Tupel)** mit runden Klammern
# - Verstehe **Unveränderlichkeit** von Daten-Kapseln
#
# **Einmal strukturiert, für immer organisiert!** Die Macht der Archive wartet...

# %% [markdown]
# ## 📚 Archiv-Struktur 1: Die Stallkarte - Der digitale Pferdepass
#
# **Was es ist:** Ein Dictionary ist eine Sammlung von Schlüssel-Wert-Paaren, die du mit geschweiften Klammern erstellst.
#
# **Die Anatomie einer Stallkarte:**
# ```python
# # Leere Stallkarte erstellen
# leere_karte = {}
#
# # Stallkarte mit Daten füllen
# pferd = {"name": "Thunder", "rasse": "Hannoveraner", "alter": 8}
# ```
#
# **Schritt-für-Schritt-Erklärung:**
# 1. **`{}`** - Geschweifte Klammern definieren eine Stallkarte
# 2. **`:`** - Doppelpunkt trennt Schlüssel vom Wert
# 3. **`,`** - Kommas trennen die Paare
# 4. **`[key]`** - Mit Schlüssel greifst du auf Daten zu
#
# **Warum so nützlich:**
# - 🎯 Daten mit Namen statt Index organisieren
# - 🔍 Schneller Zugriff über Namen
# - ⚡ Flexibel erweiterbar und änderbar
# - 🎲 Verschiedene Datentypen mischbar

# %%
# Beispiel 1: Einfache Stallkarten erstellen
# Leere Stallkarte
leere_karte = {}
print(f"Leere Stallkarte: {leere_karte}")

# Pferde-Stallkarte
pferd = {
    "name": "Thunder",
    "rasse": "Hannoveraner",
    "alter": 8,
    "groesse": 1.72
}
print(f"Pferde-Stallkarte: {pferd}")

# Reiter-Stallkarte
reiter = {
    "name": "Anna",
    "level": "Fortgeschritten",
    "erfahrung": 5,
    "eigene_pferde": True
}
print(f"Reiter-Stallkarte: {reiter}")

# %%
# Beispiel 2: Auf Stallkarten zugreifen
pferd = {
    "name": "Thunder",
    "rasse": "Hannoveraner",
    "alter": 8,
    "groesse": 1.72
}

print("=== Pferde-Zugriff ===")
print(f"Pferde-Name: {pferd['name']}")
print(f"Rasse: {pferd['rasse']}")
print(f"Alter: {pferd['alter']} Jahre")
print(f"Größe: {pferd['groesse']} m")

# Mit get() Methode (sicherer)
print(f"\nMit get(): {pferd.get('name')}")
print(f"Nicht existierend: {pferd.get('geschlecht', 'Unbekannt')}")

# %%
# Beispiel 3: Stallkarten ändern und erweitern
pferd = {
    "name": "Thunder",
    "rasse": "Hannoveraner",
    "alter": 8
}

print(f"Original: {pferd}")

# Wert ändern
pferd["alter"] = 9
print(f"Nach Geburtstag: {pferd}")

# Neues Element hinzufügen
pferd["besitzer"] = "Anna"
print(f"Nach Besitzer hinzufügen: {pferd}")

# Element entfernen
entfernt = pferd.pop("rasse")
print(f"Entfernt: {entfernt}")
print(f"Nach entfernen: {pferd}")

# %% [markdown]
# ## 📦 Archiv-Struktur 2: Die Daten-Kapsel - Die unveränderliche Aufzeichnung
#
# **Die wichtigsten Kapsel-Eigenschaften:**
#
# **Erstellung:**
# - `kapsel = (1, 2, 3)` - Mit runden Klammern
# - `kapsel = 1, 2, 3` - Ohne Klammern
# - `kapsel = (1,)` - Ein Element mit Komma
#
# **Unveränderlichkeit:**
# - Einmal erstellt, können Kapseln nicht geändert werden
# - Perfekt für konstante Daten
# - Geschützt vor unbeabsichtigten Änderungen

# %%
# 🔍 Übungen mit Daten-Kapseln

# Beispiel 1: Kapseln erstellen
koordinaten = (100, 200)
print(f"Koordinaten: {koordinaten}")

# Ohne Klammern
position = 10, 20
print(f"Position: {position}")

# Ein Element
einzel = (42,)
print(f"Einzelne Kapsel: {einzel}")

# Zugriff auf Elemente
print(f"\nX-Koordinate: {koordinaten[0]}")
print(f"Y-Koordinate: {koordinaten[1]}")

# %%
# Beispiel 2: Kapseln sind unveränderlich
trainings_status = ("Aktiv", "Stabil", "Gesund")
print(f"Trainings-Status: {trainings_status}")

# Zugriff funktioniert
print(f"Status: {trainings_status[0]}")

# Ändern funktioniert NICHT!
try:
    trainings_status[0] = "Inaktiv"
except TypeError as e:
    print(f"Fehler: {e}")

# Aber Kapseln in Listen können geändert werden
training = [
    ("Dressur", "Aktiv"),
    ("Springen", "Stabil"),
    ("Western", "Gesund")
]
training[1] = ("Springen", "Inaktiv")
print(f"\nTraining nach Änderung: {training}")

# %%
# Beispiel 3: Kapsel unpacking und Methoden
pferd_daten = ("Thunder", "Hannoveraner", 8, 1.72)

# Kapsel unpacking
name, rasse, alter, groesse = pferd_daten
print("=== Kapsel Unpacking ===")
print(f"Name: {name}")
print(f"Rasse: {rasse}")
print(f"Alter: {alter}")
print(f"Größe: {groesse} m")

# Kapsel-Methoden
print(f"\nAnzahl Elemente: {len(pferd_daten)}")
print(f"Index von 'Hannoveraner': {pferd_daten.index('Hannoveraner')}")
print(f"Anzahl 'Hannoveraner': {pferd_daten.count('Hannoveraner')}")

# %% [markdown]
# ## ✨ Archiv-Struktur 3: Verschachtelte Strukturen - Das Daten-Netzwerk
#
# **Die mächtigsten Kombinationen:**
#
# **Stallkarte in Stallkarte:**
# - `pferd = {"name": "Thunder", "gesundheit": {"zustand": "Gut", "impfung": "Aktuell"}}`
#
# **Liste von Stallkarten:**
# - `pferde = [{"name": "T", "rasse": "H"}, {"name": "L", "rasse": "I"}]`
#
# **Kapsel als Stallkarte-Schlüssel:**
# - `positionen = {(10, 20): "Box A", (30, 40): "Box B"}`

# %%
# Beispiel 1: Stallkarte in Stallkarte
stall = {
    "name": "Sonnental",
    "location": {
        "region": "Süddeutschland",
        "koordinaten": (100, 200),
        "bundesland": "Bayern"
    },
    "einrichtungen": {
        "reithalle": "20x40m",
        "reitplatz": "30x60m",
        "paddocks": "5 Stück"
    }
}

print("=== Verschachtelte Stallkarte ===")
print(f"Stall: {stall['name']}")
print(f"Region: {stall['location']['region']}")
print(f"Koordinaten: {stall['location']['koordinaten']}")
print(f"Reithalle: {stall['einrichtungen']['reithalle']}")

# %%
# Beispiel 2: Liste von Stallkarten
pferde = [
    {
        "name": "Thunder",
        "rasse": "Hannoveraner",
        "alter": 8,
        "trainingslevel": "M"
    },
    {
        "name": "Luna",
        "rasse": "Isländer",
        "alter": 6,
        "trainingslevel": "A"
    },
    {
        "name": "Stormy",
        "rasse": "Quarter Horse",
        "alter": 10,
        "trainingslevel": "L"
    }
]

print("=== Pferde-Liste ===")
for pferd in pferde:
    print(f"{pferd['name']} - {pferd['rasse']} ({pferd['alter']} Jahre)")

# Nach Alter filtern
junge = [p for p in pferde if p['alter'] < 8]
print(f"\nJunge Pferde: {[p['name'] for p in junge]}")

# %%
# Beispiel 3: Komplexe Archiv-Strukturen
# Kapsel als Stallkarte-Schlüssel
box_karte = {
    (1, 1): "Thunder",
    (1, 2): "Luna",
    (2, 1): "Stormy"
}

print("=== Box-Karte ===")
for position, pferd in box_karte.items():
    print(f"Box {position}: {pferd}")

# Komplexes Trainingssystem
training = {
    "aktiv": [
        {
            "pferd": "Thunder",
            "disziplin": "Dressur",
            "zeitplan": ("Mo", "Mi", "Fr"),
            "status": "In Bearbeitung"
        }
    ],
    "abgeschlossen": [
        {
            "pferd": "Luna",
            "disziplin": "Western",
            "zeitplan": ("Di", "Do"),
            "status": "Erfolg"
        }
    ]
}

print(f"\nAktive Trainings: {len(training['aktiv'])}")
print(f"Abgeschlossene Trainings: {len(training['abgeschlossen'])}")

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein Stallhelfer hat versucht, die Daten zu organisieren, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1

pferd = {
    "name": "Thunder",
    "rasse": "Hannoveraner"
}
print(f"Pferd: {pferd}")

# %%
# 🐛 Bug #2

koordinaten = (100, 200)
koordinaten[0] = 150

# %%
# 🐛 Bug #3

pferde = [
    {"name": "Thunder", "rasse": "Hannoveraner"},
    {"name": "Luna", "rasse": "Isländer"}
]
print(pferde[2])

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Stallarchivar
#
# **Belohnung:** 300 Huf-Punkte + Stall-Schlüssel
#
# Auf dem Reiterhof Sonnentals erstellst du deine erste Stallkarte (Dictionary) für Pferdedaten.
#
# **Deine Aufgaben:**
#
# 1. **Pferde-Stallkarte anlegen**
#    - Erstelle ein Dictionary `pferd` mit Schlüsseln z.B. `name`, `rasse`, `alter`, `groesse` und passenden Werten
#    - Gib das Dictionary mit `print()` aus
#    - Nutze geschweifte Klammern `{}` und Doppelpunkte für Schlüssel: Wert
#
# 2. **Werte ändern und ergänzen**
#    - Ändere den Wert von `alter` (z.B. auf eine neue Zahl)
#    - Füge einen neuen Schlüssel `besitzer` mit einem Wert hinzu
#    - Gib das aktualisierte Dictionary aus
#
# 3. **Pferde-Liste aus Dictionaries**
#    - Erstelle eine Liste mit 3 Elementen; jedes Element ist ein Dictionary mit z.B. `name`, `rasse`, `alter`
#    - Gib die Liste und die Werte eines Pferdes (z.B. `pferde[0]["name"]`) aus
#
# 4. **Zugriff und Ausgabe**
#    - Greife mit `pferd["name"]` und `pferd.get("rasse")` auf Werte zu und gib sie aus
#    - Gib eine kurze übersichtliche Zusammenfassung (z.B. „Pferd X, Rasse Y, Alter Z“) aus
#
# **Beispiel-Code zum Starten:**
# ```python
# pferd = {"name": "Luna", "rasse": "Hannoveraner", "alter": 8, "groesse": 1.65}
# print(f"Pferd: {pferd}")
#
# pferd["alter"] = 9
# pferd["besitzer"] = "Anna"
# print(f"Aktualisiert: {pferd}")
# ```
#
# **Bonus-Challenge:**
# - Erstelle ein verschachteltes Dictionary (z.B. Pferd mit Unter-Dictionary „gesundheit“).
#
# **Erwartete Ausgabe:**
# ```
# Pferd: {'name': 'Luna', 'rasse': 'Hannoveraner', ...}
# Aktualisiert: {...}
# Pferd 0: Luna, Hannoveraner
# Zusammenfassung: Luna, Hannoveraner, 9 Jahre
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Koordinaten-Reiter
#
# **Belohnung:** 400 Huf-Punkte + GPS-Halsband
#
# Du nutzt Tupel für 2D-Koordinaten (Reitwege) und kombinierst sie mit Dictionaries.
#
# **Deine Aufgaben:**
#
# 1. **Koordinaten als Tupel**
#    - Erstelle mindestens zwei 2D-Koordinaten als Tupel (z.B. `pos1 = (100, 200)` für Wegpunkte)
#    - Gib die Tupel und die Länge mit `len(pos1)` aus
#    - Greife per Index auf x, y zu (z.B. `pos1[0]`, `pos1[1]`) und gib sie aus
#
# 2. **Tupel-Unpacking**
#    - Nutze Unpacking: `x, y = pos1` und gib x, y aus
#    - Erstelle eine zweite Koordinate und unpacke sie ebenfalls
#
# 3. **Positions-Dictionary**
#    - Erstelle ein Dictionary `positionen`, in dem Schlüssel Namen (Strings, z.B. „Stall“, „Reitplatz“) und Werte Koordinaten-Tupel sind (z.B. `{"Stall": (0, 0), "Reitplatz": (50, 30)}`)
#    - Gib das Dictionary aus und greife auf eine Position zu (z.B. `positionen["Stall"]`)
#
# 4. **Abstand (vereinfacht)**
#    - Schreibe eine einfache Funktion `abstand(koord1, koord2)`, die z.B. die euklidische Distanz für 2D berechnet: √((x1-x2)² + (y1-y2)²)
#    - Rufe sie für zwei deiner Koordinaten auf und gib das Ergebnis aus
#
# **Beispiel-Code zum Starten:**
# ```python
# pos1 = (100, 200)
# pos2 = (150, 250)
# print(f"Pos1: {pos1}, len: {len(pos1)}")
#
# x, y = pos1
# print(f"Unpacked: x={x}, y={y}")
#
# positionen = {"Stall": (0, 0), "Reitplatz": (50, 30)}
# print(f"Stall: {positionen['Stall']}")
# ```
#
# **Bonus-Challenge:**
# - Füge 3D-Koordinaten (x, y, z) als Tupel hinzu und erweitere die Abstandsberechnung.
#
# **Erwartete Ausgabe:**
# ```
# Pos1: (100, 200), len: 2
# Unpacked: x=100, y=200
# Stall: (0, 0)
# Abstand: 111.8
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Die Reiter-Gilde
#
# **Belohnung:** 500 Huf-Punkte + Reitmeister-Urkunde
#
# Du baust eine kleine Reiter-Gilde mit Liste von Dictionaries und Suchfunktionen.
#
# **Deine Aufgaben:**
#
# 1. **Reiter-Liste aus Dictionaries**
#    - Erstelle eine Liste `reiter`, in der jedes Element ein Dictionary ist mit z.B. `name`, `level`, `alter`, `erfahrung` (Jahre)
#    - Lege mindestens 3 Reiter an und gib die Liste aus
#
# 2. **Mitglieder hinzufügen**
#    - Füge mit `reiter.append({...})` ein neues Reiter-Mitglied hinzu
#    - Gib die aktualisierte Liste und die Anzahl der Mitglieder mit `len(reiter)` aus
#
# 3. **Suchfunktion nach Level**
#    - Schreibe eine Funktion `suche_level(reiter_liste, level)`, die alle Reiter mit diesem Level zurückgibt (z.B. Liste von Dictionaries)
#    - Rufe die Funktion für ein Level (z.B. 2) auf und gib die gefundenen Reiter aus
#
# 4. **Statistik und Zuweisung**
#    - Berechne das Durchschnittsalter der Reiter (Summe der Alter / Anzahl) und gib es aus
#    - Optional: Weise einem oder mehreren Reitern ein neues Schlüssel-Wert-Paar zu (z.B. `"pferd": "Luna"`) und gib die aktualisierte Liste aus
#
# **Beispiel-Code zum Starten:**
# ```python
# reiter = [
#     {"name": "Anna", "level": 2, "alter": 14, "erfahrung": 3},
#     {"name": "Ben", "level": 1, "alter": 12, "erfahrung": 1},
#     {"name": "Clara", "level": 2, "alter": 15, "erfahrung": 4},
# ]
# print(f"Reiter: {len(reiter)} Mitglieder")
#
# def suche_level(reiter_liste, level):
#     return [r for r in reiter_liste if r.get("level") == level]
# ```
#
# **Bonus-Challenge:**
# - Füge zu jedem Reiter Schlüssel wie `turniere` (Liste) oder `erfolge` hinzu und gib eine Übersicht aus.
#
# **Erwartete Ausgabe:**
# ```
# Reiter: 3 Mitglieder
# Nach Hinzufügen: 4 Mitglieder
# Level 2: [{'name': 'Anna', ...}, {'name': 'Clara', ...}]
# Durchschnittsalter: 13.7
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten des Reitmeisters (Reflexion)
#
# Bevor du weiterreitest, denke über diese Fragen nach:
#
# 1. **Warum sollte man eine Stallkarte statt einer Liste verwenden?**
#
# 2. **Wann sind Kapseln besser als Listen?**
#
# 3. **Wie helfen verschachtelte Strukturen bei der Datenorganisation?**
#
# Diskutiere deine Gedanken mit anderen Reitern!

# %% [markdown]
# ### 📖 Archiv-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **dict** 🐴: Datentyp für Stallkarten
# - **{}** 📦: Geschweifte Klammern für Stallkarten
# - **key** 🔑: Schlüssel in der Stallkarte
# - **value** 💎: Wert in der Stallkarte
# - **tuple** 📍: Datentyp für Kapseln
# - **()** ⭕: Runde Klammern für Kapseln
# - **immutable** 🔒: Unveränderlich
# - **nested** 🎲: Verschachtelt
# - **unpacking** 📤: Auspacken von Kapseln
# - **get()** 🔍: Sichere Zugriffsmethode

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ✅ Stallkarten erstellen und verwenden
# - ✅ Auf Werte über Schlüssel zugreifen
# - ✅ Kapseln erstellen und verstehen
# - ✅ Unveränderlichkeit von Kapseln nutzen
# - ✅ Verschachtelte Datenstrukturen erstellen
# - ✅ Komplexe Daten organisieren

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Hervorragend!** Du hast die Stall-Archive des Reiterhofs gemeistert!
#
# **Das hast du gelernt:**
# - Stallkarten für strukturierte Daten
# - Kapseln für unveränderliche Daten
# - Verschachtelte Datenstrukturen
# - Zugriffsmethoden und Operationen
# - Komplexe Datenorganisation
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🐴 **Pferdesport:** Pferdeprofile, Trainingsdaten, Turnierergebnisse
# - 📱 **Apps:** Benutzerprofile, Einstellungen, Konfigurationen
# - 🌐 **Websites:** JSON-Daten, Metadaten, Inhalte
# - 🤖 **KI-Systeme**: Modelleinstellungen, Parameter, Ergebnisse
# - 📊 **Wissenschaft:** Experiment-Daten, Messwerte, Ergebnisse

# %% [markdown]
# ## 🐉 Boss-Kampf: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Quests sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 Huf-Punkte + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Der Daten-Generator
#
# **Belohnung:** 500 Huf-Punkte + Meister-Plan
#
# Du baust einen Daten-Generator für zufällige Pferde-Dictionaries und filterst sie.
#
# **Deine Aufgaben:**
#
# 1. **Pferde-Generator**
#    - Erstelle eine Funktion `generiere_pferd()` oder `generiere_pferd(name)`, die ein Dictionary mit z.B. `name`, `rasse` (aus einer Liste mit `random.choice`), `alter` (`random.randint(5, 20)`), `geschwindigkeit` (`random.randint(1, 10)`) zurückgibt
#    - Gib ein Beispiel-Pferd aus
#
# 2. **Koordinaten und Entfernung**
#    - Schreibe eine Funktion `berechne_entfernung(koord1, koord2)`, die zwei 2D-Tupel nimmt und die euklidische Distanz berechnet: √((x1-x2)² + (y1-y2)²); nutze `math.sqrt` oder `**0.5`
#    - Behandle den Fall, dass die Tupel nicht genau 2 Elemente haben (z.B. Fehlermeldung oder 0 zurückgeben)
#    - Gib die Entfernung für zwei Beispiel-Koordinaten aus
#
# 3. **Stall-Datenbank und Suche**
#    - Erstelle eine Liste `pferde` und füge 10–20 generierte Pferde hinzu (mit einer Schleife)
#    - Schreibe eine Funktion `suche_name(pferde, name)`, die das erste Pferd mit passendem Namen zurückgibt (oder None)
#    - Schreibe eine Funktion `filter_rasse(pferde, rasse)`, die alle Pferde mit dieser Rasse zurückgibt
#    - Optional: Funktion `filter_alter(pferde, min_alter)` für Mindestalter
#
# 4. **Statistik und Ausgabe**
#    - Berechne und gib aus: Anzahl Pferde, durchschnittliches Alter, Anzahl pro Rasse (z.B. mit Schleife und Dictionary für Zählung)
#    - Gib eine kurze übersichtliche Zusammenfassung aus
#
# **Beispiel-Code zum Starten:**
# ```python
# import random
# import math
#
# def generiere_pferd():
#     rassen = ["Hannoveraner", "Holsteiner", "Vollblut"]
#     return {
#         "name": f"Pferd-{random.randint(1, 500)}",
#         "rasse": random.choice(rassen),
#         "alter": random.randint(5, 20),
#         "geschwindigkeit": random.randint(1, 10)
#     }
#
# def berechne_entfernung(koord1, koord2):
#     if len(koord1) != 2 or len(koord2) != 2:
#         return 0
#     return math.sqrt((koord1[0]-koord2[0])**2 + (koord1[1]-koord2[1])**2)
# ```
#
# **Bonus-Challenge:**
# - Füge eine einfache Pferde-Validierung hinzu (z.B. alter > 0, geschwindigkeit im erlaubten Bereich).
#
# **Erwartete Ausgabe:**
# ```
# Beispiel-Pferd: {'name': 'Pferd-42', 'rasse': 'Hannoveraner', ...}
# Entfernung: 50.0
# Gefunden: Pferd-42
# Filter Rasse Hannoveraner: 7 Pferde
# Statistik: 20 Pferde, Ø Alter 12, Rassen: Hannoveraner 8, Holsteiner 6, Vollblut 6
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Der Stall-Manager
#
# **Belohnung:** 600 Huf-Punkte + Stall-Meister-Titel
#
# Du verwaltest einen Stall als verschachteltes Dictionary mit Boxen und Pferden.
#
# **Deine Aufgaben:**
#
# 1. **Stall-Struktur**
#    - Erstelle eine Funktion `erstelle_stall(name, boxen_anzahl)`, die ein Dictionary zurückgibt mit z.B. `name`, `boxen` (ein Dictionary mit Schlüsseln wie "1", "2" oder "Box-1", Wert z.B. `{"pferd": None}` oder leeres Dictionary) und `einrichtungen` (Liste von Strings, z.B. ["Sattelkammer", "Futterlager"])
#    - Gib den Stall aus
#
# 2. **Boxen und Pferde-Zuweisung**
#    - Erstelle eine Funktion `weise_pferd_zu(stall, box_nummer, pferd_name)`, die in `stall["boxen"][box_nummer]` das Pferd einträgt (z.B. als String oder als Dictionary mit name)
#    - Gib die aktualisierte Stall-Struktur (z.B. welche Boxen belegt sind) aus
#
# 3. **Suche und Statistik**
#    - Schreibe eine Funktion `suche_box(stall, pferd_name)`, die die Box-Nummer zurückgibt, in der das Pferd steht (oder None)
#    - Berechne eine kurze Statistik (z.B. wie viele Boxen belegt, wie viele frei) und gib sie aus
#
# 4. **Ereignis (simuliert)**
#    - Erstelle eine Funktion `zufalls_ereignis(stall)`, die z.B. mit `random.choice` ein „Ereignis“ wählt (z.B. "Futterlieferung", "Tierarzt") und eine Meldung ausgibt oder einen Eintrag in `einrichtungen` ändert
#    - Rufe sie einmal auf und gib das Ergebnis aus
#
# **Beispiel-Code zum Starten:**
# ```python
# import random
#
# def erstelle_stall(name, boxen_anzahl):
#     boxen = {str(i): {"pferd": None} for i in range(1, boxen_anzahl + 1)}
#     return {"name": name, "boxen": boxen, "einrichtungen": ["Sattelkammer", "Futterlager"]}
#
# def weise_pferd_zu(stall, box_nummer, pferd_name):
#     stall["boxen"][str(box_nummer)]["pferd"] = pferd_name
# ```
#
# **Bonus-Challenge:**
# - Füge eine einfache „Turnier-Planung“ hinzu: z.B. Liste von Turnier-Terminen im Stall-Dictionary und Ausgabe der nächsten Termine.
#
# **Erwartete Ausgabe:**
# ```
# Stall: Sonnental, 20 Boxen
# Nach Zuweisung: Box 1 = Luna, Box 2 = Storm
# Luna steht in Box 1
# Statistik: 2 belegt, 18 frei
# Ereignis: Futterlieferung
# ```

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Die Turnier-Datenbank
#
# **Belohnung:** 400 Huf-Punkte + Turnier-Buch
#
# Du verwaltest Turniere als Dictionaries mit Tupeln für unveränderliche Daten.
#
# **Deine Aufgaben:**
#
# 1. **Turnier-Struktur**
#    - Erstelle eine Funktion `erstelle_turnier(turnier_id, name, disziplin)`, die ein Dictionary zurückgibt mit z.B. `id`, `name`, `disziplin`, `teilnehmer` (Liste von Namen oder leere Liste), `status` ("anmeldung", "durchführung", "abgeschlossen"); nutze für feste Daten optional ein Tupel (z.B. `(turnier_id, name)`)
#    - Lege 3–5 Turniere an und speichere sie in einer Liste `turniere`
#    - Gib die Liste aus
#
# 2. **Teilnehmer-Zuweisung und Status**
#    - Schreibe eine Funktion `fuege_teilnehmer_hinzu(turnier, name)`, die einen Namen zur Liste `turnier["teilnehmer"]` hinzufügt
#    - Schreibe eine Funktion `setze_status(turnier, neuer_status)`, die `turnier["status"]` ändert
#    - Rufe beide für je ein Turnier auf und gib das aktualisierte Turnier aus
#
# 3. **Suche und Filter**
#    - Erstelle eine Funktion `turniere_nach_status(turniere, status)`, die alle Turniere mit diesem Status zurückgibt
#    - Erstelle eine Funktion `turnier_mit_id(turniere, turnier_id)`, die das erste Turnier mit dieser ID zurückgibt (oder None)
#    - Gib die gefilterten Ergebnisse aus
#
# 4. **Statistik und Bericht**
#    - Berechne: Anzahl Turniere gesamt, Anzahl pro Status (z.B. mit Schleife und Dictionary)
#    - Gib eine kurze übersichtliche Zusammenfassung aus (z.B. „5 Turniere, 2 in Durchführung, 1 abgeschlossen“)
#
# **Beispiel-Code zum Starten:**
# ```python
# def erstelle_turnier(turnier_id, name, disziplin):
#     return {"id": turnier_id, "name": name, "disziplin": disziplin, "teilnehmer": [], "status": "anmeldung"}
#
# def fuege_teilnehmer_hinzu(turnier, name):
#     turnier["teilnehmer"].append(name)
#
# def turniere_nach_status(turniere, status):
#     return [t for t in turniere if t.get("status") == status]
# ```
#
# **Bonus-Challenge:**
# - Füge zu jedem Turnier ein Feld `ergebnisse` (z.B. Liste von (Name, Platz)) und `sieger` hinzu und gib eine Ergebnis-Übersicht aus.
#
# **Erwartete Ausgabe:**
# ```
# Turniere: 5
# Turnier Springen aktualisiert: teilnehmer=['Anna', 'Ben'], status=durchführung
# Aktive Turniere: 2
# Statistik: 5 Turniere, anmeldung: 2, durchführung: 2, abgeschlossen: 1

# %%
# 🐉 Deine Lösung hier:

print()
print("🎉 +400 Huf-Punkte: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Stallmeister der unendlichen Archive besiegt!")
print("⭐ Titel erhalten: Meister der Stall-Archive")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 8 gemeistert!")
print("📚 Nächste Woche: JSON-Dateien und I/O!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen:

# %%
# ✅ Lösung Bug #1: Fehlende schließende Klammer

# Problem: Stallkarte nicht geschlossen
pferd = {
    "name": "Thunder",
    "rasse": "Hannoveraner"
}
print(f"Pferd: {pferd}")

# %%
# ✅ Lösung Bug #2: Kapseln sind unveränderlich

# Problem: Kapseln können nicht geändert werden
koordinaten = [100, 200]  # Liste verwenden
koordinaten[0] = 150
print(f"Koordinaten: {koordinaten}")

# %%
# ✅ Lösung Bug #3: Index außerhalb des Bereichs

# Problem: Index 2 existiert nicht (nur 0,1)
pferde = [
    {"name": "Thunder", "rasse": "Hannoveraner"},
    {"name": "Luna", "rasse": "Isländer"}
]
print(pferde[1])  # Letztes Element
