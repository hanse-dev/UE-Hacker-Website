# %% [markdown]
# # 🐉 Boss Quests – 🗡️ Week 6 – Lists: The Treasure Vault of Collections
# > ⚠️ Harder! Combines everything from this week.
#
# **⚠️ ATTENTION:** These quests are significantly harder! They combine everything you have learned.
#
# **Rewards:** 1500 XP total + legendary items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 1: The Spell Generator
#
# **Reward:** 500 XP + Spell Crystal
#
# Build a system that automatically generates, filters, and sorts spells.
#
# **Step 1 – Generate spells:**
# Write `generate_spell(element, level)` that returns a list with entries (e.g. spell names depending on element/level) and return the list with `return`
#
# **Step 2 – Calculate statistics:**
# Create `calculate_spell_stats(spell_list)` that returns the length and optionally the average, and print or return the values as a dictionary
#
# **Step 3 – Create multiple spells:**
# Create a list `spells` and add at least 10 spells using a loop (e.g. with `generate_spell("Fire", i)`) and use `append()` for each entry
#
# **Step 4 – Filter and sort spells:**
# Write `filter_spells(spell_list, search_term)` that returns only entries containing the search term, sort the list with `sort()` or `sorted()`, and print the result
#
# **Step 5 – Assemble the generator:**
# Call all functions in the main section and print a short summary (count, stats, filtered count)
#
# **Bonus:** Add random attributes (e.g. mana cost, range) and validate the data.

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss Quest 2: The Guild Manager
#
# **Reward:** 600 XP + Guild Master Title
#
# Manage departments and members of a mage guild using lists and simple functions.
#
# **Step 1 – Create departments:**
# Create `create_departments(num_departments, members_per_department)` that returns a nested list (each department is a list with placeholders like "free") and return the nested list
#
# **Step 2 – Place members:**
# Write `place_member(departments, dept_index, name)` that adds a member at the specified department position, using index access to update the list
#
# **Step 3 – Distribute mana:**
# Create `distribute_mana(departments, total_mana)` that distributes mana evenly or by occupancy across the departments and return a list with mana per department
#
# **Step 4 – Print overview:**
# Write `show_overview(departments)` that prints all departments and their members in a formatted way, and at the end print a short summary (number of departments, total slots)
#
# **Bonus:** Simulate random quests (e.g. "Defeat dragon") and a function that marks them as completed.

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 3: The Quest Database
#
# **Reward:** 400 XP + Quest Book
#
# Manage quests in a list: create, search, filter, and evaluate them.
#
# **Step 1 – Create a quest:**
# Create `create_quest(name, goal, difficulty)` that returns a dictionary with "name", "goal", "difficulty" (and optionally "status") and return the dictionary with `return`
#
# **Step 2 – Add quest to list:**
# Create a list `quests` and write `add_quest(quest, quest_list)` that adds with `append()` and prints a confirmation
#
# **Step 3 – Search quests:**
# Write `search_quests(quest_list, search_term)` that returns all quests whose name or goal contains the search term
#
# **Step 4 – Filter by status:**
# Create `filter_by_status(quest_list, status)` and return the filtered list
#
# **Step 5 – Print statistics:**
# Write `quest_stats(quest_list)` that prints the count and optionally the distribution by difficulty; call all functions in the main section
#
# **Bonus:** Add a "reward" or "success" field to each quest and print a success statistic.

# %%
print()
print("🎉 +400 XP: Boss Quest completed!")
print("🏆 You have defeated the Guardian of Infinite Collections!")
print("⭐ Title earned: Master of Treasure Collections")
print()
print("🎊 CONGRATULATIONS! You have mastered Week 6!")
print("📚 Next week: Modules and libraries (math, random)!")

# %% [markdown]
# ---
#
# 🎊 **Congratulations!** You have completed all Boss Quests this week!
#
# **Up next:** Week 7 is already waiting!
