# %% [markdown]
# # 🐉 Boss Quests – 🐴 Week 2 – Data Types and Variables: The Four Hoof-Beat Types
# > ⚠️ Harder! Combines everything from this week.
#
# **⚠️ WARNING:** These missions are significantly harder! They combine everything you have learned.
#
# **Rewards:** 1500 Hoof Points total + legendary items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 1: The Feed Room
#
# **Reward:** 500 Hoof Points + Feed Room Key
#
# The feed room has 8 sacks. Each one must be catalogued!
#
# **Step 1 – Record the feed:**
# Create variables for 8 sacks with feed type (String) and weight (Float) and give each sack a unique label
#
# **Step 2 – Create feed protocol:**
# Output a heading `"=== FEED ROOM PROTOCOL ==="` and create a description for each sack using f-Strings
#
# **Step 3 – Calculate average:**
# Add all weights and divide the sum by 8
#
# **Step 4 – Find the heaviest sack:**
# Compare all weights and determine the sack with the highest weight
#
# **Step 5 – Determine total weight:**
# Calculate the total weight of all sacks by adding all weights
#
# **Bonus:** Count and output how many sacks are below the average!

# %%
# 🐴 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss Quest 2: The Training Hall
#
# **Reward:** 600 Hoof Points + Training Master Title
#
# In the training hall you analyse the exercise plans!
#
# **Step 1 – Create exercises:**
# Create 5 exercises with name, intensity (Float 1–5), duration (minutes), difficulty (1–5) and use appropriate data types for each property
#
# **Step 2 – Output exercise descriptions:**
# Output a heading `"=== TRAINING HALL PROTOCOL ==="` and create a description for each exercise using f-Strings
#
# **Step 3 – Sum total duration:**
# Add all duration values and store the total in a variable
#
# **Step 4 – Find most intense exercises:**
# Find the most intense exercise (highest intensity) and find the most difficult exercise (highest difficulty)
#
# **Step 5 – Calculate average intensity:**
# Add all intensities and divide by 5 and store the average
#
# **Step 6 – Filter demanding ones:**
# Determine which exercises are above average and use Boolean variables for marking
#
# **Bonus:** Calculate the efficiency (intensity / duration × 10) for each exercise!

# %%
# 🐴 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 3: The Tournament Training
#
# **Reward:** 400 Hoof Points + Tournament Plan
#
# Plan the next big tournament training!
#
# **Step 1 – Define training units:**
# Create Unit 1: goal, duration (days), cost, number of participants, success probability (0–1) and create Unit 2: goal, duration (days), cost, number of participants, success probability (0–1)
#
# **Step 2 – Create training protocol:**
# Output a heading `"=== TRAINING PROTOCOL ==="` and present both units with all data
#
# **Step 3 – Calculate totals:**
# Add the total cost of both units and add the total number of participants
#
# **Step 4 – Forecast success:**
# Calculate expected success: participants × success probability and calculate for both units
#
# **Step 5 – Compare units:**
# Compare cost, duration and success probability and clearly show the differences
#
# **Step 6 – Determine efficiency:**
# Find out which unit is more efficient and use a Boolean variable for marking
#
# **Bonus:** Calculate the cost per participant for each unit!

# %%
# 🐴 Your solution here:

print()
print("🎉 +400 Hoof Points: Final challenge complete!")
print("🏆 You mastered the dressage horse with stubborn hooves!")
print("⭐ Title earned: Master of Hoof-Beat Types")
print()
print("🎊 CONGRATULATIONS! You have mastered Week 2!")
print("🐴 Next week: Conditions (if-else)!")

# %% [markdown]
# ---
#
# 🎊 **Congratulations!** You have completed all boss quests of this week!
#
# **Next:** Week 3 is already waiting!
