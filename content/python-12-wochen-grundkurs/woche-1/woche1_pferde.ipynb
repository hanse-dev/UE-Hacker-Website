# %% [markdown]
# # 🐴 Woche 1 – Dein erstes Programm: Die Freundschaft beginnt
#
# **Huf-Punkte zu verdienen:** 1000 Punkte
# **Herausforderung:** Das scheue Reitpferd

# %% [markdown]
# ## 🌟 Die Freundschaft beginnt: Willkommen im Reiterhof Sonnental
#
# Willkommen, junge Pferdefreund:in! Du betrittst den idyllischen **Reiterhof Sonnental** – ein Ort voller Natur, Freundschaft und Abenteuer mit Pferden. In dieser Woche lernst du die vier wichtigsten **Lektionen**:
#
# **Deine Mission:**
# - Lerne, wie du Text mit `print()` ausgibst
# - Speichere Informationen in **Stallboxen**
# - Kombiniere Texte und Informationen zu Nachrichten
# - Füge Kommentare hinzu, um deinen Code zu erklären
#
# **Leg los!** Dein Pferdefreund wartet schon auf dich...

# %% [markdown]
# ## 🐎 Was ist eine Lektion?
#
# Eine **Lektion** ist wie eine Trainingseinheit für dich und dein Pferd - eine festgelegte Übung, die ihr gemeinsam lernt und beherrscht.
#
# **Stell dir vor:**
# - 🐴 Pferde brauchen klare Anweisungen und Training
# - 👥 Jede Lektion baut auf der vorherigen auf
# - 🌿 Mit jeder Lektion werdet ihr besser zusammen
# - 🏆 Am Ende könntet ihr ganze Parcours reiten
#
# **In der Programmierung lernen wir:**
# - Die grundlegenden Lektionen (Befehle) von Python
# - Wie man diese Lektionen kombiniert
# - Wie man eigene Lektionen erstellt (später)
#
# **Jede Lektion, die du lernst, macht dich zu einem besseren Reiter/Programmierer!**

# %% [markdown]
# ## 📚 Lektion 1: Der `print()`-Ruf
#
# **Was es ist:** `print()` ist dein erster Ruf an das Pferd. Er gibt Text auf dem Bildschirm aus.
#
# **Warum nützlich:**
# - 🗣️ Sagt deinem Pferd, was es tun soll
# - 📝 Schreibt wichtige Notizen für den Stall
# - 🏅 Zeigt Erfolge beim Training an
# - 📋 Hält Trainingserfolge fest
#
# **Wichtig:** Text muss immer in Anführungszeichen `"` oder `'` stehen!

# %%
# Beispiel 1: Einfache Textausgabe
print("Hallo Welt!")
print("Willkommen im Reiterhof Sonnental!")

# Beispiel 2: Mehrere Zeilen
print("Dies ist dein erstes Programm.")
print("Du bist jetzt ein Programmierer!")

# Beispiel 3: Leere Zeile für bessere Übersicht
print()
print("=== Dein Programm läuft erfolgreich! ===")

# %% [markdown]
# ## 📦 Lektion 2: Stallboxen - Digitale Futtertröge
#
# **Was es ist:** Eine Stallbox (Variable) ist wie ein Futtertrog mit Namen. Du kannst Informationen darin speichern und später wieder abrufen.
#
# **Warum nützlich:**
# - 🥕 Bewahrt Leckerlis für dein Pferd auf
# - 📟 Merkt sich die Telefonnummern der Reiter
# - ⚖️ Hält das Gewicht der Pferde fest
# - 🔄 Kann jederzeit mit neuen Daten gefüllt werden
#
# **Wichtig:**
# - Text: in Anführungszeichen (`"Stormy"`)
# - Zahlen: ohne Anführungszeichen (`42`)

# %%
# Beispiel 1: Verschiedene Stallboxen
pferd_name = "Stormy"      # Text (String)
pferd_alter = 8           # Zahl (Integer)
pferd_hohe = 165          # Zahl (Integer)
pferd_reitbar = True      # Wahrheitswert (Boolean)

# Beispiel 2: Stallboxen ausgeben
print("Pferd-Name:")
print(pferd_name)
print("Alter:")
print(pferd_alter)
print("Stockmaß:")
print(pferd_hohe)

# Beispiel 3: Stallboxen können sich ändern
print("\nHuf-Punkte vor dem Ausritt: " + str(pferd_hohe))
pferd_hohe = 170  # Neuer Wert
print("Huf-Punkte nach dem Ausritt: " + str(pferd_hohe))

# %% [markdown]
# ## ✨ Lektion 3: Informationen kombinieren
#
# **Was es ist:** Mit `+` kannst du Texte und Stallboxen zu einer Nachricht verbinden.
#
# **Warum nützlich:**
# - 📝 Schreibt persönliche Grüße an die Reiter
# - 🏇 Erstellt komplette Pferdeprofile
# - 🥕 Kombiniert Futterpläne mit Pferdenamen
# - 📊 Macht Ausgaben informativer und übersichtlicher
#
# **Wichtig:** Zahlen müssen mit `str()` in Text umgewandelt werden!

# %%
# Beispiel 1: Einfache Kombination
name = "Luna"
rasse = "Haflinger"
print("Reiter: " + name)
print("Pferd: " + rasse)

# Beispiel 2: Mit Zahlen (str() nötig!)
karotten = 20
print("Karotten: " + str(karotten))

# Beispiel 3: Komplexe Sätze
print(name + " reitet auf einem " + rasse + " und hat " + str(karotten) + " Karotten dabei.")

# Beispiel 4: Mehrere Informationen
print("\n=== PFERDEPROFIL ===")
print("Name: " + name)
print("Rasse: " + rasse)
print("Belohnung: " + str(karotten) + " Karotten")
print("=====================")

# %% [markdown]
# ## 💭 Lektion 4: Kommentare - Notizen für den Stall
#
# **Was es ist:** Kommentare sind Notizen im Code, die mit `#` beginnen. Der Computer ignoriert sie.
#
# **Warum nützlich:**
# - 📝 Erklärt Trainingseinheiten für andere Reiter
# - 🐴 Hilft dir, dich an besondere Pferde zu erinnern
# - 👥 Macht den Stall-Plan für alle verständlich
# - 📚 Hält wichtige Tipps für die Zukunft fest
#
# **Wichtig:** Kommentare stehen immer in einer eigenen Zeile oder nach dem Code!

# %%
# Beispiel 1: Einfache Kommentare
# Dies ist ein Kommentar
print("Hallo!")  # Dies ist ein Kommentar nach dem Code

# Beispiel 2: Mehrzeilige Erklärungen
# Erstelle ein Pferd mit folgenden Eigenschaften:
# - Name: Sunny
# - Alter: 12 Jahre
# - Spezialität: Dressur
pferd_name = "Sunny"
pferd_alter = 12

# Beispiel 3: Kommentare zur Erklärung von Berechnungen
futter = 25          # Futtermenge in kg
verbrauch = 5       # Tagesverbrauch
rest_futter = futter - verbrauch  # Berechne verbleibendes Futter
print("Verbleibendes Futter: " + str(rest_futter) + " kg")
