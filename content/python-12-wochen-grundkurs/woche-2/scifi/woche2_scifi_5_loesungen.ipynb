# %% [markdown]
# # 🔧 Lösungen – 🚀 Woche 2 – Datentypen und Variablen: Die vier Quanten-Typen
#
# > Erst selber versucht? Dann check hier nach!

# %% [markdown]
# ## 🐛 Debug-Quest Lösungen

# %%
# ✅ Lösung Bug #1: Falscher Befehl

# Problem: Kein f-String verwendet
roboter = "R2D2"
status = 3
print(f"Hallo {roboter}! Dein Status ist {status}.")

# %%
# ✅ Lösung Bug #2: Datenkollision

# Problem: String und Integer können nicht subtrahiert werden
energie = "80"
verbrauch = 30
print(f"Restenergie: {int(energie) - verbrauch}")

# %%
# ✅ Lösung Bug #3: Falsches Protokoll

# Problem: Variable in f-String nicht in geschweifte Klammern
schildstaerke = 95
print(f"Schildstärke: {schildstaerke} Prozent")

# %% [markdown]
# ## ⭐ Missions-Lösungsvorschläge
#
# > Lösungsvorschläge werden noch ergänzt.

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Das Energiedepot

# %%
# ✏️ Lösungsvorschlag Mission 1 – Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Die Flottenanalyse

# %%
# ✏️ Lösungsvorschlag Mission 2 – Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Der Asteroiden-Mining

# %%
# ✏️ Lösungsvorschlag Mission 3 – Deine Lösung hier:
