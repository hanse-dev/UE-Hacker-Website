# %% [markdown]
# # 🐉 Boss Quests – 🐴 Week 11 – Advanced OOP: The Magic Evolution!
# > ⚠️ More difficult! Combines everything from this week.
#
# **⚠️ WARNING:** These challenges are extremely difficult! They combine all advanced concepts.
#
# **Rewards:** 1800 Hoof Points total + epic items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 1: The Riding School Hierarchy
#
# **Reward:** 600 Hoof Points + Riding Instructor Badge
#
# The riding school has beginners, intermediates and pros – each gets their own lessons!
#
# **Step 1 – Base class:**
# Write a class `Rider` with name and level. Add a method `lesson()`.
#
# **Step 2 – Levels:**
# Derive 3 child classes (Beginner, Intermediate, Pro). Each overrides `lesson()` with appropriate content.
#
# **Step 3 – Riding school:**
# Create one rider of each level. Call `lesson()` for all and show the polymorphism.
#
# **Bonus:** Add `__str__` for a nice output.

# %%
# 🐴 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss Quest 2: The Horse Family
#
# **Reward:** 800 Hoof Points + Breeder's Medal
#
# All horses can gallop – but each breed has its own strength!
#
# **Step 1 – Base class:**
# Write a class `Horse` with name and energy. Add a method `run()`.
#
# **Step 2 – Breeds:**
# Derive 3 child classes (e.g. Haflinger, Arab, Andalusian). Each overrides `run()` with their special style.
#
# **Step 3 – Race:**
# Create one representative of each breed. Let them all run and show their introduction with `__str__`.
#
# **Bonus:** Add `__eq__` that compares two horses by energy.

# %%
# 🐴 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 3: The Stable Residents System
#
# **Reward:** 400 Hoof Points + Animal Caretaker Badge
#
# Various animals live on the horse farm – each makes its own sounds!
#
# **Step 1 – Base class:**
# Write a class `StableResident` with name. Add a method `make_sound()`.
#
# **Step 2 – Animals:**
# Derive 4 animals (Horse, Dog, Cat, Chicken). Each overrides `make_sound()`.
#
# **Step 3 – Morning round:**
# Create one of each animal and call `make_sound()` for all.
#
# **Bonus:** Add `__str__` and `__len__`.

# %%
# 🐴 Your solution here:

print()
print("🎉 +400 Hoof Points: Challenge completed!")
print("🏆 You have defeated the Master Breeder!")
print("⭐ Title earned: Master of Horse OOP")
print()
print("🎊 CONGRATULATIONS! You have mastered Week 11!")
print("🐴 Next week: Graphic projects with Turtle!")

# %% [markdown]
# ---
#
# 🎊 **Congratulations!** You have mastered all Boss Quests of this week!
#
# **Next up:** Week 12 is already waiting!
