# %% [markdown]
# # 🚀 Woche 4 – Schleifen (for, while): Der Zyklus der Zeit
#
# **Cyber Credits zu verdienen:** 1000 Punkte
# **Herausforderung:** Der unendliche Zeit-Loop

# %% [markdown]
# ## 🌟 Die Geschichte beginnt: Im Chronos-Turm
#
# Willkommen, Kommandant! Du erreichst den **Chronos-Turm** – ein Ort, an dem Zeit sich wiederholt und Zyklen die Realität programmieren. In dieser Woche lernst du die drei **Zeit-Zyklen**:
#
# **Deine Mission:**
# - Meistere die **for-Schleife** für kontrollierte Wiederholungen
# - Beherrsche die **while-Schleife** für flexible Bedingungen
# - Verstehe **range()** für präzise Zeit-Messungen
# - Lerne **break** und **continue** für Zeit-Manipulation
#
# **Die Zeit wartet auf niemanden!** Der Zyklus beginnt jetzt...

# %% [markdown]
# ## 📚 Systemprotokoll 1: Die for-Schleife - Der Zeit-Loop
#
# **Was es ist:** Eine for-Schleife wiederholt Code für jedes Element in einer Sequenz.
#
# **Die Anatomie einer for-Schleife:**
# ```python
# for variable in sequenz:
#     # Code, der für jedes Element ausgeführt wird
# ```
#
# **Schritt-für-Schritt-Erklärung:**
# 1. **`for`** - Das Kommando, das den Zeit-Loop startet
# 2. **`variable`** - Ein Platzhalter, der bei jedem Durchlauf das aktuelle Element enthält
# 3. **`in`** - Verbindet die Variable mit der Sequenz
# 4. **`sequenz`** - Die Sammlung, durch die wir iterieren (z.B. Liste, String, range())
# 5. **`:`** - Beendet die Schleifen-Definition
# 6. **Eingerückter Code** - Wird bei jedem Durchlauf ausgeführt
#
# **Der Iterator:**
# - Der Iterator ist wie ein unsichtbarer Zeit-Messer, der sich merkt, wo wir in der Sequenz sind
# - Er startet beim ersten Element
# - Nach jedem Durchlauf springt er automatisch zum nächsten Element
# - Die Schleife endet, wenn kein Element mehr übrig ist
#
# **Warum so nützlich:**
# - 🎯 Automatisiere wiederholende Aufgaben
# - 🔍 Verarbeite jedes Element einzeln
# - ⚡ Mache Code effizienter und kürzer
# - 🎲 Erstelle Muster und Sequenzen

# %%
# Beispiel 1: Einfache for-Schleife mit range()
print("=== Beispiel 1: 5 Zeit-Zyklen ===")
# range(5) erzeugt die Zahlen 0, 1, 2, 3, 4
for i in range(5):
    print(f"Zeit-Zyklus {i+1}: Systeme synchronisiert")

print("\n=== Was passiert hier? ===")
print("1. range(5) erstellt: [0, 1, 2, 3, 4]")
print("2. i wird bei jedem Durchlauf auf das nächste Element gesetzt")
print("3. Wir geben i+1 aus, um von 1-5 zu zählen")
print("4. Die Schleife endet nach dem letzten Element")

# %%
# Beispiel 2: For-Schleife mit Start und Ende
print("=== Beispiel 2: Sektoren 3 bis 7 scannen ===")
# range(3, 8) erzeugt die Zahlen 3, 4, 5, 6, 7 (8 ist exklusiv!)
for sektor in range(3, 8):
    print(f"Sektor {sektor}: Scan abgeschlossen")

print("\n=== Wichtige Beobachtung ===")
print("range(start, ende) enthält start, aber nicht ende!")
print("Wie bei Koordinaten: von 3 bis VOR 8")

# %%
# Beispiel 3: For-Schleife mit Schrittweite
print("=== Beispiel 3: Jeder zweite Sektor ===")
# range(0, 11, 2) erzeugt: 0, 2, 4, 6, 8, 10
for sektor in range(0, 11, 2):
    print(f"Sektor {sektor}: Verstärkung aktiviert")

print("\n=== Die Schrittweite ===")
print("range(start, ende, schritt) überspringt Sektoren")
print("Hier: jeder zweite Sektor überspringen")

# %%
# Beispiel 4: For-Schleife über einen String
print("=== Beispiel 4: Buchstaben eines Codes ===")
code = "ALPHA"
print(f"Der Code ist: {code}")
print("Buchstaben für Buchstabe:")

for buchstabe in code:
    print(f"  - {buchstabe}")

print("\n=== Was passiert hier? ===")
print("String wird als Sequenz von Buchstaben behandelt")
print("Jeder Buchstabe wird einzeln durchlaufen")

# %%
# Beispiel 5: For-Schleife über eine Liste
print("=== Beispiel 5: Planeten-System scannen ===")
planeten = ["Merkur", "Venus", "Erde", "Mars", "Jupiter"]
print("Planeten im System:")

for planet in planeten:
    print(f"  - {planet}")

print("\n=== Mit Index und Name ===")
# enumerate gibt uns sowohl Index als auch Wert
for index, planet in enumerate(planeten, start=1):
    print(f"  Planet {index}: {planet}")

# %% [markdown]
# ## 🔍 Das Geheimnis von range() - Der Zeit-Generator
#
# **range() ist dein mächtigstes Werkzeug für Zeit-Sequenzen!**
#
# ### Die drei Formen von range():
#
# 1. **`range(n)`** - Zahlen von 0 bis n-1
#    ```python
#    range(5) → 0, 1, 2, 3, 4
#    ```
#
# 2. **`range(start, ende)`** - Zahlen von start bis ende-1
#    ```python
#    range(2, 7) → 2, 3, 4, 5, 6
#    ```
#
# 3. **`range(start, ende, schritt)`** - Zahlen mit Abständen
#    ```python
#    range(1, 10, 2) → 1, 3, 5, 7, 9
#    ```
#
# **Wichtige Regeln:**
# - Die **obere Grenze ist immer exklusiv** (wird nicht mitgezählt)
# - **Negative Schritte** sind möglich für rückwärts zählen
# - range() ist **sehr speichereffizient** (erzeugt Zahlen erst bei Bedarf)

# %%
# 🔍 Übungen mit range()

# Übung 1: Countdown zum Sprung
print("=== Countdown zum Hypersprung ===")
for i in range(5, 0, -1):
    print(f"{i}...")
print("🚀 HYPERSPRUNG!")

# Übung 2: Gerade Zeitstempel
print("\n=== Gerade Zeitstempel ===")
for zeit in range(0, 21, 2):
    print(f"T{zeit:02d}", end=" ")
print()

# Übung 3: Energie-Zyklen
print("\n=== Energie-Zyklen ===")
for zyklus in range(1, 6):
    print(f"Zyklus {zyklus}: Energie-Wellen aktiv")

# %% [markdown]
# ## 📦 Systemprotokoll 2: Die while-Schleife - Der Dauer-Scanner
#
# **Was es ist:** Eine while-Schleife wiederholt Code, solange eine Bedingung wahr ist.
#
# **Die Anatomie einer while-Schleife:**
# ```python
# while bedingung:
#     # Code, der wiederholt wird, solange bedingung wahr ist
#     # WICHTIG: Die Bedingung muss irgendwann falsch werden!
# ```
#
# **Warum nützlich:**
# - ⏳ Wiederhole, bis etwas eintritt
# - 🎮 Daueraufgaben im Hintergrund
# - 🔍 Sensoren überwachen
# - ⚡ Unbekannte Anzahl von Wiederholungen
#
# **⚠️ Vorsicht:** Endlosschleifen entstehen, wenn die Bedingung niemals falsch wird!

# %%
# Beispiel 1: Einfache while-Schleife
print("=== Beispiel 1: Bis 10 scannen ===")
scan = 0
while scan <= 10:
    print(f"Scan {scan}: Daten empfangen")
    scan += 1  # WICHTIG: Hochzählen, sonst Endlosschleife!

print("\n=== Was passiert hier? ===")
print("1. scan startet bei 0")
print("2. Solange scan <= 10, wird der Code ausgeführt")
print("3. scan += 1 erhöht den Wert bei jedem Durchlauf")
print("4. Bei scan = 11 wird die Bedingung falsch → Schleife endet")

# %%
# Beispiel 2: Schild-Generator
print("=== Beispiel 2: Schild-Generator ===")
energie = 100
minute = 1

while energie > 20:
    verbrauch = 15
    energie -= verbrauch
    print(f"Minute {minute}: -{verbrauch} Energie, übrig: {energie}%")
    minute += 1

print(f"\n⚠️ Schild-Kritisch nach {minute-1} Minuten!")
print("Energie nachladen!")

# %%
# Beispiel 3: Zugangscodes
print("=== Beispiel 3: Zugangscodes ===")
code = ""
versuche = 0
max_versuche = 3

while code != "NEXUS" and versuche < max_versuche:
    code = input("Gib den Zugangscode ein: ")
    versuche += 1
    
    if code == "NEXUS":
        print("✅ Zugang gewährt!")
    elif versuche >= max_versuche:
        print("❌ Zu viele Versuche! System gesperrt.")
    else:
        print(f"Falsch! Noch {max_versuche - versuche} Versuche")

# %% [markdown]
# ## ✨ Systemprotokoll 3: break und continue - Die Zeit-Manipulatoren
#
# **break** - Beendet den Zeit-Loop sofort
# **continue** - Springt zum nächsten Zyklus
#
# **Warum nützlich:**
# - 🛑 Frühzeitiges Beenden bei Gefahr
# - ⏭️ Bestimmte Zyklen überspringen
# - 🎯 Effiziente System-Optimierung
# - ⚡ Energie sparen

# %%
# Beispiel 1: break bei Alarm
print("=== Beispiel 1: System-Scan bei Alarm beenden ===")
systeme = ["Kern", "Schild", "Waffen", "ANOMALIE", "Antrieb"]

for system in systeme:
    print(f"Scanne: {system}")
    if system == "ANOMALIE":
        print("🚨 ANOMALIE ENTDECKT! Scan abgebrochen.")
        break  # Schleife sofort beenden

print("\n=== Ohne break würden alle Systeme gescannt ===")

# %%
# Beispiel 2: continue für Filter
print("=== Beispiel 2: Nur Kritische Systeme ===")
systeme = ["Licht", "🚨 REAKTOR", "Klima", "⚠️ SCHILD", "Musik"]

print("Kritische Systeme:")
for system in systeme:
    # Überspringe, wenn kein Warn-Symbol
    if "🚨" not in system and "⚠️" not in system:
        continue  # Zum nächsten Durchlauf springen
    print(f"  - {system}")

# %%
# Beispiel 3: Komplexe Zeit-Manipulation
print("=== Beispiel 3: Missions-Protokoll ===")
stunde = 1
max_stunden = 10

while stunde <= max_stunden:
    print(f"\nStunde {stunde}:")
    
    # 3 System-Checks pro Stunde
    for check in range(3):
        print(f"  Check {check+1}: Systeme OK")
        
        # Spezial-Event bei Stunde 5
        if stunde == 5 and check == 1:
            print("  🌟 Solar-Flare: Zusätzliche Scans!")
            continue
    
    stunde += 1
    
    # Mission abbrechen bei Störung
    if stunde > 7:
        print("\n⚡ Energie-Störung! Mission abgebrochen.")
        break

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein Techniker hat versucht, Zeit-Loops zu programmieren, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1

zeit = 0
while zeit < 5:
    print(f"Zeit {zeit}")

# %%
# 🐛 Bug #2

for i in range(5):
    print(f"System {i+1}")

# %%
# 🐛 Bug #3

for i in range(3):
print(f"Protokoll {i}")
print("Ende")

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Quanten-Zähler
#
# **Belohnung:** 300 Cyber Credits + Quanten-Chip
#
# Meistere die Quanten-Zeit im Chronos-Turm und trainiere verschiedene Zählmuster mit for-Schleifen.
#
# **Deine Aufgaben:**
#
# 1. **Zeitstempel erzeugen**
#    - Gib alle Zahlen von 1 bis 20 mit einer for-Schleife aus
#    - Füge vor jedem Wert den Text `Zeit:` ein
#    - Gib am Ende eine kurze Abschlussmeldung aus
#
# 2. **Spezielle Zeitmuster zählen**
#    - Gib nur die geraden Zahlen von 1 bis 20 aus
#    - Gib die Zahlen von 20 bis 1 rückwärts aus
#    - Gib jedes dritte Zeitstempel von 0 bis 30 aus
#
# 3. **Zeit-Analyse durchführen**
#    - Berechne die Summe aller Zahlen von 1 bis 100
#    - Speichere das Ergebnis in einer Variablen
#    - Gib die Summe mit einer erklärenden Nachricht aus
#
# 4. **Eigene Zeit-Sequenz entwerfen (optional)**
#    - Überlege dir ein eigenes Zählmuster (z.B. nur Vielfache von 7)
#    - Implementiere dieses Muster mit range()
#    - Gib das Ergebnis mit einem passenden Titel aus
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Einfache Zeitstempel von 1 bis 20
# for zeit in range(1, 21):
#     print(f"Zeit: {zeit}")
#
# print("---")
#
# # 2. Gerade Zahlen von 1 bis 20
# for zahl in range(2, 21, 2):
#     print(zahl)
# ```
#
# **Bonus-Challenge:**
# - Erstelle eine Quadrat-Tabelle: Gib für jede Zahl von 1 bis 10 sowohl die Zahl als auch ihr Quadrat aus (1², 2², 3², ...).
# - Formatiere die Ausgabe so, dass sie wie eine kleine Tabelle aussieht.
#
# **Erwartete Ausgabe:**
# ```
# Zeit: 1
# Zeit: 2
# ...
# Zeit: 20
# ---
# 2
# 4
# 6
# ...
# 20
# ...
# Summe der Zahlen von 1 bis 100: 5050
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Raumstation-Kommandant
#
# **Belohnung:** 400 Cyber Credits + Kommandanten-Schlüssel
#
# Du bist für alle 10 Decks der Raumstation verantwortlich und musst Alarme, Boni und Wartungen im Blick behalten.
#
# **Deine Aufgaben:**
#
# 1. **Deck-Scanner programmieren**
#    - Erstelle eine Schleife, die alle Decks von 1 bis 10 durchgeht
#    - Gib für jedes Deck eine Standardmeldung aus
#    - Speichere die aktuelle Deck-Nummer in einer Variablen
#
# 2. **Warnungen und Boni verwalten**
#    - Gib bei Deck 3, 6 und 9 eine Warnung aus (z.B. "⚠️ Warnung auf Deck 3")
#    - Gib bei Deck 5 und 10 eine Bonusmeldung aus
#    - Kombiniere Warnung und Bonus, falls ein Deck beides sein könnte
#
# 3. **Wartung und Überspringen**
#    - Überspringe Deck 7 komplett mit `continue`
#    - Gib eine kurze Info aus, wenn Deck 7 übersprungen wird (z.B. "Deck 7 in Wartung")
#    - Achte darauf, dass für Deck 7 keine weitere Ausgabe im Schleifen-Körper erfolgt
#
# 4. **Missions-Ende steuern**
#    - Beende die Schleife bei Deck 10 mit `break`
#    - Gib zum Schluss eine Erfolgsmeldung aus (z.B. "✅ Alle wichtigen Decks überprüft!")
#    - Stelle sicher, dass die Meldung nur einmal am Ende erscheint
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Deck-Scanner Grundstruktur
# for deck in range(1, 11):
#     print(f"Deck {deck}: Standard-Scan läuft...")
#
#     # Hier kommen deine if-Bedingungen für Warnungen, Boni und Wartung hin
#
# print("Raumstations-Scan abgeschlossen.")
# ```
#
# **Bonus-Challenge:**
# - Füge eine Liste mit Ereignisbeschreibungen hinzu (z.B. "Keine Auffälligkeiten", "Kleine Störung", "Großer Alarm").
# - Wähle für jedes Deck zufällig eine Beschreibung aus und füge sie zur Ausgabe hinzu.
#
# **Erwartete Ausgabe:**
# ```
# Deck 1: Standard-Scan läuft...
# Deck 2: Standard-Scan läuft...
# Deck 3: Standard-Scan läuft...
# ⚠️ Warnung auf Deck 3!
# ...
# Deck 7 in Wartung – Scan übersprungen.
# ...
# Deck 10: Standard-Scan läuft...
# 🎁 Bonus auf Deck 10!
# ✅ Alle wichtigen Decks überprüft!
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Das Zeit-Paradoxon
#
# **Belohnung:** 500 Cyber Credits + Zeit-Reise-Lizenz
#
# Du steckst in einem Zeit-Paradoxon fest und springst zufällig durch die Jahre – nur mit cleveren Schleifen kannst du entkommen.
#
# **Deine Aufgaben:**
#
# 1. **Zeit-Loop aufbauen**
#    - Erstelle eine `while True`-Schleife als Haupt-Zeit-Loop
#    - Lege Variablen für `spruenge` und das aktuelle `jahr` an
#    - Erhöhe die Anzahl der Sprünge bei jedem Durchlauf
#
# 2. **Zeit-Sprünge simulieren**
#    - Generiere zufällige Zeit-Sprünge (z.B. mit positiven und negativen Werten)
#    - Aktualisiere das aktuelle Jahr mit jedem Sprung
#    - Merke dir das Startjahr (z.B. 2024) als Bezugspunkt
#
# 3. **Enden des Paradoxons steuern**
#    - Beende nach 100 Sprüngen mit einer Meldung wie "Gefangen im Zeit-Paradoxon"
#    - Beende sofort mit `break`, wenn du wieder im Startjahr landest
#    - Gib unterschiedliche Abschlussmeldungen für Erfolg und Misserfolg aus
#
# 4. **Statusmeldungen und Kontrolle**
#    - Gib bei jedem 10. Sprung eine Statusmeldung mit aktuellem Jahr und Sprungzahl aus
#    - Achte darauf, dass die Schleife immer ein klares Ende hat
#    - Nutze if-Bedingungen, um die verschiedenen Fälle sauber zu trennen
#
# **Beispiel-Code zum Starten:**
# ```python
# import random
#
# start_jahr = 2024
# aktuelles_jahr = start_jahr
# spruenge = 0
#
# while True:
#     spruenge += 1
#     sprungweite = random.randint(-50, 50)
#     aktuelles_jahr += sprungweite
#
#     # Status alle 10 Sprünge
#     if spruenge % 10 == 0:
#         print(f"Sprung {spruenge}: Jahr {aktuelles_jahr}")
#
#     # Hier prüfst du auf Erfolg oder Misserfolg
#     # und brichst die Schleife mit break ab
# ```
#
# **Bonus-Challenge:**
# - Erstelle eine Liste, in der du jedes besuchte Jahr speicherst.
# - Gib am Ende alle Jahre in der richtigen Reihenfolge aus.
#
# **Erwartete Ausgabe:**
# ```
# Sprung 10: Jahr 1987
# Sprung 20: Jahr 2103
# ...
# ✅ Du bist im Jahr 2024 gelandet – das Paradoxon ist beendet!
# # oder
# ❌ Nach 100 Sprüngen bist du im Zeit-Tunnel gefangen.
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten des Zeit-Meisters (Reflexion)
#
# Bevor du weiterreist, denke über diese Fragen nach:
#
# 1. **Wann würdest du for statt while verwenden (und umgekehrt)?**
#
# 2. **Warum ist range(ende) exklusiv für das Ende?**
#
# 3. **Wie kannst du Endlosschleifen vermeiden?**
#
# Diskutiere deine Gedanken mit anderen Kommandanten!

# %% [markdown]
# ### 📖 Tech-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **for** 🔄: Schleife über Sequenzen
# - **while** ⏳: Schleife mit Bedingung
# - **range()** 🔢: Erzeugt Zahlenfolgen
# - **in** 📍: Prüft Mitgliedschaft/Iteration
# - **break** 🛑: Beendet Schleife sofort
# - **continue** ⏭️: Springt zum nächsten Durchlauf
# - **Iterator** 👣: Verfolgt aktuelle Position
# - **Variable** 📦: Speichert aktuelle Werte
# - **Schrittweite** 📏: Abstand zwischen Zahlen
# - **Endlosschleife** ♾️: Schleife ohne Ende
# - **Einrückung** 📝: Code-Block in Schleifen

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ✅ for-Schleifen mit range() verwenden
# - ✅ while-Schleifen mit Bedingungen steuern
# - ✅ Schleifen über Strings und Listen
# - ✅ break und continue richtig einsetzen
# - ✅ Verschachtelte Schleifen erstellen
# - ✅ Endlosschleifen erkennen und vermeiden
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die finalen Herausforderungen!

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Exzellent!** Du hast den Zyklus der Zeit gemeistert!
#
# **Das hast du gelernt:**
# - for-Schleifen für kontrollierte Wiederholungen
# - while-Schleifen für flexible Bedingungen
# - range() für präzise Zahlenfolgen
# - break und continue für Schleifen-Kontrolle
# - Verschachtelte Schleifen für komplexe Muster
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🎮 **Spiele:** Game-Loops, Animationen, KI-Züge
# - 📱 **Apps:** Daten-Downloads, Updates, Benachrichtigungen
# - 🌐 **Websites:** Bildergalerien, News-Feeds, Suchen
# - 🤖 **KI-Systeme:** Training, Datenanalyse, Mustererkennung
# - 📊 **Wissenschaft:** Simulationen, Berechnungen, Modelle
#
# **Als Nächstes:** In Woche 5 lernst du **Funktionen**!

# %% [markdown]
# ## 🚀 Finale Herausforderung: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Missionen sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 Cyber Credits + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Finale Herausforderung 1: Die Primzahl-Entschlüsselung
#
# **Belohnung:** 500 Cyber Credits + Quanten-Prozessor
#
# Entschlüssle die Primzahl-Codes des Chronos-Turms und analysiere alle Primzahlen in einem bestimmten Bereich.
#
# **Deine Aufgaben:**
#
# 1. **Zahlenbereich vorbereiten**
#    - Erstelle eine Schleife von 2 bis 100 mit `range(2, 101)`
#    - Speichere jede aktuell geprüfte Zahl in einer Variablen `zahl`
#    - Bereite Listen/Variablen für Primzahlen, Anzahl und Summe vor
#
# 2. **Primzahl-Test implementieren**
#    - Nutze eine verschachtelte Schleife, um jede `zahl` zu testen
#    - Teile `zahl` durch alle möglichen Teiler und prüfe den Rest mit `%`
#    - Setze eine Variable `ist_prim` je nach Ergebnis auf `True` oder `False`
#
# 3. **Ergebnisse sammeln und ausgeben**
#    - Füge jede gefundene Primzahl zu einer Liste hinzu
#    - Gib jede Primzahl mit einer gut lesbaren Nachricht aus
#    - Zähle, wie viele Primzahlen gefunden wurden, und berechne ihre Summe
#
# 4. **Visualisierung erstellen**
#    - Erstelle eine einfache Darstellung aller Primzahlen in einer Zeile
#    - Nutze z.B. ein Symbol oder Markierung für Primzahlen
#    - Gib am Ende eine kurze Zusammenfassung aus
#
# **Beispiel-Code zum Starten:**
# ```python
# print("=== PRIMZAHL-ENTSCHLÜSSELUNG ===")
#
# primzahlen = []
# anzahl = 0
# summe = 0
#
# for zahl in range(2, 101):
#     ist_prim = True
#     for teiler in range(2, zahl):
#         if zahl % teiler == 0:
#             ist_prim = False
#             break
#
#     if ist_prim:
#         primzahlen.append(zahl)
#         anzahl += 1
#         summe += zahl
# ```
#
# **Bonus-Challenge:**
# - Erweitere den Bereich auf 2 bis 1000 und finde die größte Primzahl.
# - Vergleiche, wie sich Anzahl und Summe der Primzahlen verändern.
#
# **Erwartete Ausgabe:**
# ```
# === PRIMZAHL-ENTSCHLÜSSELUNG ===
# 2 ist eine Primzahl
# 3 ist eine Primzahl
# 5 ist eine Primzahl
# ...
# 97 ist eine Primzahl
#
# Anzahl der Primzahlen: 25
# Summe der Primzahlen: 1060
# Primzahlen: 2 3 5 7 11 ... 97
# ```

# %%
# 🚀 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Finale Herausforderung 2: Das Holodeck
#
# **Belohnung:** 600 Cyber Credits + Holodeck-Meister
#
# Erstelle ein virtuelles Holodeck mit einem Schachbrett-Grid, beweglichen Objekten und einfachen Kollisionsregeln.
#
# **Deine Aufgaben:**
#
# 1. **Holodeck-Grid aufbauen**
#    - Erstelle ein 8x8-Grid mit zwei verschachtelten for-Schleifen
#    - Nutze eine Liste von Listen, um das Grid zu speichern
#    - Verwende unterschiedliche Symbole für helle und dunkle Felder (z.B. ⬜ und ⬛)
#
# 2. **Muster und Objekte platzieren**
#    - Implementiere das Schachbrettmuster über `(zeile + spalte) % 2`
#    - Setze einen Spieler und ein Ziel auf Startpositionen (z.B. oben links und unten rechts)
#    - Speichere die Positionen in Variablen (z.B. `spieler_pos`, `ziel_pos`)
#
# 3. **Bewegung simulieren**
#    - Erstelle eine Schleife, die mehrere Züge simuliert
#    - Aktualisiere in jedem Schritt die Spielerposition
#    - Gib nach jedem Zug das Grid oder zumindest die aktuelle Position aus
#
# 4. **Kollisionen und Zielerreichung prüfen**
#    - Prüfe bei jedem Zug, ob der Spieler das Ziel erreicht hat
#    - Gib eine Erfolgsmeldung bei Zielerreichung aus
#    - Optional: Beende die Simulation mit `break`, wenn das Ziel erreicht ist
#
# **Beispiel-Code zum Starten:**
# ```python
# print("=== HOLODECK-SIMULATOR ===")
#
# # Grid erstellen
# grid = []
# for zeile in range(8):
#     grid_reihe = []
#     for spalte in range(8):
#         if (zeile + spalte) % 2 == 0:
#             grid_reihe.append("⬜")
#         else:
#             grid_reihe.append("⬛")
#     grid.append(grid_reihe)
#
# spieler_pos = [0, 0]
# ziel_pos = [7, 7]
#
# print("Startposition Spieler:", spieler_pos)
# print("Zielposition:", ziel_pos)
# ```
#
# **Bonus-Challenge:**
# - Füge Schach-Koordinaten (A–H, 1–8) zur Ausgabe hinzu.
# - Gib bei jedem Zug die aktuelle Koordinate des Spielers (z.B. "Spieler auf Feld C3") aus.
#
# **Erwartete Ausgabe:**
# ```
# === HOLODECK-SIMULATOR ===
# Startposition Spieler: [0, 0]
# Zielposition: [7, 7]
# Zug 1: Spieler auf [1, 0]
# Zug 2: Spieler auf [2, 0]
# ...
# ✅ Ziel erreicht! Holodeck-Simulation erfolgreich abgeschlossen.
# ```

# %%
# 🚀 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Finale Herausforderung 3: Der unendliche Tunnel
#
# **Belohnung:** 400 Cyber Credits + Tunnel-Navigator
#
# Der Wurmloch-Tunnel scheint endlos – du testest, wie weit dein Schiff im Tunnel überleben kann.
#
# **Deine Aufgaben:**
#
# 1. **Tunnel-Schleife programmieren**
#    - Erstelle eine Endlosschleife mit `while True`
#    - Nutze eine Variable `distanz`, um die Anzahl der durchflogenen Portale zu zählen
#    - Gib zu Beginn eine Startmeldung mit dem aktuellen Status aus
#
# 2. **Portale und Energie simulieren**
#    - Generiere für jedes Portal eine zufällige Energie mit `random.randint()`
#    - Reduziere bei jedem Durchgang den Treibstoff und ggf. den Schild
#    - Gib zu jedem Portal eine kurze Meldung mit Energie und Status aus
#
# 3. **Schiff-Status überwachen**
#    - Verwalte `schild` und `treibstoff` mit Variablen
#    - Brich die Schleife mit `break` ab, wenn Treibstoff oder Schild auf 0 fällt
#    - Gib passende Warnungen bei kritischen Werten aus
#
# 4. **Bestleistung speichern und Statistik ausgeben**
#    - Speichere die beste erreichte Distanz in `beste_distanz`
#    - Aktualisiere sie, wenn ein neuer Rekord erreicht wird
#    - Gib am Ende eine Zusammenfassung mit Distanz, bester Distanz und wichtigen Ereignissen aus
#
# **Beispiel-Code zum Starten:**
# ```python
# import random
#
# print("=== WURMLOCH-TUNNEL ===")
#
# distanz = 0
# beste_distanz = 0
# schild = 100
# treibstoff = 100
#
# while True:
#     distanz += 1
#     portal_energie = random.randint(1, 100)
#     treibstoff -= 5
#
#     print(f"Portal {distanz}: Energie {portal_energie}, Treibstoff {treibstoff}%, Schild {schild}%")
#
#     if treibstoff <= 0:
#         print("🚫 Treibstoff leer!")
#         break
#
# # Hier kannst du Statistiken und Rekorde ausgeben
# ```
#
# **Bonus-Challenge:**
# - Füge Alien-Begegnungen mit zufälligen Ereignissen hinzu (z.B. Schildschaden oder Bonus-Treibstoff).
# - Speichere alle besonderen Ereignisse in einer Liste und gib sie am Ende sortiert aus.
#
# **Erwartete Ausgabe:**
# ```
# === WURMLOCH-TUNNEL ===
# Portal 1: Energie 73, Treibstoff 95%, Schild 100%
# Portal 2: Energie 12, Treibstoff 90%, Schild 100%
# ...
# 🚫 Treibstoff leer!
# Beste Distanz: 17 Portale
# ```

# %%
# 🚀 Deine Lösung hier:

print()
print("🎉 +400 Cyber Credits: Finale Herausforderung abgeschlossen!")
print("🏆 Du hast den unendlichen Zeit-Loop besiegt!")
print("⭐ Titel erhalten: Meister der Zeit-Zyklen")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 4 gemeistert!")
print("🚀 Nächste Woche: Funktionen (def, return)!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen:

# %%
# ✅ Lösung Bug #1: Endlosschleife

# Problem: zeit wird nicht erhöht
zeit = 0
while zeit < 5:
    print(f"Zeit {zeit}")
    zeit += 1  # Das fehlte!

# %%
# ✅ Lösung Bug #2: Falsche range-Grenze

# Problem: range(5) gibt 0-4, aber wir wollen 1-5
for i in range(1, 6):  # Start bei 1, ende bei 6 (exklusiv)
    print(f"System {i}")

# %%
# ✅ Lösung Bug #3: Vergessene Einrückung

# Problem: Code nach for nicht eingerückt
for i in range(3):
    print(f"Protokoll {i}")
print("Ende")
