# %% [markdown]
# # 🐛 Debug-Quest – ⚔️ Woche 9 – JSON-Dateien und I/O: Die Schriftrollen der Daten
#
# > 📖 Vorher: `…_1_lektion` durcharbeiten

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein Schreiber hat versucht, die Schriftrollen zu beschreiben, aber etwas läuft schief! Finde die Fehler:

# %% [markdown]
# ### 🐛 Bug #1
#
# **Was passiert:** Dieser Code enthält einen Fehler – findest du ihn?

# %%
# 🐛 Bug #1

with open('test.txt', 'w') as f:
    f.write('Hallo')
    inhalt = f.read()

# %% [markdown]
# ### 🐛 Bug #2
#
# **Was passiert:** `str` hat keine Methode oder Eigenschaft namens `read`. Schau genau auf die Schreibweise – Python unterscheidet Groß- und Kleinbuchstaben.

# %%
# 🐛 Bug #2

import json
daten = {'name': 'Test'}
json_string = json.dumps(daten)
ergebnis = json.load(json_string)

# %% [markdown]
# ### 🐛 Bug #3
#
# **Was passiert:** Die angegebene Datei existiert nicht. Prüfe den Dateinamen und ob die Datei im richtigen Ordner liegt.

# %%
# 🐛 Bug #3

import csv
with open('test.csv', 'r') as f:
    reader = csv.reader(f)
    for zeile in reader:
        print(zeile[0], zeile[1], zeile[2])
