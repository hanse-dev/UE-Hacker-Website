# %% [markdown]
# # 🐛 Debug-Quest – 🐴 Woche 5 – Funktionen: Die Trainingsroutinen
#
# Ein Anfänger hat versucht, Trainingsroutinen zu erstellen, aber etwas läuft schief! Finde die Fehler:
# > 💡 **Diese Fehler wurden absichtlich eingebaut** – damit du das Debuggen üben kannst!

# %% [markdown]
# ### 🐛 Bug #1
#
# Was ist falsch? Finde und behebe den Fehler!

# %%
def begruessung():
print("Willkommen im Stall!")
return "Begrüßt"

# %% [markdown]
# ### 🐛 Bug #2
#
# Was ist falsch? Finde und behebe den Fehler!

# %%
def berechne_trainingszeit(dauer):
    return dauer * 60

result = berechne_trainingszeit
print(f"Trainingszeit: {result}")

# %% [markdown]
# ### 🐛 Bug #3
#
# Was ist falsch? Finde und behebe den Fehler!

# %%
def addiere_trainingseinheiten(einheiten1, einheiten2):
    gesamt = einheiten1 + einheiten2

gesamt_training = addiere_trainingseinheiten(5, 3)
print(f"Gesamt-Training: {gesamt_training}")
