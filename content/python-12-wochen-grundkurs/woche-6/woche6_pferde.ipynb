# %% [markdown]
# # 🐴 Woche 6 – Listen: Die Trainings-Sammlungen
#
# **Huf-Punkte zu verdienen:** 1000 Punkte
# **Boss:** Der Stallmeister der unendlichen Listen

# %% [markdown]
# ## 🌟 Die Quest beginnt: Die Trainingshalle der Organisation
#
# Willkommen im Reiterhof Sonnental! Du erreichst die **Trainingshalle der Organisation** – ein Ort, an dem unendlich viele Trainingspläne und Pferdedaten gesammelt und organisiert werden können. In dieser Woche lernst du die drei **Arten der Sammlungs-Techniken**:
#
# **Deine Mission:**
# - Meistere die **Listen-Erstellung** mit eckigen Klammern
# - Beherrsche **Elemente hinzufügen** mit append() und insert()
# - Lerne **Elemente entfernen** mit remove() und pop()
# - Verstehe **Listen durchsuchen** mit index() und in-Operator
#
# **Einmal gesammelt, für immer organisiert!** Die Macht der Listen wartet...

# %% [markdown]
# ## 📚 Sammlungs-Technik 1: Die Listen-Erstellung - Der erste Plan
#
# **Was es ist:** Eine Liste ist eine geordnete Sammlung von Elementen, die du mit eckigen Klammern erstellst.
#
# **Die Anatomie einer Liste:**
# ```python
# # Leere Liste erstellen
# leere_liste = []
#
# # Liste mit Elementen erstellen
# pferde_liste = ["Thunder", "Luna", "Storm"]
# ```
#
# **Schritt-für-Schritt-Erklärung:**
# 1. **`[]`** - Eckige Klammern definieren eine Liste
# 2. **`,`** - Kommas trennen die Elemente
# 3. **`""`** - Strings werden in Anführungszeichen gesetzt
# 4. **`[]`** - Mit Index greifst du auf Elemente zu (beginnt bei 0)
#
# **Warum so nützlich:**
# - 🎯 Mehrere Werte in einer Variable speichern
# - 🔍 Geordnete Struktur für Daten
# - ⚡ Flexibel erweiterbar und veränderbar
# - 🎲 Verschiedene Datentypen mischbar

# %%
# Beispiel 1: Einfache Listen erstellen
# Leere Liste
leere_liste = []
print(f"Leere Liste: {leere_liste}")

# Liste mit Pferden
pferde = ["Thunder", "Luna", "Storm", "Shadow"]
print(f"Pferde-Liste: {pferde}")

# Liste mit Zahlen
trainings_level = [1, 2, 3, 4, 5]
print(f"Trainings-Level: {trainings_level}")

# Gemischte Liste
mixed = ["Sattel", 25, True, "Zaumzeug"]
print(f"Gemischte Liste: {mixed}")

# %%
# Beispiel 2: Auf Listenelemente zugreifen
ausruestung = ["Sattel", "Zaumzeug", "Gerte", "Satteldecke", "Hufpflege"]

print("=== Ausrüstungs-Zugriff ===")
print(f"Gesamte Ausrüstung: {ausruestung}")
print(f"Erstes Item: {ausruestung[0]}")
print(f"Zweites Item: {ausruestung[1]}")
print(f"Letztes Item: {ausruestung[-1]}")

# Länge der Liste
print(f"Anzahl Items: {len(ausruestung)}")

# Slicing (Ausschnitte)
print(f"Erste 3 Items: {ausruestung[0:3]}")
print(f"Letzte 2 Items: {ausruestung[-2:]}")

# %%
# Beispiel 3: Listen in Listen (verschachtelte Listen)
pferde_party = [
    ["Thunder", "Hannoveraner", 8, "Springen"],
    ["Luna", "Isländer", 5, "Dressur"],
    ["Storm", "Quarter Horse", 6, "Western"]
]

print("=== Pferde-Party ===")
print(f"Erstes Pferd: {pferde_party[0]}")
print(f"Name des ersten Pferdes: {pferde_party[0][0]}")
print(f"Rasse des zweiten Pferdes: {pferde_party[1][1]}")
print(f"Alter des dritten Pferdes: {pferde_party[2][2]} Jahre")
print(f"Disziplin des ersten Pferdes: {pferde_party[0][3]}")

# %% [markdown]
# ## 📦 Sammlungs-Technik 2: Elemente verwalten - Der Stallmeister
#
# **Die wichtigsten Listen-Methoden:**
#
# **Elemente hinzufügen:**
# - `append(element)` - Fügt am Ende hinzu
# - `insert(index, element)` - Fügt an bestimmter Position ein
#
# **Elemente entfernen:**
# - `remove(element)` - Entfernt erstes Vorkommen
# - `pop(index)` - Entfernt und gibt Element zurück
# - `clear()` - Leert die gesamte Liste

# %%
# 🔍 Übungen mit append() und insert()

# Beispiel 1: Elemente hinzufügen
trainings_plan = []
print(f"Leerer Trainingsplan: {trainings_plan}")

# Mit append() am Ende hinzufügen
trainings_plan.append("Longieren")
print(f"Nach append: {trainings_plan}")

trainings_plan.append("Dressur")
trainings_plan.append("Springen")
print(f"Voll gefüllt: {trainings_plan}")

# Mit insert() an bestimmter Position einfügen
trainings_plan.insert(0, "Aufwärmen")  # Am Anfang
print(f"Nach insert(0): {trainings_plan}")

trainings_plan.insert(2, "Cavaletti")  # An Position 2
print(f"Nach insert(2): {trainings_plan}")

# %%
# Beispiel 2: Elemente entfernen
futter_plan = ["Heu", "Hafer", "Müsli", "Karotten", "Äpfel", "Müsli"]
print(f"Original-Futterplan: {futter_plan}")

# Mit remove() erstes Vorkommen entfernen
futter_plan.remove("Müsli")
print(f"Nach remove('Müsli'): {futter_plan}")

# Mit pop() letztes Element entfernen und zurückgeben
letztes_futter = futter_plan.pop()
print(f"Nach pop(): {futter_plan}")
print(f"Entferntes Futter: {letztes_futter}")

# Mit pop(index) bestimmtes Element entfernen
zweites_futter = futter_plan.pop(1)
print(f"Nach pop(1): {futter_plan}")
print(f"Entferntes Futter: {zweites_futter}")

# Mit clear() alles löschen
futter_plan.clear()
print(f"Nach clear(): {futter_plan}")

# %%
# Beispiel 3: Listen kombinieren
pferde = ["Thunder", "Luna", "Storm"]
reiter = ["Anna", "Max", "Sarah"]
trainings = ["Dressur", "Springen", "Western"]

print("=== Listen kombinieren ===")
print(f"Pferde: {pferde}")
print(f"Reiter: {reiter}")
print(f"Trainings: {trainings}")

# Mit + Operator kombinieren
alle = pferde + reiter + trainings
print(f"Alles kombiniert: {alle}")

# Mit extend() eine Liste zur anderen hinzufügen
pferde.extend(reiter)
print(f"Pferde erweitert: {pferde}")

# %% [markdown]
# ## ✨ Sammlungs-Technik 3: Listen durchsuchen und sortieren - Der Ordnungs-Zauber
#
# **Die mächtigsten Such-Methoden:**
#
# **Suchen und prüfen:**
# - `index(element)` - Gibt Index des Elements zurück
# - `element in liste` - Prüft ob Element vorhanden
# - `count(element)` - Zählt Vorkommen
#
# **Sortieren:**
# - `sort()` - Sortiert die Liste selbst
# - `sorted(liste)` - Gibt sortierte Kopie zurück
# - `reverse()` - Kehrt Reihenfolge um

# %%
# Beispiel 1: In Listen suchen
pferde = ["Thunder", "Luna", "Storm", "Shadow", "Thunder", "Luna"]

print("=== In Listen suchen ===")
print(f"Pferde-Liste: {pferde}")

# Mit index() Position finden
position_luna = pferde.index("Luna")
print(f"Luna an Position: {position_luna}")

# Mit in() prüfen ob vorhanden
hat_storm = "Storm" in pferde
hat_bobby = "Bobby" in pferde
print(f"Storm vorhanden: {hat_storm}")
print(f"Bobby vorhanden: {hat_bobby}")

# Mit count() zählen
anzahl_thunder = pferde.count("Thunder")
print(f"Anzahl Thunder: {anzahl_thunder}")

# %%
# Beispiel 2: Listen sortieren
level = [5, 2, 8, 1, 9, 3]
namen = ["Zara", "Anna", "Max", "Berta", "Klaus"]

print("=== Listen sortieren ===")
print(f"Original-Level: {level}")
print(f"Original-Namen: {namen}")

# Mit sort() direkt sortieren
level.sort()
print(f"Level nach sort(): {level}")

# Mit sorted() Kopie sortieren
sortierte_namen = sorted(namen)
print(f"Namen Original: {namen}")
print(f"Namen sortiert: {sortierte_namen}")

# Umgekehrt sortieren
level.sort(reverse=True)
print(f"Level absteigend: {level}")

# Mit reverse() Reihenfolge umkehren
namen.reverse()
print(f"Namen umgekehrt: {namen}")

# %%
# Beispiel 3: Fortgeschrittene Listen-Operationen
disziplinen = ["Dressur", "Springen", "Western", "Dressur", "Western"]

print("=== Fortgeschrittene Operationen ===")
print(f"Disziplinen-Liste: {disziplinen}")

# Einzigartige Elemente (mit set)
einzigartige_disziplinen = list(set(disziplinen))
print(f"Einzigartige Disziplinen: {einzigartige_disziplinen}")

# Listen mit for-Schleife durchlaufen
print("\nAlle Disziplinen:")
for i, d in enumerate(disziplinen):
    print(f"  Position {i}: {d}")

# List Comprehension (fortgeschritten)
lange_namen = [d for d in disziplinen if len(d) > 6]
print(f"\nDisziplinen mit langen Namen: {lange_namen}")

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein Stallhelfer hat versucht, die Pferdelisten zu organisieren, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1

pferde = ["Thunder", "Luna", "Storm"
print(f"Pferde: {pferde}")

# %%
# 🐛 Bug #2

ausruestung = ["Sattel", "Zaumzeug", "Gerte"]
print(ausruestung[3])

# %%
# 🐛 Bug #3

level = [1, 5, 10, 15]
level.sort(reverse)
print(level)

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Pferdesammler
#
# **Belohnung:** 300 Huf-Punkte + Stall-Schlüssel
#
# Erstelle deine erste Pferdesammlung!
#
# **Was du tun sollst:**
# 1. **Liste erstellen:** Erstelle eine Liste mit 5 verschiedenen Pferdenamen
# 2. **Pferde hinzufügen:** Füge mit append() 3 neue Pferde hinzu
# 3. **Pferd entfernen:** Entferne mit remove() ein Pferd
# 4. **Position finden:** Finde mit index() die Position eines Pferdes
# 5. **Sortieren:** Sortiere die Pferde alphabetisch mit sort()
#
# **Tipp:** Nutze die eckigen Klammern [] für die Listen-Erstellung!
#
# **Bonus-Challenge:** Erstelle eine verschachtelte Liste mit Pferde-Details.

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Trainings-Manager
#
# **Belohnung:** 400 Huf-Punkte + Trainings-Planer
#
# Erstelle ein komplettes Trainings-System!
#
# **Was du tun sollst:**
# 1. **Trainingsliste erstellen:** Erstelle eine Liste mit verschiedenen Übungen
# 2. **Übung hinzufügen:** Erstelle eine Funktion mit append() und insert()
# 3. **Übung entfernen:** Erstelle eine Funktion mit remove() und pop()
# 4. **Training suchen:** Erstelle eine Funktion mit index() und in-Operator
# 5. **Statistik anzeigen:** Zeige Anzahl, Dauer und Schwierigkeit
#
# **Tipp:** Nutze Funktionen, um die Listen-Operationen zu organisieren!
#
# **Bonus-Challenge:** Füge Zeitplanung und Schwierigkeitsgrade hinzu.

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Die Reiter-Gilde
#
# **Belohnung:** 500 Huf-Punkte + Reitmeister-Urkunde
#
# Erstelle ein System für eine Reiter-Gilde!
#
# **Was du tun sollst:**
# 1. **Gilden-Liste erstellen:** Erstelle eine verschachtelte Liste mit Reiterdaten
# 2. **Reiter hinzufügen:** Erstelle eine Funktion für neue Mitglieder
# 3. **Reiter suchen:** Erstelle eine Funktion zur Suche nach Level
# 4. **Reiter sortieren:** Erstelle eine Funktion mit sort() und sorted()
# 5. **Statistik erstellen:** Zeige Levelverteilung und Pferde
#
# **Tipp:** Nutze verschachtelte Listen für komplexe Reiterdaten!
#
# **Bonus-Challenge:** Füge Turniere und Siege zur Gilde hinzu.

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten des Stallmeisters (Reflexion)
#
# Bevor du weiterreitest, denke über diese Fragen nach:
#
# 1. **Warum sind Listen besser als einzelne Variablen?**
#
# 2. **Wann sollte man append() und wann insert() verwenden?**
#
# 3. **Was ist der Unterschied zwischen sort() und sorted()?**
#
# Diskutiere deine Gedanken mit anderen Reitern!

# %% [markdown]
# ### 📖 Pferde-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **list** 🐴: Datentyp für Listen
# - **[]** 📦: Eckige Klammern für Listen
# - **append()** ➕: Am Ende hinzufügen
# - **insert()** 📍: An Position einfügen
# - **remove()** ❌: Element entfernen
# - **pop()** 🎯: Element entfernen und zurückgeben
# - **index()** 🔍: Position finden
# - **in** ✅: Prüfen ob vorhanden
# - **sort()** 📊: Liste sortieren
# - **nested list** 🎲: Verschachtelte Liste

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ✅ Listen erstellen mit eckigen Klammern
# - ✅ Elemente hinzufügen mit append() und insert()
# - ✅ Elemente entfernen mit remove() und pop()
# - ✅ Listen durchsuchen mit index() und in-Operator
# - ✅ Listen sortieren mit sort() und sorted()
# - ✅ Listen verschachteln für komplexe Datenstrukturen
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die Boss-Quests!

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Hervorragend!** Du hast die Trainings-Sammlungen gemeistert!
#
# **Das hast du gelernt:**
# - Listen erstellen und verwalten
# - Elemente hinzufügen und entfernen
# - In Listen suchen und sortieren
# - Verschachtelte Listen erstellen
# - Fortgeschrittene Listen-Operationen
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🐴 **Pferdesport:** Trainingspläne, Turnier-Listen, Pferde-Datenbanken
# - 📱 **Apps:** Kontaktlisten, Playlists, Einkaufswagen
# - 🌐 **Websites:** Menüs, Galerien, Daten-Tabellen
# - 🤖 **KI-Systeme:** Datensätze, Feature-Listen, Ergebnisse
# - 📊 **Wissenschaft:** Messwerte, Experiment-Daten, Ergebnisse
#
# **Als Nächstes:** In Woche 7 lernst du **Module und Bibliotheken**!

# %% [markdown]
# ## 🐉 Boss-Kampf: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Quests sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 Huf-Punkte + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Der Trainings-Generator
#
# **Belohnung:** 500 Huf-Punkte + Trainings-Kristall
#
# Erstelle ein System, das automatisch Trainings generiert!
#
# **Was du tun sollst:**
#
# **1. Training generieren:**
#    - Erstelle eine Funktion für pferdetyp- und schwierigkeitsbasierte Trainings
#    - Die Funktion soll pferdetyp and schwierigkeit als Parameter nehmen
#    - Gib eine Liste mit generierten Trainings zurück
#
# **2. Intensität berechnen:**
#    - Schreibe eine Funktion, die die Dauer und Komplexität prüft
#    - Die Funktion soll eine trainingsliste entgegennehmen
#    - Gib Statistik über die Trainings zurück
#
# **3. Trainingsliste erstellen:**
#    - Erstelle eine Funktion für anzahlbasierte Trainings
#    - Die Funktion soll anzahl and pferdetyp nutzen
#    - Gib eine Liste mit mehreren Trainings zurück
#
# **4. Training filtern:**
#    - Schreibe eine Funktion mit suchkriteriumbasiertem Filter
#    - Die Funktion soll trainingsliste and suchbegriff nehmen
#    - Gib eine gefilterte Liste zurück
#
# **5. Schwierigkeit sortieren:**
#    - Erstelle eine Funktion für schwierigkeitsgestützte Sortierung
#    - Die Funktion soll trainingsliste and schwierigkeiten nutzen
#    - Gib eine sortierte Liste zurück
#
# **6. System integrieren:**
#    - Verbinde alle Funktionen zu einem Generator
#    - Erstelle mindestens 10 verschiedene Trainings
#    - Zeige eine Statistik der generierten Trainings
#
# **Beispiel-Struktur:**
# ```python
# # So könntest du beginnen:
# def generiere_training(pferdetyp, schwierigkeit):
#     # Generiert Training basierend auf Typ und Schwierigkeit
#     pass
#
# def berechne_trainings_statistik(trainingsliste):
#     # Berechnet Statistik über die Trainings
#     pass
#
# # ... weitere Funktionen hier
#
# # Hauptprogramm
# trainings = []
# # Generiere Trainings...
# ```
#
# **Bonus-Challenge:** Füge zufällige Trainings-Attribute und Validierung hinzu.

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Der Stall-Manager
#
# **Belohnung:** 600 Huf-Punkte + Stallmeister-Titel
#
# Erstelle ein System für Stall-Verwaltung!
#
# **Was du tun sollst:**
#
# **1. Boxen generieren:**
#    - Erstelle eine Funktion für anzahlbasierte Boxen und Pferde
#    - Die Funktion soll anzahl_boxen and pferde_pro_box nehmen
#    - Gib eine verschachtelte Liste mit Boxen zurück
#
# **2. Pferde platzieren:**
#    - Schreibe eine Funktion für boxen- und listenbasierte Platzierung
#    - Die Funktion soll boxen and pferdeliste nutzen
#    - Platziere Pferde in den Boxen
#
# **3. Futter planen:**
#    - Erstelle eine Funktion für bedarfsbasierte Futterverteilung
#    - Die Funktion soll boxen and totales_futter nehmen
#    - Verteile Futter basierend auf Pferdebedarf
#
# **4. Übersicht zeigen:**
#    - Schreibe eine Funktion für boxenbasierte Pferde-Übersicht
#    - Die Funktion soll alle boxen entgegennehmen
#    - Gib eine formatierte Übersicht zurück
#
# **5. Platz finden:**
#    - Erstelle eine Funktion zur Suche nach freien Plätzen
#    - Die Funktion soll boxen and anzahl_plaetze nutzen
#    - Gib Liste mit freien Boxen zurück
#
# **6. System steuern:**
#    - Schreibe eine Funktion, die den kompletten Stall verwaltet
#    - Die Funktion soll alle stall_daten nutzen
#    - Implementiere Steuerungsfunktionen
#
# **Beispiel-Struktur:**
# ```python
# # So könntest du beginnen:
# def erstelle_boxen(anzahl_boxen, pferde_pro_box):
#     # Erstellt verschachtelte Boxen-Liste
#     pass
#
# def platziere_pferde(boxen, pferdeliste):
#     # Platziert Pferde in Boxen
#     pass
#
# # ... weitere Funktionen hier
#
# # Hauptprogramm
# stall = {
#     "boxen": [],
#     "futter": 10000,
#     "pferde": []
# }
# # Verwalte Stall...
# ```
#
# **Bonus-Challenge:** Füge zufällige Pflegeaufgaben und Ereignisse hinzu.

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Die Turnier-Datenbank
#
# **Belohnung:** 400 Huf-Punkte + Turnier-Protokoll
#
# Erstelle ein komplettes Turnier-Verwaltungssystem!
#
# **Was du tun sollst:**
#
# **1. Turnier erstellen:**
#    - Erstelle eine Funktion für name-, disziplin- und schwierigkeitsbasierte Turniere
#    - Die Funktion soll name, disziplin and schwierigkeit als Parameter nehmen
#    - Gib ein Turnier-Dictionary zurück
#
# **2. Turnier hinzufügen:**
#    - Schreibe eine Funktion für datenbankbasierte Speicherung
#    - Die Funktion soll turnier and turnierliste nehmen
#    - Füge Turnier zur Liste hinzu und gib Bestätigung
#
# **3. Turnier suchen:**
#    - Erstelle eine Funktion für suchbegriffbasierte Suche
#    - Die Funktion soll turnierliste and suchbegriff nutzen
#    - Gib gefundene Turniere zurück
#
# **4. Status filtern:**
#    - Schreibe eine Funktion für statusbasierte Filterung
#    - Die Funktion soll turnierliste and status nutzen
#    - Gib gefilterte Turniere zurück
#
# **5. Statistik erstellen:**
#    - Erstelle eine Funktion für datenbankbasierte Auswertung
#    - Die Funktion soll turnierliste entgegennehmen
#    - Berechne und gib Statistiken zurück
#
# **6. System steuern:**
#    - Schreibe eine Funktion, die das Turnier-System verwaltet
#    - Die Funktion soll alle turnier_daten nutzen
#    - Implementiere vollständige Verwaltung
#
# **Beispiel-Struktur:**
# ```python
# # So könntest du beginnen:
# def erstelle_turnier(name, disziplin, schwierigkeit):
#     # Erstellt Turnier-Dictionary
#     pass
#
# def fuege_turnier_hinzu(turnier, turnierliste):
#     # Fügt Turnier zur Datenbank hinzu
#     pass
#
# # ... weitere Funktionen hier
#
# # Hauptprogramm
# turniere = []
# # Verwalte Turniere...
# ```
#
# **Bonus-Challenge:** Füge Turnier-Ergebnisse und Preise hinzu.

# %%
# 🐉 Deine Lösung hier:

print()
print("🎉 +400 Huf-Punkte: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Stallmeister der unendlichen Listen besiegt!")
print("⭐ Titel erhalten: Meister der Trainings-Sammlungen")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 6 gemeistert!")
print("📚 Nächste Woche: Module und Bibliotheken (math, random)!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen:

# %%
# ✅ Lösung Bug #1: Fehlende schließende Klammer

# Problem: Liste nicht geschlossen
pferde = ["Thunder", "Luna", "Storm"]
print(f"Pferde: {pferde}")

# %%
# ✅ Lösung Bug #2: Index außerhalb des Bereichs

# Problem: Index 3 existiert nicht (nur 0,1,2)
ausruestung = ["Sattel", "Zaumzeug", "Gerte"]
print(ausruestung[2])  # Letztes Element

# %%
# ✅ Lösung Bug #3: Falscher Parameter für sort()

# Problem: reverse ist ein Boolean, keine separate Variable
level = [1, 5, 10, 15]
level.sort(reverse=True)
print(level)
