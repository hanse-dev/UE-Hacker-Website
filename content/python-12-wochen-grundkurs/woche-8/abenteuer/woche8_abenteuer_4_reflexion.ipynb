# %% [markdown]
# # 🤔 Reflexion & Zusammenfassung – ⚔️ Woche 8 – Dictionaries und Tupel: Steckbriefe und Artefakte
# ### 🤔 Weisheiten des Archivars (Reflexion)
#
# Bevor du weitergehst, denke über diese Fragen nach:

# %% [markdown]
# ✏️ *Deine Antwort:*

# %% [markdown]
# 1. **Warum sollte man einen Steckbrief (Dictionary) statt einer Liste verwenden?**

# %% [markdown]
# ✏️ *Deine Antwort:*

# %% [markdown]
# 2. **Wann sind Artefakte (Tupel) besser als Listen?**

# %% [markdown]
# ✏️ *Deine Antwort:*

# %% [markdown]
# 3. **Wie helfen verschachtelte Steckbriefe bei der Datenorganisation?**
#
# Diskutiere deine Gedanken mit anderen Abenteurern!

# %% [markdown]
# ✏️ *Deine Antwort:*

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Legendär!** Du hast Steckbriefe und Artefakte gemeistert!
#
# **Das hast du gelernt:**
# - Steckbriefe (Dictionaries) für strukturierte Daten mit Namen
# - Artefakte (Tupel) für unveränderliche Daten
# - Verschachtelte Datenstrukturen
# - Zugriffsmethoden und Operationen
# - Komplexe Datenorganisation
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🎮 **Spiele:** Charaktere, Inventar, Spiel-Status
# - 📱 **Apps:** Benutzerprofile, Einstellungen, Konfigurationen
# - 🌐 **Websites:** JSON-Daten, Metadaten, Inhalte
# - 🤖 **KI-Systeme**: Modelleinstellungen, Parameter, Ergebnisse
# - 📊 **Wissenschaft:** Experiment-Daten, Messwerte, Ergebnisse
