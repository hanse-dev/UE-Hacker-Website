# %% [markdown]
# # 🐉 Boss Quests – 🐴 Week 3 – Conditions (if-else): The Crossroads of the Riding Path
# > ⚠️ Harder! Combines everything from this week.
#
# **⚠️ WARNING:** These missions are significantly harder! They combine everything you've learned.
#
# **Rewards:** A total of 1500 Hoof Points + legendary items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 1: The Rider Quiz
#
# **Reward:** 500 Hoof Points + Rider Certificate
#
# Test your knowledge of horsemanship!
#
# **Step 1 – Create quiz answers:**
# Create 5 Boolean variables for answers (True = correct, False = wrong) and give each question a unique number
#
# **Step 2 – Check answers one by one:**
# Use if-else for each answer and print "✅ Correct!" or "❌ Wrong!"
#
# **Step 3 – Count points:**
# Create a variable `points = 0` and add 100 points per correct answer with `points += 100`
#
# **Step 4 – Create final rating:**
# Check with if: points >= 400 → Grade "A" and check with elif: points >= 300 → Grade "B"
#
# **Step 5 – Issue certificate:**
# Check with if whether points >= 300 (passed) and print a Rider Certificate
#
# **Bonus:** Add different difficulty levels!

# %%
# 🐴 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss Quest 2: The Obstacle Simulator
#
# **Reward:** 600 Hoof Points + Riding Master License
#
# The simulator has 5 levels with increasing requirements!
#
# **Step 1 – Level 1: Mounting:**
# Create variables for horse_height (in meters) and rider_weight (in kg) and check with if: horse_height >= 1.60 AND rider_weight <= 80
#
# **Step 2 – Level 2: Gait choice:**
# Create a variable gait with value "Walk" or "Trot" and use if-else for the gait choice
#
# **Step 3 – Level 3: Speed:**
# Create a variable speed (0-100) and use if-elif-else for 5 levels:
#
# **Step 4 – Level 4: Obstacle check:**
# Create variables for height, width, difficulty (each 0-100) and use nested if conditions
#
# **Step 5 – Level 5: Dismount:**
# Create variables for time, errors, style (0-100) and build complex logic: time <= 60 OR (errors == 0 AND style >= 80)
#
# **Step 6 – Points system:**
# Count successful levels with variable successes = 0 and add 1 per completed level
#
# **Bonus:** Add time limits for each level!

# %%
# 🐴 Your solution here:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 3: The Tournament
#
# **Reward:** 400 Hoof Points + Tournament Badge
#
# Run the most important tournament!
#
# **Step 1 – Create tournament phases:**
# Create 5 Boolean variables for phases (phase1_ok, phase2_ok, etc.) and simulate different successes and failures
#
# **Step 2 – Write difficulty level:**
# Create a variable difficulty (1-5) and use if-elif-else for 5 levels:
#
# **Step 3 – Simulate random events:**
# Create Boolean variables for: obstacle_knocked, horse_spooked, saddle_slipped and check each event with if
#
# **Step 4 – Check success conditions:**
# Count successful phases and check: successful_phases >= 4 AND difficulty <= 3
#
# **Step 5 – Special actions:**
# Check with nested if: difficulty >= 4 AND successful_phases < 3 and print "Extra training required!"
#
# **Step 6 – Tournament evaluation:**
# Calculate total points: successful_phases × 100 - difficulty × 20 and calculate placement: (successful_phases / 5) × 100
#
# **Bonus:** Add a team score for team tournaments!

# %%
# 🐴 Your solution here:

print()
print("🎉 +400 Hoof Points: Final Challenge completed!")
print("🏆 You have mastered the horse of the undecided paths!")
print("⭐ Title earned: Master of the Crossroads")
print()
print("🎊 CONGRATULATIONS! You have mastered Week 3!")
print("🐴 Next week: Loops (for, while)!")

# %% [markdown]
# ---
#
# 🎊 **Congratulations!** You have completed all Boss Quests this week!
#
# **Up next:** Week 4 is already waiting!
