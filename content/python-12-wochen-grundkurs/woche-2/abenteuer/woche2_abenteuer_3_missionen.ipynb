# %% [markdown]
# # ⭐ Missionen – 💎 Woche 2 – Datentypen und Variablen: Die vier magischen Elemente
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Schatz des Magiers
#
# **Belohnung:** 300 XP + Kristallkugel
#
# Ein alter Magier hat seinen Schatz versteckt. Finde ihn, indem du die Hinweise entschlüsselst!
#
# **Schritt 1 – Heldenname festlegen:**
# Erstelle eine Variable für deinen Heldennamen und erstelle eine Variable für deine Helden-ID (Ganzzahl)
#
# **Schritt 2 – Schatztruhen erfassen:**
# Speichere die Anzahl der Truhen als Ganzzahl und speichere das Gold pro Truhe als Kommazahl (z.B. 125.5)
#
# **Schritt 3 – Gesamtgold berechnen:**
# Multipliziere die Truhen mit dem Gold pro Truhe und speichere das Ergebnis in einer Variable
#
# **Bonus:** Füge eine Variable für magischen Staub pro Truhe hinzu und berechne die Gesamtmenge!

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Das Zauberbuch
#
# **Belohnung:** 400 XP + Magisches Tintenfass
#
# Du musst ein Zauberbuch mit Informationen über verschiedene Sprüche erstellen!
#
# **Schritt 1 – Zauber benennen:**
# Erstelle drei Variablen für Zaubernamen als Text und erstelle drei Variablen für Schadenswerte als Ganzzahlen
#
# **Schritt 2 – Zauberprotokoll ausgeben:**
# Gib eine Überschrift "=== ZAUBERBUCH ===" aus und gib jeden Zauber mit Name, Schaden und Mana-Kosten aus
#
# **Schritt 3 – Gesamtschaden berechnen:**
# Addiere alle Schadenswerte und speichere die Summe in einer Variable
#
# **Schritt 4 – Durchschnittsschaden ermitteln:**
# Addiere alle Schadenswerte und teile durch 3 und speichere den Durchschnitt in einer Variable
#
# **Bonus:** Berechne die durchschnittlichen Mana-Kosten!

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Die Arena des Champions
#
# **Belohnung:** 500 XP + Championmedaille
#
# In der Arena kämpfen die besten Helden. Berechne ihre Statistiken!
#
# **Schritt 1 – Helden erstellen:**
# Erstelle für Held 1: Name, Level, Stärke, Intelligenz und erstelle für Held 2: Name, Level, Stärke, Intelligenz
#
# **Schritt 2 – Gesamtstatistik berechnen:**
# Berechne für Held 1: Stärke + Intelligenz und berechne für Held 2: Stärke + Intelligenz
#
# **Schritt 3 – Stärkeren Helden bestimmen:**
# Gib beide Helden mit ihren Gesamtstatistiken aus und vergleiche die Werte und bestimme den Stärkeren
#
# **Schritt 4 – Kampfansage ausgeben:**
# Gib eine Nachricht aus, wer stärker ist und berechne die durchschnittliche Stärke beider Helden
#
#
# > 💡 **Tipp:** Du entscheidest selbst, wie du das umsetzt – es gibt keinen einzig richtigen Weg!
# **Bonus:** Berechne, wie viel stärker der Sieger ist!

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Hake ab, was du schon kannst:
#
# - ☐ f-Strings für die Textformatierung verwenden
# - ☐ Die vier Grunddatentypen kennen und anwenden
# - ☐ `type()` und `len()` benutzen
# - ☐ Typumwandlungen durchführen (`int()`, `float()`, `str()`)
# - ☐ Eingaben mit `input()` einlesen
