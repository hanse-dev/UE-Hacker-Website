# %% [markdown]
# # 🔧 Lösungen – 🐴 Woche 9 – JSON-Dateien und I/O: Die Stall-Archive des Reiterhofs
# > Erst selber versucht? Dann check hier nach!

# %% [markdown]
# **Erklärung:** Dieser Code enthält einen Fehler – findest du ihn?

# %%
# Problem: Kann nicht im 'w' Modus lesen
with open('test.txt', 'w') as f:
    f.write('Hallo')

with open('test.txt', 'r') as f:
    inhalt = f.read()
    print(f'Inhalt: {inhalt}')

# %% [markdown]
# **Erklärung:** `str` hat keine Methode oder Eigenschaft namens `read`. Schau genau auf die Schreibweise – Python unterscheidet Groß- und Kleinbuchstaben.

# %%
# Problem: load() erwartet Datei, nicht String
import json
daten = {'name': 'Test'}
json_string = json.dumps(daten)
ergebnis = json.loads(json_string)  # loads() für String
print(f'Ergebnis: {ergebnis}')

# %% [markdown]
# **Erklärung:** Die angegebene Datei existiert nicht. Prüfe den Dateinamen und ob die Datei im richtigen Ordner liegt.

# %%
# Problem: Zugriff auf nicht existierende Spalten
import csv
with open('test.csv', 'r') as f:
    reader = csv.reader(f)
    for zeile in reader:
        if len(zeile) >= 3:  # Prüfen ob genug Spalten
            print(zeile[0], zeile[1], zeile[2])
        else:
            print(f'Zeile hat nur {len(zeile)} Spalten: {zeile}')

# %% [markdown]
# ## ⭐ Missions-Lösungsvorschläge
#
# > Lösungsvorschläge werden noch ergänzt.

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Pferde-Logger

# %%
# ✏️ Lösungsvorschlag Mission 1 – Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der JSON-Konverter

# %%
# ✏️ Lösungsvorschlag Mission 2 – Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Die CSV-Datenbank

# %%
# ✏️ Lösungsvorschlag Mission 3 – Deine Lösung hier:
