# %% [markdown]
# # 🚀 Woche 3 – Bedingungen (if-else): Die Pfade der Entscheidung
#
# **Cyber Credits zu verdienen:** 1000 Punkte
# **Herausforderung:** Der KI-Hüter der paradoxen Entscheidungen

# %% [markdown]
# ## 🌟 Die Geschichte beginnt: Am Knotenpunkt des Universums
#
# Willkommen, Kommandant! Du erreichst den **Knotenpunkt des Universums** – ein Ort, an dem jede Entscheidung über die Zukunft der Galaxie entscheidet. In dieser Woche lernst du die drei **Protokolle der Entscheidung**:
#
# **Deine Mission:**
# - Lerne, wie du mit **if-else** Entscheidungen triffst
# - Meistere **Vergleichs-Operatoren** für präzise Urteile
# - Beherrsche **logische Verknüpfungen** für komplexe Bedingungen
# - Verstehe die **Macht der Einrückung** für verschachtelte Pfade
#
# **Wähle weise!** Das Schicksal der Galaxie liegt in deinen Händen...

# %% [markdown]
# ## 📚 Systemprotokoll 1: Der einfache Pfad (if)
#
# **Was es ist:** `if` prüft eine Bedingung und führt Code nur aus, wenn die Bedingung wahr ist.
#
# **Warum nützlich:**
# - 🎯 Treffe Entscheidungen basierend auf Bedingungen
# - 🔍 Prüfe, ob etwas wahr oder falsch ist
# - ⚔️ Aktiviere Systeme nur bei Bedarf
# - 🎲 Reagiere auf Sensordaten
#
# **Wichtig:** Der Code nach `if` muss eingerückt werden!

# %%
# Beispiel 1: Einfache if-Bedingung
sicherheitsstufe = 5
if sicherheitsstufe >= 5:
    print("🎉 Zugriff auf Hauptsystem gewährt!")

# Beispiel 2: Prüfen auf True/False
system_online = True
if system_online:
    print("🔑 Alle Systeme operational.")

# Beispiel 3: Befehl prüfen
befehl = "START"
if befehl == "START":
    print("🚀 Startsequenz eingeleitet!")

# %% [markdown]
# ## 🔍 Die Algorithmen des Vergleichs: Wichtige Operatoren
#
# ### Zuweisung vs Vergleich: = vs ==
#
# **Das ist ein entscheidender Unterschied!**
#
# - **`=` (ein Gleichheitszeichen)**: Weist einer Variable einen Wert zu
#   ```python
#   level = 10  # Weise level den Wert 10 zu
#   ```
#
# - **`==` (zwei Gleichheitszeichen)**: Vergleicht zwei Werte auf Gleichheit
#   ```python
#   if level == 10:  # Prüfe OB level 10 ist
#       print("Zugriffslevel 10 erreicht!")
#   ```
#
# ### Die vier Vergleichsalgorithmen
#
# - **`<` (kleiner als)**: Prüft, ob der linke Wert kleiner ist
#   ```python
#   if energie < 20:
#       print("⚠️ Niedrige Energie!")
#   ```
#
# - **`<=` (kleiner oder gleich)**: Prüft, ob der linke Wert kleiner oder gleich ist
#   ```python
#   if temperatur <= 100:
#       print("🌡️ Normale Temperatur!")
#   ```
#
# - **`>` (größer als)**: Prüft, ob der linke Wert größer ist
#   ```python
#   if geschwindigkeit > 1000:
#       print("💨 Überlichtgeschwindigkeit!")
#   ```
#
# - **`>=` (größer oder gleich)**: Prüft, ob der linke Wert größer oder gleich ist
#   ```python
#   if schildstaerke >= 50:
#       print("🛡️ Schilde stabil!")
#   ```
#
# **Merke:** In Bedingungen immer `==` für Vergleiche verwenden, nie `=`!

# %%
# 🔍 Übungen zu Vergleichsoperatoren

# Beispiel 1: = vs == im Vergleich
rang = 15  # Zuweisung mit =
if rang == 15:  # Vergleich mit ==
    print("✅ Richtig: Rang 15 erreicht")

# Beispiel 2: Alle vier Vergleichsoperatoren
wert = 42
print(f"Wert: {wert}")
print(f"{wert} < 50: {wert < 50}")
print(f"{wert} <= 42: {wert <= 42}")
print(f"{wert} > 30: {wert > 30}")
print(f"{wert} >= 42: {wert >= 42}")

# Beispiel 3: Praktische Anwendung
energie = 85
verbrauch = 60
if energie > verbrauch:
    print(f"⚡ Sprung möglich! Übrig: {energie - verbrauch}%")
elif energie == verbrauch:
    print("⚖️ Genau für einen Sprung!")
else:
    print(f"❌ Sprung unmöglich! Fehlen: {verbrauch - energie}%")

# %% [markdown]
# ## 📦 Systemprotokoll 2: Der zweigeteilte Pfad (if-else)
#
# **Was es ist:** `if-else` bietet zwei Pfade - einen für wahre und einen für falsche Bedingungen.
#
# **Warum nützlich:**
# - ✅ Handle unterschiedlich bei Erfolg/Misserfolg
# - 🔄 Gib alternative Antworten
# - 🎮 Erstelle Win/Lose-Szenarien
# - ⚖️ Balance gute und schlechte Ergebnisse
#
# **Wichtig:** `else` braucht keine Bedingung und wird bei allem anderen ausgeführt!

# %%
# Beispiel 1: Scan-Ergebnis
signale = 18
if signale >= 15:
    print("⚔️ Lebensformen entdeckt!")
else:
    print("💨 Sektor leer.")

# Beispiel 2: System-Check
druck_ok = False
if druck_ok:
    print("🍺 Druckkammern betriebsbereit.")
else:
    print("🚫 Druckabfall erkannt!")

# Beispiel 3: Energie-Check
energie = 45
verbrauch = 50
if energie >= verbrauch:
    print(f"💰 Sprung möglich! Rest: {energie - verbrauch}%")
else:
    print(f"❌ Sprung unmöglich! Fehlt: {verbrauch - energie}%")

# %% [markdown]
# ## ✨ Systemprotokoll 3: Der multiple Pfad (if-elif-else)
#
# **Was es ist:** `if-elif-else` prüft mehrere Bedingungen nacheinander.
#
# **Warum nützlich:**
# - 🎭 Handle unterschiedlich bei verschiedenen Situationen
# - 🌟 Erstelle Stufen- und Level-Systeme
# - 🎨 Gib personalisierte Antworten
# - 🏆 Bewerte Leistungen mit Noten
#
# **Wichtig:** `elif` braucht immer eine Bedingung! Nur der erste wahre Pfad wird ausgeführt.

# %%
# Beispiel 1: Rang-Bewertung
punkte = 750
if punkte >= 1000:
    print("🏆 Fleet-Kommandant!")
elif punkte >= 500:
    print("⭐ Kapitän!")
elif punkte >= 100:
    print("🌟 Leutnant!")
else:
    print("📚 Kadett!")

# Beispiel 2: Waffensystem
waffe = "Laser"
if waffe == "Laser":
    print("🔥 Laser aktiviert!")
elif waffe == "Plasma":
    print("💧 Plasmathron geladen!")
elif waffe == "Quantum":
    print("🌪️ Quantum-Torpedo bereit!")
elif waffe == "Ion":
    print("⚡ Ionengeschütz online!")
else:
    print("❓ Unbekannte Waffe!")

# Beispiel 3: Schiffs-Klasse
schild = 8
waffen = 12
if schild > 10 and waffen > 10:
    print("⚔️🧠 Schlachtschiff!")
elif schild > 10:
    print("💪 Kreuzer!")
elif waffen > 10:
    print("🧙 Zerstörer!")
else:
    print("👤 Fregatte!")

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein junger Techniker hat versucht, Entscheidungsprotokolle zu programmieren, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1

level = 10
if level >= 10:
print("Zugriff gewährt!")
print("Willkommen Kommandant!")

# %%
# 🐛 Bug #2

user = "Admin"
if user = "Admin":
    print("Hallo Admin!")

# %%
# 🐛 Bug #3

status = 25
if status >= 18:
    print("System aktiv")
elif:
    print("System inaktiv")

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Sicherheits-Scanner
#
# **Belohnung:** 300 Cyber Credits + Scanner-Lizenz
#
# Der Sicherheits-Scanner prüft, wer die Brücke betreten darf!
#
# **Deine Aufgaben:**
#
# 1. **Zugangsdaten erfassen**
#    - Erstelle eine Variable für den Rang (Ganzzahl 1-10)
#    - Erstelle eine Variable für Ausweisbesitz (Boolean True/False)
#    - Erstelle eine Variable für Notfallzugriff (Boolean True/False)
#
# 2. **Zugangsregel implementieren**
#    - Prüfe mit if, ob Rang >= 5 ODER Ausweis vorhanden ODER Notfall
#    - Nutze den `or`-Operator für die Verknüpfung
#    - Gib "Zugang gewährt" bei Erfolg aus
#
# 3. **Ablehnungsmeldung hinzufügen**
#    - Nutze else für den Fall, dass keine Bedingung zutrifft
#    - Gib "Zugang verweigert" aus
#    - Füge eine Begründung hinzu
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Zugangsdaten erfassen
# rang = 4
# hat_ausweis = True
# notfall = False
#
# # 2. Zugangsregel
# if rang >= 5 or hat_ausweis or notfall:
#     print("✅ Zugang gewährt!")
# else:
#     print("❌ Zugang verweigert!")
# ```
#
# **Bonus-Challenge:**
# - Fordere nur bei Rang unter 8 einen Ausweis!
#
# **Erwartete Ausgabe:**
# ```
# ✅ Zugang gewährt!
# Grund: Ausweis vorhanden
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Terminal-Zugang
#
# **Belohnung:** 400 Cyber Credits + Terminal-Zugang
#
# Das Terminal gibt nur Zugriff, wenn das richtige Passwort eingegeben wird!
#
# **Deine Aufgaben:**
#
# 1. **Passwörter festlegen**
#    - Erstelle eine Variable für das Admin-Passwort
#    - Erstelle eine Variable für das Gast-Passwort
#    - Erstelle eine Variable für das Notfall-Passwort
#
# 2. **Eingabe simulieren**
#    - Erstelle eine Variable für die eingegebene Passwort-Eingabe
#    - Speichere ein Testpasswort als String
#
# 3. **Zugriffsprüfung implementieren**
#    - Prüfe mit if, ob Eingabe == Admin-Passwort
#    - Prüfe mit elif, ob Eingabe == Gast-Passwort
#    - Prüfe mit elif, ob Eingabe == Notfall-Passwort
#    - Nutze else für falsche Passwörter
#
# 4. **Unterschiedliche Meldungen ausgeben**
#    - Gib bei Admin: "Vollzugriff gewährt"
#    - Gib bei Gast: "Lesezugriff gewährt"
#    - Gib bei Notfall: "Notfallzugriff aktiviert"
#    - Gib bei Fehler: "Zugriff verweigert"
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Passwörter festlegen
# admin_pw = "ALPHA-7"
# gast_pw = "BETA-3"
# notfall_pw = "OMEGA-9"
#
# # 2. Eingabe simulieren
# eingabe = "ALPHA-7"
#
# # 3. Zugriffsprüfung
# if eingabe == admin_pw:
#     print("🔓 Vollzugriff gewährt!")
# elif eingabe == gast_pw:
#     print("👁️ Lesezugriff gewährt!")
# ```
#
# **Bonus-Challenge:**
# - Gib verschiedene Hinweise bei falschen Passwörtern!
#
# **Erwartete Ausgabe:**
# ```
# 🔓 Vollzugriff gewährt!
# Willkommen, Administrator!
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Die Missionsbewertung
#
# **Belohnung:** 500 Cyber Credits + Missionsabzeichen
#
# Die Mission wird nach ihrer Leistung bewertet!
#
# **Deine Aufgaben:**
#
# 1. **Missionsdaten erfassen**
#    - Erstelle eine Variable für das Level (1-10)
#    - Erstelle eine Variable für Erfolgspunkte (0-100)
#    - Erstelle eine Variable für die Zeit in Minuten
#    - Erstelle eine Variable für Verluste (Anzahl)
#
# 2. **Gesamtnote berechnen**
#    - Berechne: note = Erfolgspunkte - (Verluste × 10) - (Zeit / 5)
#    - Speichere das Ergebnis in einer Variable
#    - Gib die Note aus
#
# 3. **Legendär-Status prüfen**
#    - Prüfe: Level >= 10 UND note >= 85 UND Verluste == 0
#    - Nutze `and` für die Verknüpfung
#    - Gib "🏆 LEGENDÄR!" bei Erfolg aus
#
# 4. **Weitere Bewertungsstufen**
#    - Prüfe mit elif: Level >= 8 UND note >= 70 UND Verluste <= 2
#    - Gib "⭐ EXZELLENT!" aus
#    - Prüfe mit elif: Level >= 5 UND note >= 50 UND Verluste <= 5
#    - Gib "✅ GUT!" aus
#    - Nutze else für "📚 BESTANDEN"
#
# 5. **Blitz-Bonus prüfen**
#    - Prüfe separat mit if, ob Zeit < 30
#    - Gib "+50 Bonus für Blitzmission!" aus
#    - Addiere den Bonus zur Note
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Missionsdaten erfassen
# level = 10
# erfolgspunkte = 95
# zeit = 25
# verluste = 0
#
# # 2. Gesamtnote berechnen
# note = erfolgspunkte - (verluste * 10) - (zeit / 5)
# print(f"Note: {note}")
#
# # 3. Legendär-Status prüfen
# if level >= 10 and note >= 85 and verluste == 0:
#     print("🏆 LEGENDÄR!")
# ```
#
# **Bonus-Challenge:**
# - Berücksichtige auch die Schwierigkeit der Mission!
#
# **Erwartete Ausgabe:**
# ```
# Note: 90.0
# 🏆 LEGENDÄR!
# +50 Bonus für Blitzmission!
# Finale Note: 140.0
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten der Missionsleiterin (Reflexion)
#
# Bevor du weiterfliegst, denke über diese Fragen nach:
#
# 1. **Warum ist die richtige Einrückung bei Bedingungen so wichtig?**
#
# 2. **Was ist der Unterschied zwischen `==` und `=`?**
#
# 3. **Wann würdest du `elif` anstelle von mehreren `if`-Statements verwenden?**
#
# Diskutiere deine Gedanken mit anderen Kommandant:innen!

# %% [markdown]
# ### 📖 Tech-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **if** 🎯: Prüft eine Bedingung und führt Code aus bei Wahr
# - **else** 🔄: Alternativcode bei falscher Bedingung
# - **elif** 🎭: Prüft zusätzliche Bedingungen
# - **==** ⚖️: Vergleichsoperator für Gleichheit
# - **!=** ❌: Vergleichsoperator für Ungleichheit
# - **>** 📈: Größer als
# - **<** 📉: Kleiner als
# - **>=** 📊: Größer oder gleich
# - **<=** 📉: Kleiner oder gleich
# - **and** 🔗: Logisches UND
# - **or** ⚡: Logisches ODER
# - **not** 🚫: Logische Verneinung

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ✅ if-Bedingungen für einfache Entscheidungen
# - ✅ if-else für zwei Wege der Entscheidung
# - ✅ if-elif-else für multiple Pfade
# - ✅ Vergleichsoperatoren richtig anwenden
# - ✅ Logische Operatoren (and, or, not) nutzen
# - ✅ Verschachtelte Bedingungen mit Einrückung
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die finalen Herausforderungen!

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Exzellent!** Du hast die Pfade der Entscheidung gemeistert!
#
# **Das hast du gelernt:**
# - Entscheidungen mit if-else treffen
# - Vergleichsoperatoren für präzise Prüfungen
# - Logische Verknüpfungen für komplexe Regeln
# - Die Macht der Einrückung verstehen
# - Verschachtelte Bedingungen meistern
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🎮 **Spiele:** Game-Logik, KI-Entscheidungen, Spielregeln
# - 📱 **Apps:** Benutzer-Authentifizierung, Validierung, Berechtigungen
# - 🌐 **Websites:** Formular-Prüfungen, Navigation, Benutzer-Interaktionen
# - 🤖 **KI-Systeme:** Entscheidungsbäume, Mustererkennung
# - 📊 **Wissenschaft:** Datenfilterung, experimentelle Bedingungen
#
# **Als Nächstes:** In Woche 4 lernst du **Schleifen (for, while)**!

# %% [markdown]
# ## 🚀 Finale Herausforderung: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Missionen sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 Cyber Credits + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Das KI-Quiz
#
# **Belohnung:** 500 Cyber Credits + KI-Zertifikat
#
# Teste dein Wissen über künstliche Intelligenz!
#
# **Deine Aufgaben:**
#
# 1. **Quiz-Antworten erstellen**
#    - Erstelle 5 Boolean-Variablen für Antworten (True = richtig, False = falsch)
#    - Gib jeder Frage eine eindeutige Nummer
#    - Simuliere verschiedene Antworten
#
# 2. **Antworten einzeln prüfen**
#    - Nutze if-else für jede Antwort
#    - Gib "✅ Richtig!" oder "❌ Falsch!" aus
#    - Zeige die richtige Antwort bei Fehlern
#
# 3. **Punkte zählen**
#    - Erstelle eine Variable `punkte = 0`
#    - Addiere 100 Punkte pro richtige Antwort mit `punkte += 100`
#    - Gib die Gesamtpunktzahl aus
#
# 4. **Abschlussbewertung erstellen**
#    - Prüfe mit if: punkte >= 400 → Note "A"
#    - Prüfe mit elif: punkte >= 300 → Note "B"
#    - Prüfe mit elif: punkte >= 200 → Note "C"
#    - Prüfe mit elif: punkte >= 100 → Note "D"
#    - Nutze else für Note "F"
#
# 5. **Zertifikat ausgeben**
#    - Prüfe mit if, ob punkte >= 300 (bestanden)
#    - Gib ein digitales Zertifikat aus
#    - Nutze verschachtelte if für Zertifikatsstufe (Gold/Silber/Bronze)
#
# **Beispiel-Code zum Starten:**
# ```python
# # 1. Quiz-Antworten erstellen
# print("=== KI-QUIZ ===")
# print()
#
# frage1_richtig = True   # Frage 1: Ist Python eine Programmiersprache?
# frage2_richtig = False  # Frage 2: Ist 2+2=5?
# frage3_richtig = True   # Frage 3: Nutzt KI Algorithmen?
# frage4_richtig = True   # Frage 4: Kann Python Daten verarbeiten?
# frage5_richtig = False  # Frage 5: Ist HTML eine Programmiersprache?
#
# # 2. Antworten prüfen
# punkte = 0
#
# if frage1_richtig:
#     print("Frage 1: ✅ Richtig!")
#     punkte += 100
# else:
#     print("Frage 1: ❌ Falsch! Richtig ist: True")
#
# # ... weitere Fragen prüfen
# ```
#
# **Bonus-Challenge:**
# - Füge verschiedene Schwierigkeitsgrade hinzu!
#
# **Erwartete Ausgabe:**
# ```
# === KI-QUIZ ===
#
# Frage 1: ✅ Richtig!
# Frage 2: ❌ Falsch! Richtig ist: False
# ...
#
# Gesamtpunktzahl: 300
# Note: B
# 🎓 Zertifikat: Silber
# ```

# %%
# 🚀 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Der Raumschiff-Simulator
#
# **Belohnung:** 600 Cyber Credits + Piloten-Lizenz
#
# Der Simulator hat 5 Level mit steigenden Anforderungen!
#
# **Deine Aufgaben:**
#
# 1. **Level 1: Startsequenz**
#    - Erstelle Variablen für energie (0-100) und system_ok (Boolean)
#    - Prüfe mit if: energie >= 50 UND system_ok
#    - Gib "✅ Startsequenz aktiviert!" aus
#    - Nutze else für Fehlermeldung
#
# 2. **Level 2: Kurswahl**
#    - Erstelle eine Variable kurs mit Wert "Nord" oder "Süd"
#    - Nutze if-else für die Kurswahl
#    - Gib "Kurs Nord gewählt" oder "Kurs Süd gewählt" aus
#    - Bestätige die Richtung
#
# 3. **Level 3: Geschwindigkeit**
#    - Erstelle eine Variable geschwindigkeit (0-1000)
#    - Nutze if-elif-else für 5 Stufen:
#      - < 100: "Langsam"
#      - < 300: "Normal"
#      - < 500: "Schnell"
#      - < 800: "Sehr schnell"
#      - >= 800: "Überlicht"
#    - Gib Warnung bei >= 800 aus
#
# 4. **Level 4: Systemprüfung**
#    - Erstelle Variablen für schilde, waffen, antrieb (jeweils 0-100)
#    - Nutze verschachtelte if-Bedingungen
#    - Prüfe: schilde >= 50 UND waffen >= 50 UND antrieb >= 50
#    - Gib "Alle Systeme bereit" oder spezifische Fehler aus
#
# 5. **Level 5: Notlandung**
#    - Erstelle Variablen für treibstoff, atmosphaere (Boolean), landeplatz (Boolean)
#    - Baue komplexe Logik: treibstoff >= 20 ODER (atmosphaere UND landeplatz)
#    - Gib verschiedene Ergebnisse aus
#    - Prüfe alle Kombinationen
#
# 6. **Punktesystem**
#    - Zähle erfolgreiche Level mit Variable erfolge = 0
#    - Addiere 1 pro bestandenem Level
#    - Gib Pilotenrang aus (5=Ass, 4=Experte, 3=Fortgeschritten, 2=Anfänger, 1=Kadett)
#
# **Beispiel-Code zum Starten:**
# ```python
# # So könntest du beginnen:
# print("=== RAUMSCHIFF-SIMULATOR ===")
# print()
#
# erfolge = 0
#
# # Level 1: Startsequenz
# energie = 85
# system_ok = True
# if energie >= 50 and system_ok:
#     print("Level 1: ✅ Startsequenz aktiviert!")
#     erfolge += 1
# else:
#     print("Level 1: ❌ Start nicht möglich!")
#
# # Level 2: Kurswahl
# kurs = "Nord"
# if kurs == "Nord":
#     print("Level 2: ✅ Kurs Nord gewählt!")
#     erfolge += 1
# else:
#     print("Level 2: ✅ Kurs Süd gewählt!")
#     erfolge += 1
#
# # ... weitere Level
# ```
#
# **Bonus-Challenge:**
# - Füge Zeitlimits für jedes Level hinzu!
#
# **Erwartete Ausgabe:**
# ```
# === RAUMSCHIFF-SIMULATOR ===
#
# Level 1: ✅ Startsequenz aktiviert!
# Level 2: ✅ Kurs Nord gewählt!
# Level 3: ⚡ Überlicht! WARNUNG!
# Level 4: ✅ Alle Systeme bereit!
# Level 5: ✅ Notlandung erfolgreich!
#
# Erfolgreiche Level: 5/5
# Pilotenrang: Ass
# ```

# %%
# 🚀 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Die Galaxie-Mission
#
# **Belohnung:** 400 Cyber Credits + Missionsabzeichen
#
# Führe die gefährlichste Mission durch!
#
# **Deine Aufgaben:**
#
# 1. **Missionsphasen erstellen**
#    - Erstelle 5 Boolean-Variablen für Phasen (phase1_ok, phase2_ok, etc.)
#    - Simuliere verschiedene Erfolge und Misserfolge
#    - Gib jeder Phase einen Namen
#
# 2. **Gefahrenstufe implementieren**
#    - Erstelle eine Variable gefahrenstufe (1-5)
#    - Nutze if-elif-else für 5 Stufen:
#      - 5: "KRITISCH"
#      - 4: "HOCH"
#      - 3: "MITTEL"
#      - 2: "NIEDRIG"
#      - 1: "SICHER"
#    - Gib entsprechende Warnungen aus
#
# 3. **Zufallsereignisse simulieren**
#    - Erstelle Boolean-Variablen für: meteor_treffer, piraten_angriff, system_ausfall
#    - Prüfe jedes Ereignis mit if
#    - Gib spezifische Meldungen aus
#    - Reduziere Erfolgschance bei Ereignissen
#
# 4. **Erfolgsbedingungen prüfen**
#    - Zähle erfolgreiche Phasen
#    - Prüfe: erfolgreiche_phasen >= 4 UND gefahrenstufe <= 3
#    - Nutze kombinierte Bedingungen mit and/or
#    - Gib "Mission erfolgreich" oder "Mission fehlgeschlagen" aus
#
# 5. **Sonderaktionen**
#    - Prüfe mit verschachtelten if: gefahrenstufe >= 4 UND erfolgreiche_phasen < 3
#    - Gib "Rettungsaktion erforderlich!" aus
#    - Biete Rettungsoptionen an
#    - Implementiere Notfallprotokoll
#
# 6. **Missionsauswertung**
#    - Berechne Gesamtpunkte: erfolgreiche_phasen × 100 - gefahrenstufe × 20
#    - Berechne Erfolgquote: (erfolgreiche_phasen / 5) × 100
#    - Gib Bewertung aus (>80%: Exzellent, >60%: Gut, >40%: Bestanden, sonst: Gescheitert)
#    - Erstelle Abschlussmeldung mit Empfehlung
#
# **Beispiel-Code zum Starten:**
# ```python
# # So könntest du beginnen:
# print("=== GALAXIE-MISSION ===")
# print()
#
# # 1. Missionsphasen
# phase1_ok = True
# phase2_ok = True
# phase3_ok = False
# phase4_ok = True
# phase5_ok = True
#
# # 2. Gefahrenstufe
# gefahrenstufe = 3
# if gefahrenstufe >= 4:
#     print("⚠️ KRITISCHE WARNUNG!")
# elif gefahrenstufe >= 3:
#     print("⚡ Vorsicht geboten!")
# else:
#     print("✅ Mission verläuft sicher.")
#
# # 3. Zufallsereignisse
# meteor_treffer = False
# piraten_angriff = True
# system_ausfall = False
#
# if meteor_treffer:
#     print("💥 Meteor-Treffer!")
# if piraten_angriff:
#     print("🏴‍☠️ Piraten-Angriff!")
#
# # ... weitere Logik
# ```
#
# **Bonus-Challenge:**
# - Füge ein Team-Score für Multiplayer-Missionen hinzu!
#
# **Erwartete Ausgabe:**
# ```
# === GALAXIE-MISSION ===
#
# ⚡ Vorsicht geboten!
# 🏴‍☠️ Piraten-Angriff!
#
# Phase 1: ✅ Erfolgreich
# Phase 2: ✅ Erfolgreich
# Phase 3: ❌ Fehlgeschlagen
# Phase 4: ✅ Erfolgreich
# Phase 5: ✅ Erfolgreich
#
# Erfolgreiche Phasen: 4/5
# Gesamtpunkte: 340
# Erfolgquote: 80%
# Bewertung: Exzellent
# Empfehlung: Beförderung vorgeschlagen!
# ```

# %%
# 🚀 Deine Lösung hier:

print()
print("🎉 +400 Cyber Credits: Finale Herausforderung abgeschlossen!")
print("🏆 Du hast den KI-Hüter der paradoxen Entscheidungen besiegt!")
print("⭐ Titel erhalten: Meister der Pfade")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 3 gemeistert!")
print("🚀 Nächste Woche: Schleifen (for, while)!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen:

# %%
# ✅ Lösung Bug #1: Falsche Einrückung

# Problem: Code nach if nicht eingerückt
level = 10
if level >= 10:
    print("Zugriff gewährt!")
    print("Willkommen Kommandant!")

# %%
# ✅ Lösung Bug #2: Falscher Vergleich

# Problem: = statt == für Vergleich verwendet
user = "Admin"
if user == "Admin":
    print("Hallo Admin!")

# %%
# ✅ Lösung Bug #3: Vergessene Bedingung

# Problem: elif braucht immer eine Bedingung
status = 25
if status >= 18:
    print("System aktiv")
else:
    print("System inaktiv")
