# %% [markdown]
# # 🐴 Woche 10 – OOP Grundlagen: Die magischen Blaupausen!
#
# **Huf-Punkte zu verdienen:** 1000 Punkte
# **Herausforderung:** Die Meisterreiterin

# %% [markdown]
# ## 🌟 Die Freundschaft beginnt: Willkommen im Reiterhof Sonnental
#
# Willkommen, junge Pferdefreund:in! Du betrittst den idyllischen **Reiterhof Sonnental** – ein Ort voller Natur, Freundschaft und Abenteuer mit Pferden. In dieser Woche lernst du die drei wichtigsten Lektion:
#
# **Deine Mission:**
# - Klassen als Stallpläne für Pferde erstellen
# - Objekte als individuelle Pferde erschaffen
# - Methoden als Fähigkeiten der Pferde verleihen
#
# **Leg los!** Dein Pferdefreund wartet schon auf dich...

# %% [markdown]
# ## 📚 Lektion 1: Klassen erstellen
#
# **Was es ist:** Eine Klasse ist wie ein Stallplan für Pferde. Sie beschreibt, welche Eigenschaften und Fähigkeiten jedes Pferd haben soll.
#
# **Warum nützlich:**
# - Du kannst viele ähnliche Pferde schnell anlegen
# - Dein Code wird ordentlich und strukturiert
# - Du kannst Pferde-Informationen direkt speichern
#
# **Wichtig:** Klassennamen beginnen immer mit einem Großbuchstaben!

# %%
# Beispiel 1: Erste Klasse erstellen
class Pferd:
    pass

# Beispiel 2: Klasse mit Attributen
class Reiter:
    name = "Unbekannt"
    erfahrung = 0

# Beispiel 3: Klasse mit Methode
class Pony:
    def wiehern(self):
        print("Wieher! 🐴")

# %% [markdown]
# ## 🐎 Lektion 2: Objekte instanziieren
#
# **Was es ist:** Ein Objekt ist ein konkretes Pferd, das aus dem Stallplan geboren wurde.
#
# **Warum nützlich:**
# - Jedes Pferd hat eigene Werte
# - Du kannst viele unabhängige Pferde erstellen
# - Pferde können miteinander interagieren
#
# **Wichtig:** Jedes Objekt ist einzigartig, auch wenn es von derselben Klasse stammt!

# %%
# Beispiel 1: Objekte erstellen
mein_pferd = Pferd()
dein_pferd = Pferd()

# Beispiel 2: Attribute setzen
anna = Reiter()
anna.name = "Anna"
anna.erfahrung = 5

# Beispiel 3: Mehrere Objekte
lucky = Pony()
spirit = Pony()
lucky.wiehern()

# %% [markdown]
# ## 🍃 Lektion 3: Der Konstruktor (__init__)
#
# **Was es ist:** Der Konstruktor ist eine spezielle Methode, die automatisch ausgeführt wird, wenn ein Pferd geboren wird.
#
# **Warum nützlich:**
# - Pferde werden direkt mit richtigen Werten erstellt
# - Du kannst Startwerte übergeben
# - Geburtsinformationen werden zentralisiert
#
# **Wichtig:** __init__ hat immer `self` als ersten Parameter! (Warum `self` nötig ist, erfährst du in der nächsten Sektion.)

# %%
# Beispiel 1: Einfacher Konstruktor
class Pferd:
    def __init__(self, name):
        self.name = name

# Beispiel 2: Konstruktor mit mehreren Werten
class Fohlen:
    def __init__(self, name, alter, geschlecht):
        self.name = name
        self.alter = alter
        self.geschlecht = geschlecht

# Beispiel 3: Konstruktor mit Standardwerten
class Pferd:
    def __init__(self, name="Stormy", rasse="Pony"):
        self.name = name
        self.rasse = rasse

# %% [markdown]
# ## 🪞 Warum `self`? – Der Schlüssel zu deinen Pferden
#
# **Was ist `self`?** `self` ist die Referenz auf **das konkrete Pferd**, das gerade angesprochen wird. Wenn du `lucky.wiehern()` aufrufst, ist `self` in der Methode genau das Objekt `lucky`.
#
# **Warum brauchen wir es überhaupt?** Eine Klasse kann viele Pferde erzeugen. Python muss wissen: *Welches* dieser Pferde ist gemeint? Bei 10 Pferden muss die Methode wissen: „Ich arbeite für DIESES Pferd hier.“
#
# **Im Konstruktor `__init__`:**
# - `self.name = name` bedeutet: **Speichere** den übergebenen `name` auf DIESEM Pferd.
# - Ohne `self` würde Python nicht wissen, wo die Variable hingehört – sie würde nur lokal existieren und nach dem Aufruf verschwinden.
#
# **In Methoden:**
# - `self.name` bedeutet: **Lese den Namen** von DIESEM Pferd.
# - Ohne `self` könnte die Methode nicht auf die Attribute des Objekts zugreifen – sie würde nicht wissen, ob es Lucky, Spirit oder ein anderes Pferd ist.
#
# **So funktioniert der Aufruf im Hintergrund:**
# - `lucky.wiehern()` wird von Python zu `Pony.wiehern(lucky)` übersetzt.
# - Das erste Argument ist immer das Objekt selbst – deshalb heißt der Parameter `self`.

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein junger Reiter hat versucht, die ersten Pferde-Klassen zu erstellen, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1: Klasse ohne Großbuchstaben

class pferd:
    name = "Stormy"

mein_pferd = pferd()
print(mein_pferd.name)

# %%
# 🐛 Bug #2: Falscher Konstruktor

class Reiter:
    def __init(name, level):
        name = name
        level = level

maria = Reiter("Maria", 3)
print(maria.name)

# %%
# 🐛 Bug #3: Methode ohne self

class Pferd:
    def __init__(self, name):
        self.name = name
    
    def galoppieren():
        print(f"{self.name} galoppiert! 🐎")

pferd = Pferd("Spirit")
pferd.galoppieren()

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Erstelle deine erste Pferdeklasse
#
# **Belohnung:** 300 Huf-Punkte + Pferdedecke
#
# Der Stallmeister braucht eine Übersicht aller Pferde im Hof!
#
# **Deine Aufgaben:**
#
# 1. **Klasse Pferd anlegen**
#    - Erstelle mit `class Pferd:` eine Klasse
#    - Füge im Konstruktor `__init__(self, name, rasse, alter, geschlecht)` die Attribute hinzu (z.B. `self.name = name`)
#
# 2. **Objekt erstellen**
#    - Erstelle ein Objekt: `lucky = Pferd("Lucky", "Isländer", 8, "Wallach")`
#    - Gib alle Eigenschaften mit `print()` aus
#
# 3. **Zweites Pferd**
#    - Erstelle ein zweites Pferd mit anderen Werten und gib seine Eigenschaften aus
#
# **Beispiel-Code zum Starten:**
# ```python
# class Pferd:
#     def __init__(self, name, rasse, alter, geschlecht):
#         self.name = name
#         self.rasse = rasse
#         self.alter = alter
#         self.geschlecht = geschlecht
#
# lucky = Pferd("Lucky", "Isländer", 8, "Wallach")
# print(f"Name: {lucky.name}, Rasse: {lucky.rasse}, Alter: {lucky.alter}, Geschlecht: {lucky.geschlecht}")
# ```
#
# **Bonus-Challenge:** Füge eine Methode `vorstellen()` hinzu, die eine kurze Beschreibung des Pferdes zurückgibt.
#
# **Erwartete Ausgabe:**
# ```
# Name: Lucky, Rasse: Isländer, Alter: 8, Geschlecht: Wallach
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Die Reitschule
#
# **Belohnung:** 400 Huf-Punkte + Reithelm
#
# Die Reitschule braucht eine Organisation für ihre Schüler und Pferde!
#
# **Deine Aufgaben:**
#
# 1. **Klasse Reiter anlegen**
#    - Erstelle `class Reiter:` mit `__init__(self, name, level=1, lieblingspferd="Keins")`
#    - Weise name, level und lieblingspferd zu
#
# 2. **Drei Reiter erstellen**
#    - Erstelle Objekte für Lisa, Tom und Sarah (mit unterschiedlichen Leveln)
#    - Gib name und level für jeden aus
#
# 3. **Erfahrensten finden**
#    - Gib aus, welcher Reiter den höchsten Level hat
#
# **Beispiel-Code zum Starten:**
# ```python
# class Reiter:
#     def __init__(self, name, level=1, lieblingspferd="Keins"):
#         self.name = name
#         self.level = level
#         self.lieblingspferd = lieblingspferd
#
# lisa = Reiter("Lisa", 3, "Lucky")
# print(f"{lisa.name}: Level {lisa.level}")
# ```
#
# **Bonus-Challenge:** Füge ein Attribut `spezialitaet` hinzu und gib es aus.
#
# **Erwartete Ausgabe:**
# ```
# Lisa: Level 3
# Tom: Level 1
# Sarah: Level 2
# Erfahrenste: Lisa
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Der Pferdestall
#
# **Belohnung:** 500 Huf-Punkte + Futtereimer
#
# Der Stall braucht eine Struktur für alle Pferde!
#
# **Deine Aufgaben:**
#
# 1. **Klasse Pferd anlegen**
#    - Erstelle `class Pferd:` mit `__init__(self, name, rasse, geschlecht)`; weise die Attribute zu
#
# 2. **Methode füttern()**
#    - Definiere `def füttern(self):` und gib darin `"Mampf! 🐴"` aus
#
# 3. **Zwei Pferde erstellen**
#    - Erstelle ein Islandpferd und ein Shetlandpony
#    - Rufe für beide `füttern()` auf und gib name und Rasse aus
#
# **Beispiel-Code zum Starten:**
# ```python
# class Pferd:
#     def __init__(self, name, rasse, geschlecht):
#         self.name = name
#         self.rasse = rasse
#         self.geschlecht = geschlecht
#     def füttern(self):
#         print("Mampf! 🐴")
#
# islander = Pferd("Spirit", "Isländer", "Wallach")
# islander.füttern()
# ```
#
# **Bonus-Challenge:** Füge eine Methode `streicheln()` hinzu, die eine Meldung ausgibt.
#
# **Erwartete Ausgabe:**
# ```
# Isländer: Spirit
# Mampf! 🐴
# Shetlandpony: Mini
# Mampf! 🐴
# ```

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten der erfahrenen Reitlehrerin (Reflexion)
#
# Bevor du weiterreitest, denke über diese Fragen nach:
#
# 1. **Was ist der Unterschied zwischen einer Klasse und einem Objekt?**
#
# 2. **Warum braucht jede Methode in einer Klasse den Parameter self?**
#
# 3. **Wann würdest du Klassen anstelle von einfachen Variablen verwenden?**
#
# Diskutiere deine Gedanken mit anderen Pferdefreunden!

# %% [markdown]
# ### 📖 Reiterhof-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **Klasse** 🏗️: Ein Stallplan für Pferde
# - **Objekt** 🐴: Ein konkretes Pferd
# - **Instanz** ⚡: Ein anderes Wort für Objekt
# - **Attribut** 💎: Eine Eigenschaft eines Pferdes
# - **Methode** 🎯: Eine Fähigkeit eines Pferdes
# - **Konstruktor** 🔨: Die __init__ Methode zur Geburt
# - **self** 🪞: Referenz auf das aktuelle Objekt – ermöglicht Methoden und dem Konstruktor, auf die Attribute genau dieses Objekts zuzugreifen
# - **Instantiierung** ✨: Das Erstellen eines Pferdes
# - **Blueprint** 📐: Ein anderes Wort für Klasse
# - **Eigenschaft** 🌟: Ein anderes Wort für Attribut
# - **Verhalten** 🎪: Die Aktionen eines Pferdes (Methoden)
# - **Zustand** 📊: Die Werte aller Attribute

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ✅ Klassen mit dem class-Schlüsselwort erstellen
# - ✅ Objekte von Klassen instanziieren
# - ✅ Attribute auf Objekten setzen und lesen
# - ✅ Methoden in Klassen definieren
# - ✅ Den Konstruktor __init__ verwenden
# - ✅ Den self-Parameter korrekt nutzen
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die finalen Herausforderungen!

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Wunderbar!** Du hast die OOP Grundlagen gemeistert!
#
# **Das hast du gelernt:**
# - Klassen als Baupläne für Pferde
# - Objekte als individuelle Pferde
# - Attribute als Eigenschaften
# - Methoden als Fähigkeiten
# - Konstruktoren für die Geburt
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🐴 **Pferdesport:** Pferdeverwaltung, Turniere, Training
# - 🌾 **Landwirtschaft:** Tierhaltung, Ernte, Maschinen
# - 🏇 **Reitställe:** Buchungen, Kunden, Pferde
# - 🦄 **Tierpflege:** Patienten, Behandlungen, Termine
# - 📊 **Pferdezucht:** Stammbäume, Zuchtprogramme
#
# **Als Nächstes:** In Woche 11 lernst du **OOP Fortgeschritten - Vererbung und Polymorphismus**!

# %% [markdown]
# ## 🏆 Abschluss-Challenge: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Herausforderungen sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 Huf-Punkte + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Das Stall-Management-System
#
# **Belohnung:** 500 Huf-Punkte + Stallmeister-Schlüssel
#
# Die Meisterreiterin braucht ein komplettes System für den Reiterhof!
#
# **Deine Aufgaben:**
#
# **1. Erstelle eine Klasse Pferd:**
#    - Mit Attributen: name, rasse, alter, geschlecht, gesundheit
#    - Die Klasse soll die Grundlage für alle Pferde sein
#    - Tipp: Nutze __init__ für alle Eigenschaften
#
# **2. Erstelle eine Klasse Stall:**
#    - Mit Attributen: name, kapazität, pferde (Liste)
#    - Erstelle eine Methode pferd_aufnehmen(pferd)
#    - Die Methode soll prüfen ob noch Platz ist
#
# **3. Erstelle eine Klasse Futter:**
#    - Mit Attributen: typ, menge, preis_pro_kg
#    - Erstelle eine Methode verbrauchen(menge)
#    - Die Methode soll den Vorrat reduzieren
#
# **4. Erstelle ein Buchungssystem:**
#    - Erstelle eine Klasse Buchung für Reitstunden
#    - Methoden: buchen(reiter, pferd, zeit), stornieren()
#    - Das System soll doppelte Buchungen vermeiden
#
# **5. Erstelle eine Reiter-Klasse:**
#    - Mit Attributen: name, erfahrung, gebuchte_stunden
#    - Methoden: reiten(pferd), lernen(), bewerten()
#    - Der Reiter verbessert sich mit jeder Stunde
#
# **6. Hauptprogramm:**
#    - Erstelle 2 Ställe mit je 10 Plätzen
#    - Fülle die Ställe mit 15 verschiedenen Pferden
#    - Erstelle 5 Reiter mit unterschiedlichen Fähigkeiten
#    - Simuliere eine Woche mit Buchungen und Fütterung
#    - Zeige die Auslastung der Ställe
#
# **Beispiel-Struktur:**
# ```python
# # So könntest du beginnen:
# import datetime
#
# class Pferd:
#     def __init__(self, name, rasse, alter, geschlecht, gesundheit):
#         # Beschreibung was die Klasse tut
#         pass
#
# # ... weitere Klassen hier
#
# # Hauptprogramm
# stall1 = Stall("Hauptstall", 10, [])
# # Verarbeite Pferde...
# ```
#
# **Bonus-Challenge:** Füge ein Veterinärsystem für kranke Pferde hinzu!
#
# **Erwartete Ausgabe:**
# ```
# Stall Hauptstall: 10/10 belegt
# Stall Nebenstall: 5/10 belegt
# Auslastung: 15 Pferde, 5 Reiter mit Buchungen
# ```

# %%
# 🐴 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Die Reitturnier-Organisation
#
# **Belohnung:** 600 Huf-Punkte + Goldmedaille
#
# Der Turnierveranstalter braucht ein komplettes System für Wettbewerbe!
#
# **Deine Aufgaben:**
#
# **1. Erstelle eine Klasse Reiter:**
#    - Mit Attributen: name, alter, verein, pferd, punkte
#    - Prüfe das Alter falls alter < 8
#    - Gib "Zu jung" zurück wenn alter < 8
#
# **2. Erstelle eine Klasse Pferd:**
#    - Mit Attributen: name, rasse, geschlecht, disziplin
#    - Erstelle eine Methode training(dauer)
#    - Das Pferd wird besser mit mehr Training
#
# **3. Erstelle eine Klasse Disziplin:**
#    - Mit Attributen: name, schwierigkeit, max_punkte
#    - Methoden: bewerten(reiter), note_vergeben(punkte)
#    - Behandle Fehler wenn punkte > max_punkte
#
# **4. Erstelle eine Klasse Richter:**
#    - Mit Attributen: name, erfahrung, disziplin
#    - Methoden: bewerten(reiter), kommentar_schreiben(reiter)
#    - Noten sind von 0 bis max_punkte
#
# **5. Erstelle eine Klasse Turnier:**
#    - Mit Attributen: name, datum, disziplinen, teilnehmer
#    - Methoden: anmelden(reiter), starten(), ergebnisse_anzeigen()
#    - Gruppiere und aggregiere Daten nach Disziplinen
#
# **6. Hauptprogramm:**
#    - Erstelle 3 Disziplinen (Dressur, Springen, Vielseitigkeit)
#    - Erstelle 20 Reiter mit unterschiedlichen Pferden
#    - Melde die Reiter zu den Disziplinen an
#    - Simuliere das Turnier mit Bewertung und Siegerehrung
#    - Zeige die Sieger in jeder Disziplin
#
# **Beispiel-Struktur:**
# ```python
# # So könntest du beginnen:
# import random
#
# class Reiter:
#     def __init__(self, name, alter, verein, pferd, punkte):
#         # Erkenne gültige Werte
#         pass
#
# def turnier_simulieren(turnier):
#     # Simuliere das Turnier
#     pass
#
# # ... weitere Klassen hier
#
# # Hauptprogramm
# turnier = Turnier("Sonnental-Cup", [], [])
# # Verarbeite Reiter...
# ```
#
# **Bonus-Challenge:** Füge eine Pokalwertung über alle Disziplinen hinzu!
#
# **Erwartete Ausgabe:**
# ```
# Sonnental-Cup: 20 Teilnehmer
# Sieger Dressur: [Name]
# Sieger Springen: [Name]
# Sieger Vielseitigkeit: [Name]
# ```

# %%
# 🐴 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Die Pferdetherapie-Praxis
#
# **Belohnung:** 400 Huf-Punkte + Therapie-Zertifikat
#
# Die Pferdetherapeutin braucht ein digitales System für ihre Patienten!
#
# **Deine Aufgaben:**
#
# **1. Erstelle eine Klasse Patient:**
#    - Mit Attributen: name, alter, diagnose, pferd, fortschritt
#    - Erstelle eine Methode therapie_stunde(dauer)
#    - Die Methode soll den Fortschritt basierend auf Dauer berechnen
#
# **2. Erstelle eine Klasse Therapiepferd:**
#    - Mit Attributen: name, rasse, charakter, belastbarkeit
#    - Methoden: arbeiten(dauer), ausruhen(), zustand_prüfen()
#    - Das Pferd wird müde bei zu viel Arbeit
#
# **3. Erstelle eine Klasse Termin:**
#    - Mit Attributen: datum, uhrzeit, patient, pferd, dauer
#    - Erstelle eine Methode stattfinden()
#    - Der Termin wird als abgeschlossen markiert
#
# **4. Erstelle eine Klasse Therapeut:**
#    - Mit Attributen: name, spezialisierung, erfahrung
#    - Methoden: termin_buchen(patient), behandlung_durchführen()
#    - Der Therapeut dokumentiert jeden Fortschritt
#
# **5. Erstelle eine Klasse Praxis:**
#    - Mit Attributen: name, patienten, pferde, termine, therapeuten
#    - Methoden: patient_aufnehmen(), termin_vergeben(), statistik_anzeigen()
#    - Verwalte alle Termine und Patienten
#
# **6. Hauptprogramm:**
#    - Erstelle 5 Therapiepferde mit unterschiedlichen Charakteren
#    - Erstelle 10 Patienten mit verschiedenen Diagnosen
#    - Die Praxis hat 2 Therapeuten
#    - Simuliere einen Monat mit Therapiestunden
#    - Zeige die Fortschritte aller Patienten
#
# **Beispiel-Struktur:**
# ```python
# # So könntest du beginnen:
# import datetime
#
# class Patient:
#     def __init__(self, name, alter, diagnose, pferd, fortschritt):
#         # Beschreibung was die Klasse tut
#         pass
#
# def therapie_simulieren(praxis):
#     # Simuliere die Therapie
#     pass
#
# # ... weitere Klassen hier
#
# # Hauptprogramm
# praxis = Praxis("Sonnental-Therapie", [], [], [], [])
# # Verarbeite Patienten...
# ```
#
# **Bonus-Challenge:** Füge ein Abrechnungssystem für die Krankenkassen hinzu!
#
# **Erwartete Ausgabe:**
# ```
# Sonnental-Therapie: 10 Patienten, 5 Pferde, 2 Therapeuten
# Fortschritte nach 4 Wochen: [Übersicht pro Patient]
# ```

# %%
# 🐴 Deine Lösung hier:

print()
print("🎉 +400 Huf-Punkte: Herausforderung abgeschlossen!")
print("🏆 Du hast die Meisterreiterin besiegt!")
print("⭐ Titel erhalten: Pferdeflüsterer")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 10 gemeistert!")
print("🐴 Nächste Woche: OOP Fortgeschritten - Vererbung und Polymorphismus!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen:

# %%
# ✅ Lösung Bug #1: Klasse ohne Großbuchstaben

# Problem: Klassen müssen mit einem Großbuchstaben beginnen
class Pferd:
    name = "Stormy"

mein_pferd = Pferd()
print(mein_pferd.name)

# %%
# ✅ Lösung Bug #2: Falscher Konstruktor

# Problem: __init__ braucht self als ersten Parameter – sonst weiß Python nicht,
# auf welchem Objekt die Attribute (name, level) gespeichert werden sollen.
class Reiter:
    def __init__(self, name, level):
        self.name = name
        self.level = level

maria = Reiter("Maria", 3)
print(maria.name)

# %%
# ✅ Lösung Bug #3: Methode ohne self

# Problem: Methoden brauchen immer self als ersten Parameter – ohne self kann
# die Methode nicht auf self.name zugreifen (sie weiß nicht, welches Pferd gemeint ist).
class Pferd:
    def __init__(self, name):
        self.name = name
    
    def galoppieren(self):
        print(f"{self.name} galoppiert! 🐎")

pferd = Pferd("Spirit")
pferd.galoppieren()
