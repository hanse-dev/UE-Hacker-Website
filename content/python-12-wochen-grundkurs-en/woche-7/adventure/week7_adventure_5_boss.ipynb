# %% [markdown]
# # 🐉 Boss Quests – ⚔️ Week 7 – Modules and Libraries: The Library of Borrowed Magic
# > ⚠️ Harder! Combines everything from this week.
#
# **⚠️ WARNING:** These quests are significantly harder! They combine everything you've learned.
#
# **Rewards:** 1500 XP total + legendary items!
#
# The Archivist himself now steps before you: whoever combines all his knowledge with theirs earns a place among the Masters of the Library.

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 1: The Archivist's Dice Tower
#
# **Reward:** 500 XP + Simulation Crystal
#
# At the heart of the library stands an old dice tower – whoever rolls the highest number wins the treasure hunt!
#
# **Step 1 – Rolling:**
# Generate one dice roll (1–6) for each of 3 players with `random.randint()` and print the results.
#
# **Step 2 – Winner:**
# Work out who rolled the highest number, and announce the winner.
#
# **Step 3 – Tournament:**
# Run 5 rounds and count who wins most often. Print the overall statistics at the end.
#
# **Bonus:** Add a "Magic Die" (1–20) as a joker round.

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss Quest 2: The Name Oracle
#
# **Reward:** 600 XP + Elemental Staff
#
# The library's oracle reads your fate from your name and the runes of chance.
#
# **Step 1 – Luck rune:**
# Let the user enter their name. Draw as many random runes from `string.ascii_uppercase` with `random.choice()` as the name has letters, and combine them into a "luck rune".
#
# **Step 2 – Prophecy:**
# Create a list of 6 prophecies and pick a matching one with `random.choice()`.
#
# **Step 3 – Horoscope:**
# Combine name, luck rune and prophecy into a personal horoscope text and print it.
#
# **Bonus:** Show how likely this prophecy was (in %, rounded).

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss Quest 3: The Random Dungeon
#
# **Reward:** 400 XP + Guild Master Certificate (Artifact)
#
# No adventure is ever the same – a brand new dungeon every time!
#
# **Step 1 – Create rooms:**
# Create lists of possible room types (e.g. "Treasure Room", "Trap", "Empty Room") and monsters. Randomly pick 5 rooms.
#
# **Step 2 – Assign monsters:**
# Randomly assign a monster to each room (or none – some rooms are safe).
#
# **Step 3 – Print the dungeon:**
# Print the dungeon room by room: number, type and contents. At the end, calculate how many lives the hero would need (1 life per 2 monsters, rounded up – e.g. with `(monster_count + 1) // 2`).
#
# **Bonus:** Let the player decide with `input()` whether they want to enter a dangerous room.

# %%
print()
print("🎉 +400 XP: Boss Quest complete!")
print("🏆 You have defeated the Archivist of Borrowed Magic!")
print("⭐ Title earned: Master of the Library of Pyralia")
print()
print("🎊 CONGRATULATIONS! You have mastered Week 7!")
print("📚 Next week: Dictionaries and Tuples!")

# %% [markdown]
# ---
#
# 🎊 **Congratulations!** You have mastered all the Boss Quests this week!
#
# **Coming up next:** Week 8 awaits!
