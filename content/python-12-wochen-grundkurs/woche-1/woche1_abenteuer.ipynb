# %% [markdown]
# # 🗺️ Woche 1 – Einführung und erstes Programm: Die Reise beginnt
#
# **XP zu verdienen:** 1000 Punkte
# **Boss:** Der Schweige-Drache der stummen Befehle

# %% [markdown]
# ## 🌟 Die Quest beginnt: Willkommen in Pythonia
#
# Willkommen, junger Abenteurer! Du betrittst die magische Welt von **Pythonia** – ein Land voller Geheimnissen und Abenteuer. In dieser Woche lernst du die vier wichtigsten **Zauberformeln**:
#
# **Deine Mission:**
# - Lerne, wie du Text mit `print()` ausgibst
# - Speichere Informationen in **Variablen**
# - Kombiniere Texte und Variablen zu Nachrichten
# - Füge Kommentare hinzu, um deinen Code zu erklären
#
# **Leg los!** Dein erster Zauber wartet schon...

# %% [markdown]
# ## 🧙 Was ist eine Zauberformel?
#
# Eine **Zauberformel** ist wie ein magischer Spruch, den du lernen musst - eine feste Abfolge von Worten und Gesten, die eine bestimmte Wirkung erzielt.
#
# **Stell dir vor:**
# - 🧙‍♂️ Ein Magier muss die richtigen Worte kennen
# - ✨ Jeder Zauber hat eine exakte Formel
# - 📚 Mit der Zeit lernst du immer mächtigere Zauber
# - 🎯 Am Ende kannst du komplexe Magie wirken
#
# **In der Programmierung lernen wir:**
# - Die grundlegenden Zauberformeln (Befehle) von Python
# - Wie man diese Formeln kombiniert
# - Wie man eigene Zauber erschafft (später)
#
# **Jede Zauberformel, die du meisterst, macht dich zu einem mächtigeren Magier!**

# %% [markdown]
# ## 📚 Zauberformel 1: Der `print()`-Zauber
#
# **Was es ist:** `print()` ist dein erster magischer Befehl. Er gibt Text auf dem Bildschirm aus.
#
# **Warum nützlich:**
# - 🔮 Lässt magische Schrift erscheinen
# - 📜 Schreibt Prophezeiungen und Boten
# - 🗺️ Erstellt Karten und Beschreibungen
# - 📖 Hält Abenteuer für die Nachwelt fest
#
# **Wichtig:** Text muss immer in Anführungszeichen `"` oder `'` stehen!

# %%
# Beispiel 1: Einfache Textausgabe
print("Hallo Welt!")
print("Willkommen in Pythonia!")

# Beispiel 2: Mehrere Zeilen
print("Dies ist dein erstes Programm.")
print("Du bist jetzt ein Programmierer!")

# Beispiel 3: Leere Zeile für bessere Übersicht
print()
print("=== Dein Programm läuft erfolgreich! ===")

# %% [markdown]
# ## 📦 Zauberformel 2: Variablen - Magische Behälter
#
# **Was es ist:** Eine Variable ist wie eine Schatztruhe mit Namen. Du kannst Informationen darin speichern und später wieder abrufen.
#
# **Warum nützlich:**
# - 💰 Bewahrt Schätze und Gold auf
# - ⚔️ Merkt sich die Namen berühmter Waffen
# - 🧪 Speichert Tränke und ihre Wirkung
# - 🔄 Kann jederzeit mit neuen Schätzen gefüllt werden
#
# **Wichtig:**
# - Text: in Anführungszeichen (`"Gandalf"`)
# - Zahlen: ohne Anführungszeichen (`42`)

# %%
# Beispiel 1: Verschiedene Variablentypen
held_name = "Aragorn"      # Text (String)
held_level = 1             # Zahl (Integer)
held_gold = 50             # Zahl (Integer)
held_kaempfer = True       # Wahrheitswert (Boolean)

# Beispiel 2: Variablen ausgeben
print("Helden-Name:")
print(held_name)
print("Level:")
print(held_level)
print("Gold:")
print(held_gold)

# Beispiel 3: Variablen können sich ändern
print("Gold vor dem Kampf: " + str(held_gold))
held_gold = 150  # Neuer Wert
print("Gold nach dem Sieg: " + str(held_gold))

# %% [markdown]
# ## ✨ Zauberformel 3: Texte kombinieren
#
# **Was es ist:** Mit `+` kannst du Texte und Variablen zu einer Nachricht verbinden.
#
# **Warum nützlich:**
# - 📜 Schreibt epische Heldengeschichten
# - 🏰 Erstellt Beschreibungen von Burgen
# - ⚔️ Kombiniert Waffennamen mit ihrer Stärke
# - 📊 Macht Ausgaben informativer und magischer
#
# **Wichtig:** Zahlen müssen mit `str()` in Text umgewandelt werden!

# %%
# Beispiel 1: Einfache Kombination
name = "Legolas"
waffe = "Bogen"
print("Held: " + name)
print("Waffe: " + waffe)

# Beispiel 2: Mit Zahlen (str() nötig!)
pfeile = 20
print("Pfeile: " + str(pfeile))

# Beispiel 3: Komplexe Sätze
print(name + " hat einen " + waffe + " mit " + str(pfeile) + " Pfeilen.")

# Beispiel 4: Mehrere Informationen
print()
print("=== CHARAKTERBOGEN ===")
print("Name: " + name)
print("Waffe: " + waffe)
print("Munition: " + str(pfeile) + " Pfeile")
print("=====================")

# %% [markdown]
# ## 🐛 Debug-Quest: Finde die Fehler!
#
# Ein junger Magier hat versucht, seine ersten Zauber zu wirken, aber etwas läuft schief! Finde die Fehler:

# %%
# 🐛 Bug #1: Fehlende Anführungszeichen

print(Hallo Welt)

# %%
# 🐛 Bug #2: Zahl ohne str()

alter = 25
print("Ich bin " + alter + " Jahre alt.")

# %%
# 🐛 Bug #3: Falsche Variable

name = "Gandalf"
print("Willkommen, " + nam)

# %% [markdown]
# ## 🎯 Haupt-Missionen: Beweise dein Können!
#
# Die Zeit ist gekommen, dein Wissen in echten Herausforderungen zu beweisen!

# %% [markdown]
# ### ⭐⭐☆☆☆ Mission 1: Der Zauberlehrling
#
# **Belohnung:** 300 XP + Magischer Grimoire
#
# Deine erste Prüfung als Zauberlehrling! Zeige, dass du die grundlegenden Zauberformeln beherrschst.
#
# **Was du tun sollst:**
# 1. **Namen nennen:** Nutze den print()-Befehl für deinen Namen
# 2. **Begrüßen:** Gib eine magische Begrüßung in einer zweiten Zeile aus
# 3. **Alter speichern:** Erstelle eine Variable für dein Alter
# 4. **Satz bilden:** Gib einen Satz aus, der dein Alter enthält
# 5. **Abstand schaffen:** Füge eine leere Zeile zwischen den Ausgaben ein
#
# **Tipp:** Nutze `print()` für leere Zeilen zur besseren Übersicht!
#
# **Bonus-Challenge:** Gib eine magische Formel aus!

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐☆☆ Mission 2: Der Schatzjäger
#
# **Belohnung:** 400 XP + Schatzkarte
#
# Du hast einen Schatz gefunden! Dokumentiere deinen Fund für die Gilde.
#
# **Was du tun sollst:**
# 1. **Schatzdaten erfassen:** Erstelle Variablen für Schatzname, Wert, Fundort
# 2. **Einzelwerte ausgeben:** Gib jeden Wert in einer eigenen Zeile aus
# 3. **Fund beschreiben:** Erstelle einen vollständigen Satz über den Schatzfund
# 4. **Überschrift setzen:** Gib eine Überschrift "SCHATZBERICHT" aus
# 5. **Bericht verfassen:** Kombiniere alle Informationen zu einem Gilde-Bericht
#
# **Tipp:** Nutze `print()` für leere Zeilen zur besseren Übersicht!
#
# **Bonus-Challenge:** Füge eine Bewertung des Schatzes hinzu!

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Mission 3: Der Held des Dorfes
#
# **Belohnung:** 500 XP + Heldenschwert
#
# Das Dorf wird von einem Ungeheuer bedroht! Erstelle ein Heldenprofil für den Retter.
#
# **Was du tun sollst:**
# 1. **Heldeneigenschaften festlegen:** Erstelle 5 Variablen für Heldendaten
# 2. **Dramatische Überschrift:** Gib eine epische Überschrift für das Profil aus
# 3. **Werte vorstellen:** Stelle jeden Heldenwert mit beschreibendem Text vor
# 4. **Geschichte erzählen:** Erstelle eine Heldengeschichte in 3 Sätzen
# 5. **Schlachtruf:** Beende mit einem kraftvollen Schlachtruf
#
# **Tipp:** Nutze `print()` für leere Zeilen zur besseren Übersicht!
#
# **Bonus-Challenge:** Füge eine magische Fähigkeit hinzu!

# %%
# 🎯 Deine Lösung hier:

# %% [markdown]
# ### 🤔 Weisheiten des alten Magiers (Reflexion)
#
# Bevor du weiterziehst, denke über diese Fragen nach:
#
# 1. **Warum müssen Texte immer in Anführungszeichen?**
#
# 2. **Was passiert, wenn du versuchst, eine Zahl direkt mit Text zu verbinden?**
#
# 3. **Wie können Variablen dir beim Programmieren helfen?**
#
# Diskutiere deine Gedanken mit anderen Abenteurern!

# %% [markdown]
# ### 📖 Zauberspruch-Lexikon (Schlüsselwörter)
#
# **Wichtige Begriffe dieser Woche:**
#
# - **print()** 🔮: Magischer Befehl zur Textausgabe
# - **Variable** 💰: Behälter zum Speichern von Informationen
# - **String** 📜: Text in Anführungszeichen
# - **Integer** 🔢: Ganze Zahl ohne Komma
# - **Boolean** ✅: Wahrheitswert (True/False)
# - **Verkettung** ⛓️: Verbinden von Texten mit `+`
# - **str()** 🔄: Wandelt Zahlen in Text um
# - **Kommentar** 📝: Erklärung im Code mit `#`
# - **Syntax** 📐: Regeln für korrekten Code
# - **Fehler** 🐛: Wenn der Code nicht funktioniert
# - **Debugging** 🔧: Fehler finden und beheben
# - **Ausgabe** 📺: Was auf dem Bildschirm erscheint

# %% [markdown]
# ### 🎯 Lernziele – Hast du sie erreicht?
#
# Überprüfe selbst, ob du diese Fähigkeiten gemeistert hast:
#
# - ✅ Text mit `print()` ausgeben
# - ✅ Informationen in Variablen speichern
# - ✅ Texte mit `+` und `str()` kombinieren
# - ✅ Kommentare mit `#` hinzufügen
# - ✅ Einfache Fehler finden und beheben
# - ✅ Eigene kleine Programme schreiben
#
# Wenn du alle Punkte abhaken kannst – Glückwunsch! Du bist bereit für die Boss-Quests!

# %% [markdown]
# ### 🏆 Zusammenfassung: Deine Reise
#
# **Fantastisch!** Du hast die Grundlagen der Programmierung gemeistert!
#
# **Das hast du gelernt:**
# - Wie du dem Computer mit `print()` Befehle gibst
# - Wie du Informationen in Variablen speicherst
# - Wie du Texte und Zahlen kombinierst
# - Wie du deinen Code mit Kommentaren erklärst
# - Wie du einfache Fehler selbst findest
#
# **In der echten Welt werden diese Grundlagen verwendet für:**
# - 🎮 **Spiele:** Anzeigen von Spielständen und Nachrichten
# - 📱 **Apps:** Benutzerbenachrichtigungen und Textanzeigen
# - 🌐 **Websites:** Dynamische Inhalte und Texte
# - 🤖 **Chatbots:** Antworten und Konversationen
# - 📊 **Datenanalyse:** Ausgabe von Ergebnissen und Berichten
#
# **Als Nächstes:** In Woche 2 lernst du **Datentypen und Variablen**!

# %% [markdown]
# ## 🐉 Boss-Kampf: Hausaufgaben-Quests
#
# **⚠️ ACHTUNG:** Diese Quests sind deutlich schwieriger! Sie kombinieren alles, was du gelernt hast.
#
# **Belohnungen:** Insgesamt 1500 XP + legendäre Items!

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 1: Der Turm des Wissens
#
# **Belohnung:** 500 XP + Kristallkugel
#
# Der alte Turm enthält uraltes Wissen. Entschlüssele die magischen Inschriften!
#
# **Was du tun sollst:**
# 1. **Weisheitsgedicht:** Schreibe 4 Zeilen über die Macht des Programmierens
# 2. **Verse bewahren:** Lege für jeden Vers eine eigene Variable an
# 3. **Gedicht verkünden:** Gib alle Zeilen untereinander aus
# 4. **Magische Signatur:** Füge eine Überschrift und einen Autorennamen hinzu
# 5. **Macht bewerten:** Gib eine Bewertung von 1-5 Sternen aus
# 6. **Essenz erklären:** Gib einen Satz aus, warum Programmieren magisch ist
#
# **Struktur-Tipp:**
# - Beginne mit einer magischen Überschrift
# - Gib dann jede Zeile des Gedichts aus
# - Füge am Ende die Bewertung und Erklärung hinzu
#
# **Bonus-Challenge:** Füge eine versteckte Botschaft im Code hinzu!

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐⭐ Boss-Quest 2: Der Fluch des Schweige-Drachen
#
# **Belohnung:** 600 XP + Drachenamulett
#
# Der Schweige-Drache hat den Dorfältesten verstummen lassen! Nur ein perfekter Zauber kann ihn heilen.
#
# **Was du tun sollst:**
# 1. **Heilungsrezept:** Erstelle eine Formel mit 3 magischen Zutaten
# 2. **Zutaten beschreiben:** Gib jede Zutat mit ihrer heilenden Wirkung aus
# 3. **Zauber weben:** Kombiniere alle Zutaten zu einem vollständigen Heilungszauber
# 4. **Incantation:** Gib den vollständigen Zauber als magischen Spruch aus
# 5. **Warnung:** Füge eine Warnung vor möglichen Nebenwirkungen hinzu
# 6. **Erfolg vermelden:** Erstelle eine Erfolgsmeldung nach der Heilung
#
# **Struktur-Tipp:**
# - Beginne mit einer Überschrift für das Heilungsritual
# - Liste jede Zutat mit ihrer Wirkung auf
# - Beende mit dem Zauber und der Erfolgsmeldung
#
# **Bonus-Challenge:** Schreibe den Zauber rückwärts für extra Macht!

# %%
# 🐉 Deine Lösung hier:

# %% [markdown]
# ### ⭐⭐⭐⭐☆ Boss-Quest 3: Das Portal der Möglichkeiten
#
# **Belohnung:** 400 XP + Portalschlüssel
#
# Ein magisches Portal öffnet sich - aber wohin führt es? Erstelle ein Portalprotokoll!
#
# **Was du tun sollst:**
# 1. **Portal beschreiben:** Beschreibe das Aussehen (Farbe, Form, Größe)
# 2. **Koordinaten ermitteln:** Gib 3 magische Koordinaten für das Portal aus
# 3. **Reisewarnung:** Erstelle eine Warnung für künftige Portalreisende
# 4. **Ziele aufzählen:** Gib die möglichen Reiseziele durch das Portal aus
# 5. **Rückkehrweg:** Füge eine Anweisung für die sichere Rückkehr hinzu
# 6. **Rätsel stellen:** Beende mit einem mysteriösen Rätsel über das Portal
#
# **Struktur-Tipp:**
# - Beginne mit einer Überschrift für das Portalprotokoll
# - Gib Beschreibung und Koordinaten an
# - Füge am Ende Warnungen und das Rätsel hinzu
#
# **Bonus-Challenge:** Kodiere eine geheime Botschaft im Portal!

# %%
# 🐉 Deine Lösung hier:

print()
print("🎉 +400 XP: Boss-Quest abgeschlossen!")
print("🏆 Du hast den Schweige-Drachen besiegt!")
print("⭐ Titel erhalten: Portal-Meister")
print()
print("🎊 GLÜCKWUNSCH! Du hast Woche 1 gemeistert!")
print("📚 Nächste Woche: Datentypen und Variablen!")

# %% [markdown]
# ## 🔧 Debug-Quest Lösungen
#
# **Hast du die Fehler gefunden?** Hier sind die Lösungen:

# %%
# ✅ Lösung Bug #1: Fehlende Anführungszeichen

# Problem: Text ohne Anführungszeichen
print("Hallo Welt")

# %%
# ✅ Lösung Bug #2: Zahl ohne str()

# Problem: Zahl kann nicht direkt mit Text verbunden werden
alter = 25
print("Ich bin " + str(alter) + " Jahre alt.")

# %%
# ✅ Lösung Bug #3: Falsche Variable

# Problem: Variable 'nam' existiert nicht
name = "Gandalf"
print("Willkommen, " + name)
